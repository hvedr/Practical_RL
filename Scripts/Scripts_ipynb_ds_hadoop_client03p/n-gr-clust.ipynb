# %%
res = {}
with open('./data/dialogs.txt') as f:
    buf = []
    name = None
    for line in f:
        line = line.strip()
        if line == '':
            continue
        if line[0] == '=': #header
            if name:
                res[name] = buf
            buf = []
            name = line[4:-4]
            #print("[%s]" % name)
            #break
        else:
            buf.append(line)

# %%
len(res)
# Out:
# 4039

# %%
for k in res:
    print(k)
    print(res[k])
    break
# Out:
# out-79600878288-78007552771-20161021-092303-1477030983.1131.mp3
# ['O: \xd0\xb7\xd0\xb4\xd1\x80\xd0\xb0\xd0\xb2\xd1\x81\xd1\x82\xd0\xb2\xd1\x83\xd0\xb9\xd1\x82\xd0\xb5', 'A: \xd0\xb7\xd0\xb4\xd1\x80\xd0\xb0\xd0\xb2\xd1\x81\xd1\x82\xd0\xb2\xd1\x83\xd0\xb9\xd1\x82\xd0\xb5', 'O: \xd1\x8d\xd1\x82\xd0\xbe \xd1\x81\xd0\xbe\xd1\x82\xd1\x80\xd1\x83\xd0\xb4\xd0\xbd\xd0\xb8\xd0\xba \xd0\xb1\xd0\xb0\xd0\xbd\xd0\xba\xd0\xb0 \xd1\x82\xd0\xb8\xd0\xbd\xd1\x8c\xd0\xba\xd0\xbe\xd1\x84\xd1\x84 \xd0\xb2\xd0\xb0\xd0\xbc \xd1\x81\xd0\xb5\xd0\xb9\xd1\x87\xd0\xb0\xd1\x81 \xd1\x83\xd0\xb4\xd0\xbe\xd0\xb1\xd0\xbd\xd0\xbe \xd1\x83\xd0\xb6\xd0\xb5 \xd1\x81\xd0\xb5\xd0\xb9\xd1\x87\xd0\xb0\xd1\x81 \xd1\x82\xd0\xb0\xd0\xbc', 'A: \xd1\x83\xd0\xb6\xd0\xb5 \xd0\xb4\xd0\xb0', 'O: \xd1\x83\xd0\xb4\xd0\xbe\xd0\xb1\xd0\xbd\xd0\xbe \xd0\xb4\xd0\xb0 \xd0\xb0 \xd1\x81 \xd1\x83 \xd1\x85\xd0\xbe\xd1\x87\xd1\x83 \xd1\x83\xd0\xb7\xd0\xbd\xd0\xb0\xd1\x82\xd1\x8c \xd0\xb2\xd0\xb0\xd0\xbc \xd0\xb7\xd0\xb2\xd0\xbe\xd0\xbd\xd0\xb8\xd0\xbb\xd0\xb8 \xd0\xbf\xd0\xbe \xd0\xbf\xd0\xbe\xd0\xb2\xd0\xbe\xd0\xb4\xd1\x83 \xd0\xba\xd0\xb0\xd1\x80\xd1\x82\xd1\x8b \xd0\xba\xd1\x80\xd0\xb5\xd0\xb4\xd0\xb8\xd1\x82\xd0\xbd\xd0\xb0\xd1\x8f \xd0\xb2\xd0\xb0\xd1\x81 \xd0\xbf\xd0\xbe\xd0\xbb\xd0\xbd\xd0\xbe\xd1\x81\xd1\x82\xd1\x8c\xd1\x8e \xd0\xbf\xd1\x80\xd0\xbe\xd0\xb8\xd0\xbd\xd1\x84\xd0\xbe\xd1\x80\xd0\xbc\xd0\xb8\xd1\x80\xd0\xbe\xd0\xb2\xd0\xb0\xd1\x82\xd1\x8c', 'A: \xd0\xbd\xd0\xb5\xd1\x82 \xd0\xbd\xd0\xb5\xd1\x82\xd1\x83 \xd0\xb4\xd0\xb5\xd0\xbb\xd0\xb0\xd0\xbb\xd0\xb8', 'O: \xd0\xbd\xd0\xb5 \xd0\xbf\xd0\xbe\xd0\xb3\xd0\xbe\xd0\xb2\xd0\xbe\xd1\x80\xd0\xb8\xd0\xbb\xd0\xb8 \xd0\xb4\xd0\xb0 \xd0\xb0 \xd1\x81\xd0\xba\xd0\xb0\xd0\xb6\xd0\xb8\xd1\x82\xd0\xb5 \xd0\xba\xd0\xb0\xd0\xba \xd1\x8f \xd0\xbc\xd0\xbe\xd0\xb3\xd1\x83 \xd0\xba \xd0\xb2\xd0\xb0\xd0\xbc \xd0\xbe\xd0\xb1\xd1\x80\xd0\xb0\xd1\x89\xd0\xb0\xd1\x82\xd1\x8c\xd1\x81\xd1\x8f', 'O: \xd0\xb7\xd0\xbd\xd0\xb0\xd0\xb5\xd1\x82\xd0\xb5 \xd0\xbe\xd1\x87\xd0\xb5\xd0\xbd\xd1\x8c \xd0\xbf\xd1\x80\xd0\xb8\xd1\x8f\xd1\x82\xd0\xbd\xd0\xbe \xd0\xb2\xd0\xb0\xd0\xbc \xd1\x81\xd0\xb5\xd0\xb9\xd1\x87\xd0\xb0\xd1\x81 \xd1\x83 \xd0\xb2\xd0\xb0\xd1\x81 \xd0\xb2\xd0\xbe\xd0\xb7\xd0\xbc\xd0\xbe\xd0\xb6\xd0\xbd\xd0\xbe\xd1\x81\xd1\x82\xd1\x8c \xd0\xb1\xd0\xb5\xd1\x81\xd0\xbf\xd0\xbb\xd0\xb0\xd1\x82\xd0\xbd\xd0\xbe \xd0\xb7\xd0\xb0\xd0\xbf\xd0\xbe\xd0\xbb\xd0\xbd\xd0\xb8\xd1\x82\xd1\x8c \xd0\xb7\xd0\xb0\xd1\x8f\xd0\xb2\xd0\xba\xd1\x83 \xd0\xbd\xd0\xb0 \xd1\x80\xd0\xb0\xd1\x81\xd1\x81\xd0\xbc\xd0\xbe\xd1\x82\xd1\x80\xd0\xb5\xd0\xbd\xd0\xb8\xd0\xb5 \xd0\xba\xd1\x80\xd0\xb5\xd0\xb4\xd0\xb8\xd1\x82\xd0\xbd\xd0\xbe\xd0\xb9 \xd0\xba\xd0\xb0\xd1\x80\xd1\x82\xd1\x8b \xd1\x82\xd0\xb8\xd0\xbd\xd1\x8c\xd0\xba\xd0\xbe\xd1\x84\xd1\x84 \xd0\xbf\xd0\xbb\xd0\xb0\xd1\x82\xd0\xb8\xd0\xbd\xd1\x83\xd0\xbc \xd0\xba\xd0\xb0\xd1\x80\xd1\x82\xd1\x8b \xd1\x81 \xd0\xbb\xd0\xb8\xd0\xbc\xd0\xb8\xd1\x82\xd0\xbe\xd0\xbc \xd0\xb4\xd0\xbe \xd1\x82\xd1\x80\xd1\x91\xd1\x85\xd1\x81\xd0\xbe\xd1\x82 \xd0\xbd\xd0\xb0 \xd1\x81\xd1\x83\xd0\xbc\xd0\xbc\xd1\x83 \xd0\xbc\xd0\xbe\xd0\xb6\xd0\xb5\xd1\x82\xd0\xb5 \xd1\x83\xd0\xb1\xd1\x80\xd0\xb0\xd1\x82\xd1\x8c \xd0\xbb\xd1\x8e\xd0\xb1\xd0\xbe\xd0\xb9 \xd0\xbf\xd0\xbe\xd0\xb6\xd0\xb5\xd0\xbb\xd0\xb0\xd0\xbd\xd0\xb8\xd1\x8f \xd0\xb2\xd1\x8b \xd1\x85\xd0\xbe\xd1\x82\xd0\xb8\xd1\x82\xd0\xb5 \xd0\xb1\xd1\x83\xd0\xb4\xd0\xb5\xd1\x82 \xd0\xbf\xd1\x80\xd0\xb5\xd0\xb4\xd0\xbe\xd1\x81\xd1\x82\xd0\xb0\xd0\xb2\xd0\xbb\xd0\xb5\xd0\xbd \xd0\xbb\xd1\x8c\xd0\xb3\xd0\xbe\xd1\x82\xd0\xbd\xd1\x8b\xd0\xb9 \xd0\xbf\xd0\xb5\xd1\x80\xd0\xb8\xd0\xbe\xd0\xb4 \xd0\xbd\xd0\xb0 \xd0\xbe\xd0\xbf\xd0\xbb\xd0\xb0\xd1\x82\xd1\x83 \xd0\xbf\xd0\xbe\xd0\xba\xd1\x83\xd0\xbf\xd0\xbe\xd0\xba \xd0\xb4\xd0\xbe', 'O: \xd0\xbf\xd1\x8f\xd1\x82\xd0\xb8 \xd0\xb4\xd0\xbd\xd0\xb5\xd0\xb9 \xd1\x82\xd0\xbe \xd0\xb5\xd1\x81\xd1\x82\xd1\x8c \xd0\xb2\xd1\x8b \xd1\x81\xd0\xbc\xd0\xbe\xd0\xb6\xd0\xb5\xd1\x82\xd0\xb5 \xd0\xbf\xd0\xbe\xd0\xbb\xd1\x8c\xd0\xb7\xd0\xbe\xd0\xb2\xd0\xb0\xd1\x82\xd1\x8c\xd1\x81\xd1\x8f \xd0\xb4\xd0\xb5\xd0\xbd\xd1\x8c\xd0\xb3\xd0\xb0\xd0\xbc\x ...

# %%
def ngr(s, n, res = dict(), prefix = ''):
    for i in range(len(s)-n+1):
        k = prefix + s[i:(i+n)]
        res[k] = res[k] + 1 if k in res else 1
    return res

# %%
ngr("привет", 1, dict(), 'x_')
# Out:
# {'x_в': 1, 'x_е': 1, 'x_и': 1, 'x_п': 1, 'x_р': 1, 'x_т': 1}

# %%
def tngr(talk, n):
    res = dict()
    for s in talk:
        if s[:3] == 'A: ':
            ngr(s[3:], n, res, 'a_')
        elif s[:3] == 'O: ':
            ngr(s[3:], n, res, 'o_')
    return res

# %%
tngr(res['out-79124124330-78007552771-20161021-101533-1477034133.14022.mp3'], 2)
# Out:
# {'a_ \xd0': 13,
#  'a_ \xd1': 4,
#  'a_\x80\xd0': 4,
#  'a_\x81\xd0': 2,
#  'a_\x81\xd1': 2,
#  'a_\x82 ': 1,
#  'a_\x82\xd0': 3,
#  'a_\x82\xd1': 2,
#  'a_\x83 ': 3,
#  'a_\x83\xd0': 2,
#  'a_\x87\xd0': 1,
#  'a_\x88\xd1': 1,
#  'a_\x8b ': 1,
#  'a_\x8b\xd1': 1,
#  'a_\x8c ': 1,
#  'a_\x8d\xd1': 1,
#  'a_\xb0 ': 4,
#  'a_\xb0\xd0': 6,
#  'a_\xb0\xd1': 1,
#  'a_\xb1\xd0': 4,
#  'a_\xb2\xd0': 1,
#  'a_\xb2\xd1': 1,
#  'a_\xb3\xd1': 1,
#  'a_\xb4\xd0': 4,
#  'a_\xb5 ': 3,
#  'a_\xb5\xd0': 3,
#  'a_\xb5\xd1': 2,
#  'a_\xb7\xd0': 2,
#  'a_\xb8\xd1': 1,
#  'a_\xba ': 1,
#  'a_\xba\xd0': 2,
#  'a_\xba\xd1': 1,
#  'a_\xbb\xd0': 1,
#  'a_\xbb\xd1': 2,
#  'a_\xbc ': 1,
#  'a_\xbc\xd0': 1,
#  'a_\xbc\xd1': 2,
#  'a_\xbd\xd0': 6,
#  'a_\xbd\xd1': 1,
#  'a_\xbe ': 2,
#  'a_\xbe\xd0': 5,
#  'a_\xbe\xd1': 4,
#  'a_\xbf\xd0': 1,
#  'a_\xd0\xb0': 12,
#  'a_\xd0\xb1': 4,
#  'a_\xd0\xb2': 2,
#  'a_\xd0\xb3': 1,
#  'a_\xd0\xb4': 4,
#  'a_\xd0\xb5': 9,
#  'a_\xd0\xb7': 2,
#  'a_\xd0\xb8': 1,
#  'a_\xd0\xba': 4,
#  'a_\xd0\xbb': 3,
#  'a_\xd0\xbc': 4,
#  'a_\xd0\xbd': 7,
#  'a_\xd0\xbe': 11,
#  'a_\xd0\xbf': 1,
#  'a_\xd1\x80': 4,
#  'a_\xd1\x81': 4,
#  'a_\xd1\x82': 7,
#  'a_\xd1\x83': 6,
#  'a_\xd1\x87': 1,
#  'a_\xd1\x88': 1,
#  'a_\xd1\x8b': 2,
#  'a_\xd1\x8c': 1,
#  'a_\xd1\x8d': 1,
#  'a_\xd1\x91': 1,
#  'o_ \xd0': 28,
#  'o_ \xd1': 14,
#  'o_\x80 ': 1,
#  'o_\x80\xd0': 11,
#  'o_\x80\xd1': 3,
#  'o_\x81 ': 2,
#  'o_\x81\xd0': 6,
#  'o_\x81\xd1': 3,
#  'o_\x82 ': 3,
#  'o_\x82\xd0': 8,
#  'o_\x82\xd1': 5,
#  'o_\x83 ': 1,
#  'o_\x83\xd0': 4,
#  'o_\x83\xd1': 2,
#  'o_\x84 ': 1,
#  'o_\x84\xd1': 1,
#  'o_\x85\xd0': 2,
#  'o_\x87\xd0': 1,
#  'o_\x87\xd1': 1,
#  'o_\x88\xd0': 1,
#  'o_\x8b ': 1,
#  'o_\x8b\xd0': 1,
#  'o_\x8b\xd1': 2,
#  'o_\x8c ': 6,
#  'o_\x8c\xd0': 2,
#  'o_\x8e ': 2,
#  'o_\x8e\xd1': 1,
#  'o_\x8f ': 5,
#  'o_\x8f\xd0': 2,
#  'o_\x8f\xd1': 2,
#  'o_\xb0 ': 1,
#  'o_\xb0\xd0': 11,
#  'o_\xb0\xd1': 5,
#  'o_\xb1\xd0': 2,
#  'o_\xb1\xd1': 3,
#  'o_\xb2\xd0': 10,
#  'o_\xb2\xd1': 8,
#  'o_\xb3\xd0': 3,
#  'o_\xb4\xd0': 7,
#  'o_\xb4\xd1': 2,
#  'o_\xb5 ': 4,
#  'o_\xb5\xd0': 15,
#  'o_\xb5\xd1': 4,
#  'o_\xb6\xd0': 4,
#  'o_\xb7\xd0': 4,
#  'o_\xb8 ': 3,
#  'o_\xb8\xd0': 7,
#  'o_\xb8\xd1': 5,
#  'o_\xb9 ': 1,
#  'o_\xb9\xd1': 1,
#  'o_\xba\xd0': 7,
#  'o_\xba\xd1': 1,
#  'o_\xbb\xd0': 7,
#  'o_\xbb\xd1': 1,
#  'o_\xbc ': 1,
#  'o_\xbc\xd0': 8,
#  'o_\xbc\xd1': 2,
#  'o_\xbd\xd0': 19,
#  'o_\xbd\xd1': 5,
#  'o_\xbe ': 10,
#  'o_\xbe\xd0': 15,
#  'o_\xbe\xd1': 7,
#  'o_\xbf\xd0': 4,
#  'o_\xbf\xd1': 2,
#  'o_\xd0\xb0': 18,
#  'o_\xd0\xb1': 5,
#  'o_\xd0\xb2': 18,
#  'o_\xd0\xb3': 3,
#  'o_\xd0\xb4': 9,
#  'o_\xd0\xb5': 25,
#  'o_\xd0\xb6': 4,
#  'o_\xd0\xb7': 4,
#  'o_\xd0\xb8': 15,
#  'o_\xd0\xb9': 2,
#  'o_\xd0\xba': 8,
#  'o_\xd0\xbb': 8,
#  'o_\xd0\xbc': 11,
#  'o_\xd0\xbd': 24,
#  'o_\xd0\xbe': 32,
#  'o_\xd0\xbf': 6,
#  'o_\xd1\x80': 15,
#  'o_\xd1\x81': 11,
#  'o_\xd1\x82': 16,
#  'o_\xd1\x83': 7,
#  'o_\xd1\x84': 2,
#  'o_\xd1\x85': 2,
#  'o_\xd1\x87': 2,
#  'o_\xd1\x88': 1,
#  'o_\xd1\x8b': 4,
#  'o_\xd1\x8c': 8,
#  'o_\xd1\x8e': 3,
#  'o_\xd1\x8f': 10}

# %%
def cos(d1, d2):
    norm = sum([d1[k]*d1[k] for k in d1])*sum([d2[k]*d2[k] for k in d2])
    norm = norm**0.5
    if norm == 0:
        return 0
    return sum([d1[k]*d2[k] for k in d1 if k in d2])/norm

# %%
n = 3
ngrs = {k: tngr(res[k], n) for k in res}

# %%
base = 'out-79124124330-78007552771-20161021-101533-1477034133.14022.mp3' #перезвоните
#base = 'out-79653676200-78007552771-20161021-104305-1477035785.21944.mp3' #нет сейчас работы
sim = sorted([(k, cos(ngrs[k], ngrs[base])) for k in ngrs], key = lambda x: -x[1])

# %%
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets

def f(i):
    print('name=%s\ncos=%f\n%s' % (sim[i][0], sim[i][1], '\n'.join(res[sim[i][0]])))
    return None
    #return str(res[sim[i][0]])   

interact(f, i = widgets.IntSlider(min=0,max=len(res)-1,step=1,value=0))
None
#interact(f, x=widgets.IntSlider(min=0,max=30,step=1,value=10))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-671d725e4893> in <module>()
# ----> 1 from ipywidgets import interact, interactive, fixed
#       2 import ipywidgets as widgets
#       3
#       4 def f(i):
#       5     print('name=%s\ncos=%f\n%s' % (sim[i][0], sim[i][1], '\n'.join(res[sim[i][0]])))
#
# ImportError: No module named ipywidgets

# %%
s = 'родственником'
v = ngr(s, n, dict(), prefix = 'o_')

sim = sorted([(k, cos(ngrs[k], v)) for k in ngrs], key = lambda x: -x[1])
