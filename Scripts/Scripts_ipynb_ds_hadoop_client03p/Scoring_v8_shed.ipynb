# %% [markdown]
# # Кредитный скоринг
# ## Оптимизация - ускорение работы алгоритма

# %%
##### Config
from pyspark import SparkConf, SparkContext, HiveContext
import re
import numpy as np
import pandas as pd
import datetime
from pyspark.mllib.regression import LabeledPoint
from pyspark.mllib.feature import HashingTF
from pyspark.mllib.classification import LogisticRegressionWithSGD, NaiveBayes, NaiveBayesModel
import scipy.sparse as sps
from pyspark.mllib.linalg import Vectors
from pyspark.mllib.linalg import SparseVector
from pyspark.mllib.evaluation import BinaryClassificationMetrics
import hashlib
from collections import Counter

hive_config_query = '''
set hive.vectorized.execution.enabled=true;
set hive.vectorized.execution.reduce.enabled = true;
set mapreduce.map.memory.mb=4096;
set mapreduce.map.child.java.opts=-Xmx4g;
set mapreduce.task.io.sort.mb=1024;
set mapreduce.reduce.child.java.opts=-Xmx4g;
set mapreduce.reduce.memory.mb=7000;
set mapreduce.reduce.shuffle.input.buffer.percent=0.5;
set mapreduce.input.fileinputformat.split.minsize=536870912;
set mapreduce.input.fileinputformat.split.maxsize=1073741824;
set hive.optimize.ppd=true;
set hive.merge.smallfiles.avgsize=536870912;
set hive.merge.mapredfiles=true;
set hive.merge.mapfiles=true;
set hive.hadoop.supports.splittable.combineinputformat=true;
set hive.exec.reducers.bytes.per.reducer=536870912;
set hive.exec.parallel=true;
set hive.exec.max.created.files=10000000;
set hive.exec.compress.output=true;
set hive.exec.dynamic.partition.mode=nonstrict;
set hive.exec.max.dynamic.partitions=1000000;
set hive.exec.max.dynamic.partitions.pernode=100000;
set io.seqfile.compression.type=BLOCK;
set mapreduce.map.failures.maxpercent=5;
'''

sc.stop()
conf = (SparkConf()
        .set("spark.executor.instances", 4)
        .set("spark.driver.maxResultSize", "16g")
        .set('spark.driver.memory','16g')
        .set("spark.executor.memory", '4g')
        .set("spark.yarn.executor.memoryOverhead", 1048)
       )
sc = SparkContext(conf=conf)
hc = HiveContext(sc)

for q in hive_config_query.split(';'):
    try:
        hc.sql(q)
    except:
        pass

# %%
options = ((1,180,'2016-12-01'),(2,60,'2000-01-01'),(3,30,'2000-01-01'),(4,10,'2000-01-01'),(5,2,'2000-01-01'))
queries=[]
for i,depth,startymd in options:
    queries.append(feat_gen_query_pattern.replace('#ind',str(i)).replace('#depth',str(depth)).replace('#startymd',startymd))
#print('\n\n'.join(queries))

# %%
import cPickle
import xgboost as xgb
from sklearn.feature_extraction import DictVectorizer
v1 = cPickle.load(open('data/ccall_scoring_dict_vectorizer','r'))
bst1 = cPickle.load(open('data/ccall_scoring_xgb.model','r'))
type(bst1),type(v1)

# %%
def metrics(y_true,y_score,lift = None, return_str = False):
    import sklearn
    import collections
    
    if True:
        
        res = collections.OrderedDict()
        samp_size = len(y_true)
        res['Sample size'] = samp_size
        res['Posit share'] = sum(y_true) * 1./ samp_size
        res['Sample size'] = len(y_true)
        res['AUC ROC'] = sklearn.metrics.roc_auc_score(y_true = y_true, y_score = y_score)
        res['AUC PR'] = sklearn.metrics.average_precision_score( y_true,  y_score)
        res['Log loss'] = sklearn.metrics.log_loss(y_true = y_true, y_pred = y_score)
        if lift:
            predictions_and_labels = sorted(zip(y_score,y_true), key = lambda e:-e[0])
            for l in lift:
                res['Lift ' + str(l)] = sum([e[1] for e in predictions_and_labels[:int(l * samp_size)]]) * 1. / int(l * samp_size) / res['Posit share']                
        if return_str:
            res = '\n'.join(['{:<12}: {:.5f}'.format(k,v) for (k,v) in res.items()]) + '.'
        return res

# %%
print(metrics(y_true = df_test['approve'],y_score = df_test['pred'], lift = [0.1,0.3,0.5,0.7,0.9],return_str = 1))

# %%
feat_gen_query_pattern_new2 = '''


-- 1/6. v#ind. Оптимизация кред скоринга. Генерация новых фичей.
create table user_kposminin.ccall_scoring_opt_new#ind_2 as 
  select 
     v.phone_mobile,     
     v.call_ymd,
     v.approve as approve,
     v.urlfr,
     t1.score as score1,
     t2.score as score2,
     t3.score as score3,
     t4.score as score4,
     v.cnt,
     v.hits,
     v.avg_duration,
     v.time_std, 
     v.ymd_range, 
     v.avg_hour,
     v.avg_hour_q10, 
     v.avg_hour_q90, 
     v.ymd_cnt,
     trim(pc.provider) as mob_provider,
     r.ind,
     r.pop_country_share, 
     r.pop_city_share, 
     r.population / r.area_sq_km as density,
     r.area_sq_km,
     trim(r.federal_district) as federal_district, 
     r.avg_salary_2015_rub, 
     r.utc_time_zone_val,
     substr(y.section_ind, 0, 6) as yaca_ind
  from
     user_kposminin.ccall_scoring_opt#ind_1 v
     left join user_kposminin.tgt_cnt_dates td1 on td1.ymd = v.call_ymd and td1.target = 'ccall_tinkoff_approve_from_fullapp'
     left join user_kposminin.urlfr_tgt_cnt t1 on t1.urlfr = v.urlfr and t1.target = td1.target and t1.ymd = td1.tgt_ymd
     left join (
       select urlfr,score from prod_features_liveinternet.urlfr_tgt_cnt_cumulative2
       where ymd = '2017-01-15' and target = 'tinkoff_platinum_approved_application03@tinkoff_action'
       and (cnt_total > 30000 or cnt_positive > 10)) t2 on t2.urlfr = v.urlfr
     left join (
       select urlfr,score from prod_features_liveinternet.urlfr_tgt_cnt_cumulative2
       where ymd = '2017-01-15' and target = 'tinkoff_platinum_complete_application03@tinkoff_action'
       and (cnt_total > 30000 or cnt_positive > 10)) t3 on t3.urlfr = v.urlfr
     left join user_kposminin.tgt_cnt_dates td2 on td2.ymd = v.call_ymd and td2.target = 'tinkoff_LON_CCR_default'
     left join user_kposminin.urlfr_tgt_cnt t4 on t4.urlfr = v.urlfr and t4.target = td2.target and t4.ymd = td2.tgt_ymd
     left join user_kposminin.yaca_urlfr y on y.urlfr = v.urlfr

     left join hermes.phone_codes pc on trim(pc.phone_code) = substr(v.phone_mobile,2,9)
     left join hermes.region_stat r on r.ind = pc.region_ind

;


-- 2/6. v#ind. Оптимизация кред скоринга. Генерация фичей.
create table user_kposminin.ccall_scoring_opt_new#ind_3 as 
select
  phone_mobile                   as phone_mobile,
  call_ymd                       as call_ymd, 
  yaca_ind                       as yaca_ind,
  sum(cnt)                       as visits_cnt
from user_kposminin.ccall_scoring_opt_new#ind_2 a
group by
  phone_mobile, call_ymd, yaca_ind 
;

set mapreduce.input.fileinputformat.split.minsize=536870912;
set mapreduce.input.fileinputformat.split.maxsize=268435456;
set hive.exec.reducers.bytes.per.reducer=268435456;

-- 3/6. v#ind. Оптимизация кред скоринга. Генерация фичей.
create table user_kposminin.ccall_scoring_opt_new#ind_5 as 
select 
  phone_mobile as phone_mobile, 
  call_ymd as call_ymd, 
  max(a.approve) as approve,
  count(*) as cnt, 
  sum(cnt) as visits_cnt, 
  sum(hits) as hits, 
  avg(avg_duration) as avg_duration, 
  avg(time_std) as avg_time_std, 
  avg(ymd_range) as avg_ymd_range, 
  avg(ymd_cnt) as avg_ymd_cnt, 
  avg(avg_hour) as avg_hour, 
  avg(avg_hour_q10) as avg_hour_q10, 
  avg(avg_hour_q90) as avg_hour_q90, 
  max(score1) as max_score1, 
  avg(score1) as avg_score1, 
  percentile_approx(score1,array(0.95,0.9,0.7,0.5,0.3)) as q_arr_score1, 
  max(score2) as max_score2, 
  avg(score2) as avg_score2, 
  percentile_approx(score2,array(0.95,0.9,0.7,0.5,0.3)) as q_arr_score2, 
  max(score3) as max_score3,
  avg(score3) as avg_score3, 
  percentile_approx(score3,array(0.95,0.9,0.7,0.5,0.3)) as q_arr_score3, 
  max(score4) as max_score4,
  avg(score4) as avg_score4, 
  percentile_approx(score4,array(0.95,0.9,0.7,0.5,0.3)) as q_arr_score4 
from user_kposminin.ccall_scoring_opt_new#ind_2 a 
group by a.phone_mobile, a.call_ymd
;

-- 4/6. v#ind. Оптимизация кред скоринга. Генерация фичей.
create table user_kposminin.ccall_scoring_opt_new#ind_5_part2 as 
select 
  phone_mobile as phone_mobile, 
  call_ymd as call_ymd, 
  sum(if(urlfr like 'e.mail.ru%',1,0)) as emailru,
  sum(if(urlfr like 'm.%',1,0))/sum(1) as mobile_share,
  sum(if(urlfr rlike '^(m\\.)?vk.com%', 1, 0))/sum(1) as vk_share,
  sum(if(urlfr like 'vk.com%' or urlfr rlike '^(m\\.)?ok\\.ru' or urlfr like 'm.odnoklassniki.ru%' or urlfr rlike '^(m\\.)?my.mail.ru',1,0))/sum(1) as social_share,

  sum(if(avg_hour >= 9 and avg_hour <= 20,cnt,0))/sum(1) as work_hours_hits_share,
  stddev(avg_hour) as hour_std,  
  count( if(score1 > 1, urlfr,Null))/sum(1) as good_urlfr_share_score1,
  count( if(score2 > -7, urlfr,Null))/sum(1) as good_urlfr_share_score2,
  count( if(score3 > -7, urlfr,Null))/sum(1) as good_urlfr_share_score3,
  avg( if(score1 > 1, time_std ,Null)) as good_urlfr_timestd_score1,
  max(
             named_struct(
             'score1', score1,
             'time_std', time_std
             )           
     ).time_std as max_urlfr_time_std_1,
  max(ind) as ind,                                        
  max(pop_country_share) as pop_country_share, 
  max(pop_city_share) as pop_city_share, 
  max(density) as density,
  max(area_sq_km) as area_sq_km,
  max(federal_district) as federal_district, 
  max(avg_salary_2015_rub) as avg_salary_2015_rub, 
  max(utc_time_zone_val) as utc_time_zone_val

from user_kposminin.ccall_scoring_opt_new#ind_2 a 
group by a.phone_mobile, a.call_ymd
;

 


-- 5/6. v#ind. Оптимизация кред скоринга. Генерация фичей.
create table user_kposminin.ccall_scoring_opt_new#ind_6 as 
select
  b.phone_mobile                 as phone_mobile,
  b.call_ymd                     as call_ymd, 
  concat_ws(" ",sort_array(collect_list(concat(b.yaca_ind,":",format_number(b.visits_cnt/greatest(c.visits_cnt,cast(1 as bigint)),5))))) as yaca_str
  
from user_kposminin.ccall_scoring_opt_new#ind_3 b 
  left join user_kposminin.ccall_scoring_opt_new#ind_5 c on c.phone_mobile = b.phone_mobile and c.call_ymd = b.call_ymd
group by
  b.phone_mobile, b.call_ymd ;
 
-- 6/6. v#ind. Оптимизация кред скоринга. Генерация фичей.
create table user_kposminin.ccall_scoring_opt_new#ind_scoring as
select
  a.*,
  c.emailru, 
  c.mobile_share, 
  c.vk_share, 
  c.social_share,
  c.work_hours_hits_share, 
  c.hour_std, 
  c.good_urlfr_share_score1, 
  c.good_urlfr_share_score2, 
  c.good_urlfr_share_score3, 
  c.good_urlfr_timestd_score1, 
  c.max_urlfr_time_std_1,
  c.pop_country_share, 
  c.pop_city_share, 
  c.density,
  c.area_sq_km,
  c.federal_district, 
  c.avg_salary_2015_rub, 
  c.utc_time_zone_val,
  b.yaca_str
from
  user_kposminin.ccall_scoring_opt_new#ind_5 a
  left join user_kposminin.ccall_scoring_opt_new#ind_6 b on b.phone_mobile = a.phone_mobile and b.call_ymd = a.call_ymd
  left join user_kposminin.ccall_scoring_opt_new#ind_5_part2 c on c.phone_mobile = a.phone_mobile and c.call_ymd = a.call_ymd
;

set mapreduce.input.fileinputformat.split.minsize=1073741824;
set mapreduce.input.fileinputformat.split.maxsize=536870912;
set hive.exec.reducers.bytes.per.reducer=536870912;


-- -- -- 

-- 1/2. v#ind. Оптимизация кред скоринга. Досчитаывание фич.
create table user_kposminin.ccall_scoring_opt_new#ind_5_part3 as 
select 
  phone_mobile as phone_mobile, 
  call_ymd as call_ymd, 
  min(score1) as min_score1, 
  min(score2) as min_score2, 
  min(score3) as min_score3, 
  min(score4) as min_score4 
from user_kposminin.ccall_scoring_opt_new#ind_2 a 
group by a.phone_mobile, a.call_ymd
;

-- 2/2. v#ind. Оптимизация кред скоринга. Досчитаывание фич.
create table user_kposminin.ccall_scoring_opt_new#ind_scoring_add as
select
  a.*,
  b.min_score1,
  b.min_score2,
  b.min_score3,
  b.min_score4
from
  user_kposminin.ccall_scoring_opt_new#ind_scoring a
  left join user_kposminin.ccall_scoring_opt_new#ind_5_part3 b on b.phone_mobile = a.phone_mobile and b.call_ymd = a.call_ymd
;

'''

# %%
#options = ((1,180,'2016-12-01'),(2,60,'2000-01-01'),(3,30,'2000-01-01'),(4,10,'2000-01-01'),(5,2,'2000-01-01'))
queries_new=[]
for i,depth,startymd in options:
    queries_new.append(feat_gen_query_pattern_new2.replace('#ind',str(i)).replace('#depth',str(depth)).replace('#startymd',startymd))
#print('\n\n'.join(queries_new[::-1]))
#print('\n\n'.join([';'.join(e.split(';')[-3:]) for e in queries_new]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-ae1d9b5de571> in <module>()
#       2 queries_new=[]
#       3 for i,depth,startymd in options:
# ----> 4     queries_new.append(feat_gen_query_pattern_new2.replace('#ind',str(i)).replace('#depth',str(depth)).replace('#startymd',startymd))
#       5 #print('\n\n'.join(queries_new[::-1]))
#       6 #print('\n\n'.join([';'.join(e.split(';')[-3:]) for e in queries_new]))
#
# NameError: name 'feat_gen_query_pattern_new2' is not defined

# %% [markdown]
# # Строим классификаторы

# %%
cols = [u'phone_mobile', u'call_ymd', u'approve', u'cnt', u'visits_cnt',
       u'hits', u'avg_duration', u'avg_time_std', u'avg_ymd_range',
       u'avg_ymd_cnt', u'avg_hour', u'avg_hour_q10', u'avg_hour_q90',
       u'max_score1', u'avg_score1', u'q95_score1', u'q90_score1',
       u'q70_score1', u'q50_score1', u'q30_score1', u'max_score2',
       u'avg_score2', u'q95_score2', u'q90_score2', u'q70_score2',
       u'q50_score2', u'q30_score2', u'max_score3', u'avg_score3',
       u'q95_score3', u'q90_score3', u'q70_score3', u'q50_score3',
       u'q30_score3',  u'max_score4', u'avg_score4',
       u'q95_score4', u'q90_score4', u'q70_score4', u'q50_score4',
       u'q30_score4', u'emailru', u'mobile_share', u'vk_share',
       u'social_share', u'work_hours_hits_share', u'hour_std',
       u'good_urlfr_share_score1', u'good_urlfr_share_score2',
       u'good_urlfr_share_score3', u'good_urlfr_timestd_score1',
       u'max_urlfr_time_std_1', u'pop_country_share',
       u'pop_city_share', u'density', u'area_sq_km', u'federal_district',
       u'avg_salary_2015_rub', u'utc_time_zone_val', u'yaca_str',u'min_score1',
       u'min_score2', u'min_score3', u'min_score4']

# %%
import cPickle
from sklearn.feature_extraction import DictVectorizer
import os
import sklearn, sklearn.cross_validation

v1 = cPickle.load(open('data/ccall_scoring_dict_vectorizer','r'))
type(v1)
federal_districts = [u'ЦФО',u'СЗФО',u'ЮФО',u'СКФО',u'ПФО',u'УФО',u'СФО',u'ДВФО'] # todo

def encode(v, classes, default_value = -1):
    '''Encode text value v which values are from classes list. Returns v index and -1 if it wasn't found in the list.'''
    try:
        return classes.index(v)
    except ValueError:
        return default_value
from pylightgbm.models import GBMClassifier

exec_path = "/opt/share/LightGBM-master/lightgbm"
os.environ["LIGHTGBM_EXEC"] = exec_path

# %%
feat_demogr = [ u'pop_country_share', u'pop_city_share', u'density', u'area_sq_km', u'federal_district', 
               u'avg_salary_2015_rub', u'utc_time_zone_val']
feat_urlfr_level = [u'avg_duration', u'avg_time_std', u'avg_ymd_range', u'avg_ymd_cnt', u'avg_hour', u'avg_hour_q10', u'avg_hour_q90']

yaca_cols = ['yaca_{}'.format(i) for i in range(416)]
feat_cols_w_yaca = feat_cols + yaca_cols
feat_list = [
    feat_cols_w_yaca, 
    feat_cols, 
    [c for c in feat_cols if not (('score2' in c) or ('score3' in c))],
    [c for c in feat_cols if not (('score4' in c))],
    [c for c in feat_cols if not (('score2' in c) or ('score3' in c) or ('score4' in c))],
    [c for c in feat_cols if not re.match('q[0-9]{,2}_',c)] ,
    [c for c in feat_cols if not re.match('q[0-9]{,2}',c)],
    [c for c in feat_cols if not (re.match('q[0-9]{,2}_',c) or (c in feat_urlfr_level))],
    [c for c in feat_cols if not (('score2' in c) or ('score3' in c) or re.match('q[0-9]{,2}',c))],
    [c for c in feat_cols if not (re.match('q[0-9]{,2}_',c) or (c in feat_demogr))],
    [u'avg_score1']
]

# %%
label = 'approve'

# %%
feat_select_res = {}

for ind,depth,_ in options[1:]: #((3,30,'2000-01-01'),):
    df_train = (hc.sql('select * from user_kposminin.ccall_scoring_opt_new#ind_scoring_add'.replace('#ind',str(ind)))
        .filter(' call_ymd <= "2016-11-15"')
        .map(lambda r: 
                list(r[:15]) + (r[15] if r[15] else [None] * 5) + list(r[16:18]) + (r[18] if r[18] else  [None] * 5)  + list(r[19:21]) + 
               (r[21] if r[21]  else [None] * 5)  + list(r[22:24]) + (r[24] if r[24]  else [None] * 5) + list(r[25:40]) + 
                [encode(r[40], federal_districts)] + list(r[41:])
            )
        .toDF()
        .toPandas()
         )
    '''
    # Handling categorial text columns
    enc = {} 
    categorial_cols = [56]
    for i in categorial_cols:
        enc[i] = sklearn.preprocessing.LabelEncoder()
        df_train.iloc[:,i] = enc[i].fit_transform(df_train.iloc[:,i])
    '''
                
    df_train.columns = cols
    feat_cols = [c for c in df_train.columns if not c in (u'phone_mobile', u'call_ymd', u'approve', u'yaca_str')]
    
    #Handle yaca columns
    df_train_yaca_dense = v1.transform(df_train['yaca_str'].map(lambda s: { kv.split(':')[0]:float(kv.split(':')[1])  for kv in s.split(' ')} if s else {}))
    yaca_cols = ['yaca_{}'.format(i) for i in range(df_train_yaca_dense.shape[1])]
    for i in range(df_train_yaca_dense.shape[1]):
        df_train.loc[:,'yaca_{}'.format(i)] = df_train_yaca_dense[:,i]
    feat_cols_w_yaca = feat_cols + yaca_cols
    
    #Test data formation
    df_test = (hc.sql('select * from user_kposminin.ccall_scoring_opt_new#ind_scoring_add'.replace('#ind',str(ind)))
        .filter(' call_ymd > "2016-11-15"')
        .map(lambda r: 
                list(r[:15]) + (r[15] if r[15] else [None] * 5) + list(r[16:18]) + (r[18] if r[18] else  [None] * 5)  + list(r[19:21]) + 
               (r[21] if r[21]  else [None] * 5)  + list(r[22:24]) + (r[24] if r[24]  else [None] * 5) + list(r[25:40]) + 
                [encode(r[40], federal_districts)] + list(r[41:])
            )
        .toDF()
        .toPandas()
         )
    
    df_test.columns = cols
    # Handling categrial text columns
    #for i in categorial_cols:
    #    df_test.iloc[:,i] = enc[i].transform(df_test.iloc[:,i])
        
    #Handle yaca columns
    df_test_yaca_dense = v1.transform(df_test['yaca_str'].map(lambda s: { kv.split(':')[0]:float(kv.split(':')[1])  for kv in s.split(' ')} if s else {}))
    yaca_cols = ['yaca_{}'.format(i) for i in range(df_test_yaca_dense.shape[1])]
    for i in range(df_test_yaca_dense.shape[1]):
        df_test.loc[:,'yaca_{}'.format(i)] = df_test_yaca_dense[:,i]
    
    clf = GBMClassifier(
        exec_path=exec_path,
        min_data_in_leaf=50,
       # is_unbalance = True,
        num_iterations = 200,
        bagging_fraction = 0.8,
        bagging_freq = 10,
        num_leaves = 127,
        learning_rate = 0.1,
        metric = 'auc',
        early_stopping_round=10
    )
    feat_select_res[ind] = []
    for feats in feat_list:
        cv_score = sklearn.cross_validation.cross_val_score(clf, df_train[feats], df_train[label], cv=5, scoring='roc_auc')
        feat_select_res[ind].append((feats,cv_score))

# %%
def cv(clf, X, y, folds = 5, metrics = 'roc_auc,pr_auc'):
    '''calc cross-validation metrics for clf classfier (actually LightGBM classifier) on X,y data '''
    assert X.shape[0] == len(y), 'X and y lengths doesnt match'
    idx = range(X.shape[0])
    np.random.shuffle(idx)
    fold_idx = []
    for i in range(folds):
        fold_idx.append(idx[i*len(idx)/folds:(i+1)*len(idx)/folds])
    res = {k:[] for k in metrics.split(',')}
    
    for i in range(folds):
        train_idx = reduce(lambda x,y: x+y,(fold_idx[:i] + fold_idx[(i+1):]))
        valid_idx = fold_idx[i]
        
        clf.fit(X[train_idx],y[train_idx])
        valid_pred = clf.predict_proba(X[valid_idx])[:,1]
        
        if('roc_auc' in metrics):
            res['roc_auc'].append(
                sklearn.metrics.roc_auc_score(
                  y_true = y[valid_idx],
                  y_score = valid_pred
                )
            )
        if('pr_auc' in metrics):
            res['pr_auc'].append(
                sklearn.metrics.average_precision_score(
                  y_true = y[valid_idx],
                  y_score = valid_pred
                )
            )
    return res

# %%
#df_train_yaca_dense[ind]

# %% [markdown]
# ## Выборки по всем вариантам

# %%
feat_select_res = {}
df_train,df_test,df_train_yaca_dense,df_test_yaca_dense = {}, {},{},{}

for ind,depth,_ in options[1:]: #((3,30,'2000-01-01'),):
    df_train[ind] = (hc.sql('select * from user_kposminin.ccall_scoring_opt_new#ind_scoring_add'.replace('#ind',str(ind)))
        .filter('call_ymd <= "2016-11-15"')
        .map(lambda r: 
                list(r[:15]) + (r[15] if r[15] else [None] * 5) + list(r[16:18]) + (r[18] if r[18] else  [None] * 5)  + list(r[19:21]) + 
               (r[21] if r[21]  else [None] * 5)  + list(r[22:24]) + (r[24] if r[24]  else [None] * 5) + list(r[25:40]) + 
                [encode(r[40], federal_districts)] + list(r[41:])
            )
        .toDF()
        .toPandas()
         )
                
    df_train[ind].columns = cols
    #feat_cols = [c for c in df_train.columns if not c in (u'phone_mobile', u'call_ymd', u'approve', u'yaca_str')]
    
    #Handle yaca columns
    df_train_yaca_dense[ind] = v1.transform(df_train[ind]['yaca_str'].map(lambda s: { kv.split(':')[0]:float(kv.split(':')[1])  for kv in s.split(' ')} if s else {}))
    #yaca_cols = ['yaca_{}'.format(i) for i in range(df_train_yaca_dense.shape[1])]
    for i in range(df_train_yaca_dense[ind].shape[1]):
        df_train[ind].loc[:,'yaca_{}'.format(i)] = df_train_yaca_dense[ind][:,i]
    #feat_cols_w_yaca = feat_cols + yaca_cols
    
    #Test data formation
    df_test[ind] = (hc.sql('select * from user_kposminin.ccall_scoring_opt_new#ind_scoring_add'.replace('#ind',str(ind)))
        .filter(' call_ymd > "2016-11-15"')
        .map(lambda r: 
                list(r[:15]) + (r[15] if r[15] else [None] * 5) + list(r[16:18]) + (r[18] if r[18] else  [None] * 5)  + list(r[19:21]) + 
               (r[21] if r[21]  else [None] * 5)  + list(r[22:24]) + (r[24] if r[24]  else [None] * 5) + list(r[25:40]) + 
                [encode(r[40], federal_districts)] + list(r[41:])
            )
        .toDF()
        .toPandas()
         )
    
    df_test[ind].columns = cols
    # Handling categrial text columns
    #for i in categorial_cols:
    #    df_test.iloc[:,i] = enc[i].transform(df_test.iloc[:,i])
        
    #Handle yaca columns
    df_test_yaca_dense[ind] = v1.transform(df_test[ind]['yaca_str'].map(lambda s: { kv.split(':')[0]:float(kv.split(':')[1])  for kv in s.split(' ')} if s else {}))
    #yaca_cols = ['yaca_{}'.format(i) for i in range(df_test_yaca_dense.shape[1])]
    for i in range(df_test_yaca_dense[ind].shape[1]):
        df_test[ind].loc[:,'yaca_{}'.format(i)] = df_test_yaca_dense[ind][:,i]

# %%
feat_select_res = {}

for ind,depth,_ in options[1:]: #((3,30,'2000-01-01'),):
    df_train = (hc.sql('select * from user_kposminin.ccall_scoring_opt_new#ind_scoring_add'.replace('#ind',str(ind)))
        .filter(' call_ymd <= "2016-11-15"')
        .map(lambda r: 
                list(r[:15]) + (r[15] if r[15] else [None] * 5) + list(r[16:18]) + (r[18] if r[18] else  [None] * 5)  + list(r[19:21]) + 
               (r[21] if r[21]  else [None] * 5)  + list(r[22:24]) + (r[24] if r[24]  else [None] * 5) + list(r[25:40]) + 
                [encode(r[40], federal_districts)] + list(r[41:])
            )
        .toDF()
        .toPandas()
         )
                
    df_train.columns = cols
    feat_cols = [c for c in df_train.columns if not c in (u'phone_mobile', u'call_ymd', u'approve', u'yaca_str')]
    
    #Handle yaca columns
    df_train_yaca_dense = v1.transform(df_train['yaca_str'].map(lambda s: { kv.split(':')[0]:float(kv.split(':')[1])  for kv in s.split(' ')} if s else {}))
    yaca_cols = ['yaca_{}'.format(i) for i in range(df_train_yaca_dense.shape[1])]
    for i in range(df_train_yaca_dense.shape[1]):
        df_train.loc[:,'yaca_{}'.format(i)] = df_train_yaca_dense[:,i]
    feat_cols_w_yaca = feat_cols + yaca_cols
    
    #Test data formation
    df_test = (hc.sql('select * from user_kposminin.ccall_scoring_opt_new#ind_scoring_add'.replace('#ind',str(ind)))
        .filter(' call_ymd > "2016-11-15"')
        .map(lambda r: 
                list(r[:15]) + (r[15] if r[15] else [None] * 5) + list(r[16:18]) + (r[18] if r[18] else  [None] * 5)  + list(r[19:21]) + 
               (r[21] if r[21]  else [None] * 5)  + list(r[22:24]) + (r[24] if r[24]  else [None] * 5) + list(r[25:40]) + 
                [encode(r[40], federal_districts)] + list(r[41:])
            )
        .toDF()
        .toPandas()
         )
    
    df_test.columns = cols
    # Handling categrial text columns
    #for i in categorial_cols:
    #    df_test.iloc[:,i] = enc[i].transform(df_test.iloc[:,i])
        
    #Handle yaca columns
    df_test_yaca_dense = v1.transform(df_test['yaca_str'].map(lambda s: { kv.split(':')[0]:float(kv.split(':')[1])  for kv in s.split(' ')} if s else {}))
    yaca_cols = ['yaca_{}'.format(i) for i in range(df_test_yaca_dense.shape[1])]
    for i in range(df_test_yaca_dense.shape[1]):
        df_test.loc[:,'yaca_{}'.format(i)] = df_test_yaca_dense[:,i]
    
    feat_list = [
        feat_cols_w_yaca, 
        feat_cols, 
        [c for c in feat_cols if not (('score2' in c) or ('score3' in c))],
        [c for c in feat_cols if not (('score4' in c))],
        [c for c in feat_cols if not (('score2' in c) or ('score3' in c) or ('score4' in c))],
        [c for c in feat_cols if not re.match('q[0-9]{,2}_',c)],
        [c for c in feat_cols if not re.match('q[0-9]{,2}',c)],
        [c for c in feat_cols if not (re.match('q[0-9]{,2}_',c) or (c in feat_urlfr_level))],
        [c for c in feat_cols if not (('score2' in c) or ('score3' in c) or re.match('q[0-9]{,2}_',c))],
        [c for c in feat_cols if not (re.match('q[0-9]{,2}_',c) or (c in feat_demogr))],
        [u'avg_score1']
    
    ]
    clf = GBMClassifier(
        exec_path=exec_path,
        min_data_in_leaf=50,
       # is_unbalance = True,
        num_iterations = 120,
        bagging_fraction = 0.8,
        bagging_freq = 10,
        num_leaves = 127,
        learning_rate = 0.05,
        metric = 'auc',
        verbose=False
    )
    feat_select_res[ind] = []
    for feats in feat_list:
        print('Calcs cv scores for {} dataset and {} feats'.format(ind,feat_list.index(feats)))
        res = cv(clf,df_train[feats].values, df_train[label].values, folds=5)
        feat_select_res[ind].append((feats,res))
        
cPickle.dump(feat_select_res,open('res.pck','w'))

# %%
feat_select_res = cPickle.load(open('res.pck','r'))
df_res = pd.DataFrame([(k,e[0],e[1]['pr_auc'],e[1]['roc_auc']) for e in v for (k,v) in feat_select_res.items()], columns = ['option','feats','cv_pr','cv_roc'])
df_res['avg_roc'] = df_res['cv_roc'].map(lambda l: sum(l)/len(l))
df_res['std_roc'] = df_res['cv_roc'].map(lambda l: np.std(l))
df_res['min_roc'] = df_res['cv_roc'].map(lambda l: min(l))
df_res['max_roc'] = df_res['cv_roc'].map(lambda l: max(l))
df_res['feats_len'] = df_res['feats'].map(lambda l: len(l))
#[(k,) + e for e in v for (k,v) in feat_select_res.items()]
df_res.sort('avg_roc',ascending = False)
#feats = df_res.sort('avg_roc',ascending = False).iloc[5,1]
# Out:
#     option                                              feats  \
# 0        2  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 2        4  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 3        5  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 1        3  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 4        2  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 5        3  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 6        4  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 7        5  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 15       5  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 12       2  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 13       3  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 14       4  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 23       5  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 21       3  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 20       2  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 22       4  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 24       2  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 25       3  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 26       4  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 27       5  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 30       4  [cnt, visits_cnt, hits, max_score1, avg_score1...
# 28       2  [cnt, visits_cnt, hits, max_score1, avg_score1...
# 29       3  [cnt, visits_cnt, hits, max_score1, avg_score1...
# 31       5  [cnt, visits_cnt, hits, max_score1, avg_score1...
# 11       5  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 10       4  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 9        3  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 8        2  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 32       2  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 35       5  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 34       4  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 33       3  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 16       2  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 17       3  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 19       5  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 18       4  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 36       2  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 37       3  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 38       4  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 39       5  [cnt, visits_cnt, hits, avg_duration, avg_time...
# 40       2                                       [avg_score1]
# 41       3                                       [avg_score1]
# 42       4                                       [avg_score1]
# 43       5                                       [avg_score1]
#
#                                                 cv_pr  \
# 0   [0.46171284226, 0.454653102457, 0.455256580161...
# 2   [0.46171284226, 0.454653102457, 0.455256580161...
# 3   [0.46171284226, 0.454653102457, 0.455256580161...
# 1   [0.46171284226, 0.454653102457, 0.455256580161...
# 4   [0.457834118698, 0.456891651205, 0.45381510211...
# 5   [0.457834118698, 0.456891651205, 0.45381510211...
# 6   [0.457834118698, 0.456891651205, 0.45381510211...
# 7   [0.457834118698, 0.456891651205, 0.45381510211...
# 15  [0.459055536053, 0.455869400292, 0.45752311552...
# 12  [0.459055536053, 0.455869400292, 0.45752311552...
# 13  [0.459055536053, 0.455869400292, 0.45752311552...
# 14  [0.459055536053, 0.455869400292, 0.45752311552...
# 23  [0.456459189831, 0.45022801753, 0.459099201208...
# 21  [0.456459189831, 0.45022801753, 0.459099201208...
# 20  [0.456459189831, 0.45022801753, 0.459099201208...
# 22  [0.456459189831, 0.45022801753, 0.459099201208...
# 24  [0.453282771766, 0.453522573252, 0.45609484192...
# 25  [0.453282771766, 0.453522573252, 0.45609484192...
# 26  [0.453282771766, 0.453522573252, 0.45609484192...
# 27  [0.453282771766, 0.453522573252, 0.45609484192...
# 30  [0.447595894518, 0.449199520512, 0.45367292062...
# 28  [0.447595894518, 0.449199520512, 0.45367292062...
# 29  [0.447595894518, 0.449199520512, 0.45367292062...
# %%
clf = GBMClassifier(
        exec_path=exec_path,
        min_data_in_leaf=50,
       # is_unbalance = True,
        num_iterations = 120,
        bagging_fraction = 0.8,
        bagging_freq = 10,
        num_leaves = 127,
        learning_rate = 0.05,
        metric = 'auc',
        verbose=True
    )

#r = cv(clf,df_train[feats].values, df_train[label].values, folds=5)

# %%
X, y, folds = df_train[3][feats].values, df_train[3][label].values, 5

if 1:
    idx = range(X.shape[0])
    np.random.shuffle(idx)
    fold_idx = []
    for i in range(folds):
        fold_idx.append(idx[i*len(idx)/folds:(i+1)*len(idx)/folds])
    res = {k:[] for k in metrics.split(',')}
    
    for i in range(folds):
        train_idx = reduce(lambda x,y: x+y,(fold_idx[:i] + fold_idx[(i+1):]))
        valid_idx = fold_idx[i]
        
        clf.fit(X[train_idx],y[train_idx],test_data = [(X[valid_idx],y[valid_idx])])
        valid_pred = clf.predict_proba(X[valid_idx])[:,1]
        
        if('roc_auc' in metrics):
            res['roc_auc'].append(
                sklearn.metrics.roc_auc_score(
                  y_true = y[valid_idx],
                  y_score = valid_pred
                )
            )
        if('pr_auc' in metrics):
            res['pr_auc'].append(
                sklearn.metrics.average_precision_score(
                  y_true = y[valid_idx],
                  y_score = valid_pred
                )
            )
res
# Out:
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Warning] Ignoring feature Column_40, only has one value
# [LightGBM] [Info] Finished loading data in 6.332858 seconds
# [LightGBM] [Info] Number of postive: 87344, number of negative: 156230
# [LightGBM] [Info] Number of data: 243574, number of features: 59
# [LightGBM] [Info] Finished initializing training
# [LightGBM] [Info] Started training...
# [LightGBM] [Info] Iteration:1, valid_1 auc : 0.641248
# [LightGBM] [Info] 0.288513 seconds elapsed, finished iteration 1
# [LightGBM] [Info] Iteration:2, valid_1 auc : 0.644312
# [LightGBM] [Info] 0.581842 seconds elapsed, finished iteration 2
# [LightGBM] [Info] Iteration:3, valid_1 auc : 0.647194
# [LightGBM] [Info] 0.872055 seconds elapsed, finished iteration 3
# [LightGBM] [Info] Iteration:4, valid_1 auc : 0.650007
# [LightGBM] [Info] 1.165749 seconds elapsed, finished iteration 4
# [LightGBM] [Info] Iteration:5, valid_1 auc : 0.651715
# [LightGBM] [Info] 1.456718 seconds elapsed, finished iteration 5
# [LightGBM] [Info] Iteration:6, valid_1 auc : 0.651978
# [LightGBM] [Info] 1.757428 seconds elapsed, finished iteration 6
# [LightGBM] [Info] Iteration:7, valid_1 auc : 0.652695
# [LightGBM] [Info] 2.173054 seconds elapsed, finished iteration 7
# [LightGBM] [Info] Iteration:8, valid_1 auc : 0.653323
# [LightGBM] [Info] 2.554679 seconds elapsed, finished iteration 8
# [LightGBM] [Info] Iteration:9, valid_1 auc : 0.654143
# [LightGBM] [Info] 2.973793 seconds elapsed, finished iteration 9
# [LightGBM] [Info] Iteration:10, valid_1 auc : 0.654593
# [LightGBM] [Info] 3.259305 seconds elapsed, finished iteration 10
# [LightGBM] [Info] Iteration:11, valid_1 auc : 0.655255
# [LightGBM] [Info] 3.553498 seconds elapsed, finished iteration 11
# [LightGBM] [Info] Iteration:12, valid_1 auc : 0.655650
# [LightGBM] [Info] 3.844831 seconds elapsed, finished iteration 12
# [LightGBM] [Info] Iteration:13, valid_1 auc : 0.656253
# [LightGBM] [Info] 4.143461 seconds elapsed, finished iteration 13
# [LightGBM] [Info] Iteration:14, valid_1 auc : 0.656534
# [LightGBM] [Info] 4.431857 seconds elapsed, finished iteration 14
# [LightGBM] [Info] Iteration:15, valid_1 auc : 0.656874
# [LightGBM] [Info] 4.854495 seconds elapsed, finished iteration 15
# [LightGBM] [Info] Iteration:16, valid_1 auc : 0.657123
# [LightGBM] [Info] 5.147825 seconds elapsed, finished iteration 16
# [LightGBM] [Info] Iteration:17, valid_1 auc : 0.657231
# [LightGBM] [Info] 5.589753 seconds elapsed, finished iteration 17
# [LightGBM] [Info] Iteration:18, valid_1 auc : 0.657564
# [LightGBM] [Info] 6.060055 seconds elapsed, finished iteration 18
# [LightGBM] [Info] Iteration:19, valid_1 auc : 0.657631
# [LightGBM] [Info] 6.358176 seconds elapsed, finished iteration 19
# [LightGBM] [Info] Iteration:20, valid_1 auc : 0.657821
# [LightGBM] [Info] 6.657762 seconds elapsed, finished iteration 20
# [LightGBM] [Info] Iteration:21, valid_1 auc : 0.658023
# [LightGBM] [Info] 6.955113 seconds elapsed, finished iteration 21
# [LightGBM] [Info] Iteration:22, valid_1 auc : 0.658153
# [LightGBM] [Info] 7.228685 seconds elapsed, finished iteration 22
# [LightGBM] [Info] Iteration:23, valid_1 auc : 0.658258
# [LightGBM] [Info] 7.518479 seconds elapsed, finished iteration 23
# [LightGBM] [Info] Iteration:24, valid_1 auc : 0.658464
# [LightGBM] [Info] 7.797757 seconds elapsed, finished iteration 24
# [LightGBM] [Info] Iteration:25, valid_1 auc : 0.658596
# [LightGBM] [Info] 8.081714 seconds elapsed, finished iteration 25
# [LightGBM] [Info] Iteration:26, valid_1 auc : 0.658894
# [LightGBM] [Info] 8.359825 seconds elapsed, finished iteration 26
# [LightGBM] [Info] Iteration:27, valid_1 auc : 0.659280
# [LightGBM] [Info] 8.637875 seconds elapsed, finished iteration 27
# [LightGBM] [Info] Iteration:28, valid_1 auc : 0.659494
# [LightGBM] [Info] 9.100919 seconds elapsed, finished iteration 28
# [LightGBM] [Info] Iteration:29, valid_1 auc : 0.659618
# [LightGBM] [Info] 9.486628 seconds elapsed, finished iteration 29
# [LightGBM] [Info] Iteration:30, valid_1 auc : 0.659771
# [LightGBM] [Info] 9.777897 seconds elapsed, finished iteration 30
# [LightGBM] [Info] Iteration:31, valid_1 auc : 0.660073
# [LightGBM] [Info] 10.197725 seconds elapsed, finished iteration 31
# [LightGBM] [Info] Iteration:32, valid_1 auc : 0.660259
# [LightGBM] [Info] 10.490529 seconds elapsed, finished iteration 32
# [LightGBM] [Info] Iteration:33, valid_1 auc : 0.660474
# [LightGBM] [Info] 10.774216 seconds elapsed, finished iteration 33
# [LightGBM] [Info] Iteration:34, valid_1 auc : 0.660551
# [LightGBM] [Info] 11.043819 seconds elapsed, finished iteration 34
# [LightGBM] [Info] Iteration:35, valid_1 auc : 0.660616
# [LightGBM] [Info] 11.435814 seconds elapsed, finished iteration 35
# [LightGBM] [Info] Iteration:36, valid_1 auc : 0.660845
# [LightGBM] [Info] 11.834293 seconds elapsed, finished iteration 36
# [LightGBM] [Info] Iteration:37, valid_1 auc : 0.660884
# [LightGBM] [Info] 12.266789 seconds elapsed, finished iteration 37
# [LightGBM] [Info] Iteration:38, valid_1 auc : 0.660960
# [LightGBM] [Info] 12.544992 seconds elapsed, finished iteration 38
# [LightGBM] [Info] Iteration:39, valid_1 auc : 0.661061
# [LightGBM] [Info] 12.943539 seconds elapsed, finished iteration 39
# [LightGBM] [Info] Iteration:40, valid_1 auc : 0.661306
# [LightGBM] [Info] 13.326646 seconds elapsed, finished iteration 40
# [LightGBM] [Info] Iteration:41, valid_1 auc : 0.661435
# [LightGBM] [Info] 13.594994 seconds elapsed, finished iteration 41
# [LightGBM] [Info] Iteration:42, valid_1 auc : 0.661528
# [LightGBM] [Info] 14.028773 seconds elapsed, finished iteration 42
# [LightGBM] [Info] Iteration:43, valid_1 auc : 0.661762
# [LightGBM] [Info] 14.428919 seconds elapsed, finished iteration 43
# [LightGBM] [Info] Iteration:44, valid_1 auc : 0.661830
# [LightGBM] [Info] 14.804577 seconds elapsed, finished iteration 44
# [LightGBM] [Info] Iteration:45, valid_1 auc : 0.661856
# [LightGBM] [Info] 15.187205 seconds elapsed, finished iteration 45
# [LightGBM] [Info] Iteration:46, valid_1 auc : 0.661944
# [LightGBM] [Info] 15.446297 seconds elapsed, finished iteration 46
# [LightGBM] [Info] Iteration:47, valid_1 auc : 0.662061
# [LightGBM] [Info] 15.700346 seconds elapsed, finished iteration 47
# [LightGBM] [Info] Iteration:48, valid_1 auc : 0.662162
# [LightGBM] [Info] 15.968394 seconds elapsed, finished iteration 48
# [LightGBM] [Info] Iteration:49, valid_1 auc : 0.662202
# [LightGBM] [Info] 16.241971 seconds elapsed, finished iteration 49
# [LightGBM] [Info] Iteration:50, valid_1 auc : 0.662349
# [LightGBM] [Info] 16.494779 seconds elapsed, finished iteration 50
# [LightGBM] [Info] Iteration:51, valid_1 auc : 0.662484
# [LightGBM] [Info] 16.896589 seconds elapsed, finished iteration 51
# [LightGBM] [Info] Iteration:52, valid_1 auc : 0.662613
# [LightGBM] [Info] 17.295028 seconds elapsed, finished iteration 52
# [LightGBM] [Info] Iteration:53, valid_1 auc : 0.662694
# [LightGBM] [Info] 17.549817 seconds elapsed, finished iteration 53
# [LightGBM] [Info] Iteration:54, valid_1 auc : 0.662845
# [LightGBM] [Info] 17.810718 seconds elapsed, finished iteration 54
# [LightGBM] [Info] Iteration:55, valid_1 auc : 0.662924
# [LightGBM] [Info] 18.052125 seconds elapsed, finished iteration 55
# [LightGBM] [Info] Iteration:56, valid_1 auc : 0.663105
# [LightGBM] [Info] 18.315373 seconds elapsed, finished iteration 56
# [LightGBM] [Info] Iteration:57, valid_1 auc : 0.663236
# [LightGBM] [Info] 18.572828 seconds elapsed, finished iteration 57
# [LightGBM] [Info] Iteration:58, valid_1 auc : 0.663259
# [LightGBM] [Info] 18.923951 seconds elapsed, finished iteration 58
# [LightGBM] [Info] Iteration:59, valid_1 auc : 0.663347
# [LightGBM] [Info] 19.157712 seconds elapsed, finished iteration 59
# [LightGBM] [Info] Iteration:60, valid_1 auc : 0.663338
# [LightGBM] [Info] 19.565459 seconds elapsed, finished iteration 60
# [LightGBM] [Info] Iteration:61, valid_1 auc : 0.663336
# [LightGBM] [Info] 19.927794 seconds elapsed, finished iteration 61
# [LightGBM] [Info] Iteration:62, valid_1 auc : 0.663408
# [LightGBM] [Info] 20.169678 seconds elapsed, finished iteration 62
# [LightGBM] [Info] Iteration:63, valid_1 auc : 0.663458
# [LightGBM] [Info] 20.396441 seconds elapsed, finished iteration 63
# [LightGBM] [Info] Iteration:64, valid_1 auc : 0.663553
# [LightGBM] [Info] 20.634881 seconds elapsed, finished iteration 64
# [LightGBM] [Info] Iteration:65, valid_1 auc : 0.663576
# [LightGBM] [Info] 21.008355 seconds elapsed, finished iteration 65
# [LightGBM] [Info] Iteration:66, valid_1 auc : 0.663663
# [LightGBM] [Info] 21.351150 seconds elapsed, finished iteration 66
# [LightGBM] [Info] Iteration:67, valid_1 auc : 0.663757
# [LightGBM] [Info] 21.584821 seconds elapsed, finished iteration 67
# [LightGBM] [Info] Iteration:68, valid_1 auc : 0.663891
# [LightGBM] [Info] 21.931010 seconds elapsed, finished iteration 68
# [LightGBM] [Info] Iteration:69, valid_1 auc : 0.663890
# [LightGBM] [Info] 22.298576 seconds elapsed, finished iteration 69
# [LightGBM] [Info] Iteration:70, valid_1 auc : 0.664003
# [LightGBM] [Info] 22.591978 seconds elapsed, finished iteration 70
# [LightGBM] [Info] Iteration:71, valid_1 auc : 0.664070
# [LightGBM] [Info] 23.058178 seconds elapsed, finished iteration 71
# [LightGBM] [Info] Iteration:72, valid_1 auc : 0.664085
# [LightGBM] [Info] 23.341352 seconds elapsed, finished iteration 72
# [LightGBM] [Info] Iteration:73, valid_1 auc : 0.664077
# [LightGBM] [Info] 23.662306 seconds elapsed, finished iteration 73
# [LightGBM] [Info] Iteration:74, valid_1 auc : 0.664198
# [LightGBM] [Info] 23.925843 seconds elapsed, finished iteration 74
# [LightGBM] [Info] Iteration:75, valid_1 auc : 0.664240
# [LightGBM] [Info] 24.163977 seconds elapsed, finished iteration 75
# [LightGBM] [Info] Iteration:76, valid_1 auc : 0.664248
# [LightGBM] [Info] 24.540763 seconds elapsed, finished iteration 76
# [LightGBM] [Info] Iteration:77, valid_1 auc : 0.664238
# [LightGBM] [Info] 24.771937 seconds elapsed, finished iteration 77
# [LightGBM] [Info] Iteration:78, valid_1 auc : 0.664248
# [LightGBM] [Info] 25.097276 seconds elapsed, finished iteration 78
# [LightGBM] [Info] Iteration:79, valid_1 auc : 0.664320
# [LightGBM] [Info] 25.319812 seconds elapsed, finished iteration 79
# [LightGBM] [Info] Iteration:80, valid_1 auc : 0.664271
# [LightGBM] [Info] 25.635416 seconds elapsed, finished iteration 80
# [LightGBM] [Info] Iteration:81, valid_1 auc : 0.664291
# [LightGBM] [Info] 25.854444 seconds elapsed, finished iteration 81
# [LightGBM] [Info] Iteration:82, valid_1 auc : 0.664295
# [LightGBM] [Info] 26.080827 seconds elapsed, finished iteration 82
# [LightGBM] [Info] Iteration:83, valid_1 auc : 0.664322
# [LightGBM] [Info] 26.287027 seconds elapsed, finished iteration 83
# [LightGBM] [Info] Iteration:84, valid_1 auc : 0.664288
# [LightGBM] [Info] 26.495618 seconds elapsed, finished iteration 84
# [LightGBM] [Info] Iteration:85, valid_1 auc : 0.664351
# [LightGBM] [Info] 26.856712 seconds elapsed, finished iteration 85
# [LightGBM] [Info] Iteration:86, valid_1 auc : 0.664418
# [LightGBM] [Info] 27.082351 seconds elapsed, finished iteration 86
# [LightGBM] [Info] Iteration:87, valid_1 auc : 0.664354
# [LightGBM] [Info] 27.288787 seconds elapsed, finished iteration 87
# [LightGBM] [Info] Iteration:88, valid_1 auc : 0.664346
# [LightGBM] [Info] 27.476697 seconds elapsed, finished iteration 88
# [LightGBM] [Info] Iteration:89, valid_1 auc : 0.664360
# [LightGBM] [Info] 27.666736 seconds elapsed, finished iteration 89
# [LightGBM] [Info] Iteration:90, valid_1 auc : 0.664414
# [LightGBM] [Info] 27.882411 seconds elapsed, finished iteration 90
# [LightGBM] [Info] Iteration:91, valid_1 auc : 0.664445
# [LightGBM] [Info] 28.108044 seconds elapsed, finished iteration 91
# [LightGBM] [Info] Iteration:92, valid_1 auc : 0.664495
# [LightGBM] [Info] 28.472505 seconds elapsed, finished iteration 92
# [LightGBM] [Info] Iteration:93, valid_1 auc : 0.664490
# [LightGBM] [Info] 28.676729 seconds elapsed, finished iteration 93
# [LightGBM] [Info] Iteration:94, valid_1 auc : 0.664494
# [LightGBM] [Info] 28.860787 seconds elapsed, finished iteration 94
# [LightGBM] [Info] Iteration:95, valid_1 auc : 0.664524
# [LightGBM] [Info] 29.058685 seconds elapsed, finished iteration 95
# [LightGBM] [Info] Iteration:96, valid_1 auc : 0.664552
# [LightGBM] [Info] 29.275471 seconds elapsed, finished iteration 96
# [LightGBM] [Info] Iteration:97, valid_1 auc : 0.664570
# [LightGBM] [Info] 29.489718 seconds elapsed, finished iteration 97
# [LightGBM] [Info] Iteration:98, valid_1 auc : 0.664673
# [LightGBM] [Info] 29.686461 seconds elapsed, finished iteration 98
# [LightGBM] [Info] Iteration:99, valid_1 auc : 0.664720
# [LightGBM] [Info] 29.978865 seconds elapsed, finished iteration 99
# [LightGBM] [Info] Iteration:100, valid_1 auc : 0.664748
# [LightGBM] [Info] 30.187024 seconds elapsed, finished iteration 100
# [LightGBM] [Info] Iteration:101, valid_1 auc : 0.664787
# [LightGBM] [Info] 30.383304 seconds elapsed, finished iteration 101
# [LightGBM] [Info] Iteration:102, valid_1 auc : 0.664831
# [LightGBM] [Info] 30.596683 seconds elapsed, finished iteration 102
# [LightGBM] [Info] Iteration:103, valid_1 auc : 0.664832
# [LightGBM] [Info] 30.955982 seconds elapsed, finished iteration 103
# [LightGBM] [Info] Iteration:104, valid_1 auc : 0.664902
# [LightGBM] [Info] 31.172091 seconds elapsed, finished iteration 104
# [LightGBM] [Info] Iteration:105, valid_1 auc : 0.664960
# [LightGBM] [Info] 31.376601 seconds elapsed, finished iteration 105
# [LightGBM] [Info] Iteration:106, valid_1 auc : 0.664931
# [LightGBM] [Info] 31.727020 seconds elapsed, finished iteration 106
# [LightGBM] [Info] Iteration:107, valid_1 auc : 0.664951
# [LightGBM] [Info] 31.898878 seconds elapsed, finished iteration 107
# [LightGBM] [Info] Iteration:108, valid_1 auc : 0.664882
# [LightGBM] [Info] 32.077463 seconds elapsed, finished iteration 108
# [LightGBM] [Info] Iteration:109, valid_1 auc : 0.664852
# [LightGBM] [Info] 32.253263 seconds elapsed, finished iteration 109
# [LightGBM] [Info] Iteration:110, valid_1 auc : 0.664902
# [LightGBM] [Info] 32.549716 seconds elapsed, finished iteration 110
# [LightGBM] [Info] Iteration:111, valid_1 auc : 0.664817
# [LightGBM] [Info] 32.875641 seconds elapsed, finished iteration 111
# [LightGBM] [Info] Iteration:112, valid_1 auc : 0.664787
# [LightGBM] [Info] 33.071364 seconds elapsed, finished iteration 112
# [LightGBM] [Info] Iteration:113, valid_1 auc : 0.664817
# [LightGBM] [Info] 33.267849 seconds elapsed, finished iteration 113
# [LightGBM] [Info] Iteration:114, valid_1 auc : 0.664825
# [LightGBM] [Info] 33.452800 seconds elapsed, finished iteration 114
# [LightGBM] [Info] Iteration:115, valid_1 auc : 0.664830
# [LightGBM] [Info] 33.639796 seconds elapsed, finished iteration 115
# [LightGBM] [Info] Iteration:116, valid_1 auc : 0.664792
# [LightGBM] [Info] 33.817169 seconds elapsed, finished iteration 116
# [LightGBM] [Info] Iteration:117, valid_1 auc : 0.664792
# [LightGBM] [Info] 34.008667 seconds elapsed, finished iteration 117
# [LightGBM] [Info] Iteration:118, valid_1 auc : 0.664768
# [LightGBM] [Info] 34.178559 seconds elapsed, finished iteration 118
# [LightGBM] [Info] Iteration:119, valid_1 auc : 0.664783
# [LightGBM] [Info] 34.318236 seconds elapsed, finished iteration 119
# [LightGBM] [Info] Iteration:120, valid_1 auc : 0.664719
# [LightGBM] [Info] 34.505048 seconds elapsed, finished iteration 120
# [LightGBM] [Info] Finished training
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading 120 models
# [LightGBM] [Info] Finished initializing prediction
# [LightGBM] [Info] Finished prediction
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Warning] Ignoring feature Column_40, only has one value
# [LightGBM] [Info] Finished loading data in 6.825486 seconds
# [LightGBM] [Info] Number of postive: 87432, number of negative: 156142
# [LightGBM] [Info] Number of data: 243574, number of features: 59
# [LightGBM] [Info] Finished initializing training
# [LightGBM] [Info] Started training...
# [LightGBM] [Info] Iteration:1, valid_1 auc : 0.645056
# [LightGBM] [Info] 0.296621 seconds elapsed, finished iteration 1
# [LightGBM] [Info] Iteration:2, valid_1 auc : 0.648708
# [LightGBM] [Info] 0.571901 seconds elapsed, finished iteration 2
# [LightGBM] [Info] Iteration:3, valid_1 auc : 0.650418
# [LightGBM] [Info] 1.030145 seconds elapsed, finished iteration 3
# [LightGBM] [Info] Iteration:4, valid_1 auc : 0.651107
# [LightGBM] [Info] 1.330535 seconds elapsed, finished iteration 4
# [LightGBM] [Info] Iteration:5, valid_1 auc : 0.651635
# [LightGBM] [Info] 1.753357 seconds elapsed, finished iteration 5
# [LightGBM] [Info] Iteration:6, valid_1 auc : 0.652453
# [LightGBM] [Info] 2.048807 seconds elapsed, finished iteration 6
# [LightGBM] [Info] Iteration:7, valid_1 auc : 0.652847
# [LightGBM] [Info] 2.337347 seconds elapsed, finished iteration 7
# [LightGBM] [Info] Iteration:8, valid_1 auc : 0.653281
# [LightGBM] [Info] 2.620574 seconds elapsed, finished iteration 8
# [LightGBM] [Info] Iteration:9, valid_1 auc : 0.653424
# [LightGBM] [Info] 2.904633 seconds elapsed, finished iteration 9
# [LightGBM] [Info] Iteration:10, valid_1 auc : 0.653604
# [LightGBM] [Info] 3.194407 seconds elapsed, finished iteration 10
# [LightGBM] [Info] Iteration:11, valid_1 auc : 0.654296
# [LightGBM] [Info] 3.484559 seconds elapsed, finished iteration 11
# [LightGBM] [Info] Iteration:12, valid_1 auc : 0.654730
# [LightGBM] [Info] 3.773857 seconds elapsed, finished iteration 12
# [LightGBM] [Info] Iteration:13, valid_1 auc : 0.655068
# [LightGBM] [Info] 4.178267 seconds elapsed, finished iteration 13
# [LightGBM] [Info] Iteration:14, valid_1 auc : 0.655271
# [LightGBM] [Info] 4.482276 seconds elapsed, finished iteration 14
# [LightGBM] [Info] Iteration:15, valid_1 auc : 0.655640
# [LightGBM] [Info] 4.759856 seconds elapsed, finished iteration 15
# [LightGBM] [Info] Iteration:16, valid_1 auc : 0.656013
# [LightGBM] [Info] 5.043208 seconds elapsed, finished iteration 16
# [LightGBM] [Info] Iteration:17, valid_1 auc : 0.656236
# [LightGBM] [Info] 5.325212 seconds elapsed, finished iteration 17
# [LightGBM] [Info] Iteration:18, valid_1 auc : 0.656450
# [LightGBM] [Info] 5.612084 seconds elapsed, finished iteration 18
# [LightGBM] [Info] Iteration:19, valid_1 auc : 0.656602
# [LightGBM] [Info] 5.885966 seconds elapsed, finished iteration 19
# [LightGBM] [Info] Iteration:20, valid_1 auc : 0.656947
# [LightGBM] [Info] 6.169932 seconds elapsed, finished iteration 20
# [LightGBM] [Info] Iteration:21, valid_1 auc : 0.657257
# [LightGBM] [Info] 6.454298 seconds elapsed, finished iteration 21
# [LightGBM] [Info] Iteration:22, valid_1 auc : 0.657641
# [LightGBM] [Info] 6.742955 seconds elapsed, finished iteration 22
# [LightGBM] [Info] Iteration:23, valid_1 auc : 0.657891
# [LightGBM] [Info] 7.021041 seconds elapsed, finished iteration 23
# [LightGBM] [Info] Iteration:24, valid_1 auc : 0.658104
# [LightGBM] [Info] 7.291507 seconds elapsed, finished iteration 24
# [LightGBM] [Info] Iteration:25, valid_1 auc : 0.658366
# [LightGBM] [Info] 7.566440 seconds elapsed, finished iteration 25
# [LightGBM] [Info] Iteration:26, valid_1 auc : 0.658563
# [LightGBM] [Info] 7.845247 seconds elapsed, finished iteration 26
# [LightGBM] [Info] Iteration:27, valid_1 auc : 0.658903
# [LightGBM] [Info] 8.240314 seconds elapsed, finished iteration 27
# [LightGBM] [Info] Iteration:28, valid_1 auc : 0.659185
# [LightGBM] [Info] 8.651528 seconds elapsed, finished iteration 28
# [LightGBM] [Info] Iteration:29, valid_1 auc : 0.659400
# [LightGBM] [Info] 8.940456 seconds elapsed, finished iteration 29
# [LightGBM] [Info] Iteration:30, valid_1 auc : 0.659558
# [LightGBM] [Info] 9.210455 seconds elapsed, finished iteration 30
# [LightGBM] [Info] Iteration:31, valid_1 auc : 0.659704
# [LightGBM] [Info] 9.501354 seconds elapsed, finished iteration 31
# [LightGBM] [Info] Iteration:32, valid_1 auc : 0.659876
# [LightGBM] [Info] 9.784823 seconds elapsed, finished iteration 32
# [LightGBM] [Info] Iteration:33, valid_1 auc : 0.660004
# [LightGBM] [Info] 10.076925 seconds elapsed, finished iteration 33
# [LightGBM] [Info] Iteration:34, valid_1 auc : 0.660138
# [LightGBM] [Info] 10.633731 seconds elapsed, finished iteration 34
# [LightGBM] [Info] Iteration:35, valid_1 auc : 0.660308
# [LightGBM] [Info] 10.959197 seconds elapsed, finished iteration 35
# [LightGBM] [Info] Iteration:36, valid_1 auc : 0.660380
# [LightGBM] [Info] 11.363807 seconds elapsed, finished iteration 36
# [LightGBM] [Info] Iteration:37, valid_1 auc : 0.660504
# [LightGBM] [Info] 11.755844 seconds elapsed, finished iteration 37
# [LightGBM] [Info] Iteration:38, valid_1 auc : 0.660576
# [LightGBM] [Info] 12.015233 seconds elapsed, finished iteration 38
# [LightGBM] [Info] Iteration:39, valid_1 auc : 0.660684
# [LightGBM] [Info] 12.257395 seconds elapsed, finished iteration 39
# [LightGBM] [Info] Iteration:40, valid_1 auc : 0.660767
# [LightGBM] [Info] 12.520835 seconds elapsed, finished iteration 40
# [LightGBM] [Info] Iteration:41, valid_1 auc : 0.660967
# [LightGBM] [Info] 12.785420 seconds elapsed, finished iteration 41
# [LightGBM] [Info] Iteration:42, valid_1 auc : 0.661055
# [LightGBM] [Info] 13.050012 seconds elapsed, finished iteration 42
# [LightGBM] [Info] Iteration:43, valid_1 auc : 0.661172
# [LightGBM] [Info] 13.314408 seconds elapsed, finished iteration 43
# [LightGBM] [Info] Iteration:44, valid_1 auc : 0.661358
# [LightGBM] [Info] 13.568721 seconds elapsed, finished iteration 44
# [LightGBM] [Info] Iteration:45, valid_1 auc : 0.661459
# [LightGBM] [Info] 13.828753 seconds elapsed, finished iteration 45
# [LightGBM] [Info] Iteration:46, valid_1 auc : 0.661574
# [LightGBM] [Info] 14.227563 seconds elapsed, finished iteration 46
# [LightGBM] [Info] Iteration:47, valid_1 auc : 0.661701
# [LightGBM] [Info] 14.483147 seconds elapsed, finished iteration 47
# [LightGBM] [Info] Iteration:48, valid_1 auc : 0.661844
# [LightGBM] [Info] 14.746882 seconds elapsed, finished iteration 48
# [LightGBM] [Info] Iteration:49, valid_1 auc : 0.661780
# [LightGBM] [Info] 15.117404 seconds elapsed, finished iteration 49
# [LightGBM] [Info] Iteration:50, valid_1 auc : 0.661871
# [LightGBM] [Info] 15.371279 seconds elapsed, finished iteration 50
# [LightGBM] [Info] Iteration:51, valid_1 auc : 0.661938
# [LightGBM] [Info] 15.623754 seconds elapsed, finished iteration 51
# [LightGBM] [Info] Iteration:52, valid_1 auc : 0.662010
# [LightGBM] [Info] 15.988358 seconds elapsed, finished iteration 52
# [LightGBM] [Info] Iteration:53, valid_1 auc : 0.662047
# [LightGBM] [Info] 16.231196 seconds elapsed, finished iteration 53
# [LightGBM] [Info] Iteration:54, valid_1 auc : 0.662205
# [LightGBM] [Info] 16.468069 seconds elapsed, finished iteration 54
# [LightGBM] [Info] Iteration:55, valid_1 auc : 0.662383
# [LightGBM] [Info] 16.702283 seconds elapsed, finished iteration 55
# [LightGBM] [Info] Iteration:56, valid_1 auc : 0.662403
# [LightGBM] [Info] 16.923636 seconds elapsed, finished iteration 56
# [LightGBM] [Info] Iteration:57, valid_1 auc : 0.662476
# [LightGBM] [Info] 17.321820 seconds elapsed, finished iteration 57
# [LightGBM] [Info] Iteration:58, valid_1 auc : 0.662549
# [LightGBM] [Info] 17.721019 seconds elapsed, finished iteration 58
# [LightGBM] [Info] Iteration:59, valid_1 auc : 0.662717
# [LightGBM] [Info] 17.965637 seconds elapsed, finished iteration 59
# [LightGBM] [Info] Iteration:60, valid_1 auc : 0.662828
# [LightGBM] [Info] 18.191628 seconds elapsed, finished iteration 60
# [LightGBM] [Info] Iteration:61, valid_1 auc : 0.662982
# [LightGBM] [Info] 18.446170 seconds elapsed, finished iteration 61
# [LightGBM] [Info] Iteration:62, valid_1 auc : 0.663045
# [LightGBM] [Info] 18.667759 seconds elapsed, finished iteration 62
# [LightGBM] [Info] Iteration:63, valid_1 auc : 0.663176
# [LightGBM] [Info] 18.906324 seconds elapsed, finished iteration 63
# [LightGBM] [Info] Iteration:64, valid_1 auc : 0.663291
# [LightGBM] [Info] 19.351126 seconds elapsed, finished iteration 64
# [LightGBM] [Info] Iteration:65, valid_1 auc : 0.663398
# [LightGBM] [Info] 19.719360 seconds elapsed, finished iteration 65
# [LightGBM] [Info] Iteration:66, valid_1 auc : 0.663427
# [LightGBM] [Info] 19.960118 seconds elapsed, finished iteration 66
# [LightGBM] [Info] Iteration:67, valid_1 auc : 0.663437
# [LightGBM] [Info] 20.218898 seconds elapsed, finished iteration 67
# [LightGBM] [Info] Iteration:68, valid_1 auc : 0.663508
# [LightGBM] [Info] 20.618730 seconds elapsed, finished iteration 68
# [LightGBM] [Info] Iteration:69, valid_1 auc : 0.663569
# [LightGBM] [Info] 20.896620 seconds elapsed, finished iteration 69
# [LightGBM] [Info] Iteration:70, valid_1 auc : 0.663627
# [LightGBM] [Info] 21.161481 seconds elapsed, finished iteration 70
# [LightGBM] [Info] Iteration:71, valid_1 auc : 0.663760
# [LightGBM] [Info] 21.411125 seconds elapsed, finished iteration 71
# [LightGBM] [Info] Iteration:72, valid_1 auc : 0.663827
# [LightGBM] [Info] 21.682212 seconds elapsed, finished iteration 72
# [LightGBM] [Info] Iteration:73, valid_1 auc : 0.663834
# [LightGBM] [Info] 21.926222 seconds elapsed, finished iteration 73
# [LightGBM] [Info] Iteration:74, valid_1 auc : 0.663938
# [LightGBM] [Info] 22.157994 seconds elapsed, finished iteration 74
# [LightGBM] [Info] Iteration:75, valid_1 auc : 0.664013
# [LightGBM] [Info] 22.370605 seconds elapsed, finished iteration 75
# [LightGBM] [Info] Iteration:76, valid_1 auc : 0.664105
# [LightGBM] [Info] 22.598593 seconds elapsed, finished iteration 76
# [LightGBM] [Info] Iteration:77, valid_1 auc : 0.664137
# [LightGBM] [Info] 22.944927 seconds elapsed, finished iteration 77
# [LightGBM] [Info] Iteration:78, valid_1 auc : 0.664144
# [LightGBM] [Info] 23.248563 seconds elapsed, finished iteration 78
# [LightGBM] [Info] Iteration:79, valid_1 auc : 0.664195
# [LightGBM] [Info] 23.483482 seconds elapsed, finished iteration 79
# [LightGBM] [Info] Iteration:80, valid_1 auc : 0.664185
# [LightGBM] [Info] 23.775024 seconds elapsed, finished iteration 80
# [LightGBM] [Info] Iteration:81, valid_1 auc : 0.664166
# [LightGBM] [Info] 24.093805 seconds elapsed, finished iteration 81
# [LightGBM] [Info] Iteration:82, valid_1 auc : 0.664201
# [LightGBM] [Info] 24.439940 seconds elapsed, finished iteration 82
# [LightGBM] [Info] Iteration:83, valid_1 auc : 0.664244
# [LightGBM] [Info] 24.650869 seconds elapsed, finished iteration 83
# [LightGBM] [Info] Iteration:84, valid_1 auc : 0.664227
# [LightGBM] [Info] 25.000098 seconds elapsed, finished iteration 84
# [LightGBM] [Info] Iteration:85, valid_1 auc : 0.664229
# [LightGBM] [Info] 25.205047 seconds elapsed, finished iteration 85
# [LightGBM] [Info] Iteration:86, valid_1 auc : 0.664257
# [LightGBM] [Info] 25.406832 seconds elapsed, finished iteration 86
# [LightGBM] [Info] Iteration:87, valid_1 auc : 0.664238
# [LightGBM] [Info] 25.603705 seconds elapsed, finished iteration 87
# [LightGBM] [Info] Iteration:88, valid_1 auc : 0.664173
# [LightGBM] [Info] 25.869757 seconds elapsed, finished iteration 88
# [LightGBM] [Info] Iteration:89, valid_1 auc : 0.664157
# [LightGBM] [Info] 26.150874 seconds elapsed, finished iteration 89
# [LightGBM] [Info] Iteration:90, valid_1 auc : 0.664168
# [LightGBM] [Info] 26.475051 seconds elapsed, finished iteration 90
# [LightGBM] [Info] Iteration:91, valid_1 auc : 0.664240
# [LightGBM] [Info] 26.718752 seconds elapsed, finished iteration 91
# [LightGBM] [Info] Iteration:92, valid_1 auc : 0.664306
# [LightGBM] [Info] 26.978625 seconds elapsed, finished iteration 92
# [LightGBM] [Info] Iteration:93, valid_1 auc : 0.664373
# [LightGBM] [Info] 27.271078 seconds elapsed, finished iteration 93
# [LightGBM] [Info] Iteration:94, valid_1 auc : 0.664457
# [LightGBM] [Info] 27.543988 seconds elapsed, finished iteration 94
# [LightGBM] [Info] Iteration:95, valid_1 auc : 0.664481
# [LightGBM] [Info] 27.805788 seconds elapsed, finished iteration 95
# [LightGBM] [Info] Iteration:96, valid_1 auc : 0.664523
# [LightGBM] [Info] 28.123170 seconds elapsed, finished iteration 96
# [LightGBM] [Info] Iteration:97, valid_1 auc : 0.664464
# [LightGBM] [Info] 28.330673 seconds elapsed, finished iteration 97
# [LightGBM] [Info] Iteration:98, valid_1 auc : 0.664445
# [LightGBM] [Info] 28.602866 seconds elapsed, finished iteration 98
# [LightGBM] [Info] Iteration:99, valid_1 auc : 0.664391
# [LightGBM] [Info] 28.802231 seconds elapsed, finished iteration 99
# [LightGBM] [Info] Iteration:100, valid_1 auc : 0.664319
# [LightGBM] [Info] 28.953069 seconds elapsed, finished iteration 100
# [LightGBM] [Info] Iteration:101, valid_1 auc : 0.664367
# [LightGBM] [Info] 29.189403 seconds elapsed, finished iteration 101
# [LightGBM] [Info] Iteration:102, valid_1 auc : 0.664318
# [LightGBM] [Info] 29.447775 seconds elapsed, finished iteration 102
# [LightGBM] [Info] Iteration:103, valid_1 auc : 0.664300
# [LightGBM] [Info] 29.697752 seconds elapsed, finished iteration 103
# [LightGBM] [Info] Iteration:104, valid_1 auc : 0.664337
# [LightGBM] [Info] 29.988931 seconds elapsed, finished iteration 104
# [LightGBM] [Info] Iteration:105, valid_1 auc : 0.664362
# [LightGBM] [Info] 30.233325 seconds elapsed, finished iteration 105
# [LightGBM] [Info] Iteration:106, valid_1 auc : 0.664324
# [LightGBM] [Info] 30.549205 seconds elapsed, finished iteration 106
# [LightGBM] [Info] Iteration:107, valid_1 auc : 0.664342
# [LightGBM] [Info] 30.717356 seconds elapsed, finished iteration 107
# [LightGBM] [Info] Iteration:108, valid_1 auc : 0.664367
# [LightGBM] [Info] 30.936309 seconds elapsed, finished iteration 108
# [LightGBM] [Info] Iteration:109, valid_1 auc : 0.664347
# [LightGBM] [Info] 31.119126 seconds elapsed, finished iteration 109
# [LightGBM] [Info] Iteration:110, valid_1 auc : 0.664345
# [LightGBM] [Info] 31.301351 seconds elapsed, finished iteration 110
# [LightGBM] [Info] Iteration:111, valid_1 auc : 0.664347
# [LightGBM] [Info] 31.484287 seconds elapsed, finished iteration 111
# [LightGBM] [Info] Iteration:112, valid_1 auc : 0.664375
# [LightGBM] [Info] 31.677796 seconds elapsed, finished iteration 112
# [LightGBM] [Info] Iteration:113, valid_1 auc : 0.664390
# [LightGBM] [Info] 31.856901 seconds elapsed, finished iteration 113
# [LightGBM] [Info] Iteration:114, valid_1 auc : 0.664362
# [LightGBM] [Info] 32.033980 seconds elapsed, finished iteration 114
# [LightGBM] [Info] Iteration:115, valid_1 auc : 0.664319
# [LightGBM] [Info] 32.341294 seconds elapsed, finished iteration 115
# [LightGBM] [Info] Iteration:116, valid_1 auc : 0.664347
# [LightGBM] [Info] 32.634499 seconds elapsed, finished iteration 116
# [LightGBM] [Info] Iteration:117, valid_1 auc : 0.664373
# [LightGBM] [Info] 32.925794 seconds elapsed, finished iteration 117
# [LightGBM] [Info] Iteration:118, valid_1 auc : 0.664365
# [LightGBM] [Info] 33.087899 seconds elapsed, finished iteration 118
# [LightGBM] [Info] Iteration:119, valid_1 auc : 0.664375
# [LightGBM] [Info] 33.409441 seconds elapsed, finished iteration 119
# [LightGBM] [Info] Iteration:120, valid_1 auc : 0.664394

# %%
clf.fit(df_train[feats], df_train[label], test_data = [(df_test[f], df_test[label])])

# %%
import cPickle
cPickle.dump(feat_select_res,open('feat_select_result.txt','w'))

# %%
df_res = pd.DataFrame([(k,) + e for e in v for (k,v) in feat_select_res.items()], columns = ['option','feats','cv_roc'])
df_res['avg_roc'] = df_res['cv_roc'].map(lambda l: sum(l)/len(l))
df_res['std_roc'] = df_res['cv_roc'].map(lambda l: np.std(l))
df_res['min_roc'] = df_res['cv_roc'].map(lambda l: min(l))
df_res['max_roc'] = df_res['cv_roc'].map(lambda l: max(l))
#[(k,) + e for e in v for (k,v) in feat_select_res.items()]
f = df_res.sort('avg_roc',ascending = False).iloc[0,1]

# %%
 
clf = GBMClassifier(
        exec_path=exec_path,
        min_data_in_leaf=50,
       # is_unbalance = True,
        num_iterations = 200,
        bagging_fraction = 0.8,
        bagging_freq = 10,
        num_leaves = 127,
        learning_rate = 0.1,
        metric = 'auc',
        early_stopping_round=30
    )

clf.fit(df_train[f], df_train[label], test_data = [(df_test[f], df_test[label])])
# Out:
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Warning] Ignoring feature Column_20, only has one value
# [LightGBM] [Info] Finished loading data in 3.703381 seconds
# [LightGBM] [Info] Number of postive: 109267, number of negative: 195200
# [LightGBM] [Info] Number of data: 304467, number of features: 32
# [LightGBM] [Info] Finished initializing training
# [LightGBM] [Info] Started training...
# [LightGBM] [Info] Iteration:1, valid_1 auc : 0.646418
# [LightGBM] [Info] 0.209253 seconds elapsed, finished iteration 1
# [LightGBM] [Info] Iteration:2, valid_1 auc : 0.652398
# [LightGBM] [Info] 0.410751 seconds elapsed, finished iteration 2
# [LightGBM] [Info] Iteration:3, valid_1 auc : 0.652892
# [LightGBM] [Info] 0.618843 seconds elapsed, finished iteration 3
# [LightGBM] [Info] Iteration:4, valid_1 auc : 0.654054
# [LightGBM] [Info] 0.812832 seconds elapsed, finished iteration 4
# [LightGBM] [Info] Iteration:5, valid_1 auc : 0.654632
# [LightGBM] [Info] 1.004930 seconds elapsed, finished iteration 5
# [LightGBM] [Info] Iteration:6, valid_1 auc : 0.655833
# [LightGBM] [Info] 1.203853 seconds elapsed, finished iteration 6
# [LightGBM] [Info] Iteration:7, valid_1 auc : 0.656980
# [LightGBM] [Info] 1.390174 seconds elapsed, finished iteration 7
# [LightGBM] [Info] Iteration:8, valid_1 auc : 0.657144
# [LightGBM] [Info] 1.570536 seconds elapsed, finished iteration 8
# [LightGBM] [Info] Iteration:9, valid_1 auc : 0.657603
# [LightGBM] [Info] 1.752138 seconds elapsed, finished iteration 9
# [LightGBM] [Info] Iteration:10, valid_1 auc : 0.657638
# [LightGBM] [Info] 2.100516 seconds elapsed, finished iteration 10
# [LightGBM] [Info] Iteration:11, valid_1 auc : 0.658064
# [LightGBM] [Info] 2.286812 seconds elapsed, finished iteration 11
# [LightGBM] [Info] Iteration:12, valid_1 auc : 0.658183
# [LightGBM] [Info] 2.619671 seconds elapsed, finished iteration 12
# [LightGBM] [Info] Iteration:13, valid_1 auc : 0.658965
# [LightGBM] [Info] 2.794970 seconds elapsed, finished iteration 13
# [LightGBM] [Info] Iteration:14, valid_1 auc : 0.659250
# [LightGBM] [Info] 3.128621 seconds elapsed, finished iteration 14
# [LightGBM] [Info] Iteration:15, valid_1 auc : 0.659510
# [LightGBM] [Info] 3.310567 seconds elapsed, finished iteration 15
# [LightGBM] [Info] Iteration:16, valid_1 auc : 0.660082
# [LightGBM] [Info] 3.493027 seconds elapsed, finished iteration 16
# [LightGBM] [Info] Iteration:17, valid_1 auc : 0.660518
# [LightGBM] [Info] 3.772612 seconds elapsed, finished iteration 17
# [LightGBM] [Info] Iteration:18, valid_1 auc : 0.661041
# [LightGBM] [Info] 3.942925 seconds elapsed, finished iteration 18
# [LightGBM] [Info] Iteration:19, valid_1 auc : 0.661220
# [LightGBM] [Info] 4.254985 seconds elapsed, finished iteration 19
# [LightGBM] [Info] Iteration:20, valid_1 auc : 0.661533
# [LightGBM] [Info] 4.566253 seconds elapsed, finished iteration 20
# [LightGBM] [Info] Iteration:21, valid_1 auc : 0.661606
# [LightGBM] [Info] 4.738800 seconds elapsed, finished iteration 21
# [LightGBM] [Info] Iteration:22, valid_1 auc : 0.661905
# [LightGBM] [Info] 4.907620 seconds elapsed, finished iteration 22
# [LightGBM] [Info] Iteration:23, valid_1 auc : 0.662188
# [LightGBM] [Info] 5.077377 seconds elapsed, finished iteration 23
# [LightGBM] [Info] Iteration:24, valid_1 auc : 0.662382
# [LightGBM] [Info] 5.370836 seconds elapsed, finished iteration 24
# [LightGBM] [Info] Iteration:25, valid_1 auc : 0.662680
# [LightGBM] [Info] 5.532129 seconds elapsed, finished iteration 25
# [LightGBM] [Info] Iteration:26, valid_1 auc : 0.662736
# [LightGBM] [Info] 5.692340 seconds elapsed, finished iteration 26
# [LightGBM] [Info] Iteration:27, valid_1 auc : 0.662861
# [LightGBM] [Info] 5.845908 seconds elapsed, finished iteration 27
# [LightGBM] [Info] Iteration:28, valid_1 auc : 0.663060
# [LightGBM] [Info] 6.007429 seconds elapsed, finished iteration 28
# [LightGBM] [Info] Iteration:29, valid_1 auc : 0.662962
# [LightGBM] [Info] 6.373785 seconds elapsed, finished iteration 29
# [LightGBM] [Info] Iteration:30, valid_1 auc : 0.662990
# [LightGBM] [Info] 6.550058 seconds elapsed, finished iteration 30
# [LightGBM] [Info] Iteration:31, valid_1 auc : 0.662985
# [LightGBM] [Info] 6.850313 seconds elapsed, finished iteration 31
# [LightGBM] [Info] Iteration:32, valid_1 auc : 0.662989
# [LightGBM] [Info] 6.998624 seconds elapsed, finished iteration 32
# [LightGBM] [Info] Iteration:33, valid_1 auc : 0.662875
# [LightGBM] [Info] 7.146886 seconds elapsed, finished iteration 33
# [LightGBM] [Info] Iteration:34, valid_1 auc : 0.662948
# [LightGBM] [Info] 7.288032 seconds elapsed, finished iteration 34
# [LightGBM] [Info] Iteration:35, valid_1 auc : 0.662939
# [LightGBM] [Info] 7.436780 seconds elapsed, finished iteration 35
# [LightGBM] [Info] Iteration:36, valid_1 auc : 0.662915
# [LightGBM] [Info] 7.571052 seconds elapsed, finished iteration 36
# [LightGBM] [Info] Iteration:37, valid_1 auc : 0.662946
# [LightGBM] [Info] 7.722127 seconds elapsed, finished iteration 37
# [LightGBM] [Info] Iteration:38, valid_1 auc : 0.662888
# [LightGBM] [Info] 7.871289 seconds elapsed, finished iteration 38
# [LightGBM] [Info] Iteration:39, valid_1 auc : 0.662901
# [LightGBM] [Info] 8.014611 seconds elapsed, finished iteration 39
# [LightGBM] [Info] Iteration:40, valid_1 auc : 0.662929
# [LightGBM] [Info] 8.155223 seconds elapsed, finished iteration 40
# [LightGBM] [Info] Iteration:41, valid_1 auc : 0.663004
# [LightGBM] [Info] 8.425300 seconds elapsed, finished iteration 41
# [LightGBM] [Info] Iteration:42, valid_1 auc : 0.663057
# [LightGBM] [Info] 8.718739 seconds elapsed, finished iteration 42
# [LightGBM] [Info] Iteration:43, valid_1 auc : 0.663058
# [LightGBM] [Info] 8.832633 seconds elapsed, finished iteration 43
# [LightGBM] [Info] Iteration:44, valid_1 auc : 0.662914
# [LightGBM] [Info] 8.959812 seconds elapsed, finished iteration 44
# [LightGBM] [Info] Iteration:45, valid_1 auc : 0.663067
# [LightGBM] [Info] 9.228980 seconds elapsed, finished iteration 45
# [LightGBM] [Info] Iteration:46, valid_1 auc : 0.663198
# [LightGBM] [Info] 9.368161 seconds elapsed, finished iteration 46
# [LightGBM] [Info] Iteration:47, valid_1 auc : 0.663129
# [LightGBM] [Info] 9.640887 seconds elapsed, finished iteration 47
# [LightGBM] [Info] Iteration:48, valid_1 auc : 0.663227
# [LightGBM] [Info] 9.810160 seconds elapsed, finished iteration 48
# [LightGBM] [Info] Iteration:49, valid_1 auc : 0.663110
# [LightGBM] [Info] 10.079287 seconds elapsed, finished iteration 49
# [LightGBM] [Info] Iteration:50, valid_1 auc : 0.663074
# [LightGBM] [Info] 10.342058 seconds elapsed, finished iteration 50
# [LightGBM] [Info] Iteration:51, valid_1 auc : 0.663227
# [LightGBM] [Info] 10.474634 seconds elapsed, finished iteration 51
# [LightGBM] [Info] Iteration:52, valid_1 auc : 0.663147
# [LightGBM] [Info] 10.611834 seconds elapsed, finished iteration 52
# [LightGBM] [Info] Iteration:53, valid_1 auc : 0.663081
# [LightGBM] [Info] 10.738987 seconds elapsed, finished iteration 53
# [LightGBM] [Info] Iteration:54, valid_1 auc : 0.663073
# [LightGBM] [Info] 10.979048 seconds elapsed, finished iteration 54
# [LightGBM] [Info] Iteration:55, valid_1 auc : 0.663076
# [LightGBM] [Info] 11.091406 seconds elapsed, finished iteration 55
# [LightGBM] [Info] Iteration:56, valid_1 auc : 0.663143
# [LightGBM] [Info] 11.210708 seconds elapsed, finished iteration 56
# [LightGBM] [Info] Iteration:57, valid_1 auc : 0.663195
# [LightGBM] [Info] 11.334567 seconds elapsed, finished iteration 57
# [LightGBM] [Info] Iteration:58, valid_1 auc : 0.663252
# [LightGBM] [Info] 11.464529 seconds elapsed, finished iteration 58
# [LightGBM] [Info] Iteration:59, valid_1 auc : 0.663152
# [LightGBM] [Info] 11.571079 seconds elapsed, finished iteration 59
# [LightGBM] [Info] Iteration:60, valid_1 auc : 0.663065
# [LightGBM] [Info] 11.694615 seconds elapsed, finished iteration 60
# [LightGBM] [Info] Iteration:61, valid_1 auc : 0.663091
# [LightGBM] [Info] 11.830301 seconds elapsed, finished iteration 61
# [LightGBM] [Info] Iteration:62, valid_1 auc : 0.663085
# [LightGBM] [Info] 12.083943 seconds elapsed, finished iteration 62
# [LightGBM] [Info] Iteration:63, valid_1 auc : 0.663122
# [LightGBM] [Info] 12.405929 seconds elapsed, finished iteration 63
# [LightGBM] [Info] Iteration:64, valid_1 auc : 0.663114
# [LightGBM] [Info] 12.643206 seconds elapsed, finished iteration 64
# [LightGBM] [Info] Iteration:65, valid_1 auc : 0.663093
# [LightGBM] [Info] 12.791641 seconds elapsed, finished iteration 65
# [LightGBM] [Info] Iteration:66, valid_1 auc : 0.662990
# [LightGBM] [Info] 12.896233 seconds elapsed, finished iteration 66
# [LightGBM] [Info] Iteration:67, valid_1 auc : 0.663111
# [LightGBM] [Info] 13.083647 seconds elapsed, finished iteration 67
# [LightGBM] [Info] Iteration:68, valid_1 auc : 0.663000
# [LightGBM] [Info] 13.230315 seconds elapsed, finished iteration 68
# [LightGBM] [Info] Iteration:69, valid_1 auc : 0.663044
# [LightGBM] [Info] 13.331330 seconds elapsed, finished iteration 69
# [LightGBM] [Info] Iteration:70, valid_1 auc : 0.662940
# [LightGBM] [Info] 13.628163 seconds elapsed, finished iteration 70
# [LightGBM] [Info] Iteration:71, valid_1 auc : 0.662860
# [LightGBM] [Info] 13.800793 seconds elapsed, finished iteration 71
# [LightGBM] [Info] Iteration:72, valid_1 auc : 0.662762
# [LightGBM] [Info] 13.912786 seconds elapsed, finished iteration 72
# [LightGBM] [Info] Iteration:73, valid_1 auc : 0.662639
# [LightGBM] [Info] 14.013755 seconds elapsed, finished iteration 73
# [LightGBM] [Info] Iteration:74, valid_1 auc : 0.662598
# [LightGBM] [Info] 14.097158 seconds elapsed, finished iteration 74
# [LightGBM] [Info] Iteration:75, valid_1 auc : 0.662613
# [LightGBM] [Info] 14.204979 seconds elapsed, finished iteration 75
# [LightGBM] [Info] Iteration:76, valid_1 auc : 0.662559
# [LightGBM] [Info] 14.292122 seconds elapsed, finished iteration 76
# [LightGBM] [Info] Iteration:77, valid_1 auc : 0.662466
# [LightGBM] [Info] 14.387461 seconds elapsed, finished iteration 77
# [LightGBM] [Info] Iteration:78, valid_1 auc : 0.662368
# [LightGBM] [Info] 14.472233 seconds elapsed, finished iteration 78
# [LightGBM] [Info] Iteration:79, valid_1 auc : 0.662284
# [LightGBM] [Info] 14.589352 seconds elapsed, finished iteration 79
# [LightGBM] [Info] Iteration:80, valid_1 auc : 0.662170
# [LightGBM] [Info] 14.788868 seconds elapsed, finished iteration 80
# [LightGBM] [Info] Iteration:81, valid_1 auc : 0.662148
# [LightGBM] [Info] 14.968542 seconds elapsed, finished iteration 81
# [LightGBM] [Info] Iteration:82, valid_1 auc : 0.662091
# [LightGBM] [Info] 15.055272 seconds elapsed, finished iteration 82
# [LightGBM] [Info] Iteration:83, valid_1 auc : 0.662010
# [LightGBM] [Info] 15.329016 seconds elapsed, finished iteration 83
# [LightGBM] [Info] Iteration:84, valid_1 auc : 0.661897
# [LightGBM] [Info] 15.494389 seconds elapsed, finished iteration 84
# [LightGBM] [Info] Iteration:85, valid_1 auc : 0.661785
# [LightGBM] [Info] 15.617911 seconds elapsed, finished iteration 85
# [LightGBM] [Info] Iteration:86, valid_1 auc : 0.661701
# [LightGBM] [Info] 15.705440 seconds elapsed, finished iteration 86
# [LightGBM] [Info] Iteration:87, valid_1 auc : 0.661585
# [LightGBM] [Info] 15.785383 seconds elapsed, finished iteration 87
# [LightGBM] [Info] Iteration:88, valid_1 auc : 0.661471
# [LightGBM] [Info] Early stopping at iteration 88, the best iteration round is 58
# [LightGBM] [Info] 15.867063 seconds elapsed, finished iteration 88
# [LightGBM] [Info] Finished training

# %%
clf.score(df_test[f], df_test[label])
# Out:
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading 58 models
# [LightGBM] [Info] Finished initializing prediction
# [LightGBM] [Info] Finished prediction
# 0.63567484586624412

# %%
# шаблон. пока не вычисляется

    dtrain_all_yaca = xgb.DMatrix( df_test[feat_cols_w_yaca], missing = np.nan)
    df_test.loc[:,'pred'] = bst1.predict(dtest_all_yaca)
    
    print('Option {} (depth {}). AUC ROC: {:.5f}. AUC PR: {:.5f}. Avg label {:.5f}. Sampled count {}.'.format(
            ind,
            depth,
            sklearn.metrics.roc_auc_score(
                y_true = df_test['approve'],
                y_score = df_test['pred']),
            sklearn.metrics.average_precision_score(
                y_true = df_test['approve'],
                y_score = df_test['pred']),
            df_test['approve'].mean(),
            df_test.shape[0]
         ))

# %%
import sklearn

#print("Features as classifiers: AUC ROC on test. ")
features_performance = [(
        f,
        sklearn.metrics.roc_auc_score(y_true = df_train['approve'],y_score = df_train[f].fillna(-1000)),
        sklearn.metrics.average_precision_score(y_true = df_train['approve'],y_score = df_train[f].fillna(-1000)),
    ) for f in feat_cols]
print('Feature standalone performace\n{:<30}  {:<15}  {:<15}\n'.format('Feature','Train AUC ROC','Train AUC PR') + 
    '\n'.join('{:<30}  {:<15.4f}  {:<15.4f}'.format(*e) for e in sorted(features_performance, key = lambda e: -e[1])))
# Out:
# Feature importances
# Feature                         Train AUC ROC    Train AUC PR
# avg_score1                      0.6045           0.4516
# q30_score1                      0.5986           0.4497
# q50_score1                      0.5971           0.4501
# q70_score1                      0.5959           0.4470
# q90_score1                      0.5749           0.4176
# q95_score1                      0.5564           0.4020
# min_score1                      0.5559           0.3957
# avg_salary_2015_rub             0.5483           0.3951
# density                         0.5472           0.4243
# pop_country_share               0.5406           0.4204
# good_urlfr_share_score1         0.5389           0.3941
# max_score1                      0.5309           0.3839
# min_score2                      0.5288           0.3793
# avg_hour_q10                    0.5270           0.3801
# emailru                         0.5266           0.3783
# avg_hour                        0.5258           0.3801
# avg_hour_q90                    0.5248           0.3795
# work_hours_hits_share           0.5228           0.3738
# avg_score2                      0.5227           0.3679
# avg_time_std                    0.5200           0.3752
# avg_ymd_range                   0.5200           0.3757
# min_score3                      0.5187           0.3724
# good_urlfr_timestd_score1       0.5182           0.3701
# max_urlfr_time_std_1            0.5152           0.3650
# q30_score2                      0.5136           0.3548
# avg_ymd_cnt                     0.5073           0.3683
# q50_score2                      0.5031           0.3480
# social_share                    0.5028           0.3606
# pop_city_share                  0.5013           0.3493
# min_score4                      0.5005           0.3566
# vk_share                        0.4977           0.3015
# max_score4                      0.4968           0.3470
# visits_cnt                      0.4922           0.3493
# cnt                             0.4910           0.3490
# area_sq_km                      0.4891           0.3510
# q70_score2                      0.4885           0.3403
# max_score2                      0.4882           0.3342
# utc_time_zone_val               0.4858           0.3405
# federal_district                0.4850           0.3531
# hits                            0.4831           0.3439
# q90_score2                      0.4718           0.3284
# max_score3                      0.4665           0.3209
# q95_score2                      0.4630           0.3229
# avg_duration                    0.4628           0.3368
# hour_std                        0.4625           0.3327
# mobile_share                    0.4606           0.3306
# good_urlfr_share_score2         0.4590           0.3055
# avg_score3                      0.4578           0.3233
# q30_score3                      0.4542           0.3249
# q95_score4                      0.4522           0.3244
# q50_score3                      0.4499           0.3227
# q70_score3                      0.4449           0.3190
# good_urlfr_share_score3         0.4435           0.3146
# q90_score3                      0.4379           0.3143
# avg_score4                      0.4348           0.3190
# q95_score3                      0.4342           0.3129
# q30_score4                      0.4294           0.3172
# q90_score4                      0.4080           0.3040
# q50_score4                      0.4068           0.3076
# q70_score4                      0.3985           0.3068

# %%
##### import numpy as np
from sklearn import datasets, metrics, model_selection
from pylightgbm.models import GBMClassifier

# full path to lightgbm executable (on Windows include .exe)
exec_path = "/opt/share/LightGBM-master/lightgbm"

#X, Y = datasets.make_classification(n_samples=200, n_features=10)
#x_train, x_test, y_train, y_test = model_selection.train_test_split(X, Y, test_size=0.2)

clf = GBMClassifier(
        exec_path=exec_path,
        min_data_in_leaf=50,
       # is_unbalance = True,
        num_iterations = 200,
        bagging_fraction = 0.8,
        bagging_freq = 10,
        num_leaves = 127,
        learning_rate = 0.1,
        metric = 'auc',
        early_stopping_round=10
)

clf.fit(df_train[feat_cols_w_yaca], df_train['approve'], test_data = [(df_test[feat_cols_w_yaca], df_test['approve'])])
# mean: 0.65748, std: 0.00037, params: {'num_leaves': 63, 'learning_rate': 0.02, 'bagging_fraction': 0.9},
# Out:
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Warning] Ignoring feature Column_126, only has one value
# [LightGBM] [Warning] Ignoring feature Column_136, only has one value
# [LightGBM] [Warning] Ignoring feature Column_145, only has one value
# [LightGBM] [Warning] Ignoring feature Column_181, only has one value
# [LightGBM] [Warning] Ignoring feature Column_192, only has one value
# [LightGBM] [Warning] Ignoring feature Column_214, only has one value
# [LightGBM] [Warning] Ignoring feature Column_215, only has one value
# [LightGBM] [Warning] Ignoring feature Column_304, only has one value
# [LightGBM] [Warning] Ignoring feature Column_348, only has one value
# [LightGBM] [Warning] Ignoring feature Column_349, only has one value
# [LightGBM] [Warning] Ignoring feature Column_355, only has one value
# [LightGBM] [Warning] Ignoring feature Column_399, only has one value
# [LightGBM] [Warning] Ignoring feature Column_400, only has one value
# [LightGBM] [Warning] Ignoring feature Column_416, only has one value
# [LightGBM] [Warning] Ignoring feature Column_467, only has one value
# [LightGBM] [Warning] Ignoring feature Column_469, only has one value
# [LightGBM] [Info] Finished loading data in 28.791543 seconds
# [LightGBM] [Info] Number of postive: 109267, number of negative: 195200
# [LightGBM] [Info] Number of data: 304467, number of features: 460
# [LightGBM] [Info] Finished initializing training
# [LightGBM] [Info] Started training...
# [LightGBM] [Info] Iteration:1, valid_1 auc : 0.647937
# [LightGBM] [Info] 0.710190 seconds elapsed, finished iteration 1
# [LightGBM] [Info] Iteration:2, valid_1 auc : 0.653572
# [LightGBM] [Info] 1.438596 seconds elapsed, finished iteration 2
# [LightGBM] [Info] Iteration:3, valid_1 auc : 0.656287
# [LightGBM] [Info] 2.186719 seconds elapsed, finished iteration 3
# [LightGBM] [Info] Iteration:4, valid_1 auc : 0.658460
# [LightGBM] [Info] 2.883568 seconds elapsed, finished iteration 4
# [LightGBM] [Info] Iteration:5, valid_1 auc : 0.659806
# [LightGBM] [Info] 3.666853 seconds elapsed, finished iteration 5
# [LightGBM] [Info] Iteration:6, valid_1 auc : 0.660516
# [LightGBM] [Info] 4.403344 seconds elapsed, finished iteration 6
# [LightGBM] [Info] Iteration:7, valid_1 auc : 0.660786
# [LightGBM] [Info] 5.112105 seconds elapsed, finished iteration 7
# [LightGBM] [Info] Iteration:8, valid_1 auc : 0.661452
# [LightGBM] [Info] 5.803606 seconds elapsed, finished iteration 8
# [LightGBM] [Info] Iteration:9, valid_1 auc : 0.662022
# [LightGBM] [Info] 6.684862 seconds elapsed, finished iteration 9
# [LightGBM] [Info] Iteration:10, valid_1 auc : 0.662140
# [LightGBM] [Info] 7.560287 seconds elapsed, finished iteration 10
# [LightGBM] [Info] Iteration:11, valid_1 auc : 0.662718
# [LightGBM] [Info] 8.325495 seconds elapsed, finished iteration 11
# [LightGBM] [Info] Iteration:12, valid_1 auc : 0.663091
# [LightGBM] [Info] 9.006909 seconds elapsed, finished iteration 12
# [LightGBM] [Info] Iteration:13, valid_1 auc : 0.663393
# [LightGBM] [Info] 9.689220 seconds elapsed, finished iteration 13
# [LightGBM] [Info] Iteration:14, valid_1 auc : 0.663989
# [LightGBM] [Info] 10.359016 seconds elapsed, finished iteration 14
# [LightGBM] [Info] Iteration:15, valid_1 auc : 0.664480
# [LightGBM] [Info] 10.997007 seconds elapsed, finished iteration 15
# [LightGBM] [Info] Iteration:16, valid_1 auc : 0.664907
# [LightGBM] [Info] 11.734722 seconds elapsed, finished iteration 16
# [LightGBM] [Info] Iteration:17, valid_1 auc : 0.665582
# [LightGBM] [Info] 12.415403 seconds elapsed, finished iteration 17
# [LightGBM] [Info] Iteration:18, valid_1 auc : 0.665836
# [LightGBM] [Info] 13.126939 seconds elapsed, finished iteration 18
# [LightGBM] [Info] Iteration:19, valid_1 auc : 0.666078
# [LightGBM] [Info] 13.801317 seconds elapsed, finished iteration 19
# [LightGBM] [Info] Iteration:20, valid_1 auc : 0.666665
# [LightGBM] [Info] 14.533581 seconds elapsed, finished iteration 20
# [LightGBM] [Info] Iteration:21, valid_1 auc : 0.667007
# [LightGBM] [Info] 15.394176 seconds elapsed, finished iteration 21
# [LightGBM] [Info] Iteration:22, valid_1 auc : 0.667395
# [LightGBM] [Info] 16.101690 seconds elapsed, finished iteration 22
# [LightGBM] [Info] Iteration:23, valid_1 auc : 0.667509
# [LightGBM] [Info] 16.818373 seconds elapsed, finished iteration 23
# [LightGBM] [Info] Iteration:24, valid_1 auc : 0.667532
# [LightGBM] [Info] 17.748904 seconds elapsed, finished iteration 24
# [LightGBM] [Info] Iteration:25, valid_1 auc : 0.667679
# [LightGBM] [Info] 18.423421 seconds elapsed, finished iteration 25
# [LightGBM] [Info] Iteration:26, valid_1 auc : 0.667743
# [LightGBM] [Info] 19.009090 seconds elapsed, finished iteration 26
# [LightGBM] [Info] Iteration:27, valid_1 auc : 0.668127
# [LightGBM] [Info] 19.793601 seconds elapsed, finished iteration 27
# [LightGBM] [Info] Iteration:28, valid_1 auc : 0.668283
# [LightGBM] [Info] 20.601123 seconds elapsed, finished iteration 28
# [LightGBM] [Info] Iteration:29, valid_1 auc : 0.668595
# [LightGBM] [Info] 21.195680 seconds elapsed, finished iteration 29
# [LightGBM] [Info] Iteration:30, valid_1 auc : 0.668764
# [LightGBM] [Info] 21.812222 seconds elapsed, finished iteration 30
# [LightGBM] [Info] Iteration:31, valid_1 auc : 0.668828
# [LightGBM] [Info] 22.434738 seconds elapsed, finished iteration 31
# [LightGBM] [Info] Iteration:32, valid_1 auc : 0.668964
# [LightGBM] [Info] 23.037652 seconds elapsed, finished iteration 32
# [LightGBM] [Info] Iteration:33, valid_1 auc : 0.669204
# [LightGBM] [Info] 23.831361 seconds elapsed, finished iteration 33
# [LightGBM] [Info] Iteration:34, valid_1 auc : 0.669257
# [LightGBM] [Info] 24.397650 seconds elapsed, finished iteration 34
# [LightGBM] [Info] Iteration:35, valid_1 auc : 0.669580
# [LightGBM] [Info] 24.997014 seconds elapsed, finished iteration 35
# [LightGBM] [Info] Iteration:36, valid_1 auc : 0.669732
# [LightGBM] [Info] 25.630359 seconds elapsed, finished iteration 36
# [LightGBM] [Info] Iteration:37, valid_1 auc : 0.669757
# [LightGBM] [Info] 26.410439 seconds elapsed, finished iteration 37
# [LightGBM] [Info] Iteration:38, valid_1 auc : 0.669907
# [LightGBM] [Info] 27.023295 seconds elapsed, finished iteration 38
# [LightGBM] [Info] Iteration:39, valid_1 auc : 0.669776
# [LightGBM] [Info] 27.597720 seconds elapsed, finished iteration 39
# [LightGBM] [Info] Iteration:40, valid_1 auc : 0.670006
# [LightGBM] [Info] 28.515423 seconds elapsed, finished iteration 40
# [LightGBM] [Info] Iteration:41, valid_1 auc : 0.670111
# [LightGBM] [Info] 29.098945 seconds elapsed, finished iteration 41
# [LightGBM] [Info] Iteration:42, valid_1 auc : 0.670255
# [LightGBM] [Info] 29.613409 seconds elapsed, finished iteration 42
# [LightGBM] [Info] Iteration:43, valid_1 auc : 0.670169
# [LightGBM] [Info] 30.340163 seconds elapsed, finished iteration 43
# [LightGBM] [Info] Iteration:44, valid_1 auc : 0.670328
# [LightGBM] [Info] 30.919626 seconds elapsed, finished iteration 44
# [LightGBM] [Info] Iteration:45, valid_1 auc : 0.670185
# [LightGBM] [Info] 31.477531 seconds elapsed, finished iteration 45
# [LightGBM] [Info] Iteration:46, valid_1 auc : 0.670208
# [LightGBM] [Info] 32.130040 seconds elapsed, finished iteration 46
# [LightGBM] [Info] Iteration:47, valid_1 auc : 0.670350
# [LightGBM] [Info] 32.728751 seconds elapsed, finished iteration 47
# [LightGBM] [Info] Iteration:48, valid_1 auc : 0.670541
# [LightGBM] [Info] 33.385158 seconds elapsed, finished iteration 48
# [LightGBM] [Info] Iteration:49, valid_1 auc : 0.670590
# [LightGBM] [Info] 33.933953 seconds elapsed, finished iteration 49
# [LightGBM] [Info] Iteration:50, valid_1 auc : 0.670670
# [LightGBM] [Info] 34.481515 seconds elapsed, finished iteration 50
# [LightGBM] [Info] Iteration:51, valid_1 auc : 0.670762
# [LightGBM] [Info] 35.137885 seconds elapsed, finished iteration 51
# [LightGBM] [Info] Iteration:52, valid_1 auc : 0.670679
# [LightGBM] [Info] 35.696785 seconds elapsed, finished iteration 52
# [LightGBM] [Info] Iteration:53, valid_1 auc : 0.670511
# [LightGBM] [Info] 36.213270 seconds elapsed, finished iteration 53
# [LightGBM] [Info] Iteration:54, valid_1 auc : 0.670420
# [LightGBM] [Info] 36.862404 seconds elapsed, finished iteration 54
# [LightGBM] [Info] Iteration:55, valid_1 auc : 0.670589
# [LightGBM] [Info] 37.741363 seconds elapsed, finished iteration 55
# [LightGBM] [Info] Iteration:56, valid_1 auc : 0.670483
# [LightGBM] [Info] 38.245460 seconds elapsed, finished iteration 56
# [LightGBM] [Info] Iteration:57, valid_1 auc : 0.670450
# [LightGBM] [Info] 38.976696 seconds elapsed, finished iteration 57
# [LightGBM] [Info] Iteration:58, valid_1 auc : 0.670445
# [LightGBM] [Info] 39.634802 seconds elapsed, finished iteration 58
# [LightGBM] [Info] Iteration:59, valid_1 auc : 0.670630
# [LightGBM] [Info] 40.193946 seconds elapsed, finished iteration 59
# [LightGBM] [Info] Iteration:60, valid_1 auc : 0.670673
# [LightGBM] [Info] 40.629666 seconds elapsed, finished iteration 60
# [LightGBM] [Info] Iteration:61, valid_1 auc : 0.670985
# [LightGBM] [Info] 41.259649 seconds elapsed, finished iteration 61
# [LightGBM] [Info] Iteration:62, valid_1 auc : 0.671126
# [LightGBM] [Info] 41.796264 seconds elapsed, finished iteration 62
# [LightGBM] [Info] Iteration:63, valid_1 auc : 0.671249
# [LightGBM] [Info] 42.262653 seconds elapsed, finished iteration 63
# [LightGBM] [Info] Iteration:64, valid_1 auc : 0.671449
# [LightGBM] [Info] 42.863958 seconds elapsed, finished iteration 64
# [LightGBM] [Info] Iteration:65, valid_1 auc : 0.671434
# [LightGBM] [Info] 43.264885 seconds elapsed, finished iteration 65
# [LightGBM] [Info] Iteration:66, valid_1 auc : 0.671535
# [LightGBM] [Info] 43.716983 seconds elapsed, finished iteration 66
# [LightGBM] [Info] Iteration:67, valid_1 auc : 0.671417
# [LightGBM] [Info] 44.151480 seconds elapsed, finished iteration 67
# [LightGBM] [Info] Iteration:68, valid_1 auc : 0.671594
# [LightGBM] [Info] 44.607342 seconds elapsed, finished iteration 68
# [LightGBM] [Info] Iteration:69, valid_1 auc : 0.671512
# [LightGBM] [Info] 45.091807 seconds elapsed, finished iteration 69
# [LightGBM] [Info] Iteration:70, valid_1 auc : 0.671394
# [LightGBM] [Info] 45.500868 seconds elapsed, finished iteration 70
# [LightGBM] [Info] Iteration:71, valid_1 auc : 0.671344
# [LightGBM] [Info] 45.928973 seconds elapsed, finished iteration 71
# [LightGBM] [Info] Iteration:72, valid_1 auc : 0.671301
# [LightGBM] [Info] 46.541643 seconds elapsed, finished iteration 72
# [LightGBM] [Info] Iteration:73, valid_1 auc : 0.671414
# [LightGBM] [Info] 47.035116 seconds elapsed, finished iteration 73
# [LightGBM] [Info] Iteration:74, valid_1 auc : 0.671222
# [LightGBM] [Info] 47.569697 seconds elapsed, finished iteration 74
# [LightGBM] [Info] Iteration:75, valid_1 auc : 0.671247
# [LightGBM] [Info] 48.027986 seconds elapsed, finished iteration 75
# [LightGBM] [Info] Iteration:76, valid_1 auc : 0.671221
# [LightGBM] [Info] 48.454237 seconds elapsed, finished iteration 76
# [LightGBM] [Info] Iteration:77, valid_1 auc : 0.671226
# [LightGBM] [Info] 48.893823 seconds elapsed, finished iteration 77
# [LightGBM] [Info] Iteration:78, valid_1 auc : 0.671314
# [LightGBM] [Info] Early stopping at iteration 78, the best iteration round is 68
# [LightGBM] [Info] 49.374986 seconds elapsed, finished iteration 78
# [LightGBM] [Info] Finished training

# %% [markdown]
# Iteration:68, valid_1 auc : 0.671594

# %%
label = 'approve'
clf = GBMClassifier(
        exec_path=exec_path,
        min_data_in_leaf=50,
       # is_unbalance = True,
        num_iterations = 200,
        bagging_fraction = 0.8,
        bagging_freq = 10,
        num_leaves = 127,
        learning_rate = 0.08,
        metric = 'auc',
        early_stopping_round=10
)

feat_list = [
    feat_cols_w_yaca, 
    feat_cols, 
    [c for c in feat_cols if not (('score2' in c) or ('score3' in c))],
    [c for c in feat_cols if not (('score2' in c) or ('score3' in c) or ('score4' in c))],
    [c for c in feat_cols if not re.match('q[0-9]{,2}_',c)] ,
    [c for c in feat_cols if not (('score2' in c) or ('score3' in c) or re.match('q[0-9]{,2}_',c))],
]

res = []
for feats in feat_list:
    cv_score = sklearn.cross_validation.cross_val_score(clf, df_train[feats], df_train[label], cv=5, scoring='roc_auc')
    res.append((feats,cv_score))
print res
# Out:
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Warning] Ignoring feature Column_61, only has one value
# [LightGBM] [Warning] Ignoring feature Column_136, only has one value
# [LightGBM] [Warning] Ignoring feature Column_181, only has one value
# [LightGBM] [Warning] Ignoring feature Column_186, only has one value
# [LightGBM] [Warning] Ignoring feature Column_304, only has one value
# [LightGBM] [Warning] Ignoring feature Column_348, only has one value
# [LightGBM] [Warning] Ignoring feature Column_355, only has one value
# [LightGBM] [Warning] Ignoring feature Column_403, only has one value
# [LightGBM] [Warning] Ignoring feature Column_416, only has one value
# [LightGBM] [Warning] Ignoring feature Column_429, only has one value
# [LightGBM] [Warning] Ignoring feature Column_466, only has one value
# [LightGBM] [Warning] Ignoring feature Column_467, only has one value
# [LightGBM] [Warning] Ignoring feature Column_469, only has one value
# [LightGBM] [Info] Finished loading data in 23.063600 seconds
# [LightGBM] [Info] Number of postive: 87413, number of negative: 156160
# [LightGBM] [Info] Number of data: 243573, number of features: 463
# [LightGBM] [Info] Finished initializing training
# [LightGBM] [Info] Started training...
# [LightGBM] [Info] 0.644799 seconds elapsed, finished iteration 1
# [LightGBM] [Info] 1.176903 seconds elapsed, finished iteration 2
# [LightGBM] [Info] 1.717890 seconds elapsed, finished iteration 3
# [LightGBM] [Info] 2.266369 seconds elapsed, finished iteration 4
# [LightGBM] [Info] 2.798499 seconds elapsed, finished iteration 5
# [LightGBM] [Info] 3.340473 seconds elapsed, finished iteration 6
# [LightGBM] [Info] 3.863287 seconds elapsed, finished iteration 7
# [LightGBM] [Info] 4.710268 seconds elapsed, finished iteration 8
# [LightGBM] [Info] 5.214540 seconds elapsed, finished iteration 9
# [LightGBM] [Info] 5.722100 seconds elapsed, finished iteration 10
# [LightGBM] [Info] 6.235249 seconds elapsed, finished iteration 11
# [LightGBM] [Info] 6.741946 seconds elapsed, finished iteration 12
# [LightGBM] [Info] 7.239629 seconds elapsed, finished iteration 13
# [LightGBM] [Info] 7.758920 seconds elapsed, finished iteration 14
# [LightGBM] [Info] 8.390607 seconds elapsed, finished iteration 15
# [LightGBM] [Info] 8.886751 seconds elapsed, finished iteration 16
# [LightGBM] [Info] 9.392474 seconds elapsed, finished iteration 17
# [LightGBM] [Info] 9.893949 seconds elapsed, finished iteration 18
# [LightGBM] [Info] 10.559288 seconds elapsed, finished iteration 19
# [LightGBM] [Info] 11.055224 seconds elapsed, finished iteration 20
# [LightGBM] [Info] 11.553627 seconds elapsed, finished iteration 21
# [LightGBM] [Info] 12.058717 seconds elapsed, finished iteration 22
# [LightGBM] [Info] 12.683278 seconds elapsed, finished iteration 23
# [LightGBM] [Info] 13.182619 seconds elapsed, finished iteration 24
# [LightGBM] [Info] 13.667389 seconds elapsed, finished iteration 25
# [LightGBM] [Info] 14.147920 seconds elapsed, finished iteration 26
# [LightGBM] [Info] 14.630565 seconds elapsed, finished iteration 27
# [LightGBM] [Info] 15.107695 seconds elapsed, finished iteration 28
# [LightGBM] [Info] 15.585768 seconds elapsed, finished iteration 29
# [LightGBM] [Info] 16.069476 seconds elapsed, finished iteration 30
# [LightGBM] [Info] 16.538260 seconds elapsed, finished iteration 31
# [LightGBM] [Info] 17.012695 seconds elapsed, finished iteration 32
# [LightGBM] [Info] 17.500334 seconds elapsed, finished iteration 33
# [LightGBM] [Info] 17.979928 seconds elapsed, finished iteration 34
# [LightGBM] [Info] 18.436671 seconds elapsed, finished iteration 35
# [LightGBM] [Info] 18.994668 seconds elapsed, finished iteration 36
# [LightGBM] [Info] 19.465052 seconds elapsed, finished iteration 37
# [LightGBM] [Info] 20.049847 seconds elapsed, finished iteration 38
# [LightGBM] [Info] 20.523875 seconds elapsed, finished iteration 39
# [LightGBM] [Info] 20.979994 seconds elapsed, finished iteration 40
# [LightGBM] [Info] 21.585677 seconds elapsed, finished iteration 41
# [LightGBM] [Info] 22.049767 seconds elapsed, finished iteration 42
# [LightGBM] [Info] 22.538552 seconds elapsed, finished iteration 43
# [LightGBM] [Info] 23.010504 seconds elapsed, finished iteration 44
# [LightGBM] [Info] 23.447978 seconds elapsed, finished iteration 45
# [LightGBM] [Info] 23.897171 seconds elapsed, finished iteration 46
# [LightGBM] [Info] 24.324540 seconds elapsed, finished iteration 47
# [LightGBM] [Info] 24.753137 seconds elapsed, finished iteration 48
# [LightGBM] [Info] 25.174593 seconds elapsed, finished iteration 49
# [LightGBM] [Info] 25.633896 seconds elapsed, finished iteration 50
# [LightGBM] [Info] 26.199249 seconds elapsed, finished iteration 51
# [LightGBM] [Info] 26.648994 seconds elapsed, finished iteration 52
# [LightGBM] [Info] 27.116955 seconds elapsed, finished iteration 53
# [LightGBM] [Info] 27.715855 seconds elapsed, finished iteration 54
# [LightGBM] [Info] 28.312797 seconds elapsed, finished iteration 55
# [LightGBM] [Info] 28.893660 seconds elapsed, finished iteration 56
# [LightGBM] [Info] 29.334079 seconds elapsed, finished iteration 57
# [LightGBM] [Info] 29.876882 seconds elapsed, finished iteration 58
# [LightGBM] [Info] 30.331681 seconds elapsed, finished iteration 59
# [LightGBM] [Info] 30.730542 seconds elapsed, finished iteration 60
# [LightGBM] [Info] 31.173720 seconds elapsed, finished iteration 61
# [LightGBM] [Info] 31.591353 seconds elapsed, finished iteration 62
# [LightGBM] [Info] 32.024562 seconds elapsed, finished iteration 63
# [LightGBM] [Info] 32.627028 seconds elapsed, finished iteration 64
# [LightGBM] [Info] 33.023249 seconds elapsed, finished iteration 65
# [LightGBM] [Info] 33.596889 seconds elapsed, finished iteration 66
# [LightGBM] [Info] 34.146690 seconds elapsed, finished iteration 67
# [LightGBM] [Info] 34.721680 seconds elapsed, finished iteration 68
# [LightGBM] [Info] 35.080400 seconds elapsed, finished iteration 69
# [LightGBM] [Info] 35.426465 seconds elapsed, finished iteration 70
# [LightGBM] [Info] 35.850761 seconds elapsed, finished iteration 71
# [LightGBM] [Info] 36.272471 seconds elapsed, finished iteration 72
# [LightGBM] [Info] 36.631481 seconds elapsed, finished iteration 73
# [LightGBM] [Info] 37.051259 seconds elapsed, finished iteration 74
# [LightGBM] [Info] 37.438768 seconds elapsed, finished iteration 75
# [LightGBM] [Info] 37.772826 seconds elapsed, finished iteration 76
# [LightGBM] [Info] 38.158602 seconds elapsed, finished iteration 77
# [LightGBM] [Info] 38.456407 seconds elapsed, finished iteration 78
# [LightGBM] [Info] 38.789274 seconds elapsed, finished iteration 79
# [LightGBM] [Info] 39.101292 seconds elapsed, finished iteration 80
# [LightGBM] [Info] 39.497832 seconds elapsed, finished iteration 81
# [LightGBM] [Info] 39.875534 seconds elapsed, finished iteration 82
# [LightGBM] [Info] 40.283106 seconds elapsed, finished iteration 83
# [LightGBM] [Info] 40.840910 seconds elapsed, finished iteration 84
# [LightGBM] [Info] 41.205053 seconds elapsed, finished iteration 85
# [LightGBM] [Info] 41.576373 seconds elapsed, finished iteration 86
# [LightGBM] [Info] 41.954021 seconds elapsed, finished iteration 87
# [LightGBM] [Info] 42.295727 seconds elapsed, finished iteration 88
# [LightGBM] [Info] 42.681241 seconds elapsed, finished iteration 89
# [LightGBM] [Info] 43.079639 seconds elapsed, finished iteration 90
# [LightGBM] [Info] 43.620212 seconds elapsed, finished iteration 91
# [LightGBM] [Info] 44.103927 seconds elapsed, finished iteration 92
# [LightGBM] [Info] 44.347159 seconds elapsed, finished iteration 93
# [LightGBM] [Info] 44.830763 seconds elapsed, finished iteration 94
# [LightGBM] [Info] 45.061733 seconds elapsed, finished iteration 95
# [LightGBM] [Info] 45.376275 seconds elapsed, finished iteration 96
# [LightGBM] [Info] 45.610516 seconds elapsed, finished iteration 97
# [LightGBM] [Info] 45.913243 seconds elapsed, finished iteration 98
# [LightGBM] [Info] 46.296748 seconds elapsed, finished iteration 99
# [LightGBM] [Info] 46.758265 seconds elapsed, finished iteration 100
# [LightGBM] [Info]
seconds elapsed, finished iteration 116
# [LightGBM] [Info] 13.378824 seconds elapsed, finished iteration 117
# [LightGBM] [Info] 13.461403 seconds elapsed, finished iteration 118
# [LightGBM] [Info] 13.511321 seconds elapsed, finished iteration 119
# [LightGBM] [Info] 13.593748 seconds elapsed, finished iteration 120
# [LightGBM] [Info] 13.678501 seconds elapsed, finished iteration 121
# [LightGBM] [Info] 13.759755 seconds elapsed, finished iteration 122
# [LightGBM] [Info] 13.838379 seconds elapsed, finished iteration 123
# [LightGBM] [Info] 13.911351 seconds elapsed, finished iteration 124
# [LightGBM] [Info] 13.996414 seconds elapsed, finished iteration 125
# [LightGBM] [Info] 14.067272 seconds elapsed, finished iteration 126
# [LightGBM] [Info] 14.125673 seconds elapsed, finished iteration 127
# [LightGBM] [Info] 14.189146 seconds elapsed, finished iteration 128
# [LightGBM] [Info] 14.252312 seconds elapsed, finished iteration 129
# [LightGBM] [Info] 14.334985 seconds elapsed, finished iteration 130
# [LightGBM] [Info] 14.515253 seconds elapsed, finished iteration 131
# [LightGBM] [Info] 14.627689 seconds elapsed, finished iteration 132
# [LightGBM] [Info] 14.693858 seconds elapsed, finished iteration 133
# [LightGBM] [Info] 14.761293 seconds elapsed, finished iteration 134
# [LightGBM] [Info] 14.827918 seconds elapsed, finished iteration 135
# [LightGBM] [Info] 14.972454 seconds elapsed, finished iteration 136
# [LightGBM] [Info] 15.104888 seconds elapsed, finished iteration 137
# [LightGBM] [Info] 15.170224 seconds elapsed, finished iteration 138
# [LightGBM] [Info] 15.229560 seconds elapsed, finished iteration 139
# [LightGBM] [Info] 15.305608 seconds elapsed, finished iteration 140
# [LightGBM] [Info] 15.388318 seconds elapsed, finished iteration 141
# [LightGBM] [Info] 15.461550 seconds elapsed, finished iteration 142
# [LightGBM] [Info] 15.540371 seconds elapsed, finished iteration 143
# [LightGBM] [Info] 15.615427 seconds elapsed, finished iteration 144
# [LightGBM] [Info] 15.681960 seconds elapsed, finished iteration 145
# [LightGBM] [Info] 15.758599 seconds elapsed, finished iteration 146
# [LightGBM] [Info] 15.817688 seconds elapsed, finished iteration 147
# [LightGBM] [Info] 15.879006 seconds elapsed, finished iteration 148
# [LightGBM] [Info] 15.947902 seconds elapsed, finished iteration 149
# [LightGBM] [Info] 16.015614 seconds elapsed, finished iteration 150
# [LightGBM] [Info] 16.093510 seconds elapsed, finished iteration 151
# [LightGBM] [Info] 16.164095 seconds elapsed, finished iteration 152
# [LightGBM] [Info] 16.244366 seconds elapsed, finished iteration 153
# [LightGBM] [Info] 16.316606 seconds elapsed, finished iteration 154
# [LightGBM] [Info] 16.369497 seconds elapsed, finished iteration 155
# [LightGBM] [Info] 16.437303 seconds elapsed, finished iteration 156
# [LightGBM] [Info] 16.509922 seconds elapsed, finished iteration 157
# [LightGBM] [Info] 16.582324 seconds elapsed, finished iteration 158
# [LightGBM] [Info] 16.644203 seconds elapsed, finished iteration 159
# [LightGBM] [Info] 16.699144 seconds elapsed, finished iteration 160
# [LightGBM] [Info] 16.851979 seconds elapsed, finished iteration 161
# [LightGBM] [Info] 17.002084 seconds elapsed, finished iteration 162
# [LightGBM] [Info] 17.124156 seconds elapsed, finished iteration 163
# [LightGBM] [Info] 17.184270 seconds elapsed, finished iteration 164
# [LightGBM] [Info] 17.253609 seconds elapsed, finished iteration 165
# [LightGBM] [Info] 17.391306 seconds elapsed, finished iteration 166
# [LightGBM] [Info] 17.519571 seconds elapsed, finished iteration 167
# [LightGBM] [Info] 17.603311 seconds elapsed, finished iteration 168
# [LightGBM] [Info] 17.667155 seconds elapsed, finished iteration 169
# [LightGBM] [Info] 17.739214 seconds elapsed, finished iteration 170
# [LightGBM] [Info] 17.819834 seconds elapsed, finished iteration 171
# [LightGBM] [Info] 17.906426 seconds elapsed, finished iteration 172
# [LightGBM] [Info] 17.977697 seconds elapsed, finished iteration 173
# [LightGBM] [Info] 18.059944 seconds elapsed, finished iteration 174
# [LightGBM] [Info] 18.232694 seconds elapsed, finished iteration 175
# [LightGBM] [Info] 18.369666 seconds elapsed, finished iteration 176
# [LightGBM] [Info] 18.512936 seconds elapsed, finished iteration 177
# [LightGBM] [Info] 18.637370 seconds elapsed, finished iteration 178
# [LightGBM] [Info] 18.708124 seconds elapsed, finished iteration 179
# [LightGBM] [Info] 18.840821 seconds elapsed, finished iteration 180
# [LightGBM] [Info] 18.955588 seconds elapsed, finished iteration 181
# [LightGBM] [Info] 19.085574 seconds elapsed, finished iteration 182
# [LightGBM] [Info] 19.227479 seconds elapsed, finished iteration 183
# [LightGBM] [Info] 19.291863 seconds elapsed, finished iteration 184
# [LightGBM] [Info] 19.378268 seconds elapsed, finished iteration 185
# [LightGBM] [Info] 19.507938 seconds elapsed, finished iteration 186
# [LightGBM] [Info] 19.653859 seconds elapsed, finished iteration 187
# [LightGBM] [Info] 19.760246 seconds elapsed, finished iteration 188
# [LightGBM] [Info] 19.818012 seconds elapsed, finished iteration 189
# [LightGBM] [Info] 19.879072 seconds elapsed, finished iteration 190
# [LightGBM] [Info] 19.943882 seconds elapsed, finished iteration 191
# [LightGBM] [Info] 20.011977 seconds elapsed, finished iteration 192
# [LightGBM] [Info] 20.073200 seconds elapsed, finished iteration 193
# [LightGBM] [Info] 20.216571 seconds elapsed, finished iteration 194
# [LightGBM] [Info] 20.382648 seconds elapsed, finished iteration 195
# [LightGBM] [Info] 20.531530 seconds elapsed, finished iteration 196
# [LightGBM] [Info] 20.630190 seconds elapsed, finished iteration 197
# [LightGBM] [Info] 20.682035 seconds elapsed, finished iteration 198
# [LightGBM] [Info] 20.759057 seconds elapsed, finished iteration 199
# [LightGBM] [Info] 20.837330 seconds elapsed, finished iteration 200
# [LightGBM] [Info] Finished training
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading 200 models
# [LightGBM] [Info] Finished initializing prediction
# [LightGBM] [Info] Finished prediction
# [([u'cnt', u'visits_cnt', u'hits', u'avg_duration', u'avg_time_std', u'avg_ymd_range', u'avg_ymd_cnt', u'avg_hour', u'avg_hour_q10', u'avg_hour_q90', u'max_score1', u'avg_score1', u'q95_score1', u'q90_score1', u'q70_score1', u'q50_score1', u'q30_score1', u'max_score2', u'avg_score2', u'q95_score2', u'q90_score2', u'q70_score2', u'q50_score2', u'q30_score2', u'max_score3', u'avg_score3', u'q95_score3', u'q90_score3', u'q70_score3', u'q50_score3', u'q30_score3', u'max_score4', u'avg_score4', u'q95_score4', u'q90_score4', u'q70_score4', u'q50_score4', u'q30_score4', u'emailru', u'mobile_share', u'vk_share', u'social_share', u'work_hours_hits_share', u'hour_std', u'good_urlfr_share_score1', u'good_urlfr_share_score2', u'good_urlfr_share_score3', u'good_urlfr_timestd_score1', u'max_urlfr_time_std_1', u'pop_country_share', u'pop_city_share', u'density', u'area_sq_km', u'federal_district', u'avg_salary_2015_rub', u'utc_time_zone_val', u'min_score1', u'min_score2', u'min_score3', u'min_score4', 'yaca_0', 'yaca_1', 'yaca_2', 'yaca_3', 'yaca_4', 'yaca_5', 'yaca_6', 'yaca_7', 'yaca_8', 'yaca_9', 'yaca_10', 'yaca_11', 'yaca_12', 'yaca_13', 'yaca_14', 'yaca_15', 'yaca_16', 'yaca_17', 'yaca_18', 'yaca_19', 'yaca_20', 'yaca_21', 'yaca_22', 'yaca_23', 'yaca_24', 'yaca_25', 'yaca_26', 'yaca_27', 'yaca_28', 'yaca_29', 'yaca_30', 'yaca_31', 'yaca_32', 'yaca_33', 'yaca_34', 'yaca_35', 'yaca_36', 'yaca_37', 'yaca_38', 'yaca_39', 'yaca_40', 'yaca_41', 'yaca_42', 'yaca_43', 'yaca_44', 'yaca_45', 'yaca_46', 'yaca_47', 'yaca_48', 'yaca_49', 'yaca_50', 'yaca_51', 'ya
# [LightGBM] [Info] Iteration:68, valid_1 auc : 0.671594

# %%
def modelfit(alg, dtrain, predictors, performCV=True, printFeatureImportance=True, cv_folds=5):
    #Fit the algorithm on the data
    alg.fit(dtrain[predictors], dtrain['Disbursed'])
        
    #Predict training set:
    dtrain_predictions = alg.predict(dtrain[predictors])
    dtrain_predprob = alg.predict_proba(dtrain[predictors])[:,1]
    
    #Perform cross-validation:
    if performCV:
        cv_score = cross_validation.cross_val_score(alg, dtrain[predictors], dtrain['Disbursed'], cv=cv_folds, scoring='roc_auc')
    
    #Print model report:
    print "\nModel Report"
    print "Accuracy : %.4g" % metrics.accuracy_score(dtrain['Disbursed'].values, dtrain_predictions)
    print "AUC Score (Train): %f" % metrics.roc_auc_score(dtrain['Disbursed'], dtrain_predprob)
    
    if performCV:
        print "CV Score : Mean - %.7g | Std - %.7g | Min - %.7g | Max - %.7g" % (np.mean(cv_score),np.std(cv_score),np.min(cv_score),np.max(cv_score))
        
    #Print Feature Importance:
    if printFeatureImportance:
        feat_imp = pd.Series(alg.feature_importances_, predictors).sort_values(ascending=False)
        feat_imp.plot(kind='bar', title='Feature Importances')
        plt.ylabel('Feature Importance Score')

# %% [markdown]
# ### CV Parameter tuning.

# %%
# CV Parameter tuning.
import numpy as np
from sklearn import datasets, metrics, model_selection
from pylightgbm.models import GBMClassifier

# full path to lightgbm executable (on Windows include .exe)
exec_path = "/opt/share/LightGBM-master/lightgbm"

gbm = GBMClassifier(
        exec_path=exec_path,
        min_data_in_leaf=50,
       # is_unbalance = True,
        num_iterations = 200,
        bagging_fraction = 0.8,
        bagging_freq = 10,
        num_leaves = 63,
        metric = 'auc',
        early_stopping_round = 10
)

param_grid = {'learning_rate': [0.1, 0.02], 'bagging_fraction': [0.5, 0.9], 'num_leaves': [63,127]}

scorer = metrics.make_scorer(metrics.accuracy_score, greater_is_better=True)
clf = model_selection.GridSearchCV(gbm, param_grid, scoring=scorer, cv = 3)

clf.fit(clf.fit(df_train[feat_cols_w_yaca], df_train['approve']))

print("Best score: ", clf.best_score_)
print("Best params: ", clf.best_params_)
# Out:
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Warning] Ignoring feature Column_136, only has one value
# [LightGBM] [Warning] Ignoring feature Column_145, only has one value
# [LightGBM] [Warning] Ignoring feature Column_181, only has one value
# [LightGBM] [Warning] Ignoring feature Column_186, only has one value
# [LightGBM] [Warning] Ignoring feature Column_214, only has one value
# [LightGBM] [Warning] Ignoring feature Column_304, only has one value
# [LightGBM] [Warning] Ignoring feature Column_348, only has one value
# [LightGBM] [Warning] Ignoring feature Column_349, only has one value
# [LightGBM] [Warning] Ignoring feature Column_355, only has one value
# [LightGBM] [Warning] Ignoring feature Column_396, only has one value
# [LightGBM] [Warning] Ignoring feature Column_416, only has one value
# [LightGBM] [Warning] Ignoring feature Column_429, only has one value
# [LightGBM] [Warning] Ignoring feature Column_466, only has one value
# [LightGBM] [Warning] Ignoring feature Column_467, only has one value
# [LightGBM] [Warning] Ignoring feature Column_469, only has one value
# [LightGBM] [Info] Finished loading data in 19.495036 seconds
# [LightGBM] [Info] Number of postive: 72844, number of negative: 130133
# [LightGBM] [Info] Number of data: 202977, number of features: 461
# [LightGBM] [Info] Finished initializing training
# [LightGBM] [Info] Started training...
# [LightGBM] [Info] 0.355254 seconds elapsed, finished iteration 1
# [LightGBM] [Info] 0.770612 seconds elapsed, finished iteration 2
# [LightGBM] [Info] 1.158179 seconds elapsed, finished iteration 3
# [LightGBM] [Info] 1.580633 seconds elapsed, finished iteration 4
# [LightGBM] [Info] 1.854530 seconds elapsed, finished iteration 5
# [LightGBM] [Info] 2.131049 seconds elapsed, finished iteration 6
# [LightGBM] [Info] 2.539764 seconds elapsed, finished iteration 7
# [LightGBM] [Info] 2.925713 seconds elapsed, finished iteration 8
# [LightGBM] [Info] 3.199165 seconds elapsed, finished iteration 9
# [LightGBM] [Info] 3.473699 seconds elapsed, finished iteration 10
# [LightGBM] [Info] 3.752807 seconds elapsed, finished iteration 11
# [LightGBM] [Info] 4.006709 seconds elapsed, finished iteration 12
# [LightGBM] [Info] 4.416789 seconds elapsed, finished iteration 13
# [LightGBM] [Info] 4.770349 seconds elapsed, finished iteration 14
# [LightGBM] [Info] 5.183677 seconds elapsed, finished iteration 15
# [LightGBM] [Info] 5.438442 seconds elapsed, finished iteration 16
# [LightGBM] [Info] 5.691909 seconds elapsed, finished iteration 17
# [LightGBM] [Info] 5.946658 seconds elapsed, finished iteration 18
# [LightGBM] [Info] 6.197268 seconds elapsed, finished iteration 19
# [LightGBM] [Info] 6.457809 seconds elapsed, finished iteration 20
# [LightGBM] [Info] 6.719154 seconds elapsed, finished iteration 21
# [LightGBM] [Info] 7.077146 seconds elapsed, finished iteration 22
# [LightGBM] [Info] 7.322556 seconds elapsed, finished iteration 23
# [LightGBM] [Info] 7.584776 seconds elapsed, finished iteration 24
# [LightGBM] [Info] 7.817666 seconds elapsed, finished iteration 25
# [LightGBM] [Info] 8.168962 seconds elapsed, finished iteration 26
# [LightGBM] [Info] 8.412444 seconds elapsed, finished iteration 27
# [LightGBM] [Info] 8.673199 seconds elapsed, finished iteration 28
# [LightGBM] [Info] 8.908526 seconds elapsed, finished iteration 29
# [LightGBM] [Info] 9.221629 seconds elapsed, finished iteration 30
# [LightGBM] [Info] 9.509058 seconds elapsed, finished iteration 31
# [LightGBM] [Info] 9.898353 seconds elapsed, finished iteration 32
# [LightGBM] [Info] 10.139133 seconds elapsed, finished iteration 33
# [LightGBM] [Info] 10.366905 seconds elapsed, finished iteration 34
# [LightGBM] [Info] 10.577229 seconds elapsed, finished iteration 35
# [LightGBM] [Info] 10.805838 seconds elapsed, finished iteration 36
# [LightGBM] [Info] 11.011689 seconds elapsed, finished iteration 37
# [LightGBM] [Info] 11.222597 seconds elapsed, finished iteration 38
# [LightGBM] [Info] 11.420034 seconds elapsed, finished iteration 39
# [LightGBM] [Info] 11.760335 seconds elapsed, finished iteration 40
# [LightGBM] [Info] 11.980108 seconds elapsed, finished iteration 41
# [LightGBM] [Info] 12.204870 seconds elapsed, finished iteration 42
# [LightGBM] [Info] 12.425556 seconds elapsed, finished iteration 43
# [LightGBM] [Info] 12.658278 seconds elapsed, finished iteration 44
# [LightGBM] [Info] 12.915714 seconds elapsed, finished iteration 45
# [LightGBM] [Info] 13.147486 seconds elapsed, finished iteration 46
# [LightGBM] [Info] 13.381482 seconds elapsed, finished iteration 47
# [LightGBM] [Info] 13.631382 seconds elapsed, finished iteration 48
# [LightGBM] [Info] 13.828071 seconds elapsed, finished iteration 49
# [LightGBM] [Info] 14.041201 seconds elapsed, finished iteration 50
# [LightGBM] [Info] 14.303293 seconds elapsed, finished iteration 51
# [LightGBM] [Info] 14.524144 seconds elapsed, finished iteration 52
# [LightGBM] [Info] 14.733042 seconds elapsed, finished iteration 53
# [LightGBM] [Info] 14.967483 seconds elapsed, finished iteration 54
# [LightGBM] [Info] 15.182392 seconds elapsed, finished iteration 55
# [LightGBM] [Info] 15.355213 seconds elapsed, finished iteration 56
# [LightGBM] [Info] 15.635331 seconds elapsed, finished iteration 57
# [LightGBM] [Info] 15.838377 seconds elapsed, finished iteration 58
# [LightGBM] [Info] 16.032281 seconds elapsed, finished iteration 59
# [LightGBM] [Info] 16.257003 seconds elapsed, finished iteration 60
# [LightGBM] [Info] 16.465401 seconds elapsed, finished iteration 61
# [LightGBM] [Info] 16.697604 seconds elapsed, finished iteration 62
# [LightGBM] [Info] 16.918948 seconds elapsed, finished iteration 63
# [LightGBM] [Info] 17.258596 seconds elapsed, finished iteration 64
# [LightGBM] [Info] 17.504010 seconds elapsed, finished iteration 65
# [LightGBM] [Info] 17.883779 seconds elapsed, finished iteration 66
# [LightGBM] [Info] 18.238913 seconds elapsed, finished iteration 67
# [LightGBM] [Info] 18.404768 seconds elapsed, finished iteration 68
# [LightGBM] [Info] 18.550478 seconds elapsed, finished iteration 69
# [LightGBM] [Info] 18.760736 seconds elapsed, finished iteration 70
# [LightGBM] [Info] 18.978187 seconds elapsed, finished iteration 71
# [LightGBM] [Info] 19.158226 seconds elapsed, finished iteration 72
# [LightGBM] [Info] 19.326503 seconds elapsed, finished iteration 73
# [LightGBM] [Info] 19.499445 seconds elapsed, finished iteration 74
# [LightGBM] [Info] 19.662765 seconds elapsed, finished iteration 75
# [LightGBM] [Info] 19.816413 seconds elapsed, finished iteration 76
# [LightGBM] [Info] 20.001556 seconds elapsed, finished iteration 77
# [LightGBM] [Info] 20.195075 seconds elapsed, finished iteration 78
# [LightGBM] [Info] 20.506285 seconds elapsed, finished iteration 79
# [LightGBM] [Info] 20.662505 seconds elapsed, finished iteration 80
# [LightGBM] [Info] 20.861999 seconds elapsed, finished iteration 81
# [LightGBM] [Info] 21.216847 seconds elapsed, finished iteration 82
# [LightGBM] [Info] 21.464373 seconds elapsed, finished iteration 83
# [LightGBM] [Info] 21.657137 seconds elapsed, finished iteration 84
# [LightGBM] [Info] 21.794291 seconds elapsed, finished iteration 85
# [LightGBM] [Info] 21.918702 seconds elapsed, finished iteration 86
# [LightGBM] [Info] 22.097268 seconds elapsed, finished iteration 87
# [LightGBM] [Info]
seconds elapsed, finished iteration 58
# [LightGBM] [Info] 46.649596 seconds elapsed, finished iteration 59
# [LightGBM] [Info] 47.382571 seconds elapsed, finished iteration 60
# [LightGBM] [Info] 48.176368 seconds elapsed, finished iteration 61
# [LightGBM] [Info] 48.940742 seconds elapsed, finished iteration 62
# [LightGBM] [Info] 49.632598 seconds elapsed, finished iteration 63
# [LightGBM] [Info] 50.369697 seconds elapsed, finished iteration 64
# [LightGBM] [Info] 51.126274 seconds elapsed, finished iteration 65
# [LightGBM] [Info] 51.835175 seconds elapsed, finished iteration 66
# [LightGBM] [Info] 52.659906 seconds elapsed, finished iteration 67
# [LightGBM] [Info] 53.393400 seconds elapsed, finished iteration 68
# [LightGBM] [Info] 54.118383 seconds elapsed, finished iteration 69
# [LightGBM] [Info] 54.990392 seconds elapsed, finished iteration 70
# [LightGBM] [Info] 55.760989 seconds elapsed, finished iteration 71
# [LightGBM] [Info] 56.637335 seconds elapsed, finished iteration 72
# [LightGBM] [Info] 57.442169 seconds elapsed, finished iteration 73
# [LightGBM] [Info] 58.218171 seconds elapsed, finished iteration 74
# [LightGBM] [Info] 59.134000 seconds elapsed, finished iteration 75
# [LightGBM] [Info] 59.861237 seconds elapsed, finished iteration 76
# [LightGBM] [Info] 60.579726 seconds elapsed, finished iteration 77
# [LightGBM] [Info] 61.255897 seconds elapsed, finished iteration 78
# [LightGBM] [Info] 61.917739 seconds elapsed, finished iteration 79
# [LightGBM] [Info] 62.619425 seconds elapsed, finished iteration 80
# [LightGBM] [Info] 63.306754 seconds elapsed, finished iteration 81
# [LightGBM] [Info] 64.007348 seconds elapsed, finished iteration 82
# [LightGBM] [Info] 64.702419 seconds elapsed, finished iteration 83
# [LightGBM] [Info] 65.395546 seconds elapsed, finished iteration 84
# [LightGBM] [Info] 66.061764 seconds elapsed, finished iteration 85
# [LightGBM] [Info] 66.724838 seconds elapsed, finished iteration 86
# [LightGBM] [Info] 67.433242 seconds elapsed, finished iteration 87
# [LightGBM] [Info] 68.103085 seconds elapsed, finished iteration 88
# [LightGBM] [Info] 68.962355 seconds elapsed, finished iteration 89
# [LightGBM] [Info] 69.650496 seconds elapsed, finished iteration 90
# [LightGBM] [Info] 70.396363 seconds elapsed, finished iteration 91
# [LightGBM] [Info] 71.204021 seconds elapsed, finished iteration 92
# [LightGBM] [Info] 72.093025 seconds elapsed, finished iteration 93
# [LightGBM] [Info] 72.822818 seconds elapsed, finished iteration 94
# [LightGBM] [Info] 73.572535 seconds elapsed, finished iteration 95
# [LightGBM] [Info] 74.510225 seconds elapsed, finished iteration 96
# [LightGBM] [Info] 75.187685 seconds elapsed, finished iteration 97
# [LightGBM] [Info] 75.938473 seconds elapsed, finished iteration 98
# [LightGBM] [Info] 76.598792 seconds elapsed, finished iteration 99
# [LightGBM] [Info] 77.267083 seconds elapsed, finished iteration 100
# [LightGBM] [Info] 77.919269 seconds elapsed, finished iteration 101
# [LightGBM] [Info] 78.765747 seconds elapsed, finished iteration 102
# [LightGBM] [Info] 79.500189 seconds elapsed, finished iteration 103
# [LightGBM] [Info] 80.263486 seconds elapsed, finished iteration 104
# [LightGBM] [Info] 80.992699 seconds elapsed, finished iteration 105
# [LightGBM] [Info] 81.636689 seconds elapsed, finished iteration 106
# [LightGBM] [Info] 82.285074 seconds elapsed, finished iteration 107
# [LightGBM] [Info] 82.940803 seconds elapsed, finished iteration 108
# [LightGBM] [Info] 83.582718 seconds elapsed, finished iteration 109
# [LightGBM] [Info] 84.386055 seconds elapsed, finished iteration 110
# [LightGBM] [Info] 85.166693 seconds elapsed, finished iteration 111
# [LightGBM] [Info] 85.858190 seconds elapsed, finished iteration 112
# [LightGBM] [Info] 86.575784 seconds elapsed, finished iteration 113
# [LightGBM] [Info] 87.291702 seconds elapsed, finished iteration 114
# [LightGBM] [Info] 87.941678 seconds elapsed, finished iteration 115
# [LightGBM] [Info] 88.903894 seconds elapsed, finished iteration 116
# [LightGBM] [Info] 89.606472 seconds elapsed, finished iteration 117
# [LightGBM] [Info] 90.329844 seconds elapsed, finished iteration 118
# [LightGBM] [Info] 90.995416 seconds elapsed, finished iteration 119
# [LightGBM] [Info] 91.672388 seconds elapsed, finished iteration 120
# [LightGBM] [Info] 92.325983 seconds elapsed, finished iteration 121
# [LightGBM] [Info] 92.983505 seconds elapsed, finished iteration 122
# [LightGBM] [Info] 93.601362 seconds elapsed, finished iteration 123
# [LightGBM] [Info] 94.243747 seconds elapsed, finished iteration 124
# [LightGBM] [Info] 94.876601 seconds elapsed, finished iteration 125
# [LightGBM] [Info] 95.519833 seconds elapsed, finished iteration 126
# [LightGBM] [Info] 96.131653 seconds elapsed, finished iteration 127
# [LightGBM] [Info] 96.768945 seconds elapsed, finished iteration 128
# [LightGBM] [Info] 97.885000 seconds elapsed, finished iteration 129
# [LightGBM] [Info] 98.573582 seconds elapsed, finished iteration 130
# [LightGBM] [Info] 99.236711 seconds elapsed, finished iteration 131
# [LightGBM] [Info] 100.048054 seconds elapsed, finished iteration 132
# [LightGBM] [Info] 100.710894 seconds elapsed, finished iteration 133
# [LightGBM] [Info] 101.354042 seconds elapsed, finished iteration 134
# [LightGBM] [Info] 102.145630 seconds elapsed, finished iteration 135
# [LightGBM] [Info] 102.754718 seconds elapsed, finished iteration 136
# [LightGBM] [Info] 103.499369 seconds elapsed, finished iteration 137
# [LightGBM] [Info] 104.116340 seconds elapsed, finished iteration 138
# [LightGBM] [Info] 104.738310 seconds elapsed, finished iteration 139
# [LightGBM] [Info] 105.361765 seconds elapsed, finished iteration 140
# [LightGBM] [Info] 106.006589 seconds elapsed, finished iteration 141
# [LightGBM] [Info] 106.650690 seconds elapsed, finished iteration 142
# [LightGBM] [Info] 107.376965 seconds elapsed, finished iteration 143
# [LightGBM] [Info] 108.003280 seconds elapsed, finished iteration 144
# [LightGBM] [Info] 108.692694 seconds elapsed, finished iteration 145
# [LightGBM] [Info] 109.313312 seconds elapsed, finished iteration 146
# [LightGBM] [Info] 109.956628 seconds elapsed, finished iteration 147
# [LightGBM] [Info] 110.574846 seconds elapsed, finished iteration 148
# [LightGBM] [Info] 111.207052 seconds elapsed, finished iteration 149
# [LightGBM] [Info] 111.849373 seconds elapsed, finished iteration 150
# [LightGBM] [Info] 112.481012 seconds elapsed, finished iteration 151
# [LightGBM] [Info] 113.066041 seconds elapsed, finished iteration 152
# [LightGBM] [Info] 113.685651 seconds elapsed, finished iteration 153
# [LightGBM] [Info] 114.296617 seconds elapsed, finished iteration 154
# [LightGBM] [Info] 115.009874 seconds elapsed, finished iteration 155
# [LightGBM] [Info] 115.575002 seconds elapsed, finished iteration 156
# [LightGBM] [Info] 116.156473 seconds elapsed, finished iteration 157
# [LightGBM] [Info] 116.755595 seconds elapsed, finished iteration 158
# [LightGBM] [Info] 117.512664 seconds elapsed, finished iteration 159
# [LightGBM] [Info] 118.257547 seconds elapsed, finished iteration 160
# [LightGBM] [Info] 118.880656 seconds elapsed, finished iteration 161
# [LightGBM] [Info] 119.473780 seconds elapsed, finished iteration 162
# [LightGBM] [Info] 120.122475 seconds elapsed, finished iteration 163
# [LightGBM] [Info] 120.868438 seconds elapsed, finished iteration 164
# [LightGBM] [Info] 121.510015 seconds elapsed, finished iteration 165
# [LightGBM] [Info] 122.482429 seconds elapsed, finished iteration 166
# [LightGBM] [Info] 123.090449 seconds elapsed, finished iteration 167
# [LightGBM] [Info] 123.652260 seconds elapsed, finished iteration 168
# [LightGBM] [Info] 124.391182 seconds elapsed, finished iteration 169
# [LightGBM] [Info] 125.261752 seconds elapsed, finished iteration 170
# [LightGBM] [Info] 126.020305 seconds elapsed, finished iteration 171
# [LightGBM] [Info] 126.624323 seconds elapsed, finished iteration 172
# [LightGBM] [Info] 127.348569 seconds elapsed, finished iteration 173
# [LightGBM] [Info] 128.004120 seconds elapsed, finished iteration 174
# [LightGBM] [Info] 128.616363 seconds elapsed, finished iteration 175
# [LightGBM] [Info] 129.203026 seconds elapsed, finished iteration 176
# [LightGBM] [Info] 129.936287 seconds elapsed, finished iteration 177
# [LightGBM] [Info] 130.609381 seconds elapsed, finished iteration 178
# [LightGBM] [Info] 131.221045 seconds elapsed, finished iteration 179
# [LightGBM] [Info] 131.846623 seconds elapsed, finished iteration 180
# [LightGBM] [Info] 132.701299 seconds elapsed, finished iteration 181
# [LightGBM] [Info] 133.435796 seconds elapsed, finished iteration 182
# [LightGBM] [Info] 134.153260 seconds elapsed, finished iteration 183
# [LightGBM] [Info] 134.726325 seconds elapsed, finished iteration 184
# [LightGBM] [Info] 135.396180 seconds elapsed, finished iteration 185
# [LightGBM] [Info] 135.963057 seconds elapsed, finished iteration 186
# [LightGBM] [Info] 136.513537 seconds elapsed, finished iteration 187
# [LightGBM] [Info] 137.107649 seconds elapsed, finished iteration 188
# [LightGBM] [Info] 137.805754 seconds elapsed, finished iteration 189
# [LightGBM] [Info] 138.380888 seconds elapsed, finished iteration 190
# [LightGBM] [Info] 138.963726 seconds elapsed, finished iteration 191
# [LightGBM] [Info] 139.535054 seconds elapsed, finished iteration 192
# [LightGBM] [Info] 140.076886 seconds elapsed, finished iteration 193
# [LightGBM] [Info] 140.647437 seconds elapsed, finished iteration 194
# [LightGBM] [Info] 141.253717 seconds elapsed, finished iteration 195
# [LightGBM] [Info] 141.789883 seconds elapsed, finished iteration 196
# [LightGBM] [Info] 142.465485 seconds elapsed, finished iteration 197
# [LightGBM] [Info] 143.051573 seconds elapsed, finished iteration 198
# [LightGBM] [Info] 143.667420 seconds elapsed, finished iteration 199
# [LightGBM] [Info] 144.207365 seconds elapsed, finished iteration 200
# [LightGBM] [Info] Finished training
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-314-2e46f50a6586> in <module>()
#      24 clf = model_selection.GridSearchCV(gbm, param_grid, scoring=scorer, cv = 3)
#      25
# ---> 26 clf.fit(clf.fit(df_train[feat_cols_w_yaca], df_train['approve']))
#      27
#      28 print("Best score: ", clf.best_score_)
#
# /opt/anaconda/lib/python2.7/site-packages/sklearn/model_selection/_search.pyc in fit(self, X, y, groups)
#     938             train/test set.
#     939         """
# --> 940         return self._fit(X, y, groups, ParameterGrid(self.param_grid))
#     941
#     942
#
# /opt/anaconda/lib/python2.7/site-packages/sklearn/model_selection/_search.pyc in _fit(self, X, y, groups, parameter_iterable)
#     539         self.scorer_ = check_scoring(self.estimator, scoring=self.scoring)
#     540
# --> 541         X, y, groups = indexable(X, y, groups)
#     542         n_splits = cv.get_n_splits(X, y, groups)
#     543         if self.verbose > 0 and isinstance(parameter_iterable, Sized):
#
# /opt/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in indexable(*iterables)
#     204         else:
#     205             result.append(np.array(X))
# --> 206     check_consistent_length(*result)
#     207     return result
#     208
#
# /opt/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_consistent_length(*arrays)
#     175     """
#     176
# --> 177     lengths = [_num_samples(X) for X in arrays if X is not None]
#     178     uniques = np.unique(lengths)
#     179     if len(uniques) > 1:
#
# /opt/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in _num_samples(x)
#     124         if len(x.shape) == 0:
#     125             raise TypeError("Singleton array %r cannot be considered"
# --> 126                             " a valid collection." % x)
#     127         return x.shape[0]
#     128     else:
#
# TypeError: Singleton array array(GridSearchCV(cv=3, error_score='raise',
#        estimator=GBMClassifier(application='binary', bagging_fraction=0.8, bagging_freq=10,
#        bagging_seed=3, boosting_type='gbdt', config='', drop_rate=0.01,
#        drop_seed=4, early_stopping_round=10,
#        exec_path='/opt/share/LightGBM-master/lightgbm',
#        feature_fraction=1.0, feature_fract...ass=1, num_iterations=200, num_leaves=63, num_threads=1,
#        tree_learner='serial', verbose=True),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'num_leaves': [63, 127], 'learning_rate': [0.1, 0.02], 'bagging_fraction': [0.5, 0.9]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=make_scorer(accuracy_score), verbose=0), dtype=object) cannot be considered a valid collection.

# %%
sklearn.cross_validation.cross_val_score
# Out:
# <function sklearn.cross_validation.cross_val_score>

# %%
import xgboost as xgb
param = {}
#param = {'bst:max_depth':8, 'bst:eta':1, 'silent':1, 'objective':'binary:logistic', 'alpha':1, 'tree_method':'approx'}
param['eval_metric'] = ['auc','logloss']

dtrain = xgb.DMatrix( df_train[feat_cols], label=df_train['approve'],missing=np.nan)
dvalid = xgb.DMatrix( df_valid[feat_cols], label=df_valid['approve'],missing=np.nan)

evallist  = [(dvalid,'eval'), (dtrain,'train')]
num_round = 100
bst = xgb.train( param, dtrain, num_round, evallist)

# %% [markdown]
# лучшая итерация [12]	eval-auc:0.672253	eval-logloss:0.629216	train-auc:0.681619	train-logloss:0.620445

# %% [markdown]
# ###Яндекс каталог.

# %%
from sklearn.feature_extraction import DictVectorizer
v = DictVectorizer(sparse=True)

df_train_yaca_sparse = v.fit_transform(df_train['yaca_str'].map(lambda s: { kv.split(':')[0]:float(kv.split(':')[1])  for kv in s.split(' ')} if len(s) > 0 else {}))
df_valid_yaca_sparse = v.transform(df_valid['yaca_str'].map(lambda s: { kv.split(':')[0]:float(kv.split(':')[1])  for kv in s.split(' ')} if len(s) > 0 else {}))

# %%
import sklearn.linear_model
clfLR = sklearn.linear_model.LogisticRegression(penalty = 'l1')

clfLR.fit(df_train_yaca_sparse,df_train['approve'])

# %%
print('Logistic regression for yaca features on train {:.4f}; test: {:.4f}'.format(
           sklearn.metrics.roc_auc_score(y_true = df_train['approve'],y_score = clfLR.predict_proba(df_train_yaca_sparse)[:,1]),
           sklearn.metrics.roc_auc_score(y_true = df_valid['approve'],y_score = clfLR.predict_proba(df_valid_yaca_sparse)[:,1])
    ))

# %%
import sklearn.ensemble
clfRF = sklearn.ensemble.RandomForestClassifier(max_depth = 5,n_estimators = 50)

clfRF.fit(df_train_yaca_sparse,df_train['approve'])

# %%
print('Random Forest for yaca features on train {:.4f}; test: {:.4f}'.format(
           sklearn.metrics.roc_auc_score(y_true = df_train['approve'],y_score = clfRF.predict_proba(df_train_yaca_sparse)[:,1]),
           sklearn.metrics.roc_auc_score(y_true = df_valid['approve'],y_score = clfRF.predict_proba(df_valid_yaca_sparse)[:,1])
    ))

# %%
#xgboost for yaca stangalone
dtrain_yaca = xgb.DMatrix( df_train_yaca_sparse, label=df_train['approve'])
dvalid_yaca = xgb.DMatrix( df_valid_yaca_sparse, label=df_valid['approve'])

evallist  = [(dvalid_yaca,'eval'), (dtrain_yaca,'train')]
num_round = 40
bst = xgb.train( param, dtrain_yaca, num_round, evallist )

# %% [markdown]
# лучшая итерация [37]	eval-auc:0.631754	eval-logloss:0.643753	train-auc:0.663964	train-logloss:0.628422

# %%
#bst = xgb.train( param, dtrain_yaca, 40, evallist)

df_train.loc[:,'yaca_pred'] = bst.predict(dtrain_yaca)
df_valid.loc[:,'yaca_pred'] = bst.predict(dvalid_yaca)

# %%
#param = {'bst:max_depth':4, 'bst:eta':0.1, 'silent':1, 'objective':'binary:logistic', 'alpha':0.5, 'tree_method':'approx'}
param['eval_metric'] = ['auc','logloss']

#dtrain = xgb.DMatrix(df_train[feat_cols.tolist() + ['yaca_pred']], label=df_train['approve'],missing=np.nan)
#dvalid = xgb.DMatrix(df_valid[feat_cols.tolist() + ['yaca_pred']], label=df_valid['approve'],missing=np.nan)

evallist  = [(dvalid,'eval'), (dtrain,'train')]
num_round = 400
bst = xgb.train( param, dtrain, num_round, evallist )

# %% [markdown]
# ####Использование предсказания yaca в качесте фактора не дает улучшения, даже при том, что мы переобучаемся на валидационной выборке.

# %%
from sklearn.feature_extraction import DictVectorizer
v = DictVectorizer(sparse=True)

df_train_yaca_sparse1 = v.fit_transform(df_train['yaca_str'].map(lambda s: { kv.split(':')[0]:1  for kv in s.split(' ')} if len(s) > 0 else {}))
df_valid_yaca_sparse1 = v.transform(df_valid['yaca_str'].map(lambda s: { kv.split(':')[0]:1  for kv in s.split(' ')} if len(s) > 0 else {}))

# %%
#xgboost for yaca stangalone with 1
dtrain_yaca_1 = xgb.DMatrix( df_train_yaca_sparse1, label=df_train['approve'])
dvalid_yaca_1 = xgb.DMatrix( df_valid_yaca_sparse1, label=df_valid['approve'])

evallist  = [(dvalid_yaca_1,'eval'), (dtrain_yaca_1,'train')]
num_round = 800
bst = xgb.train( param, dtrain_yaca_1, num_round, evallist )

# %% [markdown]
# ####Удивительно, но с 1 в значениях получилось хуже, чем с TF.
# ####TODO: попробовать TFIDF

# %% [markdown]
# #####все факторы yaca + простыней

# %%
from sklearn.feature_extraction import DictVectorizer
v = DictVectorizer(sparse=False)

df_train_yaca_dense = v.fit_transform(df_train['yaca_str'].map(lambda s: { kv.split(':')[0]:float(kv.split(':')[1])  for kv in s.split(' ')} if len(s) > 0 else {}))
df_valid_yaca_dense = v.transform(df_valid['yaca_str'].map(lambda s: { kv.split(':')[0]:float(kv.split(':')[1])  for kv in s.split(' ')} if len(s) > 0 else {}))
#df_train_yaca_dense = v.fit_transform(df_train['yaca_str'].map(lambda s: { kv.split(':')[0]:1  for kv in s.split(' ')} if len(s) > 0 else {}))
#df_test_yaca_dense = v.transform(df_test['yaca_str'].map(lambda s: { kv.split(':')[0]:1 for kv in s.split(' ')} if len(s) > 0 else {}))

# %%
yaca_cols = ['yaca_{}'.format(i) for i in range(df_train_yaca_dense.shape[1])]
for i in range(df_train_yaca_dense.shape[1]):
    df_train.loc[:,'yaca_{}'.format(i)] = df_train_yaca_dense[:,i]
    df_valid.loc[:,'yaca_{}'.format(i)] = df_valid_yaca_dense[:,i]

# %%
feat_cols_w_yaca = feat_cols.tolist() + yaca_cols
dtrain_all_yaca = xgb.DMatrix( df_train[feat_cols_w_yaca], label=df_train['approve'], missing = np.nan)
dvalid_all_yaca = xgb.DMatrix( df_valid[feat_cols_w_yaca], label=df_valid['approve'], missing = np.nan)

# %%
param = {
    'bst:max_depth': 5,     
    'silent': 1, 
    'objective':'binary:logistic', 
    'alpha': 1, 
    'tree_method':'approx',
    'learning_rate': 0.04,
    'eval_metric' : ['logloss','auc']
}
#'bst:eta':1, 
#    'tree_method':'approx',
evallist  = [(dvalid_all_yaca,'eval'), (dtrain_all_yaca,'train')]
num_round = 730
bst = xgb.train( param, dtrain_all_yaca, num_round, evallist,early_stopping_rounds = 10)
print(bst.best_iteration)

# %%
параметры по умолчанию [401]	eval-auc:0.680291	eval-logloss:0.623436	train-auc:0.703328	train-logloss:0.608144
                
------                 
param = {
    'bst:max_depth': 5,     
    'silent': 1, 
    'objective':'binary:logistic', 
    'alpha': 1, 
    'tree_method':'approx',
    'learning_rate': 0.04,
    'eval_metric' : ['logloss','auc']
}
[733]	eval-logloss	0.623207	eval-auc	0.680725	train-logloss	0.601083	train-auc	0.716556

                
----------

# %%
#df_test preparation
df_test_yaca_dense = v.transform(df_test['yaca_str'].map(lambda s: { kv.split(':')[0]:float(kv.split(':')[1])  for kv in s.split(' ')} if len(s) > 0 else {}))
for i in range(df_train_yaca_dense.shape[1]):
    df_test.loc[:,'yaca_{}'.format(i)] = df_test_yaca_dense[:,i]
dtest_all_yaca = xgb.DMatrix( df_test[feat_cols_w_yaca], label=df_test['approve'], missing = np.nan)

# %%
df_train.loc[:,'pred'] = bst.predict(dtrain_all_yaca)
df_valid.loc[:,'pred'] = bst.predict(dvalid_all_yaca)
df_test.loc[:,'pred'] = bst.predict(dtest_all_yaca)

# %%
def metrics(y_true,y_score,lift = None, return_str = False):
    import sklearn
    import collections
    
    if True:
        res = collections.OrderedDict()
        samp_size = len(y_true)
        res['Sample size'] = samp_size
        res['Posit share'] = sum(y_true) * 1./ samp_size
        res['Sample size'] = len(y_true)
        res['AUC ROC'] = sklearn.metrics.roc_auc_score(y_true = y_true, y_score = y_score)
        res['AUC PR'] = sklearn.metrics.auc(
                        *sklearn.metrics.precision_recall_curve(y_true = y_true, probas_pred  = y_score)[:2],
                        reorder = True
        )
        res['Log loss'] = sklearn.metrics.log_loss(y_true = y_true, y_pred = y_score)
        if lift:
            predictions_and_labels = sorted(zip(y_score,y_true), reverse = True)
            for l in lift:
                res['Lift ' + str(l)] = sum([e[1] for e in predictions_and_labels[:int(l * samp_size)]]) * 1. / int(l * samp_size) / res['Posit share']
                
        if return_str:
            res = '\n'.join(['{:<12}: {:.5f}'.format(k,v) for (k,v) in res.items()]) + '.'
        return res

# %%
print('Feature importances:\n' + '\n'.join('{:<25}  {:<5}'.format(k,v) for k,v in sorted(bst.get_fscore().items(),key = lambda e:-e[1])))

# %%
print('All features + all yaca data xgboost model.\n\nTrain \n{}\n\nValid\n{}\n\nTest\n{}\n'.format(
        metrics(y_true = df_train['approve'],y_score = df_train['pred'],lift = [0.05,0.1,0.2,0.5],return_str = True),
        metrics(y_true = df_valid['approve'],y_score = df_valid['pred'],lift = [0.05,0.1,0.2,0.5],return_str = True),
        metrics(y_true = df_test['approve'],y_score = df_test['pred'],lift = [0.05,0.1,0.2,0.5],return_str = True)
    ))

# %% [markdown]
# ### Результат лучше всех предыдущих, но в целом качество еще оставляет сомненения, можно ли это применять на проде.
