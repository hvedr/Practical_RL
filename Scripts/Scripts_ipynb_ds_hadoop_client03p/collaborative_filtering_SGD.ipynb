# %% [markdown]
# ## SVD модель интернет-логов. Выделение тем. ##
# Есть таблица интернет-логов  $m_{ij}$, каждая строка отвечает одному интернет-пользователю, каждый столбец - фрагменту урла. $m_{ij}=1$, если посетитель $i$ посетил фрагмент урла $j$ в рамках рассматриваемой сессии, иначе $m_{ij}=0$.
#
# Выделим темы - группировки урлов и пользователей. Для этого воспользуемся модификацией SVD разложения.
#
# Зафиксируем количество тем $K$. Для каждого пользователя сформируем вектор длины $K$, отражающий степень близости темы к пользователю (которая может быть отрицательной). Получаем матрицу $X_{ik}$. Индекс $i$ отвечает пользователю, $k$ отвечает теме.
#
# Аналогично сформируем вектор  длины $K$ для каждого фрагмента урла. Получаем матрицу $Y_{kj}$. $k$ отвечает теме, $j$ отвечает фрагменту урла.
#
# Далее для каждого пользователя $i$ введем число $a_i$, которое в целом характеризует его интернет-активность.
#
# Аналогично, элементы вектора $b_j$ отражают популярность урла $j$.
#
# Параметр $\mu$ есть усредняющий скаляр по всей выборке.
#
# Далее интерес пользователя  $i$ к фрагменту урла $j$ будем моделировать величиной $s_{ij} = \mu + a_i + b_j + \sum_k X_{ik} \cdot Y_{kj}$.
#
# Для перевода этой величины в вероятность, воспользуемся логистической функцией:
# $\hat{m}_{ij} = 1/(1+e^{-s_{ij}})$.
#
# Таким образом, построенная величина $\hat{m}_{ij}$ есть  модельная оценка вероятности посещения пользователем $i$ фрагмента урла $j$.
#
# Введем функцию ошибки $L = \sum_{ij} L_{ij} $,
# $$L_{ij} = -m_{ij} \cdot \ln(\hat{m}_{ij}) - (1 - m_{ij}) \cdot \ln(1 - \hat{m}_{ij}) + \lambda_{0} \cdot \mu + \lambda_{1}\cdot (a_i^2 + b_j^2) + \lambda_{2} \cdot \sum_k(X_{ik}^2 + Y_{kj}^2)$$.
#
# Для обучения будем использовать стохастический градиентный спуск.
# Следующий шаг - применять  модификацию  градиентного спуска - Adadelta http://int8.io/comparison-of-optimization-techniques-stochastic-gradient-descent-momentum-adagrad-and-adadelta/#AdaDelta_8211_implementation.

# %% [markdown]
# #####Конфигурация

# %%
#!/usr/bin/env python
#Config
from pyspark import SparkConf, SparkContext, HiveContext
#import re
import numpy as np
import pandas as pd
#import datetime
#from pyspark.mllib.regression import LabeledPoint
#from pyspark.mllib.feature import HashingTF
#from pyspark.mllib.classification import LogisticRegressionWithSGD, NaiveBayes, NaiveBayesModel
#import scipy.sparse as sps
#from pyspark.mllib.linalg import Vectors
#import sklearn
import itertools
import datetime
import sys


#from pyspark.mllib.recommendation import ALS, MatrixFactorizationModel, Rating

try:
    sc.stop()
except NameError:
    pass

conf = SparkConf().set("spark.executor.instances", 8).set("spark.driver.maxResultSize", "2g")
sc = SparkContext()
hc = HiveContext(sc)
sc.setCheckpointDir('checkpoint/')

# %% [markdown]
# ####Настройка параметров: $\lambda$ и шага

# %%
create_query ='''
create table user_kposminin.urlfr_dict as 
with src as (select * from user_kposminin.visits_ext where ymd = '2016-04-12')

select 
  urlfr, 
  rank() over (order by urlfr) as urlfr_num,
  count(*) as cnt 
from src 
group by urlfr 
having cnt > 500
;

create table user_kposminin.id_dict as 
with src as (select * from user_kposminin.visits_ext where ymd = '2016-04-12')
select 
  id,
  rank() over (order by id) as id_num,
  count(*) as cnt 
from src 
group by urlfr 
having cnt > 10 and cnt < 500
;

create_table user_kposminin.visits_enum_dense_20160412 as
with src as (select * from user_kposminin.visits_ext where ymd = '2016-04-12')
select
  s.id, i.id_num,
  s.urlfr, u.urlfr_num,
  s.cnt
from
  src s
  inner join user_kposminin.urlfr_dict u on s.urlfr = u.urlfr
  inner join user_kposminin.id_dict i on s.id = i.id
where 
u.cnt > 1000
and i.cnt > 30


'''

start_time = datetime.datetime.now()

# Param selection


query = '''
select id_num,urlfr_num from 
(select id_num,urlfr_num,count(*) over (partition by id_num) as uf_cnt,count(*) over (partition by urlfr_num) as id_cnt from user_kposminin.visits_enum_dense_20160412 
where id_num between 0 and 20000 ) a
where id_cnt > 15 and uf_cnt > 15
'''


K = 50
id_cnt = 20001
urlfr_cnt = 384000
epochs = 20


#lmbd = np.array([0.01, 0.01, 0.01])

#step = np.array([0.001, 0.005, 0.01])

param_grid = []

#   [[0.00001, 0.0001, 0.0001],[0.01, 0.05, 0.01]],
for base_step in np.exp(np.arange(-4,0,2)):
    for base_lmbd in np.exp(np.arange(-8,0,2)):
        for var_step in np.array([[0.001,1,1],[0.1,1,0.1]]):
            for var_lmbd in np.array([[0.0001,1,1],[0.01,0.1,1]]):
                param_grid.append([var_step * base_step,var_lmbd * base_lmbd])

lmbd_corr = np.ones(K) #np.exp(np.arange(-3,3,6./K))


# Load and parse the data
sampled_data = hc.sql(query) \
            .collect()
urlfr_cnt1 = len(set([e[1] for e in sampled_data])) + 1
id_cnt1 = len(set([e[0] for e in sampled_data])) + 1
print('Sampled data consists of {} rows, {} id and {} uf.'.format(len(sampled_data),id_cnt1,urlfr_cnt1))

train,test = [], []
for r in sampled_data:
    if(np.random.rand() < 0.1):
        test.append(r)
    else:
        train.append(r)
  
 
# prediction is m^hat_{ij} = 1/(1+exp(-s_{ij})) where s_{ij} = mu + a[i] + b[j] + sum_k (X[i,k] * Y[k,j])
# error function is L_{ij} = -m_{ij}*ln(m^hat_{ij}) - (1 - m_{ij})*ln(1 - m^hat_{ij}) + 
#                            lmbd[0] * mu + lmbd[1]*(a_i^2 + b_j^2) + lmbd[2]*sum_k(X_{ik}^2 + Y_{kj}^2)
f = open('data/collab_filter_SGD_param_tuning.csv','a+')
f.write('\n\n New calc at {}'.format(datetime.datetime.now()))
stat = []
prev_id = -1
uf_visited= []
neg_sig_share = 2
rho = 0.9
eps = 1e-6
errors = []
err_thres = 0.005

for step,lmbd in param_grid: # [[[0.0135,0.1353,0.0135],[1e-07,5e-03,5e-03]]]:

    #Init matrices
    mu = np.random.rand(1) - 0.5 - 1 # One-element array to be able to update inside a procedure
    a = np.random.rand(id_cnt) - 0.5
    b = np.random.rand(urlfr_cnt) - 0.5
    X = np.random.rand(id_cnt, K) - 0.5
    Y = np.random.rand(K,urlfr_cnt) - 0.5

    def make_step(i, j, v):
        s = mu[0] + a[i] + b[j] + X[i,:].dot(Y[:,j])
        pred = 1./(1+np.exp(-s))
        err = v - pred # r[2] - pred
        grad_mu = -err + lmbd[0] * mu
        grad_ai = -err + lmbd[1] * a[i]
        grad_bj = -err + lmbd[1] * b[j]
        grad_xi = -err * Y[:,j] + lmbd[2] * X[i,:] * lmbd_corr
        grad_yj = -err * X[i,:] + lmbd[2] * Y[:,j] * lmbd_corr
        
        # TODO Implement Adadelta SGD version. 
        #http://int8.io/comparison-of-optimization-techniques-stochastic-gradient-descent-momentum-adagrad-and-adadelta/#AdaDelta_8211_implementation
        # 
     
        mu[0] += - grad_mu[0] * step[0]
        a[i]  += - grad_ai * step[1]
        b[j]  += - grad_bj * step[1]
        X[i,:] = X[i,:] - grad_xi * step[2]
        Y[:,j] = Y[:,j] - grad_yj * step[2]
    
    for epoch in range(epochs):
        for r in train:
            i,j = r[:2]
            make_step(i, j, 1)
            if i == prev_id:
                uf_visited.append(j)
            else:
                # Add negative examples
                ni = np.random.randint(len(train) - len(uf_visited))
                neg, k = 0, 0
                while(neg < int(len(uf_visited) * neg_sig_share)):
                    if(not train[(ni + k) % len(train)][1] in uf_visited):                        
                        make_step(prev_id, train[(ni + k) % len(train)][1],0)
                        neg += 1
                    k +=1 
                prev_id = i
                uf_visited = [j]
        
        #calc err
        err1_p ,err2_p, err1_n, err2_n = 0, 0, 0, 0
        for r in test:
            i,j = r[:2]
            s = mu[0] + a[i] + b[j] + X[i,:].dot(Y[:,j])
            pred = 1/(1+np.exp(-s))
            err1_p += - 1 * np.log(pred) # r[2] - pred
            err2_p += - 1 * np.log(pred) + lmbd[0] * mu[0] + lmbd[1] * (a[i] ** 2 + b[j] ** 2) + lmbd[2] * (X[i,:].dot(X[i,:]*lmbd_corr) + Y[:,j].dot(Y[:,j]*lmbd_corr))
            
            if i == prev_id:
                uf_visited.append(j)
            else:
                # Add negative examples
                ni = np.random.randint(len(test) - len(uf_visited))
                neg, k = 0, 0
                while(neg < int(len(uf_visited) * neg_sig_share)):
                    if(not test[(ni + k) % len(test)][1] in uf_visited): 
                        i1, j1 = prev_id, train[(ni + k) % len(train)][1]
                        s = mu[0] + a[i1] + b[j1] + X[i1,:].dot(Y[:,j1])
                        pred = 1/(1+np.exp(-s))
                        err1_n += - 1 * np.log(1 - pred) # r[2] - pred
                        err2_n += - 1 * np.log(1 - pred) + lmbd[0] * mu[0] + lmbd[1] * (a[i1] ** 2 + b[j1] ** 2) + lmbd[2] * (X[i1,:].dot(X[i1,:]) + Y[:,j1].dot(Y[:,j1]))                        
                        neg += 1
                    k +=1 
                prev_id = i
                uf_visited = [j]
        err1_t = (err1_p + err1_n) / (len(test) * (neg_sig_share + 1))
        err2_t = (err2_p + err2_n) / (len(test) * (neg_sig_share + 1))
        err1_p /= float(len(test))
        err2_p /= float(len(test))
        err1_n /= len(test) * neg_sig_share
        err2_n /= len(test) * neg_sig_share        
        errors.append(err1_t)
        stat=('{} ' * 9).format(step,lmbd,epoch,err1_t, err1_p,err1_n,err2_t, err2_p,err2_n)
        f.write(stat + '\n')
        print(stat)
        if((len(errors)>6) & (sum(errors[-3:])/3 > sum(errors[-6:-3])/3 - err_thres)): # too fast.
            step = [s * 0.7 for s in step]
        if((len(errors)>13) & (abs(sum(errors[-3:])/3 - sum(errors[-13:-3])/10) < 1e-4)): # too slow.
            step = [s / 0.6 for s in step]
        
        
print('Finish. Work time {}.'.format(datetime.datetime.now()- start_time))
f.write('\nFinish at {}. Work time {}.\n\n\n'.format(datetime.datetime.now(),datetime.datetime.now() - start_time))
f.close()

# %% [markdown]
# ####Выбираем уплотненную подвыбрку логов: пользователей с длиной трека более 40 и фрагментов урлов с более, чем 500 уникальными посетителями в день.
# ####Обучаемся на этой выборке.
# ####В силу ограничения по памяти, обучение осуществляется пачками по 10 тыс пользователей с небольшим количеством эпох на пачку. Скорость довольно небольшая: за день обрабатывается ~ 100 пачек.
# #### Моделируем 150 тем.

# %%
K = 150

full_train_epochs = 8
batch_size = 10000
err_thres = 0.005
step, lmbd = [1e-05,0.015,0.015], [1e-08,3e-04,3e-03]
step = [e/2 for e in step]
#2,2745801053577491e-05,	0,022745801053577486,	0,022745801		2,48E-05	2,48E-04	2,48E-03


urlfr_cnt = hc.sql('select max(urlfr_num) from user_kposminin.visits_enum_dense_20160412').collect()[0][0] + 10
err = []
f = open('data/collab_filter_SGD_calc.csv','a+')
af = open('data/collab_filter_SGD_a_vec.csv','w')
Xf = open('data/collab_filter_SGD_X_matr.csv','w')

#mu = np.random.rand(1) - 0.5 - 2 # One-element array to be able to update inside a procedure
#b = np.random.rand(urlfr_cnt) - 0.5
#Y = np.random.rand(K,urlfr_cnt) - 0.5

lmbd_corr = np.ones(K) #np.exp(np.arange(-3,3,6./K))

query1 = '''
select id_num,urlfr_num from user_kposminin.visits_enum_dense_20160412 
where id_num between #low and #high
'''

for btc in range(1232, 180*10**6/batch_size):

    # Load and parse the data
    train, test = hc.sql(query1.replace('#low',str(btc*batch_size)).replace('#high',str((btc + 1) * batch_size - 1))) \
            .randomSplit([0.9,0.1])
    train = train.collect()
    test  =  test.collect()
    if(len(train) == 0): break
    str2write = '{}. Num {}. Sampled train data consists of {} rows, {} id and {} uf.\n'.format(
                                datetime.datetime.now(),
                                btc, 
                                len(train),len(set([e[0] for e in train])), len(set([e[1] for e in train])))
    print(str2write)
    f.write(str2write)
    id_start = btc*batch_size
    
    id_cnt = batch_size
    stat = []
    prev_id = -1
    uf_visited= []
    neg_sig_share = 2
    cnt = 0
    
    #Init matrices
    a = np.random.rand(id_cnt) - 0.5
    X = np.random.rand(id_cnt, K) - 0.5

    def make_step(i, j, v):
        s = mu[0] + a[i] + b[j] + X[i,:].dot(Y[:,j])
        pred = 1./(1+np.exp(-s))
        err = v - pred # r[2] - pred
        grad_mu = -err + lmbd[0] * mu
        grad_ai = -err + lmbd[1] * a[i]
        grad_bj = -err + lmbd[1] * b[j]
        grad_xi = -err * Y[:,j] + lmbd[2] * X[i,:] * lmbd_corr
        grad_yj = -err * X[i,:] + lmbd[2] * Y[:,j] * lmbd_corr
        mu[0] += - grad_mu[0] * step[0]
        a[i]  += - grad_ai * step[1]
        b[j]  += - grad_bj * step[1]
        X[i,:] = X[i,:] - grad_xi * step[2]
        Y[:,j] = Y[:,j] - grad_yj * step[2]
    
    for epoch in range(full_train_epochs):
        for r in train:
            i,j = r[0] - id_start, r[1]
            make_step(i, j, 1)
            if i == prev_id:
                uf_visited.append(j)
            else:
                # Add negative examples
                ni = np.random.randint(len(train) - len(uf_visited))
                neg, k = 0, 0
                while(neg < int(len(uf_visited) * neg_sig_share)):
                    if(not train[(ni + k) % len(train)][1] in uf_visited):                        
                        make_step(prev_id, train[(ni + k) % len(train)][1],0)
                        neg += 1
                    k +=1
                prev_id = i
                uf_visited = [j]
        
        #calc err
        err1_p ,err2_p, err1_n, err2_n = 0, 0, 0, 0
        for r in test:
            i,j = r[0] - id_start, r[1]
            s = mu[0] + a[i] + b[j] + X[i,:].dot(Y[:,j])
            pred = 1/(1+np.exp(-s))
            err1_p += - 1 * np.log(pred) # r[2] - pred
            err2_p += - 1 * np.log(pred) + lmbd[0] * mu[0] + lmbd[1] * (a[i] ** 2 + b[j] ** 2) + lmbd[2] * (X[i,:].dot(X[i,:]*lmbd_corr) + Y[:,j].dot(Y[:,j]*lmbd_corr))
            
            if i == prev_id:
                uf_visited.append(j)
            else:
                # Add negative examples
                ni = np.random.randint(len(test) - len(uf_visited))
                neg, k = 0, 0
                while(neg < int(len(uf_visited) * neg_sig_share)):
                    if(not test[(ni + k) % len(test)][1] in uf_visited): 
                        i1, j1 = prev_id, train[(ni + k) % len(train)][1]
                        s = mu[0] + a[i1] + b[j1] + X[i1,:].dot(Y[:,j1])
                        pred = 1/(1+np.exp(-s))
                        err1_n += - 1 * np.log(1 - pred) # r[2] - pred
                        err2_n += - 1 * np.log(1 - pred) + lmbd[0] * mu[0] + lmbd[1] * (a[i] ** 2 + b[j] ** 2) + lmbd[2] * (X[i,:].dot(X[i,:]*lmbd_corr) + Y[:,j].dot(Y[:,j]*lmbd_corr))
                        neg += 1
                    k +=1 
                prev_id = i
                uf_visited = [j]
        err1_t = (err1_p + err1_n) / (len(test) * (neg_sig_share + 1))
        err2_t = (err2_p + err2_n) / (len(test) * (neg_sig_share + 1))
        err1_p /= float(len(test))
        err2_p /= float(len(test))
        err1_n /= len(test) * neg_sig_share
        err2_n /= len(test) * neg_sig_share        
        err.append(err1_t)
        stat=('{} ' * 9).format(step,lmbd,epoch,err1_t, err1_p,err1_n,err2_t, err2_p,err2_n)
        f.write(stat + '\n')
        print(stat)
        cnt += 1
        if((cnt > 15) & (sum(err[-3:])/3 > sum(err[-6:-3])/3 - err_thres)): # too fast.
            step = [s * 0.6 for s in step]
            cnt = 0 
        #if((len(err) > 15) & (abs(sum(err[-3:])/3 - sum(err[-13:-3])/10) < 1e-5)): # too slow.
        #    step = [s / 0.6 for s in step]
                    
    for r in test:
        i,j = r[0] - id_start, r[1]
        make_step(i, j, 1)
        
    l = 0
    for e in a:
        af.write('{},{}\n'.format(id_start + l,a[l]))
        l+=1
    l = 0
    for e in X:
        Xf.write('{},{}\n'.format(id_start + l,','.join(str(z) for z in X[l])))
        l+=1
    if cnt % 100 == 0:
        l=0            
        with open('data/collab_filter_SGD_Y_matr.csv','w') as Yf:
            for e in Y:
                Yf.write('{},{}\n'.format(l,','.join(str(z) for z in Y[l])))
                l+=1
        l=0            
        with open('data/collab_filter_SGD_b_vec.csv','w') as bf:
            for e in b:
                bf.write('{},{}\n'.format(l,b[l]))
                l+=1
        f.write('\nmu is {}\n'.format(mu))

print('Finish. Work time {}.'.format(datetime.datetime.now() - start_time))
f.write('\nFinish at {}. Work time {}.\n\n\n'.format(datetime.datetime.now(),datetime.datetime.now() - start_time))
f.close()
# Out:
# 2016-12-27 18:44:39.554111. Num 1232. Sampled train data consists of 142542 rows, 4416 id and 49612 uf.
#
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 0 0.58739426912 1.26380299433 0.249189906514 0.6901225414 1.3664728118 0.351947406202
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 1 0.465641131625 0.836960315015 0.279981539931 0.567765295039 0.939167346953 0.382064269082
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 2 0.413501393004 0.674962914709 0.282770632152 0.515806304913 0.777324904543 0.385047005098
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 3 0.381259426407 0.603427571177 0.270175354022 0.483887718543 0.706058700644 0.372802227492
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 4 0.365106809847 0.560707216863 0.267306606339 0.468272037364 0.663811365706 0.370502373194
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 5 0.349706487376 0.531336475511 0.258891493308 0.453472428276 0.634971586467 0.362722849181
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 6 0.340085008015 0.506852259149 0.256701382447 0.444482343116 0.611073256187 0.36118688658
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 7 0.328165262539 0.495974038872 0.244260874373 0.433144453754 0.600717740568 0.349357810347
# 2016-12-27 18:57:39.459249. Num 1233. Sampled train data consists of 139949 rows, 4413 id and 48917 uf.
#
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 0 0.574334661504 1.17250568676 0.275249148876 0.675453663848 1.27342245421 0.376469268665
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 1 0.465085786571 0.811483264292 0.291887047711 0.565628948974 0.911930380813 0.392478233054
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 2 0.421917789643 0.667950433225 0.298901467851 0.522681203564 0.76859765853 0.399722976081
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 3 0.382499304044 0.597901067998 0.274798422067 0.483793475906 0.698990049644 0.376195189037
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 4 0.366925011217 0.56097848674 0.269898273456 0.468814531469 0.662587541409 0.371928026499
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 5 0.349351716898 0.524933021349 0.261561064672 0.452027496805 0.627261638868 0.364410425774
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 6 0.337820063674 0.512214207165 0.250622991929 0.441193622573 0.615164019011 0.354208424353
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 7 0.329492941934 0.498021801708 0.245228512047 0.433598473182 0.601648527157 0.349573446194
# 2016-12-27 19:12:18.205819. Num 1234. Sampled train data consists of 142412 rows, 4433 id and 49309 uf.
#
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 0 0
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 5 0.353376845736 0.520833999417 0.269648268895 0.450894472578 0.618835131297 0.366924143219
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 6 0.341735420972 0.506791451543 0.259207405687 0.440045682415 0.605481908535 0.357327569355
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 7 0.334111298037 0.494843029327 0.253745432392 0.433186467069 0.594217654788 0.35267087321
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-a50210dafa92> in <module>()
#      30     # Load and parse the data
#      31     train, test = hc.sql(query1.replace('#low',str(btc*batch_size)).replace('#high',str((btc + 1) * batch_size - 1)))             .randomSplit([0.9,0.1])
# ---> 32     train = train.collect()
#      33     test  =  test.collect()
#      34     if(len(train) == 0): break
#
# /opt/apache/spark-1.6.0-bin-hadoop2.6/python/pyspark/sql/dataframe.py in collect(self)
#     278         """
#     279         with SCCallSiteSync(self._sc) as css:
# --> 280             port = self._jdf.collectToPython()
#     281         return list(_load_from_socket(port, BatchedSerializer(PickleSerializer())))
#     282
#
# /opt/apache/spark-1.6.0-bin-hadoop2.6/python/lib/py4j-0.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#     809             proto.END_COMMAND_PART
#     810
# --> 811         answer = self.gateway_client.send_command(command)
#     812         return_value = get_return_value(
#     813             answer, self.gateway_client, self.target_id, self.name)
#
# /opt/apache/spark-1.6.0-bin-hadoop2.6/python/lib/py4j-0.9-src.zip/py4j/java_gateway.py in send_command(self, command, retry)
#     624         connection = self._get_connection()
#     625         try:
# --> 626             response = connection.send_command(command)
#     627             self._give_back_connection(connection)
#     628         except Py4JNetworkError:
#
# /opt/apache/spark-1.6.0-bin-hadoop2.6/python/lib/py4j-0.9-src.zip/py4j/java_gateway.py in send_command(self, command)
#     738         try:
#     739             self.socket.sendall(command.encode("utf-8"))
# --> 740             answer = smart_decode(self.stream.readline()[:-1])
#     741             logger.debug("Answer received: {0}".format(answer))
#     742             # Happens when a the other end is dead. There might be an empty
#
# /opt/anaconda/lib/python2.7/socket.pyc in readline(self, size)
#     432                     try:
#     433                         while data != "\n":
# --> 434                             data = recv(1)
#     435                             if not data:
#     436                                 break
#
# KeyboardInterrupt:

# %%
#Save results
l=0
Yf = open('data/collab_filter_SGD_Y_matr.csv','w')
for e in Y:
    Yf.write('{},{}\n'.format(l,','.join(str(z) for z in Y[l])))
    l+=1
l=0            
bf = open('data/collab_filter_SGD_b_vec.csv','w')
for e in b:
    bf.write('{},{}\n'.format(l,b[l]))
    l+=1

f.write('mu is {}'.format(mu))

#print('Finish. Work time {}.'.format(datetime.datetime.now() - start_time))

# %%
#[float(e) for e in x.strip().split(',')[1:]]
af = open('data/collab_filter_SGD_a_vec.csv','r')
Xf = open('data/collab_filter_SGD_X_matr.csv','r')
XTdotX = np.zeros([K+2,K+2])

cnt=0
while True:
    x = Xf.readline()
    a = af.readline()
    if not x:
        break
    if cnt % 10000 == 0: print(cnt,x.split(',')[0])
    cnt += 1
    row = [float(a.strip().split(',')[1])+mu[0],1] + [float(e) for e in x.strip().split(',')[1:]]
    for i,j in itertools.product(range(K+2),range(K+2)):
        XTdotX[i,j] += row[i]*row[j]
# Out:
# (0, '12320000')
# (10000, '12330000')
# (20000, '12340000')
# (30000, '12350000')
# (40000, '12360000')
# (50000, '12370000')
# (60000, '12380000')
# (70000, '12390000')
# (80000, '12400000')
# (90000, '12410000')
# (100000, '12420000')
# (110000, '12430000')
# (120000, '12440000')
# (130000, '12450000')
# (140000, '12460000')
# (150000, '12470000')
# (160000, '12480000')
# (170000, '12490000')
# (180000, '12500000')
# (190000, '12510000')
# (200000, '12520000')
# (210000, '12530000')
# (220000, '12540000')
# (230000, '12550000')
# (240000, '12560000')
# (250000, '12570000')
# (260000, '12580000')
# (270000, '12590000')
# (280000, '12600000')
# (290000, '12610000')
# (300000, '12620000')
# (310000, '12630000')
# (320000, '12640000')
# (330000, '12650000')
# (340000, '12660000')
# (350000, '12670000')
# (360000, '12680000')
# (370000, '12690000')
# (380000, '12700000')
# (390000, '12710000')
# (400000, '12720000')
# (410000, '12730000')
# (420000, '12740000')
# (430000, '12750000')
# (440000, '12760000')
# (450000, '12770000')
# (460000, '12780000')
# (470000, '12790000')
# (480000, '12800000')
# (490000, '12810000')
# (500000, '12820000')
# (510000, '12830000')
# (520000, '12840000')
# (530000, '12850000')
# (540000, '12860000')
# (550000, '12870000')
# (560000, '12880000')
# (570000, '12890000')
# (580000, '12900000')
# (590000, '12910000')
# (600000, '12920000')
# (610000, '12930000')
# (620000, '12940000')
# (630000, '12950000')
# (640000, '12960000')
# (650000, '12970000')
# (660000, '12980000')
# (670000, '12990000')
# (680000, '13000000')
# (690000, '13010000')
# (700000, '13020000')
# (710000, '13030000')
# (720000, '13040000')
# (730000, '13050000')
# (740000, '13060000')
# (750000, '13070000')
# (760000, '13080000')
# (770000, '13090000')
# (780000, '13100000')
# (790000, '13110000')
# (800000, '13120000')
# (810000, '13130000')
# (820000, '13140000')
# (830000, '13150000')
# (840000, '13160000')
# (850000, '13170000')
# (860000, '13180000')
# (870000, '13190000')
# (880000, '13200000')
# (890000, '13210000')
# (900000, '13220000')
# (910000, '13230000')
# (920000, '13240000')
# (930000, '13250000')
# (940000, '13260000')
# (950000, '13270000')
# (960000, '13280000')
# (970000, '13290000')
# (980000, '13300000')
# (990000, '13310000')
# (1000000, '13320000')
# (1010000, '13330000')
# (1020000, '13340000')
# (1030000, '13350000')
# (1040000, '13360000')
# (1050000, '13370000')
# (1060000, '13380000')
# (1070000, '13390000')
# (1080000, '13400000')
# (1090000, '13410000')
# (1100000, '13420000')
# (1110000, '13430000')
# (1120000, '13440000')
# (1130000, '13450000')
# (1140000, '13460000')
# (1150000, '13470000')
# (1160000, '13480000')
# (1170000, '13490000')
# (1180000, '13500000')
# (1190000, '13510000')
# (1200000, '13520000')
# (1210000, '13530000')
# (1220000, '13540000')
# (1230000, '13550000')
# (1240000, '13560000')
# (1250000, '13570000')
# (1260000, '13580000')
# (1270000, '13590000')
# (1280000, '13600000')
# (1290000, '13610000')
# (1300000, '13620000')
# (1310000, '13630000')
# (1320000, '13640000')
# (1330000, '13650000')
# (1340000, '13660000')
# (1350000, '13670000')
# (1360000, '13680000')
# (1370000, '13690000')
# (1380000, '13700000')
# (1390000, '13710000')
# (1400000, '13720000')
# (1410000, '13730000')
# (1420000, '13740000')
# (1430000, '13750000')
# (1440000, '13760000')
# (1450000, '13770000')
# (1460000, '13780000')
# (1470000, '13790000')
# (1480000, '13800000')
# (1490000, '13810000')
# (1500000, '13820000')
# (1510000, '13830000')
# (1520000, '13840000')
# (1530000, '13850000')
# (1540000, '13860000')
# (1550000, '13870000')
# (1560000, '13880000')
# (1570000, '13890000')
# (1580000, '13900000')
# (1590000, '13910000')
# (1600000, '13920000')
# (1610000, '13930000')
# (1620000, '13940000')
# (1630000, '13950000')
# (1640000, '13960000')
# (1650000, '13970000')
# (1660000, '13980000')
# (1670000, '13990000')
# (1680000, '14000000')
# (1690000, '14010000')
# (1700000, '14020000')
# (1710000, '14030000')
# (1720000, '14040000')
# (1730000, '14050000')
# (1740000, '14060000')
# (1750000, '14070000')
# (1760000, '14080000')
# (1770000, '14090000')
# (1780000, '14100000')
# (1790000, '14110000')
# (1800000, '14120000')
# (1810000, '14130000')
# (1820000, '14140000')
# (1830000, '14150000')
# (1840000, '14160000')
# (1850000, '14170000')
# (1860000, '14180000')
# (1870000, '14190000')
# (1880000, '14200000')
# (1890000, '14210000')
# (1900000, '14220000')
# (1910000, '14230000')
# (1920000, '14240000')
# (1930000, '14250000')
# (1940000, '14260000')
# (1950000, '14270000')
# (1960000, '14280000')
# (1970000, '14290000')
# (1980000, '14300000')
# (1990000, '14310000')
# (2000000, '14320000')
# (2010000, '14330000')
# (2020000, '14340000')
# (2030000, '14350000')
# (2040000, '14360000')
# (2050000, '14370000')
# (2060000, '14380000')
# (2070000, '14390000')
# (2080000, '14400000')
# (2090000, '14410000')
# (2100000, '14420000')
# (2110000, '14430000')
# (2120000, '14440000')
# (2130000, '14450000')
# (2140000, '14460000')
# (2150000, '14470000')
# (2160000, '14480000')
# (2170000, '14490000')
# (2180000, '14500000')
# (2190000, '14510000')
# (2200000, '14520000')
# (2210000, '14530000')
# (2220000, '14540000')
# (2230000, '14550000')
# (2240000, '14560000')
# (2250000, '14570000')
# (2260000, '14580000')
# (2270000, '14590000')
# (2280000, '14600000')
# (2290000, '14610000')
# (2300000, '14620000')
# (2310000, '14630000')
# (2320000, '14640000')
# (2330000, '14650000')
# (2340000, '14660000')
# (2350000, '14670000')
# (2360000, '14680000')
# (2370000, '14690000')
# (2380000, '14700000')
# (2390000, '14710000')
# (2400000, '14720000')
# (2410000, '14730000')
# (2420000, '14740000')
# (2430000, '14750000')
# (2440000, '14760000')
# (2450000, '14770000')
# (2460000, '14780000')
# (2470000, '14790000')
# (2480000, '14800000')
# (2490000, '14810000')
# (2500000, '14820000')
# (2510000, '14830000')
# (2520000, '14840000')
# (2530000, '14850000')
# (2540000, '14860000')
# (2550000, '14870000')
# (2560000, '14880000')
# (2570000, '14890000')
# (2580000, '14900000')
# (2590000, '14910000')
# (2600000, '14920000')
# (2610000, '14930000')
# (2620000, '14940000')
# (2630000, '14950000')
# (2640000, '14960000')
# (2650000, '14970000')
# (2660000, '14980000')
# (2670000, '14990000')
# (2680000, '15000000')
# (2690000, '15010000')
# (2700000, '15020000')
# (2710000, '15030000')
# (2720000, '15040000')
# (2730000, '15050000')
# (2740000, '15060000')
# (2750000, '15070000')
# (2760000, '15080000')
# (2770000, '15090000')
# (2780000, '15100000')
# (2790000, '15110000')
# (2800000, '15120000')
# (2810000, '15130000')
# (2820000, '15140000')
# (2830000, '15150000')
# (2840000, '15160000')
# (2850000, '15170000')
# (2860000, '15180000')
# (2870000, '15190000')
# (2880000, '15200000')
# (2890000, '15210000')
# (2900000, '15220000')
# (2910000, '15230000')
# (2920000, '15240000')
# (2930000, '15250000')
# (2940000, '15260000')
# (2950000, '15270000')
# (2960000, '15280000')
# (2970000, '15290000')
# (2980000, '15300000')
# (2990000, '15310000')
# (3000000, '15320000')
# (3010000, '15330000')
# (3020000, '15340000')
# (3030000, '15350000')
# (3040000, '15360000')
# (3050000, '15370000')
# (3060000, '15380000')
# (3070000, '15390000')
# (3080000, '15400000')
# (3090000, '15410000')
# (3100000, '15420000')
# (3110000, '15430000')
# (3120000, '15440000')
# (3130000, '15450000')
# (3140000, '15460000')
# (3150000, '15470000')
# (3160000, '15480000')
# (3170000, '15490000')
# (3180000, '15500000')
# (3190000, '15510000')
# (3200000, '15520000')
# (3210000, '15530000')
# (3220000, '15540000')
# (3230000, '15550000')
# (3240000, '15560000')
# (3250000, '15570000')
# (3260000, '15580000')
# (3270000, '15590000')
# (3280000, '15600000')
# (3290000, '15610000')
# (3300000, '15620000')
# (3310000, '15630000')
# (3320000, '15640000')
# (3330000, '15650000')
# (3340000, '15660000')
# (3350000, '15670000')
# (3360000, '15680000')
# (3370000, '15690000')
# (3380000, '15700000')
# (3390000, '15710000')
# (3400000, '15720000')
# (3410000, '15730000')
# (3420000, '15740000')
# (3430000, '15750000')
# (3440000, '15760000')
# (3450000, '15770000')
# (3460000, '15780000')
# (3470000, '15790000')
# (3480000, '15800000')
# (3490000, '15810000')
# (3500000, '15820000')
# (3510000, '15830000')
# (3520000, '15840000')
# (3530000, '15850000')
# (3540000, '15860000')
# (3550000, '15870000')
# (3560000, '15880000')
# (3570000, '15890000')
# (3580000, '15900000')
# (3590000, '15910000')
# (3600000, '15920000')
# (3610000, '15930000')
# (3620000, '15940000')
# (3630000, '15950000')
# (3640000, '15960000')
# (3650000, '15970000')
# (3660000, '15980000')
# (3670000, '15990000')
# (3680000, '16000000')
# (3690000, '16010000')
# (3700000, '16020000')
# (3710000, '16030000')
# (3720000, '16040000')
# (3730000, '16050000')
# (3740000, '16060000')
# (3750000, '16070000')
# (3760000, '16080000')
# (3770000, '16090000')
# (3780000, '16100000')
# (3790000, '16110000')
# (3800000, '16120000')
# (3810000, '16130000')
# (3820000, '16140000')
# (3830000, '16150000')
# (3840000, '16160000')
# (3850000, '16170000')
# (3860000, '16180000')
# (3870000, '16190000')
# (3880000, '16200000')
# (3890000, '16210000')
# (3900000, '16220000')
# (3910000, '16230000')
# (3920000, '16240000')
# (3930000, '16250000')
# (3940000, '16260000')
# (3950000, '16270000')
# (3960000, '16280000')
# (3970000, '16290000')
# (3980000, '16300000')
# (3990000, '16310000')
# (4000000, '16320000')
# (4010000, '16330000')
# (4020000, '16340000')
# (4030000, '16350000')
# (4040000, '16360000')
# (4050000, '16370000')
# (4060000, '16380000')
# (4070000, '16390000')
# (4080000, '16400000')
# (4090000, '16410000')
# (4100000, '16420000')
# (4110000, '16430000')
# (4120000, '16440000')
# (4130000, '16450000')
# (4140000, '16460000')
# (4150000, '16470000')
# (4160000, '16480000')
# (4170000, '16490000')
# (4180000, '16500000')
# (4190000, '16510000')
# (4200000, '16520000')
# (4210000, '16530000')
# (4220000, '16540000')
# (4230000, '16550000')
# (4240000, '16560000')
# (4250000, '16570000')
# (4260000, '16580000')
# (4270000, '16590000')
# (4280000, '16600000')
# (4290000, '16610000')
# (4300000, '16620000')
# (4310000, '16630000')
# (4320000, '16640000')
# (4330000, '16650000')
# (4340000, '16660000')
# (4350000, '16670000')
# (4360000, '16680000')
# (4370000, '16690000')
# (4380000, '16700000')
# (4390000, '16710000')
# (4400000, '16720000')
# (4410000, '16730000')
# (4420000, '16740000')
# (4430000, '16750000')
# (4440000, '16760000')
# (4450000, '16770000')
# (4460000, '16780000')
# (4470000, '16790000')
# (4480000, '16800000')
# (4490000, '16810000')
# (4500000, '16820000')
# (4510000, '16830000')
# (4520000, '16840000')
# (4530000, '16850000')
# (4540000, '16860000')
# (4550000, '16870000')
# (4560000, '16880000')
# (4570000, '16890000')
# (4580000, '16900000')
# (4590000, '16910000')
# (4600000, '16920000')
# (4610000, '16930000')
# (4620000, '16940000')
# (4630000, '16950000')
# (4640000, '16960000')
# (4650000, '16970000')
# (4660000, '16980000')
# (4670000, '16990000')
# (4680000, '17000000')
# (4690000, '17010000')
# (4700000, '17020000')
# (4710000, '17030000')
# (4720000, '17040000')
# (4730000, '17050000')
# (4740000, '17060000')
# (4750000, '17070000')
# (4760000, '17080000')
# (4770000, '17090000')
# (4780000, '17100000')
# (4790000, '17110000')
# (4800000, '17120000')
# (4810000, '17130000')
# (4820000, '17140000')
# (4830000, '17150000')
# (4840000, '17160000')
# (4850000, '17170000')
# (4860000, '17180000')
# (4870000, '17190000')
# (4880000, '17200000')
# (4890000, '17210000')
# (4900000, '17220000')
# (4910000, '17230000')
# (4920000, '17240000')
# (4930000, '17250000')
# (4940000, '17260000')
# (4950000, '17270000')
# (4960000, '17280000')
# (4970000, '17290000')
# (4980000, '17300000')
# (4990000, '17310000')
# (5000000, '17320000')
# (5010000, '17330000')
# (5020000, '17340000')
# (5030000, '17350000')
# (5040000, '17360000')
# (5050000, '17370000')
# (5060000, '17380000')
# (5070000, '17390000')
# (5080000, '17400000')
# (5090000, '17410000')
# (5100000, '17420000')
# (5110000, '17430000')
# (5120000, '17440000')
# (5130000, '17450000')
# (5140000, '17460000')
# (5150000, '17470000')
# (5160000, '17480000')
# (5170000, '17490000')
# (5180000, '17500000')
# (5190000, '17510000')
# (5200000, '17520000')
# (5210000, '17530000')
# (5220000, '17540000')
# (5230000, '17550000')
# (5240000, '17560000')
# (5250000, '17570000')
# (5260000, '17580000')
# (5270000, '17590000')
# (5280000, '17600000')
# (5290000, '17610000')
# (5300000, '17620000')
# (5310000, '17630000')
# (5320000, '17640000')
# (5330000, '17650000')
# (5340000, '17660000')
# (5350000, '17670000')
# (5360000, '17680000')
# (5370000, '17690000')
# (5380000, '17700000')
# (5390000, '17710000')
# (5400000, '17720000')
# (5410000, '17730000')
# (5420000, '17740000')
# (5430000, '17750000')
# (5440000, '17760000')
# (5450000, '17770000')
# (5460000, '17780000')
# (5470000, '17790000')
# (5480000, '17800000')
# (5490000, '17810000')
# (5500000, '17820000')
# (5510000, '17830000')
# (5520000, '17840000')
# (5530000, '17850000')
# (5540000, '17860000')
# (5550000, '17870000')
# (5560000, '17880000')
# (5570000, '17890000')
# (5580000, '17900000')
# (5590000, '17910000')
# (5600000, '17920000')
# (5610000, '17930000')
# (5620000, '17940000')
# (5630000, '17950000')
# (5640000, '17960000')
# (5650000, '17970000')
# (5660000, '17980000')
# (5670000, '17990000')
# (5680000, '18000000')
# (5690000, '18010000')
# (5700000, '18020000')
# (5710000, '18030000')
# (5720000, '18040000')
# (5730000, '18050000')
# (5740000, '18060000')
# (5750000, '18070000')
# (5760000, '18080000')
# (5770000, '18090000')
# (5780000, '18100000')
# (5790000, '18110000')
# (5800000, '18120000')
# (5810000, '18130000')
# (5820000, '18140000')
# (5830000, '18150000')
# (5840000, '18160000')
# (5850000, '18170000')
# (5860000, '18180000')
# (5870000, '18190000')
# (5880000, '18200000')
# (5890000, '18210000')
# (5900000, '18220000')
# (5910000, '18230000')
# (5920000, '18240000')
# (5930000, '18250000')
# (5940000, '18260000')
# (5950000, '18270000')
# (5960000, '18280000')
# (5970000, '18290000')
# (5980000, '18300000')
# (5990000, '18310000')
# (6000000, '18320000')
# (6010000, '18330000')
# (6020000, '18340000')
# (6030000, '18350000')
# (6040000, '18360000')
# (6050000, '18370000')
# (6060000, '18380000')
# (6070000, '18390000')
# (6080000, '18400000')
# (6090000, '18410000')
# (6100000, '18420000')
# (6110000, '18430000')
# (6120000, '18440000')
# (6130000, '18450000')
# (6140000, '18460000')
# (6150000, '18470000')
# (6160000, '18480000')
# (6170000, '18490000')
# (6180000, '18500000')
# (6190000, '18510000')
# (6200000, '18520000')
# (6210000, '18530000')
# (6220000, '18540000')
# (6230000, '18550000')
# (6240000, '18560000')
# (6250000, '18570000')
# (6260000, '18580000')
# (6270000, '18590000')
# (6280000, '18600000')
# (6290000, '18610000')
# (6300000, '18620000')
# (6310000, '18630000')
# (6320000, '18640000')
# (6330000, '18650000')
# (6340000, '18660000')
# (6350000, '18670000')
# (6360000, '18680000')
# (6370000, '18690000')
# (6380000, '18700000')
# (6390000, '18710000')
# (6400000, '18720000')
# (6410000, '18730000')
# (6420000, '18740000')
# (6430000, '18750000')
# (6440000, '18760000')
# (6450000, '18770000')
# (6460000, '18780000')
# (6470000, '18790000')
# (6480000, '18800000')
# (6490000, '18810000')
# (6500000, '18820000')
# (6510000, '18830000')
# (6520000, '18840000')
# (6530000, '18850000')
# (6540000, '18860000')
# (6550000, '18870000')
# (6560000, '18880000')
# (6570000, '18890000')
# (6580000, '18900000')
# (6590000, '18910000')
# (6600000, '18920000')
# (6610000, '18930000')
# (6620000, '18940000')
# (6630000, '18950000')
# (6640000, '18960000')
# (6650000, '18970000')
# (6660000, '18980000')
# (6670000, '18990000')
# (6680000, '19000000')
# (6690000, '19010000')
# (6700000, '19020000')
# (6710000, '19030000')
# (6720000, '19040000')
# (6730000, '19050000')
# (6740000, '19060000')
# (6750000, '19070000')
# (6760000, '19080000')
# (6770000, '19090000')
# (6780000, '19100000')
# (6790000, '19110000')
# (6800000, '19120000')
# (6810000, '19130000')
# (6820000, '19140000')
# (6830000, '19150000')
# (6840000, '19160000')
# (6850000, '19170000')
# (6860000, '19180000')
# (6870000, '19190000')
# (6880000, '19200000')
# (6890000, '19210000')
# (6900000, '19220000')
# (6910000, '19230000')
# (6920000, '19240000')
# (6930000, '19250000')
# (6940000, '19260000')
# (6950000, '19270000')
# (6960000, '19280000')
# (6970000, '19290000')
# (6980000, '19300000')
# (6990000, '19310000')
# (7000000, '19320000')
# (7010000, '19330000')
# (7020000, '19340000')
# (7030000, '19350000')
# (7040000, '19360000')
# (7050000, '19370000')
# (7060000, '19380000')
# (7070000, '19390000')
# (7080000, '19400000')
# (7090000, '19410000')
# (7100000, '19420000')
# (7110000, '19430000')
# (7120000, '19440000')
# (7130000, '19450000')
# (7140000, '19460000')
# (7150000, '19470000')
# (7160000, '19480000')
# (7170000, '19490000')
# (7180000, '19500000')
# (7190000, '19510000')
# (7200000, '19520000')
# (7210000, '19530000')
# (7220000, '19540000')
# (7230000, '19550000')
# (7240000, '19560000')
# (7250000, '19570000')
# (7260000, '19580000')
# (7270000, '19590000')
# (7280000, '19600000')
# (7290000, '19610000')
# (7300000, '19620000')
# (7310000, '19630000')
# (7320000, '19640000')
# (7330000, '19650000')
# (7340000, '19660000')
# (7350000, '19670000')
# (7360000, '19680000')
# (7370000, '19690000')
# (7380000, '19700000')
# (7390000, '19710000')
# (7400000, '19720000')
# (7410000, '19730000')
# (7420000, '19740000')
# (7430000, '19750000')
# (7440000, '19760000')
# (7450000, '19770000')
# (7460000, '19780000')
# (7470000, '19790000')
# (7480000, '19800000')
# (7490000, '19810000')
# (7500000, '19820000')
# (7510000, '19830000')
# (7520000, '19840000')
# (7530000, '19850000')
# (7540000, '19860000')
# (7550000, '19870000')
# (7560000, '19880000')
# (7570000, '19890000')
# (7580000, '19900000')
# (7590000, '19910000')
# (7600000, '19920000')
# (7610000, '19930000')
# (7620000, '19940000')
# (7630000, '19950000')
# (7640000, '19960000')
# (7650000, '19970000')
# (7660000, '19980000')
# (7670000, '19990000')
# (7680000, '20000000')
# (7690000, '20010000')
# (7700000, '20020000')
# (7710000, '20030000')
# (7720000, '20040000')
# (7730000, '20050000')
# (7740000, '20060000')
# (7750000, '20070000')
# (7760000, '20080000')
# (7770000, '20090000')
# (7780000, '20100000')
# (7790000, '20110000')
# (7800000, '20120000')
# (7810000, '20130000')
# (7820000, '20140000')
# (7830000, '20150000')
# (7840000, '20160000')
# (7850000, '20170000')
# (7860000, '20180000')
# (7870000, '20190000')
# (7880000, '20200000')
# (7890000, '20210000')
# (7900000, '20220000')
# (7910000, '20230000')
# (7920000, '20240000')
# (7930000, '20250000')
# (7940000, '20260000')
# (7950000, '20270000')
# (7960000, '20280000')
# (7970000, '20290000')
# (7980000, '20300000')
# (7990000, '20310000')
# (8000000, '20320000')
# (8010000, '20330000')
# (8020000, '20340000')
# (8030000, '20350000')
# (8040000, '20360000')
# (8050000, '20370000')
# (8060000, '20380000')
# (8070000, '20390000')
# (8080000, '20400000')
# (8090000, '20410000')
# (8100000, '20420000')
# (8110000, '20430000')
# (8120000, '20440000')
# (8130000, '20450000')
# (8140000, '20460000')
# (8150000, '20470000')
# (8160000, '20480000')
# (8170000, '20490000')
# (8180000, '20500000')
# (8190000, '20510000')
# (8200000, '20520000')
# (8210000, '20530000')
# (8220000, '20540000')
# (8230000, '20550000')
# (8240000, '20560000')
# (8250000, '20570000')
# (8260000, '20580000')
# (8270000, '20590000')
# (8280000, '20600000')
# (8290000, '20610000')
# (8300000, '20620000')
# (8310000, '20630000')
# (8320000, '20640000')
# (8330000, '20650000')
# (8340000, '20660000')
# (8350000, '20670000')
# (8360000, '20680000')
# (8370000, '20690000')
# (8380000, '20700000')
# (8390000, '20710000')
# (8400000, '20720000')
# (8410000, '20730000')
# (8420000, '20740000')
# (8430000, '20750000')
# (8440000, '20760000')
# (8450000, '20770000')
# (8460000, '20780000')
# (8470000, '20790000')
# (8480000, '20800000')
# (8490000, '20810000')
# (8500000, '20820000')
# (8510000, '20830000')
# (8520000, '20840000')
# (8530000, '20850000')
# (8540000, '20860000')
# (8550000, '20870000')
# (8560000, '20880000')
# (8570000, '20890000')
# (8580000, '20900000')
# (8590000, '20910000')
# (8600000, '20920000')
# (8610000, '20930000')
# (8620000, '20940000')
# (8630000, '20950000')
# (8640000, '20960000')
# (8650000, '20970000')
# (8660000, '20980000')
# (8670000, '20990000')
# (8680000, '21000000')
# (8690000, '21010000')
# (8700000, '21020000')
# (8710000, '21030000')
# (8720000, '21040000')
# (8730000, '21050000')
# (8740000, '21060000')
# (8750000, '21070000')
# (8760000, '21080000')
# (8770000, '21090000')
# (8780000, '21100000')
# (8790000, '21110000')
# (8800000, '21120000')
# (8810000, '21130000')
# (8820000, '21140000')
# (8830000, '21150000')
# (8840000, '21160000')
# (8850000, '21170000')
# (8860000, '21180000')
# (8870000, '21190000')
# (8880000, '21200000')
# (8890000, '21210000')
# (8900000, '21220000')
# (8910000, '21230000')
# (8920000, '21240000')
# (8930000, '21250000')
# (8940000, '21260000')
# (8950000, '21270000')
# (8960000, '21280000')
# (8970000, '21290000')
# (8980000, '21300000')
# (8990000, '21310000')
# (9000000, '21320000')
# (9010000, '21330000')
# (9020000, '21340000')
# (9030000, '21350000')
# (9040000, '21360000')
# (9050000, '21370000')
# (9060000, '21380000')
# (9070000, '21390000')
# (9080000, '21400000')
# (9090000, '21410000')
# (9100000, '21420000')
# (9110000, '21430000')
# (9120000, '21440000')
# (9130000, '21450000')
# (9140000, '21460000')
# (9150000, '21470000')
# (9160000, '21480000')
# (9170000, '21490000')
# (9180000, '21500000')
# (9190000, '21510000')
# (9200000, '21520000')
# (9210000, '21530000')
# (9220000, '21540000')
# (9230000, '21550000')
# (9240000, '21560000')
# (9250000, '21570000')
# (9260000, '21580000')
# (9270000, '21590000')
# (9280000, '21600000')
# (9290000, '21610000')
# (9300000, '21620000')
# (9310000, '21630000')
# (9320000, '21640000')
# (9330000, '21650000')
# (9340000, '21660000')
# (9350000, '21670000')
# (9360000, '21680000')
# (9370000, '21690000')
# (9380000, '21700000')
# (9390000, '21710000')
# (9400000, '21720000')
# (9410000, '21730000')
# (9420000, '21740000')
# (9430000, '21750000')
# (9440000, '21760000')
# (9450000, '21770000')
# (9460000, '21780000')
# (9470000, '21790000')
# (9480000, '21800000')
# (9490000, '21810000')
# (9500000, '21820000')
# (9510000, '21830000')
# (9520000, '21840000')
# (9530000, '21850000')
# (9540000, '21860000')
# (9550000, '21870000')
# (9560000, '21880000')
# (9570000, '21890000')
# (9580000, '21900000')
# (9590000, '21910000')
# (9600000, '21920000')
# (9610000, '21930000')
# (9620000, '21940000')
# (9630000, '21950000')
# (9640000, '21960000')
# (9650000, '21970000')
# (9660000, '21980000')
# (9670000, '21990000')
# (9680000, '22000000')
# (9690000, '22010000')
# (9700000, '22020000')
# (9710000, '22030000')
# (9720000, '22040000')
# (9730000, '22050000')
# (9740000, '22060000')
# (9750000, '22070000')
# (9760000, '22080000')
# (9770000, '22090000')
# (9780000, '22100000')
# (9790000, '22110000')
# (9800000, '22120000')
# (9810000, '22130000')
# (9820000, '22140000')
# (9830000, '22150000')
# (9840000, '22160000')
# (9850000, '22170000')
# (9860000, '22180000')
# (9870000, '22190000')
# (9880000, '22200000')
# (9890000, '22210000')
# (9900000, '22220000')
# (9910000, '22230000')
# (9920000, '22240000')
# (9930000, '22250000')
# (9940000, '22260000')
# (9950000, '22270000')
# (9960000, '22280000')
# (9970000, '22290000')
# (9980000, '22300000')
# (9990000, '22310000')
# (10000000, '22320000')
# (10010000, '22330000')
# (10020000, '22340000')
# (10030000, '22350000')
# (10040000, '22360000')
# (10050000, '22370000')
# (10060000, '22380000')
# (10070000, '22390000')
# (10080000, '22400000')
# (10090000, '22410000')
# (10100000, '22420000')
# (10110000, '22430000')
# (10120000, '22440000')
# (10130000, '22450000')
# (10140000, '22460000')
# (10150000, '22470000')
# (10160000, '22480000')
# (10170000, '22490000')
# (10180000, '22500000')
# (10190000, '22510000')
# (10200000, '22520000')
# (10210000, '22530000')
# (10220000, '22540000')
# (10230000, '22550000')
# (10240000, '22560000')
# (10250000, '22570000')
# (10260000, '22580000')
# (10270000, '22590000')
# (10280000, '22600000')
# (10290000, '22610000')
# (10300000, '22620000')
# (10310000, '22630000')
# (10320000, '22640000')
# (10330000, '22650000')
# (10340000, '22660000')
# (10350000, '22670000')
# (10360000, '22680000')
# (10370000, '22690000')
# (10380000, '22700000')
# (10390000, '22710000')
# (10400000, '22720000')
# (10410000, '22730000')
# (10420000, '22740000')
# (10430000, '22750000')
# (10440000, '22760000')
# (10450000, '22770000')
# (10460000, '22780000')
# (10470000, '22790000')
# (10480000, '22800000')
# (10490000, '22810000')
# (10500000, '22820000')
# (10510000, '22830000')
# (10520000, '22840000')
# (10530000, '22850000')
# (10540000, '22860000')
# (10550000, '22870000')
# (10560000, '22880000')
# (10570000, '22890000')
# (10580000, '22900000')
# (10590000, '22910000')
# (10600000, '22920000')
# (10610000, '22930000')
# (10620000, '22940000')
# (10630000, '22950000')
# (10640000, '22960000')
# (10650000, '22970000')
# (10660000, '22980000')
# (10670000, '22990000')
# (10680000, '23000000')
# (10690000, '23010000')
# (10700000, '23020000')
# (10710000, '23030000')
# (10720000, '23040000')
# (10730000, '23050000')
# (10740000, '23060000')
# (10750000, '23070000')
# (10760000, '23080000')
# (10770000, '23090000')
# (10780000, '23100000')
# (10790000, '23110000')
# (10800000, '23120000')
# (10810000, '23130000')
# (10820000, '23140000')
# (10830000, '23150000')
# (10840000, '23160000')
# (10850000, '23170000')
# (10860000, '23180000')
# (10870000, '23190000')
# (10880000, '23200000')
# (10890000, '23210000')
# (10900000, '23220000')
# (10910000, '23230000')
# (10920000, '23240000')
# (10930000, '23250000')
# (10940000, '23260000')
# (10950000, '23270000')
# (10960000, '23280000')
# (10970000, '23290000')
# (10980000, '23300000')
# (10990000, '23310000')
# (11000000, '23320000')
# (11010000, '23330000')
# (11020000, '23340000')
# (11030000, '23350000')
# (11040000, '23360000')
# (11050000, '23370000')
# (11060000, '23380000')
# (11070000, '23390000')
# (11080000, '23400000')
# (11090000, '23410000')
# (11100000, '23420000')
# (11110000, '23430000')
# (11120000, '23440000')
# (11130000, '23450000')
# (11140000, '23460000')
# (11150000, '23470000')
# (11160000, '23480000')
# (11170000, '23490000')
# (11180000, '23500000')
# (11190000, '23510000')
# (11200000, '23520000')
# (11210000, '23530000')
# (11220000, '23540000')
# (11230000, '23550000')
# (11240000, '23560000')
# (11250000, '23570000')
# (11260000, '23580000')
# (11270000, '23590000')
# (11280000, '23600000')
# (11290000, '23610000')
# (11300000, '23620000')
# (11310000, '23630000')
# (11320000, '23640000')
# (11330000, '23650000')
# (11340000, '23660000')
# (11350000, '23670000')
# (11360000, '23680000')
# (11370000, '23690000')
# (11380000, '23700000')
# (11390000, '23710000')
# (11400000, '23720000')
# (11410000, '23730000')
# (11420000, '23740000')
# (11430000, '23750000')
# (11440000, '23760000')
# (11450000, '23770000')
# (11460000, '23780000')
# (11470000, '23790000')
# (11480000, '23800000')
# (11490000, '23810000')
# (11500000, '23820000')
# (11510000, '23830000')
# (11520000, '23840000')
# (11530000, '23850000')
# (11540000, '23860000')
# (11550000, '23870000')
# (11560000, '23880000')
# (11570000, '23890000')
# (11580000, '23900000')
# (11590000, '23910000')
# (11600000, '23920000')
# (11610000, '23930000')
# (11620000, '23940000')
# (11630000, '23950000')
# (11640000, '23960000')
# (11650000, '23970000')
# (11660000, '23980000')
# (11670000, '23990000')
# (11680000, '24000000')
# (11690000, '24010000')
# (11700000, '24020000')
# (11710000, '24030000')
# (11720000, '24040000')
# (11730000, '24050000')
# (11740000, '24060000')
# (11750000, '24070000')
# (11760000, '24080000')
# (11770000, '24090000')
# (11780000, '24100000')
# (11790000, '24110000')
# (11800000, '24120000')
# (11810000, '24130000')
# (11820000, '24140000')
# (11830000, '24150000')
# (11840000, '24160000')
# (11850000, '24170000')
# (11860000, '24180000')
# (11870000, '24190000')
# (11880000, '24200000')
# (11890000, '24210000')
# (11900000, '24220000')
# (11910000, '24230000')
# (11920000, '24240000')
# (11930000, '24250000')
# (11940000, '24260000')
# (11950000, '24270000')
# (11960000, '24280000')
# (11970000, '24290000')
# (11980000, '24300000')
# (11990000, '24310000')
# (12000000, '24320000')
# (12010000, '24330000')
# (12020000, '24340000')
# (12030000, '24350000')
# (12040000, '24360000')
# (12050000, '24370000')
# (12060000, '24380000')
# (12070000, '24390000')
# (12080000, '24400000')
# (12090000, '24410000')
# (12100000, '24420000')
# (12110000, '24430000')
# (12120000, '24440000')
# (12130000, '24450000')
# (12140000, '24460000')
# (12150000, '24470000')
# (12160000, '24480000')
# (12170000, '24490000')
# (12180000, '24500000')
# (12190000, '24510000')
# (12200000, '24520000')
# (12210000, '24530000')
# (12220000, '24540000')
# (12230000, '24550000')
# (12240000, '24560000')
# (12250000, '24570000')
# (12260000, '24580000')
# (12270000, '24590000')
# (12280000, '24600000')
# (12290000, '24610000')
# (12300000, '24620000')
# (12310000, '24630000')
# (12320000, '24640000')
# (12330000, '24650000')
# (12340000, '24660000')
# (12350000, '24670000')
# (12360000, '24680000')
# (12370000, '24690000')
# (12380000, '24700000')
# (12390000, '24710000')
# (12400000, '24720000')
# (12410000, '24730000')
# (12420000, '24740000')
# (12430000, '24750000')
# (12440000, '24760000')
# (12450000, '24770000')
# (12460000, '24780000')
# (12470000, '24790000')
# (12480000, '24800000')
# (12490000, '24810000')
# (12500000, '24820000')
# (12510000, '24830000')
# (12520000, '24840000')
# (12530000, '24850000')
# (12540000, '24860000')
# (12550000, '24870000')
# (12560000, '24880000')
# (12570000, '24890000')
# (12580000, '24900000')
# (12590000, '24910000')
# (12600000, '24920000')
# (12610000, '24930000')
# (12620000, '24940000')
# (12630000, '24950000')
# (12640000, '24960000')
# (12650000, '24970000')
# (12660000, '24980000')
# (12670000, '24990000')
# (12680000, '25000000')
# (12690000, '25010000')
# (12700000, '25020000')
# (12710000, '25030000')
# (12720000, '25040000')
# (12730000, '25050000')
# (12740000, '25060000')
# (12750000, '25070000')
# (12760000, '25080000')
# (12770000, '25090000')
# (12780000, '25100000')
# (12790000, '25110000')
# (12800000, '25120000')
# (12810000, '25130000')
# (12820000, '25140000')
# (12830000, '25150000')
# (12840000, '25160000')
# (12850000, '25170000')
# (12860000, '25180000')
# (12870000, '25190000')
# (12880000, '25200000')
# (12890000, '25210000')
# (12900000, '25220000')
# (12910000, '25230000')
# (12920000, '25240000')
# (12930000, '25250000')
# (12940000, '25260000')
# (12950000, '25270000')
# (12960000, '25280000')
# (12970000, '25290000')
# (12980000, '25300000')
# (12990000, '25310000')
# (13000000, '25320000')
# (13010000, '25330000')
# (13020000, '25340000')
# (13030000, '25350000')
# (13040000, '25360000')
# (13050000, '25370000')
# (13060000, '25380000')
# (13070000, '25390000')
# (13080000, '25400000')
# (13090000, '25410000')
# (13100000, '25420000')
# (13110000, '25430000')
# (13120000, '25440000')
# (13130000, '25450000')
# (13140000, '25460000')
# (13150000, '25470000')
# (13160000, '25480000')
# (13170000, '25490000')
# (13180000, '25500000')
# (13190000, '25510000')
# (13200000, '25520000')
# (13210000, '25530000')
# (13220000, '25540000')
# (13230000, '25550000')
# (13240000, '25560000')
# (13250000, '25570000')
# (13260000, '25580000')
# (13270000, '25590000')
# (13280000, '25600000')
# (13290000, '25610000')
# (13300000, '25620000')
# (13310000, '25630000')
# (13320000, '25640000')
# (13330000, '25650000')
# (13340000, '25660000')
# (13350000, '25670000')
# (13360000, '25680000')
# (13370000, '25690000')
# (13380000, '25700000')
# (13390000, '25710000')
# (13400000, '25720000')
# (13410000, '25730000')
# (13420000, '25740000')
# (13430000, '25750000')
# (13440000, '25760000')
# (13450000, '25770000')
# (13460000, '25780000')
# (13470000, '25790000')
# (13480000, '25800000')
# (13490000, '25810000')
# (13500000, '25820000')
# (13510000, '25830000')
# (13520000, '25840000')
# (13530000, '25850000')
# (13540000, '25860000')
# (13550000, '25870000')
# (13560000, '25880000')
# (13570000, '25890000')
# (13580000, '25900000')
# (13590000, '25910000')
# (13600000, '25920000')
# (13610000, '25930000')
# (13620000, '25940000')
# (13630000, '25950000')
# (13640000, '25960000')
# (13650000, '25970000')
# (13660000, '25980000')
# (13670000, '25990000')
# (13680000, '26000000')
# (13690000, '26010000')
# (13700000, '26020000')
# (13710000, '26030000')
# (13720000, '26040000')
# (13730000, '26050000')
# (13740000, '26060000')
# (13750000, '26070000')
# (13760000, '26080000')
# (13770000, '26090000')
# (13780000, '26100000')
# (13790000, '26110000')
# (13800000, '26120000')
# (13810000, '26130000')
# (13820000, '26140000')
# (13830000, '26150000')
# (13840000, '26160000')
# (13850000, '26170000')
# (13860000, '26180000')
# (13870000, '26190000')
# (13880000, '26200000')
# (13890000, '26210000')
# (13900000, '26220000')
# (13910000, '26230000')
# (13920000, '26240000')
# (13930000, '26250000')
# (13940000, '26260000')
# (13950000, '26270000')
# (13960000, '26280000')
# (13970000, '26290000')
# (13980000, '26300000')
# (13990000, '26310000')
# (14000000, '26320000')
# (14010000, '26330000')
# (14020000, '26340000')
# (14030000, '26350000')
# (14040000, '26360000')
# (14050000, '26370000')
# (14060000, '26380000')
# (14070000, '26390000')
# (14080000, '26400000')
# (14090000, '26410000')
# (14100000, '26420000')
# (14110000, '26430000')
# (14120000, '26440000')
# (14130000, '26450000')
# (14140000, '26460000')
# (14150000, '26470000')
# (14160000, '26480000')

# %%
with open('data/XTdotX.csv','w') as fXT:
    for r in XTdotX:        
        fXT.write(','.join([str(e) for e in r])+'\n')

# %%
print('mu is {}'.format(mu))
Y.shape
Yb = np.insert(Y, 0, b, axis=0)
Yb = np.insert(Yb, 0, 1, axis=0)

l=0            
Ybf = open('data/collab_filter_SGD_Y_matr_200.csv','w')
for e in Yb:
    Ybf.write('{},{}\n'.format(l,','.join(str(z) for z in Yb[l])))
    l+=1
# Out:
# mu is [-2.13571665]

# %%
def cos_dist(Y, i,j):
    return 1 - Y[:,i].dot(Y[:,j]) / (( Y[:,i].dot(Y[:,i]) * Y[:,j].dot(Y[:,j])) ** 0.5 )

# %%
uf_dict = hc.sql('select * from user_kposminin.urlfr_dict').toPandas().set_index('urlfr_num')

# %%
#uf_dict[uf_dict['urlfr'].map(lambda v: 'gdz' in v)].sort('cnt')
uf_dict[uf_dict['urlfr'] == 'filkos.com#'].cnt.iloc[0]
# Out:
# 7536

# %%
#uf_dict[uf_dict['urlfr'].map(lambda v: up in v)]
def neighbours(urlfr, Yb, uf_dict, n = 20):
    num = uf_dict[uf_dict['urlfr'] == up].index[0]
    dists1 = sorted([[cos_dist(Yb,num,i),i] for i in range(Yb.shape[1])])
    return [[e[0],uf_dict.loc[e[1],'urlfr']] for e in dists1[:n]]

# %%
n = 100
for up in ['raiffeisen.ru#consumerloans','filkos.com#','auto.exist.ru#','vedomosti.ru#business','gdz-putina.me#']:
    print('\n' + '-' * 100 + '\n\nNearest {} neighbours for {} ({} unique visitors per day):\n\n{:<10}\t{:<30}\n'.format(
            n, up, uf_dict[uf_dict['urlfr'] == up].cnt.iloc[0],'distance','urrlfr'))
    print('\n'.join(['{:<10.5f}\t{:<30}'.format(e[0],e[1].encode('utf-8')) for e in neighbours(up, Yb,uf_dict, n = n)]))
# Out:
# ----------------------------------------------------------------------------------------------------
#
# Nearest 100 neighbours for raiffeisen.ru#consumerloans (7536 unique visitors per day):
#
# distance  	urrlfr
#
# 0.00000   	raiffeisen.ru#consumerloans
# 0.04707   	raiffeisen.ru#request
# 0.04727   	raiffeisen.ru#product
# 0.08550   	raiffeisen.ru#retail
# 0.20535   	raiffeisen.ru#
# 0.21921   	raiffeisen.ru#calculator
# 0.26032   	raiffeisen.ru#mortgageloans
# 0.27724   	raiffeisen.ru#deposit
# 0.28778   	raiffeisen.ru#deposit_investing
# 0.30226   	raiffeisen.ru#remote_service
# 0.30502   	raiffeisen.ru#cards
# 0.30734   	raiffeisen.ru#connect
# 0.31301   	trust.ru#
# 0.31347   	rusprofile.ru#
# 0.31912   	rusprofile.ru#id
# 0.31939   	2gis.ru#krasnodar
# 0.31963   	fssprus.ru#iss
# 0.31982   	raiffeisen.ru#offices
# 0.32016   	trust.ru#retail
# 0.32386   	fssprus.ru#ip
# 0.32610   	fssprus.ru#
# 0.32897   	2gis.ru#rubrics
# 0.32898   	contragents.ru#
# 0.33234   	raiffeisen.ru#special_offers
# 0.33254   	raiffeisen.ru#about
# 0.33392   	maxikarta.ru#address
# 0.33903   	rusprofile.ru#codes
# 0.33968   	2gis.ru#rostov
# 0.33971   	2gis.ru#tula
# 0.34034   	pr-prom.ru#
# 0.34237   	sredstva.ru#city
# 0.34258   	k-agent.ru#
# 0.34304   	vdolevke.ru#
# 0.34309   	actez.ru#
# 0.34514   	ryazan.hh.ru#vacancy
# 0.34570   	rosrealt.ru#kommercheskaja
# 0.34633   	whokpo.com#view
# 0.34656   	theproperty.ru#
# 0.34738   	domkadrov.ru#emppart.php
# 0.34764   	sredstva.ru#
# 0.34906   	comreport.ru#
# 0.34913   	orgpage.ru#
# 0.35004   	b2b-project.ru#profile
# 0.35010   	partnerscheck.ru#
# 0.35067   	b2b-project.ru#
# 0.35180   	info-nomer.com#
# 0.35187   	actez.ru#company
# 0.35205   	tvoyadres.ru#doma
# 0.35213   	b2bsky.ru#
# 0.35219   	fssprus.ru#torgi
# 0.35240   	comreport.ru#company
# 0.35252   	mycompany.su#RU
# 0.35281   	domofond.ru#statya
# 0.35315   	whokpo.com#
# 0.35474   	allinfo24.ru#businessman
# 0.35495   	rusmap.net#Москва
# 0.35504   	infored.ru#company
# 0.35507   	yp.ru#list
# 0.35536   	2gis.ru#countries
# 0.35563   	pr-prom.ru#site
# 0.35576   	partnerscheck.ru#kadarbitr
# 0.35587   	mycompany.su#company
# 0.35599   	2gis.ru#vladimir
# 0.35653   	ryazan.hh.ru#
# 0.35654   	russianfirms.ru#
# 0.35676   	centrcom.ru#
# 0.35702   	orgpage.ru#otzivy
# 0.35718   	realty.dmir.ru#
# 0.35755   	sredstva.ru#credit
# 0.35863   	infored.ru#
# 0.35870   	k-agent.ru#catalog
# 0.35879   	fssprus.ru#int_help
# 0.35913   	mycompany.su#
# 0.36062   	gor-gid.ru#
# 0.36165   	saratov.hh.ru#
# 0.36176   	orgpage.ru#Company
# 0.36192   	russianfirms.ru#company
# 0.36203   	vdolevke.ru#company
# 0.36211   	maxikarta.ru#
# 0.36276   	bankstep.ru#
# 0.36311   	fssprus.ru#phonebook
# 0.36314   	jobsmarket.ru#
# 0.36324   	rosrabota.ru#
# 0.36435   	mirkvartir.ru#
# 0.36445   	2gis.ru#stavropol
# 0.36473   	rusmap.net#
# 0.36536   	b2bsky.ru#companies
# 0.36559   	partnerscheck.ru#ru
# 0.36560   	saratov.superjob.ru#
# 0.36589   	orgpage.ru#viewheader
# 0.36619   	yp.ru#dom
# 0.36733   	service-online.su#catalog
# 0.36808   	fssprus.ru#osp
# 0.36874   	chance.ru#
# 0.36930   	samara.job.ru#
# 0.36963   	beboss.ru#kn
# 0.36970   	asn-news.ru#rating
# 0.37029   	hr.zarplata.ru#
# 0.37033   	domkadrov.ru#empsearch.php
# 0.37034   	gde.ru#
#
# ----------------------------------------------------------------------------------------------------
#
# Nearest 100 neighbours for filkos.com# (5548 unique visitors per day):
#
# distance  	urrlfr
#
# 0.00000   	filkos.com#
# 0.04131   	filkos.com#credit.html
# 0.27197   	bank-advisor.ru#
# 0.28725   	joblab.ru#search_vacancy.php
# 0.29107   	secure.domadengi.ru#partners
# 0.29217   	secure.domadengi.ru#1850
# 0.29335   	ify.ru#
# 0.29860   	infapronet.ru#
# 0.29948   	cashalot.su#
# 0.30172   	secure.domadengi.ru#
# 0.30577   	bank-advisor.ru#offers
# 0.30722   	vacansia-company.ru#
# 0.30981   	grubber.ru#
# 0.31113   	domkadrov.ru#emppart.php
# 0.31394   	changeworks.ru#linkvac.php
# 0.31437   	careerix.ru#linkvac.php
# 0.31509   	slanet.ru#
# 0.31678   	changeworks.ru#
# 0.31680   	bank-advisor.ru#anketa
# 0.32032   	ir-center.ru#
# 0.32179   	rabota7.ru#
# 0.32261   	careerix.ru#
# 0.32462   	surgut.zarplata.ru#
# 0.32468   	bank-advisor.ru#renessans
# 0.32715   	joblab.ru#
# 0.32815   	omsk.trud.com#
# 0.32844   	vahta.rosrabota.ru#
# 0.32860   	hotwork.ru#gojob
# 0.32871   	brn.rosrabota.ru#
# 0.32905   	nk.rosrabota.ru#
# 0.32941   	vkarmane-online.ru#
# 0.33071   	kras.rosrabota.ru#
# 0.33091   	surgut.superjob.ru#
# 0.33113   	today-job.ru#linkvac.php
# 0.33201   	sredstva.ru#city
# 0.33223   	secure.domadengi.ru#short
# 0.33316   	surgut.zarplata.ru#vacancy
# 0.33321   	fssprus.ru#phonebook
# 0.33339   	rjb.ru#svac.cgi
# 0.33477   	ir-center.ru#work
# 0.33537   	hotwork.ru#
# 0.33538   	kemerovo.irr.ru#
# 0.33543   	job24.com.ru#
# 0.33556   	joblab.ru#e
# 0.33648   	hotwork.ru#page-3
# 0.33670   	omsk.rosrabota.ru#vac-branch-tag
# 0.33822   	omsk.superjob.ru#vakansii
# 0.33872   	jobs-list.ru#
# 0.33883   	domkadrov.ru#empsearch.php
# 0.33898   	hotwork.ru#page-2
# 0.33943   	kem.rosrabota.ru#
# 0.33988   	hotwork.ru#jobs
# 0.34032   	stavzan.ru#
# 0.34032   	nizhnevartovsk.yarmarka.biz#rabota
# 0.34055   	today-job.ru#
# 0.34072   	sila-sibiri-rabota.ru#
# 0.34096   	hotwork.ru#page-4
# 0.34098   	cashalot.su#registration
# 0.34171   	sredstva.ru#credit
# 0.34290   	rabota.gorodaonline.com#
# 0.34350   	voronezh.job.ru#
# 0.34380   	jobs-list.ru#linkvac.php
# 0.34439   	domkadrov.ru#candpart.php
# 0.34439   	irk.rosrabota.ru#
# 0.34459   	domkadrov.ru#candapply.php
# 0.34502   	torgdrom.ru#
# 0.34507   	exdex.ru#tyumen
# 0.34525   	credity5.ru#
# 0.34635   	irkutsk.superjob.ru#
# 0.34749   	srt.rosrabota.ru#
# 0.34819   	rabotunaidu.ru#
# 0.34848   	бизнесок.рф#
# 0.34856   	rabota7.ru#vacancies
# 0.34911   	job24.com.ru#index
# 0.34912   	dorus.ru#add.html
# 0.34981   	rjb.ru#
# 0.35008   	naim.ru#vac
# 0.35032   	vahta.rosrabota.ru#vac-full
# 0.35070   	krasnodar-rabota.ru#
# 0.35096   	superjob.ru#prices
# 0.35116   	domkadrov.ru#
# 0.35168   	hotwork.ru#voditel
# 0.35199   	orenburg.superjob.ru#vakansii
# 0.35263   	tyumen.superjob.ru#
# 0.35274   	белка.com#
# 0.35396   	btg-expo.ru#c
# 0.35453   	nizhnevartovsk.yarmarka.biz#
# 0.35470   	get-creditz.ru#
# 0.35475   	anapa.irr.ru#
# 0.35491   	tolyatti.trud.com#
# 0.35493   	bankspro.ru#
# 0.35507   	saratov.superjob.ru#vakansii
# 0.35508   	surgut.superjob.ru#vakansii
# 0.35543   	online.rdw.ru#newspaper
# 0.35601   	btg-expo.ru#t
# 0.35683   	astrabota.ru#
# 0.35690   	nizhnevartovsk.yarmarka.biz#nizhnevartovsk
# 0.35730   	большой-каталог.рф#
# 0.35744   	barnaul.rabota.ru#
# 0.35809   	vaxta.lact.ru#
#
# ----------------------------------------------------------------------------------------------------
#
# Nearest 100 neighbours for auto.exist.ru# (5146 unique visitors per day):
#
# distance  	urrlfr
#
# 0.00000   	auto.exist.ru#
# 0.08482   	euroauto.ru#kuzov_naruzhnie_elementi
# 0.08603   	japancats.ru#scheme.aspx
# 0.08710   	euroauto.ru#firms
# 0.08737   	autodoc.ru#art
# 0.08811   	japancats.ru#
# 0.09016   	autodoc.ru#
# 0.09212   	japancats.ru#nissan
# 0.09235   	euroauto.ru#used
# 0.09255   	autodoc.ru#Web
# 0.09377   	euroauto.ru#
# 0.09397   	japancats.ru#Auth.aspx
# 0.09429   	euroauto.ru#all
# 0.09457   	japancats.ru#Group.aspx
# 0.09571   	autodoc.ru#part
# 0.09667   	japancats.ru#Parts.aspx
# 0.09716   	3139393.ru#catalog
# 0.09746   	euroauto.ru#part
# 0.09901   	autodoc.ru#Account
# 0.09914   	autodoc.ru#Pages
# 0.09923   	auto2.ru#search
# 0.09959   	3139393.ru#
# 0.09982   	euroauto.ru#nissan
# 0.09994   	elcats.ru#hyundai
# 0.10051   	japancats.ru#Unit.aspx
# 0.10052   	autodoc.ru#price
# 0.10128   	euroauto.ru#elektroosnaschenie
# 0.10178   	ferio.ru#zapchasti
# 0.10223   	autobody.ru#
# 0.10298   	japancats.ru#NISSAN
# 0.10340   	autodoc.ru#647
# 0.10387   	japancats.ru#mitsubishi
# 0.10400   	autodoc.ru#CartForm.aspx
# 0.10444   	auto2.ru#
# 0.10457   	euroauto.ru#transmissiya
# 0.10490   	rmsauto.ru#SearchSpareParts.aspx
# 0.10517   	elcats.ru#chevrolet
# 0.10519   	autodoc.ru#AllAuto.aspx
# 0.10528   	rmsauto.ru#
# 0.10607   	japancats.ru#mazda
# 0.10654   	euroauto.ru#new
# 0.10658   	autodoc.ru#brand
# 0.10661   	autobody.ru#catalog
# 0.10663   	autodoc.ru#ordersSubClients.aspx
# 0.10675   	japancats.ru#TOYOTA
# 0.10694   	plentycar.ru#autoparts
# 0.10698   	autodoc.ru#Cart
# 0.10702   	autodoc.ru#BalanceForm.aspx
# 0.10715   	elcats.ru#Options.aspx
# 0.10722   	japancats.ru#subaru
# 0.10725   	авторазбор.рф#
# 0.10748   	euroauto.ru#cars
# 0.10764   	autodoc.ru#OrderDone
# 0.10780   	autodoc.ru#LogOnPage
# 0.10855   	euroauto.ru#dvigatel
# 0.10919   	autodoc.ru#index
# 0.10972   	euroauto.ru#podveska_perednih_kolyos
# 0.10984   	autodoc.ru#CatalogOriginal.aspx
# 0.10985   	autodoc.ru#catalogs
# 0.11004   	plentycar.ru#
# 0.11022   	koreanaparts.ru#partsearch
# 0.11025   	koreanaparts.ru#
# 0.11042   	euroauto.ru#auto
# 0.11069   	autodoc.ru#acat
# 0.11095   	japancats.ru#Modification.aspx
# 0.11113   	autodoc.ru#hyundai-kia
# 0.11139   	autodoc.ru#manufacturer792
# 0.11177   	elcats.ru#Group.aspx
# 0.11191   	japancats.ru#VIN.aspx
# 0.11207   	voloton.ru#price
# 0.11232   	elcats.ru#opel
# 0.11254   	out-club.ru#board
# 0.11264   	voloton.ru#
# 0.11292   	elcats.ru#bmw
# 0.11314   	elcats.ru#Parts.aspx
# 0.11361   	out-club.ru#showthread.php
# 0.11425   	japancats.ru#honda
# 0.11462   	japancats.ru#suzuki
# 0.11494   	gm-city.ru#catalog
itors per day):
#
# distance  	urrlfr
#
# 0.00000   	gdz-putina.me#
# 0.05202   	gdz-putina.me#5-klass-onlajn
# 0.05223   	гдз.сайт#
# 0.05457   	gdzeyka.com#
# 0.05530   	gdz-putina.me#anglijskij-yazik-5
# 0.05561   	gdz-putina.me#7-klass-onlajn
# 0.05597   	gdz-putina.me#anglijskij-yazik-6
# 0.05728   	gdzeyka.com#photo
# 0.05741   	gdz-putina.me#6-klass-onlajn
# 0.05742   	gdz-putina.me#1-4-klassi-onlajn
# 0.05946   	30school.ru#5-klass
# 0.05949   	30school.ru#
# 0.05961   	гдз.сайт#1
# 0.05986   	ggddzz.ru#
# 0.06043   	megaresheba.ru#03
# 0.06053   	гдз.сайт#gdz
# 0.06060   	egeurok.ru#gdz_russkii_yazyk
# 0.06095   	гдз.сайт#6_klass
# 0.06153   	egeurok.ru#
# 0.06179   	spishy-ru.ru#6-klass
# 0.06226   	gdz-putina.info#7-klass
# 0.06243   	egeurok.ru#GDZ_matem
# 0.06260   	gdz-putina.me#gdz-po-russkomu-yaziku-7-klass-baranov-ladizhenskaya-trostentsova-2013
# 0.06279   	megaresheba.ru#0-4303
# 0.06283   	gdz-putina.info#
# 0.06289   	gdz-putina.me#russkij-yazik-7
# 0.06294   	гдз.сайт#7_klass
# 0.06314   	gdz-putina.me#russkij-yazik-6
# 0.06366   	gdz-free.com#gdz
# 0.06396   	egeurok.ru#1
# 0.06462   	gdz-putina.me#matematika-1-4
# 0.06478   	gdz-putina.me#matematika-5
# 0.06505   	gdz-putina.me#anglijskij-yazik-7
# 0.06511   	spishi-ru.net#
# 0.06537   	gdz-geo.ru#
# 0.06540   	spishy-online.ru#
# 0.06552   	gdz-putina.me#algebra-7
# 0.06568   	onlinegdz.net#
# 0.06579   	megaresheba.ru#02
# 0.06592   	30school.ru#anglijskij-yazyk.html
# 0.06593   	gdzeyka.com#7_klass
# 0.06596   	ggddzz.ru#reshebnik
# 0.06608   	domashke.net#homework
# 0.06643   	30school.ru#anglijskij-yazyk
# 0.06648   	egeurok.ru#7klass
# 0.06670   	egeurok.ru#4klass
# 0.06676   	spishy-ru.ru#
# 0.06706   	slovo.ws#05
# 0.06732   	botanam.net#
# 0.06733   	onlinegdz.net#reshebnik-matematika-5-klass-zubareva-mordkovich
# 0.06765   	egeurok.ru#6klass
# 0.06780   	egeurok.ru#gdz_biologiya
# 0.06783   	megaresheba.ru#5_klass
# 0.06798   	botanam.net#6-klass
# 0.06805   	megaresheba.ru#0-482
# 0.06809   	30school.ru#istoriya
# 0.06817   	megaresheba.ru#0-483
# 0.06827   	gdzputina.com#
# 0.06832   	gdz-free.com#
# 0.06837   	gdz-putina.info#6-klass
# 0.06856   	gdz-putina.me#gdz-reshebnik-po-anglijskomu-yaziku-6-klass-biboletova-students-book
# 0.06861   	vse-gdz.info#
# 0.06890   	botanam.net#gdz
# 0.06912   	slovo.ws#003
# 0.06921   	stavcur.ru#reshebnik_gdz
# 0.06933   	gdz-geo.ru#all-gdz
# 0.06956   	egeurok.ru#2
# 0.06985   	gdz-putina.me#gdz-po-russkomu-yaziku-6-klass-baranov-ladizhenskaya-trostentsova
# 0.06985   	gdz-putina.me#matematika-6
# 0.06996   	gdz-putina.me#reshebnik-gdz-otveti-po-anglijskomu-yaziku-5-klass-biboletova-uchebnik-enjoy-english
# 0.07044   	yroky.net#gdz
# 0.07047   	gdzpop.com#
# 0.07054   	gdzeyka.com#6_klass
# 0.07057   	gdz-stalina.com#
# 0.07058   	gdz-putina.me#gdz-reshebnik-po-russkomu-yazyku-4-klass-kanakina-goretskij-1-i-2-chast
# 0.07079   	megaresheba.ru#6_klass_biboletova
# 0.07083   	megadum.ru#
# 0.07106   	gdzeyka.com#5_klass
# 0.07112   	спиши-ру.su#gdz-po-matematike
# 0.07125   	spishy-ru.ru#5-klass
# 0.07137   	gdzv.ru#
# 0.07138   	resheba.com#russkij-jazyk
# 0.07170   	gdzpop.com#matematika-1-4
# 0.07189   	slovo.ws#02
# 0.07201   	megaresheba.ru#0-308
# 0.07220   	resheba.com#kanakina
# 0.07245   	otbet.ru#lidman-10
# 0.07251   	egeurok.ru#5klass
# 0.07258   	gdz-geo.ru#biology
# 0.07273   	gdz-putina.me#gdz-reshebnik-po-russkomu-yaziku-6-klass-razumovskaya
# 0.07277   	megaresheba.ru#0-487
# 0.07290   	gdzputina.com#5-klass
# 0.07293   	ggddzz.ru#list
# 0.07315   	egeurok.ru#gdz_anglijskij_yazik
# 0.07317   	gdzeyka.com#2014
# 0.07320   	megaresheba.ru#04
# 0.07333   	megaresheba.ru#101-1-0-1290
# 0.07338   	megaresheba.ru#42-1-0-2107
# 0.07343   	slovo.ws#resh
# 0.07345   	gdz-putina.info#anglijskij-yazik-6

# %%
#print('\n'.join(['{:<10.5f}\t{:<30}'.format(e[0],e[1].encode('utf-8')) for e in neighbours('101.credit#kredity', Yb,uf_dict, 100 )]))
up = '101.credit#kredity'
#uf_dict[uf_dict['urlfr'] == up]
neighbours(up, Yb,uf_dict, n = n)
# Out:
# [[0.0, u'101.credit#kredity'],
#  [0.18404546470662886, u'101.credit#articles'],
#  [0.32669600985135694, u'101.credit#'],
#  [0.49131145910777696, u'na-ladoni.su#'],
#  [0.49367114173451188, u'zagranguru.ru#'],
#  [0.49771437583809452, u'oktmo2014.ru#OKTMO'],
#  [0.49900987598214608, u'migrants.ru#forum'],
#  [0.50330818673528199, u'allinform.ru#'],
#  [0.50379939392092044, u'nalog-nalog.ru#poryadok_uplaty_nalogov_vznosov'],
#  [0.50431218319880466, u'm.9111.ru#'],
#  [0.50691837807519802, u'rusmap.net#\u0424\u0438\u0440\u043c\u0430'],
#  [0.50700616132484455, u'migrants.ru#'],
#  [0.50838290053426793, u'lawyer-consult.ru#'],
#  [0.51335024778263838, u'cfo.spr.ru#map'],
#  [0.51587377325777883, u'cryptopilot.ru#'],
#  [0.51605346028100874, u'cfo.spr.ru#'],
#  [0.51743035652719582, u'creditnyi.ru#'],
#  [0.52036758469937539, u'voronezhphone.ru#'],
#  [0.52050604085754726, u'pravorub.ru#'],
#  [0.52164616171006895, u'vladimirskaya-rus.ru#'],
#  [0.52284053925940721, u'vse-posobia.ru#'],
#  [0.52353606424717491, u'migrants.ru#theme.php'],
#  [0.52693854611610602, u'r77.fssprus.ru#'],
#  [0.52730538801997051, u'kontur.ru#'],
#  [0.52732124969913619, u'pravo812.ru#'],
#  [0.5282839786276361, u'topurist.ru#'],
#  [0.5284096455613253, u'd-instrukciya.ru#'],
#  [0.53095648668770301, u'helpacc.ru#'],
#  [0.53103537698633874, u'morefirm.ru#'],
#  [0.53149594800736732, u'index.kodifikant.ru#'],
#  [0.53193066355989171, u'copdoc.ru#'],
#  [0.53196157355149598, u'hochu-na-yuga.ru#tuapse'],
#  [0.53219792106673114, u'na-ladoni.su#RU'],
#  [0.53249800808526349, u'domyurist.ru#'],
#  [0.53260086897994752, u'finansovyesovety.ru#'],
#  [0.53322072160740419, u'podborkadrov.com#'],
#  [0.53482962447227433, u'pravo812.ru#useful'],
#  [0.53529207112695487, u'tramitador.ru#'],
#  [0.53534058595389733, u'mapbase.ru#'],
#  [0.53702752798100639, u'domkadrov.ru#emppart.php'],
#  [0.53749922369622483, u'9111.ru#\u0441\u0443\u0434'],
#  [0.53834135200116706, u'kreditipo.ru#'],
#  [0.53960837300131059, u'garant.ru#gpurchase'],
#  [0.53972176867691413, u'forum.zakonia.ru#showthread.php'],
#  [0.54004270710346614, u'inremo-group.ru#'],
#  [0.54071442647802437, u'novorogdenniy.ru#txt'],
#  [0.5416177819339929, u'111999.ru#'],
#  [0.54177333927743176, u'okonh.ru#'],
#  [0.54211329499183791, u'creditzzz.ru#'],
#  [0.542483470619746, u'allinfo24.ru#businessman'],
#  [0.54326505422564086, u'9111.ru#add'],
#  [0.54466595398852924, u'akibank.ru#'],
#  [0.54575278562193819, u'top-personal.ru#lawissue.html'],
#  [0.5459552077169687, u'izhcommunal.ru#'],
#  [0.54603849780382441, u'm.ppt.ru#'],
#  [0.54625156541334441, u'bsnss.net#'],
#  [0.54700458734452484, u'samaraphone.ru#'],
#  [0.5475674395323834, u'erbp.ru#news'],
#  [0.54793605702476889, u'potrebkor.ru#'],
#  [0.54817642462269078, u'77metrov.ru#'],
#  [0.54881234707449811, u'r77.fssprus.ru#iss'],
#  [0.54981870700268687, u'pages.esosedi.ru#'],
#  [0.55052218757856874, u'novorogdenniy.ru#'],
#  [0.55084719106244429, u'gk-rf.ru#'],
#  [0.55093964307655607, u'tvoi.biz#'],
#  [0.55109745272222033, u'ipinform.ru#kadry'],
#  [0.55118541688873024, u'rusmap.net#'],
#  [0.55166490814342972, u'gov-zakupki.ru#'],
#  [0.55208559860451989, u'yfo.spr.ru#map'],
#  [0.55248426424983477, u'101million.com#dokumenty'],
#  [0.55273023803698162, u'pfo.spr.ru#'],
#  [0.55288877437504236, u'maxikarta.ru#phone'],
#  [0.55290075394540883, u'besplatniy-urist.ru#'],
#  [0.55292391780659078, u'pravovedus.ru#'],
#  [0.55337482923250136, u'yurist-konsult.ru#'],
#  [0.55413065162949793, u'bizlog.ru#okved'],
#  [0.555067904283851, u'infinica.ru#'],
#  [0.55515997293560815, u'kirov-portal.ru#'],
#  [0.55531134442660979, u'pfgfx.ru#pravo'],
#  [0.55540133545051695, u'svoy-business.com#'],
#  [0.55552124761054655, u'index.kodifikant.ru#ru'],
#  [0.55558833913425831, u'oktmo2014.ru#'],
#  [0.5563874907898898, u'garant.ru#actual'],
#  [0.55643959291833311, u'zakonrf.info#gpk'],
#  [0.55654932146263147, u'ipipip.ru#kz'],
#  [0.55674055508002063, u'izhcommunal.ru#dir'],
#  [0.55738215432507965, u'sko.spr.ru#'],
#  [0.55745750565200625, u'hr-journal.ru#articles'],
#  [0.55761632448887299, u'bisgid.ru#'],
#  [0.55870254114644047, u'9111.ru#'],
#  [0.55875158178256246, u'allinfo24.ru#'],
#  [0.55929547555183468,
#   u'gazeta-unp.ru#41278-sqe-15-m11-obrazets-zapolneniya-6-ndfl'],
#  [0.55968222009522539, u'forum.infostart.ru#forum46'],
#  [0.56026824631556549,
#   u'\u043d\u043e\u0432\u044b\u0435\u0444\u043e\u0440\u043c\u044b.\u0440\u0444#'],
#  [0.56031949433575268, u'forum.zakonia.ru#'],
#  [0.56038494904069502, u'hrmaximum.ru#labor_law'],
#  [0.5606829499399002,
#   u'\u0441\u0435\u043a\u0432\u043e\u0439\u044f.\u0440\u0444#'],
#  [0.56110064764471235, u'instrukciy.ru#'],
#  [0.56113937214650234, u'komandirovka.ru#hotels'],
#  [0.56120454245104867,
#   u'9111.ru#\u043a\u0432\u0430\u0440\u0442\u0438\u0440\u0430']]

# %%
# Out:
# 2

# %%
af = open('data/collab_filter_SGD_a_vec.csv','w')
Xf = open('data/collab_filter_SGD_X_matr.csv','w')

# %%
a = [float(r[1]) for r in [e.split(',') for e in open('data/collab_filter_SGD_a_vec.csv','r').readlines()] if int(r[0]) % 20000 > 10000]

# %%
X = [[float(e) for e in r[1:]] for r in [e.split(',') for e in open('data/collab_filter_SGD_X_matr.csv','r').readlines()] if int(r[0]) % 20000 > 10000]

# %%
#ra = open('data/collab_filter_SGD_a_vec.csv','r').readlines()

# %%
Xa = np.array([[ai+ mu[0],1] + x for ai,x in zip(a,X)])

# %%
UTdotU = np.zeros([Xa.shape[1],Xa.shape[1]])
for i in range(UTdotU.shape[1]):
    for j in range(UTdotU.shape[1]):
        UTdotU[i,j] = Xa[i].dot(Xa[j])

# %%
import cPickle
cPickle.dump(UTdotU,open('UTdotU.pck','w'))

# %%
#b = [float(r[1]) for r in [e.strip().split(',') for e in open('data/collab_filter_SGD_b_vec.csv','r').readlines()[:-1]]]
Y = [[float(e) for e in r[1:]] for r in [e.strip().split(',') for e in open('data/collab_filter_SGD_Y_matr.csv','r').readlines()]]

# %%
for j in range(len(Y[-1]),len(Y[1])):
    Y[-1].append(sum([Y[i][j] for i in range(99)])/99.)
#b = b + [sum(b)/len(b)] * (len(Y[0]) - len(b))
Yb = np.array([[1,b[i]] +[Y[j][i] for j in range(len(Y))] for i in range(len(b))])

# %%
r = np.dot(Yb,UTdotU)
r1num = np.dot(r[num],Yb.T)

# %%
res = sorted(zip(r1num,range(len(r1num))))

# %%
sc.stop()
# Out:
# datetime.date(2016, 10, 23)
