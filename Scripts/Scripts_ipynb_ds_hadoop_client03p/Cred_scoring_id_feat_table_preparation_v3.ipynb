# %% [markdown]
# ### Создание таблицы факторов по кукам для кред скоринга

# %%
import datetime

# %%
try:
    sc.stop()
except:
    pass

# %%
class calc_cred_score():

    init_query = '''
    set hive.vectorized.execution.enabled=true;
    set mapreduce.map.memory.mb=4096;
    set mapreduce.map.child.java.opts=-Xmx4g;
    set mapreduce.task.io.sort.mb=1024;
    set mapreduce.reduce.child.java.opts=-Xmx4g;
    set mapreduce.reduce.memory.mb=7000;
    set mapreduce.reduce.shuffle.input.buffer.percent=0.5;
    set mapreduce.input.fileinputformat.split.minsize=536870912;
    set mapreduce.input.fileinputformat.split.maxsize=1073741824;
    set hive.optimize.ppd=true;
    set hive.merge.smallfiles.avgsize=536870912;
    set hive.merge.mapredfiles=true;
    set hive.merge.mapfiles=true;
    set hive.hadoop.supports.splittable.combineinputformat=true;
    set hive.exec.reducers.bytes.per.reducer=536870912;
    set hive.exec.parallel=true;
    set hive.exec.max.created.files=10000000;
    set hive.exec.compress.output=true;
    set hive.exec.dynamic.partition.mode=nonstrict;
    set hive.exec.max.dynamic.partitions=1000000;
    set hive.exec.max.dynamic.partitions.pernode=100000;
    set io.seqfile.compression.type=BLOCK;
    set mapred.output.compression.codec=org.apache.hadoop.io.compress.BZip2Codec;
    set mapreduce.map.failures.maxpercent=5;

    set hive.tez.auto.reducer.parallelism=true;
    set hive.tez.min.partition.factor=0.25;
    set hive.tez.max.partition.factor=2.0;
    set tez.runtime.pipelined.sorter.lazy-allocate.memory=true;
    set hive.exec.dynamic.partition.mode=nonstrict;
    '''

    create_accum_query = '''
    CREATE TABLE IF NOT EXISTS `user_kposminin.id_feat_accum`(
          `id` string, 
          `load_src` string, 
          `first_id_ymd` string, 
          `last_id_ymd` string, 
          `ymd_cnt` int, 
          `urlfr_cnt` bigint, -- `cnt` bigint, 
          `visits_cnt` bigint, 
          `hits` bigint, 
          `emailru_sum` bigint, 
          `mobile_sum` double, 
          `vk_sum` double, 
          `social_sum` double, 
          `work_hours_hits_sum` double, 
          `avg_hour_sum_sq` bigint, 
          `avg_hour_sum` bigint, 
          `max_score1` double, 
          `max_score2` double, 
          `max_score3` double, 
          `max_score4` double, 
          `max_score5` double, 
          `max_score6` double, 
          `min_score1` double, 
          `min_score2` double, 
          `min_score3` double, 
          `min_score4` double, 
          `min_score5` double, 
          `min_score6` double, 
          `sum_score1` double, 
          `sum_score2` double, 
          `sum_score3` double, 
          `sum_score4` double, 
          `sum_score5` double, 
          `sum_score6` double, 
          `cnt_score1` int, 
          `cnt_score2` int, 
          `cnt_score3` int, 
          `cnt_score4` int, 
          `cnt_score5` int, 
          `cnt_score6` int, 
          `good_urlfr_sum_score1` double, 
          `good_urlfr_sum_score2` double, 
          `good_urlfr_sum_score3` double,
          `good_urlfr_sum_score4` double,
          `good_urlfr_sum_score5` double,
          `good_urlfr_sum_score6` double)
    partitioned by (
          `first_calc_ymd` string, 
          `last_calc_ymd` string      
          )
    ;

    '''
 
    feat_1d_query_pattern = '''

    -- #ymd. Id_feats 1 day calc
    with mymd as 
     (select
       target,
       max(ymd) as max_ymd
      from
       user_kposminin.urlfr_scores
      where 
        ymd < date_add('#ymd',-3)
      group by target
     )

    insert overwrite table user_kposminin.id_feat_accum partition (first_calc_ymd, last_calc_ymd)
    select 
     id,
     load_src, 
     ymd as first_id_ymd, 
     ymd as last_id_ymd,
     1 as ymd_cnt,
     count(distinct urlfr) as urlfr_cnt,
     count(urlfr) as visits_cnt,
     sum(cnt) as hits,
     sum(if(urlfr like 'e.mail.ru%',1,0)) as emailru_sum,
     sum(if(urlfr like 'm.%',1,0)) as mobile_sum,
     sum(if(urlfr rlike '^(m\\.)?vk.com', 1, 0)) as vk_sum,
     sum(if(urlfr rlike '^(m\\.)?vk.com' or urlfr rlike '^(m\\.)?(ok|odnoklassniki)\\.ru' or urlfr rlike '^(m\\.)?my.mail.ru',1,0)) as social_sum,
     sum(if(avg_hour >= 9 and avg_hour <= 20,cnt,0)) as work_hours_hits_sum,
     sum( avg_hour * avg_hour) as avg_hour_sum_sq,
     sum(avg_hour) as avg_hour_sum,
     max(score1) as max_score1,
     max(score2) as max_score2,
     max(score3) as max_score3,
     max(score4) as max_score4,
     max(score5) as max_score5,
     max(score6) as max_score6,
     min(score1) as min_score1,
     min(score2) as min_score2,
     min(score3) as min_score3,
     min(score4) as min_score4,
     min(score5) as min_score5,
     min(score6) as min_score6,
     sum(score1) as sum_score1,
     sum(score2) as sum_score2,
     sum(score3) as sum_score3,
     sum(score4) as sum_score4, 
     sum(score5) as sum_score5,
     sum(score6) as sum_score6, 
     count(score1) as cnt_score1,
     count(score2) as cnt_score2,
     count(score3) as cnt_score3,
     count(score4) as cnt_score4, 
     count(score5) as cnt_score5,
     count(score6) as cnt_score6, 
     count( if(score1 > -0.2, urlfr,Null)) as good_urlfr_sum_score1,
     count( if(score2 > -9, urlfr,Null)) as good_urlfr_sum_score2,
     count( if(score3 > -9, urlfr,Null)) as good_urlfr_sum_score3,
     count( if(score4 > -2, urlfr,Null)) as good_urlfr_sum_score4,
     count( if(score5 > -9, urlfr,Null)) as good_urlfr_sum_score5,
     count( if(score6 > -0.2, urlfr,Null)) as good_urlfr_sum_score6,
     '#ymd' as first_calc_ymd, 
     '#ymd' as last_calc_ymd

    from
     (select
        v.id,
        'LI.02' as load_src, -- !!!! bug
        v.ymd,
        v.urlfr,
        unix_timestamp(v.ymd, 'yyyy-MM-dd')/60/60 + v.avg_hour  as time_h,
        1 as time_std,
        v.cnt as cnt,
        v.avg_hour as avg_hour,
        t1.score as score1,
        t2.score as score2,
        t3.score as score3,
        t4.score as score4,
        t5.score as score5,
        log((t2.cnt_positive + 0.1)/(t3.cnt_positive - t2.cnt_positive + 0.1)) as score6
      from
        user_kposminin.visits_cred_scor_calc_debug_20170429 v
        left join (
            select urlfr,score
              from mymd td
             inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
             where td.target = 'ccall_tinkoff_approve_from_fullapp'
        ) t1 on t1.urlfr = v.urlfr
        left join (
            select urlfr,score,positive as cnt_positive
              from mymd td
             inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
             where td.target = 'tinkoff_platinum_approved_application03@tinkoff_action' 
        ) t2 on t2.urlfr = v.urlfr
        left join (
            select urlfr,score,positive as cnt_positive
              from mymd td
             inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
             where td.target = 'tinkoff_platinum_complete_application03@tinkoff_action'
        ) t3 on t3.urlfr = v.urlfr
        left join (
            select urlfr,score
              from mymd td
             inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
             where td.target = 'tinkoff_LON_CCR_default'
        ) t4 on t4.urlfr = v.urlfr
        left join (
            select urlfr,score
              from mymd td
             inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
             where td.target = 'tinkoff_platinum_approved_application03_1m'
        ) t5 on t5.urlfr = v.urlfr
      where 
        v.ymd = '#ymd' 
     ) a 
    group by
      id,load_src,ymd
    ;
    '''

    accumulator_merge_pattern = '''

    insert overwrite table user_kposminin.id_feat_accum partition (first_calc_ymd,last_calc_ymd)
    select
      nvl(a.id,b.id) as id,
      nvl(a.load_src,b.load_src) as load_src,
      least(a.first_id_ymd,b.first_id_ymd) as first_id_ymd,
      greatest(a.last_id_ymd,b.last_id_ymd) as last_id_ymd,
      nvl(a.ymd_cnt,0) + nvl(b.ymd_cnt,0) as ymd_cnt,
      nvl(a.urlfr_cnt,0) + nvl(b.urlfr_cnt,0) as urlfr_cnt,
      nvl(a.visits_cnt,0) + nvl(b.visits_cnt,0) as visits_cnt,
      nvl(a.hits,0) + nvl(b.hits,0) as hits,
      nvl(a.emailru_sum,0) + nvl(b.emailru_sum,0) as emailru_sum,
      nvl(a.mobile_sum,0) + nvl(b.mobile_sum,0) as mobile_sum,
      nvl(a.vk_sum,0) + nvl(b.vk_sum,0) as vk_sum,
      nvl(a.social_sum,0) + nvl(b.social_sum,0) as social_sum,
      nvl(a.work_hours_hits_sum,0) + nvl(b.work_hours_hits_sum,0) as work_hours_hits_sum,
      nvl(a.avg_hour_sum_sq,0) + nvl(b.avg_hour_sum_sq,0) as avg_hour_sum_sq,
      nvl(a.avg_hour_sum,0) + nvl(b.avg_hour_sum,0) as avg_hour_sum,
      greatest(a.max_score1,b.max_score1) as max_score1,
      greatest(a.max_score2,b.max_score2) as max_score2,
      greatest(a.max_score3,b.max_score3) as max_score3,
      greatest(a.max_score4,b.max_score4) as max_score4,
      greatest(a.max_score5,b.max_score5) as max_score5,
      greatest(a.max_score6,b.max_score6) as max_score6,
      least(a.min_score1, b.min_score1) as min_score1,
      least(a.min_score2, b.min_score2) as min_score2,
      least(a.min_score3, b.min_score3) as min_score3,
      least(a.min_score4, b.min_score4) as min_score4,
      least(a.min_score5, b.min_score5) as min_score5,
      least(a.min_score6, b.min_score6) as min_score6,
      nvl(a.sum_score1,0) + nvl(b.sum_score1,0) as sum_score1,
      nvl(a.sum_score2,0) + nvl(b.sum_score2,0) as sum_score2,
      nvl(a.sum_score3,0) + nvl(b.sum_score3,0) as sum_score3,
      nvl(a.sum_score4,0) + nvl(b.sum_score4,0) as sum_score4,
      nvl(a.sum_score5,0) + nvl(b.sum_score5,0) as sum_score5,
      nvl(a.sum_score6,0) + nvl(b.sum_score6,0) as sum_score6,
      nvl(a.cnt_score1,0) + nvl(b.cnt_score1,0) as cnt_score1,
      nvl(a.cnt_score2,0) + nvl(b.cnt_score2,0) as cnt_score2,
      nvl(a.cnt_score3,0) + nvl(b.cnt_score3,0) as cnt_score3,
      nvl(a.cnt_score4,0) + nvl(b.cnt_score4,0) as cnt_score4,
      nvl(a.cnt_score5,0) + nvl(b.cnt_score5,0) as cnt_score5,
      nvl(a.cnt_score6,0) + nvl(b.cnt_score6,0) as cnt_score6,
      nvl(a.good_urlfr_sum_score1,0) + nvl(b.good_urlfr_sum_score1,0) as good_urlfr_sum_score1,
      nvl(a.good_urlfr_sum_score2,0) + nvl(b.good_urlfr_sum_score2,0) as good_urlfr_sum_score2,
      nvl(a.good_urlfr_sum_score3,0) + nvl(b.good_urlfr_sum_score3,0) as good_urlfr_sum_score3,
      nvl(a.good_urlfr_sum_score4,0) + nvl(b.good_urlfr_sum_score4,0) as good_urlfr_sum_score4,
      nvl(a.good_urlfr_sum_score5,0) + nvl(b.good_urlfr_sum_score5,0) as good_urlfr_sum_score5,
      nvl(a.good_urlfr_sum_score6,0) + nvl(b.good_urlfr_sum_score6,0) as good_urlfr_sum_score6,
      '#new_first_calc_ymd' as first_calc_ymd,
      '#new_last_calc_ymd' as last_calc_ymd
    from 
      (select * from user_kposminin.id_feat_accum a where a.first_calc_ymd = '#a_first_calc_ymd' and a.last_calc_ymd = '#a_last_calc_ymd') a
      full join (select * from user_kposminin.id_feat_accum b where b.first_calc_ymd = '#b_first_calc_ymd' and b.last_calc_ymd = '#b_last_calc_ymd') b 
        on a.id = b.id and a.load_src = b.load_src
    ;


    '''

    clear_partition_query = '''
    alter table user_kposminin.id_feat_accum drop partition (first_calc_ymd = '#first_calc_ymd', last_calc_ymd = '#last_calc_ymd');
    '''

    create_feat_table_query = '''

    create table user_kposminin.id_feat_ccall as
    select 
         a.phone_mobile, 
         count(distinct a.id) as id_cnt,
         count(distinct acc.id) as acc_id_cnt,
         a.call_ymd as call_ymd,
         max(a.approve) as approve,
         sum(acc.urlfr_cnt) as urlfr_cnt,
         sum(acc.visits_cnt) as visits_cnt, 
         sum(acc.hits) as hits,
         max(acc.max_score1) as max_score1,
         sum(acc.sum_score1) / sum(acc.cnt_score1) as avg_score1,
         min(acc.min_score1) as min_score1,
         max(acc.max_score2) as max_score2,
         sum(acc.sum_score2) / sum(acc.cnt_score2) as avg_score2,
         min(acc.min_score2) as min_score2,
         max(acc.max_score3) as max_score3,
         sum(acc.sum_score3) / sum(acc.cnt_score3) as avg_score3,
         min(acc.min_score3) as min_score3,
         max(acc.max_score4) as max_score4,
         sum(acc.sum_score4) / sum(acc.cnt_score4) as avg_score4,
         min(acc.min_score4) as min_score4,
         max(acc.max_score5) as max_score5,
         sum(acc.sum_score5) / sum(acc.cnt_score4) as avg_score5,
         min(acc.min_score5) as min_score5,
         max(acc.max_score6) as max_score6,
         sum(acc.sum_score6) / sum(acc.cnt_score4) as avg_score6,
         min(acc.min_score6) as min_score6,
         sum(acc.emailru_sum) / sum(acc.visits_cnt) as emailru_share,
         sum(acc.mobile_sum) / sum(acc.visits_cnt) as mobile_share,
         sum(acc.vk_sum) / sum(acc.visits_cnt) as vk_share,
         sum(acc.social_sum) / sum(acc.visits_cnt) as social_share,
         sum(acc.work_hours_hits_sum) / sum(acc.hits) as work_hours_hits_share,
         sqrt(sum(acc.avg_hour_sum_sq)/(sum(acc.visits_cnt)-1) - power(sum(acc.avg_hour_sum)/(sum(acc.visits_cnt) - 1), 2)) as hour_std,
         sum(acc.good_urlfr_sum_score1) / sum(acc.cnt_score1) as good_urlfr_share_score1, 
         sum(acc.good_urlfr_sum_score2) / sum(acc.cnt_score2) as good_urlfr_share_score2,
         sum(acc.good_urlfr_sum_score3) / sum(acc.cnt_score3) as good_urlfr_share_score3, 
         sum(acc.good_urlfr_sum_score4) / sum(acc.cnt_score4) as good_urlfr_share_score4, 
         sum(acc.good_urlfr_sum_score5) / sum(acc.cnt_score5) as good_urlfr_share_score5,
         sum(acc.good_urlfr_sum_score6) / sum(acc.cnt_score6) as good_urlfr_share_score6,
         max(trim(pc.provider)) as mob_provider,
         max(r.ind) as ind,
         max(r.pop_country_share) as pop_country_share, 
         max(r.pop_city_share) as pop_city_share, 
         max(r.population / r.area_sq_km) as density,
         max(r.area_sq_km) as area_sq_km,
         max(trim(r.federal_district)) as federal_district, 
         max(r.avg_salary_2015_rub) as avg_salary_2015_rub, 
         max(r.utc_time_zone_val) as utc_time_zone_val


      from
         user_kposminin.ccall_aza_id a
         inner join user_kposminin.id_feat_accum acc on acc.id = a.id and acc.last_calc_ymd = date_add(a.call_ymd, -1)
         left join dds_dic.phone_codes pc on trim(pc.phone_code) = substr(a.phone_mobile,2,9)
         left join dds_dic.region_stat r on r.ind = pc.region_id
     group by
             a.phone_mobile,
             a.call_ymd
    ;


    '''
    
    def __init__(self, hc = None, n_threads = 10, init_query = True):
        import datetime
        if(init_query):
            self.query = self.init_query + self.create_accum_query
        else:
            self.query = ''
        
    def calc_days(self, days, merge = True, clean = True):
        ''' Calc 1d feat and accum it for days (datetime.datetime list)'''
        days = sorted(days)
        acc_first_calc_ymd, acc_last_calc_ymd = [days[0]] * 2
        for day in days:
            new_first_calc_ymd = min(day,acc_first_calc_ymd)
            new_last_calc_ymd  = max(day,acc_last_calc_ymd)
            
            self.query += self.feat_1d_query_pattern.replace('#ymd',day.strftime('%Y-%m-%d'))
            if merge & (days.index(day) > 0):
                self.query += (self.accumulator_merge_pattern 
                       .replace('#a_first_calc_ymd', acc_first_calc_ymd.strftime('%Y-%m-%d'))
                       .replace('#a_last_calc_ymd', acc_last_calc_ymd.strftime('%Y-%m-%d'))
                       .replace('#b_first_calc_ymd', day.strftime('%Y-%m-%d'))
                       .replace('#b_last_calc_ymd', day.strftime('%Y-%m-%d'))
                       .replace('#new_first_calc_ymd', new_first_calc_ymd.strftime('%Y-%m-%d'))
                       .replace('#new_last_calc_ymd',  new_last_calc_ymd.strftime('%Y-%m-%d'))
                               )
                if clean & (days.index(day) > 1):
                    self.query += (self.clear_partition_query 
                       .replace('#first_calc_ymd', acc_first_calc_ymd.strftime('%Y-%m-%d'))
                       .replace('#last_calc_ymd', acc_last_calc_ymd.strftime('%Y-%m-%d'))
                                  )
                if ((clean == 'full_clean') & (days.index(day) > 1)): 
                    self.query += (self.clear_partition_query 
                       .replace('#first_calc_ymd', day.strftime('%Y-%m-%d'))
                       .replace('#last_calc_ymd', day.strftime('%Y-%m-%d'))
                                  )
            acc_first_calc_ymd = new_first_calc_ymd
            acc_last_calc_ymd = new_last_calc_ymd
    
    def calc_day_range(self, first_day = None, last_day = None, n_days = None, merge = True, clean = True):        
        assert (first_day is None) + (last_day is None) + (n_days is None) == 1, '''calc_day_range Error:
              exactly two of three params must be filled: first_day, last_day, n_days'''.replace('\n',' ')
        if first_day is None:
            day_range = [last_day + datetime.timedelta(days = i) for i in range(-n_days + 1,1)]
        elif last_day is None:
            day_range = [first_day + datetime.timedelta(days = i) for i in range(n_days)]
        else:
            first_day,last_day = min(first_day,last_day), max(first_day,last_day)
            day_range = [first_day + datetime.timedelta(days = i) for i in range((last_day - first_day).days + 1)]
        self.calc_days(day_range, merge, clean)
        
    def get_query(self):
        return self.query

    def merge_days(self, day_tuples, clean = False):
        ''' day_tuples is a list of (first_day,last_day) to merge'''
        day_tuples = sorted(day_tuples)
        acc_first_calc_ymd, acc_last_calc_ymd = day_tuples[0]
        first = True
        for (first_day,last_day) in day_tuples[1:]:
            new_first_calc_ymd = min(first_day,acc_first_calc_ymd)
            new_last_calc_ymd  = max(last_day,acc_last_calc_ymd)
            self.query += (self.accumulator_merge_pattern 
                       .replace('#a_first_calc_ymd', acc_first_calc_ymd.strftime('%Y-%m-%d'))
                       .replace('#a_last_calc_ymd',   acc_last_calc_ymd.strftime('%Y-%m-%d'))
                       .replace('#b_first_calc_ymd', first_day.strftime('%Y-%m-%d'))
                       .replace('#b_last_calc_ymd',   last_day.strftime('%Y-%m-%d'))
                       .replace('#new_first_calc_ymd', new_first_calc_ymd.strftime('%Y-%m-%d'))
                       .replace('#new_last_calc_ymd',   new_last_calc_ymd.strftime('%Y-%m-%d'))
                               )
            if (not clean is False) & ((not first) or (clean == 'full_clean')):
                self.query += (self.clear_partition_query 
                       .replace('#first_calc_ymd', acc_first_calc_ymd.strftime('%Y-%m-%d'))
                       .replace('#last_calc_ymd',   acc_last_calc_ymd.strftime('%Y-%m-%d'))
                                  )
            if (clean == 'full_clean'): 
                self.query += (self.clear_partition_query 
                       .replace('#first_calc_ymd', first_day.strftime('%Y-%m-%d'))
                       .replace('#last_calc_ymd',   last_day.strftime('%Y-%m-%d'))
                                  )
            acc_first_calc_ymd = new_first_calc_ymd
            acc_last_calc_ymd = new_last_calc_ymd
            first = False
            
    def calc_full_feat(self):
        c.query += self.create_feat_table_query

# %%
#! nohup /opt/anaconda/bin/python cred_scor_feat_table_calc_4.py 2016-12-01 2016-12-15 > cred_scor_feat_table_calc_27.log 2>&1 &
#os.popen('beeline -u "jdbc:hive2://ds-hadoop-cs01p:10000/" -n kposminin -e "' + ' '.join(c.get_query().split(';')[30].split('\n')[5:])+ '"').read()

# %% [markdown]
# ### Тестирующий день 2016-04-29.

# %%
import datetime
c = calc_cred_score(hc)
c.calc_day_range(first_day = datetime.datetime(2017,2,28) ,last_day = datetime.datetime(2017,4,28),merge = True, clean = True)
print(c.get_query())
print('-'*100)
# Out:
#     set hive.vectorized.execution.enabled=true;
#     set mapreduce.map.memory.mb=4096;
#     set mapreduce.map.child.java.opts=-Xmx4g;
#     set mapreduce.task.io.sort.mb=1024;
#     set mapreduce.reduce.child.java.opts=-Xmx4g;
#     set mapreduce.reduce.memory.mb=7000;
#     set mapreduce.reduce.shuffle.input.buffer.percent=0.5;
#     set mapreduce.input.fileinputformat.split.minsize=536870912;
#     set mapreduce.input.fileinputformat.split.maxsize=1073741824;
#     set hive.optimize.ppd=true;
#     set hive.merge.smallfiles.avgsize=536870912;
#     set hive.merge.mapredfiles=true;
#     set hive.merge.mapfiles=true;
#     set hive.hadoop.supports.splittable.combineinputformat=true;
#     set hive.exec.reducers.bytes.per.reducer=536870912;
#     set hive.exec.parallel=true;
#     set hive.exec.max.created.files=10000000;
#     set hive.exec.compress.output=true;
#     set hive.exec.dynamic.partition.mode=nonstrict;
#     set hive.exec.max.dynamic.partitions=1000000;
#     set hive.exec.max.dynamic.partitions.pernode=100000;
#     set io.seqfile.compression.type=BLOCK;
#     set mapred.output.compression.codec=org.apache.hadoop.io.compress.BZip2Codec;
#     set mapreduce.map.failures.maxpercent=5;
#
#     set hive.tez.auto.reducer.parallelism=true;
#     set hive.tez.min.partition.factor=0.25;
#     set hive.tez.max.partition.factor=2.0;
#     set tez.runtime.pipelined.sorter.lazy-allocate.memory=true;
#     set hive.exec.dynamic.partition.mode=nonstrict;
#
#     CREATE TABLE IF NOT EXISTS `user_kposminin.id_feat_accum`(
#           `id` string,
#           `load_src` string,
#           `first_id_ymd` string,
#           `last_id_ymd` string,
#           `ymd_cnt` int,
#           `urlfr_cnt` bigint, -- `cnt` bigint,
#           `visits_cnt` bigint,
#           `hits` bigint,
#           `emailru_sum` bigint,
#           `mobile_sum` double,
#           `vk_sum` double,
#           `social_sum` double,
#           `work_hours_hits_sum` double,
#           `avg_hour_sum_sq` bigint,
#           `avg_hour_sum` bigint,
#           `max_score1` double,
#           `max_score2` double,
#           `max_score3` double,
#           `max_score4` double,
#           `max_score5` double,
#           `max_score6` double,
#           `min_score1` double,
#           `min_score2` double,
#           `min_score3` double,
#           `min_score4` double,
#           `min_score5` double,
#           `min_score6` double,
#           `sum_score1` double,
#           `sum_score2` double,
#           `sum_score3` double,
#           `sum_score4` double,
#           `sum_score5` double,
#           `sum_score6` double,
#           `cnt_score1` int,
#           `cnt_score2` int,
#           `cnt_score3` int,
#           `cnt_score4` int,
#           `cnt_score5` int,
#           `cnt_score6` int,
#           `good_urlfr_sum_score1` double,
#           `good_urlfr_sum_score2` double,
#           `good_urlfr_sum_score3` double,
#           `good_urlfr_sum_score4` double,
#           `good_urlfr_sum_score5` double,
#           `good_urlfr_sum_score6` double)
#     partitioned by (
#           `first_calc_ymd` string,
#           `last_calc_ymd` string
#           )
#     ;
#
#
#
#     -- 2017-02-28. Id_feats 1 day calc
#     with mymd as
#      (select
#        target,
#        max(ymd) as max_ymd
#       from
#        user_kposminin.urlfr_scores
#       where
#         ymd < date_add('2017-02-28',-3)
#       group by target
#      )
#
#     insert overwrite table user_kposminin.id_feat_accum partition (first_calc_ymd, last_calc_ymd)
#     select
#      id,
#      load_src,
#      ymd as first_id_ymd,
#      ymd as last_id_ymd,
#      1 as ymd_cnt,
#      count(distinct urlfr) as urlfr_cnt,
#      count(urlfr) as visits_cnt,
#      sum(cnt) as hits,
#      sum(if(urlfr like 'e.mail.ru%',1,0)) as emailru_sum,
#      sum(if(urlfr like 'm.%',1,0)) as mobile_sum,
#      sum(if(urlfr rlike '^(m\.)?vk.com', 1, 0)) as vk_sum,
#      sum(if(urlfr rlike '^(m\.)?vk.com' or urlfr rlike '^(m\.)?(ok|odnoklassniki)\.ru' or urlfr rlike '^(m\.)?my.mail.ru',1,0)) as social_sum,
#      sum(if(avg_hour >= 9 and avg_hour <= 20,cnt,0)) as work_hours_hits_sum,
#      sum( avg_hour * avg_hour) as avg_hour_sum_sq,
#      sum(avg_hour) as avg_hour_sum,
#      max(score1) as max_score1,
#      max(score2) as max_score2,
#      max(score3) as max_score3,
#      max(score4) as max_score4,
#      max(score5) as max_score5,
#      max(score6) as max_score6,
#      min(score1) as min_score1,
#      min(score2) as min_score2,
#      min(score3) as min_score3,
#      min(score4) as min_score4,
#      min(score5) as min_score5,
#      min(score6) as min_score6,
#      sum(score1) as sum_score1,
#      sum(score2) as sum_score2,
#      sum(score3) as sum_score3,
#      sum(score4) as sum_score4,
#      sum(score5) as sum_score5,
#      sum(score6) as sum_score6,
#      count(score1) as cnt_score1,
#      count(score2) as cnt_score2,
#      count(score3) as cnt_score3,
#      count(score4) as cnt_score4,
#      count(score5) as cnt_score5,
#      count(score6) as cnt_score6,
#      count( if(score1 > -0.2, urlfr,Null)) as good_urlfr_sum_score1,
#      count( if(score2 > -9, urlfr,Null)) as good_urlfr_sum_score2,
#      count( if(score3 > -9, urlfr,Null)) as good_urlfr_sum_score3,
#      count( if(score4 > -2, urlfr,Null)) as good_urlfr_sum_score4,
#      count( if(score5 > -9, urlfr,Null)) as good_urlfr_sum_score5,
#      count( if(score6 > -0.2, urlfr,Null)) as good_urlfr_sum_score6,
#      '2017-02-28' as first_calc_ymd,
#      '2017-02-28' as last_calc_ymd
#
#     from
#      (select
#         v.id,
#         'LI.02' as load_src, -- !!!! bug
#         v.ymd,
#         v.urlfr,
#         unix_timestamp(v.ymd, 'yyyy-MM-dd')/60/60 + v.avg_hour  as time_h,
#         1 as time_std,
#         v.cnt as cnt,
#         v.avg_hour as avg_hour,
#         t1.score as score1,
#         t2.score as score2,
#         t3.score as score3,
#         t4.score as score4,
#         t5.score as score5,
#         log((t2.cnt_positive + 0.1)/(t3.cnt_positive - t2.cnt_positive + 0.1)) as score6
#       from
#         user_kposminin.visits_cred_scor_calc_debug_20170429 v
#         left join (
#             select urlfr,score
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'ccall_tinkoff_approve_from_fullapp'
#         ) t1 on t1.urlfr = v.urlfr
#         left join (
#             select urlfr,score,positive as cnt_positive
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_platinum_approved_application03@tinkoff_action'
#         ) t2 on t2.urlfr = v.urlfr
#         left join (
#             select urlfr,score,positive as cnt_positive
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_platinum_complete_application03@tinkoff_action'
#         ) t3 on t3.urlfr = v.urlfr
#         left join (
#             select urlfr,score
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_LON_CCR_default'
#         ) t4 on t4.urlfr = v.urlfr
#         left join (
#             select urlfr,score
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_platinum_approved_application03_1m'
#         ) t5 on t5.urlfr = v.urlfr
#       where
#         v.ymd = '2017-02-28'
#      ) a
#     group by
#       id,load_src,ymd
#     ;
#
#
#     -- 2017-03-01. Id_feats 1 day calc
#     with mymd as
#      (select
#        target,
#        max(ymd) as max_ymd
#       from
#        user_kposminin.urlfr_scores
#       where
#         ymd < date_add('2017-03-01',-3)
#       group by target
#      )
#
#     insert overwrite table user_kposminin.id_feat_accum partition (first_calc_ymd, last_calc_ymd)
#     select
#      id,
#      load_src,
#      ymd as first_id_ymd,
#      ymd as last_id_ymd,
#      1 as ymd_cnt,
#      count(distinct urlfr) as urlfr_cnt,
#      count(urlfr) as visits_cnt,
#      sum(cnt) as hits,
#      sum(if(urlfr like 'e.mail.ru%',1,0)) as emailru_sum,
#      sum(if(urlfr like 'm.%',1,0)) as mobile_sum,
#      sum(if(urlfr rlike '^(m\.)?vk.com', 1, 0)) as vk_sum,
#      sum(if(urlfr rlike '^(m\.)?vk.com' or urlfr rlike '^(m\.)?(ok|odnoklassniki)\.ru' or urlfr rlike '^(m\.)?my.mail.ru',1,0)) as social_sum,
#      sum(if(avg_hour >= 9 and avg_hour <= 20,cnt,0)) as work_hours_hits_sum,
#      sum( avg_hour * avg_hour) as avg_hour_sum_sq,
#      sum(avg_hour) as avg_hour_sum,
#      max(score1) as max_score1,
#      max(score2) as max_score2,
#      max(score3) as max_score3,
#      max(score4) as max_score4,
#      max(score5) as max_score5,
#      max(score6) as max_score6,
#      min(score1) as min_score1,
#      min(score2) as min_score2,
#      min(score3) as min_score3,
#      min(score4) as min_score4,
#      min(score5) as min_score5,
#      min(score6) as min_score6,
#      sum(score1) as sum_score1,
#      sum(score2) as sum_score2,
#      sum(score3) as sum_score3,
#      sum(score4) as sum_score4,
#      sum(score5) as sum_score5,
#      sum(score6) as sum_score6,
#      count(score1) as cnt_score1,
#      count(score2) as cnt_score2,
#      count(score3) as cnt_score3,
#      count(score4) as cnt_score4,
#      count(score5) as cnt_score5,
#      count(score6) as cnt_score6,
#      count( if(score1 > -0.2, urlfr,Null)) as good_urlfr_sum_score1,
#      count( if(score2 > -9, urlfr,Null)) as good_urlfr_sum_score2,
#      count( if(score3 > -9, urlfr,Null)) as good_urlfr_sum_score3,
#      count( if(score4 > -2, urlfr,Null)) as good_urlfr_sum_score4,
#      count( if(score5 > -9, urlfr,Null)) as good_urlfr_sum_score5,
#      count( if(score6 > -0.2, urlfr,Null)) as good_urlfr_sum_score6,
#      '2017-03-01' as first_calc_ymd,
#      '2017-03-01' as last_calc_ymd
#
#     from
#      (select
#         v.id,
#         'LI.02' as load_src, -- !!!! bug
#         v.ymd,
#         v.urlfr,
#         unix_timestamp(v.ymd, 'yyyy-MM-dd')/60/60 + v.avg_hour  as time_h,
#         1 as time_std,
#         v.cnt as cnt,
#         v.avg_hour as avg_hour,
#         t1.score as score1,
#         t2.score as score2,
#         t3.score as score3,
#         t4.score as score4,
#         t5.score as score5,
#         log((t2.cnt_positive + 0.1)/(t3.cnt_positive - t2.cnt_positive + 0.1)) as score6
#       from
#         user_kposminin.visits_cred_scor_calc_debug_20170429 v
#         left join (
#             select urlfr,score
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'ccall_tinkoff_approve_from_fullapp'
#         ) t1 on t1.urlfr = v.urlfr
#         left join (
#             select urlfr,score,positive as cnt_positive
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_platinum_approved_application03@tinkoff_action'
#         ) t2 on t2.urlfr = v.urlfr
#         left join (
#             select urlfr,score,positive as cnt_positive
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_platinum_complete_application03@tinkoff_action'
#         ) t3 on t3.urlfr = v.urlfr
#         left join (
#             select urlfr,score
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_LON_CCR_default'
#         ) t4 on t4.urlfr = v.urlfr
#         left join (
#             select urlfr,score
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_platinum_approved_application03_1m'
#         ) t5 on t5.urlfr = v.urlfr
#       where
#         v.ymd = '2017-03-01'
#      ) a
#     group by
#       id,load_src,ymd
#     ;
#
#
#     insert overwrite table user_kposminin.id_feat_accum partition (first_calc_ymd,last_calc_ymd)
#     select
#       nvl(a.id,b.id) as id,
#       nvl(a.load_src,b.load_src) as load_src,
#       least(a.first_id_ymd,b.first_id_ymd) as first_id_ymd,
#       greatest(a.last_id_ymd,b.last_id_ymd) as last_id_ymd,
#       nvl(a.ymd_cnt,0) + nvl(b.ymd_cnt,0) as ymd_cnt,
#       nvl(a.urlfr_cnt,0) + nvl(b.urlfr_cnt,0) as urlfr_cnt,
#       nvl(a.visits_cnt,0) + nvl(b.visits_cnt,0) as visits_cnt,
#       nvl(a.hits,0) + nvl(b.hits,0) as hits,
#       nvl(a.emailru_sum,0) + nvl(b.emailru_sum,0) as emailru_sum,
#       nvl(a.mobile_sum,0) + nvl(b.mobile_sum,0) as mobile_sum,
#       nvl(a.vk_sum,0) + nvl(b.vk_sum,0) as vk_sum,
#       nvl(a.social_sum,0) + nvl(b.social_sum,0) as social_sum,
#       nvl(a.work_hours_hits_sum,0) + nvl(b.work_hours_hits_sum,0) as work_hours_hits_sum,
#       nvl(a.avg_hour_sum_sq,0) + nvl(b.avg_hour_sum_sq,0) as avg_hour_sum_sq,
#       nvl(a.avg_hour_sum,0) + nvl(b.avg_hour_sum,0) as avg_hour_sum,
#       greatest(a.max_score1,b.max_score1) as max_score1,
#       greatest(a.max_score2,b.max_score2) as max_score2,
#       greatest(a.max_score3,b.max_score3) as max_score3,
#       greatest(a.max_score4,b.max_score4) as max_score4,
#       greatest(a.max_score5,b.max_score5) as max_score5,
#       greatest(a.max_score6,b.max_score6) as max_score6,
#       least(a.min_score1, b.min_score1) as min_score1,
#       least(a.min_score2, b.min_score2) as min_score2,
#       least(a.min_score3, b.min_score3) as min_score3,
#       least(a.min_score4, b.min_score4) as min_score4,
#       least(a.min_score5, b.min_score5) as min_score5,
#       least(a.min_score6, b.min_score6) as min_score6,
#       nvl(a.sum_score1,0) + nvl(b.sum_score1,0) as sum_score1,
#       nvl(a.sum_score2,0) + nvl(b.sum_score2,0) as sum_score2,
#       nvl(a.sum_score3,0) + nvl(b.sum_score3,0) as sum_score3,
#       nvl(a.sum_score4,0) + nvl(b.sum_score4,0) as sum_score4,
#       nvl(a.sum_score5,0) + nvl(b.sum_score5,0) as sum_score5,
#       nvl(a.sum_score6,0) + nvl(b.sum_score6,0) as sum_score6,
#       nvl(a.cnt_score1,0) + nvl(b.cnt_score1,0) as cnt_score1,
#       nvl(a.cnt_score2,0) + nvl(b.cnt_score2,0) as cnt_score2,
#       nvl(a.cnt_score3,0) + nvl(b.cnt_score3,0) as cnt_score3,
#       nvl(a.cnt_score4,0) + nvl(b.cnt_score4,0) as cnt_score4,
#       nvl(a.cnt_score5,0) + nvl(b.cnt_score5,0) as cnt_score5,
#       nvl(a.cnt_score6,0) + nvl(b.cnt_score6,0) as cnt_score6,
#       nvl(a.good_urlfr_sum_score1,0) + nvl(b.good_urlfr_sum_score1,0) as good_urlfr_sum_score1,
#       nvl(a.good_urlfr_sum_score2,0) + nvl(b.good_urlfr_sum_score2,0) as good_urlfr_sum_score2,
#       nvl(a.good_urlfr_sum_score3,0) + nvl(b.good_urlfr_sum_score3,0) as good_urlfr_sum_score3,
#       nvl(a.good_urlfr_sum_score4,0) + nvl(b.good_urlfr_sum_score4,0) as good_urlfr_sum_score4,
#       nvl(a.good_urlfr_sum_score5,0) + nvl(b.good_urlfr_sum_score5,0) as good_urlfr_sum_score5,
#       nvl(a.good_urlfr_sum_score6,0) + nvl(b.good_urlfr_sum_score6,0) as good_urlfr_sum_score6,
#       '2017-02-28' as first_calc_ymd,
#       '2017-03-01' as last_calc_ymd
#     from
#       (select * from user_kposminin.id_feat_accum a where a.first_calc_ymd = '2017-02-28' and a.last_calc_ymd = '2017-02-28') a
#       full join (select * from user_kposminin.id_feat_accum b where b.first_calc_ymd = '2017-03-01' and b.last_calc_ymd = '2017-03-01') b
#         on a.id = b.id and a.load_src = b.load_src
#     ;
#
#
#
#
#     -- 2017-03-02. Id_feats 1 day calc
#     with mymd as
#      (select
#        target,
#        max(ymd) as max_ymd
#       from
#        user_kposminin.urlfr_scores
#       where
#         ymd < date_add('2017-03-02',-3)
#       group by target
#      )
#
#     insert overwrite table user_kposminin.id_feat_accum partition (first_calc_ymd, last_calc_ymd)
#     select
#      id,
#      load_src,
#      ymd as first_id_ymd,
#      ymd as last_id_ymd,
#      1 as ymd_cnt,
#      count(distinct urlfr) as urlfr_cnt,
#      count(urlfr) as visits_cnt,
#      sum(cnt) as hits,
#      sum(if(urlfr like 'e.mail.ru%',1,0)) as emailru_sum,
#      sum(if(urlfr like 'm.%',1,0)) as mobile_sum,
#      sum(if(urlfr rlike '^(m\.)?vk.com', 1, 0)) as vk_sum,
#      sum(if(urlfr rlike '^(m\.)?vk.com' or urlfr rlike '^(m\.)?(ok|odnoklassniki)\.ru' or urlfr rlike '^(m\.)?my.mail.ru',1,0)) as social_sum,
#      sum(if(avg_hour >= 9 and avg_hour <= 20,cnt,0)) as work_hours_hits_sum,
#      sum( avg_hour * avg_hour) as avg_hour_sum_sq,
#      sum(avg_hour) as avg_hour_sum,
#      max(score1) as max_score1,
#      max(score2) as max_score2,
#      max(score3) as max_score3,
#      max(score4) as max_score4,
#      max(score5) as max_score5,
#      max(score6) as max_score6,
#      min(score1) as min_score1,
#      min(score2) as min_score2,
#      min(score3) as min_score3,
#      min(score4) as min_score4,
#      min(score5) as min_score5,
#      min(score6) as min_score6,
#      sum(score1) as sum_score1,
#      sum(score2) as sum_score2,
#      sum(score3) as sum_score3,
#      sum(score4) as sum_score4,
#      sum(score5) as sum_score5,
#      sum(score6) as sum_score6,
#      count(score1) as cnt_score1,
#      count(score2) as cnt_score2,
#      count(score3) as cnt_score3,
#      count(score4) as cnt_score4,
#      count(score5) as cnt_score5,
#      count(score6) as cnt_score6,
#      count( if(score1 > -0.2, urlfr,Null)) as good_urlfr_sum_score1,
#      count( if(score2 > -9, urlfr,Null)) as good_urlfr_sum_score2,
#      count( if(score3 > -9, urlfr,Null)) as good_urlfr_sum_score3,
#      count( if(score4 > -2, urlfr,Null)) as good_urlfr_sum_score4,
#      count( if(score5 > -9, urlfr,Null)) as good_urlfr_sum_score5,
#      count( if(score6 > -0.2, urlfr,Null)) as good_urlfr_sum_score6,
#      '2017-03-02' as first_calc_ymd,
#      '2017-03-02' as last_calc_ymd
#
#     from
#      (select
#         v.id,
#         'LI.02' as load_src, -- !!!! bug
#         v.ymd,
#         v.urlfr,
#         unix_timestamp(v.ymd, 'yyyy-MM-dd')/60/60 + v.avg_hour  as time_h,
#         1 as time_std,
#         v.cnt as cnt,
#         v.avg_hour as avg_hour,
#         t1.score as score1,
#         t2.score as score2,
#         t3.score as score3,
#         t4.score as score4,
#         t5.score as score5,
#         log((t2.cnt_positive + 0.1)/(t3.cnt_positive - t2.cnt_positive + 0.1)) as score6
#       from
#         user_kposminin.visits_cred_scor_calc_debug_20170429 v
#         left join (
#             select urlfr,score
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'ccall_tinkoff_approve_from_fullapp'
#         ) t1 on t1.urlfr = v.urlfr
#         left join (
#             select urlfr,score,positive as cnt_positive
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_platinum_approved_application03@tinkoff_action'
#         ) t2 on t2.urlfr = v.urlfr
#         left join (
#             select urlfr,score,positive as cnt_positive
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_platinum_complete_application03@tinkoff_action'
#         ) t3 on t3.urlfr = v.urlfr
#         left join (
#             select urlfr,score
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_LON_CCR_default'
#         ) t4 on t4.urlfr = v.urlfr
#         left join (
#             select urlfr,score
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_platinum_approved_application03_1m'
#         ) t5 on t5.urlfr = v.urlfr
#       where
#         v.ymd = '2017-03-02'
#      ) a
#     group by
#       id,load_src,ymd
#     ;
#
#
#     insert overwrite table user_kposminin.id_feat_accum partition (first_calc_ymd,last_calc_ymd)
#     select
#       nvl(a.id,b.id) as id,
#       nvl(a.load_src,b.load_src) as load_src,
#       least(a.first_id_ymd,b.first_id_ymd) as first_id_ymd,
#       greatest(a.last_id_ymd,b.last_id_ymd) as last_id_ymd,
#       nvl(a.ymd_cnt,0) + nvl(b.ymd_cnt,0) as ymd_cnt,
#       nvl(a.urlfr_cnt,0) + nvl(b.urlfr_cnt,0) as urlfr_cnt,
#       nvl(a.visits_cnt,0) + nvl(b.visits_cnt,0) as visits_cnt,
#       nvl(a.hits,0) + nvl(b.hits,0) as hits,
#       nvl(a.emailru_sum,0) + nvl(b.emailru_sum,0) as emailru_sum,
#       nvl(a.mobile_sum,0) + nvl(b.mobile_sum,0) as mobile_sum,
#       nvl(a.vk_sum,0) + nvl(b.vk_sum,0) as vk_sum,
#       nvl(a.social_sum,0) + nvl(b.social_sum,0) as social_sum,
#       nvl(a.work_hours_hits_sum,0) + nvl(b.work_hours_hits_sum,0) as work_hours_hits_sum,
#       nvl(a.avg_hour_sum_sq,0) + nvl(b.avg_hour_sum_sq,0) as avg_hour_sum_sq,
#       nvl(a.avg_hour_sum,0) + nvl(b.avg_hour_sum,0) as avg_hour_sum,
#       greatest(a.max_score1,b.max_score1) as max_score1,
#       greatest(a.max_score2,b.max_score2) as max_score2,
#       greatest(a.max_score3,b.max_score3) as max_score3,
#       greatest(a.max_score4,b.max_score4) as max_score4,
#       greatest(a.max_score5,b.max_score5) as max_score5,
#       greatest(a.max_score6,b.max_score6) as max_score6,
#       least(a.min_score1, b.min_score1) as min_score1,
#       least(a.min_score2, b.min_score2) as min_score2,
#       least(a.min_score3, b.min_score3) as min_score3,
#       least(a.min_score4, b.min_score4) as min_score4,
#       least(a.min_score5, b.min_score5) as min_score5,
#       least(a.min_score6, b.min_score6) as min_score6,
#       nvl(a.sum_score1,0) + nvl(b.sum_score1,0) as sum_score1,
#       nvl(a.sum_score2,0) + nvl(b.sum_score2,0) as sum_score2,
#       nvl(a.sum_score3,0) + nvl(b.sum_score3,0) as sum_score3,
#       nvl(a.sum_score4,0) + nvl(b.sum_score4,0) as sum_score4,
#       nvl(a.sum_score5,0) + nvl(b.sum_score5,0) as sum_score5,
#       nvl(a.sum_score6,0) + nvl(b.sum_score6,0) as sum_score6,
#       nvl(a.cnt_score1,0) + nvl(b.cnt_score1,0) as cnt_score1,
#       nvl(a.cnt_score2,0) + nvl(b.cnt_score2,0) as cnt_score2,
#       nvl(a.cnt_score3,0) + nvl(b.cnt_score3,0) as cnt_score3,
#       nvl(a.cnt_score4,0) + nvl(b.cnt_score4,0) as cnt_score4,
#       nvl(a.cnt_score5,0) + nvl(b.cnt_score5,0) as cnt_score5,
#       nvl(a.cnt_score6,0) + nvl(b.cnt_score6,0) as cnt_score6,
#       nvl(a.good_urlfr_sum_score1,0) + nvl(b.good_urlfr_sum_score1,0) as good_urlfr_sum_score1,
#       nvl(a.good_urlfr_sum_score2,0) + nvl(b.good_urlfr_sum_score2,0) as good_urlfr_sum_score2,
#       nvl(a.good_urlfr_sum_score3,0) + nvl(b.good_urlfr_sum_score3,0) as good_urlfr_sum_score3,
#       nvl(a.good_urlfr_sum_score4,0) + nvl(b.good_urlfr_sum_score4,0) as good_urlfr_sum_score4,
#       nvl(a.good_urlfr_sum_score5,0) + nvl(b.good_urlfr_sum_score5,0) as good_urlfr_sum_score5,
#       nvl(a.good_urlfr_sum_score6,0) + nvl(b.good_urlfr_sum_score6,0) as good_urlfr_sum_score6,
#       '2017-02-28' as first_calc_ymd,
#       '2017-03-02' as last_calc_ymd
#     from
#       (select * from user_kposminin.id_feat_accum a where a.first_calc_ymd = '2017-02-28' and a.last_calc_ymd = '2017-03-01') a
#       full join (select * from user_kposminin.id_feat_accum b where b.first_calc_ymd = '2017-03-02' and b.last_calc_ymd = '2017-03-02') b
#         on a.id = b.id and a.load_src = b.load_src
#     ;
#
#
#
#     alter table user_kposminin.id_feat_accum drop partition (first_calc_ymd = '2017-02-28', last_calc_ymd = '2017-03-01');
#
#
#     -- 2017-03-03. Id_feats 1 day calc
#     with mymd as
#      (select
#        target,
#        max(ymd) as max_ymd
#       from
#        user_kposminin.urlfr_scores
#       where
#         ymd < date_add('2017-03-03',-3)
#       group by target
#      )
#
#     insert overwrite table user_kposminin.id_feat_accum partition (first_calc_ymd, last_calc_ymd)
#     select
#      id,
#      load_src,
#      ymd as first_id_ymd,
#      ymd as last_id_ymd,
#      1 as ymd_cnt,
#      count(distinct urlfr) as urlfr_cnt,
#      count(urlfr) as visits_cnt,
#      sum(cnt) as hits,
#      sum(if(urlfr like 'e.mail.ru%',1,0)) as emailru_sum,
#      sum(if(urlfr like 'm.%',1,0)) as mobile_sum,
#      sum(if(urlfr rlike '^(m\.)?vk.com', 1, 0)) as vk_sum,
#      sum(if(urlfr rlike '^(m\.)?vk.com' or urlfr rlike '^(m\.)?(ok|odnoklassniki)\.ru' or urlfr rlike '^(m\.)?my.mail.ru',1,0)) as social_sum,
#      sum(if(avg_hour >= 9 and avg_hour <= 20,cnt,0)) as work_hours_hits_sum,
#      sum( avg_hour * avg_hour) as avg_hour_sum_sq,
#      sum(avg_hour) as avg_hour_sum,
#      max(score1) as max_score1,
#      max(score2) as max_score2,
#      max(score3) as max_score3,
#      max(score4) as max_score4,
#      max(score5) as max_score5,
#      max(score6) as max_score6,
#      min(score1) as min_score1,
#      min(score2) as min_score2,
#      min(score3) as min_score3,
#      min(score4) as min_score4,
#      min(score5) as min_score5,
#      min(score6) as min_score6,
#      sum(score1) as sum_score1,
#      sum(score2) as sum_score2,
#      sum(score3) as sum_score3,
#      sum(score4) as sum_score4,
#      sum(score5) as sum_score5,
#      sum(score6) as sum_score6,
#      count(score1) as cnt_score1,
#      count(score2) as cnt_score2,
#      count(score3) as cnt_score3,
#      count(score4) as cnt_score4,
#      count(score5) as cnt_score5,
#      count(score6) as cnt_score6,
#      count( if(score1 > -0.2, urlfr,Null)) as good_urlfr_sum_score1,
#      count( if(score2 > -9, urlfr,Null)) as good_urlfr_sum_score2,
#      count( if(score3 > -9, urlfr,Null)) as good_urlfr_sum_score3,
#      count( if(score4 > -2, urlfr,Null)) as good_urlfr_sum_score4,
#      count( if(score5 > -9, urlfr,Null)) as good_urlfr_sum_score5,
#      count( if(score6 > -0.2, urlfr,Null)) as good_urlfr_sum_score6,
#      '2017-03-03' as first_calc_ymd,
#      '2017-03-03' as last_calc_ymd
#
#     from
#      (select
#         v.id,
#         'LI.02' as load_src, -- !!!! bug
#         v.ymd,
#         v.urlfr,
#         unix_timestamp(v.ymd, 'yyyy-MM-dd')/60/60 + v.avg_hour  as time_h,
#         1 as time_std,
#         v.cnt as cnt,
#         v.avg_hour as avg_hour,
#         t1.score as score1,
#         t2.score as score2,
#         t3.score as score3,
#         t4.score as score4,
#         t5.score as score5,
#         log((t2.cnt_positive + 0.1)/(t3.cnt_positive - t2.cnt_positive + 0.1)) as score6
#       from
#         user_kposminin.visits_cred_scor_calc_debug_20170429 v
#         left join (
#             select urlfr,score
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'ccall_tinkoff_approve_from_fullapp'
#         ) t1 on t1.urlfr = v.urlfr
#         left join (
#             select urlfr,score,positive as cnt_positive
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_platinum_approved_application03@tinkoff_action'
#         ) t2 on t2.urlfr = v.urlfr
#         left join (
#             select urlfr,score,positive as cnt_positive
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_platinum_complete_application03@tinkoff_action'
#         ) t3 on t3.urlfr = v.urlfr
#         left join (
#             select urlfr,score
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_LON_CCR_default'
#         ) t4 on t4.urlfr = v.urlfr
#         left join (
#             select urlfr,score
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_platinum_approved_application03_1m'
#         ) t5 on t5.urlfr = v.urlfr
#       where
#         v.ymd = '2017-03-03'
#      ) a
#     group by
#       id,load_src,ymd
#     ;
#
#
#     insert overwrite table user_kposminin.id_feat_accum partition (first_calc_ymd,last_calc_ymd)
#     select
#       nvl(a.id,b.id) as id,
#       nvl(a.load_src,b.load_src) as load_src,
#       least(a.first_id_ymd,b.first_id_ymd) as first_id_ymd,
#       greatest(a.last_id_ymd,b.last_id_ymd) as last_id_ymd,
#       nvl(a.ymd_cnt,0) + nvl(b.ymd_cnt,0) as ymd_cnt,
#       nvl(a.urlfr_cnt,0) + nvl(b.urlfr_cnt,0) as urlfr_cnt,
#       nvl(a.visits_cnt,0) + nvl(b.visits_cnt,0) as visits_cnt,
#       nvl(a.hits,0) + nvl(b.hits,0) as hits,
#       nvl(a.emailru_sum,0) + nvl(b.emailru_sum,0) as emailru_sum,
#       nvl(a.mobile_sum,0) + nvl(b.mobile_sum,0) as mobile_sum,
#       nvl(a.vk_sum,0) + nvl(b.vk_sum,0) as vk_sum,
#       nvl(a.social_sum,0) + nvl(b.social_sum,0) as social_sum,
#       nvl(a.work_hours_hits_sum,0) + nvl(b.work_hours_hits_sum,0) as work_hours_hits_sum,
#       nvl(a.avg_hour_sum_sq,0) + nvl(b.avg_hour_sum_sq,0) as avg_hour_sum_sq,
#       nvl(a.avg_hour_sum,0) + nvl(b.avg_hour_sum,0) as avg_hour_sum,
#       greatest(a.max_score1,b.max_score1) as max_score1,
#       greatest(a.max_score2,b.max_score2) as max_score2,
#       greatest(a.max_score3,b.max_score3) as max_score3,
#       greatest(a.max_score4,b.max_score4) as max_score4,
#       greatest(a.max_score5,b.max_score5) as max_score5,
#       greatest(a.max_score6,b.max_score6) as max_score6,
#       least(a.min_score1, b.min_score1) as min_score1,
#       least(a.min_score2, b.min_score2) as min_score2,
#       least(a.min_score3, b.min_score3) as min_score3,
#       least(a.min_score4, b.min_score4) as min_score4,
#       least(a.min_score5, b.min_score5) as min_score5,
#       least(a.min_score6, b.min_score6) as min_score6,
#       nvl(a.sum_score1,0) + nvl(b.sum_score1,0) as sum_score1,
#       nvl(a.sum_score2,0) + nvl(b.sum_score2,0) as sum_score2,
#       nvl(a.sum_score3,0) + nvl(b.sum_score3,0) as sum_score3,
#       nvl(a.sum_score4,0) + nvl(b.sum_score4,0) as sum_score4,
#       nvl(a.sum_score5,0) + nvl(b.sum_score5,0) as sum_score5,
#       nvl(a.sum_score6,0) + nvl(b.sum_score6,0) as sum_score6,
#       nvl(a.cnt_score1,0) + nvl(b.cnt_score1,0) as cnt_score1,
#       nvl(a.cnt_score2,0) + nvl(b.cnt_score2,0) as cnt_score2,
#       nvl(a.cnt_score3,0) + nvl(b.cnt_score3,0) as cnt_score3,
#       nvl(a.cnt_score4,0) + nvl(b.cnt_score4,0) as cnt_score4,
#       nvl(a.cnt_score5,0) + nvl(b.cnt_score5,0) as cnt_score5,
#       nvl(a.cnt_score6,0) + nvl(b.cnt_score6,0) as cnt_score6,
#       nvl(a.good_urlfr_sum_score1,0) + nvl(b.good_urlfr_sum_score1,0) as good_urlfr_sum_score1,
#       nvl(a.good_urlfr_sum_score2,0) + nvl(b.good_urlfr_sum_score2,0) as good_urlfr_sum_score2,
#       nvl(a.good_urlfr_sum_score3,0) + nvl(b.good_urlfr_sum_score3,0) as good_urlfr_sum_score3,
#       nvl(a.good_urlfr_sum_score4,0) + nvl(b.good_urlfr_sum_score4,0) as good_urlfr_sum_score4,
#       nvl(a.good_urlfr_sum_score5,0) + nvl(b.good_urlfr_sum_score5,0) as good_urlfr_sum_score5,
#       nvl(a.good_urlfr_sum_score6,0) + nvl(b.good_urlfr_sum_score6,0) as good_urlfr_sum_score6,
#       '2017-02-28' as first_calc_ymd,
#       '2017-03-03' as last_calc_ymd
#     from
#       (select * from user_kposminin.id_feat_accum a where a.first_calc_ymd = '2017-02-28' and a.last_calc_ymd = '2017-03-02') a
#       full join (select * from user_kposminin.id_feat_accum b where b.first_calc_ymd = '2017-03-03' and b.last_calc_ymd = '2017-03-03') b
#         on a.id = b.id and a.load_src = b.load_src
#     ;
#
#
#
#     alter table user_kposminin.id_feat_accum drop partition (first_calc_ymd = '2017-02-28', last_calc_ymd = '2017-03-02');
#
#
#     -- 2017-03-04. Id_feats 1 day calc
#     with mymd as
#      (select
#        target,
#        max(ymd) as max_ymd
#       from
#        user_kposminin.urlfr_scores
#       where
#         ymd < date_add('2017-03-04',-3)
#       group by target
#      )
#
#     insert overwrite table user_kposminin.id_feat_accum partition (first_calc_ymd, last_calc_ymd)
#     select
#      id,
#      load_src,
#      ymd as first_id_ymd,
#      ymd as last_id_ymd,
#      1 as ymd_cnt,
#      count(distinct urlfr) as urlfr_cnt,
#      count(urlfr) as visits_cnt,
#      sum(cnt) as hits,
#      sum(if(urlfr like 'e.mail.ru%',1,0)) as emailru_sum,
#      sum(if(urlfr like 'm.%',1,0)) as mobile_sum,
#      sum(if(urlfr rlike '^(m\.)?vk.com', 1, 0)) as vk_sum,
#      sum(if(urlfr rlike '^(m\.)?vk.com' or urlfr rlike '^(m\.)?(ok|odnoklassniki)\.ru' or urlfr rlike '^(m\.)?my.mail.ru',1,0)) as social_sum,
#      sum(if(avg_hour >= 9 and avg_hour <= 20,cnt,0)) as work_hours_hits_sum,
#      sum( avg_hour * avg_hour) as avg_hour_sum_sq,
#      sum(avg_hour) as avg_hour_sum,
#      max(score1) as max_score1,
#      max(score2) as max_score2,
#      max(score3) as max_score3,
#      max(score4) as max_score4,
#      max(score5) as max_score5,
#      max(score6) as max_score6,
#      min(score1) as min_score1,
#      min(score2) as min_score2,
#      min(score3) as min_score3,
#      min(score4) as min_score4,
#      min(score5) as min_score5,
#      min(score6) as min_score6,
#      sum(score1) as sum_score1,
#      sum(score2) as sum_score2,
#      sum(score3) as sum_score3,
#      sum(score4) as sum_score4,
#      sum(score5) as sum_score5,
#      sum(score6) as sum_score6,
#      count(score1) as cnt_score1,
#      count(score2) as cnt_score2,
#      count(score3) as cnt_score3,
#      count(score4) as cnt_score4,
#      count(score5) as cnt_score5,
#      count(score6) as cnt_score6,
#      count( if(score1 > -0.2, urlfr,Null)) as good_urlfr_sum_score1,
#      count( if(score2 > -9, urlfr,Null)) as good_urlfr_sum_score2,
#      count( if(score3 > -9, urlfr,Null)) as good_urlfr_sum_score3,
#      count( if(score4 > -2, urlfr,Null)) as good_urlfr_sum_score4,
#      count( if(score5 > -9, urlfr,Null)) as good_urlfr_sum_score5,
#      count( if(score6 > -0.2, urlfr,Null)) as good_urlfr_sum_score6,
#      '2017-03-04' as first_calc_ymd,
#      '2017-03-04' as last_calc_ymd
#
#     from
#      (select
#         v.id,
#         'LI.02' as load_src, -- !!!! bug
#         v.ymd,
#         v.urlfr,
#         unix_timestamp(v.ymd, 'yyyy-MM-dd')/60/60 + v.avg_hour  as time_h,
#         1 as time_std,
#         v.cnt as cnt,
#         v.avg_hour as avg_hour,
#         t1.score as score1,
#         t2.score as score2,
#         t3.score as score3,
#         t4.score as score4,
#         t5.score as score5,
#         log((t2.cnt_positive + 0.1)/(t3.cnt_positive - t2.cnt_positive + 0.1)) as score6
#       from
#         user_kposminin.visits_cred_scor_calc_debug_20170429 v
#         left join (
#             select urlfr,score
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'ccall_tinkoff_approve_from_fullapp'
#         ) t1 on t1.urlfr = v.urlfr
#         left join (
#             select urlfr,score,positive as cnt_positive
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_platinum_approved_application03@tinkoff_action'
#         ) t2 on t2.urlfr = v.urlfr
#         left join (
#             select urlfr,score,positive as cnt_positive
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_platinum_complete_application03@tinkoff_action'
#         ) t3 on t3.urlfr = v.urlfr
#         left join (
#             select urlfr,score
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_LON_CCR_default'
#         ) t4 on t4.urlfr = v.urlfr
#         left join (
#             select urlfr,score
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_platinum_approved_application03_1m'
#         ) t5 on t5.urlfr = v.urlfr
#       where
#         v.ymd = '2017-03-04'
#      ) a
#     group by
#       id,load_src,ymd
#     ;
#
#
#     insert overwrite table user_kposminin.id_feat_accum partition (first_calc_ymd,last_calc_ymd)
#     select
#       nvl(a.id,b.id) as id,
#       nvl(a.load_src,b.load_src) as load_src,
#       least(a.first_id_ymd,b.first_id_ymd) as first_id_ymd,
#       greatest(a.last_id_ymd,b.last_id_ymd) as last_id_ymd,
#       nvl(a.ymd_cnt,0) + nvl(b.ymd_cnt,0) as ymd_cnt,
#       nvl(a.urlfr_cnt,0) + nvl(b.urlfr_cnt,0) as urlfr_cnt,
#       nvl(a.visits_cnt,0) + nvl(b.visits_cnt,0) as visits_cnt,
#       nvl(a.hits,0) + nvl(b.hits,0) as hits,
#       nvl(a.emailru_sum,0) + nvl(b.emailru_sum,0) as emailru_sum,
#       nvl(a.mobile_sum,0) + nvl(b.mobile_sum,0) as mobile_sum,
#       nvl(a.vk_sum,0) + nvl(b.vk_sum,0) as vk_sum,
#       nvl(a.social_sum,0) + nvl(b.social_sum,0) as social_sum,
#       nvl(a.work_hours_hits_sum,0) + nvl(b.work_hours_hits_sum,0) as work_hours_hits_sum,
#       nvl(a.avg_hour_sum_sq,0) + nvl(b.avg_hour_sum_sq,0) as avg_hour_sum_sq,
#       nvl(a.avg_hour_sum,0) + nvl(b.avg_hour_sum,0) as avg_hour_sum,
#       greatest(a.max_score1,b.max_score1) as max_score1,
#       greatest(a.max_score2,b.max_score2) as max_score2,
#       greatest(a.max_score3,b.max_score3) as max_score3,
#       greatest(a.max_score4,b.max_score4) as max_score4,
#       greatest(a.max_score5,b.max_score5) as max_score5,
#       greatest(a.max_score6,b.max_score6) as max_score6,
#       least(a.min_score1, b.min_score1) as min_score1,
#       least(a.min_score2, b.min_score2) as min_score2,
#       least(a.min_score3, b.min_score3) as min_score3,
#       least(a.min_score4, b.min_score4) as min_score4,
#       least(a.min_score5, b.min_score5) as min_score5,
#       least(a.min_score6, b.min_score6) as min_score6,
#       nvl(a.sum_score1,0) + nvl(b.sum_score1,0) as sum_score1,
#       nvl(a.sum_score2,0) + nvl(b.sum_score2,0) as sum_score2,
#       nvl(a.sum_score3,0) + nvl(b.sum_score3,0) as sum_score3,
#       nvl(a.sum_score4,0) + nvl(b.sum_score4,0) as sum_score4,
#       nvl(a.sum_score5,0) + nvl(b.sum_score5,0) as sum_score5,
#       nvl(a.sum_score6,0) + nvl(b.sum_score6,0) as sum_score6,
#       nvl(a.cnt_score1,0) + nvl(b.cnt_score1,0) as cnt_score1,
#       nvl(a.cnt_score2,0) + nvl(b.cnt_score2,0) as cnt_score2,
#       nvl(a.cnt_score3,0) + nvl(b.cnt_score3,0) as cnt_score3,
#       nvl(a.cnt_score4,0) + nvl(b.cnt_score4,0) as cnt_score4,
#       nvl(a.cnt_score5,0) + nvl(b.cnt_score5,0) as cnt_score5,
#       nvl(a.cnt_score6,0) + nvl(b.cnt_score6,0) as cnt_score6,
#       nvl(a.good_urlfr_sum_score1,0) + nvl(b.good_urlfr_sum_score1,0) as good_urlfr_sum_score1,
#       nvl(a.good_urlfr_sum_score2,0) + nvl(b.good_urlfr_sum_score2,0) as good_urlfr_sum_score2,
#       nvl(a.good_urlfr_sum_score3,0) + nvl(b.good_urlfr_sum_score3,0) as good_urlfr_sum_score3,
#       nvl(a.good_urlfr_sum_score4,0) + nvl(b.good_urlfr_sum_score4,0) as good_urlfr_sum_score4,
#       nvl(a.good_urlfr_sum_score5,0) + nvl(b.good_urlfr_sum_score5,0) as good_urlfr_sum_score5,
#       nvl(a.good_urlfr_sum_score6,0) + nvl(b.good_urlfr_sum_score6,0) as good_urlfr_sum_score6,
#       '2017-02-28' as first_calc_ymd,
#       '2017-03-04' as last_calc_ymd
#     from
#       (select * from user_kposminin.id_feat_accum a where a.first_calc_ymd = '2017-02-28' and a.last_calc_ymd = '2017-03-03') a
#       full join (select * from user_kposminin.id_feat_accum b where b.first_calc_ymd = '2017-03-04' and b.last_calc_ymd = '2017-03-04') b
#         on a.id = b.id and a.load_src = b.load_src
#     ;
#
#
#
#     alter table user_kposminin.id_feat_accum drop partition (first_calc_ymd = '2017-02-28', last_calc_ymd = '2017-03-03');
#
#
#     -- 2017-03-05. Id_feats 1 day calc
#     with mymd as
#      (select
#        target,
#        max(ymd) as max_ymd
#       from
#        user_kposminin.urlfr_scores
#       where
#         ymd < date_add('2017-03-05',-3)
#       group by target
#      )
#
#     insert overwrite table user_kposminin.id_feat_accum partition (first_calc_ymd, last_calc_ymd)
#     select
#      id,
#      load_src,
#      ymd as first_id_ymd,
#      ymd as last_id_ymd,
#      1 as ymd_cnt,
#      count(distinct urlfr) as urlfr_cnt,
#      count(urlfr) as visits_cnt,
#      sum(cnt) as hits,
#      sum(if(urlfr like 'e.mail.ru%',1,0)) as emailru_sum,
#      sum(if(urlfr like 'm.%',1,0)) as mobile_sum,
#      sum(if(urlfr rlike '^(m\.)?vk.com', 1, 0)) as vk_sum,
#      sum(if(urlfr rlike '^(m\.)?vk.com' or urlfr rlike '^(m\.)?(ok|odnoklassniki)\.ru' or urlfr rlike '^(m\.)?my.mail.ru',1,0)) as social_sum,
#      sum(if(avg_hour >= 9 and avg_hour <= 20,cnt,0)) as work_hours_hits_sum,
#      sum( avg_hour * avg_hour) as avg_hour_sum_sq,
#      sum(avg_hour) as avg_hour_sum,
#      max(score1) as max_score1,
#      max(score2) as max_score2,
#      max(score3) as max_score3,
#      max(score4) as max_score4,
#      max(score5) as max_score5,
#      max(score6) as max_score6,
#      min(score1) as min_score1,
#      min(score2) as min_score2,
#      min(score3) as min_score3,
#      min(score4) as min_score4,
#      min(score5) as min_score5,
#      min(score6) as min_score6,
#      sum(score1) as sum_score1,
#      sum(score2) as sum_score2,
#      sum(score3) as sum_score3,
#      sum(score4) as sum_score4,
#      sum(score5) as sum_score5,
#      sum(score6) as sum_score6,
#      count(score1) as cnt_score1,
#      count(score2) as cnt_score2,
#      count(score3) as cnt_score3,
#      count(score4) as cnt_score4,
#      count(score5) as cnt_score5,
#      count(score6) as cnt_score6,
#      count( if(score1 > -0.2, urlfr,Null)) as good_urlfr_sum_score1,
#      count( if(score2 > -9, urlfr,Null)) as good_urlfr_sum_score2,
#      count( if(score3 > -9, urlfr,Null)) as good_urlfr_sum_score3,
#      count( if(score4 > -2, urlfr,Null)) as good_urlfr_sum_score4,
#      count( if(score5 > -9, urlfr,Null)) as good_urlfr_sum_score5,
#      count( if(score6 > -0.2, urlfr,Null)) as good_urlfr_sum_score6,
#      '2017-03-05' as first_calc_ymd,
#      '2017-03-05' as last_calc_ymd
#
#     from
#      (select
#         v.id,
#         'LI.02' as load_src, -- !!!! bug
#         v.ymd,
#         v.urlfr,
#         unix_timestamp(v.ymd, 'yyyy-MM-dd')/60/60 + v.avg_hour  as time_h,
#         1 as time_std,
#         v.cnt as cnt,
#         v.avg_hour as avg_hour,
#         t1.score as score1,
#         t2.score as score2,
#         t3.score as score3,
#         t4.score as score4,
#         t5.score as score5,
#         log((t2.cnt_positive + 0.1)/(t3.cnt_positive - t2.cnt_positive + 0.1)) as score6
#       from
#         user_kposminin.visits_cred_scor_calc_debug_20170429 v
#         left join (
#             select urlfr,score
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'ccall_tinkoff_approve_from_fullapp'
#         ) t1 on t1.urlfr = v.urlfr
#         left join (
#             select urlfr,score,positive as cnt_positive
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_platinum_approved_application03@tinkoff_action'
#         ) t2 on t2.urlfr = v.urlfr
#         left join (
#             select urlfr,score,positive as cnt_positive
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_platinum_complete_application03@tinkoff_action'
#         ) t3 on t3.urlfr = v.urlfr
#         left join (
#             select urlfr,score
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_LON_CCR_default'
#         ) t4 on t4.urlfr = v.urlfr
#         left join (
#             select urlfr,score
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_platinum_approved_application03_1m'
#         ) t5 on t5.urlfr = v.urlfr
#       where
#         v.ymd = '2017-03-05'
#      ) a
#     group by
#       id,load_src,ymd
#     ;
#
#
#     insert overwrite table user_kposminin.id_feat_accum partition (first_calc_ymd,last_calc_ymd)
#     select
#       nvl(a.id,b.id) as id,
#       nvl(a.load_src,b.load_src) as load_src,
#       least(a.first_id_ymd,b.first_id_ymd) as first_id_ymd,
#       greatest(a.last_id_ymd,b.last_id_ymd) as last_id_ymd,
#       nvl(a.ymd_cnt,0) + nvl(b.ymd_cnt,0) as ymd_cnt,
#       nvl(a.urlfr_cnt,0) + nvl(b.urlfr_cnt,0) as urlfr_cnt,
#       nvl(a.visits_cnt,0) + nvl(b.visits_cnt,0) as visits_cnt,
#       nvl(a.hits,0) + nvl(b.hits,0) as hits,
#       nvl(a.emailru_sum,0) + nvl(b.emailru_sum,0) as emailru_sum,
#       nvl(a.mobile_sum,0) + nvl(b.mobile_sum,0) as mobile_sum,
#       nvl(a.vk_sum,0) + nvl(b.vk_sum,0) as vk_sum,
#       nvl(a.social_sum,0) + nvl(b.social_sum,0) as social_sum,
#       nvl(a.work_hours_hits_sum,0) + nvl(b.work_hours_hits_sum,0) as work_hours_hits_sum,
#       nvl(a.avg_hour_sum_sq,0) + nvl(b.avg_hour_sum_sq,0) as avg_hour_sum_sq,
#       nvl(a.avg_hour_sum,0) + nvl(b.avg_hour_sum,0) as avg_hour_sum,
#       greatest(a.max_score1,b.max_score1) as max_score1,
#       greatest(a.max_score2,b.max_score2) as max_score2,
#       greatest(a.max_score3,b.max_score3) as max_score3,
#       greatest(a.max_score4,b.max_score4) as max_score4,
#       greatest(a.max_score5,b.max_score5) as max_score5,
#       greatest(a.max_score6,b.max_score6) as max_score6,
#       least(a.min_score1, b.min_score1) as min_score1,
#       least(a.min_score2, b.min_score2) as min_score2,
#       least(a.min_score3, b.min_score3) as min_score3,
#       least(a.min_score4, b.min_score4) as min_score4,
#       least(a.min_score5, b.min_score5) as min_score5,
#       least(a.min_score6, b.min_score6) as min_score6,
#       nvl(a.sum_score1,0) + nvl(b.sum_score1,0) as sum_score1,
#       nvl(a.sum_score2,0) + nvl(b.sum_score2,0) as sum_score2,
#       nvl(a.sum_score3,0) + nvl(b.sum_score3,0) as sum_score3,
#       nvl(a.sum_score4,0) + nvl(b.sum_score4,0) as sum_score4,
#       nvl(a.sum_score5,0) + nvl(b.sum_score5,0) as sum_score5,
#       nvl(a.sum_score6,0) + nvl(b.sum_score6,0) as sum_score6,
#       nvl(a.cnt_score1,0) + nvl(b.cnt_score1,0) as cnt_score1,
#       nvl(a.cnt_score2,0) + nvl(b.cnt_score2,0) as cnt_score2,
#       nvl(a.cnt_score3,0) + nvl(b.cnt_score3,0) as cnt_score3,
#       nvl(a.cnt_score4,0) + nvl(b.cnt_score4,0) as cnt_score4,
#       nvl(a.cnt_score5,0) + nvl(b.cnt_score5,0) as cnt_score5,
#       nvl(a.cnt_score6,0) + nvl(b.cnt_score6,0) as cnt_score6,
#       nvl(a.good_urlfr_sum_score1,0) + nvl(b.good_urlfr_sum_score1,0) as good_urlfr_sum_score1,
#       nvl(a.good_urlfr_sum_score2,0) + nvl(b.good_urlfr_sum_score2,0) as good_urlfr_sum_score2,
#       nvl(a.good_urlfr_sum_score3,0) + nvl(b.good_urlfr_sum_score3,0) as good_urlfr_sum_score3,
#       nvl(a.good_urlfr_sum_score4,0) + nvl(b.good_urlfr_sum_score4,0) as good_urlfr_sum_score4,
#       nvl(a.good_urlfr_sum_score5,0) + nvl(b.good_urlfr_sum_score5,0) as good_urlfr_sum_score5,
#       nvl(a.good_urlfr_sum_score6,0) + nvl(b.good_urlfr_sum_score6,0) as good_urlfr_sum_score6,
#       '2017-02-28' as first_calc_ymd,
#       '2017-03-05' as last_calc_ymd
#     from
#       (select * from user_kposminin.id_feat_accum a where a.first_calc_ymd = '2017-02-28' and a.last_calc_ymd = '2017-03-04') a
#       full join (select * from user_kposminin.id_feat_accum b where b.first_calc_ymd = '2017-03-05' and b.last_calc_ymd = '2017-03-05') b
#         on a.id = b.id and a.load_src = b.load_src
#     ;
#
#
#
#     alter table user_kposminin.id_feat_accum drop partition (first_calc_ymd = '2017-02-28', last_calc_ymd = '2017-03-04');
#
#
#     -- 2017-03-06. Id_feats 1 day calc
#     with mymd as
#      (select
#        target,
#        max(ymd) as max_ymd
#       from
#        user_kposminin.urlfr_scores
#       where
#         ymd < date_add('2017-03-06',-3)
#       group by target
#      )
#
#     insert overwrite table user_kposminin.id_feat_accum partition (first_calc_ymd, last_calc_ymd)
#     select
#      id,
#      load_src,
#      ymd as first_id_ymd,
#      ymd as last_id_ymd,
#      1 as ymd_cnt,
#      count(distinct urlfr) as urlfr_cnt,
#      count(urlfr) as visits_cnt,
#      sum(cnt) as hits,
#      sum(if(urlfr like 'e.mail.ru%',1,0)) as emailru_sum,
# ...
#       from
#        user_kposminin.urlfr_scores
#       where
#         ymd < date_add('2017-04-27',-3)
#       group by target
#      )
#
#     insert overwrite table user_kposminin.id_feat_accum partition (first_calc_ymd, last_calc_ymd)
#     select
#      id,
#      load_src,
#      ymd as first_id_ymd,
#      ymd as last_id_ymd,
#      1 as ymd_cnt,
#      count(distinct urlfr) as urlfr_cnt,
#      count(urlfr) as visits_cnt,
#      sum(cnt) as hits,
#      sum(if(urlfr like 'e.mail.ru%',1,0)) as emailru_sum,
#      sum(if(urlfr like 'm.%',1,0)) as mobile_sum,
#      sum(if(urlfr rlike '^(m\.)?vk.com', 1, 0)) as vk_sum,
#      sum(if(urlfr rlike '^(m\.)?vk.com' or urlfr rlike '^(m\.)?(ok|odnoklassniki)\.ru' or urlfr rlike '^(m\.)?my.mail.ru',1,0)) as social_sum,
#      sum(if(avg_hour >= 9 and avg_hour <= 20,cnt,0)) as work_hours_hits_sum,
#      sum( avg_hour * avg_hour) as avg_hour_sum_sq,
#      sum(avg_hour) as avg_hour_sum,
#      max(score1) as max_score1,
#      max(score2) as max_score2,
#      max(score3) as max_score3,
#      max(score4) as max_score4,
#      max(score5) as max_score5,
#      max(score6) as max_score6,
#      min(score1) as min_score1,
#      min(score2) as min_score2,
#      min(score3) as min_score3,
#      min(score4) as min_score4,
#      min(score5) as min_score5,
#      min(score6) as min_score6,
#      sum(score1) as sum_score1,
#      sum(score2) as sum_score2,
#      sum(score3) as sum_score3,
#      sum(score4) as sum_score4,
#      sum(score5) as sum_score5,
#      sum(score6) as sum_score6,
#      count(score1) as cnt_score1,
#      count(score2) as cnt_score2,
#      count(score3) as cnt_score3,
#      count(score4) as cnt_score4,
#      count(score5) as cnt_score5,
#      count(score6) as cnt_score6,
#      count( if(score1 > -0.2, urlfr,Null)) as good_urlfr_sum_score1,
#      count( if(score2 > -9, urlfr,Null)) as good_urlfr_sum_score2,
#      count( if(score3 > -9, urlfr,Null)) as good_urlfr_sum_score3,
#      count( if(score4 > -2, urlfr,Null)) as good_urlfr_sum_score4,
#      count( if(score5 > -9, urlfr,Null)) as good_urlfr_sum_score5,
#      count( if(score6 > -0.2, urlfr,Null)) as good_urlfr_sum_score6,
#      '2017-04-27' as first_calc_ymd,
#      '2017-04-27' as last_calc_ymd
#
#     from
#      (select
#         v.id,
#         'LI.02' as load_src, -- !!!! bug
#         v.ymd,
#         v.urlfr,
#         unix_timestamp(v.ymd, 'yyyy-MM-dd')/60/60 + v.avg_hour  as time_h,
#         1 as time_std,
#         v.cnt as cnt,
#         v.avg_hour as avg_hour,
#         t1.score as score1,
#         t2.score as score2,
#         t3.score as score3,
#         t4.score as score4,
#         t5.score as score5,
#         log((t2.cnt_positive + 0.1)/(t3.cnt_positive - t2.cnt_positive + 0.1)) as score6
#       from
#         user_kposminin.visits_cred_scor_calc_debug_20170429 v
#         left join (
#             select urlfr,score
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'ccall_tinkoff_approve_from_fullapp'
#         ) t1 on t1.urlfr = v.urlfr
#         left join (
#             select urlfr,score,positive as cnt_positive
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_platinum_approved_application03@tinkoff_action'
#         ) t2 on t2.urlfr = v.urlfr
#         left join (
#             select urlfr,score,positive as cnt_positive
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_platinum_complete_application03@tinkoff_action'
#         ) t3 on t3.urlfr = v.urlfr
#         left join (
#             select urlfr,score
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_LON_CCR_default'
#         ) t4 on t4.urlfr = v.urlfr
#         left join (
#             select urlfr,score
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_platinum_approved_application03_1m'
#         ) t5 on t5.urlfr = v.urlfr
#       where
#         v.ymd = '2017-04-27'
#      ) a
#     group by
#       id,load_src,ymd
#     ;
#
#
#     insert overwrite table user_kposminin.id_feat_accum partition (first_calc_ymd,last_calc_ymd)
#     select
#       nvl(a.id,b.id) as id,
#       nvl(a.load_src,b.load_src) as load_src,
#       least(a.first_id_ymd,b.first_id_ymd) as first_id_ymd,
#       greatest(a.last_id_ymd,b.last_id_ymd) as last_id_ymd,
#       nvl(a.ymd_cnt,0) + nvl(b.ymd_cnt,0) as ymd_cnt,
#       nvl(a.urlfr_cnt,0) + nvl(b.urlfr_cnt,0) as urlfr_cnt,
#       nvl(a.visits_cnt,0) + nvl(b.visits_cnt,0) as visits_cnt,
#       nvl(a.hits,0) + nvl(b.hits,0) as hits,
#       nvl(a.emailru_sum,0) + nvl(b.emailru_sum,0) as emailru_sum,
#       nvl(a.mobile_sum,0) + nvl(b.mobile_sum,0) as mobile_sum,
#       nvl(a.vk_sum,0) + nvl(b.vk_sum,0) as vk_sum,
#       nvl(a.social_sum,0) + nvl(b.social_sum,0) as social_sum,
#       nvl(a.work_hours_hits_sum,0) + nvl(b.work_hours_hits_sum,0) as work_hours_hits_sum,
#       nvl(a.avg_hour_sum_sq,0) + nvl(b.avg_hour_sum_sq,0) as avg_hour_sum_sq,
#       nvl(a.avg_hour_sum,0) + nvl(b.avg_hour_sum,0) as avg_hour_sum,
#       greatest(a.max_score1,b.max_score1) as max_score1,
#       greatest(a.max_score2,b.max_score2) as max_score2,
#       greatest(a.max_score3,b.max_score3) as max_score3,
#       greatest(a.max_score4,b.max_score4) as max_score4,
#       greatest(a.max_score5,b.max_score5) as max_score5,
#       greatest(a.max_score6,b.max_score6) as max_score6,
#       least(a.min_score1, b.min_score1) as min_score1,
#       least(a.min_score2, b.min_score2) as min_score2,
#       least(a.min_score3, b.min_score3) as min_score3,
#       least(a.min_score4, b.min_score4) as min_score4,
#       least(a.min_score5, b.min_score5) as min_score5,
#       least(a.min_score6, b.min_score6) as min_score6,
#       nvl(a.sum_score1,0) + nvl(b.sum_score1,0) as sum_score1,
#       nvl(a.sum_score2,0) + nvl(b.sum_score2,0) as sum_score2,
#       nvl(a.sum_score3,0) + nvl(b.sum_score3,0) as sum_score3,
#       nvl(a.sum_score4,0) + nvl(b.sum_score4,0) as sum_score4,
#       nvl(a.sum_score5,0) + nvl(b.sum_score5,0) as sum_score5,
#       nvl(a.sum_score6,0) + nvl(b.sum_score6,0) as sum_score6,
#       nvl(a.cnt_score1,0) + nvl(b.cnt_score1,0) as cnt_score1,
#       nvl(a.cnt_score2,0) + nvl(b.cnt_score2,0) as cnt_score2,
#       nvl(a.cnt_score3,0) + nvl(b.cnt_score3,0) as cnt_score3,
#       nvl(a.cnt_score4,0) + nvl(b.cnt_score4,0) as cnt_score4,
#       nvl(a.cnt_score5,0) + nvl(b.cnt_score5,0) as cnt_score5,
#       nvl(a.cnt_score6,0) + nvl(b.cnt_score6,0) as cnt_score6,
#       nvl(a.good_urlfr_sum_score1,0) + nvl(b.good_urlfr_sum_score1,0) as good_urlfr_sum_score1,
#       nvl(a.good_urlfr_sum_score2,0) + nvl(b.good_urlfr_sum_score2,0) as good_urlfr_sum_score2,
#       nvl(a.good_urlfr_sum_score3,0) + nvl(b.good_urlfr_sum_score3,0) as good_urlfr_sum_score3,
#       nvl(a.good_urlfr_sum_score4,0) + nvl(b.good_urlfr_sum_score4,0) as good_urlfr_sum_score4,
#       nvl(a.good_urlfr_sum_score5,0) + nvl(b.good_urlfr_sum_score5,0) as good_urlfr_sum_score5,
#       nvl(a.good_urlfr_sum_score6,0) + nvl(b.good_urlfr_sum_score6,0) as good_urlfr_sum_score6,
#       '2017-02-28' as first_calc_ymd,
#       '2017-04-27' as last_calc_ymd
#     from
#       (select * from user_kposminin.id_feat_accum a where a.first_calc_ymd = '2017-02-28' and a.last_calc_ymd = '2017-04-26') a
#       full join (select * from user_kposminin.id_feat_accum b where b.first_calc_ymd = '2017-04-27' and b.last_calc_ymd = '2017-04-27') b
#         on a.id = b.id and a.load_src = b.load_src
#     ;
#
#
#
#     alter table user_kposminin.id_feat_accum drop partition (first_calc_ymd = '2017-02-28', last_calc_ymd = '2017-04-26');
#
#
#     -- 2017-04-28. Id_feats 1 day calc
#     with mymd as
#      (select
#        target,
#        max(ymd) as max_ymd
#       from
#        user_kposminin.urlfr_scores
#       where
#         ymd < date_add('2017-04-28',-3)
#       group by target
#      )
#
#     insert overwrite table user_kposminin.id_feat_accum partition (first_calc_ymd, last_calc_ymd)
#     select
#      id,
#      load_src,
#      ymd as first_id_ymd,
#      ymd as last_id_ymd,
#      1 as ymd_cnt,
#      count(distinct urlfr) as urlfr_cnt,
#      count(urlfr) as visits_cnt,
#      sum(cnt) as hits,
#      sum(if(urlfr like 'e.mail.ru%',1,0)) as emailru_sum,
#      sum(if(urlfr like 'm.%',1,0)) as mobile_sum,
#      sum(if(urlfr rlike '^(m\.)?vk.com', 1, 0)) as vk_sum,
#      sum(if(urlfr rlike '^(m\.)?vk.com' or urlfr rlike '^(m\.)?(ok|odnoklassniki)\.ru' or urlfr rlike '^(m\.)?my.mail.ru',1,0)) as social_sum,
#      sum(if(avg_hour >= 9 and avg_hour <= 20,cnt,0)) as work_hours_hits_sum,
#      sum( avg_hour * avg_hour) as avg_hour_sum_sq,
#      sum(avg_hour) as avg_hour_sum,
#      max(score1) as max_score1,
#      max(score2) as max_score2,
#      max(score3) as max_score3,
#      max(score4) as max_score4,
#      max(score5) as max_score5,
#      max(score6) as max_score6,
#      min(score1) as min_score1,
#      min(score2) as min_score2,
#      min(score3) as min_score3,
#      min(score4) as min_score4,
#      min(score5) as min_score5,
#      min(score6) as min_score6,
#      sum(score1) as sum_score1,
#      sum(score2) as sum_score2,
#      sum(score3) as sum_score3,
#      sum(score4) as sum_score4,
#      sum(score5) as sum_score5,
#      sum(score6) as sum_score6,
#      count(score1) as cnt_score1,
#      count(score2) as cnt_score2,
#      count(score3) as cnt_score3,
#      count(score4) as cnt_score4,
#      count(score5) as cnt_score5,
#      count(score6) as cnt_score6,
#      count( if(score1 > -0.2, urlfr,Null)) as good_urlfr_sum_score1,
#      count( if(score2 > -9, urlfr,Null)) as good_urlfr_sum_score2,
#      count( if(score3 > -9, urlfr,Null)) as good_urlfr_sum_score3,
#      count( if(score4 > -2, urlfr,Null)) as good_urlfr_sum_score4,
#      count( if(score5 > -9, urlfr,Null)) as good_urlfr_sum_score5,
#      count( if(score6 > -0.2, urlfr,Null)) as good_urlfr_sum_score6,
#      '2017-04-28' as first_calc_ymd,
#      '2017-04-28' as last_calc_ymd
#
#     from
#      (select
#         v.id,
#         'LI.02' as load_src, -- !!!! bug
#         v.ymd,
#         v.urlfr,
#         unix_timestamp(v.ymd, 'yyyy-MM-dd')/60/60 + v.avg_hour  as time_h,
#         1 as time_std,
#         v.cnt as cnt,
#         v.avg_hour as avg_hour,
#         t1.score as score1,
#         t2.score as score2,
#         t3.score as score3,
#         t4.score as score4,
#         t5.score as score5,
#         log((t2.cnt_positive + 0.1)/(t3.cnt_positive - t2.cnt_positive + 0.1)) as score6
#       from
#         user_kposminin.visits_cred_scor_calc_debug_20170429 v
#         left join (
#             select urlfr,score
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'ccall_tinkoff_approve_from_fullapp'
#         ) t1 on t1.urlfr = v.urlfr
#         left join (
#             select urlfr,score,positive as cnt_positive
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_platinum_approved_application03@tinkoff_action'
#         ) t2 on t2.urlfr = v.urlfr
#         left join (
#             select urlfr,score,positive as cnt_positive
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_platinum_complete_application03@tinkoff_action'
#         ) t3 on t3.urlfr = v.urlfr
#         left join (
#             select urlfr,score
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_LON_CCR_default'
#         ) t4 on t4.urlfr = v.urlfr
#         left join (
#             select urlfr,score
#               from mymd td
#              inner join user_kposminin.urlfr_scores t on t.target = td.target and t.ymd = td.max_ymd
#              where td.target = 'tinkoff_platinum_approved_application03_1m'
#         ) t5 on t5.urlfr = v.urlfr
#       where
#         v.ymd = '2017-04-28'
#      ) a
#     group by
#       id,load_src,ymd
#     ;
#
#
#     insert overwrite table user_kposminin.id_feat_accum partition (first_calc_ymd,last_calc_ymd)
#     select
#       nvl(a.id,b.id) as id,
#       nvl(a.load_src,b.load_src) as load_src,
#       least(a.first_id_ymd,b.first_id_ymd) as first_id_ymd,
#       greatest(a.last_id_ymd,b.last_id_ymd) as last_id_ymd,
#       nvl(a.ymd_cnt,0) + nvl(b.ymd_cnt,0) as ymd_cnt,
#       nvl(a.urlfr_cnt,0) + nvl(b.urlfr_cnt,0) as urlfr_cnt,
#       nvl(a.visits_cnt,0) + nvl(b.visits_cnt,0) as visits_cnt,
#       nvl(a.hits,0) + nvl(b.hits,0) as hits,
#       nvl(a.emailru_sum,0) + nvl(b.emailru_sum,0) as emailru_sum,
#       nvl(a.mobile_sum,0) + nvl(b.mobile_sum,0) as mobile_sum,
#       nvl(a.vk_sum,0) + nvl(b.vk_sum,0) as vk_sum,
#       nvl(a.social_sum,0) + nvl(b.social_sum,0) as social_sum,
#       nvl(a.work_hours_hits_sum,0) + nvl(b.work_hours_hits_sum,0) as work_hours_hits_sum,
#       nvl(a.avg_hour_sum_sq,0) + nvl(b.avg_hour_sum_sq,0) as avg_hour_sum_sq,
#       nvl(a.avg_hour_sum,0) + nvl(b.avg_hour_sum,0) as avg_hour_sum,
#       greatest(a.max_score1,b.max_score1) as max_score1,
#       greatest(a.max_score2,b.max_score2) as max_score2,
#       greatest(a.max_score3,b.max_score3) as max_score3,
#       greatest(a.max_score4,b.max_score4) as max_score4,
#       greatest(a.max_score5,b.max_score5) as max_score5,
#       greatest(a.max_score6,b.max_score6) as max_score6,
#       least(a.min_score1, b.min_score1) as min_score1,
#       least(a.min_score2, b.min_score2) as min_score2,
#       least(a.min_score3, b.min_score3) as min_score3,
#       least(a.min_score4, b.min_score4) as min_score4,
#       least(a.min_score5, b.min_score5) as min_score5,
#       least(a.min_score6, b.min_score6) as min_score6,
#       nvl(a.sum_score1,0) + nvl(b.sum_score1,0) as sum_score1,
#       nvl(a.sum_score2,0) + nvl(b.sum_score2,0) as sum_score2,
#       nvl(a.sum_score3,0) + nvl(b.sum_score3,0) as sum_score3,
#       nvl(a.sum_score4,0) + nvl(b.sum_score4,0) as sum_score4,
#       nvl(a.sum_score5,0) + nvl(b.sum_score5,0) as sum_score5,
#       nvl(a.sum_score6,0) + nvl(b.sum_score6,0) as sum_score6,
#       nvl(a.cnt_score1,0) + nvl(b.cnt_score1,0) as cnt_score1,
#       nvl(a.cnt_score2,0) + nvl(b.cnt_score2,0) as cnt_score2,
#       nvl(a.cnt_score3,0) + nvl(b.cnt_score3,0) as cnt_score3,
#       nvl(a.cnt_score4,0) + nvl(b.cnt_score4,0) as cnt_score4,
#       nvl(a.cnt_score5,0) + nvl(b.cnt_score5,0) as cnt_score5,
#       nvl(a.cnt_score6,0) + nvl(b.cnt_score6,0) as cnt_score6,
#       nvl(a.good_urlfr_sum_score1,0) + nvl(b.good_urlfr_sum_score1,0) as good_urlfr_sum_score1,
#       nvl(a.good_urlfr_sum_score2,0) + nvl(b.good_urlfr_sum_score2,0) as good_urlfr_sum_score2,
#       nvl(a.good_urlfr_sum_score3,0) + nvl(b.good_urlfr_sum_score3,0) as good_urlfr_sum_score3,
#       nvl(a.good_urlfr_sum_score4,0) + nvl(b.good_urlfr_sum_score4,0) as good_urlfr_sum_score4,
#       nvl(a.good_urlfr_sum_score5,0) + nvl(b.good_urlfr_sum_score5,0) as good_urlfr_sum_score5,
#       nvl(a.good_urlfr_sum_score6,0) + nvl(b.good_urlfr_sum_score6,0) as good_urlfr_sum_score6,
#       '2017-02-28' as first_calc_ymd,
#       '2017-04-28' as last_calc_ymd
#     from
#       (select * from user_kposminin.id_feat_accum a where a.first_calc_ymd = '2017-02-28' and a.last_calc_ymd = '2017-04-27') a
#       full join (select * from user_kposminin.id_feat_accum b where b.first_calc_ymd = '2017-04-28' and b.last_calc_ymd = '2017-04-28') b
#         on a.id = b.id and a.load_src = b.load_src
#     ;
#
#
#
#     alter table user_kposminin.id_feat_accum drop partition (first_calc_ymd = '2017-02-28', last_calc_ymd = '2017-04-27');
#
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Заполняем промежутки по 15 дней. В итоге весь год посчитан. История за 2 месяца.

# %%
day_tuples = sorted([(datetime.datetime(2016,i,1),datetime.datetime(2016,i,15)) for i in range(1,13)] + 
             [(datetime.datetime(2016,i,16),datetime.datetime(2016,i+1,1) - datetime.timedelta(days=1)) for i in range(1,12)] + 
             [(datetime.datetime(2016,12,16),datetime.datetime(2016,12,31))])
import datetime
for i in range(len(day_tuples) - 4):
    c = calc_cred_score(hc, init_query = False)
    c.merge_days(day_tuples[i:i+4], clean = 'clean')
    day = day_tuples[i+3][1] + datetime.timedelta(days=1)
    inner_day_tuple = [(min([e[0] for e in day_tuples[i:i+4]]),max([e[1] for e in day_tuples[i:i+4]]))]
    while day < day_tuples[i+4][1]:
        inner_day_tuple.append((day,day))
        day += datetime.timedelta(days=1)
    c.merge_days(inner_day_tuple, clean = False)
    #print(c.get_query())
    print('-'*100)

# %%
query = '''create table user_kposminin.ccall_aza_id as 
select distinct phone_mobile, approve, call_ymd, id from user_kposminin.ccall_visits
;'''

c = calc_cred_score(hc, init_query = False)
c.calc_full_feat()
print(c.get_query())
# Out:
#     create table user_kposminin.id_feat_ccall as
#     select
#          a.phone_mobile,
#          count(distinct a.id) as id_cnt,
#          count(distinct acc.id) as acc_id_cnt,
#          a.call_ymd as call_ymd,
#          max(a.approve) as approve,
#          sum(acc.urlfr_cnt) as urlfr_cnt,
#          sum(acc.visits_cnt) as visits_cnt,
#          sum(acc.hits) as hits,
#          max(acc.max_score1) as max_score1,
#          sum(acc.sum_score1) / sum(acc.cnt_score1) as avg_score1,
#          min(acc.min_score1) as min_score1,
#          max(acc.max_score2) as max_score2,
#          sum(acc.sum_score2) / sum(acc.cnt_score2) as avg_score2,
#          min(acc.min_score2) as min_score2,
#          max(acc.max_score3) as max_score3,
#          sum(acc.sum_score3) / sum(acc.cnt_score3) as avg_score3,
#          min(acc.min_score3) as min_score3,
#          max(acc.max_score4) as max_score4,
#          sum(acc.sum_score4) / sum(acc.cnt_score4) as avg_score4,
#          min(acc.min_score4) as min_score4,
#          max(acc.max_score5) as max_score5,
#          sum(acc.sum_score5) / sum(acc.cnt_score4) as avg_score5,
#          min(acc.min_score5) as min_score5,
#          max(acc.max_score6) as max_score6,
#          sum(acc.sum_score6) / sum(acc.cnt_score4) as avg_score6,
#          min(acc.min_score6) as min_score6,
#          sum(acc.emailru_sum) / sum(acc.visits_cnt) as emailru_share,
#          sum(acc.mobile_sum) / sum(acc.visits_cnt) as mobile_share,
#          sum(acc.vk_sum) / sum(acc.visits_cnt) as vk_share,
#          sum(acc.social_sum) / sum(acc.visits_cnt) as social_share,
#          sum(acc.work_hours_hits_sum) / sum(acc.hits) as work_hours_hits_share,
#          sqrt(sum(acc.avg_hour_sum_sq)/(sum(acc.visits_cnt)-1) - power(sum(acc.avg_hour_sum)/(sum(acc.visits_cnt) - 1), 2)) as hour_std,
#          sum(acc.good_urlfr_sum_score1) / sum(acc.cnt_score1) as good_urlfr_share_score1,
#          sum(acc.good_urlfr_sum_score2) / sum(acc.cnt_score2) as good_urlfr_share_score2,
#          sum(acc.good_urlfr_sum_score3) / sum(acc.cnt_score3) as good_urlfr_share_score3,
#          sum(acc.good_urlfr_sum_score4) / sum(acc.cnt_score4) as good_urlfr_share_score4,
#          sum(acc.good_urlfr_sum_score5) / sum(acc.cnt_score5) as good_urlfr_share_score5,
#          sum(acc.good_urlfr_sum_score6) / sum(acc.cnt_score6) as good_urlfr_share_score6,
#          max(trim(pc.provider)) as mob_provider,
#          max(r.ind) as ind,
#          max(r.pop_country_share) as pop_country_share,
#          max(r.pop_city_share) as pop_city_share,
#          max(r.population / r.area_sq_km) as density,
#          max(r.area_sq_km) as area_sq_km,
#          max(trim(r.federal_district)) as federal_district,
#          max(r.avg_salary_2015_rub) as avg_salary_2015_rub,
#          max(r.utc_time_zone_val) as utc_time_zone_val
#
#
#       from
#          user_kposminin.ccall_aza_id a
#          inner join user_kposminin.id_feat_accum acc on acc.id = a.id and acc.last_calc_ymd = date_add(a.call_ymd, -1)
#          left join dds_dic.phone_codes pc on trim(pc.phone_code) = substr(a.phone_mobile,2,9)
#          left join dds_dic.region_stat r on r.ind = pc.region_id
#      group by
#              a.phone_mobile,
#              a.call_ymd
#     ;

# %% [markdown]
# ## Таблица построена. Проверяем работоспособность - строим классификатор

# %%
##### Config
from pyspark import SparkConf, SparkContext, HiveContext
import re
import numpy as np
import pandas as pd
import datetime
from pyspark.mllib.regression import LabeledPoint
from pyspark.mllib.feature import HashingTF
from pyspark.mllib.classification import LogisticRegressionWithSGD, NaiveBayes, NaiveBayesModel
import scipy.sparse as sps
from pyspark.mllib.linalg import Vectors
from pyspark.mllib.linalg import SparseVector
from pyspark.mllib.evaluation import BinaryClassificationMetrics
import hashlib
from collections import Counter

hive_config_query = '''
set hive.vectorized.execution.enabled=true;
set hive.vectorized.execution.reduce.enabled = true;
set mapreduce.map.memory.mb=4096;
set mapreduce.map.child.java.opts=-Xmx4g;
set mapreduce.task.io.sort.mb=1024;
set mapreduce.reduce.child.java.opts=-Xmx4g;
set mapreduce.reduce.memory.mb=7000;
set mapreduce.reduce.shuffle.input.buffer.percent=0.5;
set mapreduce.input.fileinputformat.split.minsize=536870912;
set mapreduce.input.fileinputformat.split.maxsize=1073741824;
set hive.optimize.ppd=true;
set hive.merge.smallfiles.avgsize=536870912;
set hive.merge.mapredfiles=true;
set hive.merge.mapfiles=true;
set hive.hadoop.supports.splittable.combineinputformat=true;
set hive.exec.reducers.bytes.per.reducer=536870912;
set hive.exec.parallel=true;
set hive.exec.max.created.files=10000000;
set hive.exec.compress.output=true;
set hive.exec.dynamic.partition.mode=nonstrict;
set hive.exec.max.dynamic.partitions=1000000;
set hive.exec.max.dynamic.partitions.pernode=100000;
set io.seqfile.compression.type=BLOCK;
set mapreduce.map.failures.maxpercent=5;
'''

sc.stop()
conf = (SparkConf()
        .set("spark.executor.instances", 2)
        .set("spark.driver.maxResultSize", "4g")
        .set('spark.driver.memory','4g')
        .set("spark.executor.memory", '2g')
        .set("spark.yarn.executor.memoryOverhead", 1048)
       )
sc = SparkContext(conf=conf)
hc = HiveContext(sc)

for q in hive_config_query.split(';'):
    try:
        hc.sql(q)
    except:
        pass

# %%
def metrics(y_true,y_score,lift = None, return_str = False):
    import sklearn
    import collections
    
    if True:
        
        res = collections.OrderedDict()
        samp_size = len(y_true)
        res['Sample size'] = samp_size
        res['Posit share'] = sum(y_true) * 1./ samp_size
        res['Sample size'] = len(y_true)
        res['AUC ROC'] = sklearn.metrics.roc_auc_score(y_true = y_true, y_score = y_score)
        res['AUC PR'] = sklearn.metrics.average_precision_score( y_true,  y_score)
        res['Log loss'] = sklearn.metrics.log_loss(y_true = y_true, y_pred = y_score)
        if lift:
            predictions_and_labels = sorted(zip(y_score,y_true), key = lambda e:-e[0])
            for l in lift:
                res['Lift ' + str(l)] = sum([e[1] for e in predictions_and_labels[:int(l * samp_size)]]) * 1. / int(l * samp_size) / res['Posit share']                
        if return_str:
            res = '\n'.join(['{:<12}: {:.5f}'.format(k,v) for (k,v) in res.items()]) + '.'
        return res

# %%
def cv(clf, X, y, folds = 5, metrics = 'roc_auc,pr_auc'):
    '''calc cross-validation metrics for clf classfier on X,y data.
       clf must support predict_proba method.
       Returns dictionary with metrics values on each fold.
    '''
    assert X.shape[0] == len(y), 'X and y lengths doesnt match'
    idx = range(X.shape[0])
    np.random.shuffle(idx)
    fold_idx = []
    for i in range(folds):
        fold_idx.append(idx[i*len(idx)/folds:(i+1)*len(idx)/folds])
    res = {k:[] for k in metrics.split(',')}
    
    for i in range(folds):
        train_idx = reduce(lambda x,y: x+y,(fold_idx[:i] + fold_idx[(i+1):]))
        valid_idx = fold_idx[i]
        
        clf.fit(X[train_idx],y[train_idx])
        valid_pred = clf.predict_proba(X[valid_idx])[:,1]
        
        if('roc_auc' in metrics):
            res['roc_auc'].append(
                sklearn.metrics.roc_auc_score(
                  y_true = y[valid_idx],
                  y_score = valid_pred
                )
            )
        if('pr_auc' in metrics):
            res['pr_auc'].append(
                sklearn.metrics.average_precision_score(
                  y_true = y[valid_idx],
                  y_score = valid_pred
                )
            )
    return res

# %%
import cPickle
from sklearn.feature_extraction import DictVectorizer
import os
import sklearn, sklearn.cross_validation
from pylightgbm.models import GBMClassifier

# %%
#federal_districts = [u'ЦФО',u'СЗФО',u'ЮФО',u'СКФО',u'ПФО',u'УФО',u'СФО',u'ДВФО'] # todo

def encode(v, classes, default_value = -1):
    '''Encode text value v which values are from classes list. Returns v index and -1 if it wasn't found in the list.'''
    try:
        return classes.index(v)
    except ValueError:
        return default_value


exec_path = "/opt/share/LightGBM-master/lightgbm"
os.environ["LIGHTGBM_EXEC"] = exec_path

# %%
df_all = (hc.sql('select * from user_kposminin.id_feat_ccall')        
        .toPandas()
         )

#df_all.loc[:,'federal_district'] = df_all.federal_district.map(lambda v:encode(v, federal_districts))
df_train = df_all[df_all['call_ymd'] <  '2016-12-01']
df_test  = df_all[df_all['call_ymd'] >= '2016-12-01']
df_train.shape,df_test.shape
# Out:
# ((333259, 47), (28946, 47))

# %%
from sklearn import preprocessing
categ_vars = [ 'mob_provider',u'federal_district']
le = {v:preprocessing.LabelEncoder() for v in categ_vars}
for v in categ_vars:
    df_train.loc[:,v] = le[v].fit_transform(df_train[v])
    df_test.loc[:,v]  = le[v].transform(df_test[v])
# Out:
# /opt/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
#df_all.iloc[0]

# %%
def target_encoding(cat_vars, label, df_train, df_test, folds = 5, smooth_N = 100, inplace = False):
    '''
       Make target encoding of categorical_variable from cat_vars list using label.
       df_train, df_test are Pandas.DataFrame instances.
       folds is number of folds to split.
       smooth_N is smoothing number.
       returns Pandas DataFrames with categorical_variable + '_encoded' columns for train and test.
    '''
    assert type(df_train) == type(df_test) == type(pd.DataFrame()), 'df_train and df_test must be Pandas DataFrame.'
    assert all(v in df_train.columns for v in cat_vars + [label]) & \
           all(v in df_test.columns for v in cat_vars + [label]),   \
           'all categorical variables and label must be df_train and df_test columns'
    
    idx = df_train.index.tolist()
    np.random.shuffle(idx)
    fold_idx = []    
    for i in range(folds):
        fold_idx.append(idx[i*len(idx)/folds:(i+1)*len(idx)/folds])
    
    df_train_encoded = pd.DataFrame(index = idx, columns = [v + '_encoded' for v in cat_vars])
    df_test_encoded = pd.DataFrame(index = df_test.index, columns = [v + '_encoded' for v in cat_vars])
    
    for i in range(folds):
        train_idx = reduce(lambda x,y: x+y,(fold_idx[:i] + fold_idx[(i+1):]))
        valid_idx = fold_idx[i]
        
        global_mean = df_train.ix[train_idx,label].mean()
        for v in cat_vars:
            #print(v)
            v_stat = df_train.ix[train_idx].groupby(v)[label].agg([sum,len])
            df_train_encoded.ix[valid_idx,v + '_encoded'] = df_train.ix[valid_idx,v].map( lambda c:
             (v_stat.loc[c,'sum'] + smooth_N * global_mean) / (v_stat.loc[c,'len'] + smooth_N) if c in v_stat.index else global_mean)
    
    for v in cat_vars:
        v_stat = df_train.groupby(v)[label].agg([sum,len])
        df_test_encoded.loc[:,v + '_encoded'] = df_test.loc[:,v].map( lambda c:
             (v_stat.loc[c,'sum'] + smooth_N * global_mean) / (v_stat.loc[c,'len'] + smooth_N) if c in v_stat.index else global_mean)
        
    if inplace == True:
        df_train = df_train.join(df_train_encoded)
        df_test = df_test.join(df_test_encoded)
    else:
        return df_train_encoded, df_test_encoded

# %%
target_encoding(cat_vars = [ 'mob_provider',u'federal_district'], 
                              label = 'approve', df_train = df_train, df_test = df_test, folds = 3, smooth_N = 100,inplace = True)
df_train.columns
#df_train = df_train.join(df_train_enc)
#df_test  = df_test.join(df_test_enc)
# Out:
# mob_provider
# federal_district
# mob_provider
# federal_district
# mob_provider
# federal_district
# Index([u'phone_mobile', u'id_cnt', u'acc_id_cnt', u'call_ymd', u'approve',
#        u'urlfr_cnt', u'visits_cnt', u'hits', u'max_score1', u'avg_score1',
#        u'min_score1', u'max_score2', u'avg_score2', u'min_score2',
#        u'max_score3', u'avg_score3', u'min_score3', u'max_score4',
#        u'avg_score4', u'min_score4', u'max_score5', u'avg_score5',
#        u'min_score5', u'max_score6', u'avg_score6', u'min_score6',
#        u'emailru_share', u'mobile_share', u'vk_share', u'social_share',
#        u'work_hours_hits_share', u'hour_std', u'good_urlfr_share_score1',
#        u'good_urlfr_share_score2', u'good_urlfr_share_score3',
#        u'good_urlfr_share_score4', u'good_urlfr_share_score5',
#        u'good_urlfr_share_score6', u'mob_provider', u'ind',
#        u'pop_country_share', u'pop_city_share', u'density', u'area_sq_km',
#        u'federal_district', u'avg_salary_2015_rub', u'utc_time_zone_val'],
#       dtype='object')

# %%
feat_list = [
    df_train.columns[5:],
    [c for c in df_train.columns[5:] if not 'score5' in c], # good ??
    [c for c in df_train.columns[5:] if not 'score4' in c], 
    [c for c in df_train.columns[5:] if not 'score1' in c], 
    [c for c in df_train.columns[5:] if not any('score{}'.format(i) in c for i in list('236'))],
    df_train.columns[5:-11], # bad
    df_train.columns[5:-17], # bad
    df_train.columns[5:]  + df_train.columns[1:2],
    [c for c in (df_train.columns[5:]  + df_train.columns[1:2]) if not 'score5' in c], # good ??
    [c for c in (df_train.columns[5:-2]  + df_train.columns[1:2]) if not 'score5' in c],
    df_train.columns[5:-2] + df_train.columns[1:2],   
    [c for c in (df_train.columns[5:]  + df_train.columns[1:2]) if not 'share' in c]
]

label = 'approve'
# Out:
# /opt/anaconda/lib/python2.7/site-packages/pandas/core/index.py:1338: FutureWarning: using '+' to provide set union with Indexes is deprecated, use '|' or .union()
#   "use '|' or .union()", FutureWarning)

# %%
print(datetime.datetime.now())
result = []
for i in range(len(feat_list)):
    clf = GBMClassifier(
        exec_path=exec_path,
        min_data_in_leaf=50,
       # is_unbalance = True,
        num_iterations = 120,
        bagging_fraction = 0.8,
        bagging_freq = 10,
        num_leaves = 127,
        learning_rate = 0.05,
        metric = 'auc',
        verbose = False
    )
    result.append((i,feat_list[i], cv(clf, df_train[feat_list[i]].values, df_train[label].values, folds = 5, metrics = 'roc_auc,pr_auc')))
print(datetime.datetime.now())
# Out:
# 2017-05-31 13:52:58.993424
# 2017-05-31 14:27:04.858684

# %%
df_res = pd.DataFrame(result,columns = ['id','feats','metrics'])
df_res['avg_auc_roc'] = df_res['metrics'].map(lambda d: np.mean(d['roc_auc']))
df_res['std_auc_roc'] = df_res['metrics'].map(lambda d: np.std(d['roc_auc']))
df_res['min_auc_roc'] = df_res['metrics'].map(lambda d: min(d['roc_auc']))
df_res['avg_auc_pr'] = df_res['metrics'].map(lambda d: np.mean(d['pr_auc']))
df_res
# Out:
#    id                                              feats  \
# 0   0  Index([               u'urlfr_cnt',           ...
# 1   1  [urlfr_cnt, visits_cnt, hits, max_score1, avg_...
# 2   2  [urlfr_cnt, visits_cnt, hits, max_score1, avg_...
# 3   3  [urlfr_cnt, visits_cnt, hits, max_score2, avg_...
# 4   4  [urlfr_cnt, visits_cnt, hits, max_score1, avg_...
# 5   5  Index([u'urlfr_cnt', u'visits_cnt', u'hits', u...
# 6   6  Index([u'urlfr_cnt', u'visits_cnt', u'hits', u...
# 7   7  Index([               u'urlfr_cnt',           ...
#
#                                              metrics  avg_auc_roc  \
# 0  {u'pr_auc': [0.511794013588, 0.513386253207, 0...     0.668986
# 1  {u'pr_auc': [0.515478496553, 0.51499617237, 0....     0.669223
# 2  {u'pr_auc': [0.516846995118, 0.512782025885, 0...     0.668198
# 3  {u'pr_auc': [0.511834229821, 0.506280271948, 0...     0.659296
# 4  {u'pr_auc': [0.513497564319, 0.521698216584, 0...     0.666274
# 5  {u'pr_auc': [0.506971324264, 0.503659634598, 0...     0.658319
# 6  {u'pr_auc': [0.503215024669, 0.505294663653, 0...     0.656823
# 7  {u'pr_auc': [0.514410032847, 0.51649660086, 0....     0.669756
#
#    std_auc_roc  min_auc_roc  avg_auc_pr
# 0     0.001475     0.667104    0.516982
# 1     0.001317     0.668141    0.516767
# 2     0.001627     0.665775    0.515902
# 3     0.002111     0.657187    0.508054
# 4     0.001960     0.664360    0.514638
# 5     0.001968     0.655521    0.504773
# 6     0.001969     0.654138    0.503058
# 7     0.002703     0.667237    0.517546

# %% [markdown]
# ### Исключение score5 улучшает модель (?), добавление id_cnt тоже улучшает.

# %%
print('Feature importances')
sorted(zip(sorted(clf.feature_importance().items()),yet_another_feat_list[-1]),key = lambda v:-v[0][1])
# Out:
# [((2, 754), 'avg_score1'),
#  ((38, 739), 'urlfr_cnt'),
#  ((27, 735), 'min_score1'),
#  ((5, 615), 'avg_score4'),
#  ((18, 547), 'hour_std'),
#  ((40, 535), 'visits_cnt'),
#  ((13, 517), 'good_urlfr_share_score3'),
#  ((17, 460), 'hits'),
#  ((23, 459), 'max_score3'),
#  ((4, 438), 'avg_score3'),
#  ((11, 401), 'good_urlfr_share_score1'),
#  ((3, 394), 'avg_score2'),
#  ((33, 386), 'mob_provider'),
#  ((6, 362), 'avg_score5'),
#  ((37, 361), 'social_share'),
#  ((35, 354), 'pop_city_share'),
#  ((7, 353), 'avg_score6'),
#  ((14, 348), 'good_urlfr_share_score4'),
#  ((41, 346), 'vk_share'),
#  ((1, 345), 'avg_salary_2015_rub'),
#  ((30, 342), 'min_score4'),
#  ((25, 341), 'max_score5'),
#  ((34, 338), 'mobile_share'),
#  ((16, 337), 'good_urlfr_share_score6'),
#  ((42, 315), 'work_hours_hits_share'),
#  ((31, 304), 'min_score5'),
#  ((21, 301), 'max_score1'),
#  ((22, 299), 'max_score2'),
#  ((29, 293), 'min_score3'),
#  ((32, 283), 'min_score6'),
#  ((0, 278), 'area_sq_km'),
#  ((15, 278), 'good_urlfr_share_score5'),
#  ((9, 274), 'emailru_share'),
#  ((8, 265), 'density'),
#  ((28, 253), 'min_score2'),
#  ((39, 232), 'utc_time_zone_val'),
#  ((24, 216), 'max_score4'),
#  ((20, 215), 'ind'),
#  ((26, 181), 'max_score6'),
#  ((19, 107), 'id_cnt'),
#  ((12, 95), 'good_urlfr_share_score2'),
#  ((10, 75), 'federal_district'),
#  ((36, 49), 'pop_country_share')]

# %% [markdown]
# ## Вывод: берем все факторы

# %% [markdown]
# ## Далее тюним параметры

# %%
feats = df_train.columns[1:2] + df_train.columns[5:]
label = 'approve'

# %% [markdown]
# #### ставим высокий learning rate и определяем для него число деревьев

# %%
clf = GBMClassifier(
        exec_path=exec_path,
        min_data_in_leaf=100,
       # is_unbalance = True,
        num_iterations = 120,
        bagging_fraction = 0.8,
        bagging_freq = 10,
        num_leaves = 127,
        learning_rate = 0.1,
        metric = 'auc',
    )
res = []
for n_trees in [30,50,100,150,250]:
    clf = GBMClassifier(
        exec_path=exec_path,
        min_data_in_leaf=100,
       # is_unbalance = True,
        num_iterations = n_trees,
        bagging_fraction = 0.8,
        bagging_freq = 10,
        num_leaves = 127,
        learning_rate = 0.1,
        metric = 'auc',
        verbose = False
    )
    res.append((n_trees, cv(clf, df_train[feats].values, df_train[label].values, folds = 5, metrics = 'roc_auc,pr_auc')))  

print('\n'.join('{} {}'.format(e[0],np.mean(e[1]['roc_auc'])) for e in res))

#df_res = pd.DataFrame(result,columns = ['id','feats','metrics'])
#df_res['avg_auc_roc'] = df_res['metrics'].map(lambda d: np.mean(d['roc_auc']))
#df_res['std_auc_roc'] = df_res['metrics'].map(lambda d: np.std(d['roc_auc']))
#df_res['min_auc_roc'] = df_res['metrics'].map(lambda d: min(d['roc_auc']))
#df_res['avg_auc_pr'] = df_res['metrics'].map(lambda d: np.mean(d['pr_auc']))
#df_res
# Out:
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading data in 4.245451 seconds
# [LightGBM] [Info] Number of postive: 97346, number of negative: 169262
# [LightGBM] [Info] Number of data: 266608, number of features: 45
# [LightGBM] [Info] Finished initializing training
# [LightGBM] [Info] Started training...
# [LightGBM] [Info] 0.301915 seconds elapsed, finished iteration 1
# [LightGBM] [Info] 0.559169 seconds elapsed, finished iteration 2
# [LightGBM] [Info] 0.803832 seconds elapsed, finished iteration 3
# [LightGBM] [Info] 1.015187 seconds elapsed, finished iteration 4
# [LightGBM] [Info] 1.237167 seconds elapsed, finished iteration 5
# [LightGBM] [Info] 1.452098 seconds elapsed, finished iteration 6
# [LightGBM] [Info] 1.674369 seconds elapsed, finished iteration 7
# [LightGBM] [Info] 1.902531 seconds elapsed, finished iteration 8
# [LightGBM] [Info] 2.152716 seconds elapsed, finished iteration 9
# [LightGBM] [Info] 2.512865 seconds elapsed, finished iteration 10
# [LightGBM] [Info] 2.862582 seconds elapsed, finished iteration 11
# [LightGBM] [Info] 3.112670 seconds elapsed, finished iteration 12
# [LightGBM] [Info] 3.460999 seconds elapsed, finished iteration 13
# [LightGBM] [Info] 3.715526 seconds elapsed, finished iteration 14
# [LightGBM] [Info] 3.975631 seconds elapsed, finished iteration 15
# [LightGBM] [Info] 4.245366 seconds elapsed, finished iteration 16
# [LightGBM] [Info] 4.509178 seconds elapsed, finished iteration 17
# [LightGBM] [Info] 4.750797 seconds elapsed, finished iteration 18
# [LightGBM] [Info] 4.994874 seconds elapsed, finished iteration 19
# [LightGBM] [Info] 5.288048 seconds elapsed, finished iteration 20
# [LightGBM] [Info] 5.579671 seconds elapsed, finished iteration 21
# [LightGBM] [Info] 5.817532 seconds elapsed, finished iteration 22
# [LightGBM] [Info] 6.054275 seconds elapsed, finished iteration 23
# [LightGBM] [Info] 6.279896 seconds elapsed, finished iteration 24
# [LightGBM] [Info] 6.494276 seconds elapsed, finished iteration 25
# [LightGBM] [Info] 6.737500 seconds elapsed, finished iteration 26
# [LightGBM] [Info] 6.963761 seconds elapsed, finished iteration 27
# [LightGBM] [Info] 7.179923 seconds elapsed, finished iteration 28
# [LightGBM] [Info] 7.394518 seconds elapsed, finished iteration 29
# [LightGBM] [Info] 7.605463 seconds elapsed, finished iteration 30
# [LightGBM] [Info] Finished training
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading 30 models
# [LightGBM] [Info] Finished initializing prediction
# [LightGBM] [Info] Finished prediction
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading data in 4.193073 seconds
# [LightGBM] [Info] Number of postive: 97213, number of negative: 169394
# [LightGBM] [Info] Number of data: 266607, number of features: 45
# [LightGBM] [Info] Finished initializing training
# [LightGBM] [Info] Started training...
# [LightGBM] [Info] 0.317088 seconds elapsed, finished iteration 1
# [LightGBM] [Info] 0.658926 seconds elapsed, finished iteration 2
# [LightGBM] [Info] 0.930264 seconds elapsed, finished iteration 3
# [LightGBM] [Info] 1.246522 seconds elapsed, finished iteration 4
# [LightGBM] [Info] 1.583695 seconds elapsed, finished iteration 5
# [LightGBM] [Info] 1.865810 seconds elapsed, finished iteration 6
# [LightGBM] [Info] 2.125942 seconds elapsed, finished iteration 7
# [LightGBM] [Info] 2.378541 seconds elapsed, finished iteration 8
# [LightGBM] [Info] 2.650337 seconds elapsed, finished iteration 9
# [LightGBM] [Info] 2.911095 seconds elapsed, finished iteration 10
# [LightGBM] [Info] 3.186018 seconds elapsed, finished iteration 11
# [LightGBM] [Info] 3.442313 seconds elapsed, finished iteration 12
# [LightGBM] [Info] 3.702545 seconds elapsed, finished iteration 13
# [LightGBM] [Info] 3.950551 seconds elapsed, finished iteration 14
# [LightGBM] [Info] 4.199557 seconds elapsed, finished iteration 15
# [LightGBM] [Info] 4.451820 seconds elapsed, finished iteration 16
# [LightGBM] [Info] 4.695489 seconds elapsed, finished iteration 17
# [LightGBM] [Info] 4.943127 seconds elapsed, finished iteration 18
# [LightGBM] [Info] 5.193238 seconds elapsed, finished iteration 19
# [LightGBM] [Info] 5.492755 seconds elapsed, finished iteration 20
# [LightGBM] [Info] 5.762833 seconds elapsed, finished iteration 21
# [LightGBM] [Info] 6.010511 seconds elapsed, finished iteration 22
# [LightGBM] [Info] 6.250912 seconds elapsed, finished iteration 23
# [LightGBM] [Info] 6.517635 seconds elapsed, finished iteration 24
# [LightGBM] [Info] 6.759986 seconds elapsed, finished iteration 25
# [LightGBM] [Info] 6.995052 seconds elapsed, finished iteration 26
# [LightGBM] [Info] 7.230471 seconds elapsed, finished iteration 27
# [LightGBM] [Info] 7.467113 seconds elapsed, finished iteration 28
# [LightGBM] [Info] 7.711087 seconds elapsed, finished iteration 29
# [LightGBM] [Info] 7.936477 seconds elapsed, finished iteration 30
# [LightGBM] [Info] Finished training
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading 30 models
# [LightGBM] [Info] Finished initializing prediction
# [LightGBM] [Info] Finished prediction
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading data in 4.072791 seconds
# [LightGBM] [Info] Number of postive: 97452, number of negative: 169155
# [LightGBM] [Info] Number of data: 266607, number of features: 45
# [LightGBM] [Info] Finished initializing training
# [LightGBM] [Info] Started training...
# [LightGBM] [Info] 0.276762 seconds elapsed, finished iteration 1
# [LightGBM] [Info] 0.538888 seconds elapsed, finished iteration 2
# [LightGBM] [Info] 0.814937 seconds elapsed, finished iteration 3
# [LightGBM] [Info] 1.078553 seconds elapsed, finished iteration 4
# [LightGBM] [Info] 1.425136 seconds elapsed, finished iteration 5
# [LightGBM] [Info] 1.690385 seconds elapsed, finished iteration 6
# [LightGBM] [Info] 1.953168 seconds elapsed, finished iteration 7
# [LightGBM] [Info] 2.237476 seconds elapsed, finished iteration 8
# [LightGBM] [Info] 2.516847 seconds elapsed, finished iteration 9
# [LightGBM] [Info] 2.794432 seconds elapsed, finished iteration 10
# [LightGBM] [Info] 3.063649 seconds elapsed, finished iteration 11
# [LightGBM] [Info] 3.332494 seconds elapsed, finished iteration 12
# [LightGBM] [Info] 3.587127 seconds elapsed, finished iteration 13
# [LightGBM] [Info] 3.841832 seconds elapsed, finished iteration 14
# [LightGBM] [Info] 4.094615 seconds elapsed, finished iteration 15
# [LightGBM] [Info] 4.339094 seconds elapsed, finished iteration 16
# [LightGBM] [Info] 4.591195 seconds elapsed, finished iteration 17
# [LightGBM] [Info] 4.830051 seconds elapsed, finished iteration 18
# [LightGBM] [Info] 5.085439 seconds elapsed, finished iteration 19
# [LightGBM] [Info] 5.338037 seconds elapsed, finished iteration 20
# [LightGBM] [Info] 5.582639 seconds elapsed, finished iteration 21
# [LightGBM] [Info] 5.819407 seconds elapsed, finished iteration 22
# [LightGBM] [Info] 6.085520 seconds elapsed, finished iteration 23
# [LightGBM] [Info] 6.309083 seconds elapsed, finished iteration 24
# [LightGBM] [Info] 6.609663 seconds elapsed, finished iteration 25
# [LightGBM] [Info] 6.901636 seconds elapsed, finished iteration 26
# [LightGBM] [Info] 7.123924 seconds elapsed, finished iteration 27
# [LightGBM] [Info] 7.342495 seconds elapsed, finished iteration 28
# [LightGBM] [Info] 7.570604 seconds elapsed, finished iteration 29
# [LightGBM] [Info] 7.788626 seconds elapsed, finished iteration 30
# [LightGBM] [Info] Finished training
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading 30 models
# [LightGBM] [Info] Finished initializing prediction
# [LightGBM] [Info] Finished prediction
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading data in 3.926032 seconds
# [LightGBM] [Info] Number of postive: 97136, number of negative: 169471
# [LightGBM] [Info] Number of data: 266607, number of features: 45
# [LightGBM] [Info] Finished initializing training
# [LightGBM] [Info] Started training...
# [LightGBM] [Info] 0.391626 seconds elapsed, finished iteration 1
# [LightGBM] [Info] 0.756853 seconds elapsed, finished iteration 2
# [LightGBM] [Info] 1.040813 seconds elapsed, finished iteration 3
# [LightGBM] [Info] 1.302104 seconds elapsed, finished iteration 4
# [LightGBM] [Info] 1.570615 seconds elapsed, finished iteration 5
# [LightGBM] [Info] 1.831029 seconds elapsed, finished iteration 6
# [LightGBM] [Info] 2.085113 seconds elapsed, finished iteration 7
# [LightGBM] [Info] 2.347549 seconds elapsed, finished iteration 8
# [LightGBM] [Info] 2.603660 seconds elapsed, finished iteration 9
# [LightGBM] [Info] 2.864263 seconds elapsed, finished iteration 10
# [LightGBM] [Info] 3.124364 seconds elapsed, finished iteration 11
# [LightGBM] [Info] 3.381287 seconds elapsed, finished iteration 12
# [LightGBM] [Info] 3.672122 seconds elapsed, finished iteration 13
# [LightGBM] [Info] 3.930014 seconds elapsed, finished iteration 14
# [LightGBM] [Info] 4.179973 seconds elapsed, finished iteration 15
# [LightGBM] [Info] 4.430780 seconds elapsed, finished iteration 16
# [LightGBM] [Info] 4.679133 seconds elapsed, finished iteration 17
# [LightGBM] [Info] 4.915176 seconds elapsed, finished iteration 18
# [LightGBM] [Info] 5.148377 seconds elapsed, finished iteration 19
# [LightGBM] [Info] 5.383002 seconds elapsed, finished iteration 20
# [LightGBM] [Info] 5.626482 seconds elapsed, finished iteration 21
# [LightGBM] [Info] 5.857010 seconds elapsed, finished iteration 22
# [LightGBM] [Info] 6.124208 seconds elapsed, finished iteration 23
# [LightGBM] [Info] 6.344630 seconds elapsed, finished iteration 24
# [LightGBM] [Info] 6.636291 seconds elapsed, finished iteration 25
# [LightGBM] [Info] 6.957541 seconds elapsed, finished iteration 26
# [LightGBM] [Info] 7.170871 seconds elapsed, finished iteration 27
# [LightGBM] [Info] 7.475718 seconds elapsed, finished iteration 28
# [LightGBM] [Info] 7.683879 seconds elapsed, finished iteration 29
# [LightGBM] [Info] 7.915558 seconds elapsed, finished iteration 30
# [LightGBM] [Info] Finished training
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading 30 models
# [LightGBM] [Info] Finished initializing prediction
# [LightGBM] [Info] Finished prediction
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading data in 3.859108 seconds
# [LightGBM] [Info] Number of postive: 97213, number of negative: 169394
# [LightGBM] [Info] Number of data: 266607, number of features: 45
# [LightGBM] [Info] Finished initializing training
# [LightGBM] [Info] Started training...
# [LightGBM] [Info] 0.265017 seconds elapsed, finished iteration 1
# [LightGBM] [Info] 0.530239 seconds elapsed, finished iteration 2
# [LightGBM] [Info] 0.792616 seconds elapsed, finished iteration 3
# [LightGBM] [Info] 1.055014 seconds elapsed, finished iteration 4
# [LightGBM] [Info] 1.311916 seconds elapsed, finished iteration 5
# [LightGBM] [Info] 1.566970 seconds elapsed, finished iteration 6
# [LightGBM] [Info] 1.837938 seconds elapsed, finished iteration 7
# [LightGBM] [Info] 2.107334 seconds elapsed, finished iteration 8
# [LightGBM] [Info] 2.463018 seconds elapsed, finished iteration 9
# [LightGBM] [Info] 2.766758 seconds elapsed, finished iteration 10
# [LightGBM] [Info] 3.036056 seconds elapsed, finished iteration 11
# [LightGBM] [Info] 3.296676 seconds elapsed, finished iteration 12
# [LightGBM] [Info] 3.548886 seconds elapsed, finished iteration 13
# [LightGBM] [Info] 3.809203 seconds elapsed, finished iteration 14
# [LightGBM] [Info] 4.061090 seconds elapsed, finished iteration 15
# [LightGBM] [Info] 4.307923 seconds elapsed, finished iteration 16
# [LightGBM] [Info] 4.554107 seconds elapsed, finished iteration 17
# [LightGBM] [Info] 4.799131 seconds elapsed, finished iteration 18
# [LightGBM] [Info] 5.040418 seconds elapsed, finished iteration 19
# [LightGBM] [Info] 5.350226 seconds elapsed, finished iteration 20
# [LightGBM] [Info] 5.664330 seconds elapsed, finished iteration 21
# [LightGBM] [Info] 5.879028 seconds elapsed, finished iteration 22
# [LightGBM] [Info] 6.112119 seconds elapsed, finished iteration 23
# [LightGBM] [Info] 6.346157 seconds elapsed, finished iteration 24
# [LightGBM] [Info] 6.569997 seconds elapsed, finished iteration 25
# [LightGBM] [Info] 6.799148 seconds elapsed, finished iteration 26
# [LightGBM] [Info] 7.015225 seconds elapsed, finished iteration 27
# [LightGBM] [Info] 7.242769 seconds elapsed, finished iteration 28
# [LightGBM] [Info] 7.456682 seconds elapsed, finished iteration 29
# [LightGBM] [Info] 7.690653 seconds elapsed, finished iteration 30
# [LightGBM] [Info] Finished training
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading 30 models
# [LightGBM] [Info] Finished initializing prediction
# [LightGBM] [Info] Finished prediction
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading data in 3.878673 seconds
# [LightGBM] [Info] Number of postive: 97223, number of negative: 169385
# [LightGBM] [Info] Number of data: 266608, number of features: 45
# [LightGBM] [Info] Finished initializing training
# [LightGBM] [Info] Started training...
# [LightGBM] [Info] 0.281648 seconds elapsed, finished iteration 1
# [LightGBM] [Info] 0.592279 seconds elapsed, finished iteration 2
# [LightGBM] [Info] 0.890091 seconds elapsed, finished iteration 3
# [LightGBM] [Info] 1.166064 seconds elapsed, finished iteration 4
# [LightGBM] [Info] 1.442442 seconds elapsed, finished iteration 5
# [LightGBM] [Info] 1.735076 seconds elapsed, finished iteration 6
# [LightGBM] [Info] 2.008089 seconds elapsed, finished iteration 7
# [LightGBM] [Info] 2.275485 seconds elapsed, finished iteration 8
# [LightGBM] [Info] 2.531052 seconds elapsed, finished iteration 9
# [LightGBM] [Info] 2.792144 seconds elapsed, finished iteration 10
# [LightGBM] [Info] 3.051799 seconds elapsed, finished iteration 11
# [LightGBM] [Info] 3.312966 seconds elapsed, finished iteration 12
# [LightGBM] [Info] 3.564736 seconds elapsed, finished iteration 13
# [LightGBM] [Info] 3.912283 seconds elapsed, finished iteration 14
# [LightGBM] [Info] 4.174518 seconds elapsed, finished iteration 15
# [LightGBM] [Info] 4.436049 seconds elapsed, finished iteration 16
# [LightGBM] [Info] 4.697655 seconds elapsed, finished iteration 17
# [LightGBM] [Info] 4.954648 seconds elapsed, finished iteration 18
# [LightGBM] [Info] 5.199745 seconds elapsed, finished iteration 19
# [LightGBM] [Info] 5.429449 seconds elapsed, finished iteration 20
# [LightGBM] [Info] 5.673811 seconds elapsed, finished iteration 21
# [LightGBM] [Info] 5.918133 seconds elapsed, finished iteration 22
# [LightGBM] [Info] 6.238575 seconds elapsed, finished iteration 23
# [LightGBM] [Info] 6.477339 seconds elapsed, finished iteration 24
# [LightGBM] [Info] 6.709577 seconds elapsed, finished iteration 25
# [LightGBM] [Info] 6.972866 seconds elapsed, finished iteration 26
# [LightGBM] [Info] 7.206638 seconds elapsed, finished iteration 27
# [LightGBM] [Info] 7.418054 seconds elapsed, finished iteration 28
# [LightGBM] [Info] 7.683511 seconds elapsed, finished iteration 29
# [LightGBM] [Info] 7.927623 seconds elapsed, finished iteration 30
# [LightGBM] [Info] 8.183304 seconds elapsed, finished iteration 31
# [LightGBM] [Info] 8.572177 seconds elapsed, finished iteration 32
# [LightGBM] [Info] 8.827280 seconds elapsed, finished iteration 33
# [LightGBM] [Info] 9.064508 seconds elapsed, finished iteration 34
# [LightGBM] [Info] 9.284811 seconds elapsed, finished iteration 35
# [LightGBM] [Info] 9.496257 seconds elapsed, finished iteration 36
# [LightGBM] [Info] 9.688926 seconds elapsed, finished iteration 37
# [LightGBM] [Info] 9.967131 seconds elapsed, finished iteration 38
# [LightGBM] [Info] 10.191555 seconds elapsed, finished iteration 39
# [LightGBM] [Info] 10.385519 seconds elapsed, finished iteration 40
# [LightGBM] [Info] 10.583022 seconds elapsed, finished iteration 41
# [LightGBM] [Info] 10.762915 seconds elapsed, finished iteration 42
# [LightGBM] [Info] 10.985582 seconds elapsed, finished iteration 43
# [LightGBM] [Info] 11.188816 seconds elapsed, finished iteration 44
# [LightGBM] [Info] 11.379017 seconds elapsed, finished iteration 45
# [LightGBM] [Info] 11.554433 seconds elapsed, finished iteration 46
# [LightGBM] [Info] 11.748807 seconds elapsed, finished iteration 47
# [LightGBM] [Info] 12.004491 seconds elapsed, finished iteration 48
# [LightGBM] [Info] 12.184895 seconds elapsed, finished iteration 49
# [LightGBM] [Info] 12.356119 seconds elapsed, finished iteration 50
# [LightGBM] [Info] Finished training
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading 50 models
# [LightGBM] [Info] Finished initializing prediction
# [LightGBM] [Info] Finished prediction
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading data in 4.000326 seconds
# [LightGBM] [Info] Number of postive: 97373, number of negative: 169234
# [LightGBM] [Info] Number of data: 266607, number of features: 45
# [LightGBM] [Info] Finished initializing training
# [LightGBM] [Info] Started training...
# [LightGBM] [Info] 0.262120 seconds elapsed, finished iteration 1
# [LightGBM] [Info] 0.528679 seconds elapsed, finished iteration 2
# [LightGBM] [Info] 0.803753 seconds elapsed, finished iteration 3
# [LightGBM] [Info] 1.083155 seconds elapsed, finished iteration 4
# [LightGBM] [Info] 1.357339 seconds elapsed, finished iteration 5
# [LightGBM] [Info] 1.626174 seconds elapsed, finished iteration 6
# [LightGBM] [Info] 1.890193 seconds elapsed, finished iteration 7
# [LightGBM] [Info] 2.142533 seconds elapsed, finished iteration 8
# [LightGBM] [Info] 2.406122 seconds elapsed, finished iteration 9
# [LightGBM] [Info] 2.660405 seconds elapsed, finished iteration 10
# [LightGBM] [Info] 2.901301 seconds elapsed, finished iteration 11
# [LightGBM] [Info] 3.200694 seconds elapsed, finished iteration 12
# [LightGBM] [Info] 3.579288 seconds elapsed, finished iteration 13
# [LightGBM] [Info] 3.841645 seconds elapsed, finished iteration 14
# [LightGBM] [Info] 4.093232 seconds elapsed, finished iteration 15
# [LightGBM] [Info] 4.349356 seconds elapsed, finished iteration 16
# [LightGBM] [Info] 4.647493 seconds elapsed, finished iteration 17
# [LightGBM] [Info] 4.878731 seconds elapsed, finished iteration 18
# [LightGBM] [Info] 5.154510 seconds elapsed, finished iteration 19
# [LightGBM] [Info] 5.444465 seconds elapsed, finished iteration 20
# [LightGBM] [Info] 5.681019 seconds elapsed, finished iteration 21
# [LightGBM] [Info] 5.911673 seconds elapsed, finished iteration 22
# [LightGBM] [Info] 6.157631 seconds elapsed, finished iteration 23
# [LightGBM] [Info] 6.386312 seconds elapsed, finished iteration 24
# [LightGBM] [Info] 6.684993 seconds elapsed, finished iteration 25
# [LightGBM] [Info] 6.997001 seconds elapsed, finished iteration 26
# [LightGBM] [Info] 7.268337 seconds elapsed, finished iteration 27
# [LightGBM] [Info] 7.505185 seconds elapsed, finished iteration 28
# [LightGBM] [Info] 7.851629 seconds elapsed, finished iteration 29
# [LightGBM] [Info] 8.198350 seconds elapsed, finished iteration 30
# [LightGBM] [Info] 8.445080 seconds elapsed, finished iteration 31
# [LightGBM] [Info] 8.728550 seconds elapsed, finished iteration 32
# [LightGBM] [Info] 9.007713 seconds elapsed, finished iteration 33
# [LightGBM] [Info] 9.252380 seconds elapsed, finished iteration 34
# [LightGBM] [Info] 9.492412 seconds elapsed, finished iteration 35
# [LightGBM] [Info] 9.744934 seconds elapsed, finished iteration 36
# [LightGBM] [Info] 9.991979 seconds elapsed, finished iteration 37
# [LightGBM] [Info] 10.274759 seconds elapsed, finished iteration 38
# [LightGBM] [Info] 10.635893 seconds elapsed, finished iteration 39
# [LightGBM] [Info] 10.873993 seconds elapsed, finished iteration 40
# [LightGBM] [Info] 11.106609 seconds elapsed, finished iteration 41
# [LightGBM] [Info] 11.311118 seconds elapsed, finished iteration 42
# [LightGBM] [Info] 11.617536 seconds elapsed, finished iteration 43
# [LightGBM] [Info] 11.908377 seconds elapsed, finished iteration 44
# [LightGBM] [Info] 12.101642 seconds elapsed, finished iteration 45
# [LightGBM] [Info] 12.280214 seconds elapsed, finished iteration 46
# [LightGBM] [Info] 12.490806 seconds elapsed, finished iteration 47
# [LightGBM] [Info] 12.680878 seconds elapsed, finished iteration 48
# [LightGBM] [Info] 12.894185 seconds elapsed, finished iteration 49
# [LightGBM] [Info] 13.103337 seconds elapsed, finished iteration 50
# [LightGBM] [Info] Finished training
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading 50 models
# [LightGBM] [Info] Finished initializing prediction
# [LightGBM] [Info] Finished prediction
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading data in 4.180779 seconds
# [LightGBM] [Info] Number of postive: 97274, number of negative: 169333
# [LightGBM] [Info] Number of data: 266607, number of features: 45
# [LightGBM] [Info] Finished initializing training
# [LightGBM] [Info] Started training...
# [LightGBM] [Info] 0.289591 seconds elapsed, finished iteration 1
# [LightGBM] [Info] 0.564736 seconds elapsed, finished iteration 2
# [LightGBM] [Info] 0.848939 seconds elapsed, finished iteration 3
# [LightGBM] [Info] 1.124393 seconds elapsed, finished iteration 4
# [LightGBM] [Info] 1.447725 seconds elapsed, finished iteration 5
# [LightGBM] [Info] 1.688613 seconds elapsed, finished iteration 6
# [LightGBM] [Info] 2.040503 seconds elapsed, finished iteration 7
# [LightGBM] [Info] 2.393315 seconds elapsed, finished iteration 8
# [LightGBM] [Info] 2.591500 seconds elapsed, finished iteration 9
# [LightGBM] [Info] 2.908329 seconds elapsed, finished iteration 10
# [LightGBM] [Info] 3.112216 seconds elapsed, finished iteration 11
# [LightGBM] [Info] 3.304242 seconds elapsed, finished iteration 12
# [LightGBM] [Info] 3.488561 seconds elapsed, finished iteration 13
# [LightGBM] [Info] 3.804903 seconds elapsed, finished iteration 14
# [LightGBM] [Info] 4.133392 seconds elapsed, finished iteration 15
# [LightGBM] [Info] 4.430476 seconds elapsed, finished iteration 16
# [LightGBM] [Info] 4.629817 seconds elapsed, finished iteration 17
# [LightGBM] [Info] 4.828906 seconds elapsed, finished iteration 18
# [LightGBM] [Info] 5.021844 seconds elapsed, finished iteration 19
# [LightGBM] [Info] 5.221601 seconds elapsed, finished iteration 20
# [LightGBM] [Info] 5.419450 seconds elapsed, finished iteration 21
# [LightGBM] [Info] 5.614414 seconds elapsed, finished iteration 22
# [LightGBM] [Info] 5.811833 seconds elapsed, finished iteration 23
# [LightGBM] [Info] 6.006642 seconds elapsed, finished iteration 24
# [LightGBM] [Info] 6.196022 seconds elapsed, finished iteration 25
# [LightGBM] [Info] 6.502891 seconds elapsed, finished iteration 26
# [LightGBM] [Info] 6.684869 seconds elapsed, finished iteration 27
# [LightGBM] [Info] 6.854427 seconds elapsed, finished iteration 28
# [LightGBM] [Info] 7.023724 seconds elapsed, finished iteration 29
# [LightGBM] [Info] 7.194033 seconds elapsed, finished iteration 30
# [LightGBM] [Info] 7.375082 seconds elapsed, finished iteration 31
# [LightGBM] [Info] 7.530712 seconds elapsed, finished iteration 32
# [LightGBM] [Info] 7.696265 seconds elapsed, finished iteration 33
# [LightGBM] [Info] 7.863829 seconds elapsed, finished iteration 34
# [LightGBM] [Info] 8.019400 seconds elapsed, finished iteration 35
# [LightGBM] [Info] 8.190309 seconds elapsed, finished iteration 36
# [LightGBM] [Info] 8.346768 seconds elapsed, finished iteration 37
# [LightGBM] [Info] 8.497132 seconds elapsed, finished iteration 38
# [LightGBM] [Info] 8.661122 seconds elapsed, finished iteration 39
# [LightGBM] [Info] 8.818649 seconds elapsed, finished iteration 40
# [LightGBM] [Info] 8.999355 seconds elapsed, finished iteration 41
# [LightGBM] [Info] 9.364539 seconds elapsed, finished iteration 42
# [LightGBM] [Info] 9.660032 seconds elapsed, finished iteration 43
# [LightGBM] [Info] 9.822209 seconds elapsed, finished iteration 44
# [LightGBM] [Info] 9.977361 seconds elapsed, finished iteration 45
# [LightGBM] [Info] 10.244491 seconds elapsed, finished iteration 46
# [LightGBM] [Info] 10.396621 seconds elapsed, finished iteration 47
# [LightGBM] [Info] 10.540625 seconds elapsed, finished iteration 48
# [LightGBM] [Info] 10.696076 seconds elapsed, finished iteration 49
# [LightGBM] [Info] 10.842318 seconds elapsed, finished iteration 50
# [LightGBM] [Info] Finished training
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading 50 models
# [LightGBM] [Info] Finished initializing prediction
# [LightGBM] [Info] Finished prediction
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading data in 3.877347 seconds
# [LightGBM] [Info] Number of postive: 97262, number of negative: 169345
# [LightGBM] [Info] Number of data: 266607, number of features: 45
# [LightGBM] [Info] Finished initializing training
# [LightGBM] [Info] Started training...
# [LightGBM] [Info] 0.274775 seconds elapsed, finished iteration 1
# [LightGBM] [Info] 0.723595 seconds elapsed, finished iteration 2
# [LightGBM] [Info] 1.122347 seconds elapsed, finished iteration 3
# [LightGBM] [Info] 1.410878 seconds elapsed, finished iteration 4
# [LightGBM] [Info] 1.788134 seconds elapsed, finished iteration 5
# [LightGBM] [Info] 2.077912 seconds elapsed, finished iteration 6
# [LightGBM] [Info] 2.373204 seconds elapsed, finished iteration 7
# [LightGBM] [Info] 2.679981 seconds elapsed, finished iteration 8
# [LightGBM] [Info] 2.982274 seconds elapsed, finished iteration 9
# [LightGBM] [Info] 3.285977 seconds elapsed, finished iteration 10
# [LightGBM] [Info] 3.598491 seconds elapsed, finished iteration 11
# [LightGBM] [Info] 3.866736 seconds elapsed, finished iteration 12
# [LightGBM] [Info] 4.224042 seconds elapsed, finished iteration 13
# [LightGBM] [Info] 4.534366 seconds elapsed, finished iteration 14
# [LightGBM] [Info] 4.828280 seconds elapsed, finished iteration 15
# [LightGBM] [Info] 5.083408 seconds elapsed, finished iteration 16
# [LightGBM] [Info] 5.331283 seconds elapsed, finished iteration 17
# [LightGBM] [Info] 5.579425 seconds elapsed, finished iteration 18
# [LightGBM] [Info] 5.828637 seconds elapsed, finished iteration 19
# [LightGBM] [Info] 6.066559 seconds elapsed, finished iteration 20
# [LightGBM] [Info] 6.312272 seconds elapsed, finished iteration 21
# [LightGBM] [Info] 6.558137 seconds elapsed, finished iteration 22
# [LightGBM] [Info] 6.805032 seconds elapsed, finished iteration 23
# [LightGBM] [Info] 7.053180 seconds elapsed, finished iteration 24
# [LightGBM] [Info] 7.299957 seconds elapsed, finished iteration 25
# [LightGBM] [Info] 7.584221 seconds elapsed, finished iteration 26
# [LightGBM] [Info] 7.920414 seconds elapsed, finished iteration 27
# [LightGBM] [Info] 8.160555 seconds elapsed, finished iteration 28
# [LightGBM] [Info] 8.403551 seconds elapsed, finished iteration 29
# [LightGBM] [Info] 8.636612 seconds elapsed, finished iteration 30
# [LightGBM] [Info] 8.872059 seconds elapsed, finished iteration 31
# [LightGBM] [Info] 9.151522 seconds elapsed, finished iteration 32
# [LightGBM] [Info] 9.369619 seconds elapsed, finished iteration 33
# [LightGBM] [Info] 9.624502 seconds elapsed, finished iteration 34
# [LightGBM] [Info] 9.890998 seconds elapsed, finished iteration 35
# [LightGBM] [Info] 10.095752 seconds elapsed, finished iteration 36
# [LightGBM] [Info] 10.319203 seconds elapsed, finished iteration 37
# [LightGBM] [Info] 10.531195 seconds elapsed, finished iteration 38
# [LightGBM] [Info] 10.737264 seconds elapsed, finished iteration 39
# [LightGBM] [Info] 10.967341 seconds elapsed, finished iteration 40
# [LightGBM] [Info] 11.180492 seconds elapsed, finished iteration 41
# [LightGBM] [Info] 11.401927 seconds elapsed, finished iteration 42
# [LightGBM] [Info] 11.645666 seconds elapsed, finished iteration 43
# [LightGBM] [Info] 11.894459 seconds elapsed, finished iteration 44
# [LightGBM] [Info] 12.205071 seconds elapsed, finished iteration 45
# [LightGBM] [Info] 12.552915 seconds elapsed, finished iteration 46
# [LightGBM] [Info] 12.881493 seconds elapsed, finished iteration 47
# [LightGBM] [Info] 13.087327 seconds elapsed, finished iteration 48
# [LightGBM] [Info] 13.313418 seconds elapsed, finished iteration 49
# [LightGBM] [Info] 13.509981 seconds elapsed, finished iteration 50
# [LightGBM] [Info] Finished training
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading 50 models
# [LightGBM] [Info] Finished initializing prediction
# [LightGBM] [Info] Finished prediction
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading data in 4.179351 seconds
# [LightGBM] [Info] Number of postive: 97228, number of negative: 169379
# [LightGBM] [Info] Number of data: 266607, number of features: 45
# [LightGBM] [Info] Finished initializing training
# [LightGBM] [Info] Started training...
# [LightGBM] [Info] 0.267451 seconds elapsed, finished iteration 1
# [LightGBM] [Info] 0.543495 seconds elapsed, finished iteration 2
# [LightGBM] [Info] 0.823368 seconds elapsed, finished iteration 3
# [LightGBM] [Info] 1.091830 seconds elapsed, finished iteration 4
# [LightGBM] [Info] 1.360041 seconds elapsed, finished iteration 5
# [LightGBM] [Info] 1.629813 seconds elapsed, finished iteration 6
# [LightGBM] [Info] 1.883619 seconds elapsed, finished iteration 7
# [LightGBM] [Info] 2.138229 seconds elapsed, finished iteration 8
# [LightGBM] [Info] 2.399781 seconds elapsed, finished iteration 9
# [LightGBM] [Info] 2.684815 seconds elapsed, finished iteration 10
# [LightGBM] [Info] 2.947190 seconds elapsed, finished iteration 11
# [LightGBM] [Info] 3.202048 seconds elapsed, finished iteration 12
# [LightGBM] [Info] 3.457363 seconds elapsed, finished iteration 13
# [LightGBM] [Info] 3.712949 seconds elapsed, finished iteration 14
# [LightGBM] [Info] 3.962936 seconds elapsed, finished iteration 15
# [LightGBM] [Info] 4.219987 seconds elapsed, finished iteration 16
# [LightGBM] [Info] 4.477388 seconds elapsed, finished iteration 17
# [LightGBM] [Info] 4.714437 seconds elapsed, finished iteration 18
# [LightGBM] [Info] 4.957057 seconds elapsed, finished iteration 19
# [LightGBM] [Info] 5.192875 seconds elapsed, finished iteration 20
# [LightGBM] [Info] 5.481587 seconds elapsed, finished iteration 21
# [LightGBM] [Info] 5.717205 seconds elapsed, finished iteration 22
# [LightGBM] [Info] 5.952858 seconds elapsed, finished iteration 23
# [LightGBM] [Info] 6.224404 seconds elapsed, finished iteration 24
# [LightGBM] [Info] 6.579339 seconds elapsed, finished iteration 25
# [LightGBM] [Info] 6.899468 seconds elapsed, finished iteration 26
# [LightGBM] [Info] 7.136508 seconds elapsed, finished iteration 27
# [LightGBM] [Info] 7.407228 seconds elapsed, finished iteration 28
# [LightGBM] [Info] 7.660554 seconds elapsed, finished iteration 29
# [LightGBM] [Info] 7.891258 seconds elapsed, finished iteration 30
# [LightGBM] [Info] 8.123634 seconds elapsed, finished iteration 31
# [LightGBM] [Info] 8.392270 seconds elapsed, finished iteration 32
# [LightGBM] [Info] 8.637001 seconds elapsed, finished iteration 33
# [LightGBM] [Info] 8.882182 seconds elapsed, finished iteration 34
# [LightGBM] [Info] 9.125530 seconds elapsed, finished iteration 35
# [LightGBM] [Info] 9.345790 seconds elapsed, finished iteration 36
# [LightGBM] [Info] 9.556172 seconds elapsed, finished iteration 37
# [LightGBM] [Info] 9.763421 seconds elapsed, finished iteration 38
# [LightGBM] [Info] 9.980812 seconds elapsed, finished iteration 39
# [LightGBM] [Info] 10.198446 seconds elapsed, finished iteration 40
# [LightGBM] [Info] 10.415524 seconds elapsed, finished iteration 41
# [LightGBM] [Info] 10.639364 seconds elapsed, finished iteration 42
# [LightGBM] [Info] 10.832284 seconds elapsed, finished iteration 43
# [LightGBM] [Info] 11.043767 seconds elapsed, finished iteration 44
# [LightGBM] [Info] 11.296757 seconds elapsed, finished iteration 45
# [LightGBM] [Info] 11.520097 seconds elapsed, finished iteration 46
# [LightGBM] [Info] 11.729477 seconds elapsed, finished iteration 47
# [LightGBM] [Info] 11.934866 seconds elapsed, finished iteration 48
# [LightGBM] [Info] 12.151293 seconds elapsed, finished iteration 49
# [LightGBM] [Info] 12.359314 seconds elapsed, finished iteration 50
# [LightGBM] [Info] Finished training
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading 50 models
# [LightGBM] [Info] Finished initializing prediction
# [LightGBM] [Info] Finished prediction
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading data in 3.810775 seconds
# [LightGBM] [Info] Number of postive: 97202, number of negative: 169406
# [LightGBM] [Info] Number of data: 266608, number of features: 45
# [LightGBM] [Info] Finished initializing training
# [LightGBM] [Info] Started training...
# [LightGBM] [Info] 0.275371 seconds elapsed, finished iteration 1
# [LightGBM] [Info] 0.629548 seconds elapsed, finished iteration 2
# [LightGBM] [Info] 0.935880 seconds elapsed, finished iteration 3
# [LightGBM] [Info] 1.252116 seconds elapsed, finished iteration 4
# [LightGBM] [Info] 1.557767 seconds elapsed, finished iteration 5
# [LightGBM] [Info] 1.878183 seconds elapsed, finished iteration 6
# [LightGBM] [Info] 2.182672 seconds elapsed, finished iteration 7
# [LightGBM] [Info] 2.506078 seconds elapsed, finished iteration 8
# [LightGBM] [Info] 2.791377 seconds elapsed, finished iteration 9
# [LightGBM] [Info] 3.045685 seconds elapsed, finished iteration 10
# [LightGBM] [Info] 3.301753 seconds elapsed, finished iteration 11
# [LightGBM] [Info] 3.560729 seconds elapsed, finished iteration 12
# [LightGBM] [Info] 3.835128 seconds elapsed, finished iteration 13
# [LightGBM] [Info] 4.115019 seconds elapsed, finished iteration 14
# [LightGBM] [Info] 4.345431 seconds elapsed, finished iteration 15
# [LightGBM] [Info] 4.597791 seconds elapsed, finished iteration 16
# [LightGBM] [Info] 4.873621 seconds elapsed, finished iteration 17
# [LightGBM] [Info] 5.120396 seconds elapsed, finished iteration 18
# [LightGBM] [Info] 5.412997 seconds elapsed, finished iteration 19
# [LightGBM] [Info] 5.658582 seconds elapsed, finished iteration 20
# [LightGBM] [Info] 5.967339 seconds elapsed, finished iteration 21
# [LightGBM] [Info] 6.247747 seconds elapsed, finished iteration 22
# [LightGBM] [Info] 6.470797 seconds elapsed, finished iteration 23
# [LightGBM] [Info] 6.696945 seconds elapsed, finished iteration 24
# [LightGBM] [Info] 6.950679 seconds elapsed, finished iteration 25
# [LightGBM] [Info] 7.174007 seconds elapsed, finished iteration 26
# [LightGBM] [Info] 7.471483 seconds elapsed, finished iteration 27
# [LightGBM] [Info] 7.701374 seconds elapsed, finished iteration 28
# [LightGBM] [Info] 7.948116 seconds elapsed, finished iteration 29
# [LightGBM] [Info] 8.169901 seconds elapsed, finished iteration 30
# [LightGBM] [Info] 8.423940 seconds elapsed, finished iteration 31
# [LightGBM] [Info] 8.652703 seconds elapsed, finished iteration 32
# [LightGBM] [Info] 8.870252 seconds elapsed, finished iteration 33
# [LightGBM] [Info] 9.153120 seconds elapsed, finished iteration 34
# [LightGBM] [Info] 9.478852 seconds elapsed, finished iteration 35
# [LightGBM] [Info] 9.764874 seconds elapsed, finished iteration 36
# [LightGBM] [Info] 10.029648 seconds elapsed, finished iteration 37
# [LightGBM] [Info] 10.246747 seconds elapsed, finished iteration 38
# [LightGBM] [Info] 10.424104 seconds elapsed, finished iteration 39
# [LightGBM] [Info] 10.617894 seconds elapsed, finished iteration 40
# [LightGBM] [Info] 10.817905 seconds elapsed, finished iteration 41
# [LightGBM] [Info] 11.037346 seconds elapsed, finished iteration 42
# [LightGBM] [Info] 11.278485 seconds elapsed, finished iteration 43
# [LightGBM] [Info] 11.562659 seconds elapsed, finished iteration 44
# [LightGBM] [Info] 11.794743 seconds elapsed, finished iteration 45
# [LightGBM] [Info] 11.981391 seconds elapsed, finished iteration 46
# [LightGBM] [Info] 12.175595 seconds elapsed, finished iteration 47
# [LightGBM] [Info] 12.404637 seconds elapsed, finished iteration 48
# [LightGBM] [Info] 12.697255 seconds elapsed, finished iteration 49
# [LightGBM] [Info] 12.863445 seconds elapsed, finished iteration 50
# [LightGBM] [Info] 13.183524 seconds elapsed, finished iteration 51
# [LightGBM] [Info] 13.357277 seconds elapsed, finished iteration 52
# [LightGBM] [Info] 13.595856 seconds elapsed, finished iteration 53
# [LightGBM] [Info] 13.810358 seconds elapsed, finished iteration 54
# [LightGBM] [Info] 14.070552 seconds elapsed, finished iteration 55
# [LightGBM] [Info] 14.383036 seconds elapsed, finished iteration 56
# [LightGBM] [Info] 14.571564 seconds elapsed, finished iteration 57
# [LightGBM] [Info] 14.762783 seconds elapsed, finished iteration 58
# [LightGBM] [Info] 14.923443 seconds elapsed, finished iteration 59
# [LightGBM] [Info] 15.071465 seconds elapsed, finished iteration 60
# [LightGBM] [Info] 15.268687 seconds elapsed, finished iteration 61
# [LightGBM] [Info] 15.444909 seconds elapsed, finished iteration 62
# [LightGBM] [Info] 15.614829 seconds elapsed, finished iteration 63
# [LightGBM] [Info] 15.792128 seconds elapsed, finished iteration 64
# [LightGBM] [Info] 15.924553 seconds elapsed, finished iteration 65
# [LightGBM] [Info] 16.057443 seconds elapsed, finished iteration 66
# [LightGBM] [Info] 16.228964 seconds elapsed, finished iteration 67
# [LightGBM] [Info] 16.407185 seconds elapsed, finished iteration 68
# [LightGBM] [Info] 16.570668 seconds elapsed, finished iteration 69
# [LightGBM] [Info] 16.672317 seconds elapsed, finished iteration 70
# [LightGBM] [Info] 16.843125 seconds elapsed, finished iteration 71
# [LightGBM] [Info] 17.019466 seconds elapsed, finished iteration 72
# [LightGBM] [Info] 17.192578 seconds elapsed, finished iteration 73
# [LightGBM] [Info] 17.326627 seconds elapsed, finished iteration 74
# [LightGBM] [Info] 17.516784 seconds elapsed, finished iteration 75
# [LightGBM] [Info] 17.657123 seconds elapsed, finished iteration 76
# [LightGBM] [Info] 17.856791 seconds elapsed, finished iteration 77
# [LightGBM] [Info] 18.012224 seconds elapsed, finished iteration 78
# [LightGBM] [Info] 18.190979 seconds elapsed, finished iteration 79
# [LightGBM] [Info] 18.389164 seconds elapsed, finished iteration 80
# [LightGBM] [Info] 18.526761 seconds elapsed, finished iteration 81
# [LightGBM] [Info] 18.688553 seconds elapsed, finished iteration 82
# [LightGBM] [Info] 18.811305 seconds elapsed, finished iteration 83
# [LightGBM] [Info] 18.956998 seconds elapsed, finished iteration 84
# [LightGBM] [Info] 19.075864 seconds elapsed, finished iteration 85
# [LightGBM] [Info] 19.236314 seconds elapsed, finished iteration 86
# [LightGBM] [Info] 19.372530 seconds elapsed, finished iteration 87
# [LightGBM] [Info] 19.514142 seconds elapsed, finished iteration 88
# [LightGBM] [Info] 19.668970 seconds elapsed, finished iteration 89
# [LightGBM] [Info] 19.873156 seconds elapsed, finished iteration 90
# [LightGBM] [Info] 20.026802 seconds elapsed, finished iteration 91
# [LightGBM] [Info] 20.270595 seconds elapsed, finished iteration 92
# [LightGBM] [Info] 20.527221 seconds elapsed, finished iteration 93
# [LightGBM] [Info] 20.696802 seconds elapsed, finished iteration 94
# [LightGBM] [Info] 20.876610 seconds elapsed, finished iteration 95
# [LightGBM] [Info] 21.055729 seconds elapsed, finished iteration 96
# [LightGBM] [Info] 21.191834 seconds elapsed, finished iteration 97
# [LightGBM] [Info] 21.327148 seconds elapsed, finished iteration 98
# [LightGBM] [Info] 21.446041 seconds elapsed, finished iteration 99
# [LightGBM] [Info] 21.577344 seconds elapsed, finished iteration 100
# [LightGBM] [Info] Finished training
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading 100 models
# [LightGBM] [Info] Finished initializing prediction
# [LightGBM] [Info] Finished prediction
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading data in 3.825179 seconds
# [LightGBM] [Info] Number of postive: 97150, number of negative: 169457
# [LightGBM] [Info] Number of data: 266607, number of features: 45
# [LightGBM] [Info] Finished initializing training
# [LightGBM] [Info] Started training...
# [LightGBM] [Info] 0.281600 seconds elapsed, finished iteration 1
# [LightGBM] [Info] 0.559054 seconds elapsed, finished iteration 2
# [LightGBM] [Info] 0.833578 seconds elapsed, finished iteration 3
# [LightGBM] [Info] 1.172068 seconds elapsed, finished iteration 4
# [LightGBM] [Info] 1.446389 seconds elapsed, finished iteration 5
# [LightGBM] [Info] 1.797620 seconds elapsed, finished iteration 6
# [LightGBM] [Info] 2.074958 seconds elapsed, finished iteration 7
# [LightGBM] [Info] 2.348179 seconds elapsed, finished iteration 8
# [LightGBM] [Info] 2.623044 seconds elapsed, finished iteration 9
# [LightGBM] [Info] 2.917207 seconds elapsed, finished iteration 10
# [LightGBM] [Info] 3.204551 seconds elapsed, finished iteration 11
# [LightGBM] [Info] 3.463369 seconds elapsed, finished iteration 12
# [LightGBM] [Info] 3.709578 seconds elapsed, finished iteration 13
# [LightGBM] [Info] 3.948813 seconds elapsed, finished iteration 14
# [LightGBM] [Info] 4.189626 seconds elapsed, finished iteration 15
# [LightGBM] [Info] 4.424399 seconds elapsed, finished iteration 16
# [LightGBM] [Info] 4.660837 seconds elapsed, finished iteration 17
# [LightGBM] [Info] 4.889259 seconds elapsed, finished iteration 18
# [LightGBM] [Info] 5.133728 seconds elapsed, finished iteration 19
# [LightGBM] [Info] 5.384241 seconds elapsed, finished iteration 20
# [LightGBM] [Info] 5.622138 seconds elapsed, finished iteration 21
# [LightGBM] [Info] 5.861852 seconds elapsed, finished iteration 22
# [LightGBM] [Info] 6.095515 seconds elapsed, finished iteration 23
# [LightGBM] [Info] 6.325404 seconds elapsed, finished iteration 24
# [LightGBM] [Info] 6.556262 seconds elapsed, finished iteration 25
# [LightGBM] [Info] 6.788499 seconds elapsed, finished iteration 26
# [LightGBM] [Info] 7.014930 seconds elapsed, finished iteration 27
# [LightGBM] [Info] 7.295661 seconds elapsed, finished iteration 28
# [LightGBM] [Info] 7.586845 seconds elapsed, finished iteration 29
# [LightGBM] [Info] 7.962028 seconds elapsed, finished iteration 30
# [LightGBM] [Info] 8.341205 seconds elapsed, finished iteration 31
# [LightGBM] [Info] 8.627475 seconds elapsed, finished iteration 32
# [LightGBM] [Info] 8.849888 seconds elapsed, finished iteration 33
# [LightGBM] [Info] 9.062832 seconds elapsed, finished iteration 34
# [LightGBM] [Info] 9.282357 seconds elapsed, finished iteration 35
# [LightGBM] [Info] 9.492498 seconds elapsed, finished iteration 36
# [LightGBM] [Info] 9.696675 seconds elapsed, finished iteration 37
# [LightGBM] [Info] 9.911317 seconds elapsed, finished iteration 38
# [LightGBM] [Info] 10.110960 seconds elapsed, finished iteration 39
# [LightGBM] [Info] 10.349843 seconds elapsed, finished iteration 40
# [LightGBM] [Info] 10.606952 seconds elapsed, finished iteration 41
# [LightGBM] [Info] 10.814245 seconds elapsed, finished iteration 42
# [LightGBM] [Info] 11.024078 seconds elapsed, finished iteration 43
# [LightGBM] [Info] 11.291533 seconds elapsed, finished iteration 44
# [LightGBM] [Info] 11.542239 seconds elapsed, finished iteration 45
# [LightGBM] [Info] 11.781189 seconds elapsed, finished iteration 46
# [LightGBM] [Info] 11.997848 seconds elapsed, finished iteration 47
# [LightGBM] [Info] 12.179617 seconds elapsed, finished iteration 48
# [LightGBM] [Info] 12.365556 seconds elapsed, finished iteration 49
# [LightGBM] [Info] 12.562074 seconds elapsed, finished iteration 50
# [LightGBM] [Info] 12.734709 seconds elapsed, finished iteration 51
# [LightGBM] [Info] 12.939617 seconds elapsed, finished iteration 52
# [LightGBM] [Info] 13.110870 seconds elapsed, finished iteration 53
# [LightGBM] [Info] 13.281103 seconds elapsed, finished iteration 54
# [LightGBM] [Info] 13.459749 seconds elapsed, finished iteration 55
# [LightGBM] [Info] 13.617515 seconds elapsed, finished iteration 56
# [LightGBM] [Info] 13.766666 seconds elapsed, finished iteration 57
# [LightGBM] [Info] 13.977741 seconds elapsed, finished iteration 58
# [LightGBM] [Info] 14.149797 seconds elapsed, finished iteration 59
# [LightGBM] [Info] 14.286645 seconds elapsed, finished iteration 60
# [LightGBM] [Info] 14.513115 seconds elapsed, finished iteration 61
# [LightGBM] [Info] 14.731092 seconds elapsed, finished iteration 62
# [LightGBM] [Info] 14.933806 seconds elapsed, finished iteration 63
# [LightGBM] [Info] 15.121710 seconds elapsed, finished iteration 64
# [LightGBM] [Info] 15.303907 seconds elapsed, finished iteration 65
# [LightGBM] [Info] 15.504355 seconds elapsed, finished iteration 66
# [LightGBM] [Info] 15.697912 seconds elapsed, finished iteration 67
# [LightGBM] [Info] 15.841444 seconds elapsed, finished iteration 68
# [LightGBM] [Info] 16.042908 seconds elapsed, finished iteration 69
# [LightGBM] [Info] 16.259396 seconds elapsed, finished iteration 70
# [LightGBM] [Info] 16.444157 seconds elapsed, finished iteration 71
# [LightGBM] [Info] 16.580283 seconds elapsed, finished iteration 72
# [LightGBM] [Info] 16.745604 seconds elapsed, finished iteration 73
# [LightGBM] [Info] 16.908341 seconds elapsed, finished iteration 74
# [LightGBM] [Info] 17.089791 seconds elapsed, finished iteration 75
# [LightGBM] [Info] 17.320317 seconds elapsed, finished iteration 76
# [LightGBM] [Info] 17.543707 seconds elapsed, finished iteration 77
# [LightGBM] [Info] 17.742180 seconds elapsed, finished iteration 78
# [LightGBM] [Info] 17.980654 seconds elapsed, finished iteration 79
# [LightGBM] [Info] 18.114627 seconds elapsed, finished iteration 80
# [LightGBM] [Info] 18.303472 seconds elapsed, finished iteration 81
# [LightGBM] [Info] 18.446469 seconds elapsed, finished iteration 82
# [LightGBM] [Info] 18.610952 seconds elapsed, finished iteration 83
# [LightGBM] [Info] 18.755900 seconds elapsed, finished iteration 84
# [LightGBM] [Info] 18.871374 seconds elapsed, finished iteration 85
# [LightGBM] [Info] 19.014746 seconds elapsed, finished iteration 86
# [LightGBM] [Info] 19.161686 seconds elapsed, finished iteration 87
# [LightGBM] [Info] 19.323311 seconds elapsed, finished iteration 88
# [LightGBM] [Info] 19.511917 seconds elapsed, finished iteration 89
# [LightGBM] [Info] 19.716422 seconds elapsed, finished iteration 90
# [LightGBM] [Info] 19.897464 seconds elapsed, finished iteration 91
# [LightGBM] [Info] 20.052937 seconds elapsed, finished iteration 92
# [LightGBM] [Info] 20.207578 seconds elapsed, finished iteration 93
# [LightGBM] [Info] 20.412881 seconds elapsed, finished iteration 94
# [LightGBM] [Info] 20.570370 seconds elapsed, finished iteration 95
# [LightGBM] [Info] 20.682795 seconds elapsed, finished iteration 96
# [LightGBM] [Info] 20.824009 seconds elapsed, finished iteration 97
# [LightGBM] [Info] 20.952702 seconds elapsed, finished iteration 98
# [LightGBM] [Info] 21.158117 seconds elapsed, finished iteration 99
# [LightGBM] [Info] 21.309403 seconds elapsed, finished iteration 100
# [LightGBM] [Info] Finished training
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading 100 models
# [LightGBM] [Info] Finished initializing prediction
# [LightGBM] [Info] Finished prediction
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading data in 3.879735 seconds
# [LightGBM] [Info] Number of postive: 97350, number of negative: 169257
# [LightGBM] [Info] Number of data: 266607, number of features: 45
# [LightGBM] [Info] Finished initializing training
# [LightGBM] [Info] Started training...
# [LightGBM] [Info] 0.286974 seconds elapsed, finished iteration 1
# [LightGBM] [Info] 0.637054 seconds elapsed, finished iteration 2
# [LightGBM] [Info] 0.995763 seconds elapsed, finished iteration 3
# [LightGBM] [Info] 1.272969 seconds elapsed, finished iteration 4
# [LightGBM] [Info] 1.625485 seconds elapsed, finished iteration 5
# [LightGBM] [Info] 1.890749 seconds elapsed, finished iteration 6
# [LightGBM] [Info] 2.167530 seconds elapsed, finished iteration 7
# [LightGBM] [Info] 2.431498 seconds elapsed, finished iteration 8
# [LightGBM] [Info] 2.706214 seconds elapsed, finished iteration 9
# [LightGBM] [Info] 2.967627 seconds elapsed, finished iteration 10
# [LightGBM] [Info] 3.245895 seconds elapsed, finished iteration 11
# [LightGBM] [Info] 3.507614 seconds elapsed, finished iteration 12
# [LightGBM] [Info] 3.794654 seconds elapsed, finished iteration 13
# [LightGBM] [Info] 4.061422 seconds elapsed, finished iteration 14
# [LightGBM] [Info] 4.345304 seconds elapsed, finished iteration 15
# [LightGBM] [Info] 4.747248 seconds elapsed, finished iteration 16
# [LightGBM] [Info] 5.082598 seconds elapsed, finished iteration 17
# [LightGBM] [Info] 5.415599 seconds elapsed, finished iteration 18
# [LightGBM] [Info] 5.741753 seconds elapsed, finished iteration 19
# [LightGBM] [Info] 6.077253 seconds elapsed, finished iteration 20
# [LightGBM] [Info] 6.416856 seconds elapsed, finished iteration 21
# [LightGBM] [Info] 6.716616 seconds elapsed, finished iteration 22
# ...
# [LightGBM] [Info] 5.098919 seconds elapsed, finished iteration 19
# [LightGBM] [Info] 5.330992 seconds elapsed, finished iteration 20
# [LightGBM] [Info] 5.586156 seconds elapsed, finished iteration 21
# [LightGBM] [Info] 5.827121 seconds elapsed, finished iteration 22
# [LightGBM] [Info] 6.069834 seconds elapsed, finished iteration 23
# [LightGBM] [Info] 6.307071 seconds elapsed, finished iteration 24
# [LightGBM] [Info] 6.542698 seconds elapsed, finished iteration 25
# [LightGBM] [Info] 6.799382 seconds elapsed, finished iteration 26
# [LightGBM] [Info] 7.023144 seconds elapsed, finished iteration 27
# [LightGBM] [Info] 7.336135 seconds elapsed, finished iteration 28
# [LightGBM] [Info] 7.656738 seconds elapsed, finished iteration 29
# [LightGBM] [Info] 7.998945 seconds elapsed, finished iteration 30
# [LightGBM] [Info] 8.347798 seconds elapsed, finished iteration 31
# [LightGBM] [Info] 8.667195 seconds elapsed, finished iteration 32
# [LightGBM] [Info] 8.932241 seconds elapsed, finished iteration 33
# [LightGBM] [Info] 9.252905 seconds elapsed, finished iteration 34
# [LightGBM] [Info] 9.487916 seconds elapsed, finished iteration 35
# [LightGBM] [Info] 9.716165 seconds elapsed, finished iteration 36
# [LightGBM] [Info] 9.979099 seconds elapsed, finished iteration 37
# [LightGBM] [Info] 10.200951 seconds elapsed, finished iteration 38
# [LightGBM] [Info] 10.406721 seconds elapsed, finished iteration 39
# [LightGBM] [Info] 10.614101 seconds elapsed, finished iteration 40
# [LightGBM] [Info] 10.874977 seconds elapsed, finished iteration 41
# [LightGBM] [Info] 11.135693 seconds elapsed, finished iteration 42
# [LightGBM] [Info] 11.323396 seconds elapsed, finished iteration 43
# [LightGBM] [Info] 11.547298 seconds elapsed, finished iteration 44
# [LightGBM] [Info] 11.745229 seconds elapsed, finished iteration 45
# [LightGBM] [Info] 11.931513 seconds elapsed, finished iteration 46
# [LightGBM] [Info] 12.087350 seconds elapsed, finished iteration 47
# [LightGBM] [Info] 12.278824 seconds elapsed, finished iteration 48
# [LightGBM] [Info] 12.455233 seconds elapsed, finished iteration 49
# [LightGBM] [Info] 12.642259 seconds elapsed, finished iteration 50
# [LightGBM] [Info] 12.855461 seconds elapsed, finished iteration 51
# [LightGBM] [Info] 13.044298 seconds elapsed, finished iteration 52
# [LightGBM] [Info] 13.231552 seconds elapsed, finished iteration 53
# [LightGBM] [Info] 13.407234 seconds elapsed, finished iteration 54
# [LightGBM] [Info] 13.566122 seconds elapsed, finished iteration 55
# [LightGBM] [Info] 13.785137 seconds elapsed, finished iteration 56
# [LightGBM] [Info] 13.972820 seconds elapsed, finished iteration 57
# [LightGBM] [Info] 14.143603 seconds elapsed, finished iteration 58
# [LightGBM] [Info] 14.331877 seconds elapsed, finished iteration 59
# [LightGBM] [Info] 14.536458 seconds elapsed, finished iteration 60
# [LightGBM] [Info] 14.710796 seconds elapsed, finished iteration 61
# [LightGBM] [Info] 14.896489 seconds elapsed, finished iteration 62
# [LightGBM] [Info] 15.023466 seconds elapsed, finished iteration 63
# [LightGBM] [Info] 15.171097 seconds elapsed, finished iteration 64
# [LightGBM] [Info] 15.336888 seconds elapsed, finished iteration 65
# [LightGBM] [Info] 15.522558 seconds elapsed, finished iteration 66
# [LightGBM] [Info] 15.653015 seconds elapsed, finished iteration 67
# [LightGBM] [Info] 15.775673 seconds elapsed, finished iteration 68
# [LightGBM] [Info] 15.948584 seconds elapsed, finished iteration 69
# [LightGBM] [Info] 16.180541 seconds elapsed, finished iteration 70
# [LightGBM] [Info] 16.391892 seconds elapsed, finished iteration 71
# [LightGBM] [Info] 16.579849 seconds elapsed, finished iteration 72
# [LightGBM] [Info] 16.752960 seconds elapsed, finished iteration 73
# [LightGBM] [Info] 16.953689 seconds elapsed, finished iteration 74
# [LightGBM] [Info] 17.195959 seconds elapsed, finished iteration 75
# [LightGBM] [Info] 17.435369 seconds elapsed, finished iteration 76
# [LightGBM] [Info] 17.603339 seconds elapsed, finished iteration 77
# [LightGBM] [Info] 17.754641 seconds elapsed, finished iteration 78
# [LightGBM] [Info] 17.937046 seconds elapsed, finished iteration 79
# [LightGBM] [Info] 18.196060 seconds elapsed, finished iteration 80
# [LightGBM] [Info] 18.435547 seconds elapsed, finished iteration 81
# [LightGBM] [Info] 18.611467 seconds elapsed, finished iteration 82
# [LightGBM] [Info] 18.716986 seconds elapsed, finished iteration 83
# [LightGBM] [Info] 18.895697 seconds elapsed, finished iteration 84
# [LightGBM] [Info] 19.000405 seconds elapsed, finished iteration 85
# [LightGBM] [Info] 19.105894 seconds elapsed, finished iteration 86
# [LightGBM] [Info] 19.341617 seconds elapsed, finished iteration 87
# [LightGBM] [Info] 19.462739 seconds elapsed, finished iteration 88
# [LightGBM] [Info] 19.605717 seconds elapsed, finished iteration 89
# [LightGBM] [Info] 19.720679 seconds elapsed, finished iteration 90
# [LightGBM] [Info] 19.857099 seconds elapsed, finished iteration 91
# [LightGBM] [Info] 20.004919 seconds elapsed, finished iteration 92
# [LightGBM] [Info] 20.129236 seconds elapsed, finished iteration 93
# [LightGBM] [Info] 20.261922 seconds elapsed, finished iteration 94
# [LightGBM] [Info] 20.426707 seconds elapsed, finished iteration 95
# [LightGBM] [Info] 20.597994 seconds elapsed, finished iteration 96
# [LightGBM] [Info] 20.782801 seconds elapsed, finished iteration 97
# [LightGBM] [Info] 20.986985 seconds elapsed, finished iteration 98
# [LightGBM] [Info] 21.168573 seconds elapsed, finished iteration 99
# [LightGBM] [Info] 21.367983 seconds elapsed, finished iteration 100
# [LightGBM] [Info] 21.540404 seconds elapsed, finished iteration 101
# [LightGBM] [Info] 21.737668 seconds elapsed, finished iteration 102
# [LightGBM] [Info] 21.834572 seconds elapsed, finished iteration 103
# [LightGBM] [Info] 21.971179 seconds elapsed, finished iteration 104
# [LightGBM] [Info] 22.159789 seconds elapsed, finished iteration 105
# [LightGBM] [Info] 22.333127 seconds elapsed, finished iteration 106
# [LightGBM] [Info] 22.506830 seconds elapsed, finished iteration 107
# [LightGBM] [Info] 22.661986 seconds elapsed, finished iteration 108
# [LightGBM] [Info] 22.786420 seconds elapsed, finished iteration 109
# [LightGBM] [Info] 22.975888 seconds elapsed, finished iteration 110
# [LightGBM] [Info] 23.133983 seconds elapsed, finished iteration 111
# [LightGBM] [Info] 23.267303 seconds elapsed, finished iteration 112
# [LightGBM] [Info] 23.415863 seconds elapsed, finished iteration 113
# [LightGBM] [Info] 23.610412 seconds elapsed, finished iteration 114
# [LightGBM] [Info] 23.751759 seconds elapsed, finished iteration 115
# [LightGBM] [Info] 23.945143 seconds elapsed, finished iteration 116
# [LightGBM] [Info] 24.115923 seconds elapsed, finished iteration 117
# [LightGBM] [Info] 24.226175 seconds elapsed, finished iteration 118
# [LightGBM] [Info] 24.388639 seconds elapsed, finished iteration 119
# [LightGBM] [Info] 24.573183 seconds elapsed, finished iteration 120
# [LightGBM] [Info] 24.775694 seconds elapsed, finished iteration 121
# [LightGBM] [Info] 24.940953 seconds elapsed, finished iteration 122
# [LightGBM] [Info] 25.102322 seconds elapsed, finished iteration 123
# [LightGBM] [Info] 25.242373 seconds elapsed, finished iteration 124
# [LightGBM] [Info] 25.421316 seconds elapsed, finished iteration 125
# [LightGBM] [Info] 25.566790 seconds elapsed, finished iteration 126
# [LightGBM] [Info] 25.790724 seconds elapsed, finished iteration 127
# [LightGBM] [Info] 25.957624 seconds elapsed, finished iteration 128
# [LightGBM] [Info] 26.066728 seconds elapsed, finished iteration 129
# [LightGBM] [Info] 26.223004 seconds elapsed, finished iteration 130
# [LightGBM] [Info] 26.403271 seconds elapsed, finished iteration 131
# [LightGBM] [Info] 26.681682 seconds elapsed, finished iteration 132
# [LightGBM] [Info] 26.891840 seconds elapsed, finished iteration 133
# [LightGBM] [Info] 27.164506 seconds elapsed, finished iteration 134
# [LightGBM] [Info] 27.303707 seconds elapsed, finished iteration 135
# [LightGBM] [Info] 27.464969 seconds elapsed, finished iteration 136
# [LightGBM] [Info] 27.589519 seconds elapsed, finished iteration 137
# [LightGBM] [Info] 27.730975 seconds elapsed, finished iteration 138
# [LightGBM] [Info] 27.851247 seconds elapsed, finished iteration 139
# [LightGBM] [Info] 27.971117 seconds elapsed, finished iteration 140
# [LightGBM] [Info] 28.091802 seconds elapsed, finished iteration 141
# [LightGBM] [Info] 28.243735 seconds elapsed, finished iteration 142
# [LightGBM] [Info] 28.383002 seconds elapsed, finished iteration 143
# [LightGBM] [Info] 28.545118 seconds elapsed, finished iteration 144
# [LightGBM] [Info] 28.647234 seconds elapsed, finished iteration 145
# [LightGBM] [Info] 28.767658 seconds elapsed, finished iteration 146
# [LightGBM] [Info] 28.956146 seconds elapsed, finished iteration 147
# [LightGBM] [Info] 29.088199 seconds elapsed, finished iteration 148
# [LightGBM] [Info] 29.315983 seconds elapsed, finished iteration 149
# [LightGBM] [Info] 29.484265 seconds elapsed, finished iteration 150
# [LightGBM] [Info] 29.686634 seconds elapsed, finished iteration 151
# [LightGBM] [Info] 29.876422 seconds elapsed, finished iteration 152
# [LightGBM] [Info] 30.096638 seconds elapsed, finished iteration 153
# [LightGBM] [Info] 30.263044 seconds elapsed, finished iteration 154
# [LightGBM] [Info] 30.464695 seconds elapsed, finished iteration 155
# [LightGBM] [Info] 30.627725 seconds elapsed, finished iteration 156
# [LightGBM] [Info] 30.841297 seconds elapsed, finished iteration 157
# [LightGBM] [Info] 31.082396 seconds elapsed, finished iteration 158
# [LightGBM] [Info] 31.236260 seconds elapsed, finished iteration 159
# [LightGBM] [Info] 31.411561 seconds elapsed, finished iteration 160
# [LightGBM] [Info] 31.565124 seconds elapsed, finished iteration 161
# [LightGBM] [Info] 31.702076 seconds elapsed, finished iteration 162
# [LightGBM] [Info] 31.821723 seconds elapsed, finished iteration 163
# [LightGBM] [Info] 31.960229 seconds elapsed, finished iteration 164
# [LightGBM] [Info] 32.127584 seconds elapsed, finished iteration 165
# [LightGBM] [Info] 32.274472 seconds elapsed, finished iteration 166
# [LightGBM] [Info] 32.449888 seconds elapsed, finished iteration 167
# [LightGBM] [Info] 32.599519 seconds elapsed, finished iteration 168
# [LightGBM] [Info] 32.752626 seconds elapsed, finished iteration 169
# [LightGBM] [Info] 32.902912 seconds elapsed, finished iteration 170
# [LightGBM] [Info] 33.061320 seconds elapsed, finished iteration 171
# [LightGBM] [Info] 33.223079 seconds elapsed, finished iteration 172
# [LightGBM] [Info] 33.398573 seconds elapsed, finished iteration 173
# [LightGBM] [Info] 33.560950 seconds elapsed, finished iteration 174
# [LightGBM] [Info] 33.745863 seconds elapsed, finished iteration 175
# [LightGBM] [Info] 33.885038 seconds elapsed, finished iteration 176
# [LightGBM] [Info] 34.086061 seconds elapsed, finished iteration 177
# [LightGBM] [Info] 34.237913 seconds elapsed, finished iteration 178
# [LightGBM] [Info] 34.384820 seconds elapsed, finished iteration 179
# [LightGBM] [Info] 34.504872 seconds elapsed, finished iteration 180
# [LightGBM] [Info] 34.643253 seconds elapsed, finished iteration 181
# [LightGBM] [Info] 34.784983 seconds elapsed, finished iteration 182
# [LightGBM] [Info] 34.937068 seconds elapsed, finished iteration 183
# [LightGBM] [Info] 35.104922 seconds elapsed, finished iteration 184
# [LightGBM] [Info] 35.265085 seconds elapsed, finished iteration 185
# [LightGBM] [Info] 35.420137 seconds elapsed, finished iteration 186
# [LightGBM] [Info] 35.603543 seconds elapsed, finished iteration 187
# [LightGBM] [Info] 35.762926 seconds elapsed, finished iteration 188
# [LightGBM] [Info] 35.932775 seconds elapsed, finished iteration 189
# [LightGBM] [Info] 36.082685 seconds elapsed, finished iteration 190
# [LightGBM] [Info] 36.307516 seconds elapsed, finished iteration 191
# [LightGBM] [Info] 36.504542 seconds elapsed, finished iteration 192
# [LightGBM] [Info] 36.683241 seconds elapsed, finished iteration 193
# [LightGBM] [Info] 36.853261 seconds elapsed, finished iteration 194
# [LightGBM] [Info] 37.047925 seconds elapsed, finished iteration 195
# [LightGBM] [Info] 37.202422 seconds elapsed, finished iteration 196
# [LightGBM] [Info] 37.365651 seconds elapsed, finished iteration 197
# [LightGBM] [Info] 37.565037 seconds elapsed, finished iteration 198
# [LightGBM] [Info] 37.778629 seconds elapsed, finished iteration 199
# [LightGBM] [Info] 37.969879 seconds elapsed, finished iteration 200
# [LightGBM] [Info] 38.142165 seconds elapsed, finished iteration 201
# [LightGBM] [Info] 38.337156 seconds elapsed, finished iteration 202
# [LightGBM] [Info] 38.542118 seconds elapsed, finished iteration 203
# [LightGBM] [Info] 38.730555 seconds elapsed, finished iteration 204
# [LightGBM] [Info] 38.878844 seconds elapsed, finished iteration 205
# [LightGBM] [Info] 39.047740 seconds elapsed, finished iteration 206
# [LightGBM] [Info] 39.200329 seconds elapsed, finished iteration 207
# [LightGBM] [Info] 39.362508 seconds elapsed, finished iteration 208
# [LightGBM] [Info] 39.529494 seconds elapsed, finished iteration 209
# [LightGBM] [Info] 39.700297 seconds elapsed, finished iteration 210
# [LightGBM] [Info] 39.947206 seconds elapsed, finished iteration 211
# [LightGBM] [Info] 40.096714 seconds elapsed, finished iteration 212
# [LightGBM] [Info] 40.268449 seconds elapsed, finished iteration 213
# [LightGBM] [Info] 40.468025 seconds elapsed, finished iteration 214
# [LightGBM] [Info] 40.586998 seconds elapsed, finished iteration 215
# [LightGBM] [Info] 40.709348 seconds elapsed, finished iteration 216
# [LightGBM] [Info] 40.899267 seconds elapsed, finished iteration 217
# [LightGBM] [Info] 41.057448 seconds elapsed, finished iteration 218
# [LightGBM] [Info] 41.234982 seconds elapsed, finished iteration 219
# [LightGBM] [Info] 41.426898 seconds elapsed, finished iteration 220
# [LightGBM] [Info] 41.570330 seconds elapsed, finished iteration 221
# [LightGBM] [Info] 41.722660 seconds elapsed, finished iteration 222
# [LightGBM] [Info] 41.926622 seconds elapsed, finished iteration 223
# [LightGBM] [Info] 42.180066 seconds elapsed, finished iteration 224
# [LightGBM] [Info] 42.287029 seconds elapsed, finished iteration 225
# [LightGBM] [Info] 42.394319 seconds elapsed, finished iteration 226
# [LightGBM] [Info] 42.523789 seconds elapsed, finished iteration 227
# [LightGBM] [Info] 42.651995 seconds elapsed, finished iteration 228
# [LightGBM] [Info] 42.772548 seconds elapsed, finished iteration 229
# [LightGBM] [Info] 42.899983 seconds elapsed, finished iteration 230
# [LightGBM] [Info] 43.055799 seconds elapsed, finished iteration 231
# [LightGBM] [Info] 43.170103 seconds elapsed, finished iteration 232
# [LightGBM] [Info] 43.315349 seconds elapsed, finished iteration 233
# [LightGBM] [Info] 43.500240 seconds elapsed, finished iteration 234
# [LightGBM] [Info] 43.657854 seconds elapsed, finished iteration 235
# [LightGBM] [Info] 43.793936 seconds elapsed, finished iteration 236
# [LightGBM] [Info] 43.907676 seconds elapsed, finished iteration 237
# [LightGBM] [Info] 44.076254 seconds elapsed, finished iteration 238
# [LightGBM] [Info] 44.218453 seconds elapsed, finished iteration 239
# [LightGBM] [Info] 44.363377 seconds elapsed, finished iteration 240
# [LightGBM] [Info] 44.574837 seconds elapsed, finished iteration 241
# [LightGBM] [Info] 44.839912 seconds elapsed, finished iteration 242
# [LightGBM] [Info] 45.023350 seconds elapsed, finished iteration 243
# [LightGBM] [Info] 45.149522 seconds elapsed, finished iteration 244
# [LightGBM] [Info] 45.321141 seconds elapsed, finished iteration 245
# [LightGBM] [Info] 45.432201 seconds elapsed, finished iteration 246
# [LightGBM] [Info] 45.550142 seconds elapsed, finished iteration 247
# [LightGBM] [Info] 45.639257 seconds elapsed, finished iteration 248
# [LightGBM] [Info] 45.779025 seconds elapsed, finished iteration 249
# [LightGBM] [Info] 45.908369 seconds elapsed, finished iteration 250
# [LightGBM] [Info] Finished training
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading 250 models
# [LightGBM] [Info] Finished initializing prediction
# [LightGBM] [Info] Finished prediction
# 30 0.663457986835
# 50 0.667311623756
# 100 0.668313551602
# 150 0.667324033045
# 250 0.664582370733

# %% [markdown]
# 30 0.663457986835
# 50 0.667311623756
# 100 0.668313551602
# 150 0.667324033045
# 250 0.664582370733
#
# Берем 100 деревьев

# %%
param_grid = {
    'min_data_in_leaf': [10,50,100,200,500],
    'num_leaves': [15,31,63,127,255],
    'bagging_fraction': [0.5,0.8, 1],
    'bagging_freq': [5,10,30],
    'feature_fraction': [0.5, 0.8, 1]
}


#n_iter = 60
res= []
for _ in range(40):
    param = {k:np.random.choice(v) for k,v in param_grid.items()}
    clf = GBMClassifier(
        exec_path=exec_path,
        min_data_in_leaf = param['min_data_in_leaf'],
        # is_unbalance = True,
        num_iterations = 100 ,
        bagging_fraction = param['bagging_fraction'],
        bagging_freq = param['bagging_freq'],
        num_leaves = param['num_leaves'],
        learning_rate = 0.1,
        feature_fraction = param['feature_fraction'],
        metric = 'auc',
        verbose=False
    )
    
    res.append((param,cv(clf, df_train[feats].values, df_train[label].values, folds = 5, metrics = 'roc_auc,pr_auc')))

print('\n'.join('{} {} {} {}'.format(e[0],np.mean(e[1]['roc_auc']),np.std(e[1]['roc_auc']),min(e[1]['roc_auc'])) for e in res))
# Out:
# {'num_leaves': 63, 'bagging_fraction': 1.0, 'bagging_freq': 10, 'min_data_in_leaf': 200, 'feature_fraction': 0.5} 0.670686536657 0.00134905767601 0.668934706521
# {'num_leaves': 127, 'bagging_fraction': 1.0, 'bagging_freq': 10, 'min_data_in_leaf': 100, 'feature_fraction': 1.0} 0.669496914019 0.00146839472902 0.667295317051
# {'num_leaves': 127, 'bagging_fraction': 1.0, 'bagging_freq': 10, 'min_data_in_leaf': 100, 'feature_fraction': 1.0} 0.669473084327 0.00194682235685 0.665611152625
# {'num_leaves': 127, 'bagging_fraction': 0.5, 'bagging_freq': 30, 'min_data_in_leaf': 10, 'feature_fraction': 0.5} 0.663235841016 0.00180441453179 0.660899228919
# {'num_leaves': 255, 'bagging_fraction': 0.80000000000000004, 'bagging_freq': 30, 'min_data_in_leaf': 50, 'feature_fraction': 0.80000000000000004} 0.664162963372 0.002032172179 0.660556456994
# {'num_leaves': 63, 'bagging_fraction': 0.80000000000000004, 'bagging_freq': 30, 'min_data_in_leaf': 500, 'feature_fraction': 0.80000000000000004} 0.670581479857 0.00104960462332 0.669120282271
# {'num_leaves': 63, 'bagging_fraction': 1.0, 'bagging_freq': 30, 'min_data_in_leaf': 200, 'feature_fraction': 1.0} 0.671100059483 0.00151795386209 0.668361374208
# {'num_leaves': 63, 'bagging_fraction': 0.80000000000000004, 'bagging_freq': 30, 'min_data_in_leaf': 500, 'feature_fraction': 0.80000000000000004} 0.670787682611 0.00129164763399 0.66950102118
# {'num_leaves': 31, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'min_data_in_leaf': 10, 'feature_fraction': 0.5} 0.667844507265 0.00101677923085 0.666412632906
# {'num_leaves': 127, 'bagging_fraction': 1.0, 'bagging_freq': 30, 'min_data_in_leaf': 200, 'feature_fraction': 1.0} 0.669412483039 0.00205998238672 0.666744957563
# {'num_leaves': 31, 'bagging_fraction': 0.80000000000000004, 'bagging_freq': 10, 'min_data_in_leaf': 50, 'feature_fraction': 1.0} 0.669327580874 0.00183480900171 0.667650238237
# {'num_leaves': 15, 'bagging_fraction': 0.80000000000000004, 'bagging_freq': 10, 'min_data_in_leaf': 10, 'feature_fraction': 1.0} 0.667908719088 0.00190271208286 0.664686148792
# {'num_leaves': 127, 'bagging_fraction': 0.80000000000000004, 'bagging_freq': 5, 'min_data_in_leaf': 10, 'feature_fraction': 0.80000000000000004} 0.667485545039 0.00178487290212 0.665073911038
# {'num_leaves': 31, 'bagging_fraction': 1.0, 'bagging_freq': 30, 'min_data_in_leaf': 500, 'feature_fraction': 0.80000000000000004} 0.670470140253 0.00202676830238 0.667470445299
# {'num_leaves': 15, 'bagging_fraction': 0.80000000000000004, 'bagging_freq': 30, 'min_data_in_leaf': 500, 'feature_fraction': 0.5} 0.667007330241 0.00181691101717 0.663861860105
# {'num_leaves': 127, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'min_data_in_leaf': 100, 'feature_fraction': 1.0} 0.664265481008 0.00209445035821 0.661263371746
# {'num_leaves': 127, 'bagging_fraction': 0.80000000000000004, 'bagging_freq': 5, 'min_data_in_leaf': 10, 'feature_fraction': 0.5} 0.667906529024 0.00275273850828 0.664690187503
# {'num_leaves': 127, 'bagging_fraction': 1.0, 'bagging_freq': 5, 'min_data_in_leaf': 10, 'feature_fraction': 1.0} 0.668108800607 0.00234075337811 0.665102297913
# {'num_leaves': 31, 'bagging_fraction': 0.80000000000000004, 'bagging_freq': 10, 'min_data_in_leaf': 200, 'feature_fraction': 0.5} 0.669276929016 0.00142795405825 0.667609133261
# {'num_leaves': 127, 'bagging_fraction': 1.0, 'bagging_freq': 5, 'min_data_in_leaf': 200, 'feature_fraction': 1.0} 0.670123803489 0.00132662173664 0.668425579263
# {'num_leaves': 63, 'bagging_fraction': 1.0, 'bagging_freq': 10, 'min_data_in_leaf': 100, 'feature_fraction': 0.80000000000000004} 0.670646821997 0.00138949564893 0.669182276579
# {'num_leaves': 255, 'bagging_fraction': 1.0, 'bagging_freq': 5, 'min_data_in_leaf': 10, 'feature_fraction': 0.5} 0.666300723675 0.00183991186692 0.663969705864
# {'num_leaves': 15, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'min_data_in_leaf': 500, 'feature_fraction': 1.0} 0.667343013082 0.00211806965326 0.66530690469
# {'num_leaves': 63, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'min_data_in_leaf': 100, 'feature_fraction': 0.80000000000000004} 0.667739597317 0.00167794349886 0.66477529109
# {'num_leaves': 255, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'min_data_in_leaf': 500, 'feature_fraction': 0.80000000000000004} 0.664525398521 0.00202705941296 0.66054733289
# {'num_leaves': 255, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'min_data_in_leaf': 50, 'feature_fraction': 0.80000000000000004} 0.660499461296 0.0023475751839 0.658255141064
# {'num_leaves': 255, 'bagging_fraction': 1.0, 'bagging_freq': 10, 'min_data_in_leaf': 500, 'feature_fraction': 0.80000000000000004} 0.668320743555 0.00170618299561 0.665446737506
# {'num_leaves': 127, 'bagging_fraction': 0.5, 'bagging_freq': 30, 'min_data_in_leaf': 10, 'feature_fraction': 0.5} 0.663716566502 0.00176394302248 0.660717176426
# {'num_leaves': 127, 'bagging_fraction': 1.0, 'bagging_freq': 30, 'min_data_in_leaf': 200, 'feature_fraction': 0.80000000000000004} 0.669660375481 0.00171832557474 0.66761998649
# {'num_leaves': 15, 'bagging_fraction': 1.0, 'bagging_freq': 30, 'min_data_in_leaf': 100, 'feature_fraction': 0.5} 0.667402252213 0.0016740960229 0.665086960137
# {'num_leaves': 127, 'bagging_fraction': 0.80000000000000004, 'bagging_freq': 5, 'min_data_in_leaf': 10, 'feature_fraction': 0.80000000000000004} 0.666894144602 0.00255238828792 0.663082722754
# {'num_leaves': 15, 'bagging_fraction': 1.0, 'bagging_freq': 10, 'min_data_in_leaf': 500, 'feature_fraction': 0.5} 0.66739580497 0.000887175243451 0.666460495249
# {'num_leaves': 255, 'bagging_fraction': 1.0, 'bagging_freq': 5, 'min_data_in_leaf': 200, 'feature_fraction': 0.80000000000000004} 0.667532900787 0.0015571882237 0.665504892184
# {'num_leaves': 63, 'bagging_fraction': 0.5, 'bagging_freq': 30, 'min_data_in_leaf': 500, 'feature_fraction': 1.0} 0.668123460012 0.00141134893282 0.666505214658
# {'num_leaves': 255, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'min_data_in_leaf': 50, 'feature_fraction': 0.5} 0.659300489827 0.000651332516182 0.658260624045
# {'num_leaves': 31, 'bagging_fraction': 0.80000000000000004, 'bagging_freq': 10, 'min_data_in_leaf': 200, 'feature_fraction': 0.80000000000000004} 0.669664879335 0.00133956651275 0.667832126827
# {'num_leaves': 63, 'bagging_fraction': 1.0, 'bagging_freq': 30, 'min_data_in_leaf': 50, 'feature_fraction': 0.80000000000000004} 0.670253939372 0.00141454912833 0.668060802251
# {'num_leaves': 31, 'bagging_fraction': 0.80000000000000004, 'bagging_freq': 5, 'min_data_in_leaf': 10, 'feature_fraction': 1.0} 0.66980332789 0.00226970381047 0.667350551132
# {'num_leaves': 15, 'bagging_fraction': 0.80000000000000004, 'bagging_freq': 5, 'min_data_in_leaf': 500, 'feature_fraction': 0.80000000000000004} 0.668030637528 0.00185991421902 0.665000395688
# {'num_leaves': 127, 'bagging_fraction': 0.80000000000000004, 'bagging_freq': 10, 'min_data_in_leaf': 50, 'feature_fraction': 1.0} 0.667884254987 0.00328844493973 0.663906798155

# %% [markdown]
# ### Берем {'num_leaves':	63	'bagging_fraction':	1.0,	'bagging_freq':	30	'min_data_in_leaf':	200	'feature_fraction':	1.0}

# %%
param_grid = [
    {'learning_rate': 0.05, 'num_iterations':200},
    {'learning_rate': 0.1, 'num_iterations':70},
    {'learning_rate': 0.1, 'num_iterations':100},
    {'learning_rate': 0.15, 'num_iterations':70},
    {'learning_rate': 0.02, 'num_iterations':500},
    {'learning_rate': 0.02, 'num_iterations':300},
    {'learning_rate': 0.02, 'num_iterations':800},
    {'learning_rate': 0.03, 'num_iterations':300},
    {'learning_rate': 0.07, 'num_iterations':200},
    
]

res = []
for param in param_grid:
    clf = GBMClassifier(
        exec_path=exec_path,
        min_data_in_leaf=200,
       # is_unbalance = True,
        num_iterations = param['num_iterations'],
        bagging_fraction = 1,
        bagging_freq = 30,
        feature_fraction = 1,
        num_leaves = 63,
        learning_rate = param['learning_rate'],
        metric = 'auc',
        verbose = False
    )
    res.append((param, cv(clf, df_train[feats].values, df_train[label].values, folds = 5, metrics = 'roc_auc,pr_auc')))  

print('\n'.join('{} {} {} {}'.format(e[0],np.mean(e[1]['roc_auc']),np.std(e[1]['roc_auc']),min(e[1]['roc_auc'])) for e in res))
# Out:
# {'num_iterations': 200, 'learning_rate': 0.05} 0.671445196603 0.00244474230128 0.667202387635
# {'num_iterations': 70, 'learning_rate': 0.1} 0.6701116821 0.00126478888061 0.668010860877
# {'num_iterations': 100, 'learning_rate': 0.1} 0.670423096232 0.00226832234084 0.666760867654
# {'num_iterations': 70, 'learning_rate': 0.15} 0.669324273407 0.00216356611213 0.666637024768
# {'num_iterations': 500, 'learning_rate': 0.02} 0.672177949908 0.00149699404242 0.669814070198
# {'num_iterations': 300, 'learning_rate': 0.02} 0.66974981656 0.00208157822255 0.667396820025
# {'num_iterations': 800, 'learning_rate': 0.02} 0.672512597235 0.00167044870062 0.670621661101
# {'num_iterations': 300, 'learning_rate': 0.03} 0.671535424538 0.0028582088243 0.667791483836
# {'num_iterations': 200, 'learning_rate': 0.07} 0.671806518924 0.00115580622674 0.670137430707

# %%
param_grid = [
    {'learning_rate': 0.02, 'num_iterations':800},
    {'learning_rate': 0.02, 'num_iterations':1000},
    {'learning_rate': 0.02, 'num_iterations':1500},
    {'learning_rate': 0.02, 'num_iterations':700},
    {'learning_rate': 0.03, 'num_iterations':500},
    {'learning_rate': 0.05, 'num_iterations':400},
    {'learning_rate': 0.05, 'num_iterations':600}
    
]

#res = []
for param in param_grid:
    clf = GBMClassifier(
        exec_path=exec_path,
        min_data_in_leaf=200,
       # is_unbalance = True,
        num_iterations = param['num_iterations'],
        bagging_fraction = 1,
        bagging_freq = 30,
        feature_fraction = 1,
        num_leaves = 63,
        learning_rate = param['learning_rate'],
        metric = 'auc',
        verbose = False
    )
    res.append((param, cv(clf, df_train[feats].values, df_train[label].values, folds = 5, metrics = 'roc_auc,pr_auc')))  

print('\n'.join('{} {} {} {}'.format(e[0],np.mean(e[1]['roc_auc']),np.std(e[1]['roc_auc']),min(e[1]['roc_auc'])) for e in res))
# Out:
# {'num_iterations': 200, 'learning_rate': 0.05} 0.671445196603 0.00244474230128 0.667202387635
# {'num_iterations': 70, 'learning_rate': 0.1} 0.6701116821 0.00126478888061 0.668010860877
# {'num_iterations': 100, 'learning_rate': 0.1} 0.670423096232 0.00226832234084 0.666760867654
# {'num_iterations': 70, 'learning_rate': 0.15} 0.669324273407 0.00216356611213 0.666637024768
# {'num_iterations': 500, 'learning_rate': 0.02} 0.672177949908 0.00149699404242 0.669814070198
# {'num_iterations': 300, 'learning_rate': 0.02} 0.66974981656 0.00208157822255 0.667396820025
# {'num_iterations': 800, 'learning_rate': 0.02} 0.672512597235 0.00167044870062 0.670621661101
# {'num_iterations': 300, 'learning_rate': 0.03} 0.671535424538 0.0028582088243 0.667791483836
# {'num_iterations': 200, 'learning_rate': 0.07} 0.671806518924 0.00115580622674 0.670137430707
# {'num_iterations': 800, 'learning_rate': 0.02} 0.672598008389 0.00145406736606 0.670332333667
# {'num_iterations': 1000, 'learning_rate': 0.02} 0.672613191401 0.00229978467781 0.66929529083
# {'num_iterations': 1500, 'learning_rate': 0.02} 0.672419272155 0.00146619697095 0.670374568057
# {'num_iterations': 700, 'learning_rate': 0.02} 0.672692729734 0.00288642497184 0.66745647658
# {'num_iterations': 500, 'learning_rate': 0.03} 0.672653860947 0.00148033684008 0.670504368333
# {'num_iterations': 400, 'learning_rate': 0.05} 0.67197698727 0.00220071228922 0.669121944556
# {'num_iterations': 600, 'learning_rate': 0.05} 0.671048690563 0.00164156415527 0.668268678176

# %% [markdown]
# ### Выбираем {'num_iterations': 500, 'learning_rate': 0.02} 0.672177949908 0.00149699404242 0.669814070198

# %%
clf = GBMClassifier(
        exec_path=exec_path,
        min_data_in_leaf=200,
       # is_unbalance = True,
        num_iterations = 500,
        bagging_fraction = 1,
        bagging_freq = 30,
        feature_fraction = 1,
        num_leaves = 63,
        learning_rate = 0.02,
        metric = 'auc',
        verbose = True
    )
#clf.fit(df_train[feats], df_train[label])
#df_test['pred'] = clf.predict_proba(df_test[feats])[:,1]

clf.fit(df_train[feats], df_train[label], test_data = [(df_test[feats], df_test[label])])
# Out:
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading data in 5.304533 seconds
# [LightGBM] [Info] Number of postive: 121590, number of negative: 211669
# [LightGBM] [Info] Number of data: 333259, number of features: 43
# [LightGBM] [Info] Finished initializing training
# [LightGBM] [Info] Started training...
# [LightGBM] [Info] Iteration:1, valid_1 auc : 0.658212
# [LightGBM] [Info] 0.308862 seconds elapsed, finished iteration 1
# [LightGBM] [Info] Iteration:2, valid_1 auc : 0.660190
# [LightGBM] [Info] 0.616675 seconds elapsed, finished iteration 2
# [LightGBM] [Info] Iteration:3, valid_1 auc : 0.661729
# [LightGBM] [Info] 0.828338 seconds elapsed, finished iteration 3
# [LightGBM] [Info] Iteration:4, valid_1 auc : 0.661750
# [LightGBM] [Info] 1.035026 seconds elapsed, finished iteration 4
# [LightGBM] [Info] Iteration:5, valid_1 auc : 0.662829
# [LightGBM] [Info] 1.240941 seconds elapsed, finished iteration 5
# [LightGBM] [Info] Iteration:6, valid_1 auc : 0.663016
# [LightGBM] [Info] 1.592087 seconds elapsed, finished iteration 6
# [LightGBM] [Info] Iteration:7, valid_1 auc : 0.664760
# [LightGBM] [Info] 1.799989 seconds elapsed, finished iteration 7
# [LightGBM] [Info] Iteration:8, valid_1 auc : 0.664823
# [LightGBM] [Info] 2.017094 seconds elapsed, finished iteration 8
# [LightGBM] [Info] Iteration:9, valid_1 auc : 0.665880
# [LightGBM] [Info] 2.221728 seconds elapsed, finished iteration 9
# [LightGBM] [Info] Iteration:10, valid_1 auc : 0.666570
# [LightGBM] [Info] 2.436893 seconds elapsed, finished iteration 10
# [LightGBM] [Info] Iteration:11, valid_1 auc : 0.666969
# [LightGBM] [Info] 2.649289 seconds elapsed, finished iteration 11
# [LightGBM] [Info] Iteration:12, valid_1 auc : 0.667166
# [LightGBM] [Info] 2.860367 seconds elapsed, finished iteration 12
# [LightGBM] [Info] Iteration:13, valid_1 auc : 0.667532
# [LightGBM] [Info] 3.064134 seconds elapsed, finished iteration 13
# [LightGBM] [Info] Iteration:14, valid_1 auc : 0.667658
# [LightGBM] [Info] 3.276659 seconds elapsed, finished iteration 14
# [LightGBM] [Info] Iteration:15, valid_1 auc : 0.668075
# [LightGBM] [Info] 3.484392 seconds elapsed, finished iteration 15
# [LightGBM] [Info] Iteration:16, valid_1 auc : 0.668334
# [LightGBM] [Info] 3.695199 seconds elapsed, finished iteration 16
# [LightGBM] [Info] Iteration:17, valid_1 auc : 0.668371
# [LightGBM] [Info] 3.897973 seconds elapsed, finished iteration 17
# [LightGBM] [Info] Iteration:18, valid_1 auc : 0.668474
# [LightGBM] [Info] 4.109774 seconds elapsed, finished iteration 18
# [LightGBM] [Info] Iteration:19, valid_1 auc : 0.668608
# [LightGBM] [Info] 4.450208 seconds elapsed, finished iteration 19
# [LightGBM] [Info] Iteration:20, valid_1 auc : 0.668699
# [LightGBM] [Info] 4.651595 seconds elapsed, finished iteration 20
# [LightGBM] [Info] Iteration:21, valid_1 auc : 0.668746
# [LightGBM] [Info] 4.862458 seconds elapsed, finished iteration 21
# [LightGBM] [Info] Iteration:22, valid_1 auc : 0.668890
# [LightGBM] [Info] 5.069351 seconds elapsed, finished iteration 22
# [LightGBM] [Info] Iteration:23, valid_1 auc : 0.668913
# [LightGBM] [Info] 5.278036 seconds elapsed, finished iteration 23
# [LightGBM] [Info] Iteration:24, valid_1 auc : 0.669032
# [LightGBM] [Info] 5.488672 seconds elapsed, finished iteration 24
# [LightGBM] [Info] Iteration:25, valid_1 auc : 0.669245
# [LightGBM] [Info] 5.696323 seconds elapsed, finished iteration 25
# [LightGBM] [Info] Iteration:26, valid_1 auc : 0.669379
# [LightGBM] [Info] 5.912696 seconds elapsed, finished iteration 26
# [LightGBM] [Info] Iteration:27, valid_1 auc : 0.669445
# [LightGBM] [Info] 6.124193 seconds elapsed, finished iteration 27
# [LightGBM] [Info] Iteration:28, valid_1 auc : 0.669522
# [LightGBM] [Info] 6.340243 seconds elapsed, finished iteration 28
# [LightGBM] [Info] Iteration:29, valid_1 auc : 0.669666
# [LightGBM] [Info] 6.552288 seconds elapsed, finished iteration 29
# [LightGBM] [Info] Iteration:30, valid_1 auc : 0.669832
# [LightGBM] [Info] 6.758843 seconds elapsed, finished iteration 30
# [LightGBM] [Info] Iteration:31, valid_1 auc : 0.669925
# [LightGBM] [Info] 6.976778 seconds elapsed, finished iteration 31
# [LightGBM] [Info] Iteration:32, valid_1 auc : 0.670036
# [LightGBM] [Info] 7.196199 seconds elapsed, finished iteration 32
# [LightGBM] [Info] Iteration:33, valid_1 auc : 0.670130
# [LightGBM] [Info] 7.409874 seconds elapsed, finished iteration 33
# [LightGBM] [Info] Iteration:34, valid_1 auc : 0.670223
# [LightGBM] [Info] 7.742859 seconds elapsed, finished iteration 34
# [LightGBM] [Info] Iteration:35, valid_1 auc : 0.670292
# [LightGBM] [Info] 7.956650 seconds elapsed, finished iteration 35
# [LightGBM] [Info] Iteration:36, valid_1 auc : 0.670388
# [LightGBM] [Info] 8.180194 seconds elapsed, finished iteration 36
# [LightGBM] [Info] Iteration:37, valid_1 auc : 0.670494
# [LightGBM] [Info] 8.404252 seconds elapsed, finished iteration 37
# [LightGBM] [Info] Iteration:38, valid_1 auc : 0.670638
# [LightGBM] [Info] 8.614018 seconds elapsed, finished iteration 38
# [LightGBM] [Info] Iteration:39, valid_1 auc : 0.670664
# [LightGBM] [Info] 8.839776 seconds elapsed, finished iteration 39
# [LightGBM] [Info] Iteration:40, valid_1 auc : 0.670852
# [LightGBM] [Info] 9.056395 seconds elapsed, finished iteration 40
# [LightGBM] [Info] Iteration:41, valid_1 auc : 0.670909
# [LightGBM] [Info] 9.271158 seconds elapsed, finished iteration 41
# [LightGBM] [Info] Iteration:42, valid_1 auc : 0.670933
# [LightGBM] [Info] 9.485736 seconds elapsed, finished iteration 42
# [LightGBM] [Info] Iteration:43, valid_1 auc : 0.670969
# [LightGBM] [Info] 9.690604 seconds elapsed, finished iteration 43
# [LightGBM] [Info] Iteration:44, valid_1 auc : 0.671117
# [LightGBM] [Info] 9.900996 seconds elapsed, finished iteration 44
# [LightGBM] [Info] Iteration:45, valid_1 auc : 0.671204
# [LightGBM] [Info] 10.113088 seconds elapsed, finished iteration 45
# [LightGBM] [Info] Iteration:46, valid_1 auc : 0.671380
# [LightGBM] [Info] 10.309770 seconds elapsed, finished iteration 46
# [LightGBM] [Info] Iteration:47, valid_1 auc : 0.671482
# [LightGBM] [Info] 10.564839 seconds elapsed, finished iteration 47
# [LightGBM] [Info] Iteration:48, valid_1 auc : 0.671624
# [LightGBM] [Info] 10.790523 seconds elapsed, finished iteration 48
# [LightGBM] [Info] Iteration:49, valid_1 auc : 0.671636
# [LightGBM] [Info] 11.098295 seconds elapsed, finished iteration 49
# [LightGBM] [Info] Iteration:50, valid_1 auc : 0.671710
# [LightGBM] [Info] 11.319860 seconds elapsed, finished iteration 50
# [LightGBM] [Info] Iteration:51, valid_1 auc : 0.671844
# [LightGBM] [Info] 11.695006 seconds elapsed, finished iteration 51
# [LightGBM] [Info] Iteration:52, valid_1 auc : 0.671902
# [LightGBM] [Info] 11.911790 seconds elapsed, finished iteration 52
# [LightGBM] [Info] Iteration:53, valid_1 auc : 0.671998
# [LightGBM] [Info] 12.240492 seconds elapsed, finished iteration 53
# [LightGBM] [Info] Iteration:54, valid_1 auc : 0.672049
# [LightGBM] [Info] 12.459267 seconds elapsed, finished iteration 54
# [LightGBM] [Info] Iteration:55, valid_1 auc : 0.672204
# [LightGBM] [Info] 12.677376 seconds elapsed, finished iteration 55
# [LightGBM] [Info] Iteration:56, valid_1 auc : 0.672227
# [LightGBM] [Info] 12.892952 seconds elapsed, finished iteration 56
# [LightGBM] [Info] Iteration:57, valid_1 auc : 0.672311
# [LightGBM] [Info] 13.092396 seconds elapsed, finished iteration 57
# [LightGBM] [Info] Iteration:58, valid_1 auc : 0.672382
# [LightGBM] [Info] 13.295075 seconds elapsed, finished iteration 58
# [LightGBM] [Info] Iteration:59, valid_1 auc : 0.672419
# [LightGBM] [Info] 13.505411 seconds elapsed, finished iteration 59
# [LightGBM] [Info] Iteration:60, valid_1 auc : 0.672443
# [LightGBM] [Info] 13.708241 seconds elapsed, finished iteration 60
# [LightGBM] [Info] Iteration:61, valid_1 auc : 0.672591
# [LightGBM] [Info] 14.018228 seconds elapsed, finished iteration 61
# [LightGBM] [Info] Iteration:62, valid_1 auc : 0.672662
# [LightGBM] [Info] 14.353800 seconds elapsed, finished iteration 62
# [LightGBM] [Info] Iteration:63, valid_1 auc : 0.672733
# [LightGBM] [Info] 14.712566 seconds elapsed, finished iteration 63
# [LightGBM] [Info] Iteration:64, valid_1 auc : 0.672776
# [LightGBM] [Info] 14.914804 seconds elapsed, finished iteration 64
# [LightGBM] [Info] Iteration:65, valid_1 auc : 0.672786
# [LightGBM] [Info] 15.126031 seconds elapsed, finished iteration 65
# [LightGBM] [Info] Iteration:66, valid_1 auc : 0.672847
# [LightGBM] [Info] 15.336300 seconds elapsed, finished iteration 66
# [LightGBM] [Info] Iteration:67, valid_1 auc : 0.672902
# [LightGBM] [Info] 15.549525 seconds elapsed, finished iteration 67
# [LightGBM] [Info] Iteration:68, valid_1 auc : 0.673006
# [LightGBM] [Info] 15.765890 seconds elapsed, finished iteration 68
# [LightGBM] [Info] Iteration:69, valid_1 auc : 0.673034
# [LightGBM] [Info] 16.100236 seconds elapsed, finished iteration 69
# [LightGBM] [Info] Iteration:70, valid_1 auc : 0.673099
# [LightGBM] [Info] 16.326124 seconds elapsed, finished iteration 70
# [LightGBM] [Info] Iteration:71, valid_1 auc : 0.673128
# [LightGBM] [Info] 16.546546 seconds elapsed, finished iteration 71
# [LightGBM] [Info] Iteration:72, valid_1 auc : 0.673234
# [LightGBM] [Info] 16.831456 seconds elapsed, finished iteration 72
# [LightGBM] [Info] Iteration:73, valid_1 auc : 0.673314
# [LightGBM] [Info] 17.289135 seconds elapsed, finished iteration 73
# [LightGBM] [Info] Iteration:74, valid_1 auc : 0.673415
# [LightGBM] [Info] 17.493139 seconds elapsed, finished iteration 74
# [LightGBM] [Info] Iteration:75, valid_1 auc : 0.673454
# [LightGBM] [Info] 17.705743 seconds elapsed, finished iteration 75
# [LightGBM] [Info] Iteration:76, valid_1 auc : 0.673524
# [LightGBM] [Info] 18.108976 seconds elapsed, finished iteration 76
# [LightGBM] [Info] Iteration:77, valid_1 auc : 0.673589
# [LightGBM] [Info] 18.335901 seconds elapsed, finished iteration 77
# [LightGBM] [Info] Iteration:78, valid_1 auc : 0.673645
# [LightGBM] [Info] 18.565814 seconds elapsed, finished iteration 78
# [LightGBM] [Info] Iteration:79, valid_1 auc : 0.673687
# [LightGBM] [Info] 18.771059 seconds elapsed, finished iteration 79
# [LightGBM] [Info] Iteration:80, valid_1 auc : 0.673763
# [LightGBM] [Info] 18.977609 seconds elapsed, finished iteration 80
# [LightGBM] [Info] Iteration:81, valid_1 auc : 0.673804
# [LightGBM] [Info] 19.180494 seconds elapsed, finished iteration 81
# [LightGBM] [Info] Iteration:82, valid_1 auc : 0.673862
# [LightGBM] [Info] 19.377445 seconds elapsed, finished iteration 82
# [LightGBM] [Info] Iteration:83, valid_1 auc : 0.673945
# [LightGBM] [Info] 19.581281 seconds elapsed, finished iteration 83
# [LightGBM] [Info] Iteration:84, valid_1 auc : 0.674007
# [LightGBM] [Info] 19.939032 seconds elapsed, finished iteration 84
# [LightGBM] [Info] Iteration:85, valid_1 auc : 0.674057
# [LightGBM] [Info] 20.222933 seconds elapsed, finished iteration 85
# [LightGBM] [Info] Iteration:86, valid_1 auc : 0.674137
# [LightGBM] [Info] 20.525109 seconds elapsed, finished iteration 86
# [LightGBM] [Info] Iteration:87, valid_1 auc : 0.674165
# [LightGBM] [Info] 20.739054 seconds elapsed, finished iteration 87
# [LightGBM] [Info] Iteration:88, valid_1 auc : 0.674218
# [LightGBM] [Info] 21.080406 seconds elapsed, finished iteration 88
# [LightGBM] [Info] Iteration:89, valid_1 auc : 0.674344
# [LightGBM] [Info] 21.279690 seconds elapsed, finished iteration 89
# [LightGBM] [Info] Iteration:90, valid_1 auc : 0.674405
# [LightGBM] [Info] 21.488267 seconds elapsed, finished iteration 90
# [LightGBM] [Info] Iteration:91, valid_1 auc : 0.674464
# [LightGBM] [Info] 21.699262 seconds elapsed, finished iteration 91
# [LightGBM] [Info] Iteration:92, valid_1 auc : 0.674504
# [LightGBM] [Info] 21.910224 seconds elapsed, finished iteration 92
# [LightGBM] [Info] Iteration:93, valid_1 auc : 0.674524
# [LightGBM] [Info] 22.105754 seconds elapsed, finished iteration 93
# [LightGBM] [Info] Iteration:94, valid_1 auc : 0.674631
# [LightGBM] [Info] 22.295768 seconds elapsed, finished iteration 94
# [LightGBM] [Info] Iteration:95, valid_1 auc : 0.674681
# [LightGBM] [Info] 22.614673 seconds elapsed, finished iteration 95
# [LightGBM] [Info] Iteration:96, valid_1 auc : 0.674725
# [LightGBM] [Info] 22.821046 seconds elapsed, finished iteration 96
# [LightGBM] [Info] Iteration:97, valid_1 auc : 0.674786
# [LightGBM] [Info] 23.175406 seconds elapsed, finished iteration 97
# [LightGBM] [Info] Iteration:98, valid_1 auc : 0.674828
# [LightGBM] [Info] 23.387386 seconds elapsed, finished iteration 98
# [LightGBM] [Info] Iteration:99, valid_1 auc : 0.674974
# [LightGBM] [Info] 23.574262 seconds elapsed, finished iteration 99
# [LightGBM] [Info] Iteration:100, valid_1 auc : 0.675008
# [LightGBM] [Info] 23.772728 seconds elapsed, finished iteration 100
# [LightGBM] [Info] Iteration:101, valid_1 auc : 0.675040
# [LightGBM] [Info] 23.960616 seconds elapsed, finished iteration 101
# [LightGBM] [Info] Iteration:102, valid_1 auc : 0.675101
# [LightGBM] [Info] 24.155390 seconds elapsed, finished iteration 102
# [LightGBM] [Info] Iteration:103, valid_1 auc : 0.675174
# [LightGBM] [Info] 24.468644 seconds elapsed, finished iteration 103
# [LightGBM] [Info] Iteration:104, valid_1 auc : 0.675318
# [LightGBM] [Info] 24.667282 seconds elapsed, finished iteration 104
# [LightGBM] [Info] Iteration:105, valid_1 auc : 0.675371
# [LightGBM] [Info] 24.875575 seconds elapsed, finished iteration 105
# [LightGBM] [Info] Iteration:106, valid_1 auc : 0.675519
# [LightGBM] [Info] 25.055254 seconds elapsed, finished iteration 106
# [LightGBM] [Info] Iteration:107, valid_1 auc : 0.675631
# [LightGBM] [Info] 25.254425 seconds elapsed, finished iteration 107
# [LightGBM] [Info] Iteration:108, valid_1 auc : 0.675662
# [LightGBM] [Info] 25.465387 seconds elapsed, finished iteration 108
# [LightGBM] [Info] Iteration:109, valid_1 auc : 0.675676
# [LightGBM] [Info] 25.808133 seconds elapsed, finished iteration 109
# [LightGBM] [Info] Iteration:110, valid_1 auc : 0.675720
# [LightGBM] [Info] 26.167443 seconds elapsed, finished iteration 110
# [LightGBM] [Info] Iteration:111, valid_1 auc : 0.675874
# [LightGBM] [Info] 26.358241 seconds elapsed, finished iteration 111
# [LightGBM] [Info] Iteration:112, valid_1 auc : 0.675925
# [LightGBM] [Info] 26.548638 seconds elapsed, finished iteration 112
# [LightGBM] [Info] Iteration:113, valid_1 auc : 0.676052
# [LightGBM] [Info] 26.731268 seconds elapsed, finished iteration 113
# [LightGBM] [Info] Iteration:114, valid_1 auc : 0.676127
# [LightGBM] [Info] 26.922117 seconds elapsed, finished iteration 114
# [LightGBM] [Info] Iteration:115, valid_1 auc : 0.676241
# [LightGBM] [Info] 27.123443 seconds elapsed, finished iteration 115
# [LightGBM] [Info] Iteration:116, valid_1 auc : 0.676345
# [LightGBM] [Info] 27.326970 seconds elapsed, finished iteration 116
# [LightGBM] [Info] Iteration:117, valid_1 auc : 0.676401
# [LightGBM] [Info] 27.522399 seconds elapsed, finished iteration 117
# [LightGBM] [Info] Iteration:118, valid_1 auc : 0.676467
# [LightGBM] [Info] 27.714502 seconds elapsed, finished iteration 118
# [LightGBM] [Info] Iteration:119, valid_1 auc : 0.676493
# [LightGBM] [Info] 27.929755 seconds elapsed, finished iteration 119
# [LightGBM] [Info] Iteration:120, valid_1 auc : 0.676588
# [LightGBM] [Info] 28.124870 seconds elapsed, finished iteration 120
# [LightGBM] [Info] Iteration:121, valid_1 auc : 0.676653
# [LightGBM] [Info] 28.318918 seconds elapsed, finished iteration 121
# [LightGBM] [Info] Iteration:122, valid_1 auc : 0.676701
# [LightGBM] [Info] 28.525681 seconds elapsed, finished iteration 122
# [LightGBM] [Info] Iteration:123, valid_1 auc : 0.676736
# [LightGBM] [Info] 28.856921 seconds elapsed, finished iteration 123
# [LightGBM] [Info] Iteration:124, valid_1 auc : 0.676865
# [LightGBM] [Info] 29.047310 seconds elapsed, finished iteration 124
# [LightGBM] [Info] Iteration:125, valid_1 auc : 0.676929
# [LightGBM] [Info] 29.247765 seconds elapsed, finished iteration 125
# [LightGBM] [Info] Iteration:126, valid_1 auc : 0.676976
# [LightGBM] [Info] 29.450510 seconds elapsed, finished iteration 126
# [LightGBM] [Info] Iteration:127, valid_1 auc : 0.677055
# [LightGBM] [Info] 29.650682 seconds elapsed, finished iteration 127
# [LightGBM] [Info] Iteration:128, valid_1 auc : 0.677165
# [LightGBM] [Info] 29.836556 seconds elapsed, finished iteration 128
# [LightGBM] [Info] Iteration:129, valid_1 auc : 0.677230
# [LightGBM] [Info] 30.031602 seconds elapsed, finished iteration 129
# [LightGBM] [Info] Iteration:130, valid_1 auc : 0.677289
# [LightGBM] [Info] 30.230771 seconds elapsed, finished iteration 130
# [LightGBM] [Info] Iteration:131, valid_1 auc : 0.677387
# [LightGBM] [Info] 30.580682 seconds elapsed, finished iteration 131
# [LightGBM] [Info] Iteration:132, valid_1 auc : 0.677470
# [LightGBM] [Info] 30.780937 seconds elapsed, finished iteration 132
# [LightGBM] [Info] Iteration:133, valid_1 auc : 0.677555
# [LightGBM] [Info] 30.971558 seconds elapsed, finished iteration 133
# [LightGBM] [Info] Iteration:134, valid_1 auc : 0.677591
# [LightGBM] [Info] 31.168209 seconds elapsed, finished iteration 134
# [LightGBM] [Info] Iteration:135, valid_1 auc : 0.677689
# [LightGBM] [Info] 31.366919 seconds elapsed, finished iteration 135
# [LightGBM] [Info] Iteration:136, valid_1 auc : 0.677737
# [LightGBM] [Info] 31.581414 seconds elapsed, finished iteration 136
# [LightGBM] [Info] Iteration:137, valid_1 auc : 0.677795
# [LightGBM] [Info] 31.818276 seconds elapsed, finished iteration 137
# [LightGBM] [Info] Iteration:138, valid_1 auc : 0.677888
# [LightGBM] [Info] 32.060764 seconds elapsed, finished iteration 138
# [LightGBM] [Info] Iteration:139, valid_1 auc : 0.677959
# [LightGBM] [Info] 32.284175 seconds elapsed, finished iteration 139
# [LightGBM] [Info] Iteration:140, valid_1 auc : 0.678032
# [LightGBM] [Info] 32.486446 seconds elapsed, finished iteration 140
# [LightGBM] [Info] Iteration:141, valid_1 auc : 0.678133
# [LightGBM] [Info] 32.669718 seconds elapsed, finished iteration 141
# [LightGBM] [Info] Iteration:142, valid_1 auc : 0.678203
# [LightGBM] [Info] 32.857735 seconds elapsed, finished iteration 142
# [LightGBM] [Info] Iteration:143, valid_1 auc : 0.678288
# [LightGBM] [Info] 33.049275 seconds elapsed, finished iteration 143
# [LightGBM] [Info] Iteration:144, valid_1 auc : 0.678375
# [LightGBM] [Info] 33.254503 seconds elapsed, finished iteration 144
# [LightGBM] [Info] Iteration:145, valid_1 auc : 0.678426
# [LightGBM] [Info] 33.448759 seconds elapsed, finished iteration 145
# [LightGBM] [Info] Iteration:146, valid_1 auc : 0.678491
# [LightGBM] [Info] 33.633376 seconds elapsed, finished iteration 146
# [LightGBM] [Info] Iteration:147, valid_1 auc : 0.678567
# [LightGBM] [Info] 33.806274 seconds elapsed, finished iteration 147
# [LightGBM] [Info] Iteration:148, valid_1 auc : 0.678630
# [LightGBM] [Info] 34.000488 seconds elapsed, finished iteration 148
# [LightGBM] [Info] Iteration:149, valid_1 auc : 0.678673
# [LightGBM] [Info] 34.188609 seconds elapsed, finished iteration 149
# [LightGBM] [Info] Iteration:150, valid_1 auc : 0.678724
# [LightGBM] [Info] 34.368933 seconds elapsed, finished iteration 150
# [LightGBM] [Info] Iteration:151, valid_1 auc : 0.678788
# [LightGBM] [Info] 34.577492 seconds elapsed, finished iteration 151
# [LightGBM] [Info] Iteration:152, valid_1 auc : 0.678881
# [LightGBM] [Info] 34.754703 seconds elapsed, finished iteration 152
# [LightGBM] [Info] Iteration:153, valid_1 auc : 0.678973
# [LightGBM] [Info] 34.940766 seconds elapsed, finished iteration 153
# [LightGBM] [Info] Iteration:154, valid_1 auc : 0.678979
# [LightGBM] [Info] 35.135010 seconds elapsed, finished iteration 154
# [LightGBM] [Info] Iteration:155, valid_1 auc : 0.679018
# [LightGBM] [Info] 35.473131 seconds elapsed, finished iteration 155
# [LightGBM] [Info] Iteration:156, valid_1 auc : 0.679101
# [LightGBM] [Info] 35.804240 seconds elapsed, finished iteration 156
# [LightGBM] [Info] Iteration:157, valid_1 auc : 0.679126
# [LightGBM] [Info] 36.174845 seconds elapsed, finished iteration 157
# [LightGBM] [Info] Iteration:158, valid_1 auc : 0.679143
# [LightGBM] [Info] 36.367039 seconds elapsed, finished iteration 158
# [LightGBM] [Info] Iteration:159, valid_1 auc : 0.679196
# [LightGBM] [Info] 36.549499 seconds elapsed, finished iteration 159
# [LightGBM] [Info] Iteration:160, valid_1 auc : 0.679225
# [LightGBM] [Info] 36.748785 seconds elapsed, finished iteration 160
# [LightGBM] [Info] Iteration:161, valid_1 auc : 0.679320
# [LightGBM] [Info] 37.084991 seconds elapsed, finished iteration 161
# [LightGBM] [Info] Iteration:162, valid_1 auc : 0.679389
# [LightGBM] [Info] 37.261167 seconds elapsed, finished iteration 162
# [LightGBM] [Info] Iteration:163, valid_1 auc : 0.679443
# [LightGBM] [Info] 37.457571 seconds elapsed, finished iteration 163
# [LightGBM] [Info] Iteration:164, valid_1 auc : 0.679457
# [LightGBM] [Info] 37.633557 seconds elapsed, finished iteration 164
# [LightGBM] [Info] Iteration:165, valid_1 auc : 0.679494
# [LightGBM] [Info] 37.836129 seconds elapsed, finished iteration 165
# [LightGBM] [Info] Iteration:166, valid_1 auc : 0.679538
# [LightGBM] [Info] 38.011277 seconds elapsed, finished iteration 166
# [LightGBM] [Info] Iteration:167, valid_1 auc : 0.679570
# [LightGBM] [Info] 38.218281 seconds elapsed, finished iteration 167
# [LightGBM] [Info] Iteration:168, valid_1 auc : 0.679604
# [LightGBM] [Info] 38.392592 seconds elapsed, finished iteration 168
# [LightGBM] [Info] Iteration:169, valid_1 auc : 0.679652
# [LightGBM] [Info] 38.595979 seconds elapsed, finished iteration 169
# [LightGBM] [Info] Iteration:170, valid_1 auc : 0.679694
# [LightGBM] [Info] 38.906005 seconds elapsed, finished iteration 170
# [LightGBM] [Info] Iteration:171, valid_1 auc : 0.679751
# [LightGBM] [Info] 39.314043 seconds elapsed, finished iteration 171
# [LightGBM] [Info] Iteration:172, valid_1 auc : 0.679815
# [LightGBM] [Info] 39.511145 seconds elapsed, finished iteration 172
# [LightGBM] [Info] Iteration:173, valid_1 auc : 0.679842
# [LightGBM] [Info] 39.813604 seconds elapsed, finished iteration 173
# [LightGBM] [Info] Iteration:174, valid_1 auc : 0.679860
# [LightGBM] [Info] 40.012869 seconds elapsed, finished iteration 174
# [LightGBM] [Info] Iteration:175, valid_1 auc : 0.679892
# [LightGBM] [Info] 40.218326 seconds elapsed, finished iteration 175
# [LightGBM] [Info] Iteration:176, valid_1 auc : 0.679939
# [LightGBM] [Info] 40.543744 seconds elapsed, finished iteration 176
# [LightGBM] [Info] Iteration:177, valid_1 auc : 0.680016
# [LightGBM] [Info] 40.796620 seconds elapsed, finished iteration 177
# [LightGBM] [Info] Iteration:178, valid_1 auc : 0.680064
# [LightGBM] [Info] 41.103698 seconds elapsed, finished iteration 178
# [LightGBM] [Info] Iteration:179, valid_1 auc : 0.680117
# [LightGBM] [Info] 41.367166 seconds elapsed, finished iteration 179
# [LightGBM] [Info] Iteration:180, valid_1 auc : 0.680165
# [LightGBM] [Info] 41.686245 seconds elapsed, finished iteration 180
# [LightGBM] [Info] Iteration:181, valid_1 auc : 0.680174
# [LightGBM] [Info] 41.856434 seconds elapsed, finished iteration 181
# [LightGBM] [Info] Iteration:182, valid_1 auc : 0.680211
# [LightGBM] [Info] 42.051967 seconds elapsed, finished iteration 182
# [LightGBM] [Info] Iteration:183, valid_1 auc : 0.680277
# [LightGBM] [Info] 42.264471 seconds elapsed, finished iteration 183
# [LightGBM] [Info] Iteration:184, valid_1 auc : 0.680320
# [LightGBM] [Info] 42.459459 seconds elapsed, finished iteration 184
# [LightGBM] [Info] Iteration:185, valid_1 auc : 0.680325
# [LightGBM] [Info] 42.795796 seconds elapsed, finished iteration 185
# [LightGBM] [Info] Iteration:186, valid_1 auc : 0.680359
# [LightGBM] [Info] 43.121864 seconds elapsed, finished iteration 186
# [LightGBM] [Info] Iteration:187, valid_1 auc : 0.680418
# [LightGBM] [Info] 43.490924 seconds elapsed, finished iteration 187
# [LightGBM] [Info] Iteration:188, valid_1 auc : 0.680474
# [LightGBM] [Info] 43.696567 seconds elapsed, finished iteration 188
# [LightGBM] [Info] Iteration:189, valid_1 auc : 0.680492
# [LightGBM] [Info] 43.995786 seconds elapsed, finished iteration 189
# [LightGBM] [Info] Iteration:190, valid_1 auc : 0.680552
# [LightGBM] [Info] 44.192253 seconds elapsed, finished iteration 190
# [LightGBM] [Info] Iteration:191, valid_1 auc : 0.680587
# [LightGBM] [Info] 44.358596 seconds elapsed, finished iteration 191
# [LightGBM] [Info] Iteration:192, valid_1 auc : 0.680634
# [LightGBM] [Info] 44.540571 seconds elapsed, finished iteration 192
# [LightGBM] [Info] Iteration:193, valid_1 auc : 0.680641
# [LightGBM] [Info] 44.711178 seconds elapsed, finished iteration 193
# [LightGBM] [Info] Iteration:194, valid_1 auc : 0.680674
# [LightGBM] [Info] 44.899757 seconds elapsed, finished iteration 194
# [LightGBM] [Info] Iteration:195, valid_1 auc : 0.680719
# [LightGBM] [Info] 45.197514 seconds elapsed, finished iteration 195
# [LightGBM] [Info] Iteration:196, valid_1 auc : 0.680735
# [LightGBM] [Info] 45.382964 seconds elapsed, finished iteration 196
# [LightGBM] [Info] Iteration:197, valid_1 auc : 0.680772
# [LightGBM] [Info] 45.577480 seconds elapsed, finished iteration 197
# [LightGBM] [Info] Iteration:198, valid_1 auc : 0.680806
# [LightGBM] [Info] 45.898487 seconds elapsed, finished iteration 198
# [LightGBM] [Info] Iteration:199, valid_1 auc : 0.680816
# [LightGBM] [Info] 46.087761 seconds elapsed, finished iteration 199
# [LightGBM] [Info] Iteration:200, valid_1 auc : 0.680841
# [LightGBM] [Info] 46.409865 seconds elapsed, finished iteration 200
# [LightGBM] [Info] Iteration:201, valid_1 auc : 0.680879
# [LightGBM] [Info] 46.589287 seconds elapsed, finished iteration 201
# [LightGBM] [Info] Iteration:202, valid_1 auc : 0.680909
# [LightGBM] [Info] 46.869933 seconds elapsed, finished iteration 202
# [LightGBM] [Info] Iteration:203, valid_1 auc : 0.680934
# [LightGBM] [Info] 47.121678 seconds elapsed, finished iteration 203
# [LightGBM] [Info] Iteration:204, valid_1 auc : 0.680984
# [LightGBM] [Info] 47.290785 seconds elapsed, finished iteration 204
# [LightGBM] [Info] Iteration:205, valid_1 auc : 0.681035
# [LightGBM] [Info] 47.612163 seconds elapsed, finished iteration 205
# [LightGBM] [Info] Iteration:206, valid_1 auc : 0.681025
# [LightGBM] [Info] 47.815963 seconds elapsed, finished iteration 206
# [LightGBM] [Info] Iteration:207, valid_1 auc : 0.681082
# [LightGBM] [Info] 48.045727 seconds elapsed, finished iteration 207
# [LightGBM] [Info] Iteration:208, valid_1 auc : 0.681110
# [LightGBM] [Info] 48.235919 seconds elapsed, finished iteration 208
# [LightGBM] [Info] Iteration:209, valid_1 auc : 0.681156
# [LightGBM] [Info] 48.545189 seconds elapsed, finished iteration 209
# [LightGBM] [Info] Iteration:210, valid_1 auc : 0.681229
# [LightGBM] [Info] 48.732785 seconds elapsed, finished iteration 210
# [LightGBM] [Info] Iteration:211, valid_1 auc : 0.681259
# [LightGBM] [Info] 48.925635 seconds elapsed, finished iteration 211
# [LightGBM] [Info] Iteration:212, valid_1 auc : 0.681285
# [LightGBM] [Info] 49.120052 seconds elapsed, finished iteration 212
# [LightGBM] [Info] Iteration:213, valid_1 auc : 0.681310
# [LightGBM] [Info] 49.294084 seconds elapsed, finished iteration 213
# [LightGBM] [Info] Iteration:214, valid_1 auc : 0.681336
# [LightGBM] [Info] 49.488558 seconds elapsed, finished iteration 214
# [LightGBM] [Info] Iteration:215, valid_1 auc : 0.681368
# [LightGBM] [Info] 49.799515 seconds elapsed, finished iteration 215
# [LightGBM] [Info] Iteration:216, valid_1 auc : 0.681415
# [LightGBM] [Info] 50.142167 seconds elapsed, finished iteration 216
# [LightGBM] [Info] Iteration:217, valid_1 auc : 0.681467
# [LightGBM] [Info] 50.312775 seconds elapsed, finished iteration 217
# [LightGBM] [Info] Iteration:218, valid_1 auc : 0.681515
# [LightGBM] [Info] 50.494721 seconds elapsed, finished iteration 218
# [LightGBM] [Info] Iteration:219, valid_1 auc : 0.681554
# [LightGBM] [Info] 50.660709 seconds elapsed, finished iteration 219
# [LightGBM] [Info] Iteration:220, valid_1 auc : 0.681552
# [LightGBM] [Info] 50.851615 seconds elapsed, finished iteration 220
# [LightGBM] [Info] Iteration:221, valid_1 auc : 0.681589
# [LightGBM] [Info] 51.023936 seconds elapsed, finished iteration 221
# [LightGBM] [Info] Iteration:222, valid_1 auc : 0.681660
# [LightGBM] [Info] 51.196055 seconds elapsed, finished iteration 222
# [LightGBM] [Info] Iteration:223, valid_1 auc : 0.681645
# [LightGBM] [Info] 51.365901 seconds elapsed, finished iteration 223
# [LightGBM] [Info] Iteration:224, valid_1 auc : 0.681677
# [LightGBM] [Info] 51.612526 seconds elapsed, finished iteration 224
# [LightGBM] [Info] Iteration:225, valid_1 auc : 0.681722
# [LightGBM] [Info] 51.882917 seconds elapsed, finished iteration 225
# [LightGBM] [Info] Iteration:226, valid_1 auc : 0.681744
# [LightGBM] [Info] 52.076487 seconds elapsed, finished iteration 226
# [LightGBM] [Info] Iteration:227, valid_1 auc : 0.681773
# [LightGBM] [Info] 52.226047 seconds elapsed, finished iteration 227
# [LightGBM] [Info] Iteration:228, valid_1 auc : 0.681794
# [LightGBM] [Info] 52.395903 seconds elapsed, finished iteration 228
# [LightGBM] [Info] Iteration:229, valid_1 auc : 0.681824
# [LightGBM] [Info] 52.699613 seconds elapsed, finished iteration 229
# [LightGBM] [Info] Iteration:230, valid_1 auc : 0.681811
# [LightGBM] [Info] 52.874882 seconds elapsed, finished iteration 230
# [LightGBM] [Info] Iteration:231, valid_1 auc : 0.681843
# [LightGBM] [Info] 53.057236 seconds elapsed, finished iteration 231
# [LightGBM] [Info] Iteration:232, valid_1 auc : 0.681880
# [LightGBM] [Info] 53.415812 seconds elapsed, finished iteration 232
# [LightGBM] [Info] Iteration:233, valid_1 auc : 0.681912
# [LightGBM] [Info] 53.570890 seconds elapsed, finished iteration 233
# [LightGBM] [Info] Iteration:234, valid_1 auc : 0.681976
# [LightGBM] [Info] 53.751323 seconds elapsed, finished iteration 234
# [LightGBM] [Info] Iteration:235, valid_1 auc : 0.681983
# [LightGBM] [Info] 53.932592 seconds elapsed, finished iteration 235
# [LightGBM] [Info] Iteration:236, valid_1 auc : 0.682054
# [LightGBM] [Info] 54.108730 seconds elapsed, finished iteration 236
# [LightGBM] [Info] Iteration:237, valid_1 auc : 0.682097
# [LightGBM] [Info] 54.269567 seconds elapsed, finished iteration 237
# [LightGBM] [Info] Iteration:238, valid_1 auc : 0.682114
# [LightGBM] [Info] 54.438554 seconds elapsed, finished iteration 238
# [LightGBM] [Info] Iteration:239, valid_1 auc : 0.682153
# [LightGBM] [Info] 54.625501 seconds elapsed, finished iteration 239
# [LightGBM] [Info] Iteration:240, valid_1 auc : 0.682142
# [LightGBM] [Info] 54.816211 seconds elapsed, finished iteration 240
# [LightGBM] [Info] Iteration:241, valid_1 auc : 0.682148
# [LightGBM] [Info] 54.981345 seconds elapsed, finished iteration 241
# [LightGBM] [Info] Iteration:242, valid_1 auc : 0.682182
# [LightGBM] [Info] 55.139261 seconds elapsed, finished iteration 242
# [LightGBM] [Info] Iteration:243, valid_1 auc : 0.682163
# [LightGBM] [Info] 55.303747 seconds elapsed, finished iteration 243
# [LightGBM] [Info] Iteration:244, valid_1 auc : 0.682203
# [LightGBM] [Info] 55.506580 seconds elapsed, finished iteration 244
# [LightGBM] [Info] Iteration:245, valid_1 auc : 0.682229
# [LightGBM] [Info] 55.657593 seconds elapsed, finished iteration 245
# [LightGBM] [Info] Iteration:246, valid_1 auc : 0.682258
# [LightGBM] [Info] 55.841894 seconds elapsed, finished iteration 246
# [LightGBM] [Info] Iteration:247, valid_1 auc : 0.682224
# [LightGBM] [Info] 56.174467 seconds elapsed, finished iteration 247
# [LightGBM] [Info] Iteration:248, valid_1 auc : 0.682215
# [LightGBM] [Info] 56.355703 seconds elapsed, finished iteration 248
# [LightGBM] [Info] Iteration:249, valid_1 auc : 0.682271
# [LightGBM] [Info] 56.528401 seconds elapsed, finished iteration 249
# [LightGBM] [Info] Iteration:250, valid_1 auc : 0.682317
# [LightGBM] [Info] 56.677206 seconds elapsed, finished iteration 250
# [LightGBM] [Info] Iteration:251, valid_1 auc : 0.682317
# [LightGBM] [Info] 56.855083 seconds elapsed, finished iteration 251
# [LightGBM] [Info] Iteration:252, valid_1 auc : 0.682357
# [LightGBM] [Info] 57.049426 seconds elapsed, finished iteration 252
# [LightGBM] [Info] Iteration:253, valid_1 auc : 0.682351
# [LightGBM] [Info] 57.406557 seconds elapsed, finished iteration 253
# [LightGBM] [Info] Iteration:254, valid_1 auc : 0.682368
# [LightGBM] [Info] 57.538781 seconds elapsed, finished iteration 254
# [LightGBM] [Info] Iteration:255, valid_1 auc : 0.682406
# [LightGBM] [Info] 57.698071 seconds elapsed, finished iteration 255
# [LightGBM] [Info] Iteration:256, valid_1 auc : 0.682430
# [LightGBM] [Info] 58.050290 seconds elapsed, finished iteration 256
# [LightGBM] [Info] Iteration:257, valid_1 auc : 0.682457
# [LightGBM] [Info] 58.213615 seconds elapsed, finished iteration 257
# [LightGBM] [Info] Iteration:258, valid_1 auc : 0.682488
# [LightGBM] [Info] 58.393242 seconds elapsed, finished iteration 258
# [LightGBM] [Info] Iteration:259, valid_1 auc : 0.682492
# [LightGBM] [Info] 58.531912 seconds elapsed, finished iteration 259
# [LightGBM] [Info] Iteration:260, valid_1 auc : 0.682482
# [LightGBM] [Info] 58.834632 seconds elapsed, finished iteration 260
# [LightGBM] [Info] Iteration:261, valid_1 auc : 0.682442
# [LightGBM] [Info] 59.003486 seconds elapsed, finished iteration 261
# [LightGBM] [Info] Iteration:262, valid_1 auc : 0.682463
# [LightGBM] [Info] 59.186258 seconds elapsed, finished iteration 262
# [LightGBM] [Info] Iteration:263, valid_1 auc : 0.682528
# [LightGBM] [Info] 59.346371 seconds elapsed, finished iteration 263
# [LightGBM] [Info] Iteration:264, valid_1 auc : 0.682539
# [LightGBM] [Info] 59.682120 seconds elapsed, finished iteration 264
# [LightGBM] [Info] Iteration:265, valid_1 auc : 0.682501
# [LightGBM] [Info] 59.853829 seconds elapsed, finished iteration 265
# [LightGBM] [Info] Iteration:266, valid_1 auc : 0.682511
# [LightGBM] [Info] 60.014145 seconds elapsed, finished iteration 266
# [LightGBM] [Info] Iteration:267, valid_1 auc : 0.682500
# [LightGBM] [Info] 60.320046 seconds elapsed, finished iteration 267
# [LightGBM] [Info] Iteration:268, valid_1 auc : 0.682529
# [LightGBM] [Info] 60.492363 seconds elapsed, finished iteration 268
# [LightGBM] [Info] Iteration:269, valid_1 auc : 0.682574
# [LightGBM] [Info] 60.644680 seconds elapsed, finished iteration 269
# [LightGBM] [Info] Iteration:270, valid_1 auc : 0.682586
# [LightGBM] [Info] 60.822839 seconds elapsed, finished iteration 270
# [LightGBM] [Info] Iteration:271, valid_1 auc : 0.682586
# [LightGBM] [Info] 60.990278 seconds elapsed, finished iteration 271
# [LightGBM] [Info] Iteration:272, valid_1 auc : 0.682625
# [LightGBM] [Info] 61.142776 seconds elapsed, finished iteration 272
# [LightGBM] [Info] Iteration:273, valid_1 auc : 0.682629
# [LightGBM] [Info] 61.311829 seconds elapsed, finished iteration 273
# [LightGBM] [Info] Iteration:274, valid_1 auc : 0.682646
# [LightGBM] [Info] 61.477994 seconds elapsed, finished iteration 274
# [LightGBM] [Info] Iteration:275, valid_1 auc : 0.682674
# [LightGBM] [Info] 61.801581 seconds elapsed, finished iteration 275
# [LightGBM] [Info] Iteration:276, valid_1 auc : 0.682713
# [LightGBM] [Info] 62.183304 seconds elapsed, finished iteration 276
# [LightGBM] [Info] Iteration:277, valid_1 auc : 0.682722
# [LightGBM] [Info] 62.542473 seconds elapsed, finished iteration 277
# [LightGBM] [Info] Iteration:278, valid_1 auc : 0.682715
# [LightGBM] [Info] 62.990674 seconds elapsed, finished iteration 278
# [LightGBM] [Info] Iteration:279, valid_1 auc : 0.682700
# [LightGBM] [Info] 63.319267 seconds elapsed, finished iteration 279
# [LightGBM] [Info] Iteration:280, valid_1 auc : 0.682708
# [LightGBM] [Info] 63.651172 seconds elapsed, finished iteration 280
# [LightGBM] [Info] Iteration:281, valid_1 auc : 0.682713
# [LightGBM] [Info] 63.959649 seconds elapsed, finished iteration 281
# [LightGBM] [Info] Iteration:282, valid_1 auc : 0.682697
# [LightGBM] [Info] 64.136277 seconds elapsed, finished iteration 282
# [LightGBM] [Info] Iteration:283, valid_1 auc : 0.682699
# [LightGBM] [Info] 64.323556 seconds elapsed, finished iteration 283
# [LightGBM] [Info] Iteration:284, valid_1 auc : 0.682715
# [LightGBM] [Info] 64.492149 seconds elapsed, finished iteration 284
# [LightGBM] [Info] Iteration:285, valid_1 auc : 0.682735
# [LightGBM] [Info] 64.617599 seconds elapsed, finished iteration 285
# [LightGBM] [Info] Iteration:286, valid_1 auc : 0.682747
# [LightGBM] [Info] 64.753810 seconds elapsed, finished iteration 286
# [LightGBM] [Info] Iteration:287, valid_1 auc : 0.682712
# [LightGBM] [Info] 64.920360 seconds elapsed, finished iteration 287
# [LightGBM] [Info] Iteration:288, valid_1 auc : 0.682723
# [LightGBM] [Info] 65.098418 seconds elapsed, finished iteration 288
# [LightGBM] [Info] Iteration:289, valid_1 auc : 0.682720
# [LightGBM] [Info] 65.269876 seconds elapsed, finished iteration 289
# [LightGBM] [Info] Iteration:290, valid_1 auc : 0.682712
# [LightGBM] [Info] 65.606495 seconds elapsed, finished iteration 290
# [LightGBM] [Info] Iteration:291, valid_1 auc : 0.682733
# [LightGBM] [Info] 65.812353 seconds elapsed, finished iteration 291
# [LightGBM] [Info] Iteration:292, valid_1 auc : 0.682696
# [LightGBM] [Info] 65.987773 seconds elapsed, finished iteration 292
# [LightGBM] [Info] Iteration:293, valid_1 auc : 0.682692
# [LightGBM] [Info] 66.398802 seconds elapsed, finished iteration 293
# [LightGBM] [Info] Iteration:294, valid_1 auc : 0.682644
# [LightGBM] [Info] 66.597058 seconds elapsed, finished iteration 294
# [LightGBM] [Info] Iteration:295, valid_1 auc : 0.682683
# [LightGBM] [Info] 66.757264 seconds elapsed, finished iteration 295
# [LightGBM] [Info] Iteration:296, valid_1 auc : 0.682702
# [LightGBM] [Info] 66.888148 seconds elapsed, finished iteration 296
# [LightGBM] [Info] Iteration:297, valid_1 auc : 0.682703
# [LightGBM] [Info] 67.159372 seconds elapsed, finished iteration 297
# [LightGBM] [Info] Iteration:298, valid_1 auc : 0.682656
# [LightGBM] [Info] 67.352786 seconds elapsed, finished iteration 298
# [LightGBM] [Info] Iteration:299, valid_1 auc : 0.682653
# [LightGBM] [Info] 67.517418 seconds elapsed, finished iteration 299
# [LightGBM] [Info] Iteration:300, valid_1 auc : 0.682595
# [LightGBM] [Info] 67.682593 seconds elapsed, finished iteration 300
# [LightGBM] [Info] Iteration:301, valid_1 auc : 0.682610
# [LightGBM] [Info] 67.857300 seconds elapsed, finished iteration 301
# [LightGBM] [Info] Iteration:302, valid_1 auc : 0.682590
# [LightGBM] [Info] 68.008555 seconds elapsed, finished iteration 302
# [LightGBM] [Info] Iteration:303, valid_1 auc : 0.682585
# [LightGBM] [Info] 68.182377 seconds elapsed, finished iteration 303
# [LightGBM] [Info] Iteration:304, valid_1 auc : 0.682584
# [LightGBM] [Info] 68.346040 seconds elapsed, finished iteration 304
# [LightGBM] [Info] Iteration:305, valid_1 auc : 0.682555
# [LightGBM] [Info] 68.643628 seconds elapsed, finished iteration 305
# [LightGBM] [Info] Iteration:306, valid_1 auc : 0.682572
# [LightGBM] [Info] 68.775754 seconds elapsed, finished iteration 306
# [LightGBM] [Info] Iteration:307, valid_1 auc : 0.682570
# [LightGBM] [Info] 68.925990 seconds elapsed, finished iteration 307
# [LightGBM] [Info] Iteration:308, valid_1 auc : 0.682578
# [LightGBM] [Info] 69.242109 seconds elapsed, finished iteration 308
# [LightGBM] [Info] Iteration:309, valid_1 auc : 0.682551
# [LightGBM] [Info] 69.621496 seconds elapsed, finished iteration 309
# [LightGBM] [Info] Iteration:310, valid_1 auc : 0.682584
# [LightGBM] [Info] 69.910437 seconds elapsed, finished iteration 310
# [LightGBM] [Info] Iteration:311, valid_1 auc : 0.682626
# [LightGBM] [Info] 70.162067 seconds elapsed, finished iteration 311
# [LightGBM] [Info] Iteration:312, valid_1 auc : 0.682611
# [LightGBM] [Info] 70.325617 seconds elapsed, finished iteration 312
# [LightGBM] [Info] Iteration:313, valid_1 auc : 0.682617
# [LightGBM] [Info] 70.490005 seconds elapsed, finished iteration 313
# [LightGBM] [Info] Iteration:314, valid_1 auc : 0.682621
# [LightGBM] [Info] 70.669567 seconds elapsed, finished iteration 314
# [LightGBM] [Info] Iteration:315, valid_1 auc : 0.682601
# [LightGBM] [Info] 70.836124 seconds elapsed, finished iteration 315
# [LightGBM] [Info] Iteration:316, valid_1 auc : 0.682539
# [LightGBM] [Info] 70.935282 seconds elapsed, finished iteration 316
# [LightGBM] [Info] Iteration:317, valid_1 auc : 0.682560
# [LightGBM] [Info] 71.066700 seconds elapsed, finished iteration 317
# [LightGBM] [Info] Iteration:318, valid_1 auc : 0.682539
# [LightGBM] [Info] 71.268211 seconds elapsed, finished iteration 318
# [LightGBM] [Info] Iteration:319, valid_1 auc : 0.682517
# [LightGBM] [Info] 71.593069 seconds elapsed, finished iteration 319
# [LightGBM] [Info] Iteration:320, valid_1 auc : 0.682539
# [LightGBM] [Info] 71.894692 seconds elapsed, finished iteration 320
# [LightGBM] [Info] Iteration:321, valid_1 auc : 0.682531
# [LightGBM] [Info] 72.063293 seconds elapsed, finished iteration 321
# [LightGBM] [Info] Iteration:322, valid_1 auc : 0.682519
# [LightGBM] [Info] 72.195764 seconds elapsed, finished iteration 322
# [LightGBM] [Info] Iteration:323, valid_1 auc : 0.682592
# [LightGBM] [Info] 72.500666 seconds elapsed, finished iteration 323
# [LightGBM] [Info] Iteration:324, valid_1 auc : 0.682630
# [LightGBM] [Info] 72.629542 seconds elapsed, finished iteration 324
# [LightGBM] [Info] Iteration:325, valid_1 auc : 0.682652
# [LightGBM] [Info] 72.736515 seconds elapsed, finished iteration 325
# [LightGBM] [Info] Iteration:326, valid_1 auc : 0.682662
# [LightGBM] [Info] 72.901499 seconds elapsed, finished iteration 326
# [LightGBM] [Info] Iteration:327, valid_1 auc : 0.682662
# [LightGBM] [Info] 73.024185 seconds elapsed, finished iteration 327
# [LightGBM] [Info] Iteration:328, valid_1 auc : 0.682648
# [LightGBM] [Info] 73.181136 seconds elapsed, finished iteration 328
# [LightGBM] [Info] Iteration:329, valid_1 auc : 0.682639
# [LightGBM] [Info] 73.338429 seconds elapsed, finished iteration 329
# [LightGBM] [Info] Iteration:330, valid_1 auc : 0.682695
# [LightGBM] [Info] 73.505892 seconds elapsed, finished iteration 330
# [LightGBM] [Info] Iteration:331, valid_1 auc : 0.682728
# [LightGBM] [Info] 73.635889 seconds elapsed, finished iteration 331
# [LightGBM] [Info] Iteration:332, valid_1 auc : 0.682720
# [LightGBM] [Info] 73.785401 seconds elapsed, finished iteration 332
# [LightGBM] [Info] Iteration:333, valid_1 auc : 0.682755
# [LightGBM] [Info] 73.929798 seconds elapsed, finished iteration 333
# [LightGBM] [Info] Iteration:334, valid_1 auc : 0.682807
# [LightGBM] [Info] 74.099368 seconds elapsed, finished iteration 334
# [LightGBM] [Info] Iteration:335, valid_1 auc : 0.682827
# [LightGBM] [Info] 74.271456 seconds elapsed, finished iteration 335
# [LightGBM] [Info] Iteration:336, valid_1 auc : 0.682874
# [LightGBM] [Info] 74.430946 seconds elapsed, finished iteration 336
# [LightGBM] [Info] Iteration:337, valid_1 auc : 0.682863
# [LightGBM] [Info] 74.589639 seconds elapsed, finished iteration 337
# [LightGBM] [Info] Iteration:338, valid_1 auc : 0.682877
# [LightGBM] [Info] 74.700913 seconds elapsed, finished iteration 338
# [LightGBM] [Info] Iteration:339, valid_1 auc : 0.682880
# [LightGBM] [Info] 74.861126 seconds elapsed, finished iteration 339
# [LightGBM] [Info] Iteration:340, valid_1 auc : 0.682866
# [LightGBM] [Info] 75.156290 seconds elapsed, finished iteration 340
# [LightGBM] [Info] Iteration:341, valid_1 auc : 0.682927
# [LightGBM] [Info] 75.346628 seconds elapsed, finished iteration 341
# [LightGBM] [Info] Iteration:342, valid_1 auc : 0.682946
# [LightGBM] [Info] 75.552998 seconds elapsed, finished iteration 342
# [LightGBM] [Info] Iteration:343, valid_1 auc : 0.682988
# [LightGBM] [Info] 75.710124 seconds elapsed, finished iteration 343
# [LightGBM] [Info] Iteration:344, valid_1 auc : 0.682942
# [LightGBM] [Info] 76.009440 seconds elapsed, finished iteration 344
# [LightGBM] [Info] Iteration:345, valid_1 auc : 0.682936
# [LightGBM] [Info] 76.145199 seconds elapsed, finished iteration 345
# [LightGBM] [Info] Iteration:346, valid_1 auc : 0.682906
# [LightGBM] [Info] 76.316912 seconds elapsed, finished iteration 346
# [LightGBM] [Info] Iteration:347, valid_1 auc : 0.682934
# [LightGBM] [Info] 76.524903 seconds elapsed, finished iteration 347
# [LightGBM] [Info] Iteration:348, valid_1 auc : 0.682956
# [LightGBM] [Info] 76.819652 seconds elapsed, finished iteration 348
# [LightGBM] [Info] Iteration:349, valid_1 auc : 0.682981
# [LightGBM] [Info] 76.945022 seconds elapsed, finished iteration 349
# [LightGBM] [Info] Iteration:350, valid_1 auc : 0.682991
# [LightGBM] [Info] 77.247953 seconds elapsed, finished iteration 350
# [LightGBM] [Info] Iteration:351, valid_1 auc : 0.682956
# [LightGBM] [Info] 77.567241 seconds elapsed, finished iteration 351
# [LightGBM] [Info] Iteration:352, valid_1 auc : 0.682991
# [LightGBM] [Info] 77.774754 seconds elapsed, finished iteration 352
# [LightGBM] [Info] Iteration:353, valid_1 auc : 0.682957
# [LightGBM] [Info] 78.025966 seconds elapsed, finished iteration 353
# [LightGBM] [Info] Iteration:354, valid_1 auc : 0.682992
# [LightGBM] [Info] 78.291586 seconds elapsed, finished iteration 354
# [LightGBM] [Info] Iteration:355, valid_1 auc : 0.683015
# [LightGBM] [Info] 78.454984 seconds elapsed, finished iteration 355
# [LightGBM] [Info] Iteration:356, valid_1 auc : 0.683013
# [LightGBM] [Info] 78.610109 seconds elapsed, finished iteration 356
# [LightGBM] [Info] Iteration:357, valid_1 auc : 0.683024
# [LightGBM] [Info] 78.832300 seconds elapsed, finished iteration 357
# [LightGBM] [Info] Iteration:358, valid_1 auc : 0.683064
# [LightGBM] [Info] 79.012535 seconds elapsed, finished iteration 358
# [LightGBM] [Info] Iteration:359, valid_1 auc : 0.683028
# [LightGBM] [Info] 79.151834 seconds elapsed, finished iteration 359
# [LightGBM] [Info] Iteration:360, valid_1 auc : 0.683043
# [LightGBM] [Info] 79.286741 seconds elapsed, finished iteration 360
# [LightGBM] [Info] Iteration:361, valid_1 auc : 0.683062
# [LightGBM] [Info] 79.433746 seconds elapsed, finished iteration 361
# [LightGBM] [Info] Iteration:362, valid_1 auc : 0.683023
# [LightGBM] [Info] 79.574629 seconds elapsed, finished iteration 362
# [LightGBM] [Info] Iteration:363, valid_1 auc : 0.683039
# [LightGBM] [Info] 79.725722 seconds elapsed, finished iteration 363
# [LightGBM] [Info] Iteration:364, valid_1 auc : 0.683040
# [LightGBM] [Info] 79.874091 seconds elapsed, finished iteration 364
# [LightGBM] [Info] Iteration:365, valid_1 auc : 0.683003
# [LightGBM] [Info] 80.033344 seconds elapsed, finished iteration 365
# [LightGBM] [Info] Iteration:366, valid_1 auc : 0.683039
# [LightGBM] [Info] 80.201500 seconds elapsed, finished iteration 366
# [LightGBM] [Info] Iteration:367, valid_1 auc : 0.683087
# [LightGBM] [Info] 80.350576 seconds elapsed, finished iteration 367
# [LightGBM] [Info] Iteration:368, valid_1 auc : 0.683067
# [LightGBM] [Info] 80.499760 seconds elapsed, finished iteration 368
# [LightGBM] [Info] Iteration:369, valid_1 auc : 0.683089
# [LightGBM] [Info] 80.614120 seconds elapsed, finished iteration 369
# [LightGBM] [Info] Iteration:370, valid_1 auc : 0.683008
# [LightGBM] [Info] 80.733313 seconds elapsed, finished iteration 370
# [LightGBM] [Info] Iteration:371, valid_1 auc : 0.682965
# [LightGBM] [Info] 80.862454 seconds elapsed, finished iteration 371
# [LightGBM] [Info] Iteration:372, valid_1 auc : 0.682936
# [LightGBM] [Info] 80.970437 seconds elapsed, finished iteration 372
# [LightGBM] [Info] Iteration:373, valid_1 auc : 0.682954
# [LightGBM] [Info] 81.141320 seconds elapsed, finished iteration 373
# [LightGBM] [Info] Iteration:374, valid_1 auc : 0.682947
# [LightGBM] [Info] 81.269809 seconds elapsed, finished iteration 374
# [LightGBM] [Info] Iteration:375, valid_1 auc : 0.682997
# [LightGBM] [Info] 81.436733 seconds elapsed, finished iteration 375
# [LightGBM] [Info] Iteration:376, valid_1 auc : 0.682988
# [LightGBM] [Info] 81.559170 seconds elapsed, finished iteration 376
# [LightGBM] [Info] Iteration:377, valid_1 auc : 0.683013
# [LightGBM] [Info] 81.696244 seconds elapsed, finished iteration 377
# [LightGBM] [Info] Iteration:378, valid_1 auc : 0.683053
# [LightGBM] [Info] 81.844136 seconds elapsed, finished iteration 378
# [LightGBM] [Info] Iteration:379, valid_1 auc : 0.683044
# [LightGBM] [Info] 82.069967 seconds elapsed, finished iteration 379
# [LightGBM] [Info] Iteration:380, valid_1 auc : 0.683006
# [LightGBM] [Info] 82.338345 seconds elapsed, finished iteration 380
# [LightGBM] [Info] Iteration:381, valid_1 auc : 0.683031
# [LightGBM] [Info] 82.499450 seconds elapsed, finished iteration 381
# [LightGBM] [Info] Iteration:382, valid_1 auc : 0.683057
# [LightGBM] [Info] 82.646859 seconds elapsed, finished iteration 382
# [LightGBM] [Info] Iteration:383, valid_1 auc : 0.683048
# [LightGBM] [Info] 82.775170 seconds elapsed, finished iteration 383
# [LightGBM] [Info] Iteration:384, valid_1 auc : 0.683014
# [LightGBM] [Info] 83.002848 seconds elapsed, finished iteration 384
# [LightGBM] [Info] Iteration:385, valid_1 auc : 0.683015
# [LightGBM] [Info] 83.211500 seconds elapsed, finished iteration 385
# [LightGBM] [Info] Iteration:386, valid_1 auc : 0.682996
# [LightGBM] [Info] 83.330745 seconds elapsed, finished iteration 386
# [LightGBM] [Info] Iteration:387, valid_1 auc : 0.683043
# [LightGBM] [Info] 83.469690 seconds elapsed, finished iteration 387
# [LightGBM] [Info] Iteration:388, valid_1 auc : 0.682988
# [LightGBM] [Info] 83.623382 seconds elapsed, finished iteration 388
# [LightGBM] [Info] Iteration:389, valid_1 auc : 0.683002
# [LightGBM] [Info] 83.893803 seconds elapsed, finished iteration 389
# [LightGBM] [Info] Iteration:390, valid_1 auc : 0.683025
# [LightGBM] [Info] 84.063636 seconds elapsed, finished iteration 390
# [LightGBM] [Info] Iteration:391, valid_1 auc : 0.683048
# [LightGBM] [Info] 84.174896 seconds elapsed, finished iteration 391
# [LightGBM] [Info] Iteration:392, valid_1 auc : 0.683025
# [LightGBM] [Info] 84.276194 seconds elapsed, finished iteration 392
# [LightGBM] [Info] Iteration:393, valid_1 auc : 0.683043
# [LightGBM] [Info] 84.420853 seconds elapsed, finished iteration 393
# [LightGBM] [Info] Iteration:394, valid_1 auc : 0.683028
# [LightGBM] [Info] 84.517067 seconds elapsed, finished iteration 394
# [LightGBM] [Info] Iteration:395, valid_1 auc : 0.683040
# [LightGBM] [Info] 84.807069 seconds elapsed, finished iteration 395
# [LightGBM] [Info] Iteration:396, valid_1 auc : 0.683050
# [LightGBM] [Info] 84.953219 seconds elapsed, finished iteration 396
# [LightGBM] [Info] Iteration:397, valid_1 auc : 0.683044
# [LightGBM] [Info] 85.054622 seconds elapsed, finished iteration 397
# [LightGBM] [Info] Iteration:398, valid_1 auc : 0.683046
# [LightGBM] [Info] 85.173195 seconds elapsed, finished iteration 398
# [LightGBM] [Info] Iteration:399, valid_1 auc : 0.683034
# [LightGBM] [Info] 85.288428 seconds elapsed, finished iteration 399
# [LightGBM] [Info] Iteration:400, valid_1 auc : 0.683045
# [LightGBM] [Info] 85.417564 seconds elapsed, finished iteration 400
# [LightGBM] [Info] Iteration:401, valid_1 auc : 0.683012
# [LightGBM] [Info] 85.534874 seconds elapsed, finished iteration 401
# [LightGBM] [Info] Iteration:402, valid_1 auc : 0.683026
# [LightGBM] [Info] 85.682018 seconds elapsed, finished iteration 402
# [LightGBM] [Info] Iteration:403, valid_1 auc : 0.683023
# [LightGBM] [Info] 85.828026 seconds elapsed, finished iteration 403
# [LightGBM] [Info] Iteration:404, valid_1 auc : 0.683020
# [LightGBM] [Info] 85.966177 seconds elapsed, finished iteration 404
# [LightGBM] [Info] Iteration:405, valid_1 auc : 0.683020
# [LightGBM] [Info] 86.136326 seconds elapsed, finished iteration 405
# [LightGBM] [Info] Iteration:406, valid_1 auc : 0.683021
# [LightGBM] [Info] 86.264629 seconds elapsed, finished iteration 406
# [LightGBM] [Info] Iteration:407, valid_1 auc : 0.682977
# [LightGBM] [Info] 86.386778 seconds elapsed, finished iteration 407
# [LightGBM] [Info] Iteration:408, valid_1 auc : 0.682913
# [LightGBM] [Info] 86.488618 seconds elapsed, finished iteration 408
# [LightGBM] [Info] Iteration:409, valid_1 auc : 0.682906
# [LightGBM] [Info] 86.613968 seconds elapsed, finished iteration 409
# [LightGBM] [Info] Iteration:410, valid_1 auc : 0.682936
# [LightGBM] [Info] 86.769934 seconds elapsed, finished iteration 410
# [LightGBM] [Info] Iteration:411, valid_1 auc : 0.682939
# [LightGBM] [Info] 86.881627 seconds elapsed, finished iteration 411
# [LightGBM] [Info] Iteration:412, valid_1 auc : 0.682847
# [LightGBM] [Info] 87.012705 seconds elapsed, finished iteration 412
# [LightGBM] [Info] Iteration:413, valid_1 auc : 0.682857
# [LightGBM] [Info] 87.143964 seconds elapsed, finished iteration 413
# [LightGBM] [Info] Iteration:414, valid_1 auc : 0.682854
# [LightGBM] [Info] 87.241957 seconds elapsed, finished iteration 414
# [LightGBM] [Info] Iteration:415, valid_1 auc : 0.682881
# [LightGBM] [Info] 87.385235 seconds elapsed, finished iteration 415
# [LightGBM] [Info] Iteration:416, valid_1 auc : 0.682966
# [LightGBM] [Info] 87.544718 seconds elapsed, finished iteration 416
# [LightGBM] [Info] Iteration:417, valid_1 auc : 0.682972
# [LightGBM] [Info] 87.676807 seconds elapsed, finished iteration 417
# [LightGBM] [Info] Iteration:418, valid_1 auc : 0.682988
# [LightGBM] [Info] 87.822252 seconds elapsed, finished iteration 418
# [LightGBM] [Info] Iteration:419, valid_1 auc : 0.682984
# [LightGBM] [Info] 87.942121 seconds elapsed, finished iteration 419
# [LightGBM] [Info] Iteration:420, valid_1 auc : 0.682993
# [LightGBM] [Info] 88.083220 seconds elapsed, finished iteration 420
# [LightGBM] [Info] Iteration:421, valid_1 auc : 0.683025
# [LightGBM] [Info] 88.244591 seconds elapsed, finished iteration 421
# [LightGBM] [Info] Iteration:422, valid_1 auc : 0.682977
# [LightGBM] [Info] 88.377434 seconds elapsed, finished iteration 422
# [LightGBM] [Info] Iteration:423, valid_1 auc : 0.683005
# [LightGBM] [Info] 88.529285 seconds elapsed, finished iteration 423
# [LightGBM] [Info] Iteration:424, valid_1 auc : 0.682930
# [LightGBM] [Info] 88.633466 seconds elapsed, finished iteration 424
# [LightGBM] [Info] Iteration:425, valid_1 auc : 0.682911
# [LightGBM] [Info] 88.751576 seconds elapsed, finished iteration 425
# [LightGBM] [Info] Iteration:426, valid_1 auc : 0.682901
# [LightGBM] [Info] 88.852604 seconds elapsed, finished iteration 426
# [LightGBM] [Info] Iteration:427, valid_1 auc : 0.682904
# [LightGBM] [Info] 88.967214 seconds elapsed, finished iteration 427
# [LightGBM] [Info] Iteration:428, valid_1 auc : 0.682905
# [LightGBM] [Info] 89.069607 seconds elapsed, finished iteration 428
# [LightGBM] [Info] Iteration:429, valid_1 auc : 0.682902
# [LightGBM] [Info] 89.170503 seconds elapsed, finished iteration 429
# [LightGBM] [Info] Iteration:430, valid_1 auc : 0.682852
# [LightGBM] [Info] 89.278202 seconds elapsed, finished iteration 430
# [LightGBM] [Info] Iteration:431, valid_1 auc : 0.682849
# [LightGBM] [Info] 89.432866 seconds elapsed, finished iteration 431
# [LightGBM] [Info] Iteration:432, valid_1 auc : 0.682823
# [LightGBM] [Info] 89.567449 seconds elapsed, finished iteration 432
# [LightGBM] [Info] Iteration:433, valid_1 auc : 0.682790
# [LightGBM] [Info] 89.674817 seconds elapsed, finished iteration 433
# [LightGBM] [Info] Iteration:434, valid_1 auc : 0.682814
# [LightGBM] [Info] 89.803600 seconds elapsed, finished iteration 434
# [LightGBM] [Info] Iteration:435, valid_1 auc : 0.682820
# [LightGBM] [Info] 89.923608 seconds elapsed, finished iteration 435
# [LightGBM] [Info] Iteration:436, valid_1 auc : 0.682832
# [LightGBM] [Info] 90.028121 seconds elapsed, finished iteration 436
# [LightGBM] [Info] Iteration:437, valid_1 auc : 0.682876
# [LightGBM] [Info] 90.191876 seconds elapsed, finished iteration 437
# [LightGBM] [Info] Iteration:438, valid_1 auc : 0.682856
# [LightGBM] [Info] 90.293838 seconds elapsed, finished iteration 438
# [LightGBM] [Info] Iteration:439, valid_1 auc : 0.682842
# [LightGBM] [Info] 90.408020 seconds elapsed, finished iteration 439
# [LightGBM] [Info] Iteration:440, valid_1 auc : 0.682857
# [LightGBM] [Info] 90.531919 seconds elapsed, finished iteration 440
# [LightGBM] [Info] Iteration:441, valid_1 auc : 0.682858
# [LightGBM] [Info] 90.665203 seconds elapsed, finished iteration 441
# [LightGBM] [Info] Iteration:442, valid_1 auc : 0.682861
# [LightGBM] [Info] 90.779514 seconds elapsed, finished iteration 442
# [LightGBM] [Info] Iteration:443, valid_1 auc : 0.682876
# [LightGBM] [Info] 90.912010 seconds elapsed, finished iteration 443
# [LightGBM] [Info] Iteration:444, valid_1 auc : 0.682876
# [LightGBM] [Info] 91.033531 seconds elapsed, finished iteration 444
# [LightGBM] [Info] Iteration:445, valid_1 auc : 0.682875
# [LightGBM] [Info] 91.133598 seconds elapsed, finished iteration 445
# [LightGBM] [Info] Iteration:446, valid_1 auc : 0.682866
# [LightGBM] [Info] 91.237545 seconds elapsed, finished iteration 446
# [LightGBM] [Info] Iteration:447, valid_1 auc : 0.682862
# [LightGBM] [Info] 91.366563 seconds elapsed, finished iteration 447
# [LightGBM] [Info] Iteration:448, valid_1 auc : 0.682864
# [LightGBM] [Info] 91.476486 seconds elapsed, finished iteration 448
# [LightGBM] [Info] Iteration:449, valid_1 auc : 0.682875
# [LightGBM] [Info] 91.592527 seconds elapsed, finished iteration 449
# [LightGBM] [Info] Iteration:450, valid_1 auc : 0.682889
# [LightGBM] [Info] 91.678075 seconds elapsed, finished iteration 450
# [LightGBM] [Info] Iteration:451, valid_1 auc : 0.682913
# [LightGBM] [Info] 91.838267 seconds elapsed, finished iteration 451
# [LightGBM] [Info] Iteration:452, valid_1 auc : 0.682913
# [LightGBM] [Info] 91.976859 seconds elapsed, finished iteration 452
# [LightGBM] [Info] Iteration:453, valid_1 auc : 0.682919
# [LightGBM] [Info] 92.089875 seconds elapsed, finished iteration 453
# [LightGBM] [Info] Iteration:454, valid_1 auc : 0.682951
# [LightGBM] [Info] 92.251999 seconds elapsed, finished iteration 454
# [LightGBM] [Info] Iteration:455, valid_1 auc : 0.682876
# [LightGBM] [Info] 92.474064 seconds elapsed, finished iteration 455
# [LightGBM] [Info] Iteration:456, valid_1 auc : 0.682872
# [LightGBM] [Info] 92.589872 seconds elapsed, finished iteration 456
# [LightGBM] [Info] Iteration:457, valid_1 auc : 0.682903
# [LightGBM] [Info] 92.728318 seconds elapsed, finished iteration 457
# [LightGBM] [Info] Iteration:458, valid_1 auc : 0.682941
# [LightGBM] [Info] 92.874857 seconds elapsed, finished iteration 458
# [LightGBM] [Info] Iteration:459, valid_1 auc : 0.682945
# [LightGBM] [Info] 92.969721 seconds elapsed, finished iteration 459
# [LightGBM] [Info] Iteration:460, valid_1 auc : 0.682937
# [LightGBM] [Info] 93.059414 seconds elapsed, finished iteration 460
# [LightGBM] [Info] Iteration:461, valid_1 auc : 0.682944
# [LightGBM] [Info] 93.171231 seconds elapsed, finished iteration 461
# [LightGBM] [Info] Iteration:462, valid_1 auc : 0.682919
# [LightGBM] [Info] 93.279314 seconds elapsed, finished iteration 462
# [LightGBM] [Info] Iteration:463, valid_1 auc : 0.682909
# [LightGBM] [Info] 93.411753 seconds elapsed, finished iteration 463
# [LightGBM] [Info] Iteration:464, valid_1 auc : 0.682912
# [LightGBM] [Info] 93.538336 seconds elapsed, finished iteration 464
# [LightGBM] [Info] Iteration:465, valid_1 auc : 0.682911
# [LightGBM] [Info] 93.667885 seconds elapsed, finished iteration 465
# [LightGBM] [Info] Iteration:466, valid_1 auc : 0.682914
# [LightGBM] [Info] 93.938548 seconds elapsed, finished iteration 466
# [LightGBM] [Info] Iteration:467, valid_1 auc : 0.682926
# [LightGBM] [Info] 94.074355 seconds elapsed, finished iteration 467
# [LightGBM] [Info] Iteration:468, valid_1 auc : 0.682935
# [LightGBM] [Info] 94.173539 seconds elapsed, finished iteration 468
# [LightGBM] [Info] Iteration:469, valid_1 auc : 0.682934
# [LightGBM] [Info] 94.264721 seconds elapsed, finished iteration 469
# [LightGBM] [Info] Iteration:470, valid_1 auc : 0.682927
# [LightGBM] [Info] 94.380871 seconds elapsed, finished iteration 470
# [LightGBM] [Info] Iteration:471, valid_1 auc : 0.682892
# [LightGBM] [Info] 94.485037 seconds elapsed, finished iteration 471
# [LightGBM] [Info] Iteration:472, valid_1 auc : 0.682879
# [LightGBM] [Info] 94.752744 seconds elapsed, finished iteration 472
# [LightGBM] [Info] Iteration:473, valid_1 auc : 0.682883
# [LightGBM] [Info] 94.857551 seconds elapsed, finished iteration 473
# [LightGBM] [Info] Iteration:474, valid_1 auc : 0.682918
# [LightGBM] [Info] 94.943415 seconds elapsed, finished iteration 474
# [LightGBM] [Info] Iteration:475, valid_1 auc : 0.682936
# [LightGBM] [Info] 95.085357 seconds elapsed, finished iteration 475
# [LightGBM] [Info] Iteration:476, valid_1 auc : 0.682973
# [LightGBM] [Info] 95.197030 seconds elapsed, finished iteration 476
# [LightGBM] [Info] Iteration:477, valid_1 auc : 0.683000
# [LightGBM] [Info] 95.516117 seconds elapsed, finished iteration 477
# [LightGBM] [Info] Iteration:478, valid_1 auc : 0.683001
# [LightGBM] [Info] 95.613597 seconds elapsed, finished iteration 478
# [LightGBM] [Info] Iteration:479, valid_1 auc : 0.683001
# [LightGBM] [Info] 95.701769 seconds elapsed, finished iteration 479
# [LightGBM] [Info] Iteration:480, valid_1 auc : 0.683002
# [LightGBM] [Info] 95.791208 seconds elapsed, finished iteration 480
# [LightGBM] [Info] Iteration:481, valid_1 auc : 0.682992
# [LightGBM] [Info] 95.891283 seconds elapsed, finished iteration 481
# [LightGBM] [Info] Iteration:482, valid_1 auc : 0.682990
# [LightGBM] [Info] 96.024802 seconds elapsed, finished iteration 482
# [LightGBM] [Info] Iteration:483, valid_1 auc : 0.682994
# [LightGBM] [Info] 96.167487 seconds elapsed, finished iteration 483
# [LightGBM] [Info] Iteration:484, valid_1 auc : 0.682936
# [LightGBM] [Info] 96.293792 seconds elapsed, finished iteration 484
# [LightGBM] [Info] Iteration:485, valid_1 auc : 0.682943
# [LightGBM] [Info] 96.415680 seconds elapsed, finished iteration 485
# [LightGBM] [Info] Iteration:486, valid_1 auc : 0.682924
# [LightGBM] [Info] 96.512986 seconds elapsed, finished iteration 486
# [LightGBM] [Info] Iteration:487, valid_1 auc : 0.682919
# [LightGBM] [Info] 96.772220 seconds elapsed, finished iteration 487
# [LightGBM] [Info] Iteration:488, valid_1 auc : 0.682950
# [LightGBM] [Info] 96.904220 seconds elapsed, finished iteration 488
# [LightGBM] [Info] Iteration:489, valid_1 auc : 0.682939
# [LightGBM] [Info] 97.005647 seconds elapsed, finished iteration 489
# [LightGBM] [Info] Iteration:490, valid_1 auc : 0.682949
# [LightGBM] [Info] 97.098976 seconds elapsed, finished iteration 490
# [LightGBM] [Info] Iteration:491, valid_1 auc : 0.682952
# [LightGBM] [Info] 97.192104 seconds elapsed, finished iteration 491
# [LightGBM] [Info] Iteration:492, valid_1 auc : 0.682955
# [LightGBM] [Info] 97.304820 seconds elapsed, finished iteration 492
# [LightGBM] [Info] Iteration:493, valid_1 auc : 0.682950
# [LightGBM] [Info] 97.429605 seconds elapsed, finished iteration 493
# [LightGBM] [Info] Iteration:494, valid_1 auc : 0.682947
# [LightGBM] [Info] 97.547547 seconds elapsed, finished iteration 494
# [LightGBM] [Info] Iteration:495, valid_1 auc : 0.682961
# [LightGBM] [Info] 97.803591 seconds elapsed, finished iteration 495
# [LightGBM] [Info] Iteration:496, valid_1 auc : 0.682962
# [LightGBM] [Info] 97.925771 seconds elapsed, finished iteration 496
# [LightGBM] [Info] Iteration:497, valid_1 auc : 0.682976
# [LightGBM] [Info] 98.117966 seconds elapsed, finished iteration 497
# [LightGBM] [Info] Iteration:498, valid_1 auc : 0.682973
# [LightGBM] [Info] 98.294442 seconds elapsed, finished iteration 498
# [LightGBM] [Info] Iteration:499, valid_1 auc : 0.682929
# [LightGBM] [Info] 98.449194 seconds elapsed, finished iteration 499
# [LightGBM] [Info] Iteration:500, valid_1 auc : 0.682961
# [LightGBM] [Info] 98.573523 seconds elapsed, finished iteration 500
# [LightGBM] [Info] Finished training

# %% [markdown]
# ### Iteration:500, valid_1 auc : 0.683961

# %% [markdown]
# #### Строим модель на всех данных

# %%
#target encoding
avg_target = {}
categorical_features = [u'mob_provider',u'federal_district']
smooth_N = 100

df_all = (hc.sql('select * from user_kposminin.id_feat_ccall')        
        .toPandas()
         )

global_mean = df_all[label].mean()
labelencoder,avg_target = {}, {}

for v in categorical_features:
    vals = df_all[v].unique()
    labelencoder[v] = {k:v for k,v in zip(vals,range(len(vals)))}
    df_all[v] = df_all[v].map(lambda f: labelencoder[v].get(f,-1))
    v_stat = df_all.groupby(v)[label].agg([sum,len])
    avg_target[v] = (v_stat['sum'] + smooth_N * global_mean) / (v_stat['len'] + smooth_N)

# %%
#target encoding
df_enc = target_encoding([u'mob_provider',u'federal_district'], label, df_all, df_test = pd.DataFrame(columns = df_all.columns), folds = 5, smooth_N = 100, inplace = False)
df_all = df_all.join(df_enc[0])

# %%
clf = GBMClassifier(
        exec_path=exec_path,
        min_data_in_leaf=200,
       # is_unbalance = True,
        num_iterations = 500,
        bagging_fraction = 1,
        bagging_freq = 30,
        feature_fraction = 1,
        num_leaves = 63,
        learning_rate = 0.02,
        metric = 'auc',
        verbose = False
    )

clf.fit(df_all[feats], df_all[label])
# Out:
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading data in 5.080120 seconds
# [LightGBM] [Info] Number of postive: 132875, number of negative: 229330
# [LightGBM] [Info] Number of data: 362205, number of features: 43
# [LightGBM] [Info] Finished initializing training
# [LightGBM] [Info] Started training...
# [LightGBM] [Info] 0.507076 seconds elapsed, finished iteration 1
# [LightGBM] [Info] 0.873124 seconds elapsed, finished iteration 2
# [LightGBM] [Info] 1.186530 seconds elapsed, finished iteration 3
# [LightGBM] [Info] 1.525300 seconds elapsed, finished iteration 4
# [LightGBM] [Info] 1.886791 seconds elapsed, finished iteration 5
# [LightGBM] [Info] 2.121425 seconds elapsed, finished iteration 6
# [LightGBM] [Info] 2.354952 seconds elapsed, finished iteration 7
# [LightGBM] [Info] 2.715901 seconds elapsed, finished iteration 8
# [LightGBM] [Info] 2.948665 seconds elapsed, finished iteration 9
# [LightGBM] [Info] 3.174533 seconds elapsed, finished iteration 10
# [LightGBM] [Info] 3.401971 seconds elapsed, finished iteration 11
# [LightGBM] [Info] 3.750067 seconds elapsed, finished iteration 12
# [LightGBM] [Info] 3.968620 seconds elapsed, finished iteration 13
# [LightGBM] [Info] 4.207708 seconds elapsed, finished iteration 14
# [LightGBM] [Info] 4.566209 seconds elapsed, finished iteration 15
# [LightGBM] [Info] 4.805735 seconds elapsed, finished iteration 16
# [LightGBM] [Info] 5.204198 seconds elapsed, finished iteration 17
# [LightGBM] [Info] 5.422589 seconds elapsed, finished iteration 18
# [LightGBM] [Info] 5.651232 seconds elapsed, finished iteration 19
# [LightGBM] [Info] 5.873527 seconds elapsed, finished iteration 20
# [LightGBM] [Info] 6.085950 seconds elapsed, finished iteration 21
# [LightGBM] [Info] 6.305549 seconds elapsed, finished iteration 22
# [LightGBM] [Info] 6.520539 seconds elapsed, finished iteration 23
# [LightGBM] [Info] 6.733482 seconds elapsed, finished iteration 24
# [LightGBM] [Info] 6.978127 seconds elapsed, finished iteration 25
# [LightGBM] [Info] 7.384021 seconds elapsed, finished iteration 26
# [LightGBM] [Info] 7.643243 seconds elapsed, finished iteration 27
# [LightGBM] [Info] 7.864656 seconds elapsed, finished iteration 28
# [LightGBM] [Info] 8.090519 seconds elapsed, finished iteration 29
# [LightGBM] [Info] 8.423717 seconds elapsed, finished iteration 30
# [LightGBM] [Info] 8.689443 seconds elapsed, finished iteration 31
# [LightGBM] [Info] 8.923113 seconds elapsed, finished iteration 32
# [LightGBM] [Info] 9.145062 seconds elapsed, finished iteration 33
# [LightGBM] [Info] 9.383831 seconds elapsed, finished iteration 34
# [LightGBM] [Info] 9.618023 seconds elapsed, finished iteration 35
# [LightGBM] [Info] 9.854874 seconds elapsed, finished iteration 36
# [LightGBM] [Info] 10.149546 seconds elapsed, finished iteration 37
# [LightGBM] [Info] 10.415608 seconds elapsed, finished iteration 38
# [LightGBM] [Info] 10.647241 seconds elapsed, finished iteration 39
# [LightGBM] [Info] 10.906109 seconds elapsed, finished iteration 40
# [LightGBM] [Info] 11.143465 seconds elapsed, finished iteration 41
# [LightGBM] [Info] 11.362542 seconds elapsed, finished iteration 42
# [LightGBM] [Info] 11.600298 seconds elapsed, finished iteration 43
# [LightGBM] [Info] 11.839114 seconds elapsed, finished iteration 44
# [LightGBM] [Info] 12.064336 seconds elapsed, finished iteration 45
# [LightGBM] [Info] 12.297655 seconds elapsed, finished iteration 46
# [LightGBM] [Info] 12.720657 seconds elapsed, finished iteration 47
# [LightGBM] [Info] 13.076921 seconds elapsed, finished iteration 48
# [LightGBM] [Info] 13.315150 seconds elapsed, finished iteration 49
# [LightGBM] [Info] 13.550229 seconds elapsed, finished iteration 50
# [LightGBM] [Info] 13.782181 seconds elapsed, finished iteration 51
# [LightGBM] [Info] 14.000592 seconds elapsed, finished iteration 52
# [LightGBM] [Info] 14.230706 seconds elapsed, finished iteration 53
# [LightGBM] [Info] 14.452087 seconds elapsed, finished iteration 54
# [LightGBM] [Info] 14.741327 seconds elapsed, finished iteration 55
# [LightGBM] [Info] 14.989163 seconds elapsed, finished iteration 56
# [LightGBM] [Info] 15.377548 seconds elapsed, finished iteration 57
# [LightGBM] [Info] 15.639490 seconds elapsed, finished iteration 58
# [LightGBM] [Info] 15.900889 seconds elapsed, finished iteration 59
# [LightGBM] [Info] 16.270843 seconds elapsed, finished iteration 60
# [LightGBM] [Info] 16.632184 seconds elapsed, finished iteration 61
# [LightGBM] [Info] 16.856488 seconds elapsed, finished iteration 62
# [LightGBM] [Info] 17.147017 seconds elapsed, finished iteration 63
# [LightGBM] [Info] 17.485097 seconds elapsed, finished iteration 64
# [LightGBM] [Info] 17.786561 seconds elapsed, finished iteration 65
# [LightGBM] [Info] 18.010771 seconds elapsed, finished iteration 66
# [LightGBM] [Info] 18.370487 seconds elapsed, finished iteration 67
# [LightGBM] [Info] 18.732277 seconds elapsed, finished iteration 68
# [LightGBM] [Info] 18.971325 seconds elapsed, finished iteration 69
# [LightGBM] [Info] 19.190452 seconds elapsed, finished iteration 70
# [LightGBM] [Info] 19.428358 seconds elapsed, finished iteration 71
# [LightGBM] [Info] 19.652009 seconds elapsed, finished iteration 72
# [LightGBM] [Info] 19.877744 seconds elapsed, finished iteration 73
# [LightGBM] [Info] 20.091829 seconds elapsed, finished iteration 74
# [LightGBM] [Info] 20.541361 seconds elapsed, finished iteration 75
# [LightGBM] [Info] 20.752086 seconds elapsed, finished iteration 76
# [LightGBM] [Info] 20.965865 seconds elapsed, finished iteration 77
# [LightGBM] [Info] 21.191057 seconds elapsed, finished iteration 78
# [LightGBM] [Info] 21.412609 seconds elapsed, finished iteration 79
# [LightGBM] [Info] 21.626861 seconds elapsed, finished iteration 80
# [LightGBM] [Info] 21.855653 seconds elapsed, finished iteration 81
# [LightGBM] [Info] 22.297184 seconds elapsed, finished iteration 82
# [LightGBM] [Info] 22.552448 seconds elapsed, finished iteration 83
# [LightGBM] [Info] 22.800521 seconds elapsed, finished iteration 84
# [LightGBM] [Info] 23.029332 seconds elapsed, finished iteration 85
# [LightGBM] [Info] 23.245787 seconds elapsed, finished iteration 86
# [LightGBM] [Info] 23.602406 seconds elapsed, finished iteration 87
# [LightGBM] [Info] 23.829845 seconds elapsed, finished iteration 88
# [LightGBM] [Info] 24.052915 seconds elapsed, finished iteration 89
# [LightGBM] [Info] 24.267084 seconds elapsed, finished iteration 90
# [LightGBM] [Info] 24.504408 seconds elapsed, finished iteration 91
# [LightGBM] [Info] 24.715948 seconds elapsed, finished iteration 92
# [LightGBM] [Info] 24.935816 seconds elapsed, finished iteration 93
# [LightGBM] [Info] 25.160468 seconds elapsed, finished iteration 94
# [LightGBM] [Info] 25.375272 seconds elapsed, finished iteration 95
# [LightGBM] [Info] 25.603828 seconds elapsed, finished iteration 96
# [LightGBM] [Info] 25.807682 seconds elapsed, finished iteration 97
# [LightGBM] [Info] 26.033386 seconds elapsed, finished iteration 98
# [LightGBM] [Info] 26.246522 seconds elapsed, finished iteration 99
# [LightGBM] [Info] 26.444500 seconds elapsed, finished iteration 100
# [LightGBM] [Info] 26.666764 seconds elapsed, finished iteration 101
# [LightGBM] [Info] 26.874471 seconds elapsed, finished iteration 102
# [LightGBM] [Info] 27.094791 seconds elapsed, finished iteration 103
# [LightGBM] [Info] 27.314461 seconds elapsed, finished iteration 104
# [LightGBM] [Info] 27.513415 seconds elapsed, finished iteration 105
# [LightGBM] [Info] 27.723667 seconds elapsed, finished iteration 106
# [LightGBM] [Info] 27.934506 seconds elapsed, finished iteration 107
# [LightGBM] [Info] 28.148943 seconds elapsed, finished iteration 108
# [LightGBM] [Info] 28.343027 seconds elapsed, finished iteration 109
# [LightGBM] [Info] 28.704047 seconds elapsed, finished iteration 110
# [LightGBM] [Info] 29.089127 seconds elapsed, finished iteration 111
# [LightGBM] [Info] 29.292087 seconds elapsed, finished iteration 112
# [LightGBM] [Info] 29.488469 seconds elapsed, finished iteration 113
# [LightGBM] [Info] 29.716642 seconds elapsed, finished iteration 114
# [LightGBM] [Info] 29.916118 seconds elapsed, finished iteration 115
# [LightGBM] [Info] 30.125541 seconds elapsed, finished iteration 116
# [LightGBM] [Info] 30.613106 seconds elapsed, finished iteration 117
# [LightGBM] [Info] 30.821185 seconds elapsed, finished iteration 118
# [LightGBM] [Info] 31.072444 seconds elapsed, finished iteration 119
# [LightGBM] [Info] 31.456587 seconds elapsed, finished iteration 120
# [LightGBM] [Info] 31.645395 seconds elapsed, finished iteration 121
# [LightGBM] [Info] 31.862414 seconds elapsed, finished iteration 122
# [LightGBM] [Info] 32.070988 seconds elapsed, finished iteration 123
# [LightGBM] [Info] 32.278202 seconds elapsed, finished iteration 124
# [LightGBM] [Info] 32.466428 seconds elapsed, finished iteration 125
# [LightGBM] [Info] 32.670551 seconds elapsed, finished iteration 126
# [LightGBM] [Info] 32.872097 seconds elapsed, finished iteration 127
# [LightGBM] [Info] 33.052309 seconds elapsed, finished iteration 128
# [LightGBM] [Info] 33.254174 seconds elapsed, finished iteration 129
# [LightGBM] [Info] 33.472483 seconds elapsed, finished iteration 130
# [LightGBM] [Info] 33.899175 seconds elapsed, finished iteration 131
# [LightGBM] [Info] 34.127177 seconds elapsed, finished iteration 132
# [LightGBM] [Info] 34.343472 seconds elapsed, finished iteration 133
# [LightGBM] [Info] 34.622736 seconds elapsed, finished iteration 134
# [LightGBM] [Info] 34.864880 seconds elapsed, finished iteration 135
# [LightGBM] [Info] 35.079719 seconds elapsed, finished iteration 136
# [LightGBM] [Info] 35.274338 seconds elapsed, finished iteration 137
# [LightGBM] [Info] 35.487896 seconds elapsed, finished iteration 138
# [LightGBM] [Info] 35.687007 seconds elapsed, finished iteration 139
# [LightGBM] [Info] 35.907597 seconds elapsed, finished iteration 140
# [LightGBM] [Info] 36.109545 seconds elapsed, finished iteration 141
# [LightGBM] [Info] 36.310724 seconds elapsed, finished iteration 142
# [LightGBM] [Info] 36.515985 seconds elapsed, finished iteration 143
# [LightGBM] [Info] 36.922197 seconds elapsed, finished iteration 144
# [LightGBM] [Info] 37.187409 seconds elapsed, finished iteration 145
# [LightGBM] [Info] 37.370778 seconds elapsed, finished iteration 146
# [LightGBM] [Info] 37.712590 seconds elapsed, finished iteration 147
# [LightGBM] [Info] 37.942545 seconds elapsed, finished iteration 148
# [LightGBM] [Info] 38.163291 seconds elapsed, finished iteration 149
# [LightGBM] [Info] 38.370384 seconds elapsed, finished iteration 150
# [LightGBM] [Info] 38.602353 seconds elapsed, finished iteration 151
# [LightGBM] [Info] 38.799090 seconds elapsed, finished iteration 152
# [LightGBM] [Info] 38.995479 seconds elapsed, finished iteration 153
# [LightGBM] [Info] 39.210536 seconds elapsed, finished iteration 154
# [LightGBM] [Info] 39.394342 seconds elapsed, finished iteration 155
# [LightGBM] [Info] 39.613887 seconds elapsed, finished iteration 156
# [LightGBM] [Info] 39.841037 seconds elapsed, finished iteration 157
# [LightGBM] [Info] 40.195207 seconds elapsed, finished iteration 158
# [LightGBM] [Info] 40.409712 seconds elapsed, finished iteration 159
# [LightGBM] [Info] 40.725768 seconds elapsed, finished iteration 160
# [LightGBM] [Info] 41.068194 seconds elapsed, finished iteration 161
# [LightGBM] [Info] 41.415754 seconds elapsed, finished iteration 162
# [LightGBM] [Info] 41.619415 seconds elapsed, finished iteration 163
# [LightGBM] [Info] 41.839780 seconds elapsed, finished iteration 164
# [LightGBM] [Info] 42.271828 seconds elapsed, finished iteration 165
# [LightGBM] [Info] 42.667683 seconds elapsed, finished iteration 166
# [LightGBM] [Info] 42.987566 seconds elapsed, finished iteration 167
# [LightGBM] [Info] 43.206706 seconds elapsed, finished iteration 168
# [LightGBM] [Info] 43.387729 seconds elapsed, finished iteration 169
# [LightGBM] [Info] 43.610019 seconds elapsed, finished iteration 170
# [LightGBM] [Info] 43.830138 seconds elapsed, finished iteration 171
# [LightGBM] [Info] 44.246905 seconds elapsed, finished iteration 172
# [LightGBM] [Info] 44.476413 seconds elapsed, finished iteration 173
# [LightGBM] [Info] 44.699882 seconds elapsed, finished iteration 174
# [LightGBM] [Info] 44.872837 seconds elapsed, finished iteration 175
# [LightGBM] [Info] 45.191236 seconds elapsed, finished iteration 176
# [LightGBM] [Info] 45.408209 seconds elapsed, finished iteration 177
# [LightGBM] [Info] 45.604858 seconds elapsed, finished iteration 178
# [LightGBM] [Info] 45.952328 seconds elapsed, finished iteration 179
# [LightGBM] [Info] 46.144754 seconds elapsed, finished iteration 180
# [LightGBM] [Info] 46.336272 seconds elapsed, finished iteration 181
# [LightGBM] [Info] 46.541186 seconds elapsed, finished iteration 182
# [LightGBM] [Info] 46.727324 seconds elapsed, finished iteration 183
# [LightGBM] [Info] 46.925182 seconds elapsed, finished iteration 184
# [LightGBM] [Info] 47.146745 seconds elapsed, finished iteration 185
# [LightGBM] [Info] 47.355255 seconds elapsed, finished iteration 186
# [LightGBM] [Info] 47.541367 seconds elapsed, finished iteration 187
# [LightGBM] [Info] 47.752156 seconds elapsed, finished iteration 188
# [LightGBM] [Info] 48.055029 seconds elapsed, finished iteration 189
# [LightGBM] [Info] 48.243593 seconds elapsed, finished iteration 190
# [LightGBM] [Info] 48.589847 seconds elapsed, finished iteration 191
# [LightGBM] [Info] 48.772961 seconds elapsed, finished iteration 192
# [LightGBM] [Info] 48.952057 seconds elapsed, finished iteration 193
# [LightGBM] [Info] 49.157815 seconds elapsed, finished iteration 194
# [LightGBM] [Info] 49.398999 seconds elapsed, finished iteration 195
# [LightGBM] [Info] 49.598858 seconds elapsed, finished iteration 196
# [LightGBM] [Info] 49.815605 seconds elapsed, finished iteration 197
# [LightGBM] [Info] 50.024588 seconds elapsed, finished iteration 198
# [LightGBM] [Info] 50.207246 seconds elapsed, finished iteration 199
# [LightGBM] [Info] 50.410982 seconds elapsed, finished iteration 200
# [LightGBM] [Info] 50.613333 seconds elapsed, finished iteration 201
# [LightGBM] [Info] 50.795084 seconds elapsed, finished iteration 202
# [LightGBM] [Info] 50.964410 seconds elapsed, finished iteration 203
# [LightGBM] [Info] 51.363837 seconds elapsed, finished iteration 204
# [LightGBM] [Info] 51.673568 seconds elapsed, finished iteration 205
# [LightGBM] [Info] 51.887191 seconds elapsed, finished iteration 206
# [LightGBM] [Info] 52.071359 seconds elapsed, finished iteration 207
# [LightGBM] [Info] 52.265231 seconds elapsed, finished iteration 208
# [LightGBM] [Info] 52.521290 seconds elapsed, finished iteration 209
# [LightGBM] [Info] 52.772060 seconds elapsed, finished iteration 210
# [LightGBM] [Info] 52.991801 seconds elapsed, finished iteration 211
# [LightGBM] [Info] 53.166871 seconds elapsed, finished iteration 212
# [LightGBM] [Info] 53.374730 seconds elapsed, finished iteration 213
# [LightGBM] [Info] 53.577940 seconds elapsed, finished iteration 214
# [LightGBM] [Info] 53.902743 seconds elapsed, finished iteration 215
# [LightGBM] [Info] 54.117315 seconds elapsed, finished iteration 216
# [LightGBM] [Info] 54.314990 seconds elapsed, finished iteration 217
# [LightGBM] [Info] 54.528213 seconds elapsed, finished iteration 218
# [LightGBM] [Info] 54.815600 seconds elapsed, finished iteration 219
# [LightGBM] [Info] 55.001399 seconds elapsed, finished iteration 220
# [LightGBM] [Info] 55.200776 seconds elapsed, finished iteration 221
# [LightGBM] [Info] 55.380261 seconds elapsed, finished iteration 222
# [LightGBM] [Info] 55.581065 seconds elapsed, finished iteration 223
# [LightGBM] [Info] 55.759502 seconds elapsed, finished iteration 224
# [LightGBM] [Info] 55.969463 seconds elapsed, finished iteration 225
# [LightGBM] [Info] 56.176763 seconds elapsed, finished iteration 226
# [LightGBM] [Info] 56.356236 seconds elapsed, finished iteration 227
# [LightGBM] [Info] 56.524266 seconds elapsed, finished iteration 228
# [LightGBM] [Info] 56.688760 seconds elapsed, finished iteration 229
# [LightGBM] [Info] 56.874750 seconds elapsed, finished iteration 230
# [LightGBM] [Info] 57.044743 seconds elapsed, finished iteration 231
# [LightGBM] [Info] 57.237996 seconds elapsed, finished iteration 232
# [LightGBM] [Info] 57.437936 seconds elapsed, finished iteration 233
# [LightGBM] [Info] 57.638847 seconds elapsed, finished iteration 234
# [LightGBM] [Info] 57.842941 seconds elapsed, finished iteration 235
# [LightGBM] [Info] 58.031203 seconds elapsed, finished iteration 236
# [LightGBM] [Info] 58.223529 seconds elapsed, finished iteration 237
# [LightGBM] [Info] 58.432305 seconds elapsed, finished iteration 238
# [LightGBM] [Info] 58.598740 seconds elapsed, finished iteration 239
# [LightGBM] [Info] 58.772468 seconds elapsed, finished iteration 240
# [LightGBM] [Info] 58.970175 seconds elapsed, finished iteration 241
# [LightGBM] [Info] 59.146781 seconds elapsed, finished iteration 242
# [LightGBM] [Info] 59.365143 seconds elapsed, finished iteration 243
# [LightGBM] [Info] 59.687958 seconds elapsed, finished iteration 244
# [LightGBM] [Info] 59.892164 seconds elapsed, finished iteration 245
# [LightGBM] [Info] 60.191015 seconds elapsed, finished iteration 246
# [LightGBM] [Info] 60.412154 seconds elapsed, finished iteration 247
# [LightGBM] [Info] 60.630920 seconds elapsed, finished iteration 248
# [LightGBM] [Info] 60.801455 seconds elapsed, finished iteration 249
# [LightGBM] [Info] 60.986275 seconds elapsed, finished iteration 250
# [LightGBM] [Info] 61.216230 seconds elapsed, finished iteration 251
# [LightGBM] [Info] 61.411499 seconds elapsed, finished iteration 252
# [LightGBM] [Info] 61.583141 seconds elapsed, finished iteration 253
# [LightGBM] [Info] 61.797838 seconds elapsed, finished iteration 254
# [LightGBM] [Info] 61.986152 seconds elapsed, finished iteration 255
# [LightGBM] [Info] 62.184362 seconds elapsed, finished iteration 256
# [LightGBM] [Info] 62.390801 seconds elapsed, finished iteration 257
# [LightGBM] [Info] 62.537111 seconds elapsed, finished iteration 258
# [LightGBM] [Info] 62.730672 seconds elapsed, finished iteration 259
# [LightGBM] [Info] 62.911868 seconds elapsed, finished iteration 260
# [LightGBM] [Info] 63.223283 seconds elapsed, finished iteration 261
# [LightGBM] [Info] 63.419929 seconds elapsed, finished iteration 262
# [LightGBM] [Info] 63.682408 seconds elapsed, finished iteration 263
# [LightGBM] [Info] 63.964482 seconds elapsed, finished iteration 264
# [LightGBM] [Info] 64.117969 seconds elapsed, finished iteration 265
# [LightGBM] [Info] 64.435882 seconds elapsed, finished iteration 266
# [LightGBM] [Info] 64.635127 seconds elapsed, finished iteration 267
# [LightGBM] [Info] 64.799767 seconds elapsed, finished iteration 268
# [LightGBM] [Info] 64.948481 seconds elapsed, finished iteration 269
# [LightGBM] [Info] 65.157525 seconds elapsed, finished iteration 270
# [LightGBM] [Info] 65.346833 seconds elapsed, finished iteration 271
# [LightGBM] [Info] 65.543012 seconds elapsed, finished iteration 272
# [LightGBM] [Info] 65.735446 seconds elapsed, finished iteration 273
# [LightGBM] [Info] 65.898522 seconds elapsed, finished iteration 274
# [LightGBM] [Info] 66.089206 seconds elapsed, finished iteration 275
# [LightGBM] [Info] 66.268934 seconds elapsed, finished iteration 276
# [LightGBM] [Info] 66.412655 seconds elapsed, finished iteration 277
# [LightGBM] [Info] 66.591361 seconds elapsed, finished iteration 278
# [LightGBM] [Info] 66.783840 seconds elapsed, finished iteration 279
# [LightGBM] [Info] 66.980727 seconds elapsed, finished iteration 280
# [LightGBM] [Info] 67.175174 seconds elapsed, finished iteration 281
# [LightGBM] [Info] 67.332904 seconds elapsed, finished iteration 282
# [LightGBM] [Info] 67.516358 seconds elapsed, finished iteration 283
# [LightGBM] [Info] 67.703343 seconds elapsed, finished iteration 284
# [LightGBM] [Info] 67.893355 seconds elapsed, finished iteration 285
# [LightGBM] [Info] 68.085523 seconds elapsed, finished iteration 286
# [LightGBM] [Info] 68.276443 seconds elapsed, finished iteration 287
# [LightGBM] [Info] 68.454404 seconds elapsed, finished iteration 288
# [LightGBM] [Info] 68.656761 seconds elapsed, finished iteration 289
# [LightGBM] [Info] 68.850344 seconds elapsed, finished iteration 290
# [LightGBM] [Info] 69.030375 seconds elapsed, finished iteration 291
# [LightGBM] [Info] 69.197845 seconds elapsed, finished iteration 292
# [LightGBM] [Info] 69.360468 seconds elapsed, finished iteration 293
# [LightGBM] [Info] 69.538178 seconds elapsed, finished iteration 294
# [LightGBM] [Info] 69.714936 seconds elapsed, finished iteration 295
# [LightGBM] [Info] 69.865518 seconds elapsed, finished iteration 296
# [LightGBM] [Info] 70.054788 seconds elapsed, finished iteration 297
# [LightGBM] [Info] 70.223034 seconds elapsed, finished iteration 298
# [LightGBM] [Info] 70.410839 seconds elapsed, finished iteration 299
# [LightGBM] [Info] 70.571967 seconds elapsed, finished iteration 300
# [LightGBM] [Info] 70.750105 seconds elapsed, finished iteration 301
# [LightGBM] [Info] 71.143118 seconds elapsed, finished iteration 302
# [LightGBM] [Info] 71.429385 seconds elapsed, finished iteration 303
# [LightGBM] [Info] 71.596039 seconds elapsed, finished iteration 304
# [LightGBM] [Info] 71.798839 seconds elapsed, finished iteration 305
# [LightGBM] [Info] 71.985010 seconds elapsed, finished iteration 306
# [LightGBM] [Info] 72.153017 seconds elapsed, finished iteration 307
# [LightGBM] [Info] 72.320509 seconds elapsed, finished iteration 308
# [LightGBM] [Info] 72.704320 seconds elapsed, finished iteration 309
# [LightGBM] [Info] 72.978152 seconds elapsed, finished iteration 310
# [LightGBM] [Info] 73.132217 seconds elapsed, finished iteration 311
# [LightGBM] [Info] 73.335403 seconds elapsed, finished iteration 312
# [LightGBM] [Info] 73.513281 seconds elapsed, finished iteration 313
# [LightGBM] [Info] 73.720333 seconds elapsed, finished iteration 314
# [LightGBM] [Info] 73.891411 seconds elapsed, finished iteration 315
# [LightGBM] [Info] 74.097247 seconds elapsed, finished iteration 316
# [LightGBM] [Info] 74.283080 seconds elapsed, finished iteration 317
# [LightGBM] [Info] 74.466235 seconds elapsed, finished iteration 318
# [LightGBM] [Info] 74.671651 seconds elapsed, finished iteration 319
# [LightGBM] [Info] 74.828795 seconds elapsed, finished iteration 320
# [LightGBM] [Info] 74.976153 seconds elapsed, finished iteration 321
# [LightGBM] [Info] 75.149821 seconds elapsed, finished iteration 322
# [LightGBM] [Info] 75.457576 seconds elapsed, finished iteration 323
# [LightGBM] [Info] 75.647761 seconds elapsed, finished iteration 324
# [LightGBM] [Info] 75.821680 seconds elapsed, finished iteration 325
# [LightGBM] [Info] 76.028258 seconds elapsed, finished iteration 326
# [LightGBM] [Info] 76.230168 seconds elapsed, finished iteration 327
# [LightGBM] [Info] 76.396979 seconds elapsed, finished iteration 328
# [LightGBM] [Info] 76.570816 seconds elapsed, finished iteration 329
# [LightGBM] [Info] 76.730444 seconds elapsed, finished iteration 330
# [LightGBM] [Info] 76.945430 seconds elapsed, finished iteration 331
# [LightGBM] [Info] 77.201540 seconds elapsed, finished iteration 332
# [LightGBM] [Info] 77.385092 seconds elapsed, finished iteration 333
# [LightGBM] [Info] 77.553535 seconds elapsed, finished iteration 334
# [LightGBM] [Info] 77.740672 seconds elapsed, finished iteration 335
# [LightGBM] [Info] 77.905318 seconds elapsed, finished iteration 336
# [LightGBM] [Info] 78.064389 seconds elapsed, finished iteration 337
# [LightGBM] [Info] 78.227743 seconds elapsed, finished iteration 338
# [LightGBM] [Info] 78.466140 seconds elapsed, finished iteration 339
# [LightGBM] [Info] 78.716260 seconds elapsed, finished iteration 340
# [LightGBM] [Info] 78.970271 seconds elapsed, finished iteration 341
# [LightGBM] [Info] 79.112944 seconds elapsed, finished iteration 342
# [LightGBM] [Info] 79.301363 seconds elapsed, finished iteration 343
# [LightGBM] [Info] 79.456386 seconds elapsed, finished iteration 344
# [LightGBM] [Info] 79.614175 seconds elapsed, finished iteration 345
# [LightGBM] [Info] 79.946976 seconds elapsed, finished iteration 346
# [LightGBM] [Info] 80.225575 seconds elapsed, finished iteration 347
# [LightGBM] [Info] 80.402991 seconds elapsed, finished iteration 348
# [LightGBM] [Info] 80.567433 seconds elapsed, finished iteration 349
# [LightGBM] [Info] 80.698713 seconds elapsed, finished iteration 350
# [LightGBM] [Info] 80.979546 seconds elapsed, finished iteration 351
# [LightGBM] [Info] 81.168344 seconds elapsed, finished iteration 352
# [LightGBM] [Info] 81.342103 seconds elapsed, finished iteration 353
# [LightGBM] [Info] 81.541755 seconds elapsed, finished iteration 354
# [LightGBM] [Info] 81.796481 seconds elapsed, finished iteration 355
# [LightGBM] [Info] 81.973739 seconds elapsed, finished iteration 356
# [LightGBM] [Info] 82.151511 seconds elapsed, finished iteration 357
# [LightGBM] [Info] 82.325847 seconds elapsed, finished iteration 358
# [LightGBM] [Info] 82.484543 seconds elapsed, finished iteration 359
# [LightGBM] [Info] 82.619457 seconds elapsed, finished iteration 360
# [LightGBM] [Info] 82.785386 seconds elapsed, finished iteration 361
# [LightGBM] [Info] 82.891540 seconds elapsed, finished iteration 362
# [LightGBM] [Info] 83.019169 seconds elapsed, finished iteration 363
# [LightGBM] [Info] 83.158126 seconds elapsed, finished iteration 364
# [LightGBM] [Info] 83.320164 seconds elapsed, finished iteration 365
# [LightGBM] [Info] 83.496973 seconds elapsed, finished iteration 366
# [LightGBM] [Info] 83.614697 seconds elapsed, finished iteration 367
# [LightGBM] [Info] 83.778794 seconds elapsed, finished iteration 368
# [LightGBM] [Info] 83.894332 seconds elapsed, finished iteration 369
# [LightGBM] [Info] 84.001415 seconds elapsed, finished iteration 370
# [LightGBM] [Info] 84.177094 seconds elapsed, finished iteration 371
# [LightGBM] [Info] 84.335931 seconds elapsed, finished iteration 372
# [LightGBM] [Info] 84.537940 seconds elapsed, finished iteration 373
# [LightGBM] [Info] 84.767449 seconds elapsed, finished iteration 374
# [LightGBM] [Info] 84.930252 seconds elapsed, finished iteration 375
# [LightGBM] [Info] 85.087306 seconds elapsed, finished iteration 376
# [LightGBM] [Info] 85.231904 seconds elapsed, finished iteration 377
# [LightGBM] [Info] 85.391272 seconds elapsed, finished iteration 378
# [LightGBM] [Info] 85.547150 seconds elapsed, finished iteration 379
# [LightGBM] [Info] 85.660874 seconds elapsed, finished iteration 380
# [LightGBM] [Info] 85.829663 seconds elapsed, finished iteration 381
# [LightGBM] [Info] 85.985205 seconds elapsed, finished iteration 382
# [LightGBM] [Info] 86.108860 seconds elapsed, finished iteration 383
# [LightGBM] [Info] 86.219787 seconds elapsed, finished iteration 384
# [LightGBM] [Info] 86.375481 seconds elapsed, finished iteration 385
# [LightGBM] [Info] 86.502554 seconds elapsed, finished iteration 386
# [LightGBM] [Info] 86.597997 seconds elapsed, finished iteration 387
# [LightGBM] [Info] 86.823915 seconds elapsed, finished iteration 388
# [LightGBM] [Info] 87.017498 seconds elapsed, finished iteration 389
# [LightGBM] [Info] 87.126569 seconds elapsed, finished iteration 390
# [LightGBM] [Info] 87.222017 seconds elapsed, finished iteration 391
# [LightGBM] [Info] 87.334573 seconds elapsed, finished iteration 392
# [LightGBM] [Info] 87.456863 seconds elapsed, finished iteration 393
# [LightGBM] [Info] 87.563511 seconds elapsed, finished iteration 394
# [LightGBM] [Info] 87.727476 seconds elapsed, finished iteration 395
# [LightGBM] [Info] 87.854847 seconds elapsed, finished iteration 396
# [LightGBM] [Info] 87.988542 seconds elapsed, finished iteration 397
# [LightGBM] [Info] 88.180599 seconds elapsed, finished iteration 398
# [LightGBM] [Info] 88.394407 seconds elapsed, finished iteration 399
# [LightGBM] [Info] 88.563515 seconds elapsed, finished iteration 400
# [LightGBM] [Info] 88.674075 seconds elapsed, finished iteration 401
# [LightGBM] [Info] 88.870490 seconds elapsed, finished iteration 402
# [LightGBM] [Info] 88.976316 seconds elapsed, finished iteration 403
# [LightGBM] [Info] 89.131267 seconds elapsed, finished iteration 404
# [LightGBM] [Info] 89.276543 seconds elapsed, finished iteration 405
# [LightGBM] [Info] 89.423602 seconds elapsed, finished iteration 406
# [LightGBM] [Info] 89.587992 seconds elapsed, finished iteration 407
# [LightGBM] [Info] 89.710127 seconds elapsed, finished iteration 408
# [LightGBM] [Info] 89.875426 seconds elapsed, finished iteration 409
# [LightGBM] [Info] 89.975221 seconds elapsed, finished iteration 410
# [LightGBM] [Info] 90.082843 seconds elapsed, finished iteration 411
# [LightGBM] [Info] 90.182615 seconds elapsed, finished iteration 412
# [LightGBM] [Info] 90.413459 seconds elapsed, finished iteration 413
# [LightGBM] [Info] 90.628346 seconds elapsed, finished iteration 414
# [LightGBM] [Info] 90.898731 seconds elapsed, finished iteration 415
# [LightGBM] [Info] 91.280059 seconds elapsed, finished iteration 416
# [LightGBM] [Info] 91.517633 seconds elapsed, finished iteration 417
# [LightGBM] [Info] 91.873007 seconds elapsed, finished iteration 418
# [LightGBM] [Info] 92.040595 seconds elapsed, finished iteration 419
# [LightGBM] [Info] 92.192613 seconds elapsed, finished iteration 420
# [LightGBM] [Info] 92.363761 seconds elapsed, finished iteration 421
# [LightGBM] [Info] 92.472876 seconds elapsed, finished iteration 422
# [LightGBM] [Info] 92.651223 seconds elapsed, finished iteration 423
# [LightGBM] [Info] 92.825950 seconds elapsed, finished iteration 424
# [LightGBM] [Info] 92.976119 seconds elapsed, finished iteration 425
# [LightGBM] [Info] 93.263848 seconds elapsed, finished iteration 426
# [LightGBM] [Info] 93.440562 seconds elapsed, finished iteration 427
# [LightGBM] [Info] 93.652859 seconds elapsed, finished iteration 428
# [LightGBM] [Info] 93.948149 seconds elapsed, finished iteration 429
# [LightGBM] [Info] 94.078062 seconds elapsed, finished iteration 430
# [LightGBM] [Info] 94.419888 seconds elapsed, finished iteration 431
# [LightGBM] [Info] 94.554550 seconds elapsed, finished iteration 432
# [LightGBM] [Info] 94.718399 seconds elapsed, finished iteration 433
# [LightGBM] [Info] 94.857594 seconds elapsed, finished iteration 434
# [LightGBM] [Info] 95.020461 seconds elapsed, finished iteration 435
# [LightGBM] [Info] 95.135110 seconds elapsed, finished iteration 436
# [LightGBM] [Info] 95.299636 seconds elapsed, finished iteration 437
# [LightGBM] [Info] 95.437817 seconds elapsed, finished iteration 438
# [LightGBM] [Info] 95.713399 seconds elapsed, finished iteration 439
# [LightGBM] [Info] 95.857980 seconds elapsed, finished iteration 440
# [LightGBM] [Info] 95.943032 seconds elapsed, finished iteration 441
# [LightGBM] [Info] 96.044219 seconds elapsed, finished iteration 442
# [LightGBM] [Info] 96.160511 seconds elapsed, finished iteration 443
# [LightGBM] [Info] 96.276154 seconds elapsed, finished iteration 444
# [LightGBM] [Info] 96.419509 seconds elapsed, finished iteration 445
# [LightGBM] [Info] 96.565088 seconds elapsed, finished iteration 446
# [LightGBM] [Info] 96.671591 seconds elapsed, finished iteration 447
# [LightGBM] [Info] 96.818344 seconds elapsed, finished iteration 448
# [LightGBM] [Info] 96.923538 seconds elapsed, finished iteration 449
# [LightGBM] [Info] 97.083510 seconds elapsed, finished iteration 450
# [LightGBM] [Info] 97.246322 seconds elapsed, finished iteration 451
# [LightGBM] [Info] 97.420311 seconds elapsed, finished iteration 452
# [LightGBM] [Info] 97.556390 seconds elapsed, finished iteration 453
# [LightGBM] [Info] 97.697163 seconds elapsed, finished iteration 454
# [LightGBM] [Info] 97.811389 seconds elapsed, finished iteration 455
# [LightGBM] [Info] 97.896594 seconds elapsed, finished iteration 456
# [LightGBM] [Info] 98.025497 seconds elapsed, finished iteration 457
# [LightGBM] [Info] 98.145724 seconds elapsed, finished iteration 458
# [LightGBM] [Info] 98.321583 seconds elapsed, finished iteration 459
# [LightGBM] [Info] 98.479497 seconds elapsed, finished iteration 460
# [LightGBM] [Info] 98.563878 seconds elapsed, finished iteration 461
# [LightGBM] [Info] 98.668232 seconds elapsed, finished iteration 462
# [LightGBM] [Info] 98.828951 seconds elapsed, finished iteration 463
# [LightGBM] [Info] 98.972911 seconds elapsed, finished iteration 464
# [LightGBM] [Info] 99.081119 seconds elapsed, finished iteration 465
# [LightGBM] [Info] 99.219047 seconds elapsed, finished iteration 466
# [LightGBM] [Info] 99.351156 seconds elapsed, finished iteration 467
# [LightGBM] [Info] 99.455228 seconds elapsed, finished iteration 468
# [LightGBM] [Info] 99.619462 seconds elapsed, finished iteration 469
# [LightGBM] [Info] 99.736981 seconds elapsed, finished iteration 470
# [LightGBM] [Info] 99.876083 seconds elapsed, finished iteration 471
# [LightGBM] [Info] 100.021528 seconds elapsed, finished iteration 472
# [LightGBM] [Info] 100.121572 seconds elapsed, finished iteration 473
# [LightGBM] [Info] 100.242363 seconds elapsed, finished iteration 474
# [LightGBM] [Info] 100.383095 seconds elapsed, finished iteration 475
# [LightGBM] [Info] 100.517414 seconds elapsed, finished iteration 476
# [LightGBM] [Info] 100.599229 seconds elapsed, finished iteration 477
# [LightGBM] [Info] 100.775814 seconds elapsed, finished iteration 478
# [LightGBM] [Info] 101.012068 seconds elapsed, finished iteration 479
# [LightGBM] [Info] 101.260968 seconds elapsed, finished iteration 480
# [LightGBM] [Info] 101.415050 seconds elapsed, finished iteration 481
# [LightGBM] [Info] 101.499229 seconds elapsed, finished iteration 482
# [LightGBM] [Info] 101.614434 seconds elapsed, finished iteration 483
# [LightGBM] [Info] 101.873502 seconds elapsed, finished iteration 484
# [LightGBM] [Info] 101.975172 seconds elapsed, finished iteration 485
# [LightGBM] [Info] 102.286247 seconds elapsed, finished iteration 486
# [LightGBM] [Info] 102.438232 seconds elapsed, finished iteration 487
# [LightGBM] [Info] 102.598423 seconds elapsed, finished iteration 488
# [LightGBM] [Info] 102.797285 seconds elapsed, finished iteration 489
# [LightGBM] [Info] 102.960882 seconds elapsed, finished iteration 490
# [LightGBM] [Info] 103.066023 seconds elapsed, finished iteration 491
# [LightGBM] [Info] 103.366742 seconds elapsed, finished iteration 492
# [LightGBM] [Info] 103.549451 seconds elapsed, finished iteration 493
# [LightGBM] [Info] 103.766076 seconds elapsed, finished iteration 494
# [LightGBM] [Info] 103.870985 seconds elapsed, finished iteration 495
# [LightGBM] [Info] 104.136919 seconds elapsed, finished iteration 496
# [LightGBM] [Info] 104.308056 seconds elapsed, finished iteration 497
# [LightGBM] [Info] 104.442335 seconds elapsed, finished iteration 498
# [LightGBM] [Info] 104.610321 seconds elapsed, finished iteration 499
# [LightGBM] [Info] 104.767316 seconds elapsed, finished iteration 500
# [LightGBM] [Info] Finished training

# %% [markdown]
# ## Сохраняем модель

# %%
import cPickle
#clf
#pipeline
#le
#df_train.iloc[0]

hand_pipe = [
    ('features', feats),
    ('categorical_features',[u'mob_provider',u'federal_district']),
    ('labelencoder', labelencoder),
    ('target_encoded',avg_target),
    ('classifier',clf) 
]

cPickle.dump(hand_pipe,open('data/cred_scor_classifier_pipe3.pck','w'))

# %% [markdown]
# ### Контроль

# %%
control_query = '''
create table user_kposminin.phone_x_feature_control_201705 as
    select 
         a.phone_mobile, 
         count(distinct m.id) as id_cnt,
         count(distinct acc.id) as acc_id_cnt,
         a.ymd as call_ymd,
         max(a.considered) as considered,
         max(a.utm_campaign) as utm_campaign, 
         max(a.approve) as approve,
         sum(acc.urlfr_cnt) as urlfr_cnt,
         sum(acc.visits_cnt) as visits_cnt, 
         sum(acc.hits) as hits,
         max(acc.max_score1) as max_score1,
         sum(acc.sum_score1) / sum(acc.cnt_score1) as avg_score1,
         min(acc.min_score1) as min_score1,
         max(acc.max_score2) as max_score2,
         sum(acc.sum_score2) / sum(acc.cnt_score2) as avg_score2,
         min(acc.min_score2) as min_score2,
         max(acc.max_score3) as max_score3,
         sum(acc.sum_score3) / sum(acc.cnt_score3) as avg_score3,
         min(acc.min_score3) as min_score3,
         max(acc.max_score4) as max_score4,
         sum(acc.sum_score4) / sum(acc.cnt_score4) as avg_score4,
         min(acc.min_score4) as min_score4,
         max(acc.max_score5) as max_score5,
         sum(acc.sum_score5) / sum(acc.cnt_score4) as avg_score5,
         min(acc.min_score5) as min_score5,
         max(acc.max_score6) as max_score6,
         sum(acc.sum_score6) / sum(acc.cnt_score4) as avg_score6,
         min(acc.min_score6) as min_score6,
         sum(acc.emailru_sum) / sum(acc.visits_cnt) as emailru_share,
         sum(acc.mobile_sum) / sum(acc.visits_cnt) as mobile_share,
         sum(acc.vk_sum) / sum(acc.visits_cnt) as vk_share,
         sum(acc.social_sum) / sum(acc.visits_cnt) as social_share,
         sum(acc.work_hours_hits_sum) / sum(acc.hits) as work_hours_hits_share,
         sqrt(sum(acc.avg_hour_sum_sq)/(sum(acc.visits_cnt)-1) - power(sum(acc.avg_hour_sum)/(sum(acc.visits_cnt) - 1), 2)) as hour_std,
         sum(acc.good_urlfr_sum_score1) / sum(acc.cnt_score1) as good_urlfr_share_score1, 
         sum(acc.good_urlfr_sum_score2) / sum(acc.cnt_score2) as good_urlfr_share_score2,
         sum(acc.good_urlfr_sum_score3) / sum(acc.cnt_score3) as good_urlfr_share_score3, 
         sum(acc.good_urlfr_sum_score4) / sum(acc.cnt_score4) as good_urlfr_share_score4, 
         sum(acc.good_urlfr_sum_score5) / sum(acc.cnt_score5) as good_urlfr_share_score5,
         sum(acc.good_urlfr_sum_score6) / sum(acc.cnt_score6) as good_urlfr_share_score6,
         max(trim(pc.provider)) as mob_provider,
         max(r.ind) as ind,
         max(r.pop_country_share) as pop_country_share, 
         max(r.pop_city_share) as pop_city_share, 
         max(r.population / r.area_sq_km) as density,
         max(r.area_sq_km) as area_sq_km,
         max(trim(r.federal_district)) as federal_district, 
         max(r.avg_salary_2015_rub) as avg_salary_2015_rub, 
         max(r.utc_time_zone_val) as utc_time_zone_val
      from
         user_kposminin.full_app_201705 a
         inner join (
                   select
                     uid_str as id,
                     property_value as phone_num,
                     load_src
                   from
                     prod_dds.md_uid_property
                   where
                     property_cd = 'PHONE'
                  ) m on substr(m.phone_num,3,20) =  substr(a.phone_mobile,2,20)
         inner join user_kposminin.id_feat_accum acc on acc.id = m.id
         left join dds_dic.phone_codes pc on trim(pc.phone_code) = substr(a.phone_mobile,2,9)
         left join dds_dic.region_stat r on r.ind = pc.region_id
      where
        acc.first_calc_ymd = '2017-03-01' 
        and acc.last_calc_ymd = '2017-04-30'
        and a.considered = 1
     group by
             a.phone_mobile,
             a.ymd
    ;
'''

# %%
hand_pipe1 = cPickle.load(open('data/cred_scor_classifier_pipe3.pck','r'))
feats                = hand_pipe1[0][1]
categorical_features = hand_pipe1[1][1]
labelencoder         = hand_pipe1[2][1]
target_encoded       = hand_pipe1[3][1]
clf                  = hand_pipe1[4][1]

# %%
df_control = (hc.sql('select * from user_kposminin.phone_x_feature_control_201705')        
        .toPandas()
         )

for v in categorical_features:
    df_control.loc[:,v]  = df_control.loc[:,v].map(lambda f: labelencoder[v].get(f,-1))
    df_control.loc[:,v + '_encoded'] = df_control[v].map(target_encoded[v])
    
df_control['pred'] = clf.predict_proba(df_control[feats])[:,1]
# Out:
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading 500 models
# [LightGBM] [Info] Finished initializing prediction
# [LightGBM] [Info] Finished prediction

# %%
print(metrics(y_true = df_control[label], y_score = df_control.pred, lift = [0.1,0.2,0.3,0.5,0.7], return_str = True))
# Out:
# Sample size : 24292.00000
# Posit share : 0.46106
# AUC ROC     : 0.64260
# AUC PR      : 0.57768
# Log loss    : 0.68364
# Lift 0.1    : 1.38226
# Lift 0.2    : 1.34252
# Lift 0.3    : 1.29683
# Lift 0.5    : 1.21518
# Lift 0.7    : 1.14862.

# %% [markdown]
# ### Немного маловато. С чем это связано: устаревание модели, неконсистентность данных, выброс за счет малой выборки либо заявки немного разные (обучение + первый тест из выборки Азамата, которая неизвестно как сформирована. another_test сформирован из всех заявок по звонкам)?
# ### Гипотезу малой выборки проверим построением доверительного интервала для AUC ROC бутстреппингом:

# %%
roc_auc_bootstrap = []
for _ in range(500):
    sample_idx = np.random.choice(df_control.index, df_control.shape[0], replace = True)
    roc_auc_bootstrap.append(sklearn.metrics.roc_auc_score(y_true = df_control.ix[sample_idx,label], y_score = df_control.ix[sample_idx,'pred']))
print('ROC AUC percentiles {}'.format(np.percentile(roc_auc_bootstrap,q=[5,10,30,50,70,90,95])))
# Out:
# ROC AUC percentiles [ 0.63693284  0.63804903  0.64076687  0.64265378  0.64447876  0.6467406
#   0.64773351]

# %% [markdown]
# ### Наблюдаемый AUC ROC не влезает даже в 95% доверительный интервал. Итак, низкий AUC ROC не связан с малой выборкой.
# #### Возможно, причина в разнородности заявок в обучении и в последнем тесте .

# %%
#df_control.groupby('utm_campaign')[label].count().sort(inplace = False, ascending = False)
#dfc1 = df_control[df_control['utm_campaign'].map(lambda v: "cold_" in v if v else False)]
#print(metrics(y_true = dfc1[label], y_score = dfc1.pred, lift = None, return_str = True))
dfc3 = df_control.query('utm_campaign == "cold_liru_test"')
print(metrics(y_true = dfc3[label], y_score = dfc3.pred, lift = [0.1,0.2,0.25,0.3,0.5,0.7], return_str = True))
# Out:
# Sample size : 356.00000
# Posit share : 0.23315
# AUC ROC     : 0.68697
# AUC PR      : 0.37575
# Log loss    : 0.50993
# Lift 0.1    : 1.83821
# Lift 0.2    : 1.75191
# Lift 0.25   : 1.54217
# Lift 0.3    : 1.57809
# Lift 0.5    : 1.42169
# Lift 0.7    : 1.25746.

# %%
tot_label,tot_size = dfc3[label].sum(),dfc3[label].size
print('thres\tAvg_approve\tShare')
for thres in [0.1,0.2,0.25,0.3,0.35,0.4]:
    dft = dfc3[dfc3.pred > thres][label]
    print('{}\t{}\t{}'.format(thres,dft.mean(),dft.size*1./tot_size))
# Out:
# thres	Avg_approve	Share
# 0.1	0.25641025641	0.876404494382
# 0.2	0.301652892562	0.679775280899
# 0.25	0.338383838384	0.556179775281
# 0.3	0.355704697987	0.418539325843
# 0.35	0.343434343434	0.27808988764
# 0.4	0.415384615385	0.182584269663

# %% [markdown]
# ### Выбираем порог отсечения в 0.35

# %%
dfc3['pred'].median()
# Out:
# 0.2756995
