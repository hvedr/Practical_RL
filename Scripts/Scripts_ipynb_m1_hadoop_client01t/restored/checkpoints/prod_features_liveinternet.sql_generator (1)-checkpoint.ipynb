# %%
def setParams():
    print('''set hive.vectorized.execution.enabled=true;
set mapreduce.map.memory.mb=4096;
set mapreduce.map.child.java.opts=-Xmx4g;
set mapreduce.task.io.sort.mb=1024;
set mapreduce.reduce.child.java.opts=-Xmx4g;
set mapreduce.reduce.memory.mb=7000;
set mapreduce.reduce.shuffle.input.buffer.percent=0.5;
set mapreduce.input.fileinputformat.split.minsize=536870912;
set mapreduce.input.fileinputformat.split.maxsize=1073741824;
set hive.optimize.ppd=true;
set hive.merge.smallfiles.avgsize=536870912;
set hive.merge.mapredfiles=true;
set hive.merge.mapfiles=true;
set hive.hadoop.supports.splittable.combineinputformat=true;
set hive.exec.reducers.bytes.per.reducer=536870912;
set hive.exec.parallel=true;
set hive.exec.max.created.files=10000000;
set hive.exec.compress.output=true;
set hive.exec.dynamic.partition.mode=nonstrict;
set hive.exec.max.dynamic.partitions=1000000;
set hive.exec.max.dynamic.partitions.pernode=100000;
set io.seqfile.compression.type=BLOCK;
''')



sql_urlf_tgt_cnt_full_sample = '''WITH t AS (
  SELECT v.urlfr AS urlfr, COUNT(*) AS cnt_positive
  FROM prod_features_liveinternet.visits v
  WHERE v.ymd='{d}' AND v.id in
    (SELECT a.id FROM prod_features_liveinternet.tinkoff_actions a WHERE
     a.ymd='{next_d}' and a.action_type = '{action_type}')
  GROUP BY v.urlfr
)
INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt
PARTITION (ymd='{d}', target='{target}')
SELECT s.urlfr AS urlfr, nvl(t.cnt_positive, 0) as cnt_positive, s.visitors as cnt_total
FROM prod_features_liveinternet.urlfr_stat s
LEFT OUTER JOIN t ON t.urlfr = s.urlfr
WHERE s.ymd='{d}';
'''

sql_urlf_tgt_cnt_full_sample_weekly = '''WITH t AS (
  SELECT v.urlfr AS urlfr, COUNT(*) AS cnt_positive
  FROM prod_features_liveinternet.visits v
  WHERE (v.ymd between '{d_week_ago}' and '{d}') AND v.id in
    (SELECT a.id FROM prod_features_liveinternet.tinkoff_actions a WHERE
     a.ymd='{next_d}' and a.action_type = '{action_type}')
  GROUP BY v.urlfr
)
INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt
PARTITION (ymd='{d}', target='{target}_weekly')
SELECT s.urlfr AS urlfr, nvl(t.cnt_positive, 0) as cnt_positive, s.visitors as cnt_total
FROM prod_features_liveinternet.urlfr_stat s
LEFT OUTER JOIN t ON t.urlfr = s.urlfr
WHERE s.ymd='{d}';
'''

sql_urlf_tgt_cnt_ccall = '''WITH t AS (
  SELECT v.urlfr AS urlfr, COUNT(distinct if(m.approve = 1,m.id,Null)) AS cnt_positive,count(distinct m.id) as cnt_total
  FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where ymd = '{d}') v
  inner join user_kposminin.cold_calls_matched_1 m on m.id = v.id and m.ymd = '{next_d}'
  GROUP BY v.urlfr
)
INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt
PARTITION (ymd='{d}', target='{target}')
SELECT t.urlfr AS urlfr, nvl(t.cnt_positive, 0) as cnt_positive, t.cnt_total as cnt_total
FROM t;
'''


sql_urlf_tgt_cnt_ccalls_monthly_stat = '''WITH t AS (
  SELECT 
      v.urlfr AS urlfr,
      COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
      COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
      count(distinct m.phone_num) as cnt_ccall
  FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '{d_month_ago}' and '{d}')) v
  inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id and m.ymd = '{next_d}' and m.havent_started = 0
  GROUP BY v.urlfr
)
INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
PARTITION (ymd='{d}', target='ccall_monthly_phone')
SELECT t.urlfr AS urlfr, nvl(t.cnt_approve, 0) as cnt_approve, nvl(t.cnt_full_app, 0) as cnt_full_app, t.cnt_ccall as cnt_ccall
FROM t where cnt_ccall > 5;
'''

sql_urlf_tgt_cnt_ccalls_monthly_stat2 = '''WITH t AS (
  SELECT 
      m.ymd,
      v.urlfr AS urlfr,
      COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
      COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
      count(distinct m.phone_num) as cnt_ccall
  FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '{d_two_months_ago}' and '{d}')) v
  inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id 
  where 
    m.ymd between '{d_month_ago}' and '{d}'
    and m.havent_started = 0
    and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
  GROUP BY m.ymd, v.urlfr
)
INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
PARTITION (ymd, target)
SELECT 
  t.urlfr AS urlfr
, nvl(t.cnt_approve, 0) as cnt_approve
, nvl(t.cnt_full_app, 0) as cnt_full_app
, t.cnt_ccall as cnt_ccall
, t.ymd
, 'ccall_monthly_phone' as target
FROM t where cnt_ccall > 5;
'''

# %%
setParams()
import datetime
action_type = 'tinkoff_platinum_cold_call_approved'
target = 'my_ccalls' #action_type + '@tinkoff_action@my'
first_date = '2016-02-01'
next_day = datetime.datetime.strptime(first_date, "%Y-%m-%d")
d = next_day
while d.month == next_day.month:
    d = next_day
    next_day += datetime.timedelta(days=1)
    print(sql_urlf_tgt_cnt_ccalls_monthly_stat2.format(
            d = d.strftime("%Y-%m-%d"), 
            next_d = next_day.strftime("%Y-%m-%d"), 
            d_month_ago = (d - datetime.timedelta(days = 30)).strftime("%Y-%m-%d"), 
            d_two_months_ago = (d - datetime.timedelta(days = 61)).strftime("%Y-%m-%d"), 
            target = target, 
            action_type = action_type
    ))
# Out:
# set hive.vectorized.execution.enabled=true;
# set mapreduce.map.memory.mb=4096;
# set mapreduce.map.child.java.opts=-Xmx4g;
# set mapreduce.task.io.sort.mb=1024;
# set mapreduce.reduce.child.java.opts=-Xmx4g;
# set mapreduce.reduce.memory.mb=7000;
# set mapreduce.reduce.shuffle.input.buffer.percent=0.5;
# set mapreduce.input.fileinputformat.split.minsize=536870912;
# set mapreduce.input.fileinputformat.split.maxsize=1073741824;
# set hive.optimize.ppd=true;
# set hive.merge.smallfiles.avgsize=536870912;
# set hive.merge.mapredfiles=true;
# set hive.merge.mapfiles=true;
# set hive.hadoop.supports.splittable.combineinputformat=true;
# set hive.exec.reducers.bytes.per.reducer=536870912;
# set hive.exec.parallel=true;
# set hive.exec.max.created.files=10000000;
# set hive.exec.compress.output=true;
# set hive.exec.dynamic.partition.mode=nonstrict;
# set hive.exec.max.dynamic.partitions=1000000;
# set hive.exec.max.dynamic.partitions.pernode=100000;
# set io.seqfile.compression.type=BLOCK;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-02' and '2016-02-01')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-02' and '2016-02-01'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-03' and '2016-02-02')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-03' and '2016-02-02'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-04' and '2016-02-03')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-04' and '2016-02-03'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-05' and '2016-02-04')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-05' and '2016-02-04'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-06' and '2016-02-05')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-06' and '2016-02-05'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-07' and '2016-02-06')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-07' and '2016-02-06'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-08' and '2016-02-07')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-08' and '2016-02-07'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-09' and '2016-02-08')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-09' and '2016-02-08'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-10' and '2016-02-09')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-10' and '2016-02-09'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-11' and '2016-02-10')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-11' and '2016-02-10'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-12' and '2016-02-11')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-12' and '2016-02-11'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-13' and '2016-02-12')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-13' and '2016-02-12'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-14' and '2016-02-13')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-14' and '2016-02-13'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-15' and '2016-02-14')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-15' and '2016-02-14'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-16' and '2016-02-15')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-16' and '2016-02-15'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-17' and '2016-02-16')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-17' and '2016-02-16'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-18' and '2016-02-17')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-18' and '2016-02-17'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-19' and '2016-02-18')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-19' and '2016-02-18'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-20' and '2016-02-19')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-20' and '2016-02-19'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-21' and '2016-02-20')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-21' and '2016-02-20'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-22' and '2016-02-21')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-22' and '2016-02-21'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-23' and '2016-02-22')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-23' and '2016-02-22'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-24' and '2016-02-23')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-24' and '2016-02-23'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-25' and '2016-02-24')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-25' and '2016-02-24'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-26' and '2016-02-25')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-26' and '2016-02-25'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-27' and '2016-02-26')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-27' and '2016-02-26'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-28' and '2016-02-27')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-28' and '2016-02-27'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-29' and '2016-02-28')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-29' and '2016-02-28'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-30' and '2016-02-29')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-30' and '2016-02-29'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;

# %%
setParams()
import datetime
action_type = 'tinkoff_platinum_cold_call_approved'
target = 'my_ccalls' #action_type + '@tinkoff_action@my'
first_date = '2016-02-01'
d = datetime.datetime.strptime(first_date, "%Y-%m-%d")
d = next_day
for rd in ['2016-02-28','2016-06-30','2016-07-31']:
    d = datetime.datetime.strptime(rd, "%Y-%m-%d")
    print(sql_urlf_tgt_cnt_ccalls_monthly_stat2.format(
            d = d.strftime("%Y-%m-%d"), 
            next_d = next_day.strftime("%Y-%m-%d"), 
            d_month_ago = (d - datetime.timedelta(days = 30)).strftime("%Y-%m-%d"), 
            d_two_months_ago = (d - datetime.timedelta(days = 61)).strftime("%Y-%m-%d"), 
            target = target, 
            action_type = action_type
    ))
# Out:
# set hive.vectorized.execution.enabled=true;
# set mapreduce.map.memory.mb=4096;
# set mapreduce.map.child.java.opts=-Xmx4g;
# set mapreduce.task.io.sort.mb=1024;
# set mapreduce.reduce.child.java.opts=-Xmx4g;
# set mapreduce.reduce.memory.mb=7000;
# set mapreduce.reduce.shuffle.input.buffer.percent=0.5;
# set mapreduce.input.fileinputformat.split.minsize=536870912;
# set mapreduce.input.fileinputformat.split.maxsize=1073741824;
# set hive.optimize.ppd=true;
# set hive.merge.smallfiles.avgsize=536870912;
# set hive.merge.mapredfiles=true;
# set hive.merge.mapfiles=true;
# set hive.hadoop.supports.splittable.combineinputformat=true;
# set hive.exec.reducers.bytes.per.reducer=536870912;
# set hive.exec.parallel=true;
# set hive.exec.max.created.files=10000000;
# set hive.exec.compress.output=true;
# set hive.exec.dynamic.partition.mode=nonstrict;
# set hive.exec.max.dynamic.partitions=1000000;
# set hive.exec.max.dynamic.partitions.pernode=100000;
# set io.seqfile.compression.type=BLOCK;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2015-12-29' and '2016-02-28')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-01-29' and '2016-02-28'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2016-04-30' and '2016-06-30')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-05-31' and '2016-06-30'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;
#
# WITH t AS (
#   SELECT
#       m.ymd,
#       v.urlfr AS urlfr,
#       COUNT(distinct if(m.approve = 1,m.phone_num,Null)) AS cnt_approve,
#       COUNT(distinct if(m.full_app = 1,m.phone_num,Null)) AS cnt_full_app,
#       count(distinct m.phone_num) as cnt_ccall
#   FROM (select ymd,urlfr,id from prod_features_liveinternet.visits where (ymd between '2016-05-31' and '2016-07-31')) v
#   inner join user_kposminin.cold_calls_matched_5 m on m.id = v.id
#   where
#     m.ymd between '2016-07-01' and '2016-07-31'
#     and m.havent_started = 0
#     and v.ymd between date_add(m.ymd,-31) and date_add(m.ymd,-1)
#   GROUP BY m.ymd, v.urlfr
# )
# INSERT OVERWRITE TABLE user_kposminin.urlfr_tgt_cnt_ccall
# PARTITION (ymd, target)
# SELECT
#   t.urlfr AS urlfr
# , nvl(t.cnt_approve, 0) as cnt_approve
# , nvl(t.cnt_full_app, 0) as cnt_full_app
# , t.cnt_ccall as cnt_ccall
# , t.ymd
# , 'ccall_monthly_phone' as target
# FROM t where cnt_ccall > 5;

# %%
setParams()
action_type = 'tinkoff_platinum_cold_call_approved'
target = action_type + '@tinkoff_action'
first_date = '2016-04-01'
next_day = datetime.datetime.strptime(first_date, "%Y-%m-%d")
d = next_day
while d.month == next_day.month:
    d = next_day
    next_day += datetime.timedelta(days=1)
    print(sql_urlf_tgt_cnt_full_sample_weekly.format(
            d = d.strftime("%Y-%m-%d"), 
            next_d = next_day.strftime("%Y-%m-%d"), 
            d_week_ago = (d + datetime.timedelta(days=-7)).strftime("%Y-%m-%d"), 
            target = target, 
            action_type = action_type
    ).replace('\n', ' '))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b5eef52e5a0d> in <module>()
# ----> 1 setParams()
#       2 action_type = 'tinkoff_platinum_cold_call_approved'
#       3 target = action_type + '@tinkoff_action'
#       4 first_date = '2016-04-01'
#       5 next_day = datetime.datetime.strptime(first_date, "%Y-%m-%d")
#
# NameError: name 'setParams' is not defined

# %%
up = ['bankcreditcard.ru%','bankiros.ru%','sravni.ru/kredity%', 'sravni.ru/zaimy%', 'sravni.ru/kreditnyj-skoring%','allcredits.ru%',
 'moneymatika.ru/bank/kreditnie-karty%', 'moneymatika.ru/bank/potrebitelskie-kredity%' , 'moneymatika.ru/bank/mikrokredity%',
 'kompaskreditov.ru%','infapronet.ru%','cashalot.su%','filkos.com%','zaymiprosto.ru%','vkarmane-online.ru%','burocreditov.ru%',
 'mos-zaim.ru%','anketa.rsb.ru%','raiffeisen.ru/retail/cards/credit%','crediteurope.ru/privately/kreditnye_karty_card_credit%',
 'crediteurope.ru/privately/credit_cards%','trust.ru/retail/cash%']

print('\n'.join('urlfr like "{0}" or'.format(e) for e in up))
# Out:
# urlfr like "bankcreditcard.ru%" or
# urlfr like "bankiros.ru%" or
# urlfr like "sravni.ru/kredity%" or
# urlfr like "sravni.ru/zaimy%" or
# urlfr like "sravni.ru/kreditnyj-skoring%" or
# urlfr like "allcredits.ru%" or
# urlfr like "moneymatika.ru/bank/kreditnie-karty%" or
# urlfr like "moneymatika.ru/bank/potrebitelskie-kredity%" or
# urlfr like "moneymatika.ru/bank/mikrokredity%" or
# urlfr like "kompaskreditov.ru%" or
# urlfr like "infapronet.ru%" or
# urlfr like "cashalot.su%" or
# urlfr like "filkos.com%" or
# urlfr like "zaymiprosto.ru%" or
# urlfr like "vkarmane-online.ru%" or
# urlfr like "burocreditov.ru%" or
# urlfr like "mos-zaim.ru%" or
# urlfr like "anketa.rsb.ru%" or
# urlfr like "raiffeisen.ru/retail/cards/credit%" or
# urlfr like "crediteurope.ru/privately/kreditnye_karty_card_credit%" or
# urlfr like "crediteurope.ru/privately/credit_cards%" or
# urlfr like "trust.ru/retail/cash%" or

# %%
create_visits_table_query = '''
create table if not exists user_kposminin.ccalls_visits_1(
phone_num String,
id String,
label int,
full_app int,
visit_lag int,
urlfr String,
avg_hour int,
duration int,
cnt int
)
partitioned by (ymd String) 
; 
'''

ccall_visits_query = '''
insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd)
select 
  m.phone_num
, m.id
, m.approve as label
, m.full_app
, datediff(m.ymd, v.ymd) as visit_lag
, v.urlfr
, v.avg_hour
, v.duration
, v.cnt
, m.ymd as ymd
from
  (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('#d',-20) and date_add('#d',-1)) v
inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '#d') m on m.id = v.id
;
'''
import datetime
setParams()
print(create_visits_table_query)
first_date = '2016-03-01'
next_day = datetime.datetime.strptime(first_date, "%Y-%m-%d")
d = next_day
while d.month == next_day.month:
    d = next_day
    next_day += datetime.timedelta(days=1)
    print(ccall_visits_query.replace('#d', d.strftime("%Y-%m-%d")).replace('\n', ' '))
# Out:
# set hive.vectorized.execution.enabled=true;
# set mapreduce.map.memory.mb=4096;
# set mapreduce.map.child.java.opts=-Xmx4g;
# set mapreduce.task.io.sort.mb=1024;
# set mapreduce.reduce.child.java.opts=-Xmx4g;
# set mapreduce.reduce.memory.mb=7000;
# set mapreduce.reduce.shuffle.input.buffer.percent=0.5;
# set mapreduce.input.fileinputformat.split.minsize=536870912;
# set mapreduce.input.fileinputformat.split.maxsize=1073741824;
# set hive.optimize.ppd=true;
# set hive.merge.smallfiles.avgsize=536870912;
# set hive.merge.mapredfiles=true;
# set hive.merge.mapfiles=true;
# set hive.hadoop.supports.splittable.combineinputformat=true;
# set hive.exec.reducers.bytes.per.reducer=536870912;
# set hive.exec.parallel=true;
# set hive.exec.max.created.files=10000000;
# set hive.exec.compress.output=true;
# set hive.exec.dynamic.partition.mode=nonstrict;
# set hive.exec.max.dynamic.partitions=1000000;
# set hive.exec.max.dynamic.partitions.pernode=100000;
# set io.seqfile.compression.type=BLOCK;
#
#
# create table if not exists user_kposminin.ccalls_visits_1(
# phone_num String,
# id String,
# label int,
# full_app int,
# visit_lag int,
# urlfr String,
# avg_hour int,
# duration int,
# cnt int
# )
# partitioned by (ymd String)
# ;
#
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-01',-20) and date_add('2016-03-01',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-01') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-02',-20) and date_add('2016-03-02',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-02') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-03',-20) and date_add('2016-03-03',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-03') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-04',-20) and date_add('2016-03-04',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-04') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-05',-20) and date_add('2016-03-05',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-05') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-06',-20) and date_add('2016-03-06',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-06') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-07',-20) and date_add('2016-03-07',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-07') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-08',-20) and date_add('2016-03-08',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-08') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-09',-20) and date_add('2016-03-09',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-09') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-10',-20) and date_add('2016-03-10',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-10') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-11',-20) and date_add('2016-03-11',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-11') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-12',-20) and date_add('2016-03-12',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-12') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-13',-20) and date_add('2016-03-13',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-13') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-14',-20) and date_add('2016-03-14',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-14') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-15',-20) and date_add('2016-03-15',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-15') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-16',-20) and date_add('2016-03-16',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-16') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-17',-20) and date_add('2016-03-17',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-17') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-18',-20) and date_add('2016-03-18',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-18') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-19',-20) and date_add('2016-03-19',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-19') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-20',-20) and date_add('2016-03-20',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-20') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-21',-20) and date_add('2016-03-21',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-21') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-22',-20) and date_add('2016-03-22',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-22') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-23',-20) and date_add('2016-03-23',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-23') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-24',-20) and date_add('2016-03-24',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-24') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-25',-20) and date_add('2016-03-25',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-25') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-26',-20) and date_add('2016-03-26',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-26') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-27',-20) and date_add('2016-03-27',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-27') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-28',-20) and date_add('2016-03-28',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-28') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-29',-20) and date_add('2016-03-29',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-29') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-30',-20) and date_add('2016-03-30',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-30') m on m.id = v.id ;
#  insert overwrite table user_kposminin.ccalls_visits_1 partition(ymd) select    m.phone_num , m.id , m.approve as label , m.full_app , datediff(m.ymd, v.ymd) as visit_lag , v.urlfr , v.avg_hour , v.duration , v.cnt , m.ymd as ymd from   (select id, urlfr,cnt, duration, avg_hour, ymd from prod_features_liveinternet.visits where ymd between date_add('2016-03-31',-20) and date_add('2016-03-31',-1)) v inner join (select phone_num, id, approve, full_app, ymd from user_kposminin.cold_calls_matched_5 where ymd = '2016-03-31') m on m.id = v.id ;
