# %% [markdown]
# ## Кредитный скоринг заявок на основе веб-лога
# #### На основании дефолта. Ещё один подход
# 2017-04-04

# %%
#Config
from pyspark import SparkConf, SparkContext, HiveContext
import re
import numpy as np
import pandas as pd
import datetime
from pyspark.mllib.regression import LabeledPoint
from pyspark.mllib.feature import HashingTF
from pyspark.mllib.classification import LogisticRegressionWithSGD, NaiveBayes, NaiveBayesModel
import scipy.sparse as sps
from pyspark.mllib.linalg import Vectors
from pyspark.mllib.linalg import SparseVector
from pyspark.mllib.evaluation import BinaryClassificationMetrics

hive_config_query = '''
set hive.vectorized.execution.enabled=true;
set hive.vectorized.execution.reduce.enabled = true;
set mapreduce.map.memory.mb=4096;
set mapreduce.map.child.java.opts=-Xmx4g;
set mapreduce.task.io.sort.mb=1024;
set mapreduce.reduce.child.java.opts=-Xmx4g;
set mapreduce.reduce.memory.mb=7000;
set mapreduce.reduce.shuffle.input.buffer.percent=0.5;
set mapreduce.input.fileinputformat.split.minsize=536870912;
set mapreduce.input.fileinputformat.split.maxsize=1073741824;
set hive.optimize.ppd=true;
set hive.merge.smallfiles.avgsize=536870912;
set hive.merge.mapredfiles=true;
set hive.merge.mapfiles=true;
set hive.hadoop.supports.splittable.combineinputformat=true;
set hive.exec.reducers.bytes.per.reducer=536870912;
set hive.exec.parallel=true;
set hive.exec.max.created.files=10000000;
set hive.exec.compress.output=true;
set hive.exec.dynamic.partition.mode=nonstrict;
set hive.exec.max.dynamic.partitions=1000000;
set hive.exec.max.dynamic.partitions.pernode=100000;
set io.seqfile.compression.type=BLOCK;
set mapreduce.map.failures.maxpercent=5;
'''

sc.stop()
conf = SparkConf().set("spark.executor.instances", 4).set("spark.driver.maxResultSize", "14g").set('spark.driver.memory','16g')
sc = SparkContext(conf=conf)
hc = HiveContext(sc)

# %%
start_date = datetime.date(2016,12,31)

for d in dates_to_calc_2016:
    #date = str(start_date - datetime.timedelta(days = i))
    #if (not date in calced_dates):
    print(feature_visits_pattern.replace('#visit_ymd', d))

# %% [markdown]
# ## Генерация факторов
# ##### Я.Каталог

# %%
#a = train_data1.take(100)
#l = a[0][1]
#[e[0] for e in l]
#zip([list(l)[[e[0] for e in l].index(i)][1] if i in [e[0] for e in l] else 0 for i in range(420)],range(500))
a= (hc.sql(select_query)
                .filter("call_ymd < '2016-06-15'")
                .rdd
                .map(lambda r: ((r.phone_mobile,r.call_ymd,r.default_flg),r[3:]))
                .groupByKey()
                .take(10)
   )

# %%
train_data = (hc.sql(select_query)
                .filter("call_ymd < '2016-06-15'")
                .rdd
                .map(lambda r: ((r.phone_mobile,r.call_ymd,r.default_flg),r[3:]))
                .groupByKey()
                .map(lambda (k,l):(k,[list(l)[[e[0] for e in l].index(i)][1] if i in [e[0] for e in l] else 0 for i in range(420)] + 
                                     [list(l)[[e[0] for e in l].index(i)][2] if i in [e[0] for e in l] else 0 for i in range(420)] +
                                     [list(l)[[e[0] for e in l].index(i)][3] if i in [e[0] for e in l] else 0 for i in range(420)] + 
                                     [list(l)[[e[0] for e in l].index(i)][4] if i in [e[0] for e in l] else 0 for i in range(420)] + 
                                     list(list(l)[0][5:])))
                .collect() 
             )

# %%
test_data = (hc.sql(select_query)
                .filter("call_ymd >= '2016-06-15'")
                .rdd
                .map(lambda r: ((r.phone_mobile,r.call_ymd,r.default_flg),r[3:]))
                .groupByKey()
                .map(lambda (k,l):(k,[list(l)[[e[0] for e in l].index(i)][1] if i in [e[0] for e in l] else 0 for i in range(420)] + 
                                     [list(l)[[e[0] for e in l].index(i)][2] if i in [e[0] for e in l] else 0 for i in range(420)] +
                                     [list(l)[[e[0] for e in l].index(i)][3] if i in [e[0] for e in l] else 0 for i in range(420)] + 
                                     [list(l)[[e[0] for e in l].index(i)][4] if i in [e[0] for e in l] else 0 for i in range(420)] + 
                                     list(list(l)[0][5:])))
                .collect() 
             )

# %%
import xgboost as xgb
dtrain = xgb.DMatrix( [e[1] for e in train_data], label = [e[0][2] for e in train_data])
dtest  = xgb.DMatrix( [e[1] for e in test_data],  label = [e[0][2] for e in test_data] )

# %%
#train_data[12] '+79678813486', u'2016-01-25'
#dtest.get_label().mean()

# %%
import numpy as np
from sklearn import datasets, metrics, model_selection
from pylightgbm.models import GBMClassifier

# full path to lightgbm executable (on Windows include .exe)
exec_path = "lightgbm"

import sklearn.model_selection
import os

os.environ["LIGHTGBM_EXEC"] = exec_path

#X, Y = datasets.make_classification(n_samples=200, n_features=10)
#x_train, x_test, y_train, y_test = model_selection.train_test_split(X, Y, test_size=0.2)

clf = GBMClassifier(
        exec_path=exec_path,
        min_data_in_leaf=5,
        is_unbalance = True,
        num_iterations = 500,
        bagging_fraction = 0.8,
        bagging_freq = 5,
        metric = 'auc',
        early_stopping_round=10
)

x_train, y_train, x_test, y_test = [e[1] for e in train_data],[e[0][2] for e in train_data], [e[1] for e in test_data],[e[0][2] for e in test_data]

clf.fit( x_train, y_train, test_data=[(x_test, y_test)])
y_test_pred = clf.predict(np.array(x_test))
print("Accuracy: ", metrics.accuracy_score(y_test, y_test_pred))
print('AUC ROC:  ',metrics.roc_auc_score(y_test, y_test_pred))

# %%
y_test_pred = clf.predict(np.array(x_test))
print("Accuracy: ", metrics.accuracy_score(y_test, y_test_pred))
print('AUC ROC:  ',metrics.roc_auc_score(y_test, y_test_pred))

# %% [markdown]
# #### На всех фичах AUC 0.538, что плохо.

# %% [markdown]
# ### Скорим урлфрагменты на основе default_flg

# %%
query = '''
-- скор урла - логарифм регуляризованного отношения кол-ва уникальных положительных посетителей к отрицательным посетителям.
-- таких несколько партиций с интервалом в 3 месяца
insert overwrite table user_kposminin.urlfr_tgt_cnt partition (ymd, target)
select 
  urlfr,
  cnt_positive,
  cnt_total,
  log((cnt_positive + 0.1) / (cnt_total - cnt_positive + 0.1)) as score,
  ymd,
  target
from(
 select
   urlfr,
   count(distinct if(default_flg = 1, concat(phone_mobile, call_ymd), Null)) as  cnt_positive,
   count(distinct concat(phone_mobile, call_ymd)) as cnt_total,
   '2016-06-01' as ymd,
   'tinkoff_LON_CCR_default' as target
 from 
   user_kposminin.cred_app_visits
 where
   (not default_flg is Null)
   and call_ymd < '2016-06-01'
 group by urlfr
 ) a
;

-- Генерация фичей на основе этого скоринга. Шаг 1/4.
create table user_kposminin.cred_app_sc_1_1 as
select 
  phone_mobile
  ,call_ymd
  ,max(default_flg) as default_flg
  ,v.urlfr
  ,v.ymd
  ,max(
    named_struct(
      'ymd', v.ymd,
      'score', if(t.ymd < v.ymd,t.score, -10)
    )
   ).score as score
  ,max(  id_cnt ) as id_cnt
  ,max(  load_src_cnt ) as   load_src_cnt 
  ,max(  cnt ) as   cnt 
  ,max(  first_visit ) as   first_visit 
  ,max(  duration ) as   duration 
  ,max(  avg_hour ) as   avg_hour 
  ,max(  load_dttm ) as   load_dttm 
  ,max(  financial_product_type_cd ) as   financial_product_type_cd
  ,(unix_timestamp(max(v.call_ymd), 'yyyy-MM-dd') - unix_timestamp(min(v.ymd), 'yyyy-MM-dd'))/60/60/24 as lag
from 
  user_kposminin.cred_app_visits v
  left join user_kposminin.urlfr_tgt_cnt t on t.urlfr = v.urlfr
group by
  v.phone_mobile, 
  v.call_ymd,
  v.ymd,
  v.urlfr
;


set hive.tez.auto.reducer.parallelism=true;

set hive.tez.min.partition.factor=0.25;
set hive.tez.max.partition.factor=2.0;
set tez.runtime.pipelined.sorter.lazy-allocate.memory=true;
set hive.exec.reducers.bytes.per.reducer=67108864;


-- Генерация фичей на основе этого скоринга. Шаг 2/4.
create table user_kposminin.cred_app_sc_2 as
select 
  phone_mobile, 
  call_ymd, 
  max(default_flg) as default_flg,
  (unix_timestamp(max(ymd), 'yyyy-MM-dd') - unix_timestamp(min(ymd), 'yyyy-MM-dd'))/60/60/24 as ymd_range,
  stddev(unix_timestamp(ymd, 'yyyy-MM-dd')/60/60 + avg_hour) as time_std,
  count(distinct ymd) as ymd_cnt,
  max(id_cnt) as id_cnt,
  max(load_src_cnt) as load_src_cnt,
  avg(avg_hour) as avg_hour,
  percentile_approx(avg_hour,array(0.1,0.5,0.9)) as avg_hour_q_arr,
  count(*) as cnt,
  sum(cnt) as hits,
  avg(cnt) as avg_hits,
  avg(duration) as avg_duration,
  percentile_approx(duration,0.1) as duration_q10,
  percentile_approx(duration,0.9) as duration_q90,
  min(first_visit) as min_first_visit,
  avg(first_visit) as avg_first_visit,
  max(if(financial_product_type_cd = 'CCR',1,0)) as CCR,
  max(score) as max_score,
  avg(score) as avg_score,
  max(score * ( - log(lag + 1))) as max_w_score,
  avg(if(score > -2.5, avg_hour,Null)) as avg_good_hour,
  sum(if(regexp_extract(urlfr, '\.([^.#]*)#', 1) in ('ru','com','org'),1,0))/sum(1) as ru_com_share,
  sum(if(urlfr like 'e.mail.ru%',1,0))/sum(1) as emailru_share,
  sum(if(urlfr like 'm.%',1,0))/sum(1) as mobile_share,
  sum(if(urlfr rlike '^(m\\.)?vk.com%', 1, 0))/sum(1) as vk_share,
  sum(if(urlfr like 'vk.com%' or urlfr rlike '^(m\\.)?ok\\.ru' or urlfr like 'm.odnoklassniki.ru%' or urlfr rlike '^(m\\.)?my.mail.ru',1,0))/sum(1) as social_share,
  count(distinct urlfr) as urlfr_cnt    
from 
  user_kposminin.cred_app_sc_1_1
group by
  phone_mobile, 
  call_ymd
;


-- Генерация фичей на основе этого скоринга. Шаг 3/4.
create table user_kposminin.cred_app_sc_3 as
select 
  phone_mobile, 
  call_ymd,
  percentile_approx(score * ( - log(lag + 1)), array(0.1,0.3,0.5,0.7,0.8,0.9,0.98)) as w_score_q_arr,
  percentile_approx(score, array(0.1,0.3,0.5,0.7,0.8,0.9,0.98)) as score_q_arr
from 
  user_kposminin.cred_app_sc_1_1
group by
  phone_mobile, 
  call_ymd
;

-- Генерация фичей на основе этого скоринга. Шаг 4/4.
create table user_kposminin.cred_app_sc_4 as
select 
  a.*,
  b.w_score_q_arr,
  b.score_q_arr
from 
  user_kposminin.cred_app_sc_2 a
  left join user_kposminin.cred_app_sc_3 b on a.phone_mobile = b.phone_mobile and  a.call_ymd = b.call_ymd
;


'''

# %%
cols = ['phone_mobile','call_ymd','default_flg','ymd_range','time_std','ymd_cnt','id_cnt','load_src_cnt',
        'avg_hour','avg_hour_q10','avg_hour_q50','avg_hour_q90','cnt','hits','avg_hits','avg_duration',
        'duration_q10','duration_q90',
        'min_first_visit','avg_first_visit','ccr','max_score','avg_score','max_w_score','avg_good_hour',
        'ru_com_share','emailru_share','mobile_share','vk_share','social_share','urlfr_cnt',
        'wscore_q10','wscore_q30','wscore_q50','wscore_q70','wscore_q80','wscore_q90','wscore_q98',
        'score_q10','score_q30','score_q50','score_q70','score_q80','score_q90','score_q98']

# %%
df_train = (
      hc.sql('select * from user_kposminin.cred_app_sc_4')
        .filter('call_ymd <= "2016-06-01"')
        .filter('not default_flg is Null')
        .map(lambda r: 
                list(r[:9]) + (r[9] if r[9] else []) + list(r[10:-2])  + (r[-2] if r[-2] else []) + (r[-1] if r[-1] else [])
            )
        .toDF()
        .toPandas()
    )
df_train.columns = cols
feat_cols = [c for c in df_train.columns if not c in (u'phone_mobile', u'call_ymd', u'default_flg',
                                                      u'min_first_visit',u'avg_first_visit')]
    
df_test = (
      hc.sql('select * from user_kposminin.cred_app_sc_4')
        .filter('call_ymd > "2016-06-01"')
        .filter('not default_flg is Null')
        .map(lambda r: 
                list(r[:9]) + (r[9] if r[9] else []) + list(r[10:-2])  + (r[-2] if r[-2] else []) + (r[-1] if r[-1] else [])
            )
        .toDF()
        .toPandas()
    )
df_test.columns = cols
label = 'default_flg'

# %%
from sklearn import datasets, metrics, model_selection
from pylightgbm.models import GBMClassifier

# full path to lightgbm executable (on Windows include .exe)
exec_path = "/usr/bin/lightgbm"

#X, Y = datasets.make_classification(n_samples=200, n_features=10)
#x_train, x_test, y_train, y_test = model_selection.train_test_split(X, Y, test_size=0.2)

clf = GBMClassifier(
        exec_path=exec_path,
        min_data_in_leaf=10,
       # is_unbalance = True,
        num_iterations = 200,
        bagging_fraction = 0.8,
        bagging_freq = 10,
        num_leaves = 127,
        metric = 'auc',
        early_stopping_round=10
)

clf.fit(df_train[feat_cols], df_train[label], test_data = [(df_test[feat_cols], df_test[label])])
# Out:
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading data in 2.996620 seconds
# [LightGBM] [Info] Number of positive: 7820, number of negative: 127078
# [LightGBM] [Info] Total Bins 8592
# [LightGBM] [Info] Number of data: 134898, number of used features: 39
# [LightGBM] [Info] Finished initializing training
# [LightGBM] [Info] Started training...
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=16
# [LightGBM] [Info] Iteration:1, valid_1 auc : 0.569556
# [LightGBM] [Info] 0.087529 seconds elapsed, finished iteration 1
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=17
# [LightGBM] [Info] Iteration:2, valid_1 auc : 0.577962
# [LightGBM] [Info] 0.166675 seconds elapsed, finished iteration 2
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=17
# [LightGBM] [Info] Iteration:3, valid_1 auc : 0.588556
# [LightGBM] [Info] 0.249253 seconds elapsed, finished iteration 3
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=17
# [LightGBM] [Info] Iteration:4, valid_1 auc : 0.590992
# [LightGBM] [Info] 0.337459 seconds elapsed, finished iteration 4
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=16
# [LightGBM] [Info] Iteration:5, valid_1 auc : 0.594997
# [LightGBM] [Info] 0.435090 seconds elapsed, finished iteration 5
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=19
# [LightGBM] [Info] Iteration:6, valid_1 auc : 0.596007
# [LightGBM] [Info] 0.537468 seconds elapsed, finished iteration 6
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=18
# [LightGBM] [Info] Iteration:7, valid_1 auc : 0.597062
# [LightGBM] [Info] 0.640847 seconds elapsed, finished iteration 7
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=15
# [LightGBM] [Info] Iteration:8, valid_1 auc : 0.597784
# [LightGBM] [Info] 0.728868 seconds elapsed, finished iteration 8
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=16
# [LightGBM] [Info] Iteration:9, valid_1 auc : 0.597895
# [LightGBM] [Info] 0.816720 seconds elapsed, finished iteration 9
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=17
# [LightGBM] [Info] Iteration:10, valid_1 auc : 0.598177
# [LightGBM] [Info] 0.907074 seconds elapsed, finished iteration 10
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=15
# [LightGBM] [Info] Iteration:11, valid_1 auc : 0.59833
# [LightGBM] [Info] 0.999473 seconds elapsed, finished iteration 11
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=14
# [LightGBM] [Info] Iteration:12, valid_1 auc : 0.599551
# [LightGBM] [Info] 1.089587 seconds elapsed, finished iteration 12
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=16
# [LightGBM] [Info] Iteration:13, valid_1 auc : 0.596813
# [LightGBM] [Info] 1.182164 seconds elapsed, finished iteration 13
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=17
# [LightGBM] [Info] Iteration:14, valid_1 auc : 0.59796
# [LightGBM] [Info] 1.276253 seconds elapsed, finished iteration 14
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=15
# [LightGBM] [Info] Iteration:15, valid_1 auc : 0.597909
# [LightGBM] [Info] 1.365130 seconds elapsed, finished iteration 15
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=20
# [LightGBM] [Info] Iteration:16, valid_1 auc : 0.598079
# [LightGBM] [Info] 1.460549 seconds elapsed, finished iteration 16
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=15
# [LightGBM] [Info] Iteration:17, valid_1 auc : 0.598829
# [LightGBM] [Info] 1.551073 seconds elapsed, finished iteration 17
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=20
# [LightGBM] [Info] Iteration:18, valid_1 auc : 0.600611
# [LightGBM] [Info] 1.639783 seconds elapsed, finished iteration 18
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=16
# [LightGBM] [Info] Iteration:19, valid_1 auc : 0.601394
# [LightGBM] [Info] 1.738101 seconds elapsed, finished iteration 19
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=14
# [LightGBM] [Info] Iteration:20, valid_1 auc : 0.603506
# [LightGBM] [Info] 1.832137 seconds elapsed, finished iteration 20
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=13
# [LightGBM] [Info] Iteration:21, valid_1 auc : 0.604173
# [LightGBM] [Info] 1.931654 seconds elapsed, finished iteration 21
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=19
# [LightGBM] [Info] Iteration:22, valid_1 auc : 0.605612
# [LightGBM] [Info] 2.025121 seconds elapsed, finished iteration 22
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=17
# [LightGBM] [Info] Iteration:23, valid_1 auc : 0.605841
# [LightGBM] [Info] 2.125828 seconds elapsed, finished iteration 23
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=17
# [LightGBM] [Info] Iteration:24, valid_1 auc : 0.605809
# [LightGBM] [Info] 2.220508 seconds elapsed, finished iteration 24
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=18
# [LightGBM] [Info] Iteration:25, valid_1 auc : 0.608437
# [LightGBM] [Info] 2.323060 seconds elapsed, finished iteration 25
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=20
# [LightGBM] [Info] Iteration:26, valid_1 auc : 0.608828
# [LightGBM] [Info] 2.415348 seconds elapsed, finished iteration 26
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=23
# [LightGBM] [Info] Iteration:27, valid_1 auc : 0.61176
# [LightGBM] [Info] 2.513497 seconds elapsed, finished iteration 27
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=15
# [LightGBM] [Info] Iteration:28, valid_1 auc : 0.61256
# [LightGBM] [Info] 2.604033 seconds elapsed, finished iteration 28
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=21
# [LightGBM] [Info] Iteration:29, valid_1 auc : 0.613769
# [LightGBM] [Info] 2.701087 seconds elapsed, finished iteration 29
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=18
# [LightGBM] [Info] Iteration:30, valid_1 auc : 0.614608
# [LightGBM] [Info] 2.792603 seconds elapsed, finished iteration 30
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=15
# [LightGBM] [Info] Iteration:31, valid_1 auc : 0.614437
# [LightGBM] [Info] 2.884323 seconds elapsed, finished iteration 31
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=17
# [LightGBM] [Info] Iteration:32, valid_1 auc : 0.61525
# [LightGBM] [Info] 2.996879 seconds elapsed, finished iteration 32
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=18
# [LightGBM] [Info] Iteration:33, valid_1 auc : 0.613611
# [LightGBM] [Info] 3.108538 seconds elapsed, finished iteration 33
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=17
# [LightGBM] [Info] Iteration:34, valid_1 auc : 0.6147
# [LightGBM] [Info] 3.223271 seconds elapsed, finished iteration 34
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=25
# [LightGBM] [Info] Iteration:35, valid_1 auc : 0.616622
# [LightGBM] [Info] 3.327323 seconds elapsed, finished iteration 35
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=18
# [LightGBM] [Info] Iteration:36, valid_1 auc : 0.617315
# [LightGBM] [Info] 3.427333 seconds elapsed, finished iteration 36
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=16
# [LightGBM] [Info] Iteration:37, valid_1 auc : 0.61839
# [LightGBM] [Info] 3.531833 seconds elapsed, finished iteration 37
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=23
# [LightGBM] [Info] Iteration:38, valid_1 auc : 0.619264
# [LightGBM] [Info] 3.624265 seconds elapsed, finished iteration 38
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=27
# [LightGBM] [Info] Iteration:39, valid_1 auc : 0.619936
# [LightGBM] [Info] 3.713302 seconds elapsed, finished iteration 39
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=19
# [LightGBM] [Info] Iteration:40, valid_1 auc : 0.619438
# [LightGBM] [Info] 3.793950 seconds elapsed, finished iteration 40
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=18
# [LightGBM] [Info] Iteration:41, valid_1 auc : 0.619772
# [LightGBM] [Info] 3.888222 seconds elapsed, finished iteration 41
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=20
# [LightGBM] [Info] Iteration:42, valid_1 auc : 0.620113
# [LightGBM] [Info] 3.982097 seconds elapsed, finished iteration 42
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=20
# [LightGBM] [Info] Iteration:43, valid_1 auc : 0.620548
# [LightGBM] [Info] 4.076568 seconds elapsed, finished iteration 43
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=16
# [LightGBM] [Info] Iteration:44, valid_1 auc : 0.620286
# [LightGBM] [Info] 4.168922 seconds elapsed, finished iteration 44
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=22
# [LightGBM] [Info] Iteration:45, valid_1 auc : 0.619479
# [LightGBM] [Info] 4.271068 seconds elapsed, finished iteration 45
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=18
# [LightGBM] [Info] Iteration:46, valid_1 auc : 0.619431
# [LightGBM] [Info] 4.361206 seconds elapsed, finished iteration 46
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=24
# [LightGBM] [Info] Iteration:47, valid_1 auc : 0.621389
# [LightGBM] [Info] 4.460424 seconds elapsed, finished iteration 47
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=22
# [LightGBM] [Info] Iteration:48, valid_1 auc : 0.620544
# [LightGBM] [Info] 4.559062 seconds elapsed, finished iteration 48
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=19
# [LightGBM] [Info] Iteration:49, valid_1 auc : 0.619535
# [LightGBM] [Info] 4.650429 seconds elapsed, finished iteration 49
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=31
# [LightGBM] [Info] Iteration:50, valid_1 auc : 0.617746
# [LightGBM] [Info] 4.751140 seconds elapsed, finished iteration 50
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=24
# [LightGBM] [Info] Iteration:51, valid_1 auc : 0.617881
# [LightGBM] [Info] 4.854017 seconds elapsed, finished iteration 51
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=17
# [LightGBM] [Info] Iteration:52, valid_1 auc : 0.618458
# [LightGBM] [Info] 4.954099 seconds elapsed, finished iteration 52
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=19
# [LightGBM] [Info] Iteration:53, valid_1 auc : 0.618007
# [LightGBM] [Info] 5.050047 seconds elapsed, finished iteration 53
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=19
# [LightGBM] [Info] Iteration:54, valid_1 auc : 0.617458
# [LightGBM] [Info] 5.126406 seconds elapsed, finished iteration 54
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=25
# [LightGBM] [Info] Iteration:55, valid_1 auc : 0.617315
# [LightGBM] [Info] 5.206871 seconds elapsed, finished iteration 55
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=30
# [LightGBM] [Info] Iteration:56, valid_1 auc : 0.617959
# [LightGBM] [Info] 5.284531 seconds elapsed, finished iteration 56
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=22
# [LightGBM] [Info] Iteration:57, valid_1 auc : 0.617502
# [LightGBM] [Info] Early stopping at iteration 57, the best iteration round is 47
# [LightGBM] [Info] Output of best iteration round:
# Iteration:47, valid_1 auc : 0.621389
#
# [LightGBM] [Info] 5.357607 seconds elapsed, finished iteration 57
# [LightGBM] [Info] Finished training

# %% [markdown]
# [LightGBM] [Info] Iteration:47, valid_1 auc : 0.621389

# %%
clf = GBMClassifier(
        exec_path=exec_path,
        min_data_in_leaf=10,
       # is_unbalance = True,
        num_iterations = 200,
        bagging_fraction = 0.8,
        bagging_freq = 10,
        num_leaves = 127,
        metric = 'auc',
        early_stopping_round=10,
        verbose = False
)

r = cv(clf, df_train[feat_cols].values, df_train[label].values, folds = 5)
r
# Out:
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading data in 2.116740 seconds
# [LightGBM] [Info] Number of positive: 6303, number of negative: 101616
# [LightGBM] [Info] Total Bins 8540
# [LightGBM] [Info] Number of data: 107919, number of used features: 39
# [LightGBM] [Info] Finished initializing training
# [LightGBM] [Info] Started training...
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=15
# [LightGBM] [Info] 0.077955 seconds elapsed, finished iteration 1
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=19
# [LightGBM] [Info] 0.173667 seconds elapsed, finished iteration 2
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=14
# [LightGBM] [Info] 0.266064 seconds elapsed, finished iteration 3
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=17
# [LightGBM] [Info] 0.349094 seconds elapsed, finished iteration 4
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=14
# [LightGBM] [Info] 0.426295 seconds elapsed, finished iteration 5
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=19
# [LightGBM] [Info] 0.565265 seconds elapsed, finished iteration 6
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=17
# [LightGBM] [Info] 0.628355 seconds elapsed, finished iteration 7
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=13
# [LightGBM] [Info] 0.696107 seconds elapsed, finished iteration 8
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=16
# [LightGBM] [Info] 0.767509 seconds elapsed, finished iteration 9
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=17
# [LightGBM] [Info] 0.839518 seconds elapsed, finished iteration 10
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=16
# [LightGBM] [Info] 0.914933 seconds elapsed, finished iteration 11
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=17
# [LightGBM] [Info] 0.987230 seconds elapsed, finished iteration 12
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=17
# [LightGBM] [Info] 1.058245 seconds elapsed, finished iteration 13
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=13
# [LightGBM] [Info] 1.131863 seconds elapsed, finished iteration 14
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=14
# [LightGBM] [Info] 1.205171 seconds elapsed, finished iteration 15
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=19
# [LightGBM] [Info] 1.276868 seconds elapsed, finished iteration 16
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=18
# [LightGBM] [Info] 1.350650 seconds elapsed, finished iteration 17
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=18
# [LightGBM] [Info] 1.425778 seconds elapsed, finished iteration 18
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=16
# [LightGBM] [Info] 1.496709 seconds elapsed, finished iteration 19
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=16
# [LightGBM] [Info] 1.571619 seconds elapsed, finished iteration 20
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=18
# [LightGBM] [Info] 1.649388 seconds elapsed, finished iteration 21
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=17
# [LightGBM] [Info] 1.724328 seconds elapsed, finished iteration 22
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=15
# [LightGBM] [Info] 1.799087 seconds elapsed, finished iteration 23
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=14
# [LightGBM] [Info] 1.870868 seconds elapsed, finished iteration 24
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=18
# [LightGBM] [Info] 1.942586 seconds elapsed, finished iteration 25
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=24
# [LightGBM] [Info] 2.013445 seconds elapsed, finished iteration 26
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=20
# [LightGBM] [Info] 2.086477 seconds elapsed, finished iteration 27
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=20
# [LightGBM] [Info] 2.160112 seconds elapsed, finished iteration 28
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=16
# [LightGBM] [Info] 2.236729 seconds elapsed, finished iteration 29
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=17
# [LightGBM] [Info] 2.302927 seconds elapsed, finished iteration 30
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=24
# [LightGBM] [Info] 2.380317 seconds elapsed, finished iteration 31
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=15
# [LightGBM] [Info] 2.450923 seconds elapsed, finished iteration 32
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=23
# [LightGBM] [Info] 2.521080 seconds elapsed, finished iteration 33
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=24
# [LightGBM] [Info] 2.589320 seconds elapsed, finished iteration 34
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=18
# [LightGBM] [Info] 2.662072 seconds elapsed, finished iteration 35
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=16
# [LightGBM] [Info] 2.741876 seconds elapsed, finished iteration 36
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=20
# [LightGBM] [Info] 2.817346 seconds elapsed, finished iteration 37
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=21
# [LightGBM] [Info] 2.911142 seconds elapsed, finished iteration 38
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=19
# [LightGBM] [Info] 2.994172 seconds elapsed, finished iteration 39
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=16
# [LightGBM] [Info] 3.080496 seconds elapsed, finished iteration 40
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=18
# [LightGBM] [Info] 3.162048 seconds elapsed, finished iteration 41
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=26
# [LightGBM] [Info] 3.231341 seconds elapsed, finished iteration 42
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=23
# [LightGBM] [Info] 3.305353 seconds elapsed, finished iteration 43
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=30
# [LightGBM] [Info] 3.372476 seconds elapsed, finished iteration 44
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=22
# [LightGBM] [Info] 3.446662 seconds elapsed, finished iteration 45
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=18
# [LightGBM] [Info] 3.516312 seconds elapsed, finished iteration 46
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=30
# [LightGBM] [Info] 3.585928 seconds elapsed, finished iteration 47
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=18
# [LightGBM] [Info] 3.654037 seconds elapsed, finished iteration 48
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=18
# [LightGBM] [Info]
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=27
# [LightGBM] [Info] 11.161607 seconds elapsed, finished iteration 166
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=25
# [LightGBM] [Info] 11.217970 seconds elapsed, finished iteration 167
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=31
# [LightGBM] [Info] 11.284512 seconds elapsed, finished iteration 168
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=35
# [LightGBM] [Info] 11.355347 seconds elapsed, finished iteration 169
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=39
# [LightGBM] [Info] 11.432932 seconds elapsed, finished iteration 170
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=17
# [LightGBM] [Info] 11.506398 seconds elapsed, finished iteration 171
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=16
# [LightGBM] [Info] 11.574784 seconds elapsed, finished iteration 172
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=26
# [LightGBM] [Info] 11.646501 seconds elapsed, finished iteration 173
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=17
# [LightGBM] [Info] 11.708660 seconds elapsed, finished iteration 174
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=21
# [LightGBM] [Info] 11.766758 seconds elapsed, finished iteration 175
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=24
# [LightGBM] [Info] 11.824830 seconds elapsed, finished iteration 176
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=20
# [LightGBM] [Info] 11.891269 seconds elapsed, finished iteration 177
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=33
# [LightGBM] [Info] 11.955532 seconds elapsed, finished iteration 178
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=41
# [LightGBM] [Info] 12.029560 seconds elapsed, finished iteration 179
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=31
# [LightGBM] [Info] 12.095004 seconds elapsed, finished iteration 180
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=26
# [LightGBM] [Info] 12.163480 seconds elapsed, finished iteration 181
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=24
# [LightGBM] [Info] 12.227033 seconds elapsed, finished iteration 182
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=27
# [LightGBM] [Info] 12.287349 seconds elapsed, finished iteration 183
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=18
# [LightGBM] [Info] 12.350242 seconds elapsed, finished iteration 184
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=30
# [LightGBM] [Info] 12.409569 seconds elapsed, finished iteration 185
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=22
# [LightGBM] [Info] 12.469636 seconds elapsed, finished iteration 186
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=26
# [LightGBM] [Info] 12.529276 seconds elapsed, finished iteration 187
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=27
# [LightGBM] [Info] 12.592185 seconds elapsed, finished iteration 188
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=14
# [LightGBM] [Info] 12.654691 seconds elapsed, finished iteration 189
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=18
# [LightGBM] [Info] 12.720133 seconds elapsed, finished iteration 190
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=22
# [LightGBM] [Info] 12.789048 seconds elapsed, finished iteration 191
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=22
# [LightGBM] [Info] 12.852770 seconds elapsed, finished iteration 192
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=22
# [LightGBM] [Info] 12.912199 seconds elapsed, finished iteration 193
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=18
# [LightGBM] [Info] 12.982099 seconds elapsed, finished iteration 194
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=41
# [LightGBM] [Info] 13.048474 seconds elapsed, finished iteration 195
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=20
# [LightGBM] [Info] 13.114500 seconds elapsed, finished iteration 196
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=21
# [LightGBM] [Info] 13.181713 seconds elapsed, finished iteration 197
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=22
# [LightGBM] [Info] 13.250830 seconds elapsed, finished iteration 198
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=36
# [LightGBM] [Info] 13.322094 seconds elapsed, finished iteration 199
# [LightGBM] [Info] Trained a tree with leaves=127 and max_depth=22
# [LightGBM] [Info] 13.388673 seconds elapsed, finished iteration 200
# [LightGBM] [Info] Finished training
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading 201 models
# [LightGBM] [Info] Finished initializing prediction
# [LightGBM] [Info] Finished prediction
# {'pr_auc': [0.071950491278350528,
#   0.074294562782955653,
#   0.071768886500576112,
#   0.075306416063029624,
#   0.073866111581917124],
#  'roc_auc': [0.57228502960737127,
#   0.5709798530726633,
#   0.5632601128226381,
#   0.57083959705326037,
#   0.5791247754926665]}

# %%
np.mean(r['roc_auc'])
# Out:
# 0.57129787360971984

# %%
% matplotlib inline
feat_imp = pd.DataFrame([(feat_cols[k],v) for k,v in clf.feature_importance().items()]) #.sort_values(ascending=False)
feat_imp.index = feat_imp[0]
feat_imp = feat_imp.sort(1, ascending = False)[1]
feat_imp
# Out:
# 0
# ru_com_share     360
# avg_hits         343
# social_share     287
# avg_duration     246
# avg_hour         240
# mobile_share     239
# avg_good_hour    233
# duration_q90     230
# ymd_cnt          226
# score_q98        217
# wscore_q10       197
# time_std         187
# avg_hour_q10     177
# wscore_q50       174
# wscore_q30       171
# urlfr_cnt        165
# wscore_q90       164
# emailru_share    156
# score_q70        156
# avg_score        154
# hits             147
# ymd_range        146
# score_q50        138
# wscore_q80       134
# max_w_score      132
# wscore_q70       131
# wscore_q98       128
# cnt              116
# score_q80        112
# score_q90         97
# avg_hour_q90      96
# avg_hour_q50      76
# max_score         61
# ccr               32
# score_q30         30
# id_cnt            22
# score_q10          2
# duration_q10       1
# Name: 1, dtype: int64

# %%
import sklearn

#print("Features as classifiers: AUC ROC on test. ")
features_performance = [(
        f,
        sklearn.metrics.roc_auc_score(y_true = df_train[label],y_score = df_train[f].fillna(-1000)),
        sklearn.metrics.average_precision_score(y_true = df_train[label],y_score = df_train[f].fillna(-1000)),
    ) for f in feat_cols]
print('Feature standalone performace\n{:<30}  {:<15}  {:<15}\n'.format('Feature','Train AUC ROC','Train AUC PR') + 
    '\n'.join('{:<30}  {:<15.4f}  {:<15.4f}'.format(*e) for e in sorted(features_performance, key = lambda e: -e[1])))
# Out:
# Feature standalone performace
# Feature                         Train AUC ROC    Train AUC PR
# mobile_share                    0.5473           0.0777
# avg_duration                    0.5455           0.0656
# duration_q90                    0.5439           0.0654
# avg_hits                        0.5395           0.0653
# score_q98                       0.5217           0.0627
# social_share                    0.5210           0.0679
# hits                            0.5105           0.0602
# id_cnt                          0.5099           0.0616
# score_q70                       0.5087           0.0608
# max_score                       0.5087           0.0614
# ccr                             0.5077           0.4878
# score_q80                       0.5024           0.0594
# score_q90                       0.5022           0.0619
# cnt                             0.5008           0.0580
# duration_q10                    0.5005           0.0634
# urlfr_cnt                       0.5004           0.0578
# load_src_cnt                    0.5002           0.0634
# score_q10                       0.5002           0.0585
# vk_share                        0.5000           0.5290
# wscore_q50                      0.5000           0.0588
# score_q50                       0.4985           0.0596
# score_q30                       0.4985           0.0576
# wscore_q70                      0.4953           0.0568
# wscore_q30                      0.4952           0.0582
# avg_score                       0.4950           0.0577
# avg_hour_q90                    0.4944           0.0890
# wscore_q10                      0.4927           0.0570
# ymd_cnt                         0.4911           0.0563
# max_w_score                     0.4900           0.0562
# wscore_q80                      0.4896           0.0556
# ymd_range                       0.4874           0.0559
# wscore_q90                      0.4867           0.0549
# wscore_q98                      0.4866           0.0547
# time_std                        0.4845           0.0551
# ru_com_share                    0.4841           0.1059
# emailru_share                   0.4839           0.0537
# avg_good_hour                   0.4646           0.0524
# avg_hour_q50                    0.4634           0.0528
# avg_hour                        0.4561           0.0518
# avg_hour_q10                    0.4533           0.0519

# %% [markdown]
# ### CV Param selection

# %%
def cv(clf, X, y, folds = 5, metrics = 'roc_auc,pr_auc'):
    '''calc cross-validation metrics for clf classfier (actually LightGBM classifier) on X,y data '''
    assert X.shape[0] == len(y), 'X and y lengths doesnt match'
    idx = range(X.shape[0])
    np.random.shuffle(idx)
    fold_idx = []
    for i in range(folds):
        fold_idx.append(idx[i*len(idx)/folds:(i+1)*len(idx)/folds])
    res = {k:[] for k in metrics.split(',')}
    
    for i in range(folds):
        train_idx = reduce(lambda x,y: x+y,(fold_idx[:i] + fold_idx[(i+1):]))
        valid_idx = fold_idx[i]
        
        clf.fit(X[train_idx],y[train_idx])
        valid_pred = clf.predict_proba(X[valid_idx])[:,1]
        
        if('roc_auc' in metrics):
            res['roc_auc'].append(
                sklearn.metrics.roc_auc_score(
                  y_true = y[valid_idx],
                  y_score = valid_pred
                )
            )
        if('pr_auc' in metrics):
            res['pr_auc'].append(
                sklearn.metrics.average_precision_score(
                  y_true = y[valid_idx],
                  y_score = valid_pred
                )
            )
    return res

# %%
# Set high learning rate. Find optimum trees num

clf = GBMClassifier(
        exec_path=exec_path,
        min_data_in_leaf = 50,
       # is_unbalance = True,
        num_iterations = 200,
        bagging_fraction = 0.8,
        bagging_freq = 10,
        num_leaves = 63,
        learning_rate = 0.1,
        metric = 'auc',
        verbose=False
    )

    
param_grid = {
    'num_iterations': [30,70,100,150,200,300,500]

}

ngrid = 7
grid_search = sklearn.model_selection.RandomizedSearchCV(clf, param_distributions=param_grid,
                                   n_iter=ngrid,cv=5,scoring='roc_auc')

grid_search.fit(df_train[feat_cols], df_train[label])
grid_search.grid_scores_
# Out:
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# /opt/anaconda/lib/python2.7/site-packages/sklearn/model_selection/_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# [mean: 0.60078, std: 0.00826, params: {'num_iterations': 30},
#  mean: 0.60099, std: 0.00957, params: {'num_iterations': 70},
#  mean: 0.59579, std: 0.00840, params: {'num_iterations': 100},
#  mean: 0.58936, std: 0.00785, params: {'num_iterations': 150},
#  mean: 0.58389, std: 0.00886, params: {'num_iterations': 200},
#  mean: 0.57580, std: 0.00698, params: {'num_iterations': 300},
#  mean: 0.56865, std: 0.00646, params: {'num_iterations': 500}]

# %% [markdown]
# #### Selected learning_rate = 0.1,num_iterations = 70;

# %%
df_train.shape
# Out:
# (134898, 45)

# %%
# Set high learning rate. Find optimum trees num

clf = GBMClassifier(
        exec_path=exec_path,
        min_data_in_leaf = 50,
       # is_unbalance = True,
        num_iterations = 70,
        bagging_fraction = 0.8,
        bagging_freq = 10,
        num_leaves = 63,
        learning_rate = 0.1,
        metric = 'auc',
        verbose=False
    )

    
param_grid = {
    'min_data_in_leaf': [10,50,100,200,500],
    'num_leaves': [15,31,63,127,255],
    'bagging_fraction': [0.5,0.8, 1],
    'bagging_freq': [5,10,30],
    'feature_fraction': [0.5, 0.8, 1]
}

   
n_iter = 60

grid_search = sklearn.model_selection.RandomizedSearchCV(clf, param_distributions=param_grid,
                                   n_iter = n_iter, cv = 5,scoring='roc_auc')

grid_search.fit(df_train[feat_cols], df_train[label])
grid_search.grid_scores_
# Out:
# /opt/anaconda/lib/python2.7/site-packages/sklearn/model_selection/_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# [mean: 0.59545, std: 0.00717, params: {'num_leaves': 127, 'bagging_fraction': 1, 'bagging_freq': 10, 'min_data_in_leaf': 10, 'feature_fraction': 0.8},
#  mean: 0.59713, std: 0.01072, params: {'num_leaves': 127, 'bagging_fraction': 1, 'bagging_freq': 5, 'min_data_in_leaf': 200, 'feature_fraction': 1},
#  mean: 0.59321, std: 0.00843, params: {'num_leaves': 63, 'bagging_fraction': 0.5, 'bagging_freq': 30, 'min_data_in_leaf': 200, 'feature_fraction': 0.5},
#  mean: 0.60612, std: 0.01047, params: {'num_leaves': 63, 'bagging_fraction': 1, 'bagging_freq': 30, 'min_data_in_leaf': 500, 'feature_fraction': 0.5},
#  mean: 0.59557, std: 0.00766, params: {'num_leaves': 127, 'bagging_fraction': 1, 'bagging_freq': 5, 'min_data_in_leaf': 100, 'feature_fraction': 1},
#  mean: 0.61121, std: 0.01024, params: {'num_leaves': 15, 'bagging_fraction': 1, 'bagging_freq': 5, 'min_data_in_leaf': 100, 'feature_fraction': 0.8},
#  mean: 0.60404, std: 0.00778, params: {'num_leaves': 63, 'bagging_fraction': 1, 'bagging_freq': 10, 'min_data_in_leaf': 200, 'feature_fraction': 1},
#  mean: 0.60623, std: 0.01001, params: {'num_leaves': 15, 'bagging_fraction': 0.5, 'bagging_freq': 30, 'min_data_in_leaf': 200, 'feature_fraction': 1},
#  mean: 0.60377, std: 0.00898, params: {'num_leaves': 63, 'bagging_fraction': 1, 'bagging_freq': 5, 'min_data_in_leaf': 200, 'feature_fraction': 0.5},
#  mean: 0.59444, std: 0.00823, params: {'num_leaves': 127, 'bagging_fraction': 1, 'bagging_freq': 10, 'min_data_in_leaf': 10, 'feature_fraction': 0.5},
#  mean: 0.59720, std: 0.00829, params: {'num_leaves': 255, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'min_data_in_leaf': 500, 'feature_fraction': 0.5},
#  mean: 0.58613, std: 0.00465, params: {'num_leaves': 255, 'bagging_fraction': 1, 'bagging_freq': 5, 'min_data_in_leaf': 10, 'feature_fraction': 0.8},
#  mean: 0.60661, std: 0.00971, params: {'num_leaves': 31, 'bagging_fraction': 1, 'bagging_freq': 10, 'min_data_in_leaf': 100, 'feature_fraction': 0.5},
#  mean: 0.59607, std: 0.01205, params: {'num_leaves': 127, 'bagging_fraction': 1, 'bagging_freq': 30, 'min_data_in_leaf': 50, 'feature_fraction': 1},
#  mean: 0.59613, std: 0.00593, params: {'num_leaves': 63, 'bagging_fraction': 0.5, 'bagging_freq': 30, 'min_data_in_leaf': 50, 'feature_fraction': 0.8},
#  mean: 0.60833, std: 0.01039, params: {'num_leaves': 31, 'bagging_fraction': 1, 'bagging_freq': 30, 'min_data_in_leaf': 50, 'feature_fraction': 1},
#  mean: 0.60187, std: 0.00796, params: {'num_leaves': 31, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'min_data_in_leaf': 500, 'feature_fraction': 0.5},
#  mean: 0.60133, std: 0.00968, params: {'num_leaves': 63, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'min_data_in_leaf': 10, 'feature_fraction': 0.5},
#  mean: 0.60140, std: 0.00866, params: {'num_leaves': 31, 'bagging_fraction': 0.5, 'bagging_freq': 30, 'min_data_in_leaf': 50, 'feature_fraction': 0.8},
#  mean: 0.57701, std: 0.00827, params: {'num_leaves': 255, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'min_data_in_leaf': 50, 'feature_fraction': 0.5},
#  mean: 0.57833, std: 0.00447, params: {'num_leaves': 255, 'bagging_fraction': 0.5, 'bagging_freq': 30, 'min_data_in_leaf': 10, 'feature_fraction': 0.8},
#  mean: 0.60224, std: 0.00854, params: {'num_leaves': 31, 'bagging_fraction': 0.5, 'bagging_freq': 30, 'min_data_in_leaf': 10, 'feature_fraction': 0.8},
#  mean: 0.59577, std: 0.00929, params: {'num_leaves': 127, 'bagging_fraction': 0.8, 'bagging_freq': 10, 'min_data_in_leaf': 500, 'feature_fraction': 0.8},
#  mean: 0.60704, std: 0.00892, params: {'num_leaves': 15, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'min_data_in_leaf': 10, 'feature_fraction': 1},
#  mean: 0.60880, std: 0.01237, params: {'num_leaves': 31, 'bagging_fraction': 1, 'bagging_freq': 5, 'min_data_in_leaf': 500, 'feature_fraction': 1},
#  mean: 0.60897, std: 0.01102, params: {'num_leaves': 15, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'min_data_in_leaf': 200, 'feature_fraction': 0.5},
#  mean: 0.57713, std: 0.00390, params: {'num_leaves': 255, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'min_data_in_leaf': 100, 'feature_fraction': 0.5},
#  mean: 0.58819, std: 0.01024, params: {'num_leaves': 255, 'bagging_fraction': 1, 'bagging_freq': 30, 'min_data_in_leaf': 10, 'feature_fraction': 0.5},
#  mean: 0.60404, std: 0.00778, params: {'num_leaves': 63, 'bagging_fraction': 1, 'bagging_freq': 5, 'min_data_in_leaf': 200, 'feature_fraction': 1},
#  mean: 0.59727, std: 0.00685, params: {'num_leaves': 255, 'bagging_fraction': 1, 'bagging_freq': 10, 'min_data_in_leaf': 500, 'feature_fraction': 0.5},
#  mean: 0.60642, std: 0.00949, params: {'num_leaves': 31, 'bagging_fraction': 0.8, 'bagging_freq': 30, 'min_data_in_leaf': 100, 'feature_fraction': 1},
#  mean: 0.60848, std: 0.00748, params: {'num_leaves': 31, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'min_data_in_leaf': 500, 'feature_fraction': 1},
#  mean: 0.60394, std: 0.00819, params: {'num_leaves': 63, 'bagging_fraction': 1, 'bagging_freq': 10, 'min_data_in_leaf': 50, 'feature_fraction': 0.8},
#  mean: 0.60116, std: 0.00912, params: {'num_leaves': 31, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'min_data_in_leaf': 200, 'feature_fraction': 0.8},
#  mean: 0.58688, std: 0.00983, params: {'num_leaves': 255, 'bagging_fraction': 1, 'bagging_freq': 10, 'min_data_in_leaf': 50, 'feature_fraction': 0.5},
#  mean: 0.60445, std: 0.00914, params: {'num_leaves': 15, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'min_data_in_leaf': 100, 'feature_fraction': 0.8},
#  mean: 0.59301, std: 0.01038, params: {'num_leaves': 63, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'min_data_in_leaf': 200, 'feature_fraction': 0.8},
#  mean: 0.60277, std: 0.00850, params: {'num_leaves': 63, 'bagging_fraction': 0.8, 'bagging_freq': 10, 'min_data_in_leaf': 100, 'feature_fraction': 1},
#  mean: 0.60668, std: 0.01031, params: {'num_leaves': 31, 'bagging_fraction': 1, 'bagging_freq': 30, 'min_data_in_leaf': 200, 'feature_fraction': 0.5},
#  mean: 0.61115, std: 0.01106, params: {'num_leaves': 15, 'bagging_fraction': 1, 'bagging_freq': 5, 'min_data_in_leaf': 500, 'feature_fraction': 0.8},
#  mean: 0.59549, std: 0.01030, params: {'num_leaves': 63, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'min_data_in_leaf': 10, 'feature_fraction': 0.5},
#  mean: 0.59989, std: 0.00911, params: {'num_leaves': 255, 'bagging_fraction': 1, 'bagging_freq': 30, 'min_data_in_leaf': 500, 'feature_fraction': 0.8},
#  mean: 0.59357, std: 0.01161, params: {'num_leaves': 127, 'bagging_fraction': 1, 'bagging_freq': 30, 'min_data_in_leaf': 10, 'feature_fraction': 1},
#  mean: 0.58265, std: 0.00796, params: {'num_leaves': 255, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'min_data_in_leaf': 200, 'feature_fraction': 0.8},
#  mean: 0.58628, std: 0.00863, params: {'num_leaves': 127, 'bagging_fraction': 0.5, 'bagging_freq': 30, 'min_data_in_leaf': 100, 'feature_fraction': 0.5},
#  mean: 0.58484, std: 0.00601, params: {'num_leaves': 255, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'min_data_in_leaf': 100, 'feature_fraction': 1},
#  mean: 0.61071, std: 0.01156, params: {'num_leaves': 15, 'bagging_fraction': 1, 'bagging_freq': 30, 'min_data_in_leaf': 10, 'feature_fraction': 0.8},
#  mean: 0.60377, std: 0.00898, params: {'num_leaves': 63, 'bagging_fraction': 1, 'bagging_freq': 10, 'min_data_in_leaf': 200, 'feature_fraction': 0.5},
#  mean: 0.58245, std: 0.00972, params: {'num_leaves': 255, 'bagging_fraction': 0.5, 'bagging_freq': 10, 'min_data_in_leaf': 200, 'feature_fraction': 1},
#  mean: 0.60427, std: 0.01200, params: {'num_leaves': 63, 'bagging_fraction': 1, 'bagging_freq': 30, 'min_data_in_leaf': 50, 'feature_fraction': 0.5},
#  mean: 0.59723, std: 0.00959, params: {'num_leaves': 63, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'min_data_in_leaf': 50, 'feature_fraction': 0.8},
#  mean: 0.59670, std: 0.00742, params: {'num_leaves': 127, 'bagging_fraction': 1, 'bagging_freq': 30, 'min_data_in_leaf': 50, 'feature_fraction': 0.5},
#  mean: 0.59242, std: 0.01020, params: {'num_leaves': 63, 'bagging_fraction': 0.5, 'bagging_freq': 5, 'min_data_in_leaf': 100, 'feature_fraction': 0.8},
#  mean: 0.58717, std: 0.00514, params: {'num_leaves': 255, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'min_data_in_leaf': 100, 'feature_fraction': 0.5},
#  mean: 0.60252, std: 0.00823, params: {'num_leaves': 31, 'bagging_fraction': 0.5, 'bagging_freq': 30, 'min_data_in_leaf': 200, 'feature_fraction': 0.5},
#  mean: 0.60757, std: 0.00788, params: {'num_leaves': 31, 'bagging_fraction': 0.8, 'bagging_freq': 30, 'min_data_in_leaf': 50, 'feature_fraction': 0.8},
#  mean: 0.60785, std: 0.00899, params: {'num_leaves': 15, 'bagging_fraction': 0.8, 'bagging_freq': 30, 'min_data_in_leaf': 50, 'feature_fraction': 1},
#  mean: 0.60958, std: 0.01024, params: {'num_leaves': 15, 'bagging_fraction': 0.8, 'bagging_freq': 10, 'min_data_in_leaf': 200, 'feature_fraction': 1},
#  mean: 0.58819, std: 0.01024, params: {'num_leaves': 255, 'bagging_fraction': 1, 'bagging_freq': 10, 'min_data_in_leaf': 10, 'feature_fraction': 0.5},
#  mean: 0.60466, std: 0.01114, params: {'num_leaves': 31, 'bagging_fraction': 0.8, 'bagging_freq': 10, 'min_data_in_leaf': 50, 'feature_fraction': 0.8}]

# %% [markdown]
# #### selected params:
# mean	0.61121	 std	0.01024	 params	 {'num_leaves'	15	 'bagging_fraction'	1	 'bagging_freq'	5	 'min_data_in_leaf'	100	 'feature_fraction'	 0.8}

# %%
clf = GBMClassifier(
        exec_path=exec_path,
        min_data_in_leaf = 100,
       # is_unbalance = True,
        num_iterations = 70,
        bagging_fraction = 1,
        bagging_freq = 10,
        num_leaves = 15,
        learning_rate = 0.1,
        feature_fraction = 0.8,
        metric = 'auc',
        verbose=False
    )

param_set = (
    {'learning_rate':0.1, 'num_iterations':50, 'num_leaves':15},
    {'learning_rate':0.1, 'num_iterations':70, 'num_leaves':15},
    {'learning_rate':0.08, 'num_iterations':100, 'num_leaves':15},
    {'learning_rate':0.08, 'num_iterations':100, 'num_leaves':31},
    {'learning_rate':0.06, 'num_iterations':150, 'num_leaves':31},
    {'learning_rate':0.06, 'num_iterations':150, 'num_leaves':15},
    {'learning_rate':0.05, 'num_iterations':200, 'num_leaves':31},
    {'learning_rate':0.04, 'num_iterations':200, 'num_leaves':63},
    {'learning_rate':0.04, 'num_iterations':300, 'num_leaves':63},
    {'learning_rate':0.03, 'num_iterations':400, 'num_leaves':31},
    {'learning_rate':0.05, 'num_iterations':300, 'num_leaves':31},
)


#n_iter = 60
res= []
for param in param_set:
    clf = GBMClassifier(
        exec_path=exec_path,
        min_data_in_leaf = 100,
       # is_unbalance = True,
        num_iterations = param['num_iterations'],
        bagging_fraction = 1,
        bagging_freq = 10,
        num_leaves = param['num_iterations'],
        learning_rate = param['learning_rate'],
        feature_fraction = 0.8,
        metric = 'auc',
        verbose=False
    )
    
    res.append((param,cv(clf, df_train[feat_cols].values, df_train[label].values, folds = 5, metrics = 'roc_auc,pr_auc')))

res
# Out:
# [({'learning_rate': 0.1, 'num_iterations': 50, 'num_leaves': 15},
#   {'pr_auc': [0.084286220715624346,
#     0.088322256546325098,
#     0.079744264035498058,
#     0.081517660900245842,
#     0.084433639510321207],
#    'roc_auc': [0.6056876034278178,
#     0.62096607715161278,
#     0.60673254068360249,
#     0.59978394435124527,
#     0.60266560519298251]}),
#  ({'learning_rate': 0.1, 'num_iterations': 70, 'num_leaves': 15},
#   {'pr_auc': [0.078797464910333764,
#     0.082048933857588879,
#     0.088138836053995639,
#     0.081569930056610229,
#     0.07921471148279316],
#    'roc_auc': [0.59781436760121887,
#     0.6051800142275211,
#     0.61291824687733953,
#     0.59646110906274907,
#     0.58430211112503794]}),
#  ({'learning_rate': 0.08, 'num_iterations': 100, 'num_leaves': 15},
#   {'pr_auc': [0.085303276395080591,
#     0.080341032151445474,
#     0.079622124002314623,
#     0.079100281677425124,
#     0.085951523854748565],
#    'roc_auc': [0.60486672832207589,
#     0.58494961609280127,
#     0.6075814462446496,
#     0.59392442611289709,
#     0.60064574648754288]}),
#  ({'learning_rate': 0.08, 'num_iterations': 100, 'num_leaves': 31},
#   {'pr_auc': [0.088974245796736406,
#     0.080332256554701095,
#     0.085679936339634291,
#     0.08016183625460592,
#     0.076080764758617553],
#    'roc_auc': [0.60694476647231932,
#     0.60733405419431519,
#     0.60734590175161129,
#     0.59390882078710561,
#     0.59871588015829336]}),
#  ({'learning_rate': 0.06, 'num_iterations': 150, 'num_leaves': 31},
#   {'pr_auc': [0.077644669359729995,
#     0.078748778990115342,
#     0.082764764996977797,
#     0.078274959123224269,
#     0.078326239984723919],
#    'roc_auc': [0.59413490547690406,
#     0.59830864013762108,
#     0.60692285060314266,
#     0.59359496725804395,
#     0.58839298618865277]}),
#  ({'learning_rate': 0.06, 'num_iterations': 150, 'num_leaves': 15},
#   {'pr_auc': [0.079528604905082068,
#     0.082150140710706879,
#     0.080636469015016754,
#     0.082434980376460076,
#     0.082651587996746226],
#    'roc_auc': [0.59486801361276964,
#     0.6002410827641671,
#     0.60337560081595321,
#     0.59070989855575384,
#     0.59531365933750646]}),
#  ({'learning_rate': 0.05, 'num_iterations': 200, 'num_leaves': 31},
#   {'pr_auc': [0.078576892734677384,
#     0.083530786290867021,
#     0.075462476249897256,
#     0.083349733902810239,
#     0.077599442091916493],
#    'roc_auc': [0.59304476981112342,
#     0.59905331691857178,
#     0.59206354387774152,
#     0.60461716205216576,
#     0.58071120323658187]}),
#  ({'learning_rate': 0.04, 'num_iterations': 200, 'num_leaves': 63},
#   {'pr_auc': [0.080054814917778785,
#     0.079416760410072229,
#     0.081288869556660787,
#     0.079791095837539128,
#     0.083795734733921823],
#    'roc_auc': [0.59099815093243913,
#     0.5977834220414544,
#     0.6041067180945684,
#     0.59274600794384724,
#     0.60542044966116226]}),
#  ({'learning_rate': 0.04, 'num_iterations': 300, 'num_leaves': 63},
#   {'pr_auc': [0.075655946952809791,
#     0.076472061139843867,
#     0.076660972183030196,
#     0.073046012693320089,
#     0.081597638747762935],
#    'roc_auc': [0.57410910153030525,
#     0.58096921731561979,
#     0.58577639636202861,
#     0.58017542619759099,
#     0.59225133285399789]}),
#  ({'learning_rate': 0.03, 'num_iterations': 400, 'num_leaves': 31},
#   {'pr_auc': [0.077368107066558556,
#     0.079075312507721429,
#     0.074802940654538727,
#     0.074169176782563434,
#     0.071009145992496456],
#    'roc_auc': [0.58173430219539513,
#     0.58638217419756056,
#     0.58151194296145126,
#     0.5763266607438281,
#     0.5761055616101034]}),
#  ({'learning_rate': 0.05, 'num_iterations': 300, 'num_leaves': 31},
#   {'pr_auc': [0.072301603517789997,
#     0.075231656271350228,
#     0.075475714018771498,
#     0.072147508530553447,
#     0.076775265808582766],
#    'roc_auc': [0.57534756703078449,
#     0.57541699177909722,
#     0.57684225414721879,
#     0.58450828817712108,
#     0.58055904693797133]})]

# %%
df_res = pd.DataFrame([(k,v['pr_auc'],v['roc_auc']) for (k,v) in res],
                      columns = ['feats','cv_pr','cv_roc'])
df_res['avg_roc'] = df_res['cv_roc'].map(lambda l: sum(l)/len(l))
df_res['std_roc'] = df_res['cv_roc'].map(lambda l: np.std(l))
df_res['min_roc'] = df_res['cv_roc'].map(lambda l: min(l))
df_res['max_roc'] = df_res['cv_roc'].map(lambda l: max(l))
df_res['avg_pr'] = df_res['cv_pr'].map(lambda l: sum(l)/len(l))
df_res['std_pr'] = df_res['cv_pr'].map(lambda l: np.std(l))
df_res['min_pr'] = df_res['cv_pr'].map(lambda l: min(l))
df_res['max_pr'] = df_res['cv_pr'].map(lambda l: max(l))
df_res['feats_len'] = df_res['feats'].map(lambda l: len(l))
df_res
# Out:
#                                                 feats  \
# 0   {u'num_iterations': 50, u'learning_rate': 0.1,...
# 1   {u'num_iterations': 70, u'learning_rate': 0.1,...
# 2   {u'num_iterations': 100, u'learning_rate': 0.0...
# 3   {u'num_iterations': 100, u'learning_rate': 0.0...
# 4   {u'num_iterations': 150, u'learning_rate': 0.0...
# 5   {u'num_iterations': 150, u'learning_rate': 0.0...
# 6   {u'num_iterations': 200, u'learning_rate': 0.0...
# 7   {u'num_iterations': 200, u'learning_rate': 0.0...
# 8   {u'num_iterations': 300, u'learning_rate': 0.0...
# 9   {u'num_iterations': 400, u'learning_rate': 0.0...
# 10  {u'num_iterations': 300, u'learning_rate': 0.0...
#
#                                                 cv_pr  \
# 0   [0.0842862207156, 0.0883222565463, 0.079744264...
# 1   [0.0787974649103, 0.0820489338576, 0.088138836...
# 2   [0.0853032763951, 0.0803410321514, 0.079622124...
# 3   [0.0889742457967, 0.0803322565547, 0.085679936...
# 4   [0.0776446693597, 0.0787487789901, 0.082764764...
# 5   [0.0795286049051, 0.0821501407107, 0.080636469...
# 6   [0.0785768927347, 0.0835307862909, 0.075462476...
# 7   [0.0800548149178, 0.0794167604101, 0.081288869...
# 8   [0.0756559469528, 0.0764720611398, 0.076660972...
# 9   [0.0773681070666, 0.0790753125077, 0.074802940...
# 10  [0.0723016035178, 0.0752316562714, 0.075475714...
#
#                                                cv_roc   avg_roc   std_roc  \
# 0   [0.605687603428, 0.620966077152, 0.60673254068...  0.607167  0.007315
# 1   [0.597814367601, 0.605180014228, 0.61291824687...  0.599335  0.009542
# 2   [0.604866728322, 0.584949616093, 0.60758144624...  0.598394  0.008150
# 3   [0.606944766472, 0.607334054194, 0.60734590175...  0.602850  0.005552
# 4   [0.594134905477, 0.598308640138, 0.60692285060...  0.596271  0.006187
# 5   [0.594868013613, 0.600241082764, 0.60337560081...  0.596902  0.004429
# 6   [0.593044769811, 0.599053316919, 0.59206354387...  0.593898  0.007993
# 7   [0.590998150932, 0.597783422041, 0.60410671809...  0.598211  0.005811
# 8   [0.57410910153, 0.580969217316, 0.585776396362...  0.582656  0.006064
# 9   [0.581734302195, 0.586382174198, 0.58151194296...  0.580412  0.003843
# 10  [0.575347567031, 0.575416991779, 0.57684225414...  0.578535  0.003536
#
#      min_roc   max_roc    avg_pr    std_pr    min_pr    max_pr  feats_len
# 0   0.599784  0.620966  0.083661  0.002921  0.079744  0.088322          3
# 1   0.584302  0.612918  0.081954  0.003343  0.078797  0.088139          3
# 2   0.584950  0.607581  0.082064  0.002943  0.079100  0.085952          3
# 3   0.593909  0.607346  0.082246  0.004540  0.076081  0.088974          3
# 4   0.588393  0.606923  0.079152  0.001841  0.077645  0.082765          3
# 5   0.590710  0.603376  0.081480  0.001204  0.079529  0.082652          3
# 6   0.580711  0.604617  0.079704  0.003213  0.075462  0.083531          3
# 7   0.590998  0.605420  0.080869  0.001592  0.079417  0.083796          3
# 8   0.574109  0.592251  0.076687  0.002774  0.073046  0.081598          3
# 9   0.576106  0.586382  0.075285  0.002774  0.071009  0.079075          3
# 10  0.575348  0.584508  0.074386  0.001842  0.072148  0.076775          3

# %%
df_res.loc[0]['feats']
# Out:
# {'learning_rate': 0.1, 'num_iterations': 50, 'num_leaves': 15}

# %%
clf = GBMClassifier(
        exec_path=exec_path,
        min_data_in_leaf = 100,
       # is_unbalance = True,
        num_iterations = 70,
        bagging_fraction = 1,
        bagging_freq = 10,
        num_leaves = 15,
        learning_rate = 0.1,
        metric = 'auc',
        feature_fraction = 0.8,
    )

#mean 0.61121 std 0.01024 params {'num_leaves' 15 'bagging_fraction' 1 'bagging_freq' 5 'min_data_in_leaf' 100 'feature_fraction' 0.8}
r = cv(clf, df_train[feat_cols].values, df_train[label].values, folds = 5, metrics = 'roc_auc,pr_auc')
np.mean(r['roc_auc']),
# Out:
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading data in 1.890656 seconds
# [LightGBM] [Info] Number of positive: 6276, number of negative: 101643
# [LightGBM] [Info] Total Bins 8547
# [LightGBM] [Info] Number of data: 107919, number of used features: 39
# [LightGBM] [Info] Finished initializing training
# [LightGBM] [Info] Started training...
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 0.030033 seconds elapsed, finished iteration 1
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 0.058022 seconds elapsed, finished iteration 2
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 0.085434 seconds elapsed, finished iteration 3
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 0.113934 seconds elapsed, finished iteration 4
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] 0.142533 seconds elapsed, finished iteration 5
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=10
# [LightGBM] [Info] 0.168835 seconds elapsed, finished iteration 6
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=5
# [LightGBM] [Info] 0.197458 seconds elapsed, finished iteration 7
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 0.225927 seconds elapsed, finished iteration 8
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 0.253230 seconds elapsed, finished iteration 9
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 0.280107 seconds elapsed, finished iteration 10
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] 0.308513 seconds elapsed, finished iteration 11
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 0.339139 seconds elapsed, finished iteration 12
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 0.366744 seconds elapsed, finished iteration 13
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] 0.396409 seconds elapsed, finished iteration 14
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 0.424026 seconds elapsed, finished iteration 15
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 0.455217 seconds elapsed, finished iteration 16
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 0.483676 seconds elapsed, finished iteration 17
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=5
# [LightGBM] [Info] 0.515141 seconds elapsed, finished iteration 18
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 0.546505 seconds elapsed, finished iteration 19
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 0.577927 seconds elapsed, finished iteration 20
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 0.606755 seconds elapsed, finished iteration 21
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 0.635528 seconds elapsed, finished iteration 22
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 0.665628 seconds elapsed, finished iteration 23
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 0.698887 seconds elapsed, finished iteration 24
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=9
# [LightGBM] [Info] 0.725843 seconds elapsed, finished iteration 25
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] 0.755225 seconds elapsed, finished iteration 26
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 0.784293 seconds elapsed, finished iteration 27
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 0.813484 seconds elapsed, finished iteration 28
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 0.843624 seconds elapsed, finished iteration 29
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 0.870900 seconds elapsed, finished iteration 30
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] 0.897122 seconds elapsed, finished iteration 31
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 0.936418 seconds elapsed, finished iteration 32
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 0.963998 seconds elapsed, finished iteration 33
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] 0.992937 seconds elapsed, finished iteration 34
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] 1.020537 seconds elapsed, finished iteration 35
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 1.047842 seconds elapsed, finished iteration 36
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 1.075544 seconds elapsed, finished iteration 37
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] 1.101715 seconds elapsed, finished iteration 38
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 1.130592 seconds elapsed, finished iteration 39
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] 1.159375 seconds elapsed, finished iteration 40
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 1.191788 seconds elapsed, finished iteration 41
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] 1.218484 seconds elapsed, finished iteration 42
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 1.242870 seconds elapsed, finished iteration 43
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] 1.268239 seconds elapsed, finished iteration 44
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 1.295947 seconds elapsed, finished iteration 45
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] 1.323411 seconds elapsed, finished iteration 46
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] 1.350611 seconds elapsed, finished iteration 47
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 1.378415 seconds elapsed, finished iteration 48
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 1.402229 seconds elapsed, finished iteration 49
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=5
# [LightGBM] [Info] 1.425697 seconds elapsed, finished iteration 50
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=9
# [LightGBM] [Info] 1.448075 seconds elapsed, finished iteration 51
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=9
# [LightGBM] [Info] 1.475496 seconds elapsed, finished iteration 52
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 1.502996 seconds elapsed, finished iteration 53
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 1.529011 seconds elapsed, finished iteration 54
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 1.553914 seconds elapsed, finished iteration 55
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] 1.571576 seconds elapsed, finished iteration 56
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=9
# [LightGBM] [Info] 1.593302 seconds elapsed, finished iteration 57
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=9
# [LightGBM] [Info] 1.615854 seconds elapsed, finished iteration 58
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=10
# [LightGBM] [Info] 1.636286 seconds elapsed, finished iteration 59
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=10
# [LightGBM] [Info] 1.658390 seconds elapsed, finished iteration 60
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 1
seconds elapsed, finished iteration 15
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=4
# [LightGBM] [Info] 0.473181 seconds elapsed, finished iteration 16
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 0.502588 seconds elapsed, finished iteration 17
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=9
# [LightGBM] [Info] 0.535186 seconds elapsed, finished iteration 18
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 0.564235 seconds elapsed, finished iteration 19
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=5
# [LightGBM] [Info] 0.593557 seconds elapsed, finished iteration 20
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 0.624086 seconds elapsed, finished iteration 21
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 0.656188 seconds elapsed, finished iteration 22
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 0.683639 seconds elapsed, finished iteration 23
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=10
# [LightGBM] [Info] 0.710807 seconds elapsed, finished iteration 24
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=5
# [LightGBM] [Info] 0.738725 seconds elapsed, finished iteration 25
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 0.768663 seconds elapsed, finished iteration 26
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 0.794807 seconds elapsed, finished iteration 27
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] 0.821225 seconds elapsed, finished iteration 28
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 0.851543 seconds elapsed, finished iteration 29
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 0.882739 seconds elapsed, finished iteration 30
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=10
# [LightGBM] [Info] 0.909747 seconds elapsed, finished iteration 31
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 0.939162 seconds elapsed, finished iteration 32
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 0.968875 seconds elapsed, finished iteration 33
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=9
# [LightGBM] [Info] 0.996028 seconds elapsed, finished iteration 34
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] 1.021143 seconds elapsed, finished iteration 35
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 1.050425 seconds elapsed, finished iteration 36
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] 1.076326 seconds elapsed, finished iteration 37
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 1.109201 seconds elapsed, finished iteration 38
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 1.134392 seconds elapsed, finished iteration 39
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 1.164354 seconds elapsed, finished iteration 40
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 1.186899 seconds elapsed, finished iteration 41
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] 1.215593 seconds elapsed, finished iteration 42
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=5
# [LightGBM] [Info] 1.244655 seconds elapsed, finished iteration 43
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 1.271265 seconds elapsed, finished iteration 44
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 1.298685 seconds elapsed, finished iteration 45
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 1.323416 seconds elapsed, finished iteration 46
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] 1.350930 seconds elapsed, finished iteration 47
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 1.381916 seconds elapsed, finished iteration 48
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=10
# [LightGBM] [Info] 1.404636 seconds elapsed, finished iteration 49
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=9
# [LightGBM] [Info] 1.427725 seconds elapsed, finished iteration 50
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=9
# [LightGBM] [Info] 1.456092 seconds elapsed, finished iteration 51
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=9
# [LightGBM] [Info] 1.481038 seconds elapsed, finished iteration 52
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 1.504521 seconds elapsed, finished iteration 53
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 1.525667 seconds elapsed, finished iteration 54
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] 1.548527 seconds elapsed, finished iteration 55
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 1.572232 seconds elapsed, finished iteration 56
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 1.596854 seconds elapsed, finished iteration 57
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] 1.623829 seconds elapsed, finished iteration 58
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 1.642029 seconds elapsed, finished iteration 59
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=9
# [LightGBM] [Info] 1.667345 seconds elapsed, finished iteration 60
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=10
# [LightGBM] [Info] 1.686421 seconds elapsed, finished iteration 61
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] 1.708831 seconds elapsed, finished iteration 62
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=9
# [LightGBM] [Info] 1.731776 seconds elapsed, finished iteration 63
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] 1.749130 seconds elapsed, finished iteration 64
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] 1.775317 seconds elapsed, finished iteration 65
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 1.807974 seconds elapsed, finished iteration 66
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=10
# [LightGBM] [Info] 1.839043 seconds elapsed, finished iteration 67
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] 1.867346 seconds elapsed, finished iteration 68
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] 1.888651 seconds elapsed, finished iteration 69
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] 1.909474 seconds elapsed, finished iteration 70
# [LightGBM] [Info] Finished training
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading 71 models
# [LightGBM] [Info] Finished initializing prediction
# [LightGBM] [Info] Finished prediction
# {'pr_auc': [0.086699640984514409,
#   0.084277130912495488,
#   0.084362409878600414,
#   0.087120664284016242,
#   0.079642755786071787],
#  'roc_auc': [0.61947680310778974,
#   0.6030140136319867,
#   0.60529199693589464,
#   0.61323617964982846,
#   0.60684291587992467]}

# %%
clf = GBMClassifier(
        exec_path=exec_path,
        min_data_in_leaf = 100,
       # is_unbalance = True,
        num_iterations = 300,
        bagging_fraction = 1,
        bagging_freq = 10,
        num_leaves = 15,
        learning_rate = 0.1,
        metric = 'auc',
        feature_fraction = 0.8,
        early_stopping_round=10
    )

clf.fit(df_train[feat_cols], df_train[label], test_data = [(df_test[feat_cols], df_test[label])])
# Out:
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading data in 2.771454 seconds
# [LightGBM] [Info] Number of positive: 7820, number of negative: 127078
# [LightGBM] [Info] Total Bins 8592
# [LightGBM] [Info] Number of data: 134898, number of used features: 39
# [LightGBM] [Info] Finished initializing training
# [LightGBM] [Info] Started training...
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] Iteration:1, valid_1 auc : 0.593282
# [LightGBM] [Info] 0.039779 seconds elapsed, finished iteration 1
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] Iteration:2, valid_1 auc : 0.597723
# [LightGBM] [Info] 0.079822 seconds elapsed, finished iteration 2
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] Iteration:3, valid_1 auc : 0.597559
# [LightGBM] [Info] 0.115812 seconds elapsed, finished iteration 3
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] Iteration:4, valid_1 auc : 0.600037
# [LightGBM] [Info] 0.156167 seconds elapsed, finished iteration 4
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] Iteration:5, valid_1 auc : 0.601017
# [LightGBM] [Info] 0.194365 seconds elapsed, finished iteration 5
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=5
# [LightGBM] [Info] Iteration:6, valid_1 auc : 0.603739
# [LightGBM] [Info] 0.235227 seconds elapsed, finished iteration 6
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] Iteration:7, valid_1 auc : 0.605273
# [LightGBM] [Info] 0.275002 seconds elapsed, finished iteration 7
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] Iteration:8, valid_1 auc : 0.606237
# [LightGBM] [Info] 0.316822 seconds elapsed, finished iteration 8
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] Iteration:9, valid_1 auc : 0.607284
# [LightGBM] [Info] 0.354666 seconds elapsed, finished iteration 9
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] Iteration:10, valid_1 auc : 0.607394
# [LightGBM] [Info] 0.395582 seconds elapsed, finished iteration 10
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] Iteration:11, valid_1 auc : 0.60939
# [LightGBM] [Info] 0.436597 seconds elapsed, finished iteration 11
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] Iteration:12, valid_1 auc : 0.609885
# [LightGBM] [Info] 0.476801 seconds elapsed, finished iteration 12
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] Iteration:13, valid_1 auc : 0.610103
# [LightGBM] [Info] 0.515600 seconds elapsed, finished iteration 13
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=5
# [LightGBM] [Info] Iteration:14, valid_1 auc : 0.60938
# [LightGBM] [Info] 0.557733 seconds elapsed, finished iteration 14
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=5
# [LightGBM] [Info
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=5
# [LightGBM] [Info] Iteration:44, valid_1 auc : 0.630741
# [LightGBM] [Info] 1.731478 seconds elapsed, finished iteration 44
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] Iteration:45, valid_1 auc : 0.63053
# [LightGBM] [Info] 1.768867 seconds elapsed, finished iteration 45
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] Iteration:46, valid_1 auc : 0.63269
# [LightGBM] [Info] 1.810092 seconds elapsed, finished iteration 46
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] Iteration:47, valid_1 auc : 0.632721
# [LightGBM] [Info] 1.847258 seconds elapsed, finished iteration 47
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=5
# [LightGBM] [Info] Iteration:48, valid_1 auc : 0.632792
# [LightGBM] [Info] 1.886642 seconds elapsed, finished iteration 48
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] Iteration:49, valid_1 auc : 0.634119
# [LightGBM] [Info] 1.926648 seconds elapsed, finished iteration 49
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=9
# [LightGBM] [Info] Iteration:50, valid_1 auc : 0.633721
# [LightGBM] [Info] 1.963877 seconds elapsed, finished iteration 50
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=9
# [LightGBM] [Info] Iteration:51, valid_1 auc : 0.633322
# [LightGBM] [Info] 1.993791 seconds elapsed, finished iteration 51
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=11
# [LightGBM] [Info] Iteration:52, valid_1 auc : 0.634756
# [LightGBM] [Info] 2.029237 seconds elapsed, finished iteration 52
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] Iteration:53, valid_1 auc : 0.634887
# [LightGBM] [Info] 2.061494 seconds elapsed, finished iteration 53
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=12
# [LightGBM] [Info] Iteration:54, valid_1 auc : 0.635476
# [LightGBM] [Info] 2.093422 seconds elapsed, finished iteration 54
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] Iteration:55, valid_1 auc : 0.635692
# [LightGBM] [Info] 2.129559 seconds elapsed, finished iteration 55
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] Iteration:56, valid_1 auc : 0.637175
# [LightGBM] [Info] 2.164416 seconds elapsed, finished iteration 56
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] Iteration:57, valid_1 auc : 0.636506
# [LightGBM] [Info] 2.195027 seconds elapsed, finished iteration 57
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=9
# [LightGBM] [Info] Iteration:58, valid_1 auc : 0.636702
# [LightGBM] [Info] 2.229860 seconds elapsed, finished iteration 58
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] Iteration:59, valid_1 auc : 0.636852
# [LightGBM] [Info] 2.258592 seconds elapsed, finished iteration 59
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=9
# [LightGBM] [Info] Iteration:60, valid_1 auc : 0.637172
# [LightGBM] [Info] 2.291936 seconds elapsed, finished iteration 60
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=9
# [LightGBM] [Info] Iteration:61, valid_1 auc : 0.637412
# [LightGBM] [Info] 2.326252 seconds elapsed, finished iteration 61
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] Iteration:62, valid_1 auc : 0.637025
# [LightGBM] [Info] 2.364254 seconds elapsed, finished iteration 62
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] Iteration:63, valid_1 auc : 0.637554
# [LightGBM] [Info] 2.389842 seconds elapsed, finished iteration 63
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=9
# [LightGBM] [Info] Iteration:64, valid_1 auc : 0.637561
# [LightGBM] [Info] 2.425270 seconds elapsed, finished iteration 64
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=12
# [LightGBM] [Info] Iteration:65, valid_1 auc : 0.637323
# [LightGBM] [Info] 2.451315 seconds elapsed, finished iteration 65
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] Iteration:66, valid_1 auc : 0.637628
# [LightGBM] [Info] 2.481757 seconds elapsed, finished iteration 66
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] Iteration:67, valid_1 auc : 0.637597
# [LightGBM] [Info] 2.512034 seconds elapsed, finished iteration 67
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] Iteration:68, valid_1 auc : 0.638254
# [LightGBM] [Info] 2.543858 seconds elapsed, finished iteration 68
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=10
# [LightGBM] [Info] Iteration:69, valid_1 auc : 0.638454
# [LightGBM] [Info] 2.568386 seconds elapsed, finished iteration 69
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] Iteration:70, valid_1 auc : 0.638639
# [LightGBM] [Info] 2.600734 seconds elapsed, finished iteration 70
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] Iteration:71, valid_1 auc : 0.638547
# [LightGBM] [Info] 2.632533 seconds elapsed, finished iteration 71
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=10
# [LightGBM] [Info] Iteration:72, valid_1 auc : 0.63864
# [LightGBM] [Info] 2.668876 seconds elapsed, finished iteration 72
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=9
# [LightGBM] [Info] Iteration:73, valid_1 auc : 0.638255
# [LightGBM] [Info] 2.702063 seconds elapsed, finished iteration 73
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] Iteration:74, valid_1 auc : 0.638144
# [LightGBM] [Info] 2.736806 seconds elapsed, finished iteration 74
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] Iteration:75, valid_1 auc : 0.637218
# [LightGBM] [Info] 2.761478 seconds elapsed, finished iteration 75
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] Iteration:76, valid_1 auc : 0.637549
# [LightGBM] [Info] 2.792438 seconds elapsed, finished iteration 76
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=6
# [LightGBM] [Info] Iteration:77, valid_1 auc : 0.637483
# [LightGBM] [Info] 2.824312 seconds elapsed, finished iteration 77
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] Iteration:78, valid_1 auc : 0.638214
# [LightGBM] [Info] 2.859642 seconds elapsed, finished iteration 78
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=8
# [LightGBM] [Info] Iteration:79, valid_1 auc : 0.637981
# [LightGBM] [Info] 2.894983 seconds elapsed, finished iteration 79
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=7
# [LightGBM] [Info] Iteration:80, valid_1 auc : 0.637908
# [LightGBM] [Info] 2.925776 seconds elapsed, finished iteration 80
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=12
# [LightGBM] [Info] Iteration:81, valid_1 auc : 0.637957
# [LightGBM] [Info] 2.950179 seconds elapsed, finished iteration 81
# [LightGBM] [Info] Trained a tree with leaves=15 and max_depth=9
# [LightGBM] [Info] Iteration:82, valid_1 auc : 0.637856
# [LightGBM] [Info] Early stopping at iteration 82, the best iteration round is 72
# [LightGBM] [Info] Output of best iteration round:
# Iteration:72, valid_1 auc : 0.63864
#
# [LightGBM] [Info] 2.973528 seconds elapsed, finished iteration 82
# [LightGBM] [Info] Finished training

# %%
[LightGBM] [Info] Iteration:72, valid_1 auc : 0.63864

# %% [markdown]
# Итак, оптимальный классификатор имеет параметры:
# clf = GBMClassifier(
#         exec_path=exec_path,
#         min_data_in_leaf = 100,
#        # is_unbalance = True,
#         num_iterations = 300,
#         bagging_fraction = 1,
#         bagging_freq = 10,
#         num_leaves = 15,
#         learning_rate = 0.1,
#         metric = 'auc',
#         feature_fraction = 0.8,
#         early_stopping_round=10
#     )
# На кросс-валидации дает AUCROC 0.6096, на тесте 0.63864

# %%
clf = GBMClassifier(
        exec_path=exec_path,
        min_data_in_leaf=10,
       # is_unbalance = True,
        num_iterations = 50,
        bagging_fraction = 0.8,
        bagging_freq = 10,
        num_leaves = 127,
        metric = 'auc',
        early_stopping_round=10,
        verbose = False
)

#mean 0.61121 std 0.01024 params {'num_leaves' 15 'bagging_fraction' 1 'bagging_freq' 5 'min_data_in_leaf' 100 'feature_fraction' 0.8}
r = cv(clf, df_train[feat_cols].values, df_train[label].values, folds = 5, metrics = 'roc_auc,pr_auc')
np.mean(r['roc_auc']),
# Out:
# (0.59433845338847369,)

# %%
clf = GBMClassifier(
        exec_path=exec_path,
        min_data_in_leaf = 100,
       # is_unbalance = True,
        num_iterations = 120,
        bagging_fraction = 1,
        bagging_freq = 10,
        num_leaves = 63,
        learning_rate = 0.07,
        metric = 'auc',
        feature_fraction = 0.8,
        verbose = False
    )

#mean 0.61121 std 0.01024 params {'num_leaves' 15 'bagging_fraction' 1 'bagging_freq' 5 'min_data_in_leaf' 100 'feature_fraction' 0.8}
r = cv(clf, df_train[feat_cols].values, df_train[label].values, folds = 5, metrics = 'roc_auc,pr_auc')
np.mean(r['roc_auc']),
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-196-462a50f62ba1> in <module>()
#      14
#      15 #mean 0.61121 std 0.01024 params {'num_leaves' 15 'bagging_fraction' 1 'bagging_freq' 5 'min_data_in_leaf' 100 'feature_fraction' 0.8}
# ---> 16 r = cv(clf, df_train[feat_cols].values, df_train[label].values, folds = 5, metrics = 'roc_auc,pr_auc')
#      17 np.mean(r['roc_auc']),
#
# <ipython-input-180-b86aebd1ffde> in cv(clf, X, y, folds, metrics)
#      13         valid_idx = fold_idx[i]
#      14
# ---> 15         clf.fit(X[train_idx],y[train_idx])
#      16         valid_pred = clf.predict_proba(X[valid_idx])[:,1]
#      17
#
# /opt/anaconda/lib/python2.7/site-packages/pylightgbm/models.pyc in fit(self, X, y, test_data, init_scores)
#     136
#     137         with process.stdout:
# --> 138             for line in iter(process.stdout.readline, b''):
#     139                 print(line.strip().decode('utf-8')) if self.verbose else None
#     140         # wait for the subprocess to exit
#
# KeyboardInterrupt:

# %%
estimator = lgb.LGBMClassifier(nthread=3,silent=False)#,categorical_feature=[list(X_train).index(catFeature) for catFeature in categorical_features])

param_grid = {
    'learning_rate': [0.01, 0.05,0.02, 0.03,0.04],
    'n_estimators': [200,300,400,500,600],
    'num_leaves': [8],
    #'max_depth': [3,4],
    'boosting_type' : ['gbdt'],
    'objective' : ['binary'],
    'seed' : [777],
    'colsample_bytree' : [0.7,0.8,0.9,1],
    'subsample' : [0.7,0.8,0.9,1],
    'reg_alpha' : [0,0.1,0.5,1],
    'reg_lambda' : [0,1,2,5,6,7,9,10],
    'is_unbalance' : [True,False],
}

ngrid=2
gbm = RandomizedSearchCV(estimator, param_distributions=param_grid,
                                   n_iter=ngrid,cv=5,scoring='roc_auc')

gbm.fit(X_train, y_train)

# %% [markdown]
# ### Тематическое моделирование BigARTM

# %%
query = '''

-- Статистика урлфрагментов на обучающей выборке
create table user_kposminin.cred_app_urlfr_stat as 
select
  urlfr,
  count(distinct phone_mobile,call_ymd) as visitors_cnt
from
  user_kposminin.cred_app_visits
  where call_ymd < '2017-06-01'
group by urlfr
;



-- Формирование данных для BigARTM в задача cred_scoring
create table user_kposminin.cred_app_features_4_thematic_modelling as
select
  phone_mobile, 
  call_ymd, 
  concat_ws(' ',collect_list(concat(urlfr,':',hits))) as feat_hits,
  concat_ws(' ',collect_list(concat(urlfr,':',cnt))) as feat_cnt,
  concat_ws(' ',collect_list(concat(urlfr,':',1))) as feat_1,
  concat_ws(' ',collect_list(concat(urlfr,':',ymd_cnt))) as feat_ymd,
  sum(hits) as hits,
  sum(cnt) as cnt,
  max(ymd_cnt) as max_ymd_cnt
  
from
  (select 
    phone_mobile, 
    call_ymd, 
    max(default_flg) as default_flg,
    v.urlfr,
    count(*) as cnt,
    count(distinct ymd) as ymd_cnt,
    sum(cnt) as hits
  from user_kposminin.cred_app_visits v
  left join user_kposminin.cred_app_urlfr_stat st on st.urlfr = v.urlfr
  where coalesce(st.visitors_cnt,1000) > 300
  group by 
    phone_mobile, 
    call_ymd, 
    v.urlfr
  order by 
    phone_mobile, 
    call_ymd, 
    v.urlfr
  ) a  
group by 
  phone_mobile, 
  call_ymd
;



'''
