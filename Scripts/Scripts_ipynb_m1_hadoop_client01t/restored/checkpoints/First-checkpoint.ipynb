# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.DataFrame(1.00001 + np.random.randn(10**5,2)*0.01, columns = list('AB')).cumprod().plot()

# %%
a = 1
print(a)
# Out:
# 1

# %%
from pyspark import HiveContext
hc = HiveContext(sc)
rdd = hc.sql("select * from user_kposminin.test1").rdd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-a6285e6ac5e1> in <module>()
#       1 from pyspark import HiveContext
# ----> 2 hc = HiveContext(sc)
#       3 rdd = hc.sql("select * from user_kposminin.test1").rdd
#
# NameError: name 'sc' is not defined

# %%
sc
# Out:
# ''
