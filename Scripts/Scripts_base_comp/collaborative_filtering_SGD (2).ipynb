# %% [markdown]
# ## SVD модель интернет-логов. Выделение тем. ##
# Есть таблица интернет-логов  $m_{ij}$, каждая строка отвечает одному интернет-пользователю, каждый столбец - фрагменту урла. $m_{ij}=1$, если посетитель $i$ посетил фрагмент урла $j$ в рамках рассматриваемой сессии, иначе $m_{ij}=0$.
#
# Выделим темы - группировки урлов и пользователей. Для этого воспользуемся модификацией SVD разложения.
#
# Зафиксируем количество тем $K$. Для каждого пользователя сформируем вектор длины $K$, отражающий степень близости темы к пользователю (которая может быть отрицательной). Получаем матрицу $X_{ik}$. Индекс $i$ отвечает пользователю, $k$ отвечает теме.
#
# Аналогично сформируем вектор  длины $K$ для каждого фрагмента урла. Получаем матрицу $Y_{kj}$. $k$ отвечает теме, $j$ отвечает фрагменту урла.
#
# Далее для каждого пользователя $i$ введем число $a_i$, которое в целом характеризует его интернет-активность.
#
# Аналогично, элементы вектора $b_j$ отражают популярность урла $j$.
#
# Параметр $\mu$ есть усредняющий скаляр по всей выборке.
#
# Далее интерес пользователя  $i$ к фрагменту урла $j$ будем моделировать величиной $s_{ij} = \mu + a_i + b_j + \sum_k X_{ik} \cdot Y_{kj}$.
#
# Для перевода этой величины в вероятность, воспользуемся логистической функцией:
# $\hat{m}_{ij} = 1/(1+e^{-s_{ij}})$.
#
# Таким образом, построенная величина $\hat{m}_{ij}$ есть  модельная оценка вероятности посещения пользователем $i$ фрагмента урла $j$.
#
# Введем функцию ошибки $L = \sum_{ij} L_{ij} $,
# $$L_{ij} = -m_{ij} \cdot \ln(\hat{m}_{ij}) - (1 - m_{ij}) \cdot \ln(1 - \hat{m}_{ij}) + \lambda_{0} \cdot \mu + \lambda_{1}\cdot (a_i^2 + b_j^2) + \lambda_{2} \cdot \sum_k(X_{ik}^2 + Y_{kj}^2)$$.
#
# Для обучения будем использовать стохастический градиентный спуск.
# Следующий шаг - применять  модификацию  градиентного спуска - Adadelta http://int8.io/comparison-of-optimization-techniques-stochastic-gradient-descent-momentum-adagrad-and-adadelta/#AdaDelta_8211_implementation.

# %% [markdown]
# #####Конфигурация

# %%
#!/usr/bin/env python
#Config
from pyspark import SparkConf, SparkContext, HiveContext
#import re
import numpy as np
import pandas as pd
#import datetime
#from pyspark.mllib.regression import LabeledPoint
#from pyspark.mllib.feature import HashingTF
#from pyspark.mllib.classification import LogisticRegressionWithSGD, NaiveBayes, NaiveBayesModel
#import scipy.sparse as sps
#from pyspark.mllib.linalg import Vectors
#import sklearn
import itertools
import datetime
import sys


#from pyspark.mllib.recommendation import ALS, MatrixFactorizationModel, Rating

try:
    sc.stop()
except NameError:
    pass

conf = SparkConf().set("spark.executor.instances", 8).set("spark.driver.maxResultSize", "2g")
sc = SparkContext()
hc = HiveContext(sc)
sc.setCheckpointDir('checkpoint/')

# %% [markdown]
# ####Настройка параметров: $\lambda$ и шага

# %%
create_query ='''
create table user_kposminin.urlfr_dict as 
with src as (select * from user_kposminin.visits_ext where ymd = '2016-04-12')

select 
  urlfr, 
  rank() over (order by urlfr) as urlfr_num,
  count(*) as cnt 
from src 
group by urlfr 
having cnt > 500
;

create table user_kposminin.id_dict as 
with src as (select * from user_kposminin.visits_ext where ymd = '2016-04-12')
select 
  id,
  rank() over (order by id) as id_num,
  count(*) as cnt 
from src 
group by urlfr 
having cnt > 10 and cnt < 500
;

create_table user_kposminin.visits_enum_dense_20160412 as
with src as (select * from user_kposminin.visits_ext where ymd = '2016-04-12')
select
  s.id, i.id_num,
  s.urlfr, u.urlfr_num,
  s.cnt
from
  src s
  inner join user_kposminin.urlfr_dict u on s.urlfr = u.urlfr
  inner join user_kposminin.id_dict i on s.id = i.id
where 
u.cnt > 1000
and i.cnt > 30


'''

start_time = datetime.datetime.now()

# Param selection


query = '''
select id_num,urlfr_num from 
(select id_num,urlfr_num,count(*) over (partition by id_num) as uf_cnt,count(*) over (partition by urlfr_num) as id_cnt from user_kposminin.visits_enum_dense_20160412 
where id_num between 0 and 20000 ) a
where id_cnt > 15 and uf_cnt > 15
'''


K = 50
id_cnt = 20001
urlfr_cnt = 384000
epochs = 20


#lmbd = np.array([0.01, 0.01, 0.01])

#step = np.array([0.001, 0.005, 0.01])

param_grid = []

#   [[0.00001, 0.0001, 0.0001],[0.01, 0.05, 0.01]],
for base_step in np.exp(np.arange(-4,0,2)):
    for base_lmbd in np.exp(np.arange(-8,0,2)):
        for var_step in np.array([[0.001,1,1],[0.1,1,0.1]]):
            for var_lmbd in np.array([[0.0001,1,1],[0.01,0.1,1]]):
                param_grid.append([var_step * base_step,var_lmbd * base_lmbd])

lmbd_corr = np.ones(K) #np.exp(np.arange(-3,3,6./K))


# Load and parse the data
sampled_data = hc.sql(query) \
            .collect()
urlfr_cnt1 = len(set([e[1] for e in sampled_data])) + 1
id_cnt1 = len(set([e[0] for e in sampled_data])) + 1
print('Sampled data consists of {} rows, {} id and {} uf.'.format(len(sampled_data),id_cnt1,urlfr_cnt1))

train,test = [], []
for r in sampled_data:
    if(np.random.rand() < 0.1):
        test.append(r)
    else:
        train.append(r)
  
 
# prediction is m^hat_{ij} = 1/(1+exp(-s_{ij})) where s_{ij} = mu + a[i] + b[j] + sum_k (X[i,k] * Y[k,j])
# error function is L_{ij} = -m_{ij}*ln(m^hat_{ij}) - (1 - m_{ij})*ln(1 - m^hat_{ij}) + 
#                            lmbd[0] * mu + lmbd[1]*(a_i^2 + b_j^2) + lmbd[2]*sum_k(X_{ik}^2 + Y_{kj}^2)
f = open('data/collab_filter_SGD_param_tuning.csv','a+')
f.write('\n\n New calc at {}'.format(datetime.datetime.now()))
stat = []
prev_id = -1
uf_visited= []
neg_sig_share = 2
rho = 0.9
eps = 1e-6
errors = []
err_thres = 0.005

for step,lmbd in param_grid: # [[[0.0135,0.1353,0.0135],[1e-07,5e-03,5e-03]]]:

    #Init matrices
    mu = np.random.rand(1) - 0.5 - 1 # One-element array to be able to update inside a procedure
    a = np.random.rand(id_cnt) - 0.5
    b = np.random.rand(urlfr_cnt) - 0.5
    X = np.random.rand(id_cnt, K) - 0.5
    Y = np.random.rand(K,urlfr_cnt) - 0.5

    def make_step(i, j, v):
        s = mu[0] + a[i] + b[j] + X[i,:].dot(Y[:,j])
        pred = 1./(1+np.exp(-s))
        err = v - pred # r[2] - pred
        grad_mu = -err + lmbd[0] * mu
        grad_ai = -err + lmbd[1] * a[i]
        grad_bj = -err + lmbd[1] * b[j]
        grad_xi = -err * Y[:,j] + lmbd[2] * X[i,:] * lmbd_corr
        grad_yj = -err * X[i,:] + lmbd[2] * Y[:,j] * lmbd_corr
        
        # TODO Implement Adadelta SGD version. 
        #http://int8.io/comparison-of-optimization-techniques-stochastic-gradient-descent-momentum-adagrad-and-adadelta/#AdaDelta_8211_implementation
        # 
     
        mu[0] += - grad_mu[0] * step[0]
        a[i]  += - grad_ai * step[1]
        b[j]  += - grad_bj * step[1]
        X[i,:] = X[i,:] - grad_xi * step[2]
        Y[:,j] = Y[:,j] - grad_yj * step[2]
    
    for epoch in range(epochs):
        for r in train:
            i,j = r[:2]
            make_step(i, j, 1)
            if i == prev_id:
                uf_visited.append(j)
            else:
                # Add negative examples
                ni = np.random.randint(len(train) - len(uf_visited))
                neg, k = 0, 0
                while(neg < int(len(uf_visited) * neg_sig_share)):
                    if(not train[(ni + k) % len(train)][1] in uf_visited):                        
                        make_step(prev_id, train[(ni + k) % len(train)][1],0)
                        neg += 1
                    k +=1 
                prev_id = i
                uf_visited = [j]
        
        #calc err
        err1_p ,err2_p, err1_n, err2_n = 0, 0, 0, 0
        for r in test:
            i,j = r[:2]
            s = mu[0] + a[i] + b[j] + X[i,:].dot(Y[:,j])
            pred = 1/(1+np.exp(-s))
            err1_p += - 1 * np.log(pred) # r[2] - pred
            err2_p += - 1 * np.log(pred) + lmbd[0] * mu[0] + lmbd[1] * (a[i] ** 2 + b[j] ** 2) + lmbd[2] * (X[i,:].dot(X[i,:]*lmbd_corr) + Y[:,j].dot(Y[:,j]*lmbd_corr))
            
            if i == prev_id:
                uf_visited.append(j)
            else:
                # Add negative examples
                ni = np.random.randint(len(test) - len(uf_visited))
                neg, k = 0, 0
                while(neg < int(len(uf_visited) * neg_sig_share)):
                    if(not test[(ni + k) % len(test)][1] in uf_visited): 
                        i1, j1 = prev_id, train[(ni + k) % len(train)][1]
                        s = mu[0] + a[i1] + b[j1] + X[i1,:].dot(Y[:,j1])
                        pred = 1/(1+np.exp(-s))
                        err1_n += - 1 * np.log(1 - pred) # r[2] - pred
                        err2_n += - 1 * np.log(1 - pred) + lmbd[0] * mu[0] + lmbd[1] * (a[i1] ** 2 + b[j1] ** 2) + lmbd[2] * (X[i1,:].dot(X[i1,:]) + Y[:,j1].dot(Y[:,j1]))                        
                        neg += 1
                    k +=1 
                prev_id = i
                uf_visited = [j]
        err1_t = (err1_p + err1_n) / (len(test) * (neg_sig_share + 1))
        err2_t = (err2_p + err2_n) / (len(test) * (neg_sig_share + 1))
        err1_p /= float(len(test))
        err2_p /= float(len(test))
        err1_n /= len(test) * neg_sig_share
        err2_n /= len(test) * neg_sig_share        
        errors.append(err1_t)
        stat=('{} ' * 9).format(step,lmbd,epoch,err1_t, err1_p,err1_n,err2_t, err2_p,err2_n)
        f.write(stat + '\n')
        print(stat)
        if((len(errors)>6) & (sum(errors[-3:])/3 > sum(errors[-6:-3])/3 - err_thres)): # too fast.
            step = [s * 0.7 for s in step]
        if((len(errors)>13) & (abs(sum(errors[-3:])/3 - sum(errors[-13:-3])/10) < 1e-4)): # too slow.
            step = [s / 0.6 for s in step]
        
        
print('Finish. Work time {}.'.format(datetime.datetime.now()- start_time))
f.write('\nFinish at {}. Work time {}.\n\n\n'.format(datetime.datetime.now(),datetime.datetime.now() - start_time))
f.close()

# %% [markdown]
# ####Выбираем уплотненную подвыбрку логов: пользователей с длиной трека более 40 и фрагментов урлов с более, чем 500 уникальными посетителями в день.
# ####Обучаемся на этой выборке.
# ####В силу ограничения по памяти, обучение осуществляется пачками по 10 тыс пользователей с небольшим количеством эпох на пачку. Скорость довольно небольшая: за день обрабатывается ~ 100 пачек.
# #### Моделируем 40 тем.

# %%
K = 40

full_train_epochs = 8
batch_size = 10000
err_thres = 0.005
step, lmbd = [1e-05,0.015,0.015], [1e-08,3e-04,3e-03]
step = [e/2 for e in step]
#2,2745801053577491e-05,	0,022745801053577486,	0,022745801		2,48E-05	2,48E-04	2,48E-03


urlfr_cnt = hc.sql('select max(urlfr_num) from user_kposminin.visits_enum_dense_20160412').collect()[0][0] + 10
err = []
f = open('data/collab_filter_SGD_calc.csv','a+')
af = open('data/collab_filter_SGD_a_vec.csv','w')
Xf = open('data/collab_filter_SGD_X_matr.csv','w')

#mu = np.random.rand(1) - 0.5 - 2 # One-element array to be able to update inside a procedure
#b = np.random.rand(urlfr_cnt) - 0.5
#Y = np.random.rand(K,urlfr_cnt) - 0.5

lmbd_corr = np.ones(K) #np.exp(np.arange(-3,3,6./K))

query1 = '''
select id_num,urlfr_num from user_kposminin.visits_enum_dense_20160412 
where id_num between #low and #high
'''

for btc in range(479, 180*10**6/batch_size):

    # Load and parse the data
    train, test = hc.sql(query1.replace('#low',str(btc*batch_size)).replace('#high',str((btc + 1) * batch_size - 1))) \
            .randomSplit([0.9,0.1])
    train = train.collect()
    test  =  test.collect()
    if(len(train) == 0): break
    str2write = '{}. Num {}. Sampled train data consists of {} rows, {} id and {} uf.\n'.format(
                                datetime.datetime.now(),
                                btc, 
                                len(train),len(set([e[0] for e in train])), len(set([e[1] for e in train])))
    print(str2write)
    f.write(str2write)
    id_start = btc*batch_size
    
    id_cnt = batch_size
    stat = []
    prev_id = -1
    uf_visited= []
    neg_sig_share = 2
    cnt = 0
    
    #Init matrices
    a = np.random.rand(id_cnt) - 0.5
    X = np.random.rand(id_cnt, K) - 0.5

    def make_step(i, j, v):
        s = mu[0] + a[i] + b[j] + X[i,:].dot(Y[:,j])
        pred = 1./(1+np.exp(-s))
        err = v - pred # r[2] - pred
        grad_mu = -err + lmbd[0] * mu
        grad_ai = -err + lmbd[1] * a[i]
        grad_bj = -err + lmbd[1] * b[j]
        grad_xi = -err * Y[:,j] + lmbd[2] * X[i,:] * lmbd_corr
        grad_yj = -err * X[i,:] + lmbd[2] * Y[:,j] * lmbd_corr
        mu[0] += - grad_mu[0] * step[0]
        a[i]  += - grad_ai * step[1]
        b[j]  += - grad_bj * step[1]
        X[i,:] = X[i,:] - grad_xi * step[2]
        Y[:,j] = Y[:,j] - grad_yj * step[2]
    
    for epoch in range(full_train_epochs):
        for r in train:
            i,j = r[0] - id_start, r[1]
            make_step(i, j, 1)
            if i == prev_id:
                uf_visited.append(j)
            else:
                # Add negative examples
                ni = np.random.randint(len(train) - len(uf_visited))
                neg, k = 0, 0
                while(neg < int(len(uf_visited) * neg_sig_share)):
                    if(not train[(ni + k) % len(train)][1] in uf_visited):                        
                        make_step(prev_id, train[(ni + k) % len(train)][1],0)
                        neg += 1
                    k +=1
                prev_id = i
                uf_visited = [j]
        
        #calc err
        err1_p ,err2_p, err1_n, err2_n = 0, 0, 0, 0
        for r in test:
            i,j = r[0] - id_start, r[1]
            s = mu[0] + a[i] + b[j] + X[i,:].dot(Y[:,j])
            pred = 1/(1+np.exp(-s))
            err1_p += - 1 * np.log(pred) # r[2] - pred
            err2_p += - 1 * np.log(pred) + lmbd[0] * mu[0] + lmbd[1] * (a[i] ** 2 + b[j] ** 2) + lmbd[2] * (X[i,:].dot(X[i,:]*lmbd_corr) + Y[:,j].dot(Y[:,j]*lmbd_corr))
            
            if i == prev_id:
                uf_visited.append(j)
            else:
                # Add negative examples
                ni = np.random.randint(len(test) - len(uf_visited))
                neg, k = 0, 0
                while(neg < int(len(uf_visited) * neg_sig_share)):
                    if(not test[(ni + k) % len(test)][1] in uf_visited): 
                        i1, j1 = prev_id, train[(ni + k) % len(train)][1]
                        s = mu[0] + a[i1] + b[j1] + X[i1,:].dot(Y[:,j1])
                        pred = 1/(1+np.exp(-s))
                        err1_n += - 1 * np.log(1 - pred) # r[2] - pred
                        err2_n += - 1 * np.log(1 - pred) + lmbd[0] * mu[0] + lmbd[1] * (a[i] ** 2 + b[j] ** 2) + lmbd[2] * (X[i,:].dot(X[i,:]*lmbd_corr) + Y[:,j].dot(Y[:,j]*lmbd_corr))
                        neg += 1
                    k +=1 
                prev_id = i
                uf_visited = [j]
        err1_t = (err1_p + err1_n) / (len(test) * (neg_sig_share + 1))
        err2_t = (err2_p + err2_n) / (len(test) * (neg_sig_share + 1))
        err1_p /= float(len(test))
        err2_p /= float(len(test))
        err1_n /= len(test) * neg_sig_share
        err2_n /= len(test) * neg_sig_share        
        err.append(err1_t)
        stat=('{} ' * 9).format(step,lmbd,epoch,err1_t, err1_p,err1_n,err2_t, err2_p,err2_n)
        f.write(stat + '\n')
        print(stat)
        cnt += 1
        if((cnt > 15) & (sum(err[-3:])/3 > sum(err[-6:-3])/3 - err_thres)): # too fast.
            step = [s * 0.6 for s in step]
            cnt = 0 
        #if((len(err) > 15) & (abs(sum(err[-3:])/3 - sum(err[-13:-3])/10) < 1e-5)): # too slow.
        #    step = [s / 0.6 for s in step]
                    
    for r in test:
        i,j = r[0] - id_start, r[1]
        make_step(i, j, 1)
        
    l = 0
    for e in a:
        af.write('{},{}\n'.format(id_start + l,a[l]))
        l+=1
    l = 0
    for e in X:
        Xf.write('{},{}\n'.format(id_start + l,','.join(str(z) for z in X[l])))
        l+=1
l=0            
Yf = open('data/collab_filter_SGD_Y_matr.csv','w')
for e in Y:
    Yf.write('{},{}\n'.format(l,','.join(str(z) for z in Y[l])))
    l+=1
l=0            
bf = open('data/collab_filter_SGD_b_vec.csv','w')
for e in b:
    bf.write('{},{}\n'.format(l,b[l]))
    l+=1

f.write('mu is {}'.format(mu))

print('Finish. Work time {}.'.format(datetime.datetime.now() - start_time))
f.write('\nFinish at {}. Work time {}.\n\n\n'.format(datetime.datetime.now(),datetime.datetime.now() - start_time))
f.close()
# Out:
# 2016-12-13 19:29:33.593169. Num 479. Sampled train data consists of 137082 rows, 4292 id and 48747 uf.
#
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 0 0.549562582885 0.979382546857 0.3346526009 0.5981928477 1.02876783692 0.38290535309
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 1 0.484962321428 0.768282037311 0.343302463486 0.533783779888 0.81792563842 0.391712850622
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 2 0.446318339193 0.679947289667 0.329503863956 0.495815224995 0.730284790957 0.378580442014
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 3 0.421276280334 0.625556533027 0.319136153988 0.471690653051 0.676802233903 0.369134862625
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 4 0.403390550712 0.596859295757 0.30665617819 0.454709030055 0.648973344678 0.357576872744
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 5 0.396834209848 0.574949328273 0.307776650635 0.44911327274 0.627988047397 0.359675885412
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 6 0.381778992634 0.563015170502 0.291160903699 0.43494233744 0.616903424357 0.343961793981
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 7 0.371900832806 0.548377020316 0.283662739051 0.425961435466 0.603158764599 0.3373627709
# 2016-12-13 19:43:13.435600. Num 480. Sampled train data consists of 140509 rows, 4377 id and 49844 uf.
#
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 0 0.553701313851 1.02351958641 0.318792177573 0.602724324559 1.07359067957 0.367291147055
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 1 0.478924754064 0.78477674094 0.325998760627 0.527888549455 0.834908199427 0.37437872447
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 2 0.447827231848 0.691217024644 0.32613233545 0.497301810265 0.741863880886 0.375020774954
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 3 0
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 6 0.359375530391 0.533639474052 0.272243558561 0.416646855206 0.591977058546 0.328981753536
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 7 0.35276430241 0.513332015548 0.272480445841 0.410821855163 0.572420490097 0.330022537696
# 2016-12-16 10:54:01.945790. Num 752. Sampled train data consists of 138828 rows, 4376 id and 48658 uf.
#
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 0 0.546435304016 1.0294587556 0.304923578226 0.600430350588 1.08417403845 0.358558506655
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 1 0.468781053042 0.761536820254 0.322403169436 0.522634304331 0.816248275356 0.375827318818
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 2 0.43059987304 0.655669401067 0.318065109027 0.484959855592 0.71088133083 0.371999117973
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 3 0.401278947043 0.60267469427 0.300581073429 0.456327185408 0.658540270587 0.355220642819
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 4 0.391884848537 0.564806706473 0.305423919569 0.447760622996 0.621456566858 0.360912651065
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 5 0.370623916548 0.550562999303 0.280654375171 0.427340297554 0.60798167157 0.337019610546
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 6 0.370626329273 0.529492692507 0.291193147656 0.428148137808 0.5876593547 0.348392529361
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 7 0.361573192337 0.521065901873 0.281826837569 0.419767199544 0.579902544755 0.339699526938
# 2016-12-16 11:07:49.580623. Num 753. Sampled train data consists of 139612 rows, 4371 id and 48963 uf.
#
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 0 0.551155638584 1.05190276847 0.30078207364 0.604526890628 1.10615261423 0.353714028826
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 1 0.470241746881 0.78855550108 0.311084869782 0.523519723264 0.842824089746 0.363867540023
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 2 0.434058945662 0.683042230599 0.309567303193 0.487821760961 0.737825838251 0.362819722316
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 3 0.406588786351 0.617337507292 0.301214425881 0.461107840692 0.672876661766 0.355223430155
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 4 0.397726538489 0.58496265803 0.304108478719 0.453046925425 0.641272679382 0.358934048447
# [5e-06, 0.0075, 0.0075] [1e-08, 0.0003, 0.003] 5 0.379505109624 0.561610958899 0.288452184986 0.435624531611 0.618695394608 0.344089100113
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-732c284ee446> in <module>()
#      70         for r in train:
#      71             i,j = r[0] - id_start, r[1]
# ---> 72             make_step(i, j, 1)
#      73             if i == prev_id:
#      74                 uf_visited.append(j)
#
# <ipython-input-29-732c284ee446> in make_step(i, j, v)
#      54     def make_step(i, j, v):
#      55         s = mu[0] + a[i] + b[j] + X[i,:].dot(Y[:,j])
# ---> 56         pred = 1./(1+np.exp(-s))
#      57         err = v - pred # r[2] - pred
#      58         grad_mu = -err + lmbd[0] * mu
#
# KeyboardInterrupt:

# %%
#Save results
l=0            
Yf = open('data/collab_filter_SGD_Y_matr.csv','w')
for e in Y:
    Yf.write('{},{}\n'.format(l,','.join(str(z) for z in Y[l])))
    l+=1
l=0            
bf = open('data/collab_filter_SGD_b_vec.csv','w')
for e in b:
    bf.write('{},{}\n'.format(l,b[l]))
    l+=1

f.write('mu is {}'.format(mu))

#print('Finish. Work time {}.'.format(datetime.datetime.now() - start_time))

# %%
#print('mu is {}'.format(mu))
#Y.shape
#Yb = np.insert(Y, 0, b, axis=0)
#Yb = np.insert(Yb, 0, 1, axis=0)
# Out:
# array([-1.57808301])

# %%
def cos_dist(Y, i,j):
    return 1 - Y[:,i].dot(Y[:,j]) / (( Y[:,i].dot(Y[:,i]) * Y[:,j].dot(Y[:,j])) ** 0.5 )

# %%
uf_dict = hc.sql('select * from user_kposminin.urlfr_dict').toPandas().set_index('urlfr_num')

# %%
#uf_dict[uf_dict['urlfr'].map(lambda v: 'gdz' in v)].sort('cnt')
uf_dict[uf_dict['urlfr'] == 'filkos.com#'].cnt.iloc[0]
# Out:
# 7536

# %%
#uf_dict[uf_dict['urlfr'].map(lambda v: up in v)]
def neighbours(urlfr, Yb,uf_dict, k = 20):
    num = uf_dict[uf_dict['urlfr'] == up].index[0]
    dists1 = sorted([[cos_dist(Yb,num,i),i] for i in range(Yb.shape[1])])
    return [[e[0],uf_dict.loc[e[1],'urlfr']] for e in dists1[:k]]

# %%
k = 100
for up in ['raiffeisen.ru#consumerloans','filkos.com#','auto.exist.ru#','vedomosti.ru#business','gdz-putina.me#']:
    print('\n' + '-' * 100 + '\n\nNearest {} neighbours for {} ({} long-track* visitors per day):\n\n{:<10}\t{:<30}\n'.format(
            k, up, uf_dict[uf_dict['urlfr'] == up].cnt.iloc[0],'distance','urrlfr'))
    print('\n'.join(['{:<10.5f}\t{:<30}'.format(e[0],e[1].encode('utf-8')) for e in neighbours(up, Yb,uf_dict, k = 100)]))
print('\nLong-track visitors = visitors with at least 40 distinct urlfr visited for a day.')
# Out:
# ----------------------------------------------------------------------------------------------------
#
# Nearest 100 neighbours for raiffeisen.ru#consumerloans (7536 long-track* visitors per day):
#
# distance  	urrlfr
#
# 0.00000   	raiffeisen.ru#consumerloans
# 0.05604   	raiffeisen.ru#product
# 0.05767   	raiffeisen.ru#request
# 0.09010   	raiffeisen.ru#retail
# 0.13280   	wiki-numbers.ru#
# 0.13930   	nizhniynovgorod.irr.ru#search
# 0.15566   	cabinet.mirkvartir.ru#
# 0.15886   	fssprus.ru#phonebook
# 0.16205   	metaprom.ru#
# 0.16288   	klenmarket.ru#shop
# 0.16289   	oplatagosuslug.ru#
# 0.16329   	fssprus.ru#ip
# 0.16409   	rokvel.ru#
# 0.16417   	ati.su#ShowForum.aspx
# 0.16505   	avito.ru#ofis
# 0.16703   	fssprus.ru#
# 0.16850   	fssprus.ru#int_help
# 0.16853   	fssprus.ru#iss
# 0.16992   	homes.gilcom.ru#
# 0.17100   	oplatagosuslug.ru#main
# 0.17133   	klenmarket.ru#equipment
# 0.17298   	mirkvartir.ru#фотографии
# 0.17353   	balashikha.cian.ru#
# 0.17374   	domofond.ru#kvartira-na-prodazhu
# 0.17375   	cian.ru#commercial
# 0.17536   	stroyportal.ru#
# 0.17564   	wiki-numbers.ru#world
# 0.17584   	domofond.ru#novostroiki
# 0.17607   	irr.ru#searchads
# 0.17648   	theservice.ru#
# 0.17694   	wiki-numbers.ru#russia
# 0.17704   	beboss.ru#kn
# 0.17795   	rosrealt.ru#kommercheskaja
# 0.17863   	dorus.ru#
# 0.17894   	fssprus.ru#torgi
# 0.17935   	irr.ru#account
# 0.17959   	rosrealt.ru#myrosrealt.php
# 0.17964   	ati.su#Media
# 0.18166   	net-agenta.ru#
# 0.18184   	perevozka24.ru#
# 0.18211   	dorus.ru#success.php
# 0.18326   	ati.su#Trace
# 0.18356   	ati.su#Forum
# 0.18368   	klenmarket.ru#
# 0.18393   	domofond.ru#karta
# 0.18420   	mirkvartir.ru#
# 0.18444   	tenderguru.ru#
# 0.18482   	irr.ru#login
# 0.18513   	gibdd.ru#blanks
# 0.18514   	dalnoboi.ru#viewtopic.php
# 0.18541   	gibdd.ru#fines
# 0.18652   	beboss.ru#
# 0.18675   	ndv77.ru#
# 0.18699   	krasnodar.hh.ru#advanced
# 0.18702   	domofond.ru#rasmestit-obyavlenie
# 0.18724   	moskva.gde.ru#
# 0.18797   	domofond.ru#statya
# 0.18823   	samara.pulscen.ru#
# 0.18829   	dorus.ru#service.html
# 0.18830   	rusprofile.ru#
# 0.18854   	samara.tiu.ru#
# 0.18879   	irr.ru#items
# 0.18948   	kazan.irr.ru#
# 0.18982   	ati.su#Article.aspx
# 0.19000   	wiki-numbers.ru#phone
# 0.19024   	balashikha.cian.ru#sale
# 0.19072   	chel.pulscen.ru#
# 0.19077   	tiu.ru#list
# 0.19111   	irr.ru#moskva-gorod
# 0.19152   	irr.ru#editadvert
# 0.19163   	sibdom.ru#board
# 0.19274   	raiffeisen.ru#
# 0.19303   	pddmaster.ru#poleznye-sovety
# 0.19326   	gibdd.ru#about
# 0.19337   	gde.ru#
# 0.19352   	gilcom.ru#
# 0.19390   	ufa.pulscen.ru#products
# 0.19392   	afy.ru#
# 0.19413   	avito.ru#proizvodstvo
# 0.19417   	stroyportal.ru#profile
# 0.19450   	restate.ru#base
# 0.19455   	saint-petersburg.irr.ru#list=list
# 0.19475   	metaprom.ru#companies
# 0.19492   	my.tiu.ru#user
# 0.19571   	ramenskoye.cian.ru#
# 0.19588   	ati.su#Office
# 0.19601   	ati.su#ExtraAuth.aspx
# 0.19611   	stroyka74.ru#
# 0.19636   	wiki-numbers.ru#operator
# 0.19658   	kbm-osago.ru#
# 0.19676   	irr.ru#step1
# 0.19679   	actez.ru#company
# 0.19690   	yecom.ru#
# 0.19791   	mirkvartir.ru#Однокомнатные
# 0.19797   	neagent.info#
# 0.19908   	roszem.ru#
# 0.19917   	ati.su#OldSearch.aspx
# 0.19927   	meatinfo.ru#
# 0.19930   	nizhniynovgorod.irr.ru#
# 0.19934   	ati.su#Topic.aspx
#
# ----------------------------------------------------------------------------------------------------
#
# Nearest 100 neighbours for filkos.com# (5548 long-track* visitors per day):
#
# distance  	urrlfr
#
# 0.00000   	filkos.com#
# 0.05216   	filkos.com#credit.html
# 0.08512   	bank-advisor.ru#
# 0.15189   	bank-advisor.ru#offers
# 0.18430   	rusprofile.ru#sectors
# 0.19179   	ify.ru#
# 0.19466   	rus-trip.ru#
# 0.20045   	bank-advisor.ru#renessans
# 0.21081   	bazarpnz.ru#add.php
# 0.22096   	krs.rosrabota.ru#21.Без.опыта,.подработка,.стажировки,.прочее
# 0.22219   	cashalot.su#registration
# 0.22802   	rabota.gorodaonline.com#
# 0.23289   	ati.su#Login.aspx
# 0.23404   	dorus.ru#
# 0.23469   	rabota33.ru#
# 0.23483   	omsk.mlsn.ru#user
# 0.23507   	secure.domadengi.ru#
# 0.23554   	dorus.ru#success.php
# 0.23697   	pticevod.com#
# 0.23852   	uraljob.ru#
# 0.23974   	yaroslavl.tiu.ru#
# 0.24021   	job24.com.ru#index
# 0.24075   	uraljob.ru#cntr.php
# 0.24378   	бесплатныеобъявления.рф#
# 0.24418   	surgut.zarplata.ru#
# 0.24458   	bazarpnz.ru#predlagaem_rabotu
# 0.24498   	neagent.info#base
# 0.24667   	forums.kuban.ru#f1032
# 0.24682   	secure.domadengi.ru#1850
# 0.24733   	buyreklama.ru#
# 0.24808   	dorus.ru#add.html
# 0.24834   	careerix.ru#linkvac.php
# 0.25016   	sredstva.ru#credit
# 0.25062   	gorkvartira.ru#object
# 0.25075   	gde.ru#
# 0.25119   	propokupki.ru#
# 0.25173   	ir-center.ru#work
# 0.25277   	neagent.info#prodazha
# 0.25289   	secure.domadengi.ru#partners
# 0.25322   	rozshuk.ru#phones
# 0.25328   	astrakhan.zarplata.ru#vacancy
# 0.25453   	nizhnevartovsk.yarmarka.biz#
# 0.25493   	wszone.ru#
# 0.25544   	ubu.ru#ads
# 0.25594   	infapronet.ru#
# 0.25610   	szn-ural.ru#cardvac.aspx
# 0.25733   	szn-ural.ru#home
# 0.25960   	neagent.info#
# 0.26035   	rus-trip.ru#karta
# 0.26060   	krs.zarplata.ru#vacancies
# 0.26083   	krasnodar.nashaspravka.ru#
# 0.26109   	arenda.mirkvartir.ru#Московская область
# 0.26359   	arenda.mirkvartir.ru#
# 0.26362   	omsk.irr.ru#
# 0.26367   	bazarpnz.ru#rabota
# 0.26368   	forum.9111.ru#
# 0.26468   	ligakvartir.ru#
# 0.26472   	astrakhan.zarplata.ru#
# 0.26482   	tyumen.superjob.ru#
# 0.26547   	dorus.ru#service.html
# 0.26713   	ubu.ru#add
# 0.26745   	krs.zarplata.ru#company
# 0.26754   	chelyabinsk.superjob.ru#
# 0.26795   	krasnodar.blizko.ru#products
# 0.26847   	novorosjob.ru#
# 0.26861   	krasnoyarsk.superjob.ru#vakansii
# 0.26917   	yuga-build.ru#
# 0.26941   	gorod55.ru#detail
# 0.26967   	mapdata.ru#
# 0.26968   	job24.com.ru#rabota_vakhtoj_v_gazprome
# 0.26977   	kras.rosrabota.ru#
# 0.27125   	regtorg.ru#
# 0.27295   	careerix.ru#
# 0.27325   	forum.mamaabakana.ru#sp
# 0.27359   	bazarpnz.ru#nedvizhimost
# 0.27360   	krasnodar.superjob.ru#vakansii
# 0.27394   	2gis.ru#lipetsk
# 0.27427   	avtodispetcher.ru#
# 0.27451   	edumarket.ru#offer.php
# 0.27462   	credity5.ru#
# 0.27507   	krs.zarplata.ru#view
# 0.27571   	forum.9111.ru#topic.php
# 0.27605   	rjb.ru#
# 0.27629   	vahtabank.ru#
# 0.27675   	perevozka24.ru#
# 0.27699   	yarmarka-ryazan.ru#
# 0.27708   	cmlt.ru#select-rubric
# 0.27709   	krasnodar.trud.com#jobs
# 0.27720   	mxkr.ru#
# 0.27727   	bizspravka.su#search
# 0.27745   	ufz-kemerovo.ru#ishyraboty
# 0.27757   	mxkr.ru#ru
# 0.27764   	nizhnevartovsk.yarmarka.biz#nizhnevartovsk
# 0.27813   	szn-ural.ru#
# 0.27814   	kreditnyi-calculator.ru#credit
# 0.27865   	krs.rosrabota.ru#vac-branch-tag
# 0.27888   	wszone.ru#firmy
# 0.27907   	pressa-online.com#140
# 0.27966   	penza.superjob.ru#
# 0.28034   	prm.estrabota.ru#
#
# ----------------------------------------------------------------------------------------------------
#
# Nearest 100 neighbours for auto.exist.ru# (5146 long-track* visitors per day):
#
# distance  	urrlfr
#
# 0.00000   	auto.exist.ru#
# 0.05338   	autobody.ru#
# 0.05884   	koreanaparts.ru#partsearch
# 0.05919   	citroens-club.ru#forum
# 0.05951   	voloton.ru#
# 0.06177   	koreanaparts.ru#
# 0.06224   	autodoc.ru#
# 0.06256   	autodoc.ru#brand
# 0.06260   	euroauto.ru#part
# 0.06265   	autodoc.ru#part
# 0.06278   	voloton.ru#price
# 0.06303   	euroauto.ru#all
# 0.06413   	autodoc.ru#RepresentInfo.aspx
# 0.06498   	autodoc.ru#art
# 0.06656   	ferio.ru#zapchasti
# 0.06802   	autodoc.ru#price
# 0.06858   	autodoc.ru#Web
# 0.06943   	elcats.ru#hyundai
# 0.06976   	autobody.ru#catalog
# 0.06977   	tyres.spb.ru#
# 0.07013   	autodoc.ru#index
# 0.07030   	autodoc.ru#Pages
# 0.07032   	elcats.ru#Modification.aspx
# 0.07038   	евроавто.рф#parts
# 0.07096   	4tochki.ru#catalog
# 0.07106   	elcats.ru#kia
# 0.07218   	out-club.ru#showthread.php
# 0.07266   	autodoc.ru#CatalogOriginal.aspx
# 0.07301   	евроавто.рф#
# 0.07399   	plentycar.ru#autopart
# 0.07422   	rmsauto.ru#
# 0.07437   	autodoc.ru#BalanceForm.aspx
# 0.07490   	out-club.ru#board
# 0.07493   	koreanaparts.ru#product
# 0.07503   	euroauto.ru#used
# 0.07570   	euroauto.ru#cars
# 0.07585   	autodoc.ru#ordersSubClients.aspx
# 0.07596   	autozap.ru#catalog
# 0.07662   	plentycar.ru#
# 0.07670   	3139393.ru#
# 0.07692   	japancats.ru#NISSAN
# 0.07696   	3139393.ru#catalog
# 0.07705   	sti-club.su#
# 0.07720   	japancats.ru#VIN.aspx
# 0.07723   	elcats.ru#volvo
# 0.07758   	euroauto.ru#
# 0.07766   	autodoc.ru#catalogs
# 0.07767   	mosautoshina.ru#tyre
# 0.07770   	japancats.ru#
# 0.07779   	чинамобил.рф#
# 0.07788   	euroauto.ru#new
# 0.07795   	euroauto.ru#auto
# 0.07830   	euroauto.ru#firms
# 0.07847   	autodoc.ru#CatalogInfo
# 0.07881   	elcats.ru#audi
# 0.07887   	евроавто.рф#used
# 0.07942   	mosautoshina.ru#catalog
# 0.07947   	japancats.ru#nissan
# 0.07983   	autodoc.ru#LogOnPage
# 0.08015   	autodoc.ru#manufacturer792
# 0.08018   	autodoc.ru#HYUNDAI-KIA
# 0.08048   	autodoc.ru#manufacturer647
# 0.08060   	autozap.ru#
# 0.08108   	autodoc.ru#manufacturer555
# 0.08145   	autodoc.ru#AllAuto.aspx
# 0.08174   	prado-club.su#
# 0.08203   	s-shina.ru#
# 0.08227   	euroauto.ru#kuzov_naruzhnie_elementi
# 0.08239   	elcats.ru#chevrolet
# 0.08308   	4rn.ru#
# 0.08328   	elcats.ru#Options.aspx
# 0.08337   	mosautoshina.ru#
# 0.08360   	citroens-club.ru#
# 0.08362   	autodoc.ru#Catalogs
# 0.08400   	elcats.ru#CLogin.aspx
# 0.08407   	elcats.ru#renault
# 0.08416   	itrade.forum-auto.ru#paids.html
# 0.08418   	out-club.ru#
# 0.08457   	авторазбор.рф#
# 0.08468   	autodoc.ru#GetVehicleByVin
# 0.08474   	shinaexpert.ru#
# 0.08502   	elcats.ru#Registration
# 0.08506   	sa.ru#filter
# 0.08507   	japancats.ru#Modification.aspx
# 0.08536   	autodoc.ru#GetDetailsByUnitAndVin
# 0.08547   	sa.ru#
# 0.08556   	autodoc.ru#Index
# 0.08586   	elcats.ru#
# 0.08599   	autodoc.ru#CartForm.aspx
# 0.08602   	transakpp.ru#
# 0.08634   	elcats.ru#ford
# 0.08664   	relines.ru#
# 0.08668   	s-shina.ru#tyre
# 0.08697   	4tochki.ru#
# 0.08713   	4rn.ru#catalog
# 0.08719   	autodoc.ru#manufacturer558
# 0.08733   	astraclub.ru#threads
# 0.08735   	autodoc.ru#manufacturer657
# 0.08745   	gmsklad.ru#
# 0.08773   	japancats.ru#mitsubishi
#
# ----------------------------------------------------------------------------------------------------
#
# Nearest 100 neighbours for vedomosti.ru#business (21768 long-track* visitors per day):
#
# distance  	urrlfr
#
# 0.00000   	vedomosti.ru#business
# 0.02319   	vedomosti.ru#economics
# 0.02439   	vedomosti.ru#11
# 0.02486   	vedomosti.ru#finance
# 0.03039   	vedomosti.ru#rubrics
# 0.03116   	vedomosti.ru#realty
# 0.03322   	vedomosti.ru#technology
# 0.04144   	vedomosti.ru#galleries
# 0.04311   	vedomosti.ru#opinion
# 0.04426   	vedomosti.ru#articles
# 0.04841   	vedomosti.ru#10
# 0.05020   	vedomosti.ru#2015
# 0.05183   	vedomosti.ru#
# 0.05438   	vedomosti.ru#03
# 0.05441   	vedomosti.ru#comments
# 0.05478   	vedomosti.ru#08
# 0.05484   	vedomosti.ru#newspaper
# 0.05583   	vedomosti.ru#637320-rogozin-kvartiri
# 0.05803   	vedomosti.ru#05
# 0.06009   	vedomosti.ru#637361-banknoti-nominalom-200-i-2000-rublei
# 0.06162   	vedomosti.ru#02
# 0.06215   	vedomosti.ru#2016
# 0.06454   	vedomosti.ru#04
# 0.06682   	vedomosti.ru#newsline
# 0.06908   	vedomosti.ru#07
# 0.07243   	vedomosti.ru#12
# 0.07356   	vedomosti.ru#video
# 0.07397   	vedomosti.ru#news
# 0.07446   	vedomosti.ru#637312-razoblachitelnii-film-navalnom-reaktsiya-panamskoe-dose-uvereni-eksperti
# 0.07521   	vedomosti.ru#637413-saudovskaya-araviya-rossiya
# 0.07878   	vedomosti.ru#top
# 0.08244   	vedomosti.ru#637358-sobstvenniki-zhilya-zabirat-vznosi-kapremont
# 0.08421   	vedomosti.ru#2014
# 0.08622   	vedomosti.ru#auto
# 0.08636   	vedomosti.ru#637398-moskve-obyavlena-pervaya-stepen
# 0.08640   	vedomosti.ru#lifestyle
# 0.08756   	vedomosti.ru#637254-chechnya-propustit
# 0.08880   	vedomosti.ru#01
# 0.09072   	vedomosti.ru#637349-sirii-mi-28
# 0.09103   	vedomosti.ru#637396-dergunova-osvobozhdena
# 0.09474   	vedomosti.ru#politics
# 0.09522   	vedomosti.ru#23
# 0.09963   	vedomosti.ru#637346-razbilsya-mi-28
# 0.10080   	vedomosti.ru#637429-obyavleni-okonchatelnie-itogi-referenduma
# 0.10131   	vedomosti.ru#06
# 0.10165   	vedomosti.ru#637352-pochti-600-000-rossiyan-na-grani-bankrotstva
# 0.10866   	kommersant.ru#gallery
# 0.11018   	vedomosti.ru#637321-ukrainskogo-pravitelstva
# 0.11194   	vedomosti.ru#637358-ks-podtverdil-kapitalnii
# 0.11561   	vedomosti.ru#management
# 0.11992   	kommersant.ru#rubric
# 0.12255   	vedomosti.ru#2013
# 0.12616   	vedomosti.ru#637423-kasyanov-otkazalsya-snyatsya
# 0.12730   	vedomosti.ru#637356-peskov-grizlova-soveta-bezopasnosti
# 0.12888   	vedomosti.ru#637243-bankir-avdeev-pivo-pered-marafonom
# 0.12903   	finmarket.ru#news
# 0.12928   	kommersant.ru#2961866
# 0.13063   	vedomosti.ru#17
# 0.13065   	gazeta.ru#n_8495237.shtml
# 0.13183   	kommersant.ru#doc
# 0.13187   	kommersant.ru#2962136
# 0.13436   	kommersant.ru#2961906
# 0.13451   	fontanka.ru#006
# 0.13516   	vedomosti.ru#637309-skolko-mozhno-pahat
# 0.13623   	kommersant.ru#Doc
# 0.13756   	vedomosti.ru#637330-letnogo-otryada-rossiya
# 0.13951   	kommersant.ru#regions
# 0.14035   	kommersant.ru#
# 0.14255   	kommersant.ru#2961695
# 0.14313   	gazeta.ru#auto
# 0.14400   	bankir.ru#novosti
# 0.14462   	vedomosti.ru#library
# 0.14492   	vedomosti.ru#29
# 0.14590   	kommersant.ru#2962025
# 0.14628   	vedomosti.ru#637331-putin-grizlova-soveta-bezopasnosti
# 0.14791   	gazeta.ru#8173271.shtml
# 0.14796   	vedomosti.ru#637409-niderlandi-referenduma
# 0.15013   	novayagazeta.ru#1702338.html
# 0.15059   	kommersant.ru#2961612
# 0.15093   	gazeta.ru#n_8492501.shtml
# 0.15094   	gazeta.ru#n_8494541.shtml
# 0.15103   	gazeta.ru#business
# 0.15200   	slon.ru#66547
# 0.15228   	slon.ru#66543
# 0.15235   	echo.msk.ru#arsenal
# 0.15244   	fontanka.ru#121
# 0.15342   	vedomosti.ru#636963-rabotniki-timiryazevki-otkazalis-razgovarivat-s-zamministra
# 0.15416   	kommersant.ru#daily
# 0.15424   	gazeta.ru#n_8492639.shtml
# 0.15457   	vedomosti.ru#09
# 0.15517   	fontanka.ru#152
# 0.15572   	gazeta.ru#8173337.shtml
# 0.15628   	gazeta.ru#11
# 0.15634   	fontanka.ru#113
# 0.15652   	gazeta.ru#11_a_8171627.shtml
# 0.15667   	kommersant.ru#2961846
# 0.15683   	echo.msk.ru#1746420-echo.html
# 0.15774   	gazeta.ru#8172707.shtml
# 0.15836   	novayagazeta.ru#news
# 0.15878   	rbc.ru#570ca8989a79476bdd085c55
#
# ----------------------------------------------------------------------------------------------------
#
# Nearest 100 neighbours for gdz-putina.me# (382796 long-track* visitors per day):
#
# distance  	urrlfr
#
# 0.00000   	gdz-putina.me#
# 0.00772   	gdz-putina.info#
# 0.01412   	30school.ru#
# 0.01509   	gdz-putina.info#5-klass
# 0.03125   	gdz-putina.me#gdz-reshebnik-po-matematike-4-klass-moro-1-i-2-chast
# 0.03134   	egeurok.ru#2kl_Kanakina
# 0.03142   	gdz-putina.info#1-4-klassi
# 0.03164   	gdzputina.com#russkij-yazyk
# 0.03207   	egeurok.ru#1
# 0.03214   	otbet.ru#english
# 0.03224   	gdz-putina.me#russkij-yazik-7
# 0.03228   	botanam.net#5-klass
# 0.03229   	spishi-ru.net#
# 0.03246   	uchim.org#po-matematike-6-klass-vilenkin
# 0.03260   	megaresheba.ru#03
# 0.03261   	30school.ru#matematika
# 0.03263   	gdz-putina.me#anglijskij-yazik-6
# 0.03278   	otbet.ru#matematika
# 0.03299   	vse-gdz.info#matematika-4
# 0.03315   	gdz-geo.ru#
# 0.03324   	otbet.ru#russkii_yazik
# 0.03326   	onlinegdz.net#reshebnik-matematika-5-klass-zubareva-mordkovich
# 0.03328   	megaresheba.ru#04
# 0.03338   	otbet.ru#zubareva-8
# 0.03341   	megaresheba.ru#5_klass
# 0.03350   	egeurok.ru#4klass
# 0.03351   	egeurok.ru#5klass
# 0.03373   	gdzputina.com#4-klass
# 0.03394   	otbet.ru#class-4
# 0.03410   	gdzeyka.com#5_klass
# 0.03434   	gdz-spishy.com#
# 0.03434   	resheba.com#
# 0.03446   	otbet.ru#vilenkin-13-23
# 0.03456   	yroky.net#gdz
# 0.03458   	gdz-putina.me#gdz-reshebnik-po-matematika-3-klass-moro-1-i-2-chast
# 0.03463   	гдз.сайт#6_klass
#
# Long-track visitors = visitors with at least 40 distinct urlfr visited for a day.

# %%
af = open('data/collab_filter_SGD_a_vec.csv','w')
Xf = open('data/collab_filter_SGD_X_matr.csv','w')

# %%
a = [float(r[1]) for r in [e.split(',') for e in open('data/collab_filter_SGD_a_vec.csv','r').readlines()] if int(r[0]) % 20000 > 10000]

# %%
X = [[float(e) for e in r[1:]] for r in [e.split(',') for e in open('data/collab_filter_SGD_X_matr.csv','r').readlines()] if int(r[0]) % 20000 > 10000]

# %%
#ra = open('data/collab_filter_SGD_a_vec.csv','r').readlines()

# %%
Xa = np.array([[ai+ mu[0],1] + x for ai,x in zip(a,X)])

# %%
UTdotU = np.zeros([Xa.shape[1],Xa.shape[1]])
for i in range(UTdotU.shape[1]):
    for j in range(UTdotU.shape[1]):
        UTdotU[i,j] = Xa[i].dot(Xa[j])

# %%
import cPickle
cPickle.dump(UTdotU,open('UTdotU.pck','w'))

# %%
#b = [float(r[1]) for r in [e.strip().split(',') for e in open('data/collab_filter_SGD_b_vec.csv','r').readlines()[:-1]]]
Y = [[float(e) for e in r[1:]] for r in [e.strip().split(',') for e in open('data/collab_filter_SGD_Y_matr.csv','r').readlines()]]

# %%
for j in range(len(Y[-1]),len(Y[1])):
    Y[-1].append(sum([Y[i][j] for i in range(99)])/99.)
#b = b + [sum(b)/len(b)] * (len(Y[0]) - len(b))
Yb = np.array([[1,b[i]] +[Y[j][i] for j in range(len(Y))] for i in range(len(b))])

# %%
r = np.dot(Yb,UTdotU)
r1num = np.dot(r[num],Yb.T)

# %%
res = sorted(zip(r1num,range(len(r1num))))
