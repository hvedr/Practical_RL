# %% [markdown]
# ### HyperLogLog v6
# HLL в задаче look_alike. Задача - выделить людей, посещавших раздел каско на сайте ресо.

# %%
import numpy as np
from HLL import HyperLogLog as Hll

# %%
##### Config
from pyspark import SparkConf, SparkContext, HiveContext
import re
import numpy as np
import pandas as pd
import datetime
from pyspark.mllib.regression import LabeledPoint
from pyspark.mllib.feature import HashingTF
from pyspark.mllib.classification import LogisticRegressionWithSGD, NaiveBayes, NaiveBayesModel
import scipy.sparse as sps
from pyspark.mllib.linalg import Vectors
from pyspark.mllib.linalg import SparseVector
from pyspark.mllib.evaluation import BinaryClassificationMetrics

hive_config_query = '''
set hive.vectorized.execution.enabled=true;
set hive.vectorized.execution.reduce.enabled = true;
set mapreduce.map.memory.mb=4096;
set mapreduce.map.child.java.opts=-Xmx4g;
set mapreduce.task.io.sort.mb=1024;
set mapreduce.reduce.child.java.opts=-Xmx4g;
set mapreduce.reduce.memory.mb=7000;
set mapreduce.reduce.shuffle.input.buffer.percent=0.5;
set mapreduce.input.fileinputformat.split.minsize=536870912;
set mapreduce.input.fileinputformat.split.maxsize=1073741824;
set hive.optimize.ppd=true;
set hive.merge.smallfiles.avgsize=536870912;
set hive.merge.mapredfiles=true;
set hive.merge.mapfiles=true;
set hive.hadoop.supports.splittable.combineinputformat=true;
set hive.exec.reducers.bytes.per.reducer=536870912;
set hive.exec.parallel=true;
set hive.exec.max.created.files=10000000;
set hive.exec.compress.output=true;
set hive.exec.dynamic.partition.mode=nonstrict;
set hive.exec.max.dynamic.partitions=1000000;
set hive.exec.max.dynamic.partitions.pernode=100000;
set io.seqfile.compression.type=BLOCK;
set mapreduce.map.failures.maxpercent=5;
'''
try:
    sc.stop()
except: pass

conf = (SparkConf()
        .set("spark.executor.instances", 2)
        .set("spark.driver.maxResultSize", "24g")
        .set('spark.driver.memory','24g')
       # .set("spark.executor.memory", '8g')
       # .set("spark.yarn.executor.memoryOverhead", 2048)        
       )
sc = SparkContext(conf=conf)
hc = HiveContext(sc)

for q in hive_config_query.split(';'):
    try:
        hc.sql(q)
    except:
        pass

# %%
# download_file 
#! beeline -u "jdbc:hive2://ds-hadoop-cs01p:10000/" -n kposminin --incremental=true --showheader=false --outputformat=tsv2 
# --maxwidth=5000 --silent=true --showWarnings=false --showNestedErrs=false --verbose=false --nullemptystring=true 
#-e "select phone_mobile, approve, call_ymd, urlfr, ymd from user_kposminin.ccall_visits order by phone_mobile" > ccall_cred_visits.txt
#! head -1 /data1/share/kosm/data/ccall_cred_visits.txt

# %%
query = '''
create table user_kposminin.reso_positive as
select distinct '2017-03-15' as ymd, id, load_src from prod_odd.visit_feature
where ymd between '2017-03-15' and date_add('2017-03-15',3) and lower(url_fragment) = 'reso.ru#motor'
union all
select distinct '2017-03-08' as ymd, id, load_src from prod_odd.visit_feature
where ymd between '2017-03-08' and date_add('2017-03-08',3) and lower(url_fragment) = 'reso.ru#motor'
'''

train_query_pattern = '''
select 
  v.id,
  v.load_src,
  if(p.id is Null,0,1) as label,
  v.url_fragment 
from 
  prod_odd.visit_feature v
  left join user_kposminin.reso_positive p on p.id = v.id and p.load_src = v.load_src and p.ymd = v.ymd
where 
  ((not p.id is Null) or substr(md5(v.id),1,2) = '00')
  and v.ymd = '2017-03-08'
  and (not v.url_fragment like 'reso.ru#%')
order by v.id, v.load_src
'''

test_query_pattern = '''
select 
  v.id,
  v.load_src,
  if(p.id is Null,0,1) as label,
  v.url_fragment 
from 
  prod_odd.visit_feature v
  left join user_kposminin.reso_positive p on p.id = v.id and p.load_src = v.load_src and p.ymd = v.ymd
where 
  v.ymd = '2017-03-15'
  and substr(v.id,5,2) = '#cc'
order by v.id, v.load_src
'''

# %% [markdown]
# ### Подготовка датасетов

# %%
from HLL import HyperLogLog as Hll
from tqdm import tqdm
hll_len = 14
salts = ['32m4','sd8f','9zj1']

for mode,query in (('train',train_query_pattern),):    
    data = hc.sql(query).collect()
    print('read done')
    prev_key = None
    prev_approve = None
    buf = Hll(hll_len)
    with open('./data/la_hll_' + mode + '.tsv', 'w') as fo:
        for r in data:
            #(phone, approve, call_ymd, urlfr, ymd) = line
            key = '%s_%s_%s' % (r.id, r.load_src,r.label)
            if key != prev_key:
                if prev_key is not None:
                    fo.write('%s\t%s\n' % (prev_approve, '\t'.join([str(e) for e in buf.registers()])))
                prev_key = key
                buf = Hll(hll_len)
                prev_approve = r.label
            buf.add(r.url_fragment.encode('utf8'))

# %%
! shuf ./data/la_hll_train.tsv > /data1/share/kosm/data/la_hll_train_shuf.tsv
#! head -5000 /data1/share/kosm/data/la_hll_train_shuf.tsv > /data1/share/kosm/data/la_hll_train_shuf_sample.tsv
#! tail -5000 /data1/share/kosm/data/la_hll_train_shuf.tsv > /data1/share/kosm/data/la_hll_train_shuf_sample1.tsv

# %% [markdown]
# ### Обучение модели

# %%
import numpy as np
from sklearn import datasets, metrics, model_selection
from pylightgbm.models import GBMClassifier

# full path to lightgbm executable (on Windows include .exe)
exec_path = "/data1/share/LightGBM/lightgbm"

#X, Y = datasets.make_classification(n_samples=200, n_features=10)
#x_train, x_test, y_train, y_test = model_selection.train_test_split(X, Y, test_size=0.2)

clf = GBMClassifier(
        exec_path=exec_path,
        min_data_in_leaf=5,
        is_unbalance = True,
        num_iterations = 500,
        bagging_fraction = 0.8,
        bagging_freq = 5,
        metric = 'auc',
        early_stopping_round=10
)
x_train, y_train = [], []
for l in open('/data1/share/kosm/data/la_hll_train_shuf.tsv','r'):
    l = l.split('\t')
    if(l[0] == '1' or np.random.rand() < 0.1):
        x_train.append([int(e) for e in l[1:]])
        y_train.append(int(l[0]))
clf.fit( x_train, y_train)
# Out:
# pyLightGBM is looking for 'LIGHTGBM_EXEC' environment variable, cannot be found.
# exec_path will be deprecated in favor of environment variable
# [LightGBM] [Info] Finished loading parameters
# [LightGBM] [Info] Finished loading data in 189.840482 seconds
# [LightGBM] [Info] Number of postive: 1321, number of negative: 93222
# [LightGBM] [Info] Number of data: 94543, number of features: 16384
# [LightGBM] [Info] Finished initializing training
# [LightGBM] [Info] Started training...
# [LightGBM] [Info] 0.752088 seconds elapsed, finished iteration 1
# [LightGBM] [Info] 1.519850 seconds elapsed, finished iteration 2
# [LightGBM] [Info] 2.270179 seconds elapsed, finished iteration 3
# [LightGBM] [Info] 3.052368 seconds elapsed, finished iteration 4
# [LightGBM] [Info] 3.851864 seconds elapsed, finished iteration 5
# [LightGBM] [Info] 4.645904 seconds elapsed, finished iteration 6
# [LightGBM] [Info] 5.435046 seconds elapsed, finished iteration 7
# [LightGBM] [Info] 6.179668 seconds elapsed, finished iteration 8
# [LightGBM] [Info] 6.924613 seconds elapsed, finished iteration 9
# [LightGBM] [Info] 7.620105 seconds elapsed, finished iteration 10
# [LightGBM] [Info] 8.393809 seconds elapsed, finished iteration 11
# [LightGBM] [Info] 9.130387 seconds elapsed, finished iteration 12
# [LightGBM] [Info] 9.837232 seconds elapsed, finished iteration 13
# [LightGBM] [Info] 10.642779 seconds elapsed, finished iteration 14
# [LightGBM] [Info] 11.390397 seconds elapsed, finished iteration 15
# [LightGBM] [Info] 12.250088 seconds elapsed, finished iteration 16
# [LightGBM] [Info] 13.115914 seconds elapsed, finished iteration 17
# [LightGBM] [Info] 13.905933 seconds elapsed, finished iteration 18
# [LightGBM] [Info] 14.705748 seconds elapsed, finished iteration 19
# [LightGBM] [Info] 15.540495 seconds elapsed, finished iteration 20
# [LightGBM] [Info] 16.313524 seconds elapsed, finished iteration 21
# [LightGBM] [Info] 17.158327 seconds elapsed, finished iteration 22
# [LightGBM] [Info] 18.013252 seconds elapsed, finished iteration 23
# [LightGBM] [Info] 18.864073 seconds elapsed, finished iteration 24
# [LightGBM] [Info] 19.749021 seconds elapsed, finished iteration 25
# [LightGBM] [Info] 20.619671 seconds elapsed, finished iteration 26
# [LightGBM] [Info] 21.439602 seconds elapsed, finished iteration 27
# [LightGBM] [Info] 22.304381 seconds elapsed, finished iteration 28
# [LightGBM] [Info] 23.144998 seconds elapsed, finished iteration 29
# [LightGBM] [Info] 24.018176 seconds elapsed, finished iteration 30
# [LightGBM] [Info] 24.880221 seconds elapsed, finished iteration 31
# [LightGBM] [Info] 25.737867 seconds elapsed, finished iteration 32
# [LightGBM] [Info] 26.540368 seconds elapsed, finished iteration 33
# [LightGBM] [Info] 27.218278 seconds elapsed, finished iteration 34
# [LightGBM] [Info] 28.045195 seconds elapsed, finished iteration 35
# [LightGBM] [Info] 28.830869 seconds elapsed, finished iteration 36
# [LightGBM] [Info] 29.753558 seconds elapsed, finished iteration 37
# [LightGBM] [Info] 30.598632 seconds elapsed, finished iteration 38
# [LightGBM] [Info] 31.457758 seconds elapsed, finished iteration 39
# [LightGBM] [Info] 32.350880 seconds elapsed, finished iteration 40
# [LightGBM] [Info] 33.190969 seconds elapsed, finished iteration 41
# [LightGBM] [Info] 34.073903 seconds elapsed, finished iteration 42
# [LightGBM] [Info] 34.975444 seconds elapsed, finished iteration 43
# [LightGBM] [Info] 35.858501 seconds elapsed, finished iteration 44
# [LightGBM] [Info] 36.713196 seconds elapsed, finished iteration 45
# [LightGBM] [Info] 37.569399 seconds elapsed, finished iteration 46
# [LightGBM] [Info] 38.436035 seconds elapsed, finished iteration 47
# [LightGBM] [Info] 39.248897 seconds elapsed, finished iteration 48
# [LightGBM] [Info] 40.083267 seconds elapsed, finished iteration 49
# [LightGBM] [Info] 40.949653 seconds elapsed, finished iteration 50
# [LightGBM] [Info] 41.842561 seconds elapsed, finished iteration 51
# [LightGBM] [Info] 42.726007 seconds elapsed, finished iteration 52
# [LightGBM] [Info] 43.600251 seconds elapsed, finished iteration 53
# [LightGBM] [Info] 44.492309 seconds elapsed, finished iteration 54
# [LightGBM] [Info] 45.408668 seconds elapsed, finished iteration 55
# [LightGBM] [Info] 46.284547 seconds elapsed, finished iteration 56
# [LightGBM] [Info] 47.121402 seconds elapsed, finished iteration 57
# [LightGBM] [Info] 48.004885 seconds elapsed, finished iteration 58
# [LightGBM] [Info] 48.863402 seconds elapsed, finished iteration 59
# [LightGBM] [Info] 49.746792 seconds elapsed, finished iteration 60
# [LightGBM] [Info] 50.665971 seconds elapsed, finished iteration 61
# [LightGBM] [Info] 51.572851 seconds elapsed, finished iteration 62
# [LightGBM] [Info] 52.456911 seconds elapsed, finished iteration 63
# [LightGBM] [Info] 53.365022 seconds elapsed, finished iteration 64
# [LightGBM] [Info] 54.269285 seconds elapsed, finished iteration 65
# [LightGBM] [Info] 55.028073 seconds elapsed, finished iteration 66
# [LightGBM] [Info] 55.984059 seconds elapsed, finished iteration 67
# [LightGBM] [Info] 56.789288 seconds elapsed, finished iteration 68
# [LightGBM] [Info] 57.550040 seconds elapsed, finished iteration 69
# [LightGBM] [Info] 58.432437 seconds elapsed, finished iteration 70
# [LightGBM] [Info] 59.162983 seconds elapsed, finished iteration 71
# [LightGBM] [Info] 60.020963 seconds elapsed, finished iteration 72
# [LightGBM] [Info] 60.856850 seconds elapsed, finished iteration 73
# [LightGBM] [Info] 61.731100 seconds elapsed, finished iteration 74
# [LightGBM] [Info] 62.549185 seconds elapsed, finished iteration 75
# [LightGBM] [Info] 63.375508 seconds elapsed, finished iteration 76
# [LightGBM] [Info] 64.246053 seconds elapsed, finished iteration 77
# [LightGBM] [Info] 65.045905 seconds elapsed, finished iteration 78
# [LightGBM] [Info] 65.909515 seconds elapsed, finished iteration 79
# [LightGBM] [Info] 66.789718 seconds elapsed, finished iteration 80
# [LightGBM] [Info] 67.663481 seconds elapsed, finished iteration 81
# [LightGBM] [Info] 68.408828 seconds elapsed, finished iteration 82
# [LightGBM] [Info] 69.094315 seconds elapsed, finished iteration 83
# [LightGBM] [Info] 69.963863 seconds elapsed, finished iteration 84
# [LightGBM] [Info] 70.574992 seconds elapsed, finished iteration 85
# [LightGBM] [Info] 71.390460 seconds elapsed, finished iteration 86
# [LightGBM] [Info] 72.192413 seconds elapsed, finished iteration 87
# [LightGBM] [Info] 72.931573 seconds elapsed, finished iteration 88
# [LightGBM] [Info] 73.788803 seconds elapsed, finished iteration 89
# [LightGBM] [Info] 74.656931 seconds elapsed, finished iteration 90
# [LightGBM] [Info] 75.491379 seconds elapsed, finished iteration 91
# [LightGBM] [Info] 76.335820 seconds elapsed, finished iteration 92
# [LightGBM] [Info] 77.227985 seconds elapsed, finished iteration 93
# [LightGBM] [Info] 78.107615 seconds elapsed, finished iteration 94
# [LightGBM] [Info] 78.939730 seconds elapsed, finished iteration 95
# [LightGBM] [Info] 79.753694 seconds elapsed, finished iteration 96
# [LightGBM] [Info] 80.554369 seconds elapsed, finished iteration 97
# [LightGBM] [Info] 81.394249 seconds elapsed, finished iteration 98
# [LightGBM] [Info] 82.170388 seconds elapsed, finished iteration 99
# [LightGBM] [Info] 82.989304 seconds elapsed, finished iteration 100
# [LightGBM] [Info] 83.794017 seconds elapsed, finished iteration 101
# [LightGBM] [Info] 84.614403 seconds elapsed, finished iteration 102
# [LightGBM] [Info] 85.433244 seconds elapsed, finished iteration 103
# [LightGBM] [Info] 86.194480 seconds elapsed, finished iteration 104
# [LightGBM] [Info] 87.081145 seconds elapsed, finished iteration 105
# [LightGBM] [Info] 87.861732 seconds elapsed, finished iteration 106
# [LightGBM] [Info] 88.631086 seconds elapsed, finished iteration 107
# [LightGBM] [Info] 89.427657 seconds elapsed, finished iteration 108
# [LightGBM] [Info] 90.227881 seconds elapsed, finished iteration 109
# [LightGBM] [Info] 90.992186 seconds elapsed, finished iteration 110
# [LightGBM] [Info] 91.782687 seconds elapsed, finished iteration 111
# [LightGBM] [Info] 92.521463 seconds elapsed, finished iteration 112
# [LightGBM] [Info] 93.300421 seconds elapsed, finished iteration 113
# [LightGBM] [Info] 94.147384 seconds elapsed, finished iteration 114
# [LightGBM] [Info] 94.980037 seconds elapsed, finished iteration 115
# [LightGBM] [Info] 95.752730 seconds elapsed, finished iteration 116
# [LightGBM] [Info] 96.534027 seconds elapsed, finished iteration 117
# [LightGBM] [Info] 97.344323 seconds elapsed, finished iteration 118
# [LightGBM] [Info] 98.173186 seconds elapsed, finished iteration 119
# [LightGBM] [Info] 98.975577 seconds elapsed, finished iteration 120
# [LightGBM] [Info] 99.734700 seconds elapsed, finished iteration 121
# [LightGBM] [Info] 100.242385 seconds elapsed, finished iteration 122
# [LightGBM] [Info] 100.843793 seconds elapsed, finished iteration 123
# [LightGBM] [Info] 101.653433 seconds elapsed, finished iteration 124
# [LightGBM] [Info] 102.170394 seconds elapsed, finished iteration 125
# [LightGBM] [Info] 102.801942 seconds elapsed, finished iteration 126
# [LightGBM] [Info] 103.493060 seconds elapsed, finished iteration 127
# [LightGBM] [Info] 104.179803 seconds elapsed, finished iteration 128
# [LightGBM] [Info] 105.026453 seconds elapsed, finished iteration 129
# [LightGBM] [Info] 105.846247 seconds elapsed, finished iteration 130
# [LightGBM] [Info] 106.458336 seconds elapsed, finished iteration 131
# [LightGBM] [Info] 107.200943 seconds elapsed, finished iteration 132
# [LightGBM] [Info] 107.827522 seconds elapsed, finished iteration 133
# [LightGBM] [Info] 108.572261 seconds elapsed, finished iteration 134
# [LightGBM] [Info] 109.388546 seconds elapsed, finished iteration 135
# [LightGBM] [Info] 110.205703 seconds elapsed, finished iteration 136
# [LightGBM] [Info] 111.025964 seconds elapsed, finished iteration 137
# [LightGBM] [Info] 111.836138 seconds elapsed, finished iteration 138
# [LightGBM] [Info] 112.677023 seconds elapsed, finished iteration 139
# [LightGBM] [Info] 113.423357 seconds elapsed, finished iteration 140
# [LightGBM] [Info] 114.043884 seconds elapsed, finished iteration 141
# [LightGBM] [Info] 114.627905 seconds elapsed, finished iteration 142
# [LightGBM] [Info] 115.193778 seconds elapsed, finished iteration 143
# [LightGBM] [Info] 115.864610 seconds elapsed, finished iteration 144
# [LightGBM] [Info] 116.581763 seconds elapsed, finished iteration 145
# [LightGBM] [Info] 117.318148 seconds elapsed, finished iteration 146
# [LightGBM] [Info] 118.064798 seconds elapsed, finished iteration 147
# [LightGBM] [Info] 118.761613 seconds elapsed, finished iteration 148
# [LightGBM] [Info] 119.476300 seconds elapsed, finished iteration 149
# [LightGBM] [Info] 120.283382 seconds elapsed, finished iteration 150
# [LightGBM] [Info] 120.993112 seconds elapsed, finished iteration 151
# [LightGBM] [Info] 121.767694 seconds elapsed, finished iteration 152
# [LightGBM] [Info] 122.535151 seconds elapsed, finished iteration 153
# [LightGBM] [Info] 123.322322 seconds elapsed, finished iteration 154
# [LightGBM] [Info] 124.068715 seconds elapsed, finished iteration 155
# [LightGBM] [Info] 124.747662 seconds elapsed, finished iteration 156
# [LightGBM] [Info] 125.525648 seconds elapsed, finished iteration 157
# [LightGBM] [Info] 126.113715 seconds elapsed, finished iteration 158
# [LightGBM] [Info] 126.878829 seconds elapsed, finished iteration 159
# [LightGBM] [Info] 127.640930 seconds elapsed, finished iteration 160
# [LightGBM] [Info] 128.284322 seconds elapsed, finished iteration 161
# [LightGBM] [Info] 128.850335 seconds elapsed, finished iteration 162
# [LightGBM] [Info] 129.522041 seconds elapsed, finished iteration 163
# [LightGBM] [Info] 130.185136 seconds elapsed, finished iteration 164
# [LightGBM] [Info] 130.936258 seconds elapsed, finished iteration 165
# [LightGBM] [Info] 131.542968 seconds elapsed, finished iteration 166
# [LightGBM] [Info] 132.267728 seconds elapsed, finished iteration 167
# [LightGBM] [Info] 132.964926 seconds elapsed, finished iteration 168
# [LightGBM] [Info] 133.717184 seconds elapsed, finished iteration 169
# [LightGBM] [Info] 134.512847 seconds elapsed, finished iteration 170
# [LightGBM] [Info] 135.196931 seconds elapsed, finished iteration 171
# [LightGBM] [Info] 135.938424 seconds elapsed, finished iteration 172
# [LightGBM] [Info] 136.731355 seconds elapsed, finished iteration 173
# [LightGBM] [Info] 137.420754 seconds elapsed, finished iteration 174
# [LightGBM] [Info] 138.089890 seconds elapsed, finished iteration 175
# [LightGBM] [Info] 138.573340 seconds elapsed, finished iteration 176
# [LightGBM] [Info] 139.040877 seconds elapsed, finished iteration 177
# [LightGBM] [Info] 139.551194 seconds elapsed, finished iteration 178
# [LightGBM] [Info] 140.170041 seconds elapsed, finished iteration 179
# [LightGBM] [Info] 140.675697 seconds elapsed, finished iteration 180
# [LightGBM] [Info] 141.269277 seconds elapsed, finished iteration 181
# [LightGBM] [Info] 141.947583 seconds elapsed, finished iteration 182
# [LightGBM] [Info] 142.652262 seconds elapsed, finished iteration 183
# [LightGBM] [Info] 143.234176 seconds elapsed, finished iteration 184
# [LightGBM] [Info] 143.939678 seconds elapsed, finished iteration 185
# [LightGBM] [Info] 144.608866 seconds elapsed, finished iteration 186
# [LightGBM] [Info] 145.312765 seconds elapsed, finished iteration 187
# [LightGBM] [Info] 146.026984 seconds elapsed, finished iteration 188
# [LightGBM] [Info] 146.756913 seconds elapsed, finished iteration 189
# [LightGBM] [Info] 147.475240 seconds elapsed, finished iteration 190
# [LightGBM] [Info] 148.120642 seconds elapsed, finished iteration 191
# [LightGBM] [Info] 148.828070 seconds elapsed, finished iteration 192
# [LightGBM] [Info] 149.534546 seconds elapsed, finished iteration 193
# [LightGBM] [Info] 200.078996 seconds elapsed, finished iteration 285
# [LightGBM] [Info] 200.557448 seconds elapsed, finished iteration 286
# [LightGBM] [Info] 201.029466 seconds elapsed, finished iteration 287
# [LightGBM] [Info] 201.475288 seconds elapsed, finished iteration 288
# [LightGBM] [Info] 201.921850 seconds elapsed, finished iteration 289
# [LightGBM] [Info] 202.350120 seconds elapsed, finished iteration 290
# [LightGBM] [Info] 202.862528 seconds elapsed, finished iteration 291
# [LightGBM] [Info] 203.373585 seconds elapsed, finished iteration 292
# [LightGBM] [Info] 203.861726 seconds elapsed, finished iteration 293
# [LightGBM] [Info] 204.384936 seconds elapsed, finished iteration 294
# [LightGBM] [Info] 204.921249 seconds elapsed, finished iteration 295
# [LightGBM] [Info] 205.446847 seconds elapsed, finished iteration 296
# [LightGBM] [Info] 205.920438 seconds elapsed, finished iteration 297
# [LightGBM] [Info] 206.518577 seconds elapsed, finished iteration 298
# [LightGBM] [Info] 207.128103 seconds elapsed, finished iteration 299
# [LightGBM] [Info] 207.723946 seconds elapsed, finished iteration 300
# [LightGBM] [Info] 208.251795 seconds elapsed, finished iteration 301
# [LightGBM] [Info] 208.749360 seconds elapsed, finished iteration 302
# [LightGBM] [Info] 209.252144 seconds elapsed, finished iteration 303
# [LightGBM] [Info] 209.725562 seconds elapsed, finished iteration 304
# [LightGBM] [Info] 210.220601 seconds elapsed, finished iteration 305
# [LightGBM] [Info] 210.689027 seconds elapsed, finished iteration 306
# [LightGBM] [Info] 211.158192 seconds elapsed, finished iteration 307
# [LightGBM] [Info] 211.619602 seconds elapsed, finished iteration 308
# [LightGBM] [Info] 212.094424 seconds elapsed, finished iteration 309
# [LightGBM] [Info] 212.571318 seconds elapsed, finished iteration 310
# [LightGBM] [Info] 213.054840 seconds elapsed, finished iteration 311
# [LightGBM] [Info] 213.566629 seconds elapsed, finished iteration 312
# [LightGBM] [Info] 214.059975 seconds elapsed, finished iteration 313
# [LightGBM] [Info] 214.539087 seconds elapsed, finished iteration 314
# [LightGBM] [Info] 214.986346 seconds elapsed, finished iteration 315
# [LightGBM] [Info] 215.461384 seconds elapsed, finished iteration 316
# [LightGBM] [Info] 215.955492 seconds elapsed, finished iteration 317
# [LightGBM] [Info] 216.433586 seconds elapsed, finished iteration 318
# [LightGBM] [Info] 216.907995 seconds elapsed, finished iteration 319
# [LightGBM] [Info] 217.391857 seconds elapsed, finished iteration 320
# [LightGBM] [Info] 217.879942 seconds elapsed, finished iteration 321
# [LightGBM] [Info] 218.387341 seconds elapsed, finished iteration 322
# [LightGBM] [Info] 218.926043 seconds elapsed, finished iteration 323
# [LightGBM] [Info] 219.435107 seconds elapsed, finished iteration 324
# [LightGBM] [Info] 219.943553 seconds elapsed, finished iteration 325
# [LightGBM] [Info] 220.447780 seconds elapsed, finished iteration 326
# [LightGBM] [Info] 220.970497 seconds elapsed, finished iteration 327
# [LightGBM] [Info] 221.468390 seconds elapsed, finished iteration 328
# [LightGBM] [Info] 222.009435 seconds elapsed, finished iteration 329
# [LightGBM] [Info] 222.521838 seconds elapsed, finished iteration 330
# [LightGBM] [Info] 263.232385 seconds elapsed, finished iteration 422
# [LightGBM] [Info] 263.637529 seconds elapsed, finished iteration 423
# [LightGBM] [Info] 264.059787 seconds elapsed, finished iteration 424
# [LightGBM] [Info] 264.499191 seconds elapsed, finished iteration 425
# [LightGBM] [Info] 264.944895 seconds elapsed, finished iteration 426
# [LightGBM] [Info] 265.380463 seconds elapsed, finished iteration 427
# [LightGBM] [Info] 265.812622 seconds elapsed, finished iteration 428
# [LightGBM] [Info] 266.237607 seconds elapsed, finished iteration 429
# [LightGBM] [Info] 266.684666 seconds elapsed, finished iteration 430
# [LightGBM] [Info] 267.118572 seconds elapsed, finished iteration 431
# [LightGBM] [Info] 267.554650 seconds elapsed, finished iteration 432
# [LightGBM] [Info] 267.991139 seconds elapsed, finished iteration 433
# [LightGBM] [Info] 268.436082 seconds elapsed, finished iteration 434
# [LightGBM] [Info] 268.870730 seconds elapsed, finished iteration 435
# [LightGBM] [Info] 269.335923 seconds elapsed, finished iteration 436
# [LightGBM] [Info] 269.781146 seconds elapsed, finished iteration 437
# [LightGBM] [Info] 270.222235 seconds elapsed, finished iteration 438
# [LightGBM] [Info] 270.667415 seconds elapsed, finished iteration 439
# [LightGBM] [Info] 271.132070 seconds elapsed, finished iteration 440
# [LightGBM] [Info] 271.555385 seconds elapsed, finished iteration 441
# [LightGBM] [Info] 271.970969 seconds elapsed, finished iteration 442
# [LightGBM] [Info] 272.383866 seconds elapsed, finished iteration 443
# [LightGBM] [Info] 272.781716 seconds elapsed, finished iteration 444
# [LightGBM] [Info] 273.209471 seconds elapsed, finished iteration 445
# [LightGBM] [Info] 273.680420 seconds elapsed, finished iteration 446
# [LightGBM] [Info] 274.168305 seconds elapsed, finished iteration 447
# [LightGBM] [Info] 274.659351 seconds elapsed, finished iteration 448
# [LightGBM] [Info] 275.118870 seconds elapsed, finished iteration 449
# [LightGBM] [Info] 275.602309 seconds elapsed, finished iteration 450
# [LightGBM] [Info] 276.075977 seconds elapsed, finished iteration 451
# [LightGBM] [Info] 276.549156 seconds elapsed, finished iteration 452
# [LightGBM] [Info] 277.065356 seconds elapsed, finished iteration 453
# [LightGBM] [Info] 277.538150 seconds elapsed, finished iteration 454
# [LightGBM] [Info] 278.024457 seconds elapsed, finished iteration 455
# [LightGBM] [Info] 278.447133 seconds elapsed, finished iteration 456
# [LightGBM] [Info] 278.867192 seconds elapsed, finished iteration 457
# [LightGBM] [Info] 279.292172 seconds elapsed, finished iteration 458
# [LightGBM] [Info] 279.713582 seconds elapsed, finished iteration 459
# [LightGBM] [Info] 280.134701 seconds elapsed, finished iteration 460
# [LightGBM] [Info] 280.538680 seconds elapsed, finished iteration 461
# [LightGBM] [Info] 280.946831 seconds elapsed, finished iteration 462
# [LightGBM] [Info] 281.358622 seconds elapsed, finished iteration 463
# [LightGBM] [Info] 281.782049 seconds elapsed, finished iteration 464
# [LightGBM] [Info] 282.176191 seconds elapsed, finished iteration 465
# [LightGBM] [Info] 282.593679 seconds elapsed, finished iteration 466
# [LightGBM] [Info] 283.002144 seconds elapsed, finished iteration 467
# [LightGBM] [Info] 283.412029 seconds elapsed, finished iteration 468
# [LightGBM] [Info] 283.846152 seconds elapsed, finished iteration 469
# [LightGBM] [Info] 284.267239 seconds elapsed, finished iteration 470
# [LightGBM] [Info] 284.676921 seconds elapsed, finished iteration 471
# [LightGBM] [Info] 285.072554 seconds elapsed, finished iteration 472
# [LightGBM] [Info] 285.478012 seconds elapsed, finished iteration 473
# [LightGBM] [Info] 285.879864 seconds elapsed, finished iteration 474
# [LightGBM] [Info] 286.284348 seconds elapsed, finished iteration 475
# [LightGBM] [Info] 286.698420 seconds elapsed, finished iteration 476
# [LightGBM] [Info] 287.126700 seconds elapsed, finished iteration 477
# [LightGBM] [Info] 287.556245 seconds elapsed, finished iteration 478
# [LightGBM] [Info] 287.979042 seconds elapsed, finished iteration 479
# [LightGBM] [Info] 288.403461 seconds elapsed, finished iteration 480
# [LightGBM] [Info] 288.814052 seconds elapsed, finished iteration 481
# [LightGBM] [Info] 289.219363 seconds elapsed, finished iteration 482
# [LightGBM] [Info] 289.645888 seconds elapsed, finished iteration 483
# [LightGBM] [Info] 290.077904 seconds elapsed, finished iteration 484
# [LightGBM] [Info] 290.512565 seconds elapsed, finished iteration 485
# [LightGBM] [Info] 290.919573 seconds elapsed, finished iteration 486
# [LightGBM] [Info] 291.307224 seconds elapsed, finished iteration 487
# [LightGBM] [Info] 291.694189 seconds elapsed, finished iteration 488
# [LightGBM] [Info] 292.079624 seconds elapsed, finished iteration 489
# [LightGBM] [Info] 292.455620 seconds elapsed, finished iteration 490
# [LightGBM] [Info] 292.858531 seconds elapsed, finished iteration 491
# [LightGBM] [Info] 293.261549 seconds elapsed, finished iteration 492
# [LightGBM] [Info] 293.675065 seconds elapsed, finished iteration 493
# [LightGBM] [Info] 294.081275 seconds elapsed, finished iteration 494
# [LightGBM] [Info] 294.482174 seconds elapsed, finished iteration 495
# [LightGBM] [Info] 294.897604 seconds elapsed, finished iteration 496
# [LightGBM] [Info] 295.327654 seconds elapsed, finished iteration 497
# [LightGBM] [Info] 295.765018 seconds elapsed, finished iteration 498
# [LightGBM] [Info] 296.194932 seconds elapsed, finished iteration 499
# [LightGBM] [Info] 296.621017 seconds elapsed, finished iteration 500
# [LightGBM] [Info] Finished training

# %%
idx = [i for i in range(len(y_train)) if y_train[i] == 1 or np.random.rand() < 0.1]
x_train_samp,y_train_samp = [x_train[i] for i in idx],[y_train[i] for i in idx]

# %%
del x_train, y_train
gc
#clf.fit(x_train_samp,y_train_samp)

# %%
import cPickle
#cPickle.dump(clf,open('clfHLL.pck','w'))
clf = cPickle.load(open('clfHLL.pck','r'))

# %% [markdown]
# ### Применяем к тесту. На диске HLL за день (180 млн кук) будет занимать около 6 ТБ, так что скорим на лету

# %%
from HLL import HyperLogLog as Hll
from tqdm import tqdm
import itertools
hll_len = 14
batch_size = 10 ** 5

salts = ['32m4','sd8f','9zj1']

result = []
for mode,query in (('test',test_query_pattern),):    
    prev_key = None
    prev_approve = None
    buf = Hll(hll_len)
    batch = []
    with open('./data/la_hll_test_scoring.tsv', 'w') as fo:
        for cc in list(itertools.product(*['0123456789ABCDEF']*2)):
            if cc != ('0', '0'):
                data = hc.sql(query.replace('#cc',''.join(cc))).collect()
            print('Read done for {}. Collected {} rows'.format(cc,len(data)))
            for r in data:
                #(phone, approve, call_ymd, urlfr, ymd) = line
                key = '%s_%s_%s' % (r.id, r.load_src,r.label)
                if key != prev_key:
                    if prev_key is not None:                        
                        feat = buf.registers() #('%s\t%s\n' % (prev_approve, '\t'.join([str(e) for e in buf.registers()])))
                        batch.append([prev_approve,feat])
                        if(len(batch) > batch_size):
                            scores = clf.predict_proba(np.array([e[1] for e in batch]))[:,1]
                            batch_res = zip([e[0] for e in batch],scores)
                            fo.write('\n'.join(['{}\t{}'.format(a,s) for a,s in batch_res]))  #%s\t%s\n' % (prev_approve, str(score)))
                            result += batch_res
                            batch = []
                    prev_key = key
                    buf = Hll(hll_len)
                    prev_approve = r.label
                buf.add(r.url_fragment.encode('utf8'))
        if(len(batch) > 0):
            scores = clf.predict_proba(np.array([e[1] for e in batch]))[:,1]
            batch_res = zip([e[0] for e in batch],scores)
            fo.write('\n'.join(['{}\t{}'.format(a,s) for a,s in batch_res]))  #%s\t%s\n' % (prev_approve, str(score)))
            result += batch_res
            batch = []

# %% [markdown]
# ### За неделю работы ноутбука отскорилось 67млн кук. Это треть. Результаты:

# %%
def metrics(y_true, y_score, lift = None, return_str = False):
    import sklearn
    import collections
    
    if True:
        # y_true = [0 if e == '-1' else 1 for e in os.popen('''perl -ne 'print substr($_,0,2) . "\n"' /data1/share/kosm/data/url_text_valid_vw.txt''').read().split()]
        # y_score = [float(e.strip('\n')) for e in open('/data1/share/kosm/data/url_text_valid_predictions_quadr.txt','r').readlines()]
        
        res = collections.OrderedDict()
        samp_size = len(y_true)
        res['Sample size'] = samp_size
        res['Posit share'] = sum(y_true) * 1./ samp_size
        res['Sample size'] = len(y_true)
        res['AUC ROC'] = sklearn.metrics.roc_auc_score(y_true = y_true, y_score = y_score)
        res['AUC PR'] = sklearn.metrics.auc(
                        *sklearn.metrics.precision_recall_curve(y_true = y_true, probas_pred  = y_score)[:2],
                        reorder = True
        )
        res['Log loss'] = sklearn.metrics.log_loss(y_true = y_true, y_pred = y_score)
        if lift:
            predictions_and_labels = sorted(zip(y_score,y_true), reverse = True)
            for l in lift:
                res['Lift ' + str(l)] = sum([e[1] for e in predictions_and_labels[:int(l * samp_size)]]) * 1. / int(l * samp_size) / res['Posit share']
                
        if return_str:
            res = '\n'.join(['{:<12}: {:.5f}'.format(k,v) for (k,v) in res.items()]) + '.'
        return res

# %%
#! head ./data/la_hll_test_scoring.tsv
data_str = [e.split('\t') for e in open('./data/la_hll_test_scoring.tsv','r').readlines()]
y_true  = [int(e[0]) for e in data_str]
y_score = [float(e[1]) for e in data_str]

m = metrics(y_true, y_score, lift = [0.0001,0.001, 0.01,0.05,0.1,0.2,0.5], return_str = False)
print(m)
# Out:
# OrderedDict([('Sample size', 81300001), ('Posit share', 8.130381203808349e-06), ('AUC ROC', 0.82518026059402538), ('AUC PR', 0.00136533274002175), ('Log loss', 0.052158121618300288), ('Lift 0.0001', 378.2148306732689), ('Lift 0.001', 87.74584071619839), ('Lift 0.01', 22.844175772665444), ('Lift 0.05', 8.623298139350533), ('Lift 0.1', 5.8396369855952726), ('Lift 0.2', 3.373676289605559), ('Lift 0.5', 1.7851740007778294)])

# %% [markdown]
# ### Стандартная модель

# %%
stand_model_queries = '''
set hive.exec.dynamic.partition.mode=nonstrict;

insert overwrite table user_kposminin.urlfr_tgt_cnt partition(ymd, target)
select
  urlfr,
  cnt_positive,
  cnt_total,
  log((cnt_positive + 0.1)/(cnt_total - cnt_positive + 0.1)) as score,
  ymd,
  'reso_motor_la' as target
from
  (select
    v.url_fragment as urlfr,
    count(distinct p.id) as cnt_positive, 
    count(distinct v.id) as cnt_total, 
    v.ymd
  from
    prod_odd.visit_feature v
    left join user_kposminin.reso_positive p on p.id = v.id and p.load_src = v.load_src and p.ymd = v.ymd
  where
    v.ymd = '2017-03-08'
    and (not lower(v.url_fragment) like 'reso.ru#%')
  group by
    v.url_fragment, v.ymd
  ) a
where
  (cnt_total > 10000 or cnt_positive > 1)
;


insert overwrite table user_kposminin.urlfr_tgt_cnt partition(ymd, target)
select
  urlfr,
  cnt_positive,
  cnt_total,
  score,
  ymd,
  'reso_motor_la' as target
from
  user_kposminin.urlfr_tgt_cnt 
where 
  target = 'reso_motor_la'
  and (not urlfr like 'reso.ru#%')
;



create table user_kposminin.reso_test_20170315 as 
select
  v.id,
  v.load_src,
  max(if(p.id is Null,0,1)) as label,
  max(t.score) as score
from 
  prod_odd.visit_feature v
  left join user_kposminin.reso_positive p on p.id = v.id and p.load_src = v.load_src and p.ymd = v.ymd
  left join user_kposminin.urlfr_tgt_cnt t on t.urlfr = v.url_fragment and t.ymd = '2017-03-08' and t.target = 'reso_motor_la'
where 
  v.ymd = '2017-03-15'
  and (not v.url_fragment like 'reso.ru#%')
group by 
  v.id,
  v.load_src
;
'''

# %%
data_stand = (hc.sql('select label,score from user_kposminin.reso_test_20170315')
              .toPandas())

# %%
#m_stand = metrics(y_true = data_stand['label'], y_score = data_stand['score'].fillna(-100), lift = [0.0001,0.001, 0.01,0.05,0.1,0.2,0.5], return_str = True)
#print(m_stand)

# %%
m_stand = metrics(y_true = data_stand['label'], y_score = data_stand['score'].fillna(-100), lift = [0.0001,0.001, 0.01,0.05,0.1,0.2,0.5], return_str = False)

# %%
#result = pd.DataFrame([m,m_stand],index = ['HLL',"Stand"]).T
print(result.iloc[1:].applymap(lambda v:'{:.3f}'.format(v)))
# Out:
#                       HLL          Stand
# AUC ROC             0.825          0.898
# Lift 0.0001       402.065       1043.805
# Lift 0.001         85.428        199.495
# Lift 0.01          22.948         35.311
# Lift 0.05           8.476         11.961
# Lift 0.1            5.796          7.302
# Lift 0.2            3.358          4.329
# Lift 0.5            1.786          1.915
# Log loss            0.053          0.000
# Posit share         0.000          0.000
# Sample size  72499838.000  256448394.000

# %% [markdown]
# ## Вывод: Стандартный подход показал себя существенно лучше HLL классификатора по всем показателям
