# %%
##### Config
from pyspark import SparkConf, SparkContext, HiveContext
import re
import numpy as np
import pandas as pd
import datetime
from pyspark.mllib.regression import LabeledPoint
from pyspark.mllib.feature import HashingTF
from pyspark.mllib.classification import LogisticRegressionWithSGD, NaiveBayes, NaiveBayesModel
import scipy.sparse as sps
from pyspark.mllib.linalg import Vectors
from pyspark.mllib.linalg import SparseVector
from pyspark.mllib.evaluation import BinaryClassificationMetrics

hive_config_query = '''
set hive.vectorized.execution.enabled=true;
set hive.vectorized.execution.reduce.enabled = true;
set mapreduce.map.memory.mb=4096;
set mapreduce.map.child.java.opts=-Xmx4g;
set mapreduce.task.io.sort.mb=1024;
set mapreduce.reduce.child.java.opts=-Xmx4g;
set mapreduce.reduce.memory.mb=7000;
set mapreduce.reduce.shuffle.input.buffer.percent=0.5;
set mapreduce.input.fileinputformat.split.minsize=536870912;
set mapreduce.input.fileinputformat.split.maxsize=1073741824;
set hive.optimize.ppd=true;
set hive.merge.smallfiles.avgsize=536870912;
set hive.merge.mapredfiles=true;
set hive.merge.mapfiles=true;
set hive.hadoop.supports.splittable.combineinputformat=true;
set hive.exec.reducers.bytes.per.reducer=536870912;
set hive.exec.parallel=true;
set hive.exec.max.created.files=10000000;
set hive.exec.compress.output=true;
set hive.exec.dynamic.partition.mode=nonstrict;
set hive.exec.max.dynamic.partitions=1000000;
set hive.exec.max.dynamic.partitions.pernode=100000;
set io.seqfile.compression.type=BLOCK;
set mapreduce.map.failures.maxpercent=5;
'''
try:
    sc.stop()
except: pass

conf = (SparkConf()
        .set("spark.executor.instances", 2)
        .set("spark.driver.maxResultSize", "8g")
        .set('spark.driver.memory','8g')
       # .set("spark.executor.memory", '8g')
       # .set("spark.yarn.executor.memoryOverhead", 2048)        
       )
sc = SparkContext(conf=conf)
hc = HiveContext(sc)

for q in hive_config_query.split(';'):
    try:
        hc.sql(q)
    except:
        pass

# %%
train_conf_str = '''
# task type, support train and predict
task = train

# boosting type, support gbdt for now, alias: boosting, boost
boosting_type = gbdt

# application type, support following application
# regression , regression task
# binary , binary classification task
# lambdarank , lambdarank task
# alias: application, app
objective = binary

# eval metrics, support multi metric, delimite by ',' , support following metrics
# l1 
# l2 , default metric for regression
# ndcg , default metric for lambdarank
# auc 
# binary_logloss , default metric for binary
# binary_error
metric = auc,binary_logloss

# frequence for metric output
metric_freq = 1

# true if need output metric for training data, alias: tranining_metric, train_metric
is_training_metric = true

# number of bins for feature bucket, 255 is a recommend setting, it can save memories, and also has good accuracy. 
max_bin = 255

# training data
# if exsting weight file, should name to "binary.train.weight"
# alias: train_data, train
#data = binary.train

# validation data, support multi validation data, separated by ','
# if exsting weight file, should name to "binary.test.weight"
# alias: valid, test, test_data, 
#valid_data = binary.test

# number of trees(iterations), alias: num_tree, num_iteration, num_iterations, num_round, num_rounds
num_trees = 200

# shrinkage rate , alias: shrinkage_rate
learning_rate = 0.05

# number of leaves for one tree, alias: num_leaf
num_leaves = 63

# type of tree learner, support following types:
# serial , single machine version
# feature , use feature parallel to train
# data , use data parallel to train
# voting , use voting based parallel to train
# alias: tree
tree_learner = data

# number of threads for multi-threading. One thread will use one CPU, defalut is setted to #cpu. 
# num_threads = 8

# feature sub-sample, will random select 80% feature to train on each iteration 
# alias: sub_feature
feature_fraction = 0.8

#classes are unbalanced
is_unbalance = true

# Support bagging (data sub-sample), will perform bagging every 5 iterations
bagging_freq = 5

# Bagging farction, will random select 80% data on bagging
# alias: sub_row
bagging_fraction = 0.8

# minimal number data for one leaf, use this to deal with over-fit
# alias : min_data_per_leaf, min_data
min_data_in_leaf = 5

# minimal sum hessians for one leaf, use this to deal with over-fit
#min_sum_hessian_in_leaf = 5.0

# save memory and faster speed for sparse feature, alias: is_sparse
is_enable_sparse = true

# when data is bigger than memory size, set this to true. otherwise set false will have faster speed
# alias: two_round_loading, two_round
use_two_round_loading = true

# true if need to save data to binary file and application will auto load data from binary file next time
# alias: is_save_binary, save_binary
is_save_binary_file = false

# output model file
output_model = lgbm.model

'''

lgbm_dir = './lgbm_url_text'
import os
os.popen('mkdir -p '+lgbm_dir).read()
open(lgbm_dir + '/train.conf','w').write(train_conf_str)

# %%
#! ls /data1/share/kosm/data
train_file_path = '/data1/share/kosm/data/url_text_train_data1.txt'
test_file_path = '/data1/share/kosm/data/url_text_test_data1.txt'
test1_file_path = '/data1/share/kosm/data/url_text_test_data1_sampled.txt' # Тест с исходной долей положительного класса
lgbm_exec_path = "/data1/share/LightGBM/lightgbm"

# %%
#! ls /data1/share/kosm/data
train_file_path = '/data1/share/kosm/data/url_text_train_train_libsvm.txt'
test_file_path = '/data1/share/kosm/data/url_text_valid_libsvm.txt'
#test1_file_path = '/data1/share/kosm/data/url_text_test_data1_sampled.txt' # Тест с исходной долей положительного класса
lgbm_exec_path = "/data1/share/LightGBM/lightgbm"

# %%
#os.popen(lgbm_exec_path +' config=' + lgbm_dir + '/train.conf data=' + train_file_path + ' valid=' + test_file_path + '> ' + lgbm_dir + '/log').read()
print(os.popen('tail -1000 ' + lgbm_dir + '/log').read())
# Out:
# [LightGBM] [Info] Iteration: 1, training's : AUC : 0.683007
# [LightGBM] [Info] Iteration: 1, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.688369
# [LightGBM] [Info] Iteration: 1, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.613379
# [LightGBM] [Info] 56.507716 seconds elapsed, finished iteration 1
# [LightGBM] [Info] Iteration: 2, training's : log loss : 0.681872
# [LightGBM] [Info] Iteration: 2, training's : AUC : 0.707505
# [LightGBM] [Info] Iteration: 2, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.683364
# [LightGBM] [Info] Iteration: 2, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.628964
# [LightGBM] [Info] 97.865797 seconds elapsed, finished iteration 2
# [LightGBM] [Info] Iteration: 3, training's : log loss : 0.676511
# [LightGBM] [Info] Iteration: 3, training's : AUC : 0.730585
# [LightGBM] [Info] Iteration: 3, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.678850
# [LightGBM] [Info] Iteration: 3, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.633537
# [LightGBM] [Info] 140.130226 seconds elapsed, finished iteration 3
# [LightGBM] [Info] Iteration: 4, training's : log loss : 0.671509
# [LightGBM] [Info] Iteration: 4, training's : AUC : 0.741816
# [LightGBM] [Info] Iteration: 4, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.674496
# [LightGBM] [Info] Iteration: 4, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.638672
# [LightGBM] [Info] 182.879779 seconds elapsed, finished iteration 4
# [LightGBM] [Info] Iteration: 5, training's : log loss : 0.666641
# [LightGBM] [Info] Iteration: 5, training's : AUC : 0.750434
# [LightGBM] [Info] Iteration: 5, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.670358
# [LightGBM] [Info] Iteration: 5, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.641693
# [LightGBM] [Info] 226.670509 seconds elapsed, finished iteration 5
# [LightGBM] [Info] Iteration: 6, training's : log loss : 0.661906
# [LightGBM] [Info] Iteration: 6, training's : AUC : 0.758632
# [LightGBM] [Info] Iteration: 6, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.666421
# [LightGBM] [Info] Iteration: 6, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.644340
# [LightGBM] [Info] 264.606416 seconds elapsed, finished iteration 6
# [LightGBM] [Info] Iteration: 7, training's : log loss : 0.657205
# [LightGBM] [Info] Iteration: 7, training's : AUC : 0.764154
# [LightGBM] [Info] Iteration: 7, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.662704
# [LightGBM] [Info] Iteration: 7, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.640106
# [LightGBM] [Info] 304.979286 seconds elapsed, finished iteration 7
# [LightGBM] [Info] Iteration: 8, training's : log loss : 0.652663
# [LightGBM] [Info] Iteration: 8, training's : AUC : 0.770833
# [LightGBM] [Info] Iteration: 8, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.658969
# [LightGBM] [Info] Iteration: 8, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.642238
# [LightGBM] [Info] 346.098659 seconds elapsed, finished iteration 8
# [LightGBM] [Info] Iteration: 9, training's : log loss : 0.648585
# [LightGBM] [Info] Iteration: 9, training's : AUC : 0.774523
# [LightGBM] [Info] Iteration: 9, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.655574
# [LightGBM] [Info] Iteration: 9, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.645331
# [LightGBM] [Info] 384.762336 seconds elapsed, finished iteration 9
# [LightGBM] [Info] Iteration: 10, training's : log loss : 0.644430
# [LightGBM] [Info] Iteration: 10, training's : AUC : 0.779927
# [LightGBM] [Info] Iteration: 10, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.652381
# [LightGBM] [Info] Iteration: 10, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.643320
# [LightGBM] [Info] 426.077371 seconds elapsed, finished iteration 10
# [LightGBM] [Info] Iteration: 11, training's : log loss : 0.640340
# [LightGBM] [Info] Iteration: 11, training's : AUC : 0.784244
# [LightGBM] [Info] Iteration: 11, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.648585
# [LightGBM] [Info] Iteration: 11, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.645665
# [LightGBM] [Info] 465.563399 seconds elapsed, finished iteration 11
# [LightGBM] [Info] Iteration: 12, training's : log loss : 0.636338
# [LightGBM] [Info] Iteration: 12, training's : AUC : 0.787086
# [LightGBM] [Info] Iteration: 12, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.645177
# [LightGBM] [Info] Iteration: 12, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.647227
# [LightGBM] [Info] 504.677159 seconds elapsed, finished iteration 12
# [LightGBM] [Info] Iteration: 13, training's : log loss : 0.632390
# [LightGBM] [Info] Iteration: 13, training's : AUC : 0.791941
# [LightGBM] [Info] Iteration: 13, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.642198
# [LightGBM] [Info] Iteration: 13, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.646660
# [LightGBM] [Info] 548.508164 seconds elapsed, finished iteration 13
# [LightGBM] [Info] Iteration: 14, training's : log loss : 0.628608
# [LightGBM] [Info] Iteration: 14, training's : AUC : 0.795657
# [LightGBM] [Info] Iteration: 14, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.639211
# [LightGBM] [Info] Iteration: 14, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.648276
# [LightGBM] [Info] 590.841111 seconds elapsed, finished iteration 14
# [LightGBM] [Info] Iteration: 15, training's : log loss : 0.625084
# [LightGBM] [Info] Iteration: 15, training's : AUC : 0.798849
# [LightGBM] [Info] Iteration: 15, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.636439
# [LightGBM] [Info] Iteration: 15, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.647420
# [LightGBM] [Info] 629.283496 seconds elapsed, finished iteration 15
# [LightGBM] [Info] Iteration: 16, training's : log loss : 0.621816
# [LightGBM] [Info] Iteration: 16, training's : AUC : 0.801726
# [LightGBM] [Info] Iteration: 16, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.633954
# [LightGBM] [Info] Iteration: 16, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.648998
# [LightGBM] [Info] 670.969143 seconds elapsed, finished iteration 16
# [LightGBM] [Info] Iteration: 17, training's : log loss : 0.618511
# [LightGBM] [Info] Iteration: 17, training's : AUC : 0.804759
# [LightGBM] [Info] Iteration: 17, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.631688
# [LightGBM] [Info] Iteration: 17, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.647478
# [LightGBM] [Info] 713.570584 seconds elapsed, finished iteration 17
# [LightGBM] [Info] Iteration: 18, training's : log loss : 0.615342
# [LightGBM] [Info] Iteration: 18, training's : AUC : 0.807350
# [LightGBM] [Info] Iteration: 18, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.628803
# [LightGBM] [Info] Iteration: 18, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.645663
# [LightGBM] [Info] 751.167734 seconds elapsed, finished iteration 18
# [LightGBM] [Info] Iteration: 19, training's : log loss : 0.612294
# [LightGBM] [Info] Iteration: 19, training's : AUC : 0.810085
# [LightGBM] [Info] Iteration: 19, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.626647
# [LightGBM] [Info] Iteration: 19, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.646081
# [LightGBM] [Info] 790.937211 seconds elapsed, finished iteration 19
# [LightGBM] [Info] Iteration: 20, training's : log loss : 0.609255
# [LightGBM] [Info] Iteration: 20, training's : AUC : 0.813359
# [LightGBM] [Info] Iteration: 20, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.623922
# [LightGBM] [Info] Iteration: 20, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.645653
# [LightGBM] [Info] 830.255426 seconds elapsed, finished iteration 20
# [LightGBM] [Info] Iteration: 21, training's : log loss : 0.606044
# [LightGBM] [Info] Iteration: 21, training's : AUC : 0.816644
# [LightGBM] [Info] Iteration: 21, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.621192
# [LightGBM] [Info] Iteration: 21, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.646865
# [LightGBM] [Info] 870.344541 seconds elapsed, finished iteration 21
# [LightGBM] [Info] Iteration: 22, training's : log loss : 0.602936
# [LightGBM] [Info] Iteration: 22, training's : AUC : 0.818619
# [LightGBM] [Info] Iteration: 22, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.618600
# [LightGBM] [Info] Iteration: 22, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.647396
# [LightGBM] [Info] 910.231856 seconds elapsed, finished iteration 22
# [LightGBM] [Info] Iteration: 23, training's : log loss : 0.599887
# [LightGBM] [Info] Iteration: 23, training's : AUC : 0.821590
# [LightGBM] [Info] Iteration: 23, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.616026
# [LightGBM] [Info] Iteration: 23, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.646824
# [LightGBM] [Info] 953.182092 seconds elapsed, finished iteration 23
# [LightGBM] [Info] Iteration: 24, training's : log loss : 0.596872
# [LightGBM] [Info] Iteration: 24, training's : AUC : 0.824471
# [LightGBM] [Info] Iteration: 24, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.613570
# [LightGBM] [Info] Iteration: 24, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.647528
# [LightGBM] [Info] 993.663264 seconds elapsed, finished iteration 24
# [LightGBM] [Info] Iteration: 25, training's : log loss : 0.593966
# [LightGBM] [Info] Iteration: 25, training's : AUC : 0.826669
# [LightGBM] [Info] Iteration: 25, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.611388
# [LightGBM] [Info] Iteration: 25, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.648239
# [LightGBM] [Info] 1036.460373 seconds elapsed, finished iteration 25
# [LightGBM] [Info] Iteration: 26, training's : log loss : 0.591340
# [LightGBM] [Info] Iteration: 26, training's : AUC : 0.829327
# [LightGBM] [Info] Iteration: 26, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.609411
# [LightGBM] [Info] Iteration: 26, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.647367
# [LightGBM] [Info] 1076.548104 seconds elapsed, finished iteration 26
# [LightGBM] [Info] Iteration: 27, training's : log loss : 0.588734
# [LightGBM] [Info] Iteration: 27, training's : AUC : 0.831790
# [LightGBM] [Info] Iteration: 27, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.607735
# [LightGBM] [Info] Iteration: 27, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.647987
# [LightGBM] [Info] 1115.231243 seconds elapsed, finished iteration 27
# [LightGBM] [Info] Iteration: 28, training's : log loss : 0.586158
# [LightGBM] [Info] Iteration: 28, training's : AUC : 0.834103
# [LightGBM] [Info] Iteration: 28, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.605955
# [LightGBM] [Info] Iteration: 28, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.648719
# [LightGBM] [Info] 1158.666876 seconds elapsed, finished iteration 28
# [LightGBM] [Info] Iteration: 29, training's : log loss : 0.583614
# [LightGBM] [Info] Iteration: 29, training's : AUC : 0.836106
# [LightGBM] [Info] Iteration: 29, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.604118
# [LightGBM] [Info] Iteration: 29, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.648092
# [LightGBM] [Info] 1198.870965 seconds elapsed, finished iteration 29
# [LightGBM] [Info] Iteration: 30, training's : log loss : 0.581163
# [LightGBM] [Info] Iteration: 30, training's : AUC : 0.838468
# [LightGBM] [Info] Iteration: 30, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.602333
# [LightGBM] [Info] Iteration: 30, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.647236
# [LightGBM] [Info] 1238.364332 seconds elapsed, finished iteration 30
# [LightGBM] [Info] Iteration: 31, training's : log loss : 0.578667
# [LightGBM] [Info] Iteration: 31, training's : AUC : 0.840469
# [LightGBM] [Info] Iteration: 31, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.600751
# [LightGBM] [Info] Iteration: 31, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.647243
# [LightGBM] [Info] 1277.772661 seconds elapsed, finished iteration 31
# [LightGBM] [Info] Iteration: 32, training's : log loss : 0.576210
# [LightGBM] [Info] Iteration: 32, training's : AUC : 0.842747
# [LightGBM] [Info] Iteration: 32, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.598756
# [LightGBM] [Info] Iteration: 32, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.647955
# [LightGBM] [Info] 1315.213292 seconds elapsed, finished iteration 32
# [LightGBM] [Info] Iteration: 33, training's : log loss : 0.573769
# [LightGBM] [Info] Iteration: 33, training's : AUC : 0.844792
# [LightGBM] [Info] Iteration: 33, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.597006
# [LightGBM] [Info] Iteration: 33, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.648364
# [LightGBM] [Info] 1357.477242 seconds elapsed, finished iteration 33
# [LightGBM] [Info] Iteration: 34, training's : log loss : 0.571492
# [LightGBM] [Info] Iteration: 34, training's : AUC : 0.846794
# [LightGBM] [Info] Iteration: 34, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.595145
# [LightGBM] [Info] Iteration: 34, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.648135
# [LightGBM] [Info] 1400.051429 seconds elapsed, finished iteration 34
# [LightGBM] [Info] Iteration: 35, training's : log loss : 0.569170
# [LightGBM] [Info] Iteration: 35, training's : AUC : 0.848285
# [LightGBM] [Info] Iteration: 35, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.593306
# [LightGBM] [Info] Iteration: 35, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.648768
# [LightGBM] [Info] 1441.317440 seconds elapsed, finished iteration 35
# [LightGBM] [Info] Iteration: 36, training's : log loss : 0.566750
# [LightGBM] [Info] Iteration: 36, training's : AUC : 0.850637
# [LightGBM] [Info] Iteration: 36, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.591311
# [LightGBM] [Info] Iteration: 36, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.648620
# [LightGBM] [Info] 1482.457915 seconds elapsed, finished iteration 36
# [LightGBM] [Info] Iteration: 37, training's : log loss : 0.564445
# [LightGBM] [Info] Iteration: 37, training's : AUC : 0.852722
# [LightGBM] [Info] Iteration: 37, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.589554
# [LightGBM] [Info] Iteration: 37, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.648308
# [LightGBM] [Info] 1523.799025 seconds elapsed, finished iteration 37
# [LightGBM] [Info] Iteration: 38, training's : log loss : 0.562097
# [LightGBM] [Info] Iteration: 38, training's : AUC : 0.854477
# [LightGBM] [Info] Iteration: 38, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.587554
# [LightGBM] [Info] Iteration: 38, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.648898
# [LightGBM] [Info] 1567.807085 seconds elapsed, finished iteration 38
# [LightGBM] [Info] Iteration: 39, training's : log loss : 0.559855
# [LightGBM] [Info] Iteration: 39, training's : AUC : 0.856325
# [LightGBM] [Info] Iteration: 39, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.585614
# [LightGBM] [Info] Iteration: 39, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.649138
# [LightGBM] [Info] 1610.919257 seconds elapsed, finished iteration 39
# [LightGBM] [Info] Iteration: 40, training's : log loss : 0.557592
# [LightGBM] [Info] Iteration: 40, training's : AUC : 0.858172
# [LightGBM] [Info] Iteration: 40, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.583800
# [LightGBM] [Info] Iteration: 40, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.648462
# [LightGBM] [Info] 1653.146224 seconds elapsed, finished iteration 40
# [LightGBM] [Info] Iteration: 41, training's : log loss : 0.555487
# [LightGBM] [Info] Iteration: 41, training's : AUC : 0.859735
# [LightGBM] [Info] Iteration: 41, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.582100
# [LightGBM] [Info] Iteration: 41, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.648628
# [LightGBM] [Info] 1695.358381 seconds elapsed, finished iteration 41
# [LightGBM] [Info] Iteration: 42, training's : log loss : 0.553246
# [LightGBM] [Info] Iteration: 42, training's : AUC : 0.861287
# [LightGBM] [Info] Iteration: 42, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.580216
# [LightGBM] [Info] Iteration: 42, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.647733
# [LightGBM] [Info] 1738.491505 seconds elapsed, finished iteration 42
# [LightGBM] [Info] Iteration: 43, training's : log loss : 0.551110
# [LightGBM] [Info] Iteration: 43, training's : AUC : 0.862866
# [LightGBM] [Info] Iteration: 43, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.578577
# [LightGBM] [Info] Iteration: 43, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.648538
# [LightGBM] [Info] 1775.673488 seconds elapsed, finished iteration 43
# [LightGBM] [Info] Iteration: 44, training's : log loss : 0.548994
# [LightGBM] [Info] Iteration: 44, training's : AUC : 0.864196
# [LightGBM] [Info] Iteration: 44, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.576920
# [LightGBM] [Info] Iteration: 44, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.649021
# [LightGBM] [Info] 1815.124747 seconds elapsed, finished iteration 44
# [LightGBM] [Info] Iteration: 45, training's : log loss : 0.547003
# [LightGBM] [Info] Iteration: 45, training's : AUC : 0.865422
# [LightGBM] [Info] Iteration: 45, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.575498
# [LightGBM] [Info] Iteration: 45, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.648413
# [LightGBM] [Info] 1856.895221 seconds elapsed, finished iteration 45
# [LightGBM] [Info] Iteration: 46, training's : log loss : 0.545195
# [LightGBM] [Info] Iteration: 46, training's : AUC : 0.867001
# [LightGBM] [Info] Iteration: 46, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.574049
# [LightGBM] [Info] Iteration: 46, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.647653
# [LightGBM] [Info] 1901.367206 seconds elapsed, finished iteration 46
# [LightGBM] [Info] Iteration: 47, training's : log loss : 0.543398
# [LightGBM] [Info] Iteration: 47, training's : AUC : 0.868770
# [LightGBM] [Info] Iteration: 47, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.572715
# [LightGBM] [Info] Iteration: 47, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.648101
# [LightGBM] [Info] 1944.635925 seconds elapsed, finished iteration 47
# [LightGBM] [Info] Iteration: 48, training's : log loss : 0.541487
# [LightGBM] [Info] Iteration: 48, training's : AUC : 0.870499
# [LightGBM] [Info] Iteration: 48, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.571367
# [LightGBM] [Info] Iteration: 48, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.648469
# [LightGBM] [Info] 1987.627974 seconds elapsed, finished iteration 48
# [LightGBM] [Info] Iteration: 49, training's : log loss : 0.539634
# [LightGBM] [Info] Iteration: 49, training's : AUC : 0.871949
# [LightGBM] [Info] Iteration: 49, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.569783
# [LightGBM] [Info] Iteration: 49, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.648315
# [LightGBM] [Info] 2032.127558 seconds elapsed, finished iteration 49
# [LightGBM] [Info] Iteration: 50, training's : log loss : 0.537754
# [LightGBM] [Info] Iteration: 50, training's : AUC : 0.873241
# [LightGBM] [Info] Iteration: 50, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.568420
# [LightGBM] [Info] Iteration: 50, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.648211
# [LightGBM] [Info] 2071.162920 seconds elapsed, finished iteration 50
# [LightGBM] [Info] Iteration: 51, training's : log loss : 0.535725
# [LightGBM] [Info] Iteration: 51, training's : AUC : 0.874851
# [LightGBM] [Info] Iteration: 51, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.566903
# [LightGBM] [Info] Iteration: 51, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.646890
# [LightGBM] [Info] 2112.870796 seconds elapsed, finished iteration 51
# [LightGBM] [Info] Iteration: 52, training's : log loss : 0.533755
# [LightGBM] [Info] Iteration: 52, training's : AUC : 0.876256
# [LightGBM] [Info] Iteration: 52, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.565495
# [LightGBM] [Info] Iteration: 52, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.648347
# [LightGBM] [Info] 2156.377667 seconds elapsed, finished iteration 52
# [LightGBM] [Info] Iteration: 53, training's : log loss : 0.531815
# [LightGBM] [Info] Iteration: 53, training's : AUC : 0.877636
# [LightGBM] [Info] Iteration: 53, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.564046
# [LightGBM] [Info] Iteration: 53, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.647674
# [LightGBM] [Info] 2201.184428 seconds elapsed, finished iteration 53
# [LightGBM] [Info] Iteration: 54, training's : log loss : 0.529881
# [LightGBM] [Info] Iteration: 54, training's : AUC : 0.878953
# [LightGBM] [Info] Iteration: 54, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.562484
# [LightGBM] [Info] Iteration: 54, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.646923
# [LightGBM] [Info] 2242.625846 seconds elapsed, finished iteration 54
# [LightGBM] [Info] Iteration: 55, training's : log loss : 0.527955
# [LightGBM] [Info] Iteration: 55, training's : AUC : 0.880482
# [LightGBM] [Info] Iteration: 55, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.560844
# [LightGBM] [Info] Iteration: 55, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.647411
# [LightGBM] [Info] 2282.724044 seconds elapsed, finished iteration 55
# [LightGBM] [Info] Iteration: 56, training's : log loss : 0.526076
# [LightGBM] [Info] Iteration: 56, training's : AUC : 0.881834
# [LightGBM] [Info] Iteration: 56, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.559512
# [LightGBM] [Info] Iteration: 56, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.646857
# [LightGBM] [Info] 2325.564437 seconds elapsed, finished iteration 56
# [LightGBM] [Info] Iteration: 57, training's : log loss : 0.524307
# [LightGBM] [Info] Iteration: 57, training's : AUC : 0.882973
# [LightGBM] [Info] Iteration: 57, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.557994
# [LightGBM] [Info] Iteration: 57, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.647483
# [LightGBM] [Info] 2370.238173 seconds elapsed, finished iteration 57
# [LightGBM] [Info] Iteration: 58, training's : log loss : 0.522572
# [LightGBM] [Info] Iteration: 58, training's : AUC : 0.884106
# [LightGBM] [Info] Iteration: 58, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.556466
# [LightGBM] [Info] Iteration: 58, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.647870
# [LightGBM] [Info] 2413.773484 seconds elapsed, finished iteration 58
# [LightGBM] [Info] Iteration: 59, training's : log loss : 0.520812
# [LightGBM] [Info] Iteration: 59, training's : AUC : 0.885295
# [LightGBM] [Info] Iteration: 59, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.555096
# [LightGBM] [Info] Iteration: 59, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.647095
# [LightGBM] [Info] 2454.330289 seconds elapsed, finished iteration 59
# [LightGBM] [Info] Iteration: 60, training's : log loss : 0.519170
# [LightGBM] [Info] Iteration: 60, training's : AUC : 0.886410
# [LightGBM] [Info] Iteration: 60, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.553775
# [LightGBM] [Info] Iteration: 60, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.646845
# [LightGBM] [Info] 2499.003719 seconds elapsed, finished iteration 60
# [LightGBM] [Info] Iteration: 61, training's : log loss : 0.517468
# [LightGBM] [Info] Iteration: 61, training's : AUC : 0.887425
# [LightGBM] [Info] Iteration: 61, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.552379
# [LightGBM] [Info] Iteration: 61, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.647142
# [LightGBM] [Info] 2543.109766 seconds elapsed, finished iteration 61
# [LightGBM] [Info] Iteration: 62, training's : log loss : 0.515781
# [LightGBM] [Info] Iteration: 62, training's : AUC : 0.888789
# [LightGBM] [Info] Iteration: 62, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.550947
# [LightGBM] [Info] Iteration: 62, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.647206
# [LightGBM] [Info] 2582.625921 seconds elapsed, finished iteration 62
# [LightGBM] [Info] Iteration: 63, training's : log loss : 0.514176
# [LightGBM] [Info] Iteration: 63, training's : AUC : 0.889803
# [LightGBM] [Info] Iteration: 63, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.549960
# [LightGBM] [Info] Iteration: 63, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.646465
# [LightGBM] [Info] 2624.538769 seconds elapsed, finished iteration 63
# [LightGBM] [Info] Iteration: 64, training's : log loss : 0.512674
# [LightGBM] [Info] Iteration: 64, training's : AUC : 0.890924
# [LightGBM] [Info] Iteration: 64, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.548778
# [LightGBM] [Info] Iteration: 64, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.646316
# [LightGBM] [Info] 2670.754708 seconds elapsed, finished iteration 64
# [LightGBM] [Info] Iteration: 65, training's : log loss : 0.511113
# [LightGBM] [Info] Iteration: 65, training's : AUC : 0.892013
# [LightGBM] [Info] Iteration: 65, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.547551
# [LightGBM] [Info] Iteration: 65, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.646232
# [LightGBM] [Info] 2712.941422 seconds elapsed, finished iteration 65
# [LightGBM] [Info] Iteration: 66, training's : log loss : 0.509565
# [LightGBM] [Info] Iteration: 66, training's : AUC : 0.893179
# [LightGBM] [Info] Iteration: 66, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.546407
# [LightGBM] [Info] Iteration: 66, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.646154
# [LightGBM] [Info] 2757.738816 seconds elapsed, finished iteration 66
# [LightGBM] [Info] Iteration: 67, training's : log loss : 0.508017
# [LightGBM] [Info] Iteration: 67, training's : AUC : 0.894481
# [LightGBM] [Info] Iteration: 67, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.545371
# [LightGBM] [Info] Iteration: 67, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.644872
# [LightGBM] [Info] 2801.463743 seconds elapsed, finished iteration 67
# [LightGBM] [Info] Iteration: 68, training's : log loss : 0.506520
# [LightGBM] [Info] Iteration: 68, training's : AUC : 0.895517
# [LightGBM] [Info] Iteration: 68, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.544437
# [LightGBM] [Info] Iteration: 68, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.644546
# [LightGBM] [Info] 2843.410402 seconds elapsed, finished iteration 68
# [LightGBM] [Info] Iteration: 69, training's : log loss : 0.505033
# [LightGBM] [Info] Iteration: 69, training's : AUC : 0.896712
# [LightGBM] [Info] Iteration: 69, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.543257
# [LightGBM] [Info] Iteration: 69, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.644406
# [LightGBM] [Info] 2890.718238 seconds elapsed, finished iteration 69
# [LightGBM] [Info] Iteration: 70, training's : log loss : 0.503502
# [LightGBM] [Info] Iteration: 70, training's : AUC : 0.897821
# [LightGBM] [Info] Iteration: 70, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.542183
# [LightGBM] [Info] Iteration: 70, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.644179
# [LightGBM] [Info] 2932.044544 seconds elapsed, finished iteration 70
# [LightGBM] [Info] Iteration: 71, training's : log loss : 0.502101
# [LightGBM] [Info] Iteration: 71, training's : AUC : 0.898813
# [LightGBM] [Info] Iteration: 71, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.541069
# [LightGBM] [Info] Iteration: 71, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.643735
# [LightGBM] [Info] 2976.855278 seconds elapsed, finished iteration 71
# [LightGBM] [Info] Iteration: 72, training's : log loss : 0.500652
# [LightGBM] [Info] Iteration: 72, training's : AUC : 0.899784
# [LightGBM] [Info] Iteration: 72, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.540096
# [LightGBM] [Info] Iteration: 72, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.643160
# [LightGBM] [Info] 3020.566986 seconds elapsed, finished iteration 72
# [LightGBM] [Info] Iteration: 73, training's : log loss : 0.499217
# [LightGBM] [Info] Iteration: 73, training's : AUC : 0.900712
# [LightGBM] [Info] Iteration: 73, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.539067
# [LightGBM] [Info] Iteration: 73, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.642232
# [LightGBM] [Info] 3064.249374 seconds elapsed, finished iteration 73
# [LightGBM] [Info] Iteration: 74, training's : log loss : 0.497769
# [LightGBM] [Info] Iteration: 74, training's : AUC : 0.901863
# [LightGBM] [Info] Iteration: 74, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.537952
# [LightGBM] [Info] Iteration: 74, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.642372
# [LightGBM] [Info] 3106.924957 seconds elapsed, finished iteration 74
# [LightGBM] [Info] Iteration: 75, training's : log loss : 0.496394
# [LightGBM] [Info] Iteration: 75, training's : AUC : 0.902717
# [LightGBM] [Info] Iteration: 75, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.536969
# [LightGBM] [Info] Iteration: 75, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.641290
# [LightGBM] [Info] 3151.485758 seconds elapsed, finished iteration 75
# [LightGBM] [Info] Iteration: 76, training's : log loss : 0.495133
# [LightGBM] [Info] Iteration: 76, training's : AUC : 0.903673
# [LightGBM] [Info] Iteration: 76, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.536201
# [LightGBM] [Info] Iteration: 76, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.640856
# [LightGBM] [Info] 3196.950719 seconds elapsed, finished iteration 76
# [LightGBM] [Info] Iteration: 77, training's : log loss : 0.493736
# [LightGBM] [Info] Iteration: 77, training's : AUC : 0.904580
# [LightGBM] [Info] Iteration: 77, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.535118
# [LightGBM] [Info] Iteration: 77, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.640512
# [LightGBM] [Info] 3239.636932 seconds elapsed, finished iteration 77
# [LightGBM] [Info] Iteration: 78, training's : log loss : 0.492405
# [LightGBM] [Info] Iteration: 78, training's : AUC : 0.905410
# [LightGBM] [Info] Iteration: 78, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.534140
# [LightGBM] [Info] Iteration: 78, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.640231
# [LightGBM] [Info] 3283.054473 seconds elapsed, finished iteration 78
# [LightGBM] [Info] Iteration: 79, training's : log loss : 0.491130
# [LightGBM] [Info] Iteration: 79, training's : AUC : 0.906336
# [LightGBM] [Info] Iteration: 79, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.533346
# [LightGBM] [Info] Iteration: 79, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.639830
# [LightGBM] [Info] 3325.246814 seconds elapsed, finished iteration 79
# [LightGBM] [Info] Iteration: 80, training's : log loss : 0.489830
# [LightGBM] [Info] Iteration: 80, training's : AUC : 0.907163
# [LightGBM] [Info] Iteration: 80, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.532394
# [LightGBM] [Info] Iteration: 80, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.640417
# [LightGBM] [Info] 3374.787536 seconds elapsed, finished iteration 80
# [LightGBM] [Info] Iteration: 81, training's : log loss : 0.488375
# [LightGBM] [Info] Iteration: 81, training's : AUC : 0.907962
# [LightGBM] [Info] Iteration: 81, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.531094
# [LightGBM] [Info] Iteration: 81, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.639938
# [LightGBM] [Info] 3417.533916 seconds elapsed, finished iteration 81
# [LightGBM] [Info] Iteration: 82, training's : log loss : 0.487042
# [LightGBM] [Info] Iteration: 82, training's : AUC : 0.908701
# [LightGBM] [Info] Iteration: 82, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.530243
# [LightGBM] [Info] Iteration: 82, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.639212
# [LightGBM] [Info] 3463.785361 seconds elapsed, finished iteration 82
# [LightGBM] [Info] Iteration: 83, training's : log loss : 0.485527
# [LightGBM] [Info] Iteration: 83, training's : AUC : 0.909689
# [LightGBM] [Info] Iteration: 83, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.528946
# [LightGBM] [Info] Iteration: 83, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.639430
# [LightGBM] [Info] 3507.167320 seconds elapsed, finished iteration 83
# [LightGBM] [Info] Iteration: 84, training's : log loss : 0.484291
# [LightGBM] [Info] Iteration: 84, training's : AUC : 0.910428
# [LightGBM] [Info] Iteration: 84, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.527972
# [LightGBM] [Info] Iteration: 84, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.639614
# [LightGBM] [Info] 3555.990143 seconds elapsed, finished iteration 84
# [LightGBM] [Info] Iteration: 85, training's : log loss : 0.482870
# [LightGBM] [Info] Iteration: 85, training's : AUC : 0.911247
# [LightGBM] [Info] Iteration: 85, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.526832
# [LightGBM] [Info] Iteration: 85, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.639294
# [LightGBM] [Info] 3602.469613 seconds elapsed, finished iteration 85
# [LightGBM] [Info] Iteration: 86, training's : log loss : 0.481600
# [LightGBM] [Info] Iteration: 86, training's : AUC : 0.912127
# [LightGBM] [Info] Iteration: 86, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.525886
# [LightGBM] [Info] Iteration: 86, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.638727
# [LightGBM] [Info] 3645.861773 seconds elapsed, finished iteration 86
# [LightGBM] [Info] Iteration: 87, training's : log loss : 0.480323
# [LightGBM] [Info] Iteration: 87, training's : AUC : 0.912931
# [LightGBM] [Info] Iteration: 87, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.524874
# [LightGBM] [Info] Iteration: 87, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.638477
# [LightGBM] [Info] 3687.405755 seconds elapsed, finished iteration 87
# [LightGBM] [Info] Iteration: 88, training's : log loss : 0.479053
# [LightGBM] [Info] Iteration: 88, training's : AUC : 0.913544
# [LightGBM] [Info] Iteration: 88, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.523875
# [LightGBM] [Info] Iteration: 88, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.639099
# [LightGBM] [Info] 3729.868061 seconds elapsed, finished iteration 88
# [LightGBM] [Info] Iteration: 89, training's : log loss : 0.477740
# [LightGBM] [Info] Iteration: 89, training's : AUC : 0.914162
# [LightGBM] [Info] Iteration: 89, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.522738
# [LightGBM] [Info] Iteration: 89, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.639218
# [LightGBM] [Info] 3773.069371 seconds elapsed, finished iteration 89
# [LightGBM] [Info] Iteration: 90, training's : log loss : 0.476592
# [LightGBM] [Info] Iteration: 90, training's : AUC : 0.914846
# [LightGBM] [Info] Iteration: 90, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.521937
# [LightGBM] [Info] Iteration: 90, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.638263
# [LightGBM] [Info] 3819.466435 seconds elapsed, finished iteration 90
# [LightGBM] [Info] Iteration: 91, training's : log loss : 0.475398
# [LightGBM] [Info] Iteration: 91, training's : AUC : 0.915558
# [LightGBM] [Info] Iteration: 91, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.520961
# [LightGBM] [Info] Iteration: 91, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.637727
# [LightGBM] [Info] 3865.331464 seconds elapsed, finished iteration 91
# [LightGBM] [Info] Iteration: 92, training's : log loss : 0.474094
# [LightGBM] [Info] Iteration: 92, training's : AUC : 0.916303
# [LightGBM] [Info] Iteration: 92, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.519766
# [LightGBM] [Info] Iteration: 92, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.637782
# [LightGBM] [Info] 3911.745612 seconds elapsed, finished iteration 92
# [LightGBM] [Info] Iteration: 93, training's : log loss : 0.472835
# [LightGBM] [Info] Iteration: 93, training's : AUC : 0.917056
# [LightGBM] [Info] Iteration: 93, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.518800
# [LightGBM] [Info] Iteration: 93, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.638610
# [LightGBM] [Info] 3955.069045 seconds elapsed, finished iteration 93
# [LightGBM] [Info] Iteration: 94, training's : log loss : 0.471571
# [LightGBM] [Info] Iteration: 94, training's : AUC : 0.917623
# [LightGBM] [Info] Iteration: 94, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.517894
# [LightGBM] [Info] Iteration: 94, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.638109
# [LightGBM] [Info] 3999.935535 seconds elapsed, finished iteration 94
# [LightGBM] [Info] Iteration: 95, training's : log loss : 0.470341
# [LightGBM] [Info] Iteration: 95, training's : AUC : 0.918300
# [LightGBM] [Info] Iteration: 95, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.516954
# [LightGBM] [Info] Iteration: 95, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.638007
# [LightGBM] [Info] 4048.994471 seconds elapsed, finished iteration 95
# [LightGBM] [Info] Iteration: 96, training's : log loss : 0.468998
# [LightGBM] [Info] Iteration: 96, training's : AUC : 0.918962
# [LightGBM] [Info] Iteration: 96, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.515908
# [LightGBM] [Info] Iteration: 96, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.637468
# [LightGBM] [Info] 4094.632508 seconds elapsed, finished iteration 96
# [LightGBM] [Info] Iteration: 97, training's : log loss : 0.467524
# [LightGBM] [Info] Iteration: 97, training's : AUC : 0.919705
# [LightGBM] [Info] Iteration: 97, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.514692
# [LightGBM] [Info] Iteration: 97, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.637331
# [LightGBM] [Info] 4135.249567 seconds elapsed, finished iteration 97
# [LightGBM] [Info] Iteration: 98, training's : log loss : 0.466237
# [LightGBM] [Info] Iteration: 98, training's : AUC : 0.920280
# [LightGBM] [Info] Iteration: 98, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.513650
# [LightGBM] [Info] Iteration: 98, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.636729
# [LightGBM] [Info] 4186.607549 seconds elapsed, finished iteration 98
# [LightGBM] [Info] Iteration: 99, training's : log loss : 0.464933
# [LightGBM] [Info] Iteration: 99, training's : AUC : 0.920942
# [LightGBM] [Info] Iteration: 99, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.512519
# [LightGBM] [Info] Iteration: 99, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.636150
# [LightGBM] [Info] 4227.904141 seconds elapsed, finished iteration 99
# [LightGBM] [Info] Iteration: 100, training's : log loss : 0.463575
# [LightGBM] [Info] Iteration: 100, training's : AUC : 0.921547
# [LightGBM] [Info] Iteration: 100, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.511413
# [LightGBM] [Info] Iteration: 100, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.636619
# [LightGBM] [Info] 4272.628376 seconds elapsed, finished iteration 100
# [LightGBM] [Info] Iteration: 101, training's : log loss : 0.462456
# [LightGBM] [Info] Iteration: 101, training's : AUC : 0.922178
# [LightGBM] [Info] Iteration: 101, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.510417
# [LightGBM] [Info] Iteration: 101, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.636613
# [LightGBM] [Info] 4314.962970 seconds elapsed, finished iteration 101
# [LightGBM] [Info] Iteration: 102, training's : log loss : 0.461249
# [LightGBM] [Info] Iteration: 102, training's : AUC : 0.922918
# [LightGBM] [Info] Iteration: 102, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.509487
# [LightGBM] [Info] Iteration: 102, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.636388
# [LightGBM] [Info] 4356.434636 seconds elapsed, finished iteration 102
# [LightGBM] [Info] Iteration: 103, training's : log loss : 0.460065
# [LightGBM] [Info] Iteration: 103, training's : AUC : 0.923505
# [LightGBM] [Info] Iteration: 103, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.508650
# [LightGBM] [Info] Iteration: 103, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.636108
# [LightGBM] [Info] 4394.405122 seconds elapsed, finished iteration 103
# [LightGBM] [Info] Iteration: 104, training's : log loss : 0.458894
# [LightGBM] [Info] Iteration: 104, training's : AUC : 0.924072
# [LightGBM] [Info] Iteration: 104, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.507738
# [LightGBM] [Info] Iteration: 104, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.635984
# [LightGBM] [Info] 4436.005953 seconds elapsed, finished iteration 104
# [LightGBM] [Info] Iteration: 105, training's : log loss : 0.457807
# [LightGBM] [Info] Iteration: 105, training's : AUC : 0.924681
# [LightGBM] [Info] Iteration: 105, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.507042
# [LightGBM] [Info] Iteration: 105, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.635412
# [LightGBM] [Info] 4483.462773 seconds elapsed, finished iteration 105
# [LightGBM] [Info] Iteration: 106, training's : log loss : 0.456849
# [LightGBM] [Info] Iteration: 106, training's : AUC : 0.925347
# [LightGBM] [Info] Iteration: 106, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.506353
# [LightGBM] [Info] Iteration: 106, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.634692
# [LightGBM] [Info] 4530.077830 seconds elapsed, finished iteration 106
# [LightGBM] [Info] Iteration: 107, training's : log loss : 0.455924
# [LightGBM] [Info] Iteration: 107, training's : AUC : 0.925855
# [LightGBM] [Info] Iteration: 107, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.505577
# [LightGBM] [Info] Iteration: 107, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.634542
# [LightGBM] [Info] 4574.199646 seconds elapsed, finished iteration 107
# [LightGBM] [Info] Iteration: 108, training's : log loss : 0.454833
# [LightGBM] [Info] Iteration: 108, training's : AUC : 0.926424
# [LightGBM] [Info] Iteration: 108, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.504758
# [LightGBM] [Info] Iteration: 108, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.633998
# [LightGBM] [Info] 4621.555583 seconds elapsed, finished iteration 108
# [LightGBM] [Info] Iteration: 109, training's : log loss : 0.453790
# [LightGBM] [Info] Iteration: 109, training's : AUC : 0.926877
# [LightGBM] [Info] Iteration: 109, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.503875
# [LightGBM] [Info] Iteration: 109, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.634001
# [LightGBM] [Info] 4670.140570 seconds elapsed, finished iteration 109
# [LightGBM] [Info] Iteration: 110, training's : log loss : 0.452775
# [LightGBM] [Info] Iteration: 110, training's : AUC : 0.927316
# [LightGBM] [Info] Iteration: 110, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.503155
# [LightGBM] [Info] Iteration: 110, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.633052
# [LightGBM] [Info] 4717.340303 seconds elapsed, finished iteration 110
# [LightGBM] [Info] Iteration: 111, training's : log loss : 0.451714
# [LightGBM] [Info] Iteration: 111, training's : AUC : 0.927894
# [LightGBM] [Info] Iteration: 111, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.502305
# [LightGBM] [Info] Iteration: 111, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.632801
# [LightGBM] [Info] 4766.071693 seconds elapsed, finished iteration 111
# [LightGBM] [Info] Iteration: 112, training's : log loss : 0.450577
# [LightGBM] [Info] Iteration: 112, training's : AUC : 0.928470
# [LightGBM] [Info] Iteration: 112, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.501651
# [LightGBM] [Info] Iteration: 112, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.632466
# [LightGBM] [Info] 4812.830180 seconds elapsed, finished iteration 112
# [LightGBM] [Info] Iteration: 113, training's : log loss : 0.449577
# [LightGBM] [Info] Iteration: 113, training's : AUC : 0.928942
# [LightGBM] [Info] Iteration: 113, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.500950
# [LightGBM] [Info] Iteration: 113, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.632314
# [LightGBM] [Info] 4859.572793 seconds elapsed, finished iteration 113
# [LightGBM] [Info] Iteration: 114, training's : log loss : 0.448550
# [LightGBM] [Info] Iteration: 114, training's : AUC : 0.929511
# [LightGBM] [Info] Iteration: 114, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.500173
# [LightGBM] [Info] Iteration: 114, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.632698
# [LightGBM] [Info] 4904.543117 seconds elapsed, finished iteration 114
# [LightGBM] [Info] Iteration: 115, training's : log loss : 0.447574
# [LightGBM] [Info] Iteration: 115, training's : AUC : 0.929974
# [LightGBM] [Info] Iteration: 115, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.499464
# [LightGBM] [Info] Iteration: 115, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.632109
# [LightGBM] [Info] 4951.452504 seconds elapsed, finished iteration 115
# [LightGBM] [Info] Iteration: 116, training's : log loss : 0.446193
# [LightGBM] [Info] Iteration: 116, training's : AUC : 0.931104
# [LightGBM] [Info] Iteration: 116, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.498394
# [LightGBM] [Info] Iteration: 116, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.632821
# [LightGBM] [Info] 4985.561053 seconds elapsed, finished iteration 116
# [LightGBM] [Info] Iteration: 117, training's : log loss : 0.444960
# [LightGBM] [Info] Iteration: 117, training's : AUC : 0.931875
# [LightGBM] [Info] Iteration: 117, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.497417
# [LightGBM] [Info] Iteration: 117, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.633212
# [LightGBM] [Info] 5021.489909 seconds elapsed, finished iteration 117
# [LightGBM] [Info] Iteration: 118, training's : log loss : 0.443679
# [LightGBM] [Info] Iteration: 118, training's : AUC : 0.932652
# [LightGBM] [Info] Iteration: 118, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.496467
# [LightGBM] [Info] Iteration: 118, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.633250
# [LightGBM] [Info] 5060.643044 seconds elapsed, finished iteration 118
# [LightGBM] [Info] Iteration: 119, training's : log loss : 0.442573
# [LightGBM] [Info] Iteration: 119, training's : AUC : 0.933137
# [LightGBM] [Info] Iteration: 119, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.495447
# [LightGBM] [Info] Iteration: 119, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.633920
# [LightGBM] [Info] 5107.320100 seconds elapsed, finished iteration 119
# [LightGBM] [Info] Iteration: 120, training's : log loss : 0.441555
# ...
# [LightGBM] [Info] Iteration: 162, training's : log loss : 0.404636
# [LightGBM] [Info] Iteration: 162, training's : AUC : 0.950344
# [LightGBM] [Info] Iteration: 162, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.467411
# [LightGBM] [Info] Iteration: 162, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.621322
# [LightGBM] [Info] 7034.275488 seconds elapsed, finished iteration 162
# [LightGBM] [Info] Iteration: 163, training's : log loss : 0.404027
# [LightGBM] [Info] Iteration: 163, training's : AUC : 0.950650
# [LightGBM] [Info] Iteration: 163, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.467152
# [LightGBM] [Info] Iteration: 163, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.620627
# [LightGBM] [Info] 7085.163567 seconds elapsed, finished iteration 163
# [LightGBM] [Info] Iteration: 164, training's : log loss : 0.403404
# [LightGBM] [Info] Iteration: 164, training's : AUC : 0.950965
# [LightGBM] [Info] Iteration: 164, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.466728
# [LightGBM] [Info] Iteration: 164, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.620028
# [LightGBM] [Info] 7131.606836 seconds elapsed, finished iteration 164
# [LightGBM] [Info] Iteration: 165, training's : log loss : 0.402787
# [LightGBM] [Info] Iteration: 165, training's : AUC : 0.951242
# [LightGBM] [Info] Iteration: 165, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.466317
# [LightGBM] [Info] Iteration: 165, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.619413
# [LightGBM] [Info] 7175.948634 seconds elapsed, finished iteration 165
# [LightGBM] [Info] Iteration: 166, training's : log loss : 0.402025
# [LightGBM] [Info] Iteration: 166, training's : AUC : 0.951515
# [LightGBM] [Info] Iteration: 166, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.465829
# [LightGBM] [Info] Iteration: 166, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.619412
# [LightGBM] [Info] 7220.861479 seconds elapsed, finished iteration 166
# [LightGBM] [Info] Iteration: 167, training's : log loss : 0.401071
# [LightGBM] [Info] Iteration: 167, training's : AUC : 0.951939
# [LightGBM] [Info] Iteration: 167, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.465114
# [LightGBM] [Info] Iteration: 167, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.619000
# [LightGBM] [Info] 7254.907168 seconds elapsed, finished iteration 167
# [LightGBM] [Info] Iteration: 168, training's : log loss : 0.400268
# [LightGBM] [Info] Iteration: 168, training's : AUC : 0.952267
# [LightGBM] [Info] Iteration: 168, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.464518
# [LightGBM] [Info] Iteration: 168, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.618906
# [LightGBM] [Info] 7301.559924 seconds elapsed, finished iteration 168
# [LightGBM] [Info] Iteration: 169, training's : log loss : 0.399469
# [LightGBM] [Info] Iteration: 169, training's : AUC : 0.952535
# [LightGBM] [Info] Iteration: 169, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.463972
# [LightGBM] [Info] Iteration: 169, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.619015
# [LightGBM] [Info] 7345.134493 seconds elapsed, finished iteration 169
# [LightGBM] [Info] Iteration: 170, training's : log loss : 0.398751
# [LightGBM] [Info] Iteration: 170, training's : AUC : 0.952829
# [LightGBM] [Info] Iteration: 170, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.463533
# [LightGBM] [Info] Iteration: 170, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.618560
# [LightGBM] [Info] 7389.850176 seconds elapsed, finished iteration 170
# [LightGBM] [Info] Iteration: 171, training's : log loss : 0.397931
# [LightGBM] [Info] Iteration: 171, training's : AUC : 0.953093
# [LightGBM] [Info] Iteration: 171, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.462943
# [LightGBM] [Info] Iteration: 171, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.618219
# [LightGBM] [Info] 7433.879830 seconds elapsed, finished iteration 171
# [LightGBM] [Info] Iteration: 172, training's : log loss : 0.397170
# [LightGBM] [Info] Iteration: 172, training's : AUC : 0.953334
# [LightGBM] [Info] Iteration: 172, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.462463
# [LightGBM] [Info] Iteration: 172, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.617943
# [LightGBM] [Info] 7479.996627 seconds elapsed, finished iteration 172
# [LightGBM] [Info] Iteration: 173, training's : log loss : 0.396493
# [LightGBM] [Info] Iteration: 173, training's : AUC : 0.953692
# [LightGBM] [Info] Iteration: 173, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.462035
# [LightGBM] [Info] Iteration: 173, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.617411
# [LightGBM] [Info] 7526.621956 seconds elapsed, finished iteration 173
# [LightGBM] [Info] Iteration: 174, training's : log loss : 0.395712
# [LightGBM] [Info] Iteration: 174, training's : AUC : 0.953941
# [LightGBM] [Info] Iteration: 174, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.461503
# [LightGBM] [Info] Iteration: 174, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.616892
# [LightGBM] [Info] 7571.136816 seconds elapsed, finished iteration 174
# [LightGBM] [Info] Iteration: 175, training's : log loss : 0.394925
# [LightGBM] [Info] Iteration: 175, training's : AUC : 0.954185
# [LightGBM] [Info] Iteration: 175, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.461012
# [LightGBM] [Info] Iteration: 175, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.616654
# [LightGBM] [Info] 7616.332886 seconds elapsed, finished iteration 175
# [LightGBM] [Info] Iteration: 176, training's : log loss : 0.394312
# [LightGBM] [Info] Iteration: 176, training's : AUC : 0.954461
# [LightGBM] [Info] Iteration: 176, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.460580
# [LightGBM] [Info] Iteration: 176, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.616045
# [LightGBM] [Info] 7663.745768 seconds elapsed, finished iteration 176
# [LightGBM] [Info] Iteration: 177, training's : log loss : 0.393718
# [LightGBM] [Info] Iteration: 177, training's : AUC : 0.954768
# [LightGBM] [Info] Iteration: 177, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.460200
# [LightGBM] [Info] Iteration: 177, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.615467
# [LightGBM] [Info] 7710.617892 seconds elapsed, finished iteration 177
# [LightGBM] [Info] Iteration: 178, training's : log loss : 0.393054
# [LightGBM] [Info] Iteration: 178, training's : AUC : 0.955061
# [LightGBM] [Info] Iteration: 178, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.459804
# [LightGBM] [Info] Iteration: 178, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.614790
# [LightGBM] [Info] 7753.706279 seconds elapsed, finished iteration 178
# [LightGBM] [Info] Iteration: 179, training's : log loss : 0.392239
# [LightGBM] [Info] Iteration: 179, training's : AUC : 0.955461
# [LightGBM] [Info] Iteration: 179, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.459160
# [LightGBM] [Info] Iteration: 179, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.614703
# [LightGBM] [Info] 7797.783246 seconds elapsed, finished iteration 179
# [LightGBM] [Info] Iteration: 180, training's : log loss : 0.391536
# [LightGBM] [Info] Iteration: 180, training's : AUC : 0.955765
# [LightGBM] [Info] Iteration: 180, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.458701
# [LightGBM] [Info] Iteration: 180, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.614476
# [LightGBM] [Info] 7842.250804 seconds elapsed, finished iteration 180
# [LightGBM] [Info] Iteration: 181, training's : log loss : 0.390747
# [LightGBM] [Info] Iteration: 181, training's : AUC : 0.956115
# [LightGBM] [Info] Iteration: 181, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.458037
# [LightGBM] [Info] Iteration: 181, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.614686
# [LightGBM] [Info] 7889.023402 seconds elapsed, finished iteration 181
# [LightGBM] [Info] Iteration: 182, training's : log loss : 0.389935
# [LightGBM] [Info] Iteration: 182, training's : AUC : 0.956478
# [LightGBM] [Info] Iteration: 182, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.457436
# [LightGBM] [Info] Iteration: 182, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.614692
# [LightGBM] [Info] 7931.053702 seconds elapsed, finished iteration 182
# [LightGBM] [Info] Iteration: 183, training's : log loss : 0.389267
# [LightGBM] [Info] Iteration: 183, training's : AUC : 0.956658
# [LightGBM] [Info] Iteration: 183, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.456842
# [LightGBM] [Info] Iteration: 183, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.614370
# [LightGBM] [Info] 7973.621214 seconds elapsed, finished iteration 183
# [LightGBM] [Info] Iteration: 184, training's : log loss : 0.388465
# [LightGBM] [Info] Iteration: 184, training's : AUC : 0.956878
# [LightGBM] [Info] Iteration: 184, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.456183
# [LightGBM] [Info] Iteration: 184, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.614242
# [LightGBM] [Info] 8017.829767 seconds elapsed, finished iteration 184
# [LightGBM] [Info] Iteration: 185, training's : log loss : 0.387739
# [LightGBM] [Info] Iteration: 185, training's : AUC : 0.957155
# [LightGBM] [Info] Iteration: 185, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.455716
# [LightGBM] [Info] Iteration: 185, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.613422
# [LightGBM] [Info] 8062.949788 seconds elapsed, finished iteration 185
# [LightGBM] [Info] Iteration: 186, training's : log loss : 0.387008
# [LightGBM] [Info] Iteration: 186, training's : AUC : 0.957375
# [LightGBM] [Info] Iteration: 186, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.455200
# [LightGBM] [Info] Iteration: 186, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.613179
# [LightGBM] [Info] 8109.305512 seconds elapsed, finished iteration 186
# [LightGBM] [Info] Iteration: 187, training's : log loss : 0.386359
# [LightGBM] [Info] Iteration: 187, training's : AUC : 0.957542
# [LightGBM] [Info] Iteration: 187, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.454816
# [LightGBM] [Info] Iteration: 187, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.612882
# [LightGBM] [Info] 8157.584391 seconds elapsed, finished iteration 187
# [LightGBM] [Info] Iteration: 188, training's : log loss : 0.385711
# [LightGBM] [Info] Iteration: 188, training's : AUC : 0.957736
# [LightGBM] [Info] Iteration: 188, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.454434
# [LightGBM] [Info] Iteration: 188, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.612674
# [LightGBM] [Info] 8204.570915 seconds elapsed, finished iteration 188
# [LightGBM] [Info] Iteration: 189, training's : log loss : 0.385011
# [LightGBM] [Info] Iteration: 189, training's : AUC : 0.957943
# [LightGBM] [Info] Iteration: 189, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.453999
# [LightGBM] [Info] Iteration: 189, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.612790
# [LightGBM] [Info] 8250.128673 seconds elapsed, finished iteration 189
# [LightGBM] [Info] Iteration: 190, training's : log loss : 0.384231
# [LightGBM] [Info] Iteration: 190, training's : AUC : 0.958177
# [LightGBM] [Info] Iteration: 190, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.453471
# [LightGBM] [Info] Iteration: 190, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.612796
# [LightGBM] [Info] 8291.257233 seconds elapsed, finished iteration 190
# [LightGBM] [Info] Iteration: 191, training's : log loss : 0.383605
# [LightGBM] [Info] Iteration: 191, training's : AUC : 0.958394
# [LightGBM] [Info] Iteration: 191, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.452962
# [LightGBM] [Info] Iteration: 191, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.612710
# [LightGBM] [Info] 8335.841792 seconds elapsed, finished iteration 191
# [LightGBM] [Info] Iteration: 192, training's : log loss : 0.383017
# [LightGBM] [Info] Iteration: 192, training's : AUC : 0.958641
# [LightGBM] [Info] Iteration: 192, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.452536
# [LightGBM] [Info] Iteration: 192, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.612852
# [LightGBM] [Info] 8381.143151 seconds elapsed, finished iteration 192
# [LightGBM] [Info] Iteration: 193, training's : log loss : 0.382362
# [LightGBM] [Info] Iteration: 193, training's : AUC : 0.958874
# [LightGBM] [Info] Iteration: 193, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.452101
# [LightGBM] [Info] Iteration: 193, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.612400
# [LightGBM] [Info] 8423.558263 seconds elapsed, finished iteration 193
# [LightGBM] [Info] Iteration: 194, training's : log loss : 0.381734
# [LightGBM] [Info] Iteration: 194, training's : AUC : 0.959112
# [LightGBM] [Info] Iteration: 194, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.451608
# [LightGBM] [Info] Iteration: 194, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.612305
# [LightGBM] [Info] 8468.117696 seconds elapsed, finished iteration 194
# [LightGBM] [Info] Iteration: 195, training's : log loss : 0.381109
# [LightGBM] [Info] Iteration: 195, training's : AUC : 0.959358
# [LightGBM] [Info] Iteration: 195, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.451157
# [LightGBM] [Info] Iteration: 195, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.612214
# [LightGBM] [Info] 8513.466752 seconds elapsed, finished iteration 195
# [LightGBM] [Info] Iteration: 196, training's : log loss : 0.380272
# [LightGBM] [Info] Iteration: 196, training's : AUC : 0.959754
# [LightGBM] [Info] Iteration: 196, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.450492
# [LightGBM] [Info] Iteration: 196, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.612537
# [LightGBM] [Info] 8547.653407 seconds elapsed, finished iteration 196
# [LightGBM] [Info] Iteration: 197, training's : log loss : 0.379535
# [LightGBM] [Info] Iteration: 197, training's : AUC : 0.960024
# [LightGBM] [Info] Iteration: 197, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.449916
# [LightGBM] [Info] Iteration: 197, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.612396
# [LightGBM] [Info] 8588.354970 seconds elapsed, finished iteration 197
# [LightGBM] [Info] Iteration: 198, training's : log loss : 0.378918
# [LightGBM] [Info] Iteration: 198, training's : AUC : 0.960251
# [LightGBM] [Info] Iteration: 198, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.449515
# [LightGBM] [Info] Iteration: 198, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.611886
# [LightGBM] [Info] 8633.112986 seconds elapsed, finished iteration 198
# [LightGBM] [Info] Iteration: 199, training's : log loss : 0.378165
# [LightGBM] [Info] Iteration: 199, training's : AUC : 0.960494
# [LightGBM] [Info] Iteration: 199, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.448895
# [LightGBM] [Info] Iteration: 199, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.612263
# [LightGBM] [Info] 8678.208567 seconds elapsed, finished iteration 199
# [LightGBM] [Info] Iteration: 200, training's : log loss : 0.377506
# [LightGBM] [Info] Iteration: 200, training's : AUC : 0.960708
# [LightGBM] [Info] Iteration: 200, /data1/share/kosm/data/url_text_valid_libsvm.txt's : log loss : 0.448445
# [LightGBM] [Info] Iteration: 200, /data1/share/kosm/data/url_text_valid_libsvm.txt's : AUC : 0.612055
# [LightGBM] [Info] 8726.857298 seconds elapsed, finished iteration 200
# [LightGBM] [Info] Finished training

# %%
class LGBM:
    
    '''
    My wrapper for LightGBM.
    https://github.com/Microsoft/LightGBM
    '''
    
    import os
    
    
    def set_params(self, param_dict = {}):
        '''
        Установить параметры для конфигурационного файла.
        '''
        
        train_conf_str = '''
        # task type, support train and predict
        task = train
        
        # boosting type, support gbdt for now, alias: boosting, boost
        boosting_type = gbdt
        
        # application type, support following application
        # regression , regression task
        # binary , binary classification task
        # lambdarank , lambdarank task
        # alias: application, app
        objective = binary

        # eval metrics, support multi metric, delimite by ',' , support following metrics
        # l1 
        # l2 , default metric for regression
        # ndcg , default metric for lambdarank
        # auc 
        # binary_logloss , default metric for binary
        # binary_error
        metric = auc,binary_logloss
        
        # frequence for metric output
        metric_freq = 1
        
        # true if need output metric for training data, alias: tranining_metric, train_metric
        is_training_metric = true
        
        # number of bins for feature bucket, 255 is a recommend setting, it can save memories, and also has good accuracy. 
        max_bin = 255
        
        # training data
        # if exsting weight file, should name to "binary.train.weight"
        # alias: train_data, train
        #data = binary.train
        
        # validation data, support multi validation data, separated by ','
        # if exsting weight file, should name to "binary.test.weight"
        # alias: valid, test, test_data, 
        #valid_data = binary.test
        
        # number of trees(iterations), alias: num_tree, num_iteration, num_iterations, num_round, num_rounds
        num_trees = 200
        
        # shrinkage rate , alias: shrinkage_rate
        learning_rate = 0.05
        
        # number of leaves for one tree, alias: num_leaf
        num_leaves = 127
        
        # type of tree learner, support following types:
        # serial , single machine version
        # feature , use feature parallel to train
        # data , use data parallel to train
        # voting , use voting based parallel to train
        # alias: tree
        tree_learner = data
        
        # number of threads for multi-threading. One thread will use one CPU, defalut is setted to #cpu. 
        # num_threads = 8
        
        # feature sub-sample, will random select 80% feature to train on each iteration 
        # alias: sub_feature
        feature_fraction = 0.8
        
        #classes are unbalanced
        is_unbalance = true
        
        # Support bagging (data sub-sample), will perform bagging every 5 iterations
        bagging_freq = 5
        
        # Bagging farction, will random select 80% data on bagging
        # alias: sub_row
        bagging_fraction = 0.8
        
        # minimal number data for one leaf, use this to deal with over-fit
        # alias : min_data_per_leaf, min_data
        min_data_in_leaf = 2
        
        # minimal sum hessians for one leaf, use this to deal with over-fit
        #min_sum_hessian_in_leaf = 5.0
        
        # save memory and faster speed for sparse feature, alias: is_sparse
        is_enable_sparse = true
        
        # when data is bigger than memory size, set this to true. otherwise set false will have faster speed
        # alias: two_round_loading, two_round
        use_two_round_loading = true
        
        # true if need to save data to binary file and application will auto load data from binary file next time
        # alias: is_save_binary, save_binary
        is_save_binary_file = false

        # output model file
        output_model = #wk_dir/lgbm.model
        
        '''.replace('#wk_dir',self.wk_dir)
        
        predict_conf_str = '''
        task = predict
        #data = binary.test
        input_model= #wk_dir/lgbm.model
        
        
        '''.replace('#wk_dir',self.wk_dir)
        
        open(self.wk_dir + '/train.conf','w').write(train_conf_str)
        open(self.wk_dir + '/predict.conf','w').write(predict_conf_str)
    
    def __init__(self, exe_path, wk_dir = os.path.join(os.getcwd(),'lgbm_files'), log_file_name = 'log'):
        '''
        exe_path - путь к выполняемому файлу LightGBM.
        wk_dir - рабочая директория с конфиг файлами, моделью, логами
        log_file_name - имя файла с логами.
        '''
        self.exe_path = exe_path
        self.wk_dir = wk_dir
        self.log_file_name = os.path.join(wk_dir, log_file_name)
        os.popen('mkdir -p ' + self.wk_dir).read()
        self.set_params()
    
    def train(self, train_file_path,valid_file_path = None):
        '''
        Train model. Train data must be in libsvm format.
        '''
        os.popen(self.exe_path +' config=' + self.wk_dir + 
                      '/train.conf data=' + train_file_path + 
                      (' valid=' + valid_file_path if valid_file_path else '') + 
                      ' >> ' + self.log_file_name
                ).read()
        
    def show_log(self, last_rows_num = None):
        if last_rows_num:
            return os.popen('tail -' + str(last_rows_num) + ' ' + self.log_file_name).read()
        else:
            return os.popen('cat ' + self.log_file_name).read()
    
    def predict(self, data_file_path, output_result = None):
        os.popen(self.exe_path +' config=' + self.wk_dir + 
                      '/predict.conf data=' + data_file_path +                       
                    ' output_result=' + (output_result if output_result else self.wk_dir + '/predict.txt')
                ).read()
    
    def metrics(self, data_file_path,model_path = None, output_result = None, lift = None, return_str = False):
        ''' 
            Predict data file with model and calculate performance metrics.
            Metrics: 
              sample size,
              positive class share,
              AUC ROC,
              AUC precision recall,
              Logloss,
              Lift (optional). If present, lift ( lift param: list of floats, each from 0 to 1)  calculated.
            Returns dict.
        
        '''
        import sklearn
        import collections

        if not model_path:
            model_path = self.wk_dir + '/lgbm.model'        
        if not output_result:
            output_result = self.wk_dir + '/predict.txt'
            
        self.predict(data_file_path, output_result)
        
        #get labels
        os.popen("perl -ne 'print substr($_,0,1)' " + data_file_path + ' > ' + self.wk_dir + '/labels.txt').read()
        
        y_true = [int(e) for e in open(self.wk_dir + '/labels.txt','r').read()]
        y_score = [float(e.strip('\n')) for e in open(output_result,'r').readlines()]
        
        res = collections.OrderedDict()
        samp_size = len(y_true)
        res['Sample size'] = samp_size
        res['Posit share'] = sum(y_true) * 1./ samp_size
        res['Sample size'] = len(y_true)
        res['AUC ROC'] = sklearn.metrics.roc_auc_score(y_true = y_true, y_score = y_score)
        res['AUC PR'] = sklearn.metrics.auc(
                        *sklearn.metrics.precision_recall_curve(y_true = y_true, probas_pred  = y_score)[:2],
                        reorder = True
        )
        res['Log loss'] = sklearn.metrics.log_loss(y_true = y_true, y_pred = y_score)
        if lift:
            predictions_and_labels = sorted(zip(y_score,y_true), reverse = True)
            for l in lift:
                res['Lift ' + str(l)] = sum([e[1] for e in predictions_and_labels[:int(l * samp_size)]]) * 1. / int(l * samp_size) / res['Posit share']
                
        if return_str:
            res = '\n'.join(['{:<12}: {:.5f}'.format(k,v) for (k,v) in res.items()]) + '.'
        return res

    def get_model_path(self):
        '''Returns path with model file.'''
        return self.wk_dir + '/lgbm.model'

# %%
lgbm = LGBM(exe_path = '/data1/share/LightGBM/lightgbm',wk_dir = os.getcwd() + '/lgbm_url_text')
output_result = lgbm.wk_dir + '/predict.txt'
m1 = lgbm.metrics(data_file_path = '/data1/share/kosm/data/url_text_valid_libsvm.txt',lift = [0.01,0.05,0.1,0.2],return_str = True)

print(m1)
# Out:
# Sample size : 57000.00000
# Posit share : 0.05861
# AUC ROC     : 0.64749
# AUC PR      : 0.07453
# Log loss    : 0.63168
# Lift 0.01   : 2.93325
# Lift 0.05   : 2.07124
# Lift 0.1    : 2.14606
# Lift 0.2    : 1.85573.

# %% [markdown]
# ###То же на tf данных

# %%
#! ls /data1/share/kosm/data/ | grep tf_
#! head -250000 /data1/share/kosm/data/url_text_train_tf_libsvm.txt > /data1/share/kosm/data/url_text_train_train_tf_libsvm.txt
#! tail -37000 /data1/share/kosm/data/url_text_train_tf_libsvm.txt > /data1/share/kosm/data/url_text_valid_tf_libsvm.txt
train_file_path = '/data1/share/kosm/data/url_text_train_train_tf_libsvm.txt'
valid_file_path = '/data1/share/kosm/data/url_text_valid_tf_libsvm.txt'
lgbmtf = LGBM(exe_path = '/data1/share/LightGBM/lightgbm',wk_dir = os.getcwd() + '/lgbm_url_text_tf')
lgbmtf.train( train_file_path,valid_file_path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-120-b87d40f54c91> in <module>()
#       5 valid_file_path = '/data1/share/kosm/data/url_text_valid_tf_libsvm.txt'
#       6 lgbmtf = LGBM(exe_path = '/data1/share/LightGBM/lightgbm',wk_dir = os.getcwd() + '/lgbm_url_text_tf')
# ----> 7 lgbmtf.train( train_file_path,valid_file_path)
#
# <ipython-input-101-b35eeaf0ee21> in train(self, train_file_path, valid_file_path)
#     143                       '/train.conf data=' + train_file_path +
#     144                       (' valid=' + valid_file_path if valid_file_path else '') +
# --> 145                       ' >> ' + self.log_file_name
#     146                 ).read()
#     147
#
# KeyboardInterrupt:

# %%
lgbmtf.show_log(200)

# %%
sc.stop()

# %%
import scipy
import pandas as pd

df = pd.DataFrame([[int(e) for e in r.split('\t')] for r in '1740	192	25	4\n2038	129	51	7'.split('\n')],
                  columns = 'total fullapp approve util'.split()
                  )
for i in range(len(df.columns)-1):
    c1 = df.columns[i]
    c2 = df.columns[i+1]
    print('Fisher exact test p-value for {} vs {} is {}.'.format(c1,c2,scipy.stats.fisher_exact(df[[c1,c2]],'greater')[1]))
# Out:
# Fisher exact test p-value for total vs fullapp is 0.999999212.
# Fisher exact test p-value for fullapp vs approve is 1.8978434252e-05.
# Fisher exact test p-value for approve vs util is 0.721636923691.
